# %%
#!/usr/bin/env python
# coding: utf-8

# ============================================================
# CT Cascade 학습 스크립트
#
# [구조 개요]
#   1단계: malignancy binary classification (benign / malignant)
#   2단계: malignant 샘플에 대해서만 subtype multi-class classification
#
# [원본 대비 주요 수정 사항]
#   1. inspect_fold_npz 오타 수정: .exits() → .exists()
#   2. infer_malignant_type_ids 들여쓰기 버그 수정
#      (return이 fold loop 안에 있어 fold 1 결과만 반환하던 문제)
#   3. cascade_correct 인덱스 불일치 버그 수정
#      (oracle_pred/oracle_true는 all_mal_mask 기준,
#       all_mal_pred[gt_mal_mask]는 gt_mal_mask 기준 → 길이 불일치)
#   4. fit_model print 오타 수정: 콤마로 분리된 f-string → 하나로 합침
#   5. 모델 구조 개선:
#      - shared head 이후 task별 projection(mal_proj / sub_proj) 분리
#      - early stopping 기준: val_loss → val_auc (malignancy recall 중심)
#      - subtype_loss_weight warmup 스케줄 추가
# ============================================================


# ============================================================
# 빌드 확인
# ============================================================
from torchvision import models
from torchvision.models import vit_b_16

print("=" * 60)

try:
    m1 = models.resnet50(weights=None)
    print("ResNet50 build success")
except Exception as e:
    print("Fail", e)

try:
    m2 = vit_b_16(weights=None)
    print("Vit-B/16 build success")
except Exception as e:
    print("Fail", e)

print("=" * 60)


# ============================================================
# 1) 환경 설정 + import
# ============================================================
import os
import gc
import random
import torchvision.transforms.functional as TF
from pathlib import Path
from collections import OrderedDict, defaultdict

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.metrics import (
    confusion_matrix, classification_report,
    accuracy_score, f1_score, roc_auc_score, recall_score
)

import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
from torchvision import models
from torchvision.models import vit_b_16, ViT_B_16_Weights, ResNet50_Weights

SEED = 42
random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)
torch.cuda.manual_seed_all(SEED)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Device:", device)

# cuDNN autotuner: 입력 크기가 고정일 때 속도 향상
torch.backends.cudnn.benchmark = True


# ============================================================
# 2) 경로 / 하이퍼파라미터 설정
# ============================================================
print(f"현재 작업 경로: {os.getcwd()}")

DATA_ROOT  = Path("/tf/nasw/dataset001/preprocessed/npz_us")
FOLDS      = [1, 2, 3, 4, 5]

OUTPUT_DIR = Path("./us_cascade_models")
OUTPUT_DIR.mkdir(parents=True, exist_ok=True)

IMG_SIZE     = 224
BATCH_SIZE   = 8
NUM_WORKERS  = 2
NUM_EPOCHS   = 30
LR           = 1e-4
WEIGHT_DECAY = 1e-4
PATIENCE     = 7
MIN_DELTA    = 0.001
THRESHOLD    = 0.5   # malignancy 판단 임계값

# subtype loss 가중치 warmup 설정
# - 학습 초반에는 malignancy 분류에 집중하고,
#   후반부로 갈수록 subtype loss 비중을 점진적으로 높임
SUBTYPE_LOSS_WEIGHT_START = 0.5   # 1 epoch 시작값
SUBTYPE_LOSS_WEIGHT_END   = 0.8   # NUM_EPOCHS epoch 도달값

print("DATA_ROOT:", DATA_ROOT)
print("OUTPUT_DIR:", OUTPUT_DIR.resolve())
print("FOLDS:", FOLDS)


# ============================================================
# 3) 로컬 pretrained weight 경로
# ============================================================
LOCAL_RESNET_WEIGHTS = Path("/tf/pretrained_model/resnet50-11ad3fa6.pth")
LOCAL_VIT_WEIGHTS    = Path("/tf/pretrained_model/vit_b_16-c867db91.pth")

print("LOCAL_RESNET_WEIGHTS exists:", LOCAL_RESNET_WEIGHTS.exists())
print("LOCAL_VIT_WEIGHTS exists:",    LOCAL_VIT_WEIGHTS.exists())


# ============================================================
# 4) 유틸 함수
# ============================================================
def load_local_state_dict(weight_path):
    weight_path = Path(weight_path)
    assert weight_path.exists(), f"Weight file not found: {weight_path}"

    ckpt = torch.load(weight_path, map_location="cpu")

    # 일부 checkpoint는 {"state_dict": {...}} 형태로 저장되어 있음
    if isinstance(ckpt, dict) and "state_dict" in ckpt and isinstance(ckpt["state_dict"], dict):
        ckpt = ckpt["state_dict"]

    return ckpt


def inspect_fold_npz(fold_idx):
    train_npz_path = DATA_ROOT / f"fold_{fold_idx}_train.npz"
    val_npz_path   = DATA_ROOT / f"fold_{fold_idx}_val.npz"

    # ✅ 버그 수정: .exits() → .exists()
    print("TRAIN:", train_npz_path, train_npz_path.exists())
    print("VAL:",   val_npz_path,   val_npz_path.exists())

    train_npz = np.load(train_npz_path, allow_pickle=False, mmap_mode="r")
    val_npz   = np.load(val_npz_path,   allow_pickle=False, mmap_mode="r")

    for k in train_npz.files:
        print(f"[train] {k}: shape={train_npz[k].shape}, dtype={train_npz[k].dtype}")
    for k in val_npz.files:
        print(f"[val]   {k}: shape={val_npz[k].shape}, dtype={val_npz[k].dtype}")


def get_subtype_loss_weight(epoch: int, total_epochs: int) -> float:
    """
    subtype loss 가중치를 epoch에 따라 선형 warmup.

    epoch 1  → SUBTYPE_LOSS_WEIGHT_START
    epoch N  → SUBTYPE_LOSS_WEIGHT_END
    사이는 선형 보간.

    이유: 학습 초반 malignancy gate가 불안정할 때
    subtype loss가 너무 크면 전체 학습을 방해할 수 있음.
    """
    t = (epoch - 1) / max(total_epochs - 1, 1)   # 0.0 ~ 1.0
    return SUBTYPE_LOSS_WEIGHT_START + t * (SUBTYPE_LOSS_WEIGHT_END - SUBTYPE_LOSS_WEIGHT_START)


# ============================================================
# 5) malignant subtype ID 자동 추론
# ============================================================
def infer_malignant_type_ids(data_root, folds):
    """
    NPZ 파일에서 tumor_type별로 label(0/1)을 수집하여
    항상 malignant(label=1)인 tumor_type ID 목록을 자동 추론.

    ✅ 버그 수정: 원본은 return이 fold loop 안에 있어서
       fold 1 처리 후 바로 반환되는 문제가 있었음.
       loop 밖으로 conflicts 체크와 return을 이동.
    """
    # tumor_type별로 등장한 label 값들을 수집
    label_set_by_type = defaultdict(set)

    for fold_idx in folds:
        for split_name in ["train", "val"]:
            npz_path = Path(data_root) / f"fold_{fold_idx}_{split_name}.npz"
            data     = np.load(npz_path, allow_pickle=False, mmap_mode="r")

            labels      = data["labels"].astype(int)
            tumor_types = data["tumor_types"].astype(int)

            for y, t in zip(labels, tumor_types):
                label_set_by_type[int(t)].add(int(y))

    # ✅ loop 종료 후 한 번만 체크 (원본: loop 안에서 매 fold마다 체크 후 return)
    # 동일 tumor_type이 benign/malignant 양쪽에 있으면 데이터 오류
    conflicts = {
        t: sorted(list(v))
        for t, v in label_set_by_type.items()
        if len(v) > 1
    }
    if len(conflicts) > 0:
        raise ValueError(
            f"tumor_type이 양성/악성 양쪽에 섞여 있음: {conflicts}\n"
            "데이터 전처리를 확인하세요."
        )

    # label이 {1}만인 tumor_type만 malignant subtype으로 간주
    malignant_type_ids = sorted([
        t for t, labs in label_set_by_type.items()
        if labs == {1}
    ])

    print("malignant_type_ids:", malignant_type_ids)
    return malignant_type_ids


MALIGNANT_TYPE_IDS     = infer_malignant_type_ids(DATA_ROOT, FOLDS)
MALIGNANT_MAP          = {tid: i for i, tid in enumerate(MALIGNANT_TYPE_IDS)}
NUM_MALIGNANT_SUBTYPES = len(MALIGNANT_TYPE_IDS)

print("MALIGNANT_MAP:", MALIGNANT_MAP)
print("NUM_MALIGNANT_SUBTYPES:", NUM_MALIGNANT_SUBTYPES)

#=============================================================
# 5.5) 실시간 증강 모듈
#=============================================================

class CTSliceAugmentor:
    def __init__(
        self,
        p_hflip: float = 0.5,
        p_vflip: float = 0.0,
        p_rotate: float = 0.5,
        max_angle: float = 17.0,
        p_crop: float = 0.5,
        crop_min: float = 0.8,
        p_noise: float = 0.1,
        noise_std: float = 0.005,
    ):
        self.p_hflip = p_hflip
        self.p_vflip = p_vflip
        self.p_rotate = p_rotate
        self.max_angle = max_angle
        self.p_crop = p_crop
        self.crop_min = crop_min
        self.p_noise = p_noise
        self.noise_std = noise_std


    def __call__(self, imgs):
        S, C, H, W = imgs.shape

        do_hflip = random.random() < self.p_hflip
        do_vflip = random.random() < self.p_vflip
        do_rotate = random.random() < self.p_rotate
        angle = random.uniform(-self.max_angle, self.max_angle) if do_rotate else 0.0
        do_crop = random.random() < self.p_crop
        do_noise = random.random() < self.p_noise

        top = left = crop_h = crop_w = 0
        if do_crop:
            scale = random.uniform(self.crop_min, 1.0)
            crop_h = int(H*scale)
            crop_w = int(W*scale)
            top = random.randint(0, H-crop_h)
            left = random.randint(0, W-crop_w)

        augmented = []
        for s in range(S):
            img = imgs[s]
            if do_hflip:
                img = TF.hflip(img)
            if do_vflip:
                img = TF.vflip(img)
            if do_rotate:
                img = TF.rotate(img, angle, interpolation = TF.InterpolationMode.BILINEAR, fill=0)
            if do_crop:
                img = TF.crop(img, top, left, crop_h, crop_w)
                img = TF.resize(img, [H,W], interpolation=TF.InterpolationMode.BILINEAR, antialias=True)
            augmented.append(img)

        imgs=torch.stack(augmented, dim = 0)

        if do_noise:
            imgs = (imgs + torch.randn_like(imgs) * self.noise_std).clamp(0.0, 1.0)

        return imgs


TRAIN_AUGMENTOR = CTSliceAugmentor(
    p_hflip = 0.5, p_vflip = 0.0, p_rotate=0.5, max_angle = 10.0,
    p_crop = 0.5, crop_min = 0.85, p_noise = 0.3, noise_std = 0.01,
)

def _worker_init_fn(worker_id):
    worker_seed = torch.initial_seed() % (2**32)
    np.random.seed(worker_seed)
    random.seed(worker_seed)
    


# ============================================================
# 6) Dataset 정의
# ============================================================
class OvarianCTNPZDataset(Dataset):
    def __init__(self, npz_path, is_train=True):
        super().__init__()
        self.npz = np.load(npz_path, allow_pickle=False, mmap_mode="r")

        self.images      = self.npz["images"]
        self.labels      = self.npz["labels"].astype(np.float32)
        self.tumor_types = self.npz["tumor_types"].astype(np.int64)

        # patient_ids가 없으면 인덱스로 대체
        self.patient_ids = (
            self.npz["patient_ids"]
            if "patient_ids" in self.npz.files
            else np.arange(len(self.labels))
        )

        # ImageNet 정규화 상수 (CT/US 공통으로 사용 가능)
        self.mean = torch.tensor([0.485, 0.456, 0.406], dtype=torch.float32).view(1, 3, 1, 1)
        self.std  = torch.tensor([0.229, 0.224, 0.225], dtype=torch.float32).view(1, 3, 1, 1)

        self.augmentor = TRAIN_AUGMENTOR if is_train else None

    def __len__(self):
        return len(self.labels)

    def __getitem__(self, idx):
        x           = self.images[idx]
        y           = int(self.labels[idx])
        tumor_type  = int(self.tumor_types[idx])

        # NPZ 저장 형태: [S, H, W, C] → [S, C, H, W]
        x = torch.from_numpy(np.array(x)).float().permute(0, 3, 1, 2).contiguous()
        x = x / 255.0

        if self.augmentor is not None:
            x = self.augmentor(x)
            
        x = (x - self.mean) / self.std

        # malignant 샘플에만 subtype label 부여
        if y == 1:
            if tumor_type not in MALIGNANT_MAP:
                raise ValueError(
                    f"malignant sample인데 tumor_type={tumor_type}가 MALIGNANT_MAP에 없음. "
                    f"infer_malignant_type_ids 결과 확인 필요."
                )
            mal_subtype = MALIGNANT_MAP[tumor_type]
            mal_mask    = True
        else:
            # benign은 subtype 없음 → -1로 패딩 (loss 계산 시 mal_mask로 필터링)
            mal_subtype = -1
            mal_mask    = False

        return {
            "image":       x,
            "label":       torch.tensor(y, dtype=torch.float32),
            "mal_subtype": torch.tensor(mal_subtype, dtype=torch.long),
            "mal_mask":    torch.tensor(mal_mask, dtype=torch.bool),
        }


# ============================================================
# 7) fold별 DataLoader 생성
# ============================================================
def make_fold_loaders(fold_idx):
    train_npz_path = DATA_ROOT / f"fold_{fold_idx}_train.npz"
    val_npz_path   = DATA_ROOT / f"fold_{fold_idx}_val.npz"

    assert train_npz_path.exists(), f"Missing: {train_npz_path}"
    assert val_npz_path.exists(),   f"Missing: {val_npz_path}"

    train_dataset = OvarianCTNPZDataset(train_npz_path, is_train=True)
    val_dataset   = OvarianCTNPZDataset(val_npz_path, is_train=False)

    train_loader = DataLoader(
        train_dataset,
        batch_size=BATCH_SIZE,
        shuffle=True,
        num_workers=NUM_WORKERS,
        pin_memory=True,
        worker_init_fn = _worker_init_fn,
        persistent_workers = (NUM_WORKERS > 0),
    )
    val_loader = DataLoader(
        val_dataset,
        batch_size=BATCH_SIZE,
        shuffle=False,
        num_workers=NUM_WORKERS,
        pin_memory=True
    )

    # ── malignancy pos_weight ────────────────────────────────
    # benign/malignant 불균형 보정: neg/pos 비율로 BCEWithLogitsLoss에 전달
    labels_np        = train_dataset.labels.astype(int)
    neg              = (labels_np == 0).sum()
    pos              = (labels_np == 1).sum()
    pos_weight_value = neg / max(pos, 1)
    mal_pos_weight   = torch.tensor([pos_weight_value], device=device, dtype=torch.float32)

    # ── subtype class weight ─────────────────────────────────
    # subtype별 샘플 수 역수로 class weight 계산 (inv mean normalization)
    subtype_counts = np.zeros(NUM_MALIGNANT_SUBTYPES, dtype=np.float64)
    for y, t in zip(train_dataset.labels.astype(int), train_dataset.tumor_types.astype(int)):
        if y == 1 and t in MALIGNANT_MAP:
            subtype_counts[MALIGNANT_MAP[t]] += 1.0

    subtype_counts       = np.maximum(subtype_counts, 1.0)   # 0 나누기 방지
    inv                  = 1.0 / subtype_counts
    subtype_class_weights = inv / inv.mean()                  # 평균 1로 정규화
    subtype_class_weights = torch.tensor(subtype_class_weights, dtype=torch.float32, device=device)

    print(
        f"[FOLD {fold_idx}] Train benign(0): {neg}, malignant(1): {pos}, "
        f"pos_weight={mal_pos_weight.item():.4f}, "
        f"subtype_counts={subtype_counts.tolist()}, "
        f"subtype_class_weights={subtype_class_weights.detach().cpu().numpy().round(4).tolist()}"
    )

    return train_loader, val_loader, mal_pos_weight, subtype_class_weights


# ============================================================
# 8) Cascade 손실 함수
# ============================================================
class CascadeCriterion(nn.Module):
    def __init__(self, pos_weight, subtype_class_weights, subtype_loss_weight=0.5):
        """
        Args:
            pos_weight           : BCEWithLogitsLoss의 pos_weight (malignancy)
            subtype_class_weights: CrossEntropyLoss의 class weight (subtype)
            subtype_loss_weight  : subtype loss를 얼마나 반영할지 가중치
                                   epoch마다 외부에서 업데이트 가능
        """
        super().__init__()
        self.bce               = nn.BCEWithLogitsLoss(pos_weight=pos_weight)
        self.ce                = nn.CrossEntropyLoss(weight=subtype_class_weights)
        self.subtype_loss_weight = subtype_loss_weight

    def forward(self, outputs, batch):
        labels      = batch["label"].to(device).view(-1)        # [B]
        mal_mask    = batch["mal_mask"].to(device).view(-1)     # [B] bool
        mal_subtype = batch["mal_subtype"].to(device).view(-1)  # [B]

        # malignancy binary loss (benign/malignant 전체 샘플)
        loss_m = self.bce(outputs["malignancy_logits"], labels)

        # subtype loss (malignant 샘플만)
        # mal_mask=True인 샘플만 필터링해서 CrossEntropyLoss 계산
        if mal_mask.any():
            loss_s = self.ce(
                outputs["subtype_logits"][mal_mask],
                mal_subtype[mal_mask]
            )
        else:
            # batch 안에 malignant 샘플이 없는 경우 (소규모 데이터에서 발생 가능)
            loss_s = torch.tensor(0.0, device=device)

        loss_total = loss_m + self.subtype_loss_weight * loss_s

        return {
            "loss_total":      loss_total,
            "loss_malignancy": loss_m,
            "loss_subtype":    loss_s,
        }


# ============================================================
# 9) 지표 계산 함수
# ============================================================
def compute_binary_metrics(y_true, y_prob, threshold=0.5):
    y_true = np.asarray(y_true).astype(int)
    y_prob = np.asarray(y_prob).astype(float)
    y_pred = (y_prob >= threshold).astype(int)

    return {
        "acc":    accuracy_score(y_true, y_pred),
        "auc":    roc_auc_score(y_true, y_prob) if len(np.unique(y_true)) > 1 else 0.5,
        "f1":     f1_score(y_true, y_pred, zero_division=0),
        "recall": recall_score(y_true, y_pred, zero_division=0),
        "cm":     confusion_matrix(y_true, y_pred),
    }


def compute_multiclass_metrics(y_true, y_pred):
    y_true = np.asarray(y_true).astype(int)
    y_pred = np.asarray(y_pred).astype(int)

    if len(y_true) == 0:
        return {"acc": np.nan, "macro_f1": np.nan, "macro_recall": np.nan, "cm": None}

    return {
        "acc":          accuracy_score(y_true, y_pred),
        "macro_f1":     f1_score(y_true, y_pred, average="macro", zero_division=0),
        "macro_recall": recall_score(y_true, y_pred, average="macro", zero_division=0),
        "cm":           confusion_matrix(y_true, y_pred),
    }


# ============================================================
# 10) train / eval 함수
# ============================================================
scaler = torch.amp.GradScaler(enabled=(device.type == "cuda"))


def _compute_cascade_metrics(
    all_label, all_mal_prob, all_mal_mask,
    all_subtype_true, all_subtype_pred,
    running_total, running_m, running_s,
    n_samples,
):
    """
    train_one_epoch / eval_one_epoch 공통 지표 계산 로직.
    중복 코드를 줄이기 위해 분리.

    ✅ 버그 수정: cascade_correct 인덱스 불일치 수정
        - oracle_pred / oracle_true: all_mal_mask(GT malignant) 기준으로 필터링된 배열
        - all_mal_pred[gt_mal_mask]: GT malignant 샘플에 대한 예측값
        - 위 두 배열의 길이는 동일 (gt_mal_mask == all_mal_mask)
        - 원본 코드는 all_mal_mask 대신 mal_mask를 별도로 쓰거나
          배열 길이가 맞지 않는 경우 발생 → gt_mal_mask로 통일하여 수정
    """
    mal_metrics = compute_binary_metrics(all_label, all_mal_prob, threshold=THRESHOLD)

    all_label        = np.asarray(all_label).astype(int)
    all_mal_pred     = (np.asarray(all_mal_prob) >= THRESHOLD).astype(int)
    all_mal_mask     = np.asarray(all_mal_mask).astype(bool)
    all_subtype_true = np.asarray(all_subtype_true).astype(int)
    all_subtype_pred = np.asarray(all_subtype_pred).astype(int)

    # oracle subtype: GT가 malignant인 샘플에 대해서만 subtype 평가
    # (malignancy gate의 영향 없이, subtype head 자체 성능 측정)
    oracle_true    = all_subtype_true[all_mal_mask]
    oracle_pred    = all_subtype_pred[all_mal_mask]
    subtype_oracle = compute_multiclass_metrics(oracle_true, oracle_pred)

    # cascade subtype: GT malignant 샘플 중
    #   ① malignancy gate도 malignant로 예측하고 (gate pass)
    #   ② subtype도 맞춰야 정답
    gt_mal_mask = all_mal_mask   # GT label == 1인 샘플 = mal_mask와 동일

    if gt_mal_mask.sum() > 0:
        gate_pass = all_mal_pred[gt_mal_mask] == 1   # gate 통과 여부 [N_mal]

        # ✅ oracle_pred는 gt_mal_mask 기준으로 필터링된 배열이므로 길이 일치
        subtype_correct = oracle_pred == oracle_true  # subtype 정답 여부 [N_mal]

        gate_recall          = gate_pass.mean()
        # cascade 정답 = gate도 통과하고 subtype도 맞아야 함
        subtype_cascade_acc  = (gate_pass & subtype_correct).mean()
    else:
        gate_recall         = np.nan
        subtype_cascade_acc = np.nan

    return {
        "loss":           running_total / n_samples,
        "loss_malignancy": running_m / n_samples,
        "loss_subtype":   running_s / n_samples,

        # malignancy 지표
        "acc":    mal_metrics["acc"],
        "auc":    mal_metrics["auc"],
        "f1":     mal_metrics["f1"],
        "recall": mal_metrics["recall"],
        "cm":     mal_metrics["cm"],

        # subtype oracle 지표 (gate 무관, subtype head 자체 성능)
        "subtype_oracle_acc":      subtype_oracle["acc"],
        "subtype_oracle_macro_f1": subtype_oracle["macro_f1"],
        "subtype_oracle_cm":       subtype_oracle["cm"],

        # cascade 지표 (gate + subtype 통합 성능)
        "subtype_cascade_acc":  float(subtype_cascade_acc),
        "subtype_gate_recall":  float(gate_recall),
    }


def train_one_epoch(model, loader, criterion, optimizer, device):
    model.train()

    running_total, running_m, running_s = 0.0, 0.0, 0.0
    all_label        = []
    all_mal_prob     = []
    all_mal_mask     = []
    all_subtype_true = []
    all_subtype_pred = []

    for batch in loader:
        imgs = batch["image"].to(device, non_blocking=True)

        optimizer.zero_grad()

        with torch.amp.autocast(device_type="cuda", enabled=(device.type == "cuda")):
            outputs   = model(imgs)
            loss_dict = criterion(outputs, batch)
            loss      = loss_dict["loss_total"]

        scaler.scale(loss).backward()
        scaler.step(optimizer)
        scaler.update()

        bs             = imgs.size(0)
        running_total += loss_dict["loss_total"].item() * bs
        running_m     += loss_dict["loss_malignancy"].item() * bs
        running_s     += loss_dict["loss_subtype"].item() * bs

        # CPU로 이동 후 numpy 변환
        label_np        = batch["label"].detach().cpu().numpy().astype(int).ravel()
        mal_mask_np     = batch["mal_mask"].detach().cpu().numpy().astype(bool).ravel()
        mal_prob_np     = torch.sigmoid(outputs["malignancy_logits"]).detach().cpu().numpy().ravel()
        subtype_pred_np = outputs["subtype_logits"].argmax(dim=1).detach().cpu().numpy().astype(int).ravel()
        subtype_true_np = batch["mal_subtype"].detach().cpu().numpy().astype(int).ravel()

        all_label.extend(label_np.tolist())
        all_mal_prob.extend(mal_prob_np.tolist())
        all_mal_mask.extend(mal_mask_np.tolist())
        all_subtype_true.extend(subtype_true_np.tolist())
        all_subtype_pred.extend(subtype_pred_np.tolist())

    return _compute_cascade_metrics(
        all_label, all_mal_prob, all_mal_mask,
        all_subtype_true, all_subtype_pred,
        running_total, running_m, running_s,
        len(loader.dataset),
    )


@torch.no_grad()
def eval_one_epoch(model, loader, criterion, device):
    model.eval()

    running_total, running_m, running_s = 0.0, 0.0, 0.0
    all_label        = []
    all_mal_prob     = []
    all_mal_mask     = []
    all_subtype_true = []
    all_subtype_pred = []

    for batch in loader:
        imgs = batch["image"].to(device, non_blocking=True)

        with torch.amp.autocast(device_type="cuda", enabled=(device.type == "cuda")):
            outputs   = model(imgs)
            loss_dict = criterion(outputs, batch)

        bs             = imgs.size(0)
        running_total += loss_dict["loss_total"].item() * bs
        running_m     += loss_dict["loss_malignancy"].item() * bs
        running_s     += loss_dict["loss_subtype"].item() * bs

        label_np        = batch["label"].detach().cpu().numpy().astype(int).ravel()
        mal_mask_np     = batch["mal_mask"].detach().cpu().numpy().astype(bool).ravel()
        mal_prob_np     = torch.sigmoid(outputs["malignancy_logits"]).detach().cpu().numpy().ravel()
        subtype_pred_np = outputs["subtype_logits"].argmax(dim=1).detach().cpu().numpy().astype(int).ravel()
        subtype_true_np = batch["mal_subtype"].detach().cpu().numpy().astype(int).ravel()

        all_label.extend(label_np.tolist())
        all_mal_prob.extend(mal_prob_np.tolist())
        all_mal_mask.extend(mal_mask_np.tolist())
        all_subtype_true.extend(subtype_true_np.tolist())
        all_subtype_pred.extend(subtype_pred_np.tolist())

    return _compute_cascade_metrics(
        all_label, all_mal_prob, all_mal_mask,
        all_subtype_true, all_subtype_pred,
        running_total, running_m, running_s,
        len(loader.dataset),
    )


@torch.no_grad()
def eval_confusion(model, loader, criterion, device, threshold=0.5):
    """최종 평가 + classification report 출력."""
    metrics = eval_one_epoch(model, loader, criterion, device)

    print("\n-- Final Evaluation --")
    print(f"[Malignancy]  AUC={metrics['auc']:.4f}, F1={metrics['f1']:.4f}, Recall={metrics['recall']:.4f}, Acc={metrics['acc']:.4f}")
    print(f"[Subtype Oracle]  Acc={metrics['subtype_oracle_acc']:.4f}, MacroF1={metrics['subtype_oracle_macro_f1']:.4f}")
    print(f"[Cascade]  SubtypeAcc={metrics['subtype_cascade_acc']:.4f}, GateRecall={metrics['subtype_gate_recall']:.4f}")
    print("Binary CM:")
    print(metrics["cm"])
    print("Subtype Oracle CM:")
    print(metrics["subtype_oracle_cm"])

    return metrics


# ============================================================
# 11) 모델 정의
# ============================================================

# ── 공통 Attention Pooling + Dual Head Classifier ────────────
class PatientSliceAttentionClassifier(nn.Module):
    """
    [구조 개선]
    원본: shared → malignancy_head / subtype_head (동일 표현 공유)
    수정: shared → mal_proj → malignancy_head
                 → sub_proj → subtype_head

    이유: malignancy 판단(global 패턴)과 subtype 분류(세부 형태 패턴)는
    집중해야 할 특징이 달라서 task별 projection을 추가하면 각 head가
    더 특화된 표현을 학습할 수 있음.
    """
    def __init__(self, encoder, feat_dim, hidden_dim=512, proj_dim=256, dropout=0.1):
        super().__init__()
        self.encoder = encoder

        # slice 간 중요도 attention (슬라이스별 가중합 풀링)
        self.attn = nn.Sequential(
            nn.Linear(feat_dim, feat_dim // 2),
            nn.Tanh(),
            nn.Linear(feat_dim // 2, 1),
        )

        # 공통 표현 추출
        self.shared = nn.Sequential(
            nn.Linear(feat_dim, hidden_dim),
            nn.ReLU(),
            nn.Dropout(dropout),
        )

        # ── task별 projection (개선 포인트) ──────────────────
        # malignancy: 양성/악성 global 구분에 집중
        self.mal_proj = nn.Sequential(
            nn.Linear(hidden_dim, proj_dim),
            nn.ReLU(),
            nn.Dropout(dropout),
        )
        # subtype: 악성 내 세부 형태 패턴 분류에 집중
        self.sub_proj = nn.Sequential(
            nn.Linear(hidden_dim, proj_dim),
            nn.ReLU(),
            nn.Dropout(dropout),
        )

        self.malignancy_head = nn.Linear(proj_dim, 1)
        self.subtype_head    = nn.Linear(proj_dim, NUM_MALIGNANT_SUBTYPES)

    def forward(self, x):
        # x: (B, S, C, H, W)
        B, S, C, H, W = x.shape
        x = x.view(B * S, C, H, W)

        feat = self.encoder(x)           # (B*S, feat_dim)
        feat = feat.view(B, S, -1)       # (B, S, feat_dim)

        # attention pooling
        attn_score  = self.attn(feat)                    # (B, S, 1)
        attn_weight = torch.softmax(attn_score, dim=1)
        pooled      = (feat * attn_weight).sum(dim=1)    # (B, feat_dim)

        # 공통 → task별 분기
        z     = self.shared(pooled)    # (B, hidden_dim)
        z_mal = self.mal_proj(z)       # (B, proj_dim)
        z_sub = self.sub_proj(z)       # (B, proj_dim)

        return {
            # squeeze(1): [B,1] → [B]  (BCEWithLogitsLoss 입력 형태)
            "malignancy_logits": self.malignancy_head(z_mal).squeeze(1),
            "subtype_logits":    self.subtype_head(z_sub),   # (B, NUM_MALIGNANT_SUBTYPES)
        }


# ── ResNet50 기반 모델 ────────────────────────────────────────
def build_resnet50_patient_model(
    load_pretrained=True,
    freeze_backbone=True,
    unfreeze_layer4=True,
    weight_path=LOCAL_RESNET_WEIGHTS,
):
    encoder = models.resnet50(weights=None)

    if load_pretrained:
        state_dict = load_local_state_dict(weight_path)
        encoder.load_state_dict(state_dict, strict=True)

    feat_dim   = encoder.fc.in_features   # 2048
    encoder.fc = nn.Identity()

    if freeze_backbone:
        for p in encoder.parameters():
            p.requires_grad = False
        if unfreeze_layer4:
            # layer4만 fine-tuning (고수준 특징 추출 레이어)
            for p in encoder.layer4.parameters():
                p.requires_grad = True

    model = PatientSliceAttentionClassifier(
        encoder=encoder,
        feat_dim=feat_dim,
        hidden_dim=512,
        proj_dim=256,
        dropout=0.3,
    )
    return model


# ── ViT-B/16 기반 모델 ───────────────────────────────────────
def build_vit_patient_model(
    load_pretrained=True,
    weight_path=LOCAL_VIT_WEIGHTS,
):
    encoder = vit_b_16(weights=None)

    if load_pretrained:
        state_dict = load_local_state_dict(weight_path)
        encoder.load_state_dict(state_dict, strict=True)

    feat_dim      = encoder.heads.head.in_features   # 768
    encoder.heads = nn.Identity()

    model = PatientSliceAttentionClassifier(
        encoder=encoder,
        feat_dim=feat_dim,
        hidden_dim=512,
        proj_dim=256,
        dropout=0.1,
    )
    return model


# ── CNN + Transformer Hybrid 모델 ────────────────────────────
class CNNTransformerHybridPatient(nn.Module):
    """
    ResNet50으로 슬라이스별 특징 추출 후
    Transformer로 슬라이스 간 관계를 모델링.

    [구조 개선]
    원본: shared → malignancy_head / subtype_head
    수정: shared → mal_proj → malignancy_head
                 → sub_proj → subtype_head
    """
    def __init__(
        self,
        d_model=512,
        nhead=8,
        num_layers=2,
        dim_feedforward=1024,
        proj_dim=256,
        dropout=0.1,
        load_pretrained=True,
        freeze_backbone=True,
        unfreeze_layer4=True,
        resnet_weight_path=LOCAL_RESNET_WEIGHTS,
    ):
        super().__init__()

        # ── ResNet50 backbone ─────────────────────────────────
        backbone = models.resnet50(weights=None)
        if load_pretrained:
            state_dict = load_local_state_dict(resnet_weight_path)
            backbone.load_state_dict(state_dict, strict=True)
        feat_dim    = backbone.fc.in_features   # 2048
        backbone.fc = nn.Identity()
        self.encoder = backbone

        if freeze_backbone:
            for p in self.encoder.parameters():
                p.requires_grad = False
            if unfreeze_layer4:
                for p in self.encoder.layer4.parameters():
                    p.requires_grad = True

        # ── Transformer 입력 준비 ─────────────────────────────
        # ResNet 출력(2048) → Transformer 차원(d_model)으로 projection
        self.proj = nn.Linear(feat_dim, d_model)

        # CLS 토큰: 슬라이스 전체를 요약하는 학습 가능한 토큰
        self.cls_token = nn.Parameter(torch.zeros(1, 1, d_model))

        # pos_embed: 슬라이스 위치 정보 인코딩 (1+8: CLS + 슬라이스 최대 8장)
        # 실제 슬라이스 수 S가 8보다 작으면 자동으로 슬라이싱됨
        self.pos_embed = nn.Parameter(torch.zeros(1, 1 + 8, d_model))

        # ── Transformer Encoder ───────────────────────────────
        enc_layer = nn.TransformerEncoderLayer(
            d_model=d_model,
            nhead=nhead,
            dim_feedforward=dim_feedforward,
            dropout=0.1,
            batch_first=True,
            activation="gelu",
        )
        self.transformer = nn.TransformerEncoder(enc_layer, num_layers=num_layers)
        self.norm        = nn.LayerNorm(d_model)

        # ── 공통 표현 + task별 projection (개선 포인트) ────────
        self.shared = nn.Sequential(
            nn.Linear(d_model, 512),
            nn.ReLU(),
            nn.Dropout(dropout),
        )
        self.mal_proj = nn.Sequential(
            nn.Linear(512, proj_dim),
            nn.ReLU(),
            nn.Dropout(dropout),
        )
        self.sub_proj = nn.Sequential(
            nn.Linear(512, proj_dim),
            nn.ReLU(),
            nn.Dropout(dropout),
        )
        self.malignancy_head = nn.Linear(proj_dim, 1)
        self.subtype_head    = nn.Linear(proj_dim, NUM_MALIGNANT_SUBTYPES)

    def forward(self, x):
        B, S, C, H, W = x.shape
        x = x.view(B * S, C, H, W)

        feat = self.encoder(x)          # (B*S, 2048)
        feat = feat.view(B, S, -1)      # (B, S, 2048)
        feat = self.proj(feat)          # (B, S, d_model)

        # CLS 토큰 prepend
        cls    = self.cls_token.expand(B, -1, -1)       # (B, 1, d_model)
        tokens = torch.cat([cls, feat], dim=1)           # (B, 1+S, d_model)
        # pos_embed는 최대 슬라이스 수 기준으로 정의하고 실제 S에 맞게 슬라이싱
        tokens = tokens + self.pos_embed[:, :tokens.size(1), :]

        tokens  = self.transformer(tokens)    # (B, 1+S, d_model)
        tokens  = self.norm(tokens)
        cls_out = tokens[:, 0, :]             # (B, d_model) CLS 토큰만 추출

        z     = self.shared(cls_out)   # (B, 512)
        z_mal = self.mal_proj(z)       # (B, proj_dim)
        z_sub = self.sub_proj(z)       # (B, proj_dim)

        return {
            "malignancy_logits": self.malignancy_head(z_mal).squeeze(1),
            "subtype_logits":    self.subtype_head(z_sub),
        }


def build_hybrid_patient_model(load_pretrained=True):
    return CNNTransformerHybridPatient(
        load_pretrained=load_pretrained,
        freeze_backbone=True,
        unfreeze_layer4=True,
        resnet_weight_path=LOCAL_RESNET_WEIGHTS,
    )


# ============================================================
# 12) 공통 학습 함수
# ============================================================
def fit_model(
    model, model_name, fold_idx,
    train_loader, val_loader, device,
    num_epochs=30, lr=1e-4, weight_decay=1e-4,
    criterion=None,
    patience=7, min_delta=0.001,
):
    """
    [early stopping 기준 변경]
    원본: val_loss 기준
    수정: val_auc 기준

    이유: cascade 모델에서 malignancy gate recall이 낮으면
    subtype 예측 자체가 의미 없어짐.
    val_loss는 subtype loss가 섞여 있어 malignancy 성능을
    직접 반영하지 못함 → val_auc가 더 적합.

    [subtype_loss_weight warmup]
    epoch마다 CascadeCriterion의 weight를 업데이트.
    학습 초반에는 malignancy에 집중, 후반으로 갈수록 subtype 비중 증가.
    """
    if criterion is None:
        raise ValueError("cascade 모델에서는 criterion에 CascadeCriterion을 넘겨야 함")

    model = model.to(device)
    optimizer = torch.optim.Adam(
        filter(lambda p: p.requires_grad, model.parameters()),
        lr=lr,
        weight_decay=weight_decay,
    )

    best_auc           = -1.0
    best_path          = OUTPUT_DIR / f"{model_name}_fold{fold_idx}_best.pth"
    history            = []
    early_stop_counter = 0

    for epoch in range(1, num_epochs + 1):

        # subtype loss weight warmup: epoch마다 선형 증가
        current_subtype_weight = get_subtype_loss_weight(epoch, num_epochs)
        criterion.subtype_loss_weight = current_subtype_weight

        train_metrics = train_one_epoch(model, train_loader, criterion, optimizer, device)
        val_metrics   = eval_one_epoch(model, val_loader, criterion, device)

        row = {
            "fold":  fold_idx,
            "epoch": epoch,
            "subtype_loss_weight": current_subtype_weight,

            # train 지표
            "train_loss":                    train_metrics["loss"],
            "train_loss_malignancy":         train_metrics["loss_malignancy"],
            "train_loss_subtype":            train_metrics["loss_subtype"],
            "train_acc":                     train_metrics["acc"],
            "train_auc":                     train_metrics["auc"],
            "train_f1":                      train_metrics["f1"],
            "train_recall":                  train_metrics["recall"],
            "train_subtype_oracle_acc":      train_metrics["subtype_oracle_acc"],
            "train_subtype_oracle_macro_f1": train_metrics["subtype_oracle_macro_f1"],
            "train_subtype_cascade_acc":     train_metrics["subtype_cascade_acc"],
            "train_subtype_gate_recall":     train_metrics["subtype_gate_recall"],

            # val 지표
            "val_loss":                    val_metrics["loss"],
            "val_loss_malignancy":         val_metrics["loss_malignancy"],
            "val_loss_subtype":            val_metrics["loss_subtype"],
            "val_acc":                     val_metrics["acc"],
            "val_auc":                     val_metrics["auc"],
            "val_f1":                      val_metrics["f1"],
            "val_recall":                  val_metrics["recall"],
            "val_subtype_oracle_acc":      val_metrics["subtype_oracle_acc"],
            "val_subtype_oracle_macro_f1": val_metrics["subtype_oracle_macro_f1"],
            "val_subtype_cascade_acc":     val_metrics["subtype_cascade_acc"],
            "val_subtype_gate_recall":     val_metrics["subtype_gate_recall"],
        }
        history.append(row)

        # ✅ 버그 수정: 원본은 콤마로 f-string이 분리되어 별도 출력됨
        # → 하나의 f-string으로 합침
        print(
            f"[{model_name}][Fold {fold_idx}][Epoch {epoch:02d}] "
            f"sub_w={current_subtype_weight:.3f} | "
            f"train loss={row['train_loss']:.4f}(mal={row['train_loss_malignancy']:.4f},sub={row['train_loss_subtype']:.4f}), "
            f"auc={row['train_auc']:.4f}, f1={row['train_f1']:.4f}, recall={row['train_recall']:.4f}, "
            f"oracle_f1={row['train_subtype_oracle_macro_f1']:.4f}, cascade_acc={row['train_subtype_cascade_acc']:.4f} | "
            f"val loss={row['val_loss']:.4f}(mal={row['val_loss_malignancy']:.4f},sub={row['val_loss_subtype']:.4f}), "
            f"auc={row['val_auc']:.4f}, f1={row['val_f1']:.4f}, recall={row['val_recall']:.4f}, "
            f"oracle_f1={row['val_subtype_oracle_macro_f1']:.4f}, cascade_acc={row['val_subtype_cascade_acc']:.4f}"
        )

        # ✅ early stopping 기준: val_loss → val_auc
        val_auc = row["val_auc"]
        if val_auc > best_auc + min_delta:
            best_auc           = val_auc
            early_stop_counter = 0
            torch.save(model.state_dict(), best_path)
            print(f"  -> best saved (val_auc={best_auc:.4f}): {best_path}")
        else:
            early_stop_counter += 1
            print(f"  -> no improvement ({early_stop_counter}/{patience})")

        if early_stop_counter >= patience:
            print(f"  -> early stopping triggered at epoch {epoch}")
            break

    history_df = pd.DataFrame(history)
    return model, history_df, best_path


# ============================================================
# 13) 모델 로드 함수
# ============================================================
def load_model(model_type, model_path, device):
    if model_type == "resnet":
        model = build_resnet50_patient_model(load_pretrained=False)
    elif model_type == "vit":
        model = build_vit_patient_model(load_pretrained=False)
    elif model_type == "hybrid":
        model = build_hybrid_patient_model(load_pretrained=False)
    else:
        raise ValueError(f"Unknown model type: {model_type}")

    model.load_state_dict(torch.load(model_path, map_location=device))
    model.to(device)
    model.eval()
    return model


# ============================================================
# 14) CV 실행 함수
# ============================================================
def run_cv_for_model(model_name, model_type, build_fn):
    fold_results   = []
    fold_histories = []

    for fold_idx in FOLDS:
        print("\n" + "=" * 80)
        print(f"Running {model_name} | Fold {fold_idx}")
        print("=" * 80)

        train_loader, val_loader, pos_weight, subtype_class_weights = make_fold_loaders(fold_idx)

        model = build_fn()

        # CascadeCriterion: subtype_loss_weight는 fit_model 내부에서 epoch마다 업데이트
        criterion = CascadeCriterion(
            pos_weight=pos_weight,
            subtype_class_weights=subtype_class_weights,
            subtype_loss_weight=SUBTYPE_LOSS_WEIGHT_START,
        )

        _, history_df, best_path = fit_model(
            model=model,
            model_name=model_name,
            fold_idx=fold_idx,
            train_loader=train_loader,
            val_loader=val_loader,
            device=device,
            num_epochs=NUM_EPOCHS,
            lr=LR,
            weight_decay=WEIGHT_DECAY,
            criterion=criterion,
            patience=PATIENCE,
            min_delta=MIN_DELTA,
        )

        best_model    = load_model(model_type, best_path, device)
        final_metrics = eval_confusion(best_model, val_loader, criterion, device, threshold=THRESHOLD)

        print(f"\n[{model_name}][Fold {fold_idx}] Final Metrics")
        print(f"Malignancy  AUC={final_metrics['auc']:.4f}, F1={final_metrics['f1']:.4f}, Recall={final_metrics['recall']:.4f}")
        print(f"Subtype Oracle  Acc={final_metrics['subtype_oracle_acc']:.4f}, MacroF1={final_metrics['subtype_oracle_macro_f1']:.4f}")
        print(f"Cascade  Acc={final_metrics['subtype_cascade_acc']:.4f}, GateRecall={final_metrics['subtype_gate_recall']:.4f}")

        fold_results.append({
            "model":                   model_name,
            "fold":                    fold_idx,
            "mal_acc":                 final_metrics["acc"],
            "mal_auc":                 final_metrics["auc"],
            "mal_f1":                  final_metrics["f1"],
            "mal_recall":              final_metrics["recall"],
            "subtype_oracle_acc":      final_metrics["subtype_oracle_acc"],
            "subtype_oracle_macro_f1": final_metrics["subtype_oracle_macro_f1"],
            "subtype_cascade_acc":     final_metrics["subtype_cascade_acc"],
            "subtype_gate_recall":     final_metrics["subtype_gate_recall"],
            "binary_cm":               final_metrics["cm"],
            "subtype_oracle_cm":       final_metrics["subtype_oracle_cm"],
        })

        history_df["model"] = model_name
        fold_histories.append(history_df)

        del model, best_model, train_loader, val_loader
        gc.collect()
        if torch.cuda.is_available():
            torch.cuda.empty_cache()

    result_df      = pd.DataFrame(fold_results)
    history_df_all = pd.concat(fold_histories, ignore_index=True)
    return result_df, history_df_all


# ============================================================
# 15) 학습 실행
# ============================================================

# ── ResNet50 ──────────────────────────────────────────────────
print(">>> Training ResNet50...")
resnet_cv_df, resnet_history_df = run_cv_for_model(
    model_name="ResNet50",
    model_type="resnet",
    build_fn=lambda: build_resnet50_patient_model(load_pretrained=True),
)
display(resnet_cv_df)

# ── ViT-B/16 ─────────────────────────────────────────────────
print(">>> Training ViT-B/16...")
vit_cv_df, vit_history_df = run_cv_for_model(
    model_name="ViT-B16",
    model_type="vit",
    build_fn=lambda: build_vit_patient_model(load_pretrained=True),
)
display(vit_cv_df)

# ── Hybrid ────────────────────────────────────────────────────
print(">>> Training Hybrid...")
hybrid_cv_df, hybrid_history_df = run_cv_for_model(
    model_name="Hybrid",
    model_type="hybrid",
    build_fn=lambda: build_hybrid_patient_model(load_pretrained=True),
)
display(hybrid_cv_df)


# ============================================================
# 16) 5-fold 평균 ± 표준편차 요약
# ============================================================
all_cv_df = pd.concat([resnet_cv_df, vit_cv_df, hybrid_cv_df], ignore_index=True)

summary_df = (
    all_cv_df.groupby("model")[[
        "mal_auc", "mal_f1", "mal_recall",
        "subtype_oracle_acc", "subtype_oracle_macro_f1",
        "subtype_cascade_acc", "subtype_gate_recall",
    ]]
    .agg(["mean", "std"])
)
display(summary_df)


# ============================================================
# 17) 학습 곡선 시각화
# ============================================================
def plot_one_model_by_fold(history_df, model_name):
    folds = sorted(history_df["fold"].unique())

    fig, axes = plt.subplots(1, 3, figsize=(18, 5))

    # Loss
    ax = axes[0]
    for fold in folds:
        df_f = history_df[history_df["fold"] == fold].sort_values("epoch")
        ax.plot(df_f["epoch"], df_f["train_loss"], linestyle="--", alpha=0.7, label=f"Fold{fold} Train")
        ax.plot(df_f["epoch"], df_f["val_loss"],   alpha=0.7,      label=f"Fold{fold} Val")
    ax.set_title(f"{model_name} - Total Loss")
    ax.set_xlabel("Epoch")
    ax.set_ylabel("Loss")
    ax.legend(fontsize=7)

    # Malignancy AUC
    ax = axes[1]
    for fold in folds:
        df_f = history_df[history_df["fold"] == fold].sort_values("epoch")
        ax.plot(df_f["epoch"], df_f["val_auc"], alpha=0.8, label=f"Fold{fold}")
    ax.set_title(f"{model_name} - Val Malignancy AUC")
    ax.set_xlabel("Epoch")
    ax.set_ylabel("AUC")
    ax.legend(fontsize=7)

    # Subtype cascade acc
    ax = axes[2]
    for fold in folds:
        df_f = history_df[history_df["fold"] == fold].sort_values("epoch")
        ax.plot(df_f["epoch"], df_f["val_subtype_cascade_acc"], alpha=0.8, label=f"Fold{fold}")
    ax.set_title(f"{model_name} - Val Subtype Cascade Acc")
    ax.set_xlabel("Epoch")
    ax.set_ylabel("Cascade Acc")
    ax.legend(fontsize=7)

    plt.suptitle(model_name, fontsize=13)
    plt.tight_layout()
    plt.show()


plot_one_model_by_fold(resnet_history_df, "ResNet50")
plot_one_model_by_fold(vit_history_df,    "ViT-B16")
plot_one_model_by_fold(hybrid_history_df, "Hybrid")
# Out:
# ============================================================
# ResNet50 build success
# Vit-B/16 build success
# ============================================================
# Device: cuda
# 현재 작업 경로: /tf/notebooks/Image Encoder/Untitled Folder
# DATA_ROOT: /tf/nasw/dataset001/preprocessed/npz_us
# OUTPUT_DIR: /tf/notebooks/Image Encoder/Untitled Folder/us_cascade_models
# FOLDS: [1, 2, 3, 4, 5]
# LOCAL_RESNET_WEIGHTS exists: True
# LOCAL_VIT_WEIGHTS exists: True
# malignant_type_ids: [0, 1, 3, 5, 7]
# MALIGNANT_MAP: {0: 0, 1: 1, 3: 2, 5: 3, 7: 4}
# NUM_MALIGNANT_SUBTYPES: 5
# >>> Training ResNet50...
#
# ================================================================================
# Running ResNet50 | Fold 1
# ================================================================================
# [FOLD 1] Train benign(0): 2077, malignant(1): 395, pos_weight=5.2582, subtype_counts=[32.0, 22.0, 67.0, 25.0, 249.0], subtype_class_weights=[1.151900053024292, 1.6755000352859497, 0.5501999855041504, 1.4744000434875488, 0.14800000190734863]
# [ResNet50][Fold 1][Epoch 01] sub_w=0.500 | train loss=1.3064(mal=0.7696,sub=1.0736), auc=0.8725, f1=0.5593, recall=0.7646, oracle_f1=0.1579, cascade_acc=0.4759 | val loss=0.4802(mal=0.3454,sub=0.2696), auc=0.9839, f1=0.6904, recall=0.9898, oracle_f1=0.1550, cascade_acc=0.6327
#   -> best saved (val_auc=0.9839): us_cascade_models/ResNet50_fold1_best.pth
# [ResNet50][Fold 1][Epoch 02] sub_w=0.510 | train loss=0.8686(mal=0.3634,sub=0.9899), auc=0.9704, f1=0.7628, recall=0.9443, oracle_f1=0.1648, cascade_acc=0.5899 | val loss=0.5056(mal=0.3645,sub=0.2765), auc=0.9861, f1=0.8995, recall=0.8673, oracle_f1=0.1550, cascade_acc=0.5612
#   -> best saved (val_auc=0.9861): us_cascade_models/ResNet50_fold1_best.pth
# [ResNet50][Fold 1][Epoch 03] sub_w=0.521 | train loss=0.7439(mal=0.2234,sub=0.9997), auc=0.9875, f1=0.8383, recall=0.9646, oracle_f1=0.1547, cascade_acc=0.6203 | val loss=0.4115(mal=0.2718,sub=0.2683), auc=0.9875, f1=0.8558, recall=0.9082, oracle_f1=0.1550, cascade_acc=0.5612
#   -> best saved (val_auc=0.9875): us_cascade_models/ResNet50_fold1_best.pth
# [ResNet50][Fold 1][Epoch 04] sub_w=0.531 | train loss=0.7461(mal=0.2465,sub=0.9408), auc=0.9855, f1=0.8429, recall=0.9646, oracle_f1=0.1608, cascade_acc=0.6051 | val loss=0.3760(mal=0.2162,sub=0.3008), auc=0.9918, f1=0.8792, recall=0.9286, oracle_f1=0.1550, cascade_acc=0.5714
#   -> best saved (val_auc=0.9918): us_cascade_models/ResNet50_fold1_best.pth
# [ResNet50][Fold 1][Epoch 05] sub_w=0.541 | train loss=0.6702(mal=0.1679,sub=0.9278), auc=0.9930, f1=0.8928, recall=0.9696, oracle_f1=0.1701, cascade_acc=0.6203 | val loss=0.4489(mal=0.2887,sub=0.2959), auc=0.9916, f1=0.8867, recall=0.9184, oracle_f1=0.2115, cascade_acc=0.5306
#   -> no improvement (1/7)
# [ResNet50][Fold 1][Epoch 06] sub_w=0.552 | train loss=0.6386(mal=0.1413,sub=0.9014), auc=0.9951, f1=0.8995, recall=0.9747, oracle_f1=0.2129, cascade_acc=0.6278 | val loss=0.4546(mal=0.2415,sub=0.3861), auc=0.9937, f1=0.8942, recall=0.9490, oracle_f1=0.1550, cascade_acc=0.5816
#   -> best saved (val_auc=0.9937): us_cascade_models/ResNet50_fold1_best.pth
# [ResNet50][Fold 1][Epoch 07] sub_w=0.562 | train loss=0.6170(mal=0.1291,sub=0.8681), auc=0.9956, f1=0.9091, recall=0.9747, oracle_f1=0.2209, cascade_acc=0.6203 | val loss=0.3999(mal=0.2491,sub=0.2682), auc=0.9943, f1=0.9045, recall=0.9184, oracle_f1=0.2134, cascade_acc=0.5306
#   -> no improvement (1/7)
# [ResNet50][Fold 1][Epoch 08] sub_w=0.572 | train loss=0.6136(mal=0.1269,sub=0.8503), auc=0.9954, f1=0.9151, recall=0.9823, oracle_f1=0.2398, cascade_acc=0.6456 | val loss=0.6091(mal=0.4523,sub=0.2739), auc=0.9941, f1=0.9000, recall=0.8265, oracle_f1=0.2128, cascade_acc=0.4898
#   -> no improvement (2/7)
# [ResNet50][Fold 1][Epoch 09] sub_w=0.583 | train loss=0.5821(mal=0.1019,sub=0.8239), auc=0.9974, f1=0.9375, recall=0.9873, oracle_f1=0.2417, cascade_acc=0.6329 | val loss=0.3686(mal=0.2007,sub=0.2881), auc=0.9946, f1=0.9010, recall=0.9286, oracle_f1=0.2310, cascade_acc=0.5612
#   -> no improvement (3/7)
# [ResNet50][Fold 1][Epoch 10] sub_w=0.593 | train loss=0.6092(mal=0.1339,sub=0.8013), auc=0.9941, f1=0.9293, recall=0.9823, oracle_f1=0.2500, cascade_acc=0.6608 | val loss=0.5517(mal=0.3986,sub=0.2580), auc=0.9906, f1=0.8923, recall=0.8878, oracle_f1=0.1908, cascade_acc=0.4796
#   -> no improvement (4/7)
# [ResNet50][Fold 1][Epoch 11] sub_w=0.603 | train loss=0.5666(mal=0.0693,sub=0.8242), auc=0.9986, f1=0.9479, recall=0.9899, oracle_f1=0.2646, cascade_acc=0.6684 | val loss=0.5483(mal=0.3798,sub=0.2792), auc=0.9887, f1=0.9119, recall=0.8980, oracle_f1=0.2059, cascade_acc=0.5612
#   -> no improvement (5/7)
# [ResNet50][Fold 1][Epoch 12] sub_w=0.614 | train loss=0.5746(mal=0.0744,sub=0.8149), auc=0.9987, f1=0.9451, recall=0.9797, oracle_f1=0.2606, cascade_acc=0.6557 | val loss=0.4127(mal=0.2605,sub=0.2481), auc=0.9905, f1=0.8804, recall=0.9388, oracle_f1=0.2364, cascade_acc=0.5816
#   -> no improvement (6/7)
# [ResNet50][Fold 1][Epoch 13] sub_w=0.624 | train loss=0.5414(mal=0.0573,sub=0.7756), auc=0.9993, f1=0.9549, recall=0.9924, oracle_f1=0.2763, cascade_acc=0.6759 | val loss=0.6268(mal=0.4461,sub=0.2896), auc=0.9912, f1=0.8973, recall=0.8469, oracle_f1=0.2335, cascade_acc=0.5204
#   -> no improvement (7/7)
#   -> early stopping triggered at epoch 13
#
# -- Final Evaluation --
# [Malignancy]  AUC=0.9937, F1=0.8942, Recall=0.9490, Acc=0.9644
# [Subtype Oracle]  Acc=0.6327, MacroF1=0.1550
# [Cascade]  SubtypeAcc=0.5816, GateRecall=0.9490
# Binary CM:
# [[503  17]
#  [  5  93]]
# Subtype Oracle CM:
# [[ 0  0  0  0  8]
#  [ 0  0  0  0  5]
#  [ 0  0  0  0 17]
#  [ 0  0  0  0  6]
#  [ 0  0  0  0 62]]
#
# [ResNet50][Fold 1] Final Metrics
# Malignancy  AUC=0.9937, F1=0.8942, Recall=0.9490
# Subtype Oracle  Acc=0.6327, MacroF1=0.1550
# Cascade  Acc=0.5816, GateRecall=0.9490
#
# ================================================================================
# Running ResNet50 | Fold 2
# ================================================================================
# [FOLD 2] Train benign(0): 2077, malignant(1): 395, pos_weight=5.2582, subtype_counts=[32.0, 22.0, 67.0, 25.0, 249.0], subtype_class_weights=[1.151900053024292, 1.6755000352859497, 0.5501999855041504, 1.4744000434875488, 0.14800000190734863]
# [ResNet50][Fold 2][Epoch 01] sub_w=0.500 | train loss=1.3613(mal=0.8089,sub=1.1050), auc=0.8654, f1=0.5281, recall=0.6430, oracle_f1=0.1523, cascade_acc=0.4076 | val loss=0.5401(mal=0.3996,sub=0.2811), auc=0.9670, f1=0.6904, recall=0.9898, oracle_f1=0.1550, cascade_acc=0.6327
#   -> best saved (val_auc=0.9670): us_cascade_models/ResNet50_fold2_best.pth
# [ResNet50][Fold 2][Epoch 02] sub_w=0.510 | train loss=0.9276(mal=0.4519,sub=0.9320), auc=0.9609, f1=0.7251, recall=0.9418, oracle_f1=0.1543, cascade_acc=0.5899 | val loss=0.4701(mal=0.2841,sub=0.3645), auc=0.9851, f1=0.7801, recall=0.9592, oracle_f1=0.1550, cascade_acc=0.6020
#   -> best saved (val_auc=0.9851): us_cascade_models/ResNet50_fold2_best.pth
# [ResNet50][Fold 2][Epoch 03] sub_w=0.521 | train loss=0.7926(mal=0.2985,sub=0.9490), auc=0.9806, f1=0.8171, recall=0.9443, oracle_f1=0.1547, cascade_acc=0.5975 | val loss=0.4308(mal=0.2962,sub=0.2585), auc=0.9849, f1=0.7581, recall=0.9592, oracle_f1=0.1550, cascade_acc=0.6020
#   -> no improvement (1/7)
# [ResNet50][Fold 2][Epoch 04] sub_w=0.531 | train loss=0.7712(mal=0.2639,sub=0.9553), auc=0.9834, f1=0.8279, recall=0.9620, oracle_f1=0.1725, cascade_acc=0.6177 | val loss=0.4443(mal=0.2526,sub=0.3609), auc=0.9916, f1=0.8067, recall=0.9796, oracle_f1=0.1550, cascade_acc=0.6224
#   -> best saved (val_auc=0.9916): us_cascade_models/ResNet50_fold2_best.pth
# [ResNet50][Fold 2][Epoch 05] sub_w=0.541 | train loss=0.7094(mal=0.2298,sub=0.8858), auc=0.9881, f1=0.8565, recall=0.9595, oracle_f1=0.1741, cascade_acc=0.6127 | val loss=0.3655(mal=0.2035,sub=0.2991), auc=0.9917, f1=0.8240, recall=0.9796, oracle_f1=0.1550, cascade_acc=0.6224
#   -> no improvement (1/7)
# [ResNet50][Fold 2][Epoch 06] sub_w=0.552 | train loss=0.6776(mal=0.1950,sub=0.8746), auc=0.9904, f1=0.8964, recall=0.9747, oracle_f1=0.1916, cascade_acc=0.6253 | val loss=0.3504(mal=0.1904,sub=0.2900), auc=0.9921, f1=0.8756, recall=0.9694, oracle_f1=0.1560, cascade_acc=0.6224
#   -> no improvement (2/7)
# [ResNet50][Fold 2][Epoch 07] sub_w=0.562 | train loss=0.6516(mal=0.1538,sub=0.8857), auc=0.9943, f1=0.8951, recall=0.9722, oracle_f1=0.2025, cascade_acc=0.6076 | val loss=0.2732(mal=0.1306,sub=0.2536), auc=0.9956, f1=0.9268, recall=0.9694, oracle_f1=0.2408, cascade_acc=0.6224
#   -> best saved (val_auc=0.9956): us_cascade_models/ResNet50_fold2_best.pth
# [ResNet50][Fold 2][Epoch 08] sub_w=0.572 | train loss=0.6101(mal=0.1234,sub=0.8502), auc=0.9962, f1=0.9145, recall=0.9747, oracle_f1=0.2214, cascade_acc=0.6380 | val loss=0.3982(mal=0.2215,sub=0.3088), auc=0.9918, f1=0.8421, recall=0.9796, oracle_f1=0.2459, cascade_acc=0.6327
#   -> no improvement (1/7)
# [ResNet50][Fold 2][Epoch 09] sub_w=0.583 | train loss=0.6073(mal=0.1395,sub=0.8028), auc=0.9947, f1=0.9171, recall=0.9797, oracle_f1=0.2399, cascade_acc=0.6405 | val loss=0.3587(mal=0.1825,sub=0.3024), auc=0.9932, f1=0.9057, recall=0.9796, oracle_f1=0.2322, cascade_acc=0.6020
#   -> no improvement (2/7)
# [ResNet50][Fold 2][Epoch 10] sub_w=0.593 | train loss=0.5961(mal=0.1108,sub=0.8183), auc=0.9972, f1=0.9281, recall=0.9797, oracle_f1=0.2500, cascade_acc=0.6582 | val loss=0.3568(mal=0.1540,sub=0.3419), auc=0.9948, f1=0.9100, recall=0.9796, oracle_f1=0.2069, cascade_acc=0.6429
#   -> no improvement (3/7)
# [ResNet50][Fold 2][Epoch 11] sub_w=0.603 | train loss=0.6392(mal=0.1876,sub=0.7484), auc=0.9940, f1=0.9369, recall=0.9772, oracle_f1=0.2677, cascade_acc=0.6785 | val loss=0.4412(mal=0.2403,sub=0.3328), auc=0.9911, f1=0.9163, recall=0.9490, oracle_f1=0.2454, cascade_acc=0.6020
#   -> no improvement (4/7)
# [ResNet50][Fold 2][Epoch 12] sub_w=0.614 | train loss=0.5646(mal=0.1250,sub=0.7161), auc=0.9962, f1=0.9187, recall=0.9722, oracle_f1=0.2934, cascade_acc=0.6557 | val loss=0.3754(mal=0.1614,sub=0.3487), auc=0.9941, f1=0.8837, recall=0.9694, oracle_f1=0.2376, cascade_acc=0.6224
#   -> no improvement (5/7)
# [ResNet50][Fold 2][Epoch 13] sub_w=0.624 | train loss=0.5552(mal=0.0919,sub=0.7423), auc=0.9979, f1=0.9440, recall=0.9823, oracle_f1=0.3169, cascade_acc=0.6734 | val loss=0.3375(mal=0.1500,sub=0.3005), auc=0.9956, f1=0.9412, recall=0.9796, oracle_f1=0.2564, cascade_acc=0.5612
#   -> no improvement (6/7)
# [ResNet50][Fold 2][Epoch 14] sub_w=0.634 | train loss=0.5082(mal=0.0611,sub=0.7047), auc=0.9984, f1=0.9618, recall=0.9873, oracle_f1=0.3554, cascade_acc=0.6861 | val loss=0.4571(mal=0.2909,sub=0.2620), auc=0.9889, f1=0.9179, recall=0.9694, oracle_f1=0.3016, cascade_acc=0.5204
#   -> no improvement (7/7)
#   -> early stopping triggered at epoch 14
#
# -- Final Evaluation --
# [Malignancy]  AUC=0.9956, F1=0.9268, Recall=0.9694, Acc=0.9757
# [Subtype Oracle]  Acc=0.6327, MacroF1=0.2408
# [Cascade]  SubtypeAcc=0.6224, GateRecall=0.9694
# Binary CM:
# [[508  12]
#  [  3  95]]
# Subtype Oracle CM:
# [[ 0  0  0  0  8]
#  [ 0  0  2  0  3]
#  [ 0  0  8  0  9]
#  [ 0  0  2  0  4]
#  [ 0  0  8  0 54]]
#
# [ResNet50][Fold 2] Final Metrics
# Malignancy  AUC=0.9956, F1=0.9268, Recall=0.9694
# Subtype Oracle  Acc=0.6327, MacroF1=0.2408
# Cascade  Acc=0.6224, GateRecall=0.9694
#
# ================================================================================
# Running ResNet50 | Fold 3
# ================================================================================
# [FOLD 3] Train benign(0): 2078, malignant(1): 394, pos_weight=5.2741, subtype_counts=[32.0, 21.0, 68.0, 25.0, 248.0], subtype_class_weights=[1.1354999542236328, 1.730299949645996, 0.5343000292778015, 1.4534000158309937, 0.14650000631809235]
# [ResNet50][Fold 3][Epoch 01] sub_w=0.500 | train loss=1.2568(mal=0.7168,sub=1.0799), auc=0.8925, f1=0.5813, recall=0.7081, oracle_f1=0.1546, cascade_acc=0.4492 | val loss=0.4772(mal=0.3217,sub=0.3110), auc=0.9785, f1=0.7797, recall=0.9293, oracle_f1=0.1556, cascade_acc=0.5960
#   -> best saved (val_auc=0.9785): us_cascade_models/ResNet50_fold3_best.pth
# [ResNet50][Fold 3][Epoch 02] sub_w=0.510 | train loss=0.9780(mal=0.4393,sub=1.0555), auc=0.9600, f1=0.7275, recall=0.9315, oracle_f1=0.1545, cascade_acc=0.5888 | val loss=0.4464(mal=0.3104,sub=0.2664), auc=0.9896, f1=0.8804, recall=0.9293, oracle_f1=0.1556, cascade_acc=0.6061
#   -> best saved (val_auc=0.9896): us_cascade_models/ResNet50_fold3_best.pth
# [ResNet50][Fold 3][Epoch 03] sub_w=0.521 | train loss=0.8113(mal=0.3043,sub=0.9737), auc=0.9796, f1=0.7996, recall=0.9467, oracle_f1=0.1545, cascade_acc=0.5990 | val loss=0.4070(mal=0.2655,sub=0.2717), auc=0.9873, f1=0.8738, recall=0.9091, oracle_f1=0.1556, cascade_acc=0.5859
#   -> no improvement (1/7)
# [ResNet50][Fold 3][Epoch 04] sub_w=0.531 | train loss=0.7489(mal=0.2645,sub=0.9122), auc=0.9845, f1=0.8298, recall=0.9467, oracle_f1=0.1545, cascade_acc=0.5939 | val loss=0.4142(mal=0.2677,sub=0.2758), auc=0.9896, f1=0.7851, recall=0.9596, oracle_f1=0.1556, cascade_acc=0.6162
#   -> no improvement (2/7)
# [ResNet50][Fold 3][Epoch 05] sub_w=0.541 | train loss=0.6976(mal=0.1888,sub=0.9400), auc=0.9916, f1=0.8784, recall=0.9721, oracle_f1=0.1544, cascade_acc=0.6142 | val loss=0.3999(mal=0.2105,sub=0.3499), auc=0.9913, f1=0.8398, recall=0.9798, oracle_f1=0.1556, cascade_acc=0.6263
#   -> best saved (val_auc=0.9913): us_cascade_models/ResNet50_fold3_best.pth
# [ResNet50][Fold 3][Epoch 06] sub_w=0.552 | train loss=0.6339(mal=0.1438,sub=0.8884), auc=0.9952, f1=0.8982, recall=0.9746, oracle_f1=0.1698, cascade_acc=0.6117 | val loss=0.3427(mal=0.1845,sub=0.2868), auc=0.9930, f1=0.8837, recall=0.9596, oracle_f1=0.1556, cascade_acc=0.6263
#   -> best saved (val_auc=0.9930): us_cascade_models/ResNet50_fold3_best.pth
# [ResNet50][Fold 3][Epoch 07] sub_w=0.562 | train loss=0.6557(mal=0.1639,sub=0.8748), auc=0.9932, f1=0.9108, recall=0.9721, oracle_f1=0.2149, cascade_acc=0.6091 | val loss=0.3147(mal=0.1552,sub=0.2839), auc=0.9949, f1=0.9023, recall=0.9798, oracle_f1=0.2060, cascade_acc=0.5758
#   -> best saved (val_auc=0.9949): us_cascade_models/ResNet50_fold3_best.pth
# [ResNet50][Fold 3][Epoch 08] sub_w=0.572 | train loss=0.5968(mal=0.1330,sub=0.8103), auc=0.9953, f1=0.9048, recall=0.9772, oracle_f1=0.2279, cascade_acc=0.6244 | val loss=0.3130(mal=0.1447,sub=0.2939), auc=0.9960, f1=0.8981, recall=0.9798, oracle_f1=0.2047, cascade_acc=0.5960
#   -> best saved (val_auc=0.9960): us_cascade_models/ResNet50_fold3_best.pth
# [ResNet50][Fold 3][Epoch 09] sub_w=0.583 | train loss=0.5760(mal=0.1084,sub=0.8022), auc=0.9966, f1=0.9314, recall=0.9822, oracle_f1=0.2475, cascade_acc=0.6345 | val loss=0.3626(mal=0.1845,sub=0.3056), auc=0.9949, f1=0.8688, recall=0.9697, oracle_f1=0.1544, cascade_acc=0.6162
#   -> no improvement (1/7)
# [ResNet50][Fold 3][Epoch 10] sub_w=0.593 | train loss=0.5689(mal=0.1099,sub=0.7738), auc=0.9969, f1=0.9214, recall=0.9822, oracle_f1=0.2479, cascade_acc=0.6472 | val loss=0.4082(mal=0.1939,sub=0.3612), auc=0.9946, f1=0.9179, recall=0.9596, oracle_f1=0.2124, cascade_acc=0.5758
#   -> no improvement (2/7)
# [ResNet50][Fold 3][Epoch 11] sub_w=0.603 | train loss=0.5898(mal=0.0938,sub=0.8220), auc=0.9979, f1=0.9292, recall=0.9822, oracle_f1=0.2595, cascade_acc=0.6523 | val loss=0.5041(mal=0.2812,sub=0.3694), auc=0.9902, f1=0.9082, recall=0.9495, oracle_f1=0.2131, cascade_acc=0.5556
#   -> no improvement (3/7)
# [ResNet50][Fold 3][Epoch 12] sub_w=0.614 | train loss=0.5765(mal=0.1056,sub=0.7673), auc=0.9971, f1=0.9268, recall=0.9797, oracle_f1=0.2473, cascade_acc=0.6320 | val loss=0.5025(mal=0.2843,sub=0.3556), auc=0.9873, f1=0.8186, recall=0.9798, oracle_f1=0.2255, cascade_acc=0.5859
#   -> no improvement (4/7)
# [ResNet50][Fold 3][Epoch 13] sub_w=0.624 | train loss=0.5827(mal=0.0871,sub=0.7941), auc=0.9978, f1=0.9303, recall=0.9822, oracle_f1=0.2722, cascade_acc=0.6497 | val loss=0.5869(mal=0.3564,sub=0.3693), auc=0.9930, f1=0.9167, recall=0.8889, oracle_f1=0.2638, cascade_acc=0.5354
#   -> no improvement (5/7)
# [ResNet50][Fold 3][Epoch 14] sub_w=0.634 | train loss=0.5315(mal=0.0744,sub=0.7204), auc=0.9985, f1=0.9490, recall=0.9924, oracle_f1=0.2938, cascade_acc=0.6827 | val loss=0.4575(mal=0.2219,sub=0.3712), auc=0.9928, f1=0.8932, recall=0.9293, oracle_f1=0.1961, cascade_acc=0.5051
#   -> no improvement (6/7)
# [ResNet50][Fold 3][Epoch 15] sub_w=0.645 | train loss=0.5064(mal=0.0639,sub=0.6862), auc=0.9990, f1=0.9629, recall=0.9873, oracle_f1=0.3809, cascade_acc=0.6929 | val loss=0.5208(mal=0.2570,sub=0.4092), auc=0.9934, f1=0.8738, recall=0.9091, oracle_f1=0.2557, cascade_acc=0.5253
#   -> no improvement (7/7)
#   -> early stopping triggered at epoch 15
#
# -- Final Evaluation --
# [Malignancy]  AUC=0.9960, F1=0.8981, Recall=0.9798, Acc=0.9644
# [Subtype Oracle]  Acc=0.6061, MacroF1=0.2047
# [Cascade]  SubtypeAcc=0.5960, GateRecall=0.9798
# Binary CM:
# [[499  20]
#  [  2  97]]
# Subtype Oracle CM:
# [[ 0  0  0  0  8]
#  [ 0  0  0  0  6]
#  [ 0  0  4  0 12]
#  [ 0  0  3  0  3]
#  [ 0  0  7  0 56]]
#
# [ResNet50][Fold 3] Final Metrics
# Malignancy  AUC=0.9960, F1=0.8981, Recall=0.9798
# Subtype Oracle  Acc=0.6061, MacroF1=0.2047
# Cascade  Acc=0.5960, GateRecall=0.9798
#
# ================================================================================
# Running ResNet50 | Fold 4
# ================================================================================
# [FOLD 4] Train benign(0): 2078, malignant(1): 394, pos_weight=5.2741, subtype_counts=[32.0, 21.0, 67.0, 25.0, 249.0], subtype_class_weights=[1.1338000297546387, 1.7276999950408936, 0.5414999723434448, 1.451300024986267, 0.14569999277591705]
# [ResNet50][Fold 4][Epoch 01] sub_w=0.500 | train loss=1.2397(mal=0.7184,sub=1.0425), auc=0.8881, f1=0.5493, recall=0.8198, oracle_f1=0.1629, cascade_acc=0.4898 | val loss=0.6372(mal=0.4814,sub=0.3118), auc=0.9582, f1=0.7234, recall=0.8586, oracle_f1=0.1540, cascade_acc=0.5455
#   -> best saved (val_auc=0.9582): us_cascade_models/ResNet50_fold4_best.pth
# [ResNet50][Fold 4][Epoch 02] sub_w=0.510 | train loss=0.8943(mal=0.4088,sub=0.9513), auc=0.9658, f1=0.7696, recall=0.9365, oracle_f1=0.1549, cascade_acc=0.5939 | val loss=0.5695(mal=0.4343,sub=0.2648), auc=0.9588, f1=0.7542, recall=0.8990, oracle_f1=0.1540, cascade_acc=0.5556
#   -> no improvement (1/7)
# [ResNet50][Fold 4][Epoch 03] sub_w=0.521 | train loss=0.8014(mal=0.2864,sub=0.9891), auc=0.9820, f1=0.8082, recall=0.9467, oracle_f1=0.1709, cascade_acc=0.6117 | val loss=0.5645(mal=0.4136,sub=0.2897), auc=0.9707, f1=0.7303, recall=0.8889, oracle_f1=0.1810, cascade_acc=0.5455
#   -> best saved (val_auc=0.9707): us_cascade_models/ResNet50_fold4_best.pth
# [ResNet50][Fold 4][Epoch 04] sub_w=0.531 | train loss=0.6978(mal=0.2351,sub=0.8713), auc=0.9868, f1=0.8555, recall=0.9619, oracle_f1=0.1641, cascade_acc=0.6066 | val loss=0.5025(mal=0.3584,sub=0.2713), auc=0.9777, f1=0.7470, recall=0.9394, oracle_f1=0.1540, cascade_acc=0.5960
#   -> best saved (val_auc=0.9777): us_cascade_models/ResNet50_fold4_best.pth
# [ResNet50][Fold 4][Epoch 05] sub_w=0.541 | train loss=0.7225(mal=0.2244,sub=0.9201), auc=0.9883, f1=0.8491, recall=0.9569, oracle_f1=0.1818, cascade_acc=0.6015 | val loss=0.4652(mal=0.3013,sub=0.3028), auc=0.9822, f1=0.8507, recall=0.9495, oracle_f1=0.1772, cascade_acc=0.5960
#   -> best saved (val_auc=0.9822): us_cascade_models/ResNet50_fold4_best.pth
# [ResNet50][Fold 4][Epoch 06] sub_w=0.552 | train loss=0.6572(mal=0.1672,sub=0.8882), auc=0.9938, f1=0.8801, recall=0.9594, oracle_f1=0.2270, cascade_acc=0.6168 | val loss=0.5100(mal=0.3633,sub=0.2659), auc=0.9772, f1=0.8203, recall=0.8990, oracle_f1=0.2146, cascade_acc=0.5354
#   -> no improvement (1/7)
# [ResNet50][Fold 4][Epoch 07] sub_w=0.562 | train loss=0.7410(mal=0.2261,sub=0.9161), auc=0.9906, f1=0.8750, recall=0.9594, oracle_f1=0.2195, cascade_acc=0.6041 | val loss=0.4379(mal=0.2825,sub=0.2764), auc=0.9856, f1=0.8000, recall=0.9495, oracle_f1=0.2054, cascade_acc=0.5455
#   -> best saved (val_auc=0.9856): us_cascade_models/ResNet50_fold4_best.pth
# [ResNet50][Fold 4][Epoch 08] sub_w=0.572 | train loss=0.6212(mal=0.1261,sub=0.8648), auc=0.9959, f1=0.9074, recall=0.9822, oracle_f1=0.2261, cascade_acc=0.6294 | val loss=0.4990(mal=0.3164,sub=0.3190), auc=0.9868, f1=0.8507, recall=0.9495, oracle_f1=0.1870, cascade_acc=0.5859
#   -> best saved (val_auc=0.9868): us_cascade_models/ResNet50_fold4_best.pth
# [ResNet50][Fold 4][Epoch 09] sub_w=0.583 | train loss=0.6210(mal=0.1395,sub=0.8263), auc=0.9952, f1=0.9104, recall=0.9797, oracle_f1=0.2400, cascade_acc=0.6371 | val loss=0.4899(mal=0.3294,sub=0.2754), auc=0.9863, f1=0.8210, recall=0.9495, oracle_f1=0.1658, cascade_acc=0.5657
#   -> no improvement (1/7)
# [ResNet50][Fold 4][Epoch 10] sub_w=0.593 | train loss=0.5605(mal=0.0952,sub=0.7846), auc=0.9975, f1=0.9262, recall=0.9873, oracle_f1=0.2413, cascade_acc=0.6218 | val loss=0.6916(mal=0.5258,sub=0.2795), auc=0.9765, f1=0.8812, recall=0.8990, oracle_f1=0.1952, cascade_acc=0.4848
#   -> no improvement (2/7)
# [ResNet50][Fold 4][Epoch 11] sub_w=0.603 | train loss=0.5399(mal=0.0689,sub=0.7805), auc=0.9985, f1=0.9478, recall=0.9898, oracle_f1=0.2732, cascade_acc=0.6396 | val loss=0.6243(mal=0.4595,sub=0.2732), auc=0.9857, f1=0.8738, recall=0.9091, oracle_f1=0.2069, cascade_acc=0.5354
#   -> no improvement (3/7)
# [ResNet50][Fold 4][Epoch 12] sub_w=0.614 | train loss=0.5839(mal=0.1025,sub=0.7842), auc=0.9972, f1=0.9346, recall=0.9797, oracle_f1=0.3120, cascade_acc=0.7030 | val loss=0.4767(mal=0.3081,sub=0.2747), auc=0.9885, f1=0.8103, recall=0.9495, oracle_f1=0.2710, cascade_acc=0.5556
#   -> best saved (val_auc=0.9885): us_cascade_models/ResNet50_fold4_best.pth
# [ResNet50][Fold 4][Epoch 13] sub_w=0.624 | train loss=0.5877(mal=0.1073,sub=0.7697), auc=0.9967, f1=0.9223, recall=0.9797, oracle_f1=0.2970, cascade_acc=0.6396 | val loss=0.6456(mal=0.4519,sub=0.3103), auc=0.9889, f1=0.8763, recall=0.8586, oracle_f1=0.1977, cascade_acc=0.5152
#   -> no improvement (1/7)
# [ResNet50][Fold 4][Epoch 14] sub_w=0.634 | train loss=0.5063(mal=0.0622,sub=0.6999), auc=0.9989, f1=0.9537, recall=0.9924, oracle_f1=0.3345, cascade_acc=0.7056 | val loss=0.5741(mal=0.3936,sub=0.2845), auc=0.9897, f1=0.9064, recall=0.9293, oracle_f1=0.2333, cascade_acc=0.5051
#   -> best saved (val_auc=0.9897): us_cascade_models/ResNet50_fold4_best.pth
# [ResNet50][Fold 4][Epoch 15] sub_w=0.645 | train loss=0.4639(mal=0.0458,sub=0.6483), auc=0.9993, f1=0.9703, recall=0.9949, oracle_f1=0.3884, cascade_acc=0.7234 | val loss=0.6145(mal=0.4262,sub=0.2921), auc=0.9889, f1=0.8780, recall=0.9091, oracle_f1=0.2120, cascade_acc=0.4646
#   -> no improvement (1/7)
# [ResNet50][Fold 4][Epoch 16] sub_w=0.655 | train loss=0.4494(mal=0.0633,sub=0.5892), auc=0.9990, f1=0.9558, recall=0.9873, oracle_f1=0.4710, cascade_acc=0.7640 | val loss=0.6764(mal=0.4585,sub=0.3325), auc=0.9894, f1=0.9000, recall=0.9091, oracle_f1=0.2780, cascade_acc=0.4848
#   -> no improvement (2/7)
# [ResNet50][Fold 4][Epoch 17] sub_w=0.666 | train loss=0.4589(mal=0.0537,sub=0.6089), auc=0.9991, f1=0.9679, recall=0.9949, oracle_f1=0.4333, cascade_acc=0.7284 | val loss=0.7415(mal=0.5055,sub=0.3546), auc=0.9894, f1=0.8844, recall=0.8889, oracle_f1=0.2144, cascade_acc=0.5455
#   -> no improvement (3/7)
# [ResNet50][Fold 4][Epoch 18] sub_w=0.676 | train loss=0.4533(mal=0.0530,sub=0.5922), auc=0.9991, f1=0.9630, recall=0.9898, oracle_f1=0.4670, cascade_acc=0.7487 | val loss=0.6433(mal=0.3424,sub=0.4453), auc=0.9895, f1=0.8952, recall=0.9495, oracle_f1=0.2209, cascade_acc=0.5960
#   -> no improvement (4/7)
# [ResNet50][Fold 4][Epoch 19] sub_w=0.686 | train loss=0.3869(mal=0.0462,sub=0.4966), auc=0.9992, f1=0.9691, recall=0.9949, oracle_f1=0.5378, cascade_acc=0.7919 | val loss=0.5821(mal=0.3452,sub=0.3452), auc=0.9910, f1=0.8664, recall=0.9495, oracle_f1=0.3033, cascade_acc=0.5051
#   -> best saved (val_auc=0.9910): us_cascade_models/ResNet50_fold4_best.pth
# [ResNet50][Fold 4][Epoch 20] sub_w=0.697 | train loss=0.3792(mal=0.0688,sub=0.4456), auc=0.9986, f1=0.9498, recall=0.9848, oracle_f1=0.6262, cascade_acc=0.8071 | val loss=0.5726(mal=0.2541,sub=0.4572), auc=0.9923, f1=0.8421, recall=0.9697, oracle_f1=0.1766, cascade_acc=0.5152
#   -> best saved (val_auc=0.9923): us_cascade_models/ResNet50_fold4_best.pth
# [ResNet50][Fold 4][Epoch 21] sub_w=0.707 | train loss=0.4280(mal=0.0693,sub=0.5074), auc=0.9985, f1=0.9524, recall=0.9898, oracle_f1=0.6027, cascade_acc=0.7843 | val loss=0.5629(mal=0.2939,sub=0.3805), auc=0.9916, f1=0.8708, recall=0.9192, oracle_f1=0.2351, cascade_acc=0.4646
#   -> no improvement (1/7)
# [ResNet50][Fold 4][Epoch 22] sub_w=0.717 | train loss=0.3107(mal=0.0291,sub=0.3926), auc=0.9998, f1=0.9812, recall=0.9949, oracle_f1=0.6567, cascade_acc=0.8249 | val loss=0.6017(mal=0.3663,sub=0.3282), auc=0.9907, f1=0.8792, recall=0.9192, oracle_f1=0.2481, cascade_acc=0.3838
#   -> no improvement (2/7)
# [ResNet50][Fold 4][Epoch 23] sub_w=0.728 | train loss=0.3199(mal=0.0415,sub=0.3827), auc=0.9996, f1=0.9714, recall=0.9898, oracle_f1=0.7321, cascade_acc=0.8503 | val loss=0.6575(mal=0.3215,sub=0.4618), auc=0.9918, f1=0.8738, recall=0.9091, oracle_f1=0.2234, cascade_acc=0.4747
#   -> no improvement (3/7)
# [ResNet50][Fold 4][Epoch 24] sub_w=0.738 | train loss=0.3295(mal=0.0516,sub=0.3766), auc=0.9993, f1=0.9581, recall=0.9873, oracle_f1=0.7484, cascade_acc=0.8629 | val loss=0.5909(mal=0.3183,sub=0.3695), auc=0.9910, f1=0.8756, recall=0.8889, oracle_f1=0.2912, cascade_acc=0.4949
#   -> no improvement (4/7)
# [ResNet50][Fold 4][Epoch 25] sub_w=0.748 | train loss=0.2881(mal=0.0505,sub=0.3175), auc=0.9993, f1=0.9618, recall=0.9898, oracle_f1=0.7391, cascade_acc=0.8604 | val loss=0.8522(mal=0.4924,sub=0.4809), auc=0.9840, f1=0.8718, recall=0.8586, oracle_f1=0.1903, cascade_acc=0.4040
#   -> no improvement (5/7)
# [ResNet50][Fold 4][Epoch 26] sub_w=0.759 | train loss=0.2409(mal=0.0433,sub=0.2604), auc=0.9996, f1=0.9653, recall=0.9898, oracle_f1=0.7677, cascade_acc=0.8680 | val loss=0.7489(mal=0.4092,sub=0.4478), auc=0.9913, f1=0.8878, recall=0.8788, oracle_f1=0.2219, cascade_acc=0.4747
#   -> no improvement (6/7)
# [ResNet50][Fold 4][Epoch 27] sub_w=0.769 | train loss=0.2029(mal=0.0292,sub=0.2259), auc=0.9997, f1=0.9788, recall=0.9949, oracle_f1=0.8551, cascade_acc=0.9239 | val loss=1.0340(mal=0.6895,sub=0.4481), auc=0.9918, f1=0.9032, recall=0.8485, oracle_f1=0.2242, cascade_acc=0.4949
#   -> no improvement (7/7)
#   -> early stopping triggered at epoch 27
#
# -- Final Evaluation --
# [Malignancy]  AUC=0.9923, F1=0.8421, Recall=0.9697, Acc=0.9417
# [Subtype Oracle]  Acc=0.5152, MacroF1=0.1766
# [Cascade]  SubtypeAcc=0.5152, GateRecall=0.9697
# Binary CM:
# [[486  33]
#  [  3  96]]
# Subtype Oracle CM:
# [[ 1  0  0  0  7]
#  [ 4  0  0  0  2]
#  [ 2  0  1  0 14]
#  [ 2  0  1  0  3]
#  [ 5  0  7  1 49]]
#
# [ResNet50][Fold 4] Final Metrics
# Malignancy  AUC=0.9923, F1=0.8421, Recall=0.9697
# Subtype Oracle  Acc=0.5152, MacroF1=0.1766
# Cascade  Acc=0.5152, GateRecall=0.9697
#
# ================================================================================
# Running ResNet50 | Fold 5
# ================================================================================
# [FOLD 5] Train benign(0): 2078, malignant(1): 394, pos_weight=5.2741, subtype_counts=[32.0, 22.0, 67.0, 24.0, 249.0], subtype_class_weights=[1.1378999948501587, 1.6550999879837036, 0.5435000061988831, 1.517199993133545, 0.1462000012397766]
# [ResNet50][Fold 5][Epoch 01] sub_w=0.500 | train loss=1.2675(mal=0.7441,sub=1.0469), auc=0.8839, f1=0.5685, recall=0.7107, oracle_f1=0.1553, cascade_acc=0.4442 | val loss=0.5483(mal=0.3969,sub=0.3027), auc=0.9702, f1=0.7644, recall=0.8687, oracle_f1=0.1540, cascade_acc=0.5758
#   -> best saved (val_auc=0.9702): us_cascade_models/ResNet50_fold5_best.pth
# [ResNet50][Fold 5][Epoch 02] sub_w=0.510 | train loss=0.9597(mal=0.4399,sub=1.0186), auc=0.9609, f1=0.7497, recall=0.9315, oracle_f1=0.1549, cascade_acc=0.5838 | val loss=0.5218(mal=0.3602,sub=0.3166), auc=0.9758, f1=0.7280, recall=0.9596, oracle_f1=0.1540, cascade_acc=0.6162
#   -> best saved (val_auc=0.9758): us_cascade_models/ResNet50_fold5_best.pth
# [ResNet50][Fold 5][Epoch 03] sub_w=0.521 | train loss=0.8650(mal=0.3460,sub=0.9968), auc=0.9754, f1=0.7901, recall=0.9365, oracle_f1=0.1549, cascade_acc=0.5990 | val loss=0.5002(mal=0.3488,sub=0.2908), auc=0.9740, f1=0.8241, recall=0.8990, oracle_f1=0.1540, cascade_acc=0.5758
#   -> no improvement (1/7)
# [ResNet50][Fold 5][Epoch 04] sub_w=0.531 | train loss=0.7236(mal=0.2263,sub=0.9365), auc=0.9874, f1=0.8539, recall=0.9569, oracle_f1=0.1549, cascade_acc=0.6041 | val loss=0.3942(mal=0.2262,sub=0.3162), auc=0.9899, f1=0.8282, recall=0.9495, oracle_f1=0.1540, cascade_acc=0.5960
#   -> best saved (val_auc=0.9899): us_cascade_models/ResNet50_fold5_best.pth
# [ResNet50][Fold 5][Epoch 05] sub_w=0.541 | train loss=0.6549(mal=0.1867,sub=0.8647), auc=0.9916, f1=0.8639, recall=0.9670, oracle_f1=0.1549, cascade_acc=0.6117 | val loss=0.4556(mal=0.3047,sub=0.2788), auc=0.9931, f1=0.8901, recall=0.8586, oracle_f1=0.1540, cascade_acc=0.5657
#   -> best saved (val_auc=0.9931): us_cascade_models/ResNet50_fold5_best.pth
# [ResNet50][Fold 5][Epoch 06] sub_w=0.552 | train loss=0.6884(mal=0.1788,sub=0.9237), auc=0.9917, f1=0.8761, recall=0.9695, oracle_f1=0.1544, cascade_acc=0.6066 | val loss=0.4020(mal=0.2463,sub=0.2822), auc=0.9885, f1=0.8762, recall=0.9293, oracle_f1=0.2182, cascade_acc=0.6061
#   -> no improvement (1/7)
# [ResNet50][Fold 5][Epoch 07] sub_w=0.562 | train loss=0.6628(mal=0.1555,sub=0.9026), auc=0.9945, f1=0.8866, recall=0.9721, oracle_f1=0.1979, cascade_acc=0.6244 | val loss=0.4903(mal=0.3273,sub=0.2900), auc=0.9935, f1=0.8947, recall=0.8586, oracle_f1=0.2595, cascade_acc=0.5960
#   -> no improvement (2/7)
# [ResNet50][Fold 5][Epoch 08] sub_w=0.572 | train loss=0.6119(mal=0.1115,sub=0.8742), auc=0.9962, f1=0.9353, recall=0.9898, oracle_f1=0.2227, cascade_acc=0.6294 | val loss=0.4496(mal=0.2534,sub=0.3427), auc=0.9897, f1=0.8708, recall=0.9192, oracle_f1=0.2714, cascade_acc=0.6465
#   -> no improvement (3/7)
# [ResNet50][Fold 5][Epoch 09] sub_w=0.583 | train loss=0.5902(mal=0.1134,sub=0.8181), auc=0.9964, f1=0.9234, recall=0.9797, oracle_f1=0.2326, cascade_acc=0.6371 | val loss=0.4755(mal=0.2935,sub=0.3122), auc=0.9887, f1=0.8889, recall=0.9293, oracle_f1=0.2129, cascade_acc=0.6061
#   -> no improvement (4/7)
# [ResNet50][Fold 5][Epoch 10] sub_w=0.593 | train loss=0.5799(mal=0.1341,sub=0.7517), auc=0.9952, f1=0.9145, recall=0.9772, oracle_f1=0.2501, cascade_acc=0.6599 | val loss=0.3734(mal=0.1987,sub=0.2946), auc=0.9944, f1=0.9055, recall=0.9192, oracle_f1=0.2495, cascade_acc=0.6162
#   -> best saved (val_auc=0.9944): us_cascade_models/ResNet50_fold5_best.pth
# [ResNet50][Fold 5][Epoch 11] sub_w=0.603 | train loss=0.5895(mal=0.0948,sub=0.8199), auc=0.9971, f1=0.9314, recall=0.9822, oracle_f1=0.2414, cascade_acc=0.6421 | val loss=0.5017(mal=0.3345,sub=0.2772), auc=0.9935, f1=0.8947, recall=0.8586, oracle_f1=0.2277, cascade_acc=0.5051
#   -> no improvement (1/7)
# [ResNet50][Fold 5][Epoch 12] sub_w=0.614 | train loss=0.6050(mal=0.1241,sub=0.7836), auc=0.9960, f1=0.9165, recall=0.9746, oracle_f1=0.2482, cascade_acc=0.6421 | val loss=0.3723(mal=0.1628,sub=0.3414), auc=0.9952, f1=0.9171, recall=0.9495, oracle_f1=0.2544, cascade_acc=0.6061
#   -> no improvement (2/7)
# [ResNet50][Fold 5][Epoch 13] sub_w=0.624 | train loss=0.5363(mal=0.0799,sub=0.7314), auc=0.9983, f1=0.9361, recall=0.9848, oracle_f1=0.2602, cascade_acc=0.6650 | val loss=0.4895(mal=0.2443,sub=0.3929), auc=0.9944, f1=0.9246, recall=0.9293, oracle_f1=0.2542, cascade_acc=0.6061
#   -> no improvement (3/7)
# [ResNet50][Fold 5][Epoch 14] sub_w=0.634 | train loss=0.5207(mal=0.0689,sub=0.7120), auc=0.9985, f1=0.9513, recall=0.9924, oracle_f1=0.3033, cascade_acc=0.6954 | val loss=0.4568(mal=0.2656,sub=0.3014), auc=0.9931, f1=0.9045, recall=0.9091, oracle_f1=0.2892, cascade_acc=0.5859
#   -> no improvement (4/7)
# [ResNet50][Fold 5][Epoch 15] sub_w=0.645 | train loss=0.5338(mal=0.0456,sub=0.7571), auc=0.9993, f1=0.9751, recall=0.9949, oracle_f1=0.3246, cascade_acc=0.6802 | val loss=0.5456(mal=0.3138,sub=0.3595), auc=0.9935, f1=0.9286, recall=0.9192, oracle_f1=0.2574, cascade_acc=0.5556
#   -> no improvement (5/7)
# [ResNet50][Fold 5][Epoch 16] sub_w=0.655 | train loss=0.4795(mal=0.0403,sub=0.6703), auc=0.9995, f1=0.9667, recall=0.9949, oracle_f1=0.3948, cascade_acc=0.7081 | val loss=0.4956(mal=0.2420,sub=0.3871), auc=0.9944, f1=0.9038, recall=0.9495, oracle_f1=0.2822, cascade_acc=0.5960
#   -> no improvement (6/7)
# [ResNet50][Fold 5][Epoch 17] sub_w=0.666 | train loss=0.5092(mal=0.0913,sub=0.6280), auc=0.9981, f1=0.9358, recall=0.9797, oracle_f1=0.3661, cascade_acc=0.7030 | val loss=0.4324(mal=0.1734,sub=0.3892), auc=0.9948, f1=0.8899, recall=0.9798, oracle_f1=0.2992, cascade_acc=0.6263
#   -> no improvement (7/7)
#   -> early stopping triggered at epoch 17
#
# -- Final Evaluation --
# [Malignancy]  AUC=0.9944, F1=0.9055, Recall=0.9192, Acc=0.9693
# [Subtype Oracle]  Acc=0.6566, MacroF1=0.2495
# [Cascade]  SubtypeAcc=0.6162, GateRecall=0.9192
# Binary CM:
# [[508  11]
#  [  8  91]]
# Subtype Oracle CM:
# [[ 0  0  2  0  6]
#  [ 0  0  1  0  4]
#  [ 0  0  8  0  9]
#  [ 0  0  3  0  4]
#  [ 0  0  5  0 57]]
#
# [ResNet50][Fold 5] Final Metrics
# Malignancy  AUC=0.9944, F1=0.9055, Recall=0.9192
# Subtype Oracle  Acc=0.6566, MacroF1=0.2495
# Cascade  Acc=0.6162, GateRecall=0.9192
#       model  fold   mal_acc   mal_auc    mal_f1  mal_recall  \
# 0  ResNet50     1  0.964401  0.993652  0.894231    0.948980
# 1  ResNet50     2  0.975728  0.995604  0.926829    0.969388
# 2  ResNet50     3  0.964401  0.995981  0.898148    0.979798
# 3  ResNet50     4  0.941748  0.992293  0.842105    0.969697
# 4  ResNet50     5  0.969256  0.994356  0.905473    0.919192
#
#    subtype_oracle_acc  subtype_oracle_macro_f1  subtype_cascade_acc  \
# 0            0.632653                 0.155000             0.581633
# 1            0.632653                 0.240772             0.622449
# 2            0.606061                 0.204685             0.595960
# 3            0.515152                 0.176632             0.515152
# 4            0.656566                 0.249452             0.616162
#
#    subtype_gate_recall             binary_cm  \
# 0             0.948980  [[503, 17], [5, 93]]
# 1             0.969388  [[508, 12], [3, 95]]
# 2             0.979798  [[499, 20], [2, 97]]
# 3             0.969697  [[486, 33], [3, 96]]
# 4             0.919192  [[508, 11], [8, 91]]
#
#                                    subtype_oracle_cm
# 0  [[0, 0, 0, 0, 8], [0, 0, 0, 0, 5], [0, 0, 0, 0...
# 1  [[0, 0, 0, 0, 8], [0, 0, 2, 0, 3], [0, 0, 8, 0...
# 2  [[0, 0, 0, 0, 8], [0, 0, 0, 0, 6], [0, 0, 4, 0...
# 3  [[1, 0, 0, 0, 7], [4, 0, 0, 0, 2], [2, 0, 1, 0...
# 4  [[0, 0, 2, 0, 6], [0, 0, 1, 0, 4], [0, 0, 8, 0...
# >>> Training ViT-B/16...
#
# ================================================================================
# Running ViT-B16 | Fold 1
# ================================================================================
# [FOLD 1] Train benign(0): 2077, malignant(1): 395, pos_weight=5.2582, subtype_counts=[32.0, 22.0, 67.0, 25.0, 249.0], subtype_class_weights=[1.151900053024292, 1.6755000352859497, 0.5501999855041504, 1.4744000434875488, 0.14800000190734863]
# [ViT-B16][Fold 1][Epoch 01] sub_w=0.500 | train loss=1.6950(mal=1.1758,sub=1.0384), auc=0.5098, f1=0.2517, recall=0.5063, oracle_f1=0.1669, cascade_acc=0.3342 | val loss=1.3083(mal=1.1629,sub=0.2909), auc=0.6340, f1=0.2737, recall=1.0000, oracle_f1=0.1550, cascade_acc=0.6327
#   -> best saved (val_auc=0.6340): us_cascade_models/ViT-B16_fold1_best.pth
# [ViT-B16][Fold 1][Epoch 02] sub_w=0.510 | train loss=1.6280(mal=1.1551,sub=0.9266), auc=0.5635, f1=0.2776, recall=0.5291, oracle_f1=0.1547, cascade_acc=0.3747 | val loss=1.3395(mal=1.1831,sub=0.3064), auc=0.5989, f1=0.2900, recall=0.4898, oracle_f1=0.1550, cascade_acc=0.3571
#   -> no improvement (1/7)
# [ViT-B16][Fold 1][Epoch 03] sub_w=0.521 | train loss=1.6418(mal=1.1365,sub=0.9704), auc=0.5785, f1=0.2909, recall=0.3848, oracle_f1=0.1547, cascade_acc=0.2911 | val loss=1.2638(mal=1.1112,sub=0.2932), auc=0.6025, f1=0.2479, recall=0.1531, oracle_f1=0.1550, cascade_acc=0.0918
#   -> no improvement (2/7)
# [ViT-B16][Fold 1][Epoch 04] sub_w=0.531 | train loss=1.6690(mal=1.1438,sub=0.9890), auc=0.5613, f1=0.2615, recall=0.4329, oracle_f1=0.1547, cascade_acc=0.3089 | val loss=1.2337(mal=1.0911,sub=0.2686), auc=0.5981, f1=0.3474, recall=0.3367, oracle_f1=0.1550, cascade_acc=0.2551
#   -> no improvement (3/7)
# [ViT-B16][Fold 1][Epoch 05] sub_w=0.541 | train loss=1.6500(mal=1.1167,sub=0.9850), auc=0.6152, f1=0.3397, recall=0.3848, oracle_f1=0.1547, cascade_acc=0.2835 | val loss=1.2396(mal=1.0901,sub=0.2762), auc=0.6044, f1=0.3656, recall=0.3469, oracle_f1=0.1550, cascade_acc=0.2653
#   -> no improvement (4/7)
# [ViT-B16][Fold 1][Epoch 06] sub_w=0.552 | train loss=1.6540(mal=1.1033,sub=0.9982), auc=0.6108, f1=0.3472, recall=0.3392, oracle_f1=0.1547, cascade_acc=0.2506 | val loss=1.2762(mal=1.1114,sub=0.2988), auc=0.5970, f1=0.3541, recall=0.3776, oracle_f1=0.1550, cascade_acc=0.2857
#   -> no improvement (5/7)
# [ViT-B16][Fold 1][Epoch 07] sub_w=0.562 | train loss=1.6287(mal=1.1095,sub=0.9238), auc=0.6121, f1=0.3143, recall=0.3139, oracle_f1=0.1547, cascade_acc=0.2354 | val loss=1.2776(mal=1.1072,sub=0.3032), auc=0.6309, f1=0.3308, recall=0.4388, oracle_f1=0.1550, cascade_acc=0.3265
#   -> no improvement (6/7)
# [ViT-B16][Fold 1][Epoch 08] sub_w=0.572 | train loss=1.6865(mal=1.1145,sub=0.9993), auc=0.6139, f1=0.3122, recall=0.3494, oracle_f1=0.1549, cascade_acc=0.2532 | val loss=1.2882(mal=1.1219,sub=0.2905), auc=0.6411, f1=0.3444, recall=0.2653, oracle_f1=0.1550, cascade_acc=0.1939
#   -> best saved (val_auc=0.6411): us_cascade_models/ViT-B16_fold1_best.pth
# [ViT-B16][Fold 1][Epoch 09] sub_w=0.583 | train loss=1.7244(mal=1.1417,sub=0.9999), auc=0.5816, f1=0.2928, recall=0.4203, oracle_f1=0.1685, cascade_acc=0.2785 | val loss=1.2839(mal=1.1071,sub=0.3034), auc=0.6413, f1=0.3557, recall=0.4592, oracle_f1=0.1550, cascade_acc=0.3367
#   -> no improvement (1/7)
# [ViT-B16][Fold 1][Epoch 10] sub_w=0.593 | train loss=1.6970(mal=1.1211,sub=0.9709), auc=0.6145, f1=0.3168, recall=0.4203, oracle_f1=0.1648, cascade_acc=0.2861 | val loss=1.2598(mal=1.0971,sub=0.2744), auc=0.6428, f1=0.3310, recall=0.4796, oracle_f1=0.1550, cascade_acc=0.3367
#   -> best saved (val_auc=0.6428): us_cascade_models/ViT-B16_fold1_best.pth
# [ViT-B16][Fold 1][Epoch 11] sub_w=0.603 | train loss=1.7040(mal=1.1193,sub=0.9689), auc=0.6272, f1=0.3302, recall=0.4937, oracle_f1=0.1707, cascade_acc=0.3342 | val loss=1.2954(mal=1.1260,sub=0.2806), auc=0.6022, f1=0.3356, recall=0.7653, oracle_f1=0.1550, cascade_acc=0.4898
#   -> no improvement (1/7)
# [ViT-B16][Fold 1][Epoch 12] sub_w=0.614 | train loss=1.7298(mal=1.1193,sub=0.9947), auc=0.6293, f1=0.3363, recall=0.5266, oracle_f1=0.1547, cascade_acc=0.3696 | val loss=1.2824(mal=1.1098,sub=0.2813), auc=0.6611, f1=0.3548, recall=0.5612, oracle_f1=0.1550, cascade_acc=0.3980
#   -> best saved (val_auc=0.6611): us_cascade_models/ViT-B16_fold1_best.pth
# [ViT-B16][Fold 1][Epoch 13] sub_w=0.624 | train loss=1.7200(mal=1.1094,sub=0.9783), auc=0.6429, f1=0.3422, recall=0.5215, oracle_f1=0.1586, cascade_acc=0.3544 | val loss=1.2787(mal=1.0910,sub=0.3008), auc=0.6417, f1=0.3659, recall=0.4592, oracle_f1=0.1550, cascade_acc=0.3469
#   -> no improvement (1/7)
# [ViT-B16][Fold 1][Epoch 14] sub_w=0.634 | train loss=1.7735(mal=1.1237,sub=1.0242), auc=0.6247, f1=0.3219, recall=0.5443, oracle_f1=0.1636, cascade_acc=0.3873 | val loss=1.2953(mal=1.1161,sub=0.2825), auc=0.6715, f1=0.3448, recall=0.6122, oracle_f1=0.1550, cascade_acc=0.4082
#   -> best saved (val_auc=0.6715): us_cascade_models/ViT-B16_fold1_best.pth
# [ViT-B16][Fold 1][Epoch 15] sub_w=0.645 | train loss=1.7347(mal=1.1033,sub=0.9792), auc=0.6485, f1=0.3591, recall=0.5595, oracle_f1=0.1547, cascade_acc=0.3772 | val loss=1.2836(mal=1.0883,sub=0.3028), auc=0.6419, f1=0.3433, recall=0.4694, oracle_f1=0.1550, cascade_acc=0.3163
#   -> no improvement (1/7)
# [ViT-B16][Fold 1][Epoch 16] sub_w=0.655 | train loss=1.7584(mal=1.1114,sub=0.9876), auc=0.6380, f1=0.3449, recall=0.5038, oracle_f1=0.1547, cascade_acc=0.3468 | val loss=1.2924(mal=1.1069,sub=0.2831), auc=0.6339, f1=0.3312, recall=0.5204, oracle_f1=0.1550, cascade_acc=0.3571
#   -> no improvement (2/7)
# [ViT-B16][Fold 1][Epoch 17] sub_w=0.666 | train loss=1.7346(mal=1.1051,sub=0.9458), auc=0.6345, f1=0.3542, recall=0.5089, oracle_f1=0.1547, cascade_acc=0.3443 | val loss=1.3213(mal=1.1252,sub=0.2948), auc=0.6437, f1=0.3191, recall=0.5714, oracle_f1=0.1550, cascade_acc=0.3878
#   -> no improvement (3/7)
# [ViT-B16][Fold 1][Epoch 18] sub_w=0.676 | train loss=1.7275(mal=1.0939,sub=0.9375), auc=0.6497, f1=0.3701, recall=0.5443, oracle_f1=0.1547, cascade_acc=0.3823 | val loss=1.3115(mal=1.1091,sub=0.2994), auc=0.6418, f1=0.3522, recall=0.5408, oracle_f1=0.1550, cascade_acc=0.3878
#   -> no improvement (4/7)
# [ViT-B16][Fold 1][Epoch 19] sub_w=0.686 | train loss=1.7583(mal=1.1042,sub=0.9532), auc=0.6314, f1=0.3570, recall=0.4835, oracle_f1=0.1547, cascade_acc=0.3342 | val loss=1.2914(mal=1.0932,sub=0.2889), auc=0.6756, f1=0.3525, recall=0.4694, oracle_f1=0.1550, cascade_acc=0.3367
#   -> best saved (val_auc=0.6756): us_cascade_models/ViT-B16_fold1_best.pth
# [ViT-B16][Fold 1][Epoch 20] sub_w=0.697 | train loss=1.7704(mal=1.0916,sub=0.9744), auc=0.6604, f1=0.3674, recall=0.5418, oracle_f1=0.1547, cascade_acc=0.3873 | val loss=1.2898(mal=1.0868,sub=0.2914), auc=0.6694, f1=0.3642, recall=0.5612, oracle_f1=0.1550, cascade_acc=0.3776
#   -> no improvement (1/7)
# [ViT-B16][Fold 1][Epoch 21] sub_w=0.707 | train loss=1.7873(mal=1.0903,sub=0.9860), auc=0.6645, f1=0.3703, recall=0.5620, oracle_f1=0.1549, cascade_acc=0.3848 | val loss=1.2877(mal=1.0828,sub=0.2900), auc=0.6555, f1=0.3505, recall=0.5204, oracle_f1=0.1550, cascade_acc=0.3571
#   -> no improvement (2/7)
# [ViT-B16][Fold 1][Epoch 22] sub_w=0.717 | train loss=1.8011(mal=1.1039,sub=0.9720), auc=0.6484, f1=0.3655, recall=0.5468, oracle_f1=0.1543, cascade_acc=0.3671 | val loss=1.3148(mal=1.1089,sub=0.2871), auc=0.6726, f1=0.3294, recall=0.4286, oracle_f1=0.1550, cascade_acc=0.3163
#   -> no improvement (3/7)
# [ViT-B16][Fold 1][Epoch 23] sub_w=0.728 | train loss=1.7902(mal=1.0842,sub=0.9703), auc=0.6734, f1=0.3623, recall=0.5696, oracle_f1=0.1536, cascade_acc=0.3696 | val loss=1.3075(mal=1.1036,sub=0.2803), auc=0.6760, f1=0.3239, recall=0.5816, oracle_f1=0.1550, cascade_acc=0.3980
#   -> no improvement (4/7)
# [ViT-B16][Fold 1][Epoch 24] sub_w=0.738 | train loss=1.7908(mal=1.0866,sub=0.9543), auc=0.6715, f1=0.3635, recall=0.6405, oracle_f1=0.1547, cascade_acc=0.4253 | val loss=1.3249(mal=1.1199,sub=0.2777), auc=0.6912, f1=0.3147, recall=0.7755, oracle_f1=0.1550, cascade_acc=0.5204
#   -> best saved (val_auc=0.6912): us_cascade_models/ViT-B16_fold1_best.pth
# [ViT-B16][Fold 1][Epoch 25] sub_w=0.748 | train loss=1.8317(mal=1.1066,sub=0.9691), auc=0.6507, f1=0.3349, recall=0.5367, oracle_f1=0.1655, cascade_acc=0.3392 | val loss=1.3071(mal=1.0929,sub=0.2864), auc=0.6881, f1=0.3326, recall=0.7347, oracle_f1=0.1550, cascade_acc=0.4490
#   -> no improvement (1/7)
# [ViT-B16][Fold 1][Epoch 26] sub_w=0.759 | train loss=1.8040(mal=1.0764,sub=0.9591), auc=0.6855, f1=0.3681, recall=0.6076, oracle_f1=0.1551, cascade_acc=0.4051 | val loss=1.2271(mal=1.0144,sub=0.2804), auc=0.7734, f1=0.4291, recall=0.6020, oracle_f1=0.1550, cascade_acc=0.3878
#   -> best saved (val_auc=0.7734): us_cascade_models/ViT-B16_fold1_best.pth
# [ViT-B16][Fold 1][Epoch 27] sub_w=0.769 | train loss=1.7836(mal=1.0397,sub=0.9675), auc=0.7197, f1=0.3868, recall=0.6810, oracle_f1=0.1547, cascade_acc=0.4253 | val loss=1.1623(mal=0.9631,sub=0.2590), auc=0.7856, f1=0.4387, recall=0.6020, oracle_f1=0.1550, cascade_acc=0.4082
#   -> best saved (val_auc=0.7856): us_cascade_models/ViT-B16_fold1_best.pth
# [ViT-B16][Fold 1][Epoch 28] sub_w=0.779 | train loss=1.7467(mal=0.9983,sub=0.9604), auc=0.7509, f1=0.4127, recall=0.7089, oracle_f1=0.1547, cascade_acc=0.4532 | val loss=1.1828(mal=0.9592,sub=0.2869), auc=0.7782, f1=0.4205, recall=0.7551, oracle_f1=0.1550, cascade_acc=0.5102
#   -> no improvement (1/7)
# [ViT-B16][Fold 1][Epoch 29] sub_w=0.790 | train loss=1.7313(mal=0.9507,sub=0.9885), auc=0.7806, f1=0.4379, recall=0.7316, oracle_f1=0.1545, cascade_acc=0.4430 | val loss=1.1673(mal=0.9423,sub=0.2849), auc=0.7891, f1=0.4422, recall=0.6633, oracle_f1=0.1550, cascade_acc=0.4388
#   -> best saved (val_auc=0.7891): us_cascade_models/ViT-B16_fold1_best.pth
# [ViT-B16][Fold 1][Epoch 30] sub_w=0.800 | train loss=1.7432(mal=0.9750,sub=0.9602), auc=0.7626, f1=0.4214, recall=0.7392, oracle_f1=0.1547, cascade_acc=0.4759 | val loss=1.3734(mal=1.1376,sub=0.2948), auc=0.7640, f1=0.3600, recall=0.2755, oracle_f1=0.1550, cascade_acc=0.1633
#   -> no improvement (1/7)
#
# -- Final Evaluation --
# [Malignancy]  AUC=0.7891, F1=0.4422, Recall=0.6633, Acc=0.7346
# [Subtype Oracle]  Acc=0.6327, MacroF1=0.1550
# [Cascade]  SubtypeAcc=0.4388, GateRecall=0.6633
# Binary CM:
# [[389 131]
#  [ 33  65]]
# Subtype Oracle CM:
# [[ 0  0  0  0  8]
#  [ 0  0  0  0  5]
#  [ 0  0  0  0 17]
#  [ 0  0  0  0  6]
#  [ 0  0  0  0 62]]
#
# [ViT-B16][Fold 1] Final Metrics
# Malignancy  AUC=0.7891, F1=0.4422, Recall=0.6633
# Subtype Oracle  Acc=0.6327, MacroF1=0.1550
# Cascade  Acc=0.4388, GateRecall=0.6633
#
# ================================================================================
# Running ViT-B16 | Fold 2
# ================================================================================
# [FOLD 2] Train benign(0): 2077, malignant(1): 395, pos_weight=5.2582, subtype_counts=[32.0, 22.0, 67.0, 25.0, 249.0], subtype_class_weights=[1.151900053024292, 1.6755000352859497, 0.5501999855041504, 1.4744000434875488, 0.14800000190734863]
# [ViT-B16][Fold 2][Epoch 01] sub_w=0.500 | train loss=1.6893(mal=1.1719,sub=1.0347), auc=0.5042, f1=0.2460, recall=0.4886, oracle_f1=0.1539, cascade_acc=0.3241 | val loss=1.2875(mal=1.1624,sub=0.2503), auc=0.5246, f1=0.2737, recall=1.0000, oracle_f1=0.1550, cascade_acc=0.6327
#   -> best saved (val_auc=0.5246): us_cascade_models/ViT-B16_fold2_best.pth
# [ViT-B16][Fold 2][Epoch 02] sub_w=0.510 | train loss=1.6510(mal=1.1560,sub=0.9700), auc=0.5569, f1=0.2762, recall=0.5595, oracle_f1=0.1543, cascade_acc=0.3747 | val loss=1.2936(mal=1.1613,sub=0.2593), auc=0.5737, f1=0.0000, recall=0.0000, oracle_f1=0.1550, cascade_acc=0.0000
#   -> best saved (val_auc=0.5737): us_cascade_models/ViT-B16_fold2_best.pth
# [ViT-B16][Fold 2][Epoch 03] sub_w=0.521 | train loss=1.6153(mal=1.1238,sub=0.9438), auc=0.6091, f1=0.2917, recall=0.4228, oracle_f1=0.1595, cascade_acc=0.3063 | val loss=1.2967(mal=1.1550,sub=0.2721), auc=0.5817, f1=0.2839, recall=0.2245, oracle_f1=0.1550, cascade_acc=0.1633
#   -> best saved (val_auc=0.5817): us_cascade_models/ViT-B16_fold2_best.pth
# [ViT-B16][Fold 2][Epoch 04] sub_w=0.531 | train loss=1.6331(mal=1.1221,sub=0.9623), auc=0.5935, f1=0.2909, recall=0.4253, oracle_f1=0.1547, cascade_acc=0.3038 | val loss=1.3160(mal=1.1675,sub=0.2796), auc=0.5798, f1=0.1654, recall=0.1122, oracle_f1=0.1550, cascade_acc=0.0612
#   -> no improvement (1/7)
# [ViT-B16][Fold 2][Epoch 05] sub_w=0.541 | train loss=1.6584(mal=1.1222,sub=0.9905), auc=0.6136, f1=0.3230, recall=0.3823, oracle_f1=0.1547, cascade_acc=0.2785 | val loss=1.2801(mal=1.1283,sub=0.2803), auc=0.5881, f1=0.2709, recall=0.4796, oracle_f1=0.1550, cascade_acc=0.3265
#   -> best saved (val_auc=0.5881): us_cascade_models/ViT-B16_fold2_best.pth
# [ViT-B16][Fold 2][Epoch 06] sub_w=0.552 | train loss=1.6470(mal=1.1159,sub=0.9627), auc=0.5992, f1=0.3210, recall=0.3722, oracle_f1=0.1547, cascade_acc=0.2633 | val loss=1.2987(mal=1.1412,sub=0.2854), auc=0.6011, f1=0.1955, recall=0.1327, oracle_f1=0.1550, cascade_acc=0.0714
#   -> best saved (val_auc=0.6011): us_cascade_models/ViT-B16_fold2_best.pth
# [ViT-B16][Fold 2][Epoch 07] sub_w=0.562 | train loss=1.6606(mal=1.1066,sub=0.9856), auc=0.6034, f1=0.3244, recall=0.3215, oracle_f1=0.1547, cascade_acc=0.2456 | val loss=1.2844(mal=1.1213,sub=0.2903), auc=0.6404, f1=0.3147, recall=0.3163, oracle_f1=0.1550, cascade_acc=0.2449
#   -> best saved (val_auc=0.6404): us_cascade_models/ViT-B16_fold2_best.pth
# [ViT-B16][Fold 2][Epoch 08] sub_w=0.572 | train loss=1.6863(mal=1.1210,sub=0.9876), auc=0.5747, f1=0.2840, recall=0.2987, oracle_f1=0.1547, cascade_acc=0.2177 | val loss=1.2955(mal=1.1347,sub=0.2810), auc=0.6077, f1=0.2302, recall=0.1633, oracle_f1=0.1550, cascade_acc=0.1020
#   -> no improvement (1/7)
# ...
#   -> no improvement (6/7)
# [Hybrid][Fold 3][Epoch 21] sub_w=0.707 | train loss=0.5970(mal=0.0928,sub=0.7133), auc=0.9977, f1=0.9415, recall=0.9797, oracle_f1=0.4062, cascade_acc=0.7132 | val loss=0.5689(mal=0.3085,sub=0.3683), auc=0.9893, f1=0.8788, recall=0.8788, oracle_f1=0.2063, cascade_acc=0.5152
#   -> no improvement (7/7)
#   -> early stopping triggered at epoch 21
#
# -- Final Evaluation --
# [Malignancy]  AUC=0.9963, F1=0.9293, Recall=0.9293, Acc=0.9773
# [Subtype Oracle]  Acc=0.6566, MacroF1=0.2110
# [Cascade]  SubtypeAcc=0.6061, GateRecall=0.9293
# Binary CM:
# [[512   7]
#  [  7  92]]
# Subtype Oracle CM:
# [[ 0  0  0  0  8]
#  [ 0  0  0  0  6]
#  [ 0  0  3  0 13]
#  [ 0  0  4  0  2]
#  [ 0  0  1  0 62]]
#
# [Hybrid][Fold 3] Final Metrics
# Malignancy  AUC=0.9963, F1=0.9293, Recall=0.9293
# Subtype Oracle  Acc=0.6566, MacroF1=0.2110
# Cascade  Acc=0.6061, GateRecall=0.9293
#
# ================================================================================
# Running Hybrid | Fold 4
# ================================================================================
# [FOLD 4] Train benign(0): 2078, malignant(1): 394, pos_weight=5.2741, subtype_counts=[32.0, 21.0, 67.0, 25.0, 249.0], subtype_class_weights=[1.1338000297546387, 1.7276999950408936, 0.5414999723434448, 1.451300024986267, 0.14569999277591705]
# [Hybrid][Fold 4][Epoch 01] sub_w=0.500 | train loss=1.1242(mal=0.6055,sub=1.0374), auc=0.9198, f1=0.6174, recall=0.8274, oracle_f1=0.1544, cascade_acc=0.5127 | val loss=0.5812(mal=0.4355,sub=0.2914), auc=0.9668, f1=0.7782, recall=0.9394, oracle_f1=0.1540, cascade_acc=0.5859
#   -> best saved (val_auc=0.9668): us_cascade_models/Hybrid_fold4_best.pth
# [Hybrid][Fold 4][Epoch 02] sub_w=0.510 | train loss=0.8523(mal=0.3553,sub=0.9739), auc=0.9694, f1=0.7926, recall=0.9213, oracle_f1=0.1780, cascade_acc=0.5914 | val loss=0.4935(mal=0.3535,sub=0.2744), auc=0.9797, f1=0.8091, recall=0.8990, oracle_f1=0.1540, cascade_acc=0.5556
#   -> best saved (val_auc=0.9797): us_cascade_models/Hybrid_fold4_best.pth
# [Hybrid][Fold 4][Epoch 03] sub_w=0.521 | train loss=0.7675(mal=0.2696,sub=0.9562), auc=0.9802, f1=0.8389, recall=0.9518, oracle_f1=0.1710, cascade_acc=0.6091 | val loss=0.4747(mal=0.3232,sub=0.2910), auc=0.9813, f1=0.8103, recall=0.9495, oracle_f1=0.1694, cascade_acc=0.5960
#   -> best saved (val_auc=0.9813): us_cascade_models/Hybrid_fold4_best.pth
# [Hybrid][Fold 4][Epoch 04] sub_w=0.531 | train loss=0.7266(mal=0.2231,sub=0.9482), auc=0.9879, f1=0.8381, recall=0.9594, oracle_f1=0.2006, cascade_acc=0.5914 | val loss=0.6546(mal=0.5077,sub=0.2765), auc=0.9614, f1=0.8599, recall=0.8990, oracle_f1=0.1975, cascade_acc=0.5758
#   -> no improvement (1/7)
# [Hybrid][Fold 4][Epoch 05] sub_w=0.541 | train loss=0.7636(mal=0.2421,sub=0.9632), auc=0.9845, f1=0.8526, recall=0.9543, oracle_f1=0.2096, cascade_acc=0.5990 | val loss=0.4177(mal=0.2573,sub=0.2962), auc=0.9876, f1=0.8356, recall=0.9495, oracle_f1=0.1671, cascade_acc=0.5859
#   -> best saved (val_auc=0.9876): us_cascade_models/Hybrid_fold4_best.pth
# [Hybrid][Fold 4][Epoch 06] sub_w=0.552 | train loss=0.6882(mal=0.1737,sub=0.9326), auc=0.9912, f1=0.9040, recall=0.9797, oracle_f1=0.2058, cascade_acc=0.5838 | val loss=0.4930(mal=0.3133,sub=0.3257), auc=0.9858, f1=0.8319, recall=0.9495, oracle_f1=0.1695, cascade_acc=0.5960
#   -> no improvement (1/7)
# [Hybrid][Fold 4][Epoch 07] sub_w=0.562 | train loss=0.6678(mal=0.1581,sub=0.9067), auc=0.9919, f1=0.9025, recall=0.9746, oracle_f1=0.2103, cascade_acc=0.6168 | val loss=0.5355(mal=0.3457,sub=0.3376), auc=0.9863, f1=0.8558, recall=0.8990, oracle_f1=0.1762, cascade_acc=0.5354
#   -> no improvement (2/7)
# [Hybrid][Fold 4][Epoch 08] sub_w=0.572 | train loss=0.6123(mal=0.1128,sub=0.8725), auc=0.9966, f1=0.9227, recall=0.9848, oracle_f1=0.2386, cascade_acc=0.6396 | val loss=0.5902(mal=0.4129,sub=0.3096), auc=0.9854, f1=0.8430, recall=0.9495, oracle_f1=0.1854, cascade_acc=0.5657
#   -> no improvement (3/7)
# [Hybrid][Fold 4][Epoch 09] sub_w=0.583 | train loss=0.6154(mal=0.1302,sub=0.8326), auc=0.9939, f1=0.9145, recall=0.9772, oracle_f1=0.2645, cascade_acc=0.6396 | val loss=0.6546(mal=0.4773,sub=0.3042), auc=0.9851, f1=0.8585, recall=0.8889, oracle_f1=0.2220, cascade_acc=0.5354
#   -> no improvement (4/7)
# [Hybrid][Fold 4][Epoch 10] sub_w=0.593 | train loss=0.6042(mal=0.0864,sub=0.8730), auc=0.9978, f1=0.9511, recall=0.9873, oracle_f1=0.3024, cascade_acc=0.6726 | val loss=0.4208(mal=0.2578,sub=0.2748), auc=0.9919, f1=0.8922, recall=0.9192, oracle_f1=0.1339, cascade_acc=0.1919
#   -> best saved (val_auc=0.9919): us_cascade_models/Hybrid_fold4_best.pth
# [Hybrid][Fold 4][Epoch 11] sub_w=0.603 | train loss=0.5945(mal=0.0986,sub=0.8218), auc=0.9976, f1=0.9354, recall=0.9746, oracle_f1=0.2667, cascade_acc=0.6371 | val loss=0.5582(mal=0.3857,sub=0.2860), auc=0.9887, f1=0.8942, recall=0.9394, oracle_f1=0.2562, cascade_acc=0.5354
#   -> no improvement (1/7)
# [Hybrid][Fold 4][Epoch 12] sub_w=0.614 | train loss=0.5926(mal=0.1000,sub=0.8026), auc=0.9967, f1=0.9451, recall=0.9822, oracle_f1=0.2918, cascade_acc=0.6675 | val loss=0.4072(mal=0.2027,sub=0.3332), auc=0.9905, f1=0.8868, recall=0.9495, oracle_f1=0.1643, cascade_acc=0.5556
#   -> no improvement (2/7)
# [Hybrid][Fold 4][Epoch 13] sub_w=0.624 | train loss=0.5779(mal=0.0889,sub=0.7835), auc=0.9977, f1=0.9499, recall=0.9873, oracle_f1=0.3362, cascade_acc=0.6980 | val loss=0.7157(mal=0.5299,sub=0.2977), auc=0.9892, f1=0.8900, recall=0.8990, oracle_f1=0.2216, cascade_acc=0.5455
#   -> no improvement (3/7)
# [Hybrid][Fold 4][Epoch 14] sub_w=0.634 | train loss=0.5489(mal=0.0841,sub=0.7325), auc=0.9974, f1=0.9463, recall=0.9848, oracle_f1=0.3340, cascade_acc=0.6904 | val loss=0.4956(mal=0.3015,sub=0.3058), auc=0.9876, f1=0.8120, recall=0.9596, oracle_f1=0.2432, cascade_acc=0.5152
#   -> no improvement (4/7)
# [Hybrid][Fold 4][Epoch 15] sub_w=0.645 | train loss=0.5765(mal=0.1059,sub=0.7299), auc=0.9974, f1=0.9178, recall=0.9772, oracle_f1=0.3333, cascade_acc=0.6827 | val loss=0.5673(mal=0.3163,sub=0.3893), auc=0.9905, f1=0.9038, recall=0.9495, oracle_f1=0.1934, cascade_acc=0.5354
#   -> no improvement (5/7)
# [Hybrid][Fold 4][Epoch 16] sub_w=0.655 | train loss=0.5766(mal=0.0871,sub=0.7470), auc=0.9978, f1=0.9498, recall=0.9848, oracle_f1=0.3770, cascade_acc=0.7056 | val loss=0.5840(mal=0.3608,sub=0.3407), auc=0.9890, f1=0.8762, recall=0.9293, oracle_f1=0.2307, cascade_acc=0.5556
#   -> no improvement (6/7)
# [Hybrid][Fold 4][Epoch 17] sub_w=0.666 | train loss=0.5039(mal=0.0587,sub=0.6689), auc=0.9991, f1=0.9653, recall=0.9898, oracle_f1=0.3578, cascade_acc=0.7157 | val loss=0.6071(mal=0.4219,sub=0.2783), auc=0.9887, f1=0.8544, recall=0.8889, oracle_f1=0.2795, cascade_acc=0.4343
#   -> no improvement (7/7)
#   -> early stopping triggered at epoch 17
#
# -- Final Evaluation --
# [Malignancy]  AUC=0.9919, F1=0.8922, Recall=0.9192, Acc=0.9644
# [Subtype Oracle]  Acc=0.2222, MacroF1=0.1339
# [Cascade]  SubtypeAcc=0.1919, GateRecall=0.9192
# Binary CM:
# [[505  14]
#  [  8  91]]
# Subtype Oracle CM:
# [[ 0  0  0  7  1]
#  [ 0  0  0  6  0]
#  [ 0  0  2 11  4]
#  [ 0  0  1  5  0]
#  [ 0  2  3 42 15]]
#
# [Hybrid][Fold 4] Final Metrics
# Malignancy  AUC=0.9919, F1=0.8922, Recall=0.9192
# Subtype Oracle  Acc=0.2222, MacroF1=0.1339
# Cascade  Acc=0.1919, GateRecall=0.9192
#
# ================================================================================
# Running Hybrid | Fold 5
# ================================================================================
# [FOLD 5] Train benign(0): 2078, malignant(1): 394, pos_weight=5.2741, subtype_counts=[32.0, 22.0, 67.0, 24.0, 249.0], subtype_class_weights=[1.1378999948501587, 1.6550999879837036, 0.5435000061988831, 1.517199993133545, 0.1462000012397766]
# [Hybrid][Fold 5][Epoch 01] sub_w=0.500 | train loss=1.0871(mal=0.5645,sub=1.0453), auc=0.9308, f1=0.6647, recall=0.8553, oracle_f1=0.1542, cascade_acc=0.5431 | val loss=0.4899(mal=0.3413,sub=0.2971), auc=0.9781, f1=0.7431, recall=0.9495, oracle_f1=0.1540, cascade_acc=0.6162
#   -> best saved (val_auc=0.9781): us_cascade_models/Hybrid_fold5_best.pth
# [Hybrid][Fold 5][Epoch 02] sub_w=0.510 | train loss=0.8569(mal=0.3586,sub=0.9763), auc=0.9707, f1=0.7663, recall=0.9239, oracle_f1=0.1596, cascade_acc=0.5888 | val loss=0.4434(mal=0.2809,sub=0.3184), auc=0.9866, f1=0.8267, recall=0.9394, oracle_f1=0.1540, cascade_acc=0.6061
#   -> best saved (val_auc=0.9866): us_cascade_models/Hybrid_fold5_best.pth
# [Hybrid][Fold 5][Epoch 03] sub_w=0.521 | train loss=0.7813(mal=0.2743,sub=0.9736), auc=0.9807, f1=0.8458, recall=0.9467, oracle_f1=0.1671, cascade_acc=0.6091 | val loss=0.3997(mal=0.2360,sub=0.3145), auc=0.9867, f1=0.8624, recall=0.9495, oracle_f1=0.1540, cascade_acc=0.6061
#   -> no improvement (1/7)
# [Hybrid][Fold 5][Epoch 04] sub_w=0.531 | train loss=0.7060(mal=0.1945,sub=0.9631), auc=0.9909, f1=0.8706, recall=0.9645, oracle_f1=0.1749, cascade_acc=0.6168 | val loss=0.4480(mal=0.2754,sub=0.3249), auc=0.9855, f1=0.8261, recall=0.9596, oracle_f1=0.1525, cascade_acc=0.6061
#   -> no improvement (2/7)
# [Hybrid][Fold 5][Epoch 05] sub_w=0.541 | train loss=0.7423(mal=0.1981,sub=1.0052), auc=0.9882, f1=0.8782, recall=0.9695, oracle_f1=0.1696, cascade_acc=0.5888 | val loss=0.4634(mal=0.2928,sub=0.3151), auc=0.9830, f1=0.7886, recall=0.9798, oracle_f1=0.1540, cascade_acc=0.6263
#   -> no improvement (3/7)
# [Hybrid][Fold 5][Epoch 06] sub_w=0.552 | train loss=0.7068(mal=0.1775,sub=0.9593), auc=0.9906, f1=0.8866, recall=0.9721, oracle_f1=0.1716, cascade_acc=0.6168 | val loss=0.4984(mal=0.3230,sub=0.3180), auc=0.9904, f1=0.8624, recall=0.9495, oracle_f1=0.1772, cascade_acc=0.6162
#   -> best saved (val_auc=0.9904): us_cascade_models/Hybrid_fold5_best.pth
# [Hybrid][Fold 5][Epoch 07] sub_w=0.562 | train loss=0.7002(mal=0.1633,sub=0.9553), auc=0.9917, f1=0.9040, recall=0.9797, oracle_f1=0.1879, cascade_acc=0.6218 | val loss=0.5554(mal=0.3791,sub=0.3136), auc=0.9887, f1=0.8990, recall=0.8990, oracle_f1=0.2084, cascade_acc=0.5758
#   -> no improvement (1/7)
# [Hybrid][Fold 5][Epoch 08] sub_w=0.572 | train loss=0.6555(mal=0.1232,sub=0.9300), auc=0.9963, f1=0.9209, recall=0.9746, oracle_f1=0.2312, cascade_acc=0.6294 | val loss=0.4701(mal=0.2947,sub=0.3063), auc=0.9926, f1=0.9005, recall=0.9596, oracle_f1=0.1902, cascade_acc=0.6061
#   -> best saved (val_auc=0.9926): us_cascade_models/Hybrid_fold5_best.pth
# [Hybrid][Fold 5][Epoch 09] sub_w=0.583 | train loss=0.6790(mal=0.1446,sub=0.9169), auc=0.9943, f1=0.9141, recall=0.9721, oracle_f1=0.2098, cascade_acc=0.6091 | val loss=0.3209(mal=0.1495,sub=0.2941), auc=0.9945, f1=0.9038, recall=0.9495, oracle_f1=0.2228, cascade_acc=0.5152
#   -> best saved (val_auc=0.9945): us_cascade_models/Hybrid_fold5_best.pth
# [Hybrid][Fold 5][Epoch 10] sub_w=0.593 | train loss=0.7745(mal=0.1976,sub=0.9727), auc=0.9911, f1=0.8837, recall=0.9543, oracle_f1=0.2118, cascade_acc=0.5838 | val loss=0.5860(mal=0.3975,sub=0.3178), auc=0.9928, f1=0.8969, recall=0.8788, oracle_f1=0.2055, cascade_acc=0.4444
#   -> no improvement (1/7)
# [Hybrid][Fold 5][Epoch 11] sub_w=0.603 | train loss=0.6832(mal=0.1238,sub=0.9269), auc=0.9939, f1=0.9395, recall=0.9848, oracle_f1=0.2237, cascade_acc=0.6168 | val loss=0.7845(mal=0.5960,sub=0.3124), auc=0.9921, f1=0.9043, recall=0.8586, oracle_f1=0.2454, cascade_acc=0.5758
#   -> no improvement (2/7)
# [Hybrid][Fold 5][Epoch 12] sub_w=0.614 | train loss=0.6530(mal=0.1074,sub=0.8889), auc=0.9963, f1=0.9234, recall=0.9797, oracle_f1=0.2277, cascade_acc=0.6396 | val loss=0.5336(mal=0.2993,sub=0.3817), auc=0.9882, f1=0.8774, recall=0.9394, oracle_f1=0.2289, cascade_acc=0.5960
#   -> no improvement (3/7)
# [Hybrid][Fold 5][Epoch 13] sub_w=0.624 | train loss=0.6174(mal=0.0724,sub=0.8732), auc=0.9987, f1=0.9487, recall=0.9848, oracle_f1=0.2383, cascade_acc=0.6447 | val loss=0.8213(mal=0.6409,sub=0.2891), auc=0.9858, f1=0.8865, recall=0.8283, oracle_f1=0.2417, cascade_acc=0.5556
#   -> no improvement (4/7)
# [Hybrid][Fold 5][Epoch 14] sub_w=0.634 | train loss=0.6311(mal=0.1075,sub=0.8252), auc=0.9966, f1=0.9281, recall=0.9822, oracle_f1=0.2458, cascade_acc=0.6548 | val loss=0.5859(mal=0.3943,sub=0.3019), auc=0.9920, f1=0.9137, recall=0.9091, oracle_f1=0.2612, cascade_acc=0.6162
#   -> no improvement (5/7)
# [Hybrid][Fold 5][Epoch 15] sub_w=0.645 | train loss=0.6367(mal=0.0825,sub=0.8594), auc=0.9976, f1=0.9466, recall=0.9898, oracle_f1=0.2578, cascade_acc=0.6574 | val loss=0.6521(mal=0.4684,sub=0.2848), auc=0.9583, f1=0.8986, recall=0.9394, oracle_f1=0.1582, cascade_acc=0.3434
#   -> no improvement (6/7)
# [Hybrid][Fold 5][Epoch 16] sub_w=0.655 | train loss=0.6128(mal=0.0888,sub=0.7998), auc=0.9975, f1=0.9340, recall=0.9873, oracle_f1=0.2686, cascade_acc=0.6751 | val loss=0.5007(mal=0.3193,sub=0.2769), auc=0.9853, f1=0.9254, recall=0.9394, oracle_f1=0.2188, cascade_acc=0.5051
#   -> no improvement (7/7)
#   -> early stopping triggered at epoch 16
#
# -- Final Evaluation --
# [Malignancy]  AUC=0.9945, F1=0.9038, Recall=0.9495, Acc=0.9676
# [Subtype Oracle]  Acc=0.5253, MacroF1=0.2228
# [Cascade]  SubtypeAcc=0.5152, GateRecall=0.9495
# Binary CM:
# [[504  15]
#  [  5  94]]
# Subtype Oracle CM:
# [[ 0  0  4  0  4]
#  [ 0  0  1  0  4]
#  [ 0  0 15  0  2]
#  [ 0  0  6  0  1]
#  [ 0  0 25  0 37]]
#
# [Hybrid][Fold 5] Final Metrics
# Malignancy  AUC=0.9945, F1=0.9038, Recall=0.9495
# Subtype Oracle  Acc=0.5253, MacroF1=0.2228
# Cascade  Acc=0.5152, GateRecall=0.9495
#     model  fold   mal_acc   mal_auc    mal_f1  mal_recall  subtype_oracle_acc  \
# 0  Hybrid     1  0.936893  0.992612  0.829694    0.969388            0.510204
# 1  Hybrid     2  0.972492  0.995712  0.915423    0.938776            0.632653
# 2  Hybrid     3  0.977346  0.996312  0.929293    0.929293            0.656566
# 3  Hybrid     4  0.964401  0.991923  0.892157    0.919192            0.222222
# 4  Hybrid     5  0.967638  0.994521  0.903846    0.949495            0.525253
#
#    subtype_oracle_macro_f1  subtype_cascade_acc  subtype_gate_recall  \
# 0                 0.203843             0.489796             0.969388
# 1                 0.191202             0.612245             0.938776
# 2                 0.211039             0.606061             0.929293
# 3                 0.133927             0.191919             0.919192
# 4                 0.222781             0.515152             0.949495
#
#               binary_cm                                  subtype_oracle_cm
# 0  [[484, 36], [3, 95]]  [[0, 0, 5, 0, 3], [0, 0, 4, 0, 1], [0, 0, 10, ...
# 1  [[509, 11], [6, 92]]  [[0, 0, 0, 0, 8], [0, 0, 0, 0, 5], [0, 0, 2, 0...
# 2   [[512, 7], [7, 92]]  [[0, 0, 0, 0, 8], [0, 0, 0, 0, 6], [0, 0, 3, 0...
# 3  [[505, 14], [8, 91]]  [[0, 0, 0, 7, 1], [0, 0, 0, 6, 0], [0, 0, 2, 1...
# 4  [[504, 15], [5, 94]]  [[0, 0, 4, 0, 4], [0, 0, 1, 0, 4], [0, 0, 15, ...
#            mal_auc              mal_f1           mal_recall            \
#               mean       std      mean       std       mean       std
# model
# Hybrid    0.994216  0.001908  0.894083  0.038536   0.941229  0.019335
# ResNet50  0.994377  0.001496  0.893357  0.031296   0.957411  0.024121
# ViT-B16   0.677952  0.075206  0.314553  0.073887   0.630262  0.381877
#
#          subtype_oracle_acc           subtype_oracle_macro_f1            \
#                        mean       std                    mean       std
# model
# Hybrid             0.509380  0.172896                0.192558  0.034719
# ResNet50           0.608617  0.055220                0.205308  0.040497
# ViT-B16            0.630839  0.004444                0.154726  0.000668
#
#          subtype_cascade_acc           subtype_gate_recall
#                         mean       std                mean       std
# model
# Hybrid              0.483034  0.171505            0.941229  0.019335
# ResNet50            0.586271  0.042941            0.957411  0.024121
# ViT-B16             0.419563  0.219348            0.630262  0.381877
