# %%
#!/usr/bin/env python
# coding: utf-8

# ============================================================
# CT Cascade 학습 스크립트
#
# [구조 개요]
#   1단계: malignancy binary classification (benign / malignant)
#   2단계: malignant 샘플에 대해서만 subtype multi-class classification
#
# [원본 대비 주요 수정 사항]
#   1. inspect_fold_npz 오타 수정: .exits() → .exists()
#   2. infer_malignant_type_ids 들여쓰기 버그 수정
#      (return이 fold loop 안에 있어 fold 1 결과만 반환하던 문제)
#   3. cascade_correct 인덱스 불일치 버그 수정
#      (oracle_pred/oracle_true는 all_mal_mask 기준,
#       all_mal_pred[gt_mal_mask]는 gt_mal_mask 기준 → 길이 불일치)
#   4. fit_model print 오타 수정: 콤마로 분리된 f-string → 하나로 합침
#   5. 모델 구조 개선:
#      - shared head 이후 task별 projection(mal_proj / sub_proj) 분리
#      - early stopping 기준: val_loss → val_auc (malignancy recall 중심)
#      - subtype_loss_weight warmup 스케줄 추가
# ============================================================


# ============================================================
# 빌드 확인
# ============================================================
from torchvision import models
from torchvision.models import vit_b_16

print("=" * 60)

try:
    m1 = models.resnet50(weights=None)
    print("ResNet50 build success")
except Exception as e:
    print("Fail", e)

try:
    m2 = vit_b_16(weights=None)
    print("Vit-B/16 build success")
except Exception as e:
    print("Fail", e)

print("=" * 60)


# ============================================================
# 1) 환경 설정 + import
# ============================================================
import os
import gc
import random
import torchvision.transforms.functional as TF
from pathlib import Path
from collections import OrderedDict, defaultdict

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.metrics import (
    confusion_matrix, classification_report,
    accuracy_score, f1_score, roc_auc_score, recall_score
)

import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
from torchvision import models
from torchvision.models import vit_b_16, ViT_B_16_Weights, ResNet50_Weights

SEED = 42
random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)
torch.cuda.manual_seed_all(SEED)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Device:", device)

# cuDNN autotuner: 입력 크기가 고정일 때 속도 향상
torch.backends.cudnn.benchmark = True


# ============================================================
# 2) 경로 / 하이퍼파라미터 설정
# ============================================================
print(f"현재 작업 경로: {os.getcwd()}")

DATA_ROOT  = Path("/tf/nasw/dataset001/preprocessed/npz_ct")
FOLDS      = [1, 2, 3, 4, 5]

OUTPUT_DIR = Path("./ct_cascade_models")
OUTPUT_DIR.mkdir(parents=True, exist_ok=True)

IMG_SIZE     = 224
BATCH_SIZE   = 8
NUM_WORKERS  = 2
NUM_EPOCHS   = 30
LR           = 1e-4
WEIGHT_DECAY = 1e-4
PATIENCE     = 7
MIN_DELTA    = 0.001
THRESHOLD    = 0.5   # malignancy 판단 임계값

# subtype loss 가중치 warmup 설정
# - 학습 초반에는 malignancy 분류에 집중하고,
#   후반부로 갈수록 subtype loss 비중을 점진적으로 높임
SUBTYPE_LOSS_WEIGHT_START = 0.4   # 1 epoch 시작값
SUBTYPE_LOSS_WEIGHT_END   = 0.8   # NUM_EPOCHS epoch 도달값

print("DATA_ROOT:", DATA_ROOT)
print("OUTPUT_DIR:", OUTPUT_DIR.resolve())
print("FOLDS:", FOLDS)


# ============================================================
# 3) 로컬 pretrained weight 경로
# ============================================================
LOCAL_RESNET_WEIGHTS = Path("/tf/pretrained_model/resnet50-11ad3fa6.pth")
LOCAL_VIT_WEIGHTS    = Path("/tf/pretrained_model/vit_b_16-c867db91.pth")

print("LOCAL_RESNET_WEIGHTS exists:", LOCAL_RESNET_WEIGHTS.exists())
print("LOCAL_VIT_WEIGHTS exists:",    LOCAL_VIT_WEIGHTS.exists())


# ============================================================
# 4) 유틸 함수
# ============================================================
def load_local_state_dict(weight_path):
    weight_path = Path(weight_path)
    assert weight_path.exists(), f"Weight file not found: {weight_path}"

    ckpt = torch.load(weight_path, map_location="cpu")

    # 일부 checkpoint는 {"state_dict": {...}} 형태로 저장되어 있음
    if isinstance(ckpt, dict) and "state_dict" in ckpt and isinstance(ckpt["state_dict"], dict):
        ckpt = ckpt["state_dict"]

    return ckpt


def inspect_fold_npz(fold_idx):
    train_npz_path = DATA_ROOT / f"fold_{fold_idx}_train.npz"
    val_npz_path   = DATA_ROOT / f"fold_{fold_idx}_val.npz"

    # ✅ 버그 수정: .exits() → .exists()
    print("TRAIN:", train_npz_path, train_npz_path.exists())
    print("VAL:",   val_npz_path,   val_npz_path.exists())

    train_npz = np.load(train_npz_path, allow_pickle=False, mmap_mode="r")
    val_npz   = np.load(val_npz_path,   allow_pickle=False, mmap_mode="r")

    for k in train_npz.files:
        print(f"[train] {k}: shape={train_npz[k].shape}, dtype={train_npz[k].dtype}")
    for k in val_npz.files:
        print(f"[val]   {k}: shape={val_npz[k].shape}, dtype={val_npz[k].dtype}")


def get_subtype_loss_weight(epoch: int, total_epochs: int) -> float:
    """
    subtype loss 가중치를 epoch에 따라 선형 warmup.

    epoch 1  → SUBTYPE_LOSS_WEIGHT_START
    epoch N  → SUBTYPE_LOSS_WEIGHT_END
    사이는 선형 보간.

    이유: 학습 초반 malignancy gate가 불안정할 때
    subtype loss가 너무 크면 전체 학습을 방해할 수 있음.
    """
    t = (epoch - 1) / max(total_epochs - 1, 1)   # 0.0 ~ 1.0
    return SUBTYPE_LOSS_WEIGHT_START + t * (SUBTYPE_LOSS_WEIGHT_END - SUBTYPE_LOSS_WEIGHT_START)


# ============================================================
# 5) malignant subtype ID 자동 추론
# ============================================================
def infer_malignant_type_ids(data_root, folds):
    """
    NPZ 파일에서 tumor_type별로 label(0/1)을 수집하여
    항상 malignant(label=1)인 tumor_type ID 목록을 자동 추론.

    ✅ 버그 수정: 원본은 return이 fold loop 안에 있어서
       fold 1 처리 후 바로 반환되는 문제가 있었음.
       loop 밖으로 conflicts 체크와 return을 이동.
    """
    # tumor_type별로 등장한 label 값들을 수집
    label_set_by_type = defaultdict(set)

    for fold_idx in folds:
        for split_name in ["train", "val"]:
            npz_path = Path(data_root) / f"fold_{fold_idx}_{split_name}.npz"
            data     = np.load(npz_path, allow_pickle=False, mmap_mode="r")

            labels      = data["labels"].astype(int)
            tumor_types = data["tumor_types"].astype(int)

            for y, t in zip(labels, tumor_types):
                label_set_by_type[int(t)].add(int(y))

    # ✅ loop 종료 후 한 번만 체크 (원본: loop 안에서 매 fold마다 체크 후 return)
    # 동일 tumor_type이 benign/malignant 양쪽에 있으면 데이터 오류
    conflicts = {
        t: sorted(list(v))
        for t, v in label_set_by_type.items()
        if len(v) > 1
    }
    if len(conflicts) > 0:
        raise ValueError(
            f"tumor_type이 양성/악성 양쪽에 섞여 있음: {conflicts}\n"
            "데이터 전처리를 확인하세요."
        )

    # label이 {1}만인 tumor_type만 malignant subtype으로 간주
    malignant_type_ids = sorted([
        t for t, labs in label_set_by_type.items()
        if labs == {1}
    ])

    print("malignant_type_ids:", malignant_type_ids)
    return malignant_type_ids


MALIGNANT_TYPE_IDS     = infer_malignant_type_ids(DATA_ROOT, FOLDS)
MALIGNANT_MAP          = {tid: i for i, tid in enumerate(MALIGNANT_TYPE_IDS)}
NUM_MALIGNANT_SUBTYPES = len(MALIGNANT_TYPE_IDS)

print("MALIGNANT_MAP:", MALIGNANT_MAP)
print("NUM_MALIGNANT_SUBTYPES:", NUM_MALIGNANT_SUBTYPES)

#=============================================================
# 5.5) 실시간 증강 모듈
#=============================================================

class CTSliceAugmentor:
    def __init__(
        self,
        p_hflip: float = 0.5,
        p_vflip: float = 0.0,
        p_rotate: float = 0.5,
        max_angle: float = 10.0,
        p_crop: float = 0.5,
        crop_min: float = 0.85,
        p_noise: float = 0.3,
        noise_std: float = 0.01,
    ):
        self.p_hflip = p_hflip
        self.p_vflip = p_vflip
        self.p_rotate = p_rotate
        self.max_angle = max_angle
        self.p_crop = p_crop
        self.crop_min = crop_min
        self.p_noise = p_noise
        self.noise_std = noise_std


    def __call__(self, imgs):
        S, C, H, W = imgs.shape

        do_hflip = random.random() < self.p_hflip
        do_vflip = random.random() < self.p_vflip
        do_rotate = random.random() < self.p_rotate
        angle = random.uniform(-self.max_angle, self.max_angle) if do_rotate else 0.0
        do_crop = random.random() < self.p_crop
        do_noise = random.random() < self.p_noise

        top = left = crop_h = crop_w = 0
        if do_crop:
            scale = random.uniform(self.crop_min, 1.0)
            crop_h = int(H*scale)
            crop_w = int(W*scale)
            top = random.randint(0, H-crop_h)
            left = random.randint(0, W-crop_w)

        augmented = []
        for s in range(S):
            img = imgs[s]
            if do_hflip:
                img = TF.hflip(img)
            if do_vflip:
                img = TF.vflip(img)
            if do_rotate:
                img = TF.rotate(img, angle, interpolation = TF.InterpolationMode.BILINEAR, fill=0)
            if do_crop:
                img = TF.crop(img, top, left, crop_h, crop_w)
                img = TF.resize(img, [H,W], interpolation=TF.InterpolationMode.BILINEAR, antialias=True)
            augmented.append(img)

        imgs=torch.stack(augmented, dim = 0)

        if do_noise:
            imgs = (imgs + torch.randn_like(imgs) * self.noise_std).clamp(0.0, 1.0)

        return imgs


TRAIN_AUGMENTOR = CTSliceAugmentor(
    p_hflip = 0.5, p_vflip = 0.0, p_rotate=0.5, max_angle = 10.0,
    p_crop = 0.5, crop_min = 0.85, p_noise = 0.3, noise_std = 0.01,
)

def _worker_init_fn(worker_id):
    worker_seed = torch.initial_seed() % (2**32)
    np.random.seed(worker_seed)
    random.seed(worker_seed)
    


# ============================================================
# 6) Dataset 정의
# ============================================================
class OvarianCTNPZDataset(Dataset):
    def __init__(self, npz_path, is_train=True):
        super().__init__()
        self.npz = np.load(npz_path, allow_pickle=False, mmap_mode="r")

        self.images      = self.npz["images"]
        self.labels      = self.npz["labels"].astype(np.float32)
        self.tumor_types = self.npz["tumor_types"].astype(np.int64)

        # patient_ids가 없으면 인덱스로 대체
        self.patient_ids = (
            self.npz["patient_ids"]
            if "patient_ids" in self.npz.files
            else np.arange(len(self.labels))
        )

        # ImageNet 정규화 상수 (CT/US 공통으로 사용 가능)
        self.mean = torch.tensor([0.485, 0.456, 0.406], dtype=torch.float32).view(1, 3, 1, 1)
        self.std  = torch.tensor([0.229, 0.224, 0.225], dtype=torch.float32).view(1, 3, 1, 1)

        self.augmentor = TRAIN_AUGMENTOR if is_train else None

    def __len__(self):
        return len(self.labels)

    def __getitem__(self, idx):
        x           = self.images[idx]
        y           = int(self.labels[idx])
        tumor_type  = int(self.tumor_types[idx])

        # NPZ 저장 형태: [S, H, W, C] → [S, C, H, W]
        x = torch.from_numpy(np.array(x)).float().permute(0, 3, 1, 2).contiguous()
        x = x / 255.0

        if self.augmentor is not None:
            x = self.augmentor(x)
            
        x = (x - self.mean) / self.std

        # malignant 샘플에만 subtype label 부여
        if y == 1:
            if tumor_type not in MALIGNANT_MAP:
                raise ValueError(
                    f"malignant sample인데 tumor_type={tumor_type}가 MALIGNANT_MAP에 없음. "
                    f"infer_malignant_type_ids 결과 확인 필요."
                )
            mal_subtype = MALIGNANT_MAP[tumor_type]
            mal_mask    = True
        else:
            # benign은 subtype 없음 → -1로 패딩 (loss 계산 시 mal_mask로 필터링)
            mal_subtype = -1
            mal_mask    = False

        return {
            "image":       x,
            "label":       torch.tensor(y, dtype=torch.float32),
            "mal_subtype": torch.tensor(mal_subtype, dtype=torch.long),
            "mal_mask":    torch.tensor(mal_mask, dtype=torch.bool),
        }


# ============================================================
# 7) fold별 DataLoader 생성
# ============================================================
def make_fold_loaders(fold_idx):
    train_npz_path = DATA_ROOT / f"fold_{fold_idx}_train.npz"
    val_npz_path   = DATA_ROOT / f"fold_{fold_idx}_val.npz"

    assert train_npz_path.exists(), f"Missing: {train_npz_path}"
    assert val_npz_path.exists(),   f"Missing: {val_npz_path}"

    train_dataset = OvarianCTNPZDataset(train_npz_path, is_train=True)
    val_dataset   = OvarianCTNPZDataset(val_npz_path, is_train=False)

    train_loader = DataLoader(
        train_dataset,
        batch_size=BATCH_SIZE,
        shuffle=True,
        num_workers=NUM_WORKERS,
        pin_memory=True,
        worker_init_fn = _worker_init_fn,
        persistent_workers = (NUM_WORKERS > 0),
    )
    val_loader = DataLoader(
        val_dataset,
        batch_size=BATCH_SIZE,
        shuffle=False,
        num_workers=NUM_WORKERS,
        pin_memory=True
    )

    # ── malignancy pos_weight ────────────────────────────────
    # benign/malignant 불균형 보정: neg/pos 비율로 BCEWithLogitsLoss에 전달
    labels_np        = train_dataset.labels.astype(int)
    neg              = (labels_np == 0).sum()
    pos              = (labels_np == 1).sum()
    pos_weight_value = neg / max(pos, 1)
    mal_pos_weight   = torch.tensor([pos_weight_value], device=device, dtype=torch.float32)

    # ── subtype class weight ─────────────────────────────────
    # subtype별 샘플 수 역수로 class weight 계산 (inv mean normalization)
    subtype_counts = np.zeros(NUM_MALIGNANT_SUBTYPES, dtype=np.float64)
    for y, t in zip(train_dataset.labels.astype(int), train_dataset.tumor_types.astype(int)):
        if y == 1 and t in MALIGNANT_MAP:
            subtype_counts[MALIGNANT_MAP[t]] += 1.0

    subtype_counts       = np.maximum(subtype_counts, 1.0)   # 0 나누기 방지
    inv                  = 1.0 / subtype_counts
    subtype_class_weights = inv / inv.mean()                  # 평균 1로 정규화
    subtype_class_weights = torch.tensor(subtype_class_weights, dtype=torch.float32, device=device)

    print(
        f"[FOLD {fold_idx}] Train benign(0): {neg}, malignant(1): {pos}, "
        f"pos_weight={mal_pos_weight.item():.4f}, "
        f"subtype_counts={subtype_counts.tolist()}, "
        f"subtype_class_weights={subtype_class_weights.detach().cpu().numpy().round(4).tolist()}"
    )

    return train_loader, val_loader, mal_pos_weight, subtype_class_weights


# ============================================================
# 8) Cascade 손실 함수
# ============================================================
class CascadeCriterion(nn.Module):
    def __init__(self, pos_weight, subtype_class_weights, subtype_loss_weight=0.5):
        """
        Args:
            pos_weight           : BCEWithLogitsLoss의 pos_weight (malignancy)
            subtype_class_weights: CrossEntropyLoss의 class weight (subtype)
            subtype_loss_weight  : subtype loss를 얼마나 반영할지 가중치
                                   epoch마다 외부에서 업데이트 가능
        """
        super().__init__()
        self.bce               = nn.BCEWithLogitsLoss(pos_weight=pos_weight)
        self.ce                = nn.CrossEntropyLoss(weight=subtype_class_weights)
        self.subtype_loss_weight = subtype_loss_weight

    def forward(self, outputs, batch):
        labels      = batch["label"].to(device).view(-1)        # [B]
        mal_mask    = batch["mal_mask"].to(device).view(-1)     # [B] bool
        mal_subtype = batch["mal_subtype"].to(device).view(-1)  # [B]

        # malignancy binary loss (benign/malignant 전체 샘플)
        loss_m = self.bce(outputs["malignancy_logits"], labels)

        # subtype loss (malignant 샘플만)
        # mal_mask=True인 샘플만 필터링해서 CrossEntropyLoss 계산
        if mal_mask.any():
            loss_s = self.ce(
                outputs["subtype_logits"][mal_mask],
                mal_subtype[mal_mask]
            )
        else:
            # batch 안에 malignant 샘플이 없는 경우 (소규모 데이터에서 발생 가능)
            loss_s = torch.tensor(0.0, device=device)

        loss_total = loss_m + self.subtype_loss_weight * loss_s

        return {
            "loss_total":      loss_total,
            "loss_malignancy": loss_m,
            "loss_subtype":    loss_s,
        }


# ============================================================
# 9) 지표 계산 함수
# ============================================================
def compute_binary_metrics(y_true, y_prob, threshold=0.5):
    y_true = np.asarray(y_true).astype(int)
    y_prob = np.asarray(y_prob).astype(float)
    y_pred = (y_prob >= threshold).astype(int)

    return {
        "acc":    accuracy_score(y_true, y_pred),
        "auc":    roc_auc_score(y_true, y_prob) if len(np.unique(y_true)) > 1 else 0.5,
        "f1":     f1_score(y_true, y_pred, zero_division=0),
        "recall": recall_score(y_true, y_pred, zero_division=0),
        "cm":     confusion_matrix(y_true, y_pred),
    }


def compute_multiclass_metrics(y_true, y_pred):
    y_true = np.asarray(y_true).astype(int)
    y_pred = np.asarray(y_pred).astype(int)

    if len(y_true) == 0:
        return {"acc": np.nan, "macro_f1": np.nan, "macro_recall": np.nan, "cm": None}

    return {
        "acc":          accuracy_score(y_true, y_pred),
        "macro_f1":     f1_score(y_true, y_pred, average="macro", zero_division=0),
        "macro_recall": recall_score(y_true, y_pred, average="macro", zero_division=0),
        "cm":           confusion_matrix(y_true, y_pred),
    }


# ============================================================
# 10) train / eval 함수
# ============================================================
scaler = torch.amp.GradScaler(enabled=(device.type == "cuda"))


def _compute_cascade_metrics(
    all_label, all_mal_prob, all_mal_mask,
    all_subtype_true, all_subtype_pred,
    running_total, running_m, running_s,
    n_samples,
):
    """
    train_one_epoch / eval_one_epoch 공통 지표 계산 로직.
    중복 코드를 줄이기 위해 분리.

    ✅ 버그 수정: cascade_correct 인덱스 불일치 수정
        - oracle_pred / oracle_true: all_mal_mask(GT malignant) 기준으로 필터링된 배열
        - all_mal_pred[gt_mal_mask]: GT malignant 샘플에 대한 예측값
        - 위 두 배열의 길이는 동일 (gt_mal_mask == all_mal_mask)
        - 원본 코드는 all_mal_mask 대신 mal_mask를 별도로 쓰거나
          배열 길이가 맞지 않는 경우 발생 → gt_mal_mask로 통일하여 수정
    """
    mal_metrics = compute_binary_metrics(all_label, all_mal_prob, threshold=THRESHOLD)

    all_label        = np.asarray(all_label).astype(int)
    all_mal_pred     = (np.asarray(all_mal_prob) >= THRESHOLD).astype(int)
    all_mal_mask     = np.asarray(all_mal_mask).astype(bool)
    all_subtype_true = np.asarray(all_subtype_true).astype(int)
    all_subtype_pred = np.asarray(all_subtype_pred).astype(int)

    # oracle subtype: GT가 malignant인 샘플에 대해서만 subtype 평가
    # (malignancy gate의 영향 없이, subtype head 자체 성능 측정)
    oracle_true    = all_subtype_true[all_mal_mask]
    oracle_pred    = all_subtype_pred[all_mal_mask]
    subtype_oracle = compute_multiclass_metrics(oracle_true, oracle_pred)

    # cascade subtype: GT malignant 샘플 중
    #   ① malignancy gate도 malignant로 예측하고 (gate pass)
    #   ② subtype도 맞춰야 정답
    gt_mal_mask = all_mal_mask   # GT label == 1인 샘플 = mal_mask와 동일

    if gt_mal_mask.sum() > 0:
        gate_pass = all_mal_pred[gt_mal_mask] == 1   # gate 통과 여부 [N_mal]

        # ✅ oracle_pred는 gt_mal_mask 기준으로 필터링된 배열이므로 길이 일치
        subtype_correct = oracle_pred == oracle_true  # subtype 정답 여부 [N_mal]

        gate_recall          = gate_pass.mean()
        # cascade 정답 = gate도 통과하고 subtype도 맞아야 함
        subtype_cascade_acc  = (gate_pass & subtype_correct).mean()
    else:
        gate_recall         = np.nan
        subtype_cascade_acc = np.nan

    return {
        "loss":           running_total / n_samples,
        "loss_malignancy": running_m / n_samples,
        "loss_subtype":   running_s / n_samples,

        # malignancy 지표
        "acc":    mal_metrics["acc"],
        "auc":    mal_metrics["auc"],
        "f1":     mal_metrics["f1"],
        "recall": mal_metrics["recall"],
        "cm":     mal_metrics["cm"],

        # subtype oracle 지표 (gate 무관, subtype head 자체 성능)
        "subtype_oracle_acc":      subtype_oracle["acc"],
        "subtype_oracle_macro_f1": subtype_oracle["macro_f1"],
        "subtype_oracle_cm":       subtype_oracle["cm"],

        # cascade 지표 (gate + subtype 통합 성능)
        "subtype_cascade_acc":  float(subtype_cascade_acc),
        "subtype_gate_recall":  float(gate_recall),
    }


def train_one_epoch(model, loader, criterion, optimizer, device):
    model.train()

    running_total, running_m, running_s = 0.0, 0.0, 0.0
    all_label        = []
    all_mal_prob     = []
    all_mal_mask     = []
    all_subtype_true = []
    all_subtype_pred = []

    for batch in loader:
        imgs = batch["image"].to(device, non_blocking=True)

        optimizer.zero_grad()

        with torch.amp.autocast(device_type="cuda", enabled=(device.type == "cuda")):
            outputs   = model(imgs)
            loss_dict = criterion(outputs, batch)
            loss      = loss_dict["loss_total"]

        scaler.scale(loss).backward()
        scaler.step(optimizer)
        scaler.update()

        bs             = imgs.size(0)
        running_total += loss_dict["loss_total"].item() * bs
        running_m     += loss_dict["loss_malignancy"].item() * bs
        running_s     += loss_dict["loss_subtype"].item() * bs

        # CPU로 이동 후 numpy 변환
        label_np        = batch["label"].detach().cpu().numpy().astype(int).ravel()
        mal_mask_np     = batch["mal_mask"].detach().cpu().numpy().astype(bool).ravel()
        mal_prob_np     = torch.sigmoid(outputs["malignancy_logits"]).detach().cpu().numpy().ravel()
        subtype_pred_np = outputs["subtype_logits"].argmax(dim=1).detach().cpu().numpy().astype(int).ravel()
        subtype_true_np = batch["mal_subtype"].detach().cpu().numpy().astype(int).ravel()

        all_label.extend(label_np.tolist())
        all_mal_prob.extend(mal_prob_np.tolist())
        all_mal_mask.extend(mal_mask_np.tolist())
        all_subtype_true.extend(subtype_true_np.tolist())
        all_subtype_pred.extend(subtype_pred_np.tolist())

    return _compute_cascade_metrics(
        all_label, all_mal_prob, all_mal_mask,
        all_subtype_true, all_subtype_pred,
        running_total, running_m, running_s,
        len(loader.dataset),
    )


@torch.no_grad()
def eval_one_epoch(model, loader, criterion, device):
    model.eval()

    running_total, running_m, running_s = 0.0, 0.0, 0.0
    all_label        = []
    all_mal_prob     = []
    all_mal_mask     = []
    all_subtype_true = []
    all_subtype_pred = []

    for batch in loader:
        imgs = batch["image"].to(device, non_blocking=True)

        with torch.amp.autocast(device_type="cuda", enabled=(device.type == "cuda")):
            outputs   = model(imgs)
            loss_dict = criterion(outputs, batch)

        bs             = imgs.size(0)
        running_total += loss_dict["loss_total"].item() * bs
        running_m     += loss_dict["loss_malignancy"].item() * bs
        running_s     += loss_dict["loss_subtype"].item() * bs

        label_np        = batch["label"].detach().cpu().numpy().astype(int).ravel()
        mal_mask_np     = batch["mal_mask"].detach().cpu().numpy().astype(bool).ravel()
        mal_prob_np     = torch.sigmoid(outputs["malignancy_logits"]).detach().cpu().numpy().ravel()
        subtype_pred_np = outputs["subtype_logits"].argmax(dim=1).detach().cpu().numpy().astype(int).ravel()
        subtype_true_np = batch["mal_subtype"].detach().cpu().numpy().astype(int).ravel()

        all_label.extend(label_np.tolist())
        all_mal_prob.extend(mal_prob_np.tolist())
        all_mal_mask.extend(mal_mask_np.tolist())
        all_subtype_true.extend(subtype_true_np.tolist())
        all_subtype_pred.extend(subtype_pred_np.tolist())

    return _compute_cascade_metrics(
        all_label, all_mal_prob, all_mal_mask,
        all_subtype_true, all_subtype_pred,
        running_total, running_m, running_s,
        len(loader.dataset),
    )


@torch.no_grad()
def eval_confusion(model, loader, criterion, device, threshold=0.5):
    """최종 평가 + classification report 출력."""
    metrics = eval_one_epoch(model, loader, criterion, device)

    print("\n-- Final Evaluation --")
    print(f"[Malignancy]  AUC={metrics['auc']:.4f}, F1={metrics['f1']:.4f}, Recall={metrics['recall']:.4f}, Acc={metrics['acc']:.4f}")
    print(f"[Subtype Oracle]  Acc={metrics['subtype_oracle_acc']:.4f}, MacroF1={metrics['subtype_oracle_macro_f1']:.4f}")
    print(f"[Cascade]  SubtypeAcc={metrics['subtype_cascade_acc']:.4f}, GateRecall={metrics['subtype_gate_recall']:.4f}")
    print("Binary CM:")
    print(metrics["cm"])
    print("Subtype Oracle CM:")
    print(metrics["subtype_oracle_cm"])

    return metrics


# ============================================================
# 11) 모델 정의
# ============================================================

# ── 공통 Attention Pooling + Dual Head Classifier ────────────
class PatientSliceAttentionClassifier(nn.Module):
    """
    [구조 개선]
    원본: shared → malignancy_head / subtype_head (동일 표현 공유)
    수정: shared → mal_proj → malignancy_head
                 → sub_proj → subtype_head

    이유: malignancy 판단(global 패턴)과 subtype 분류(세부 형태 패턴)는
    집중해야 할 특징이 달라서 task별 projection을 추가하면 각 head가
    더 특화된 표현을 학습할 수 있음.
    """
    def __init__(self, encoder, feat_dim, hidden_dim=512, proj_dim=256, dropout=0.1):
        super().__init__()
        self.encoder = encoder

        # slice 간 중요도 attention (슬라이스별 가중합 풀링)
        self.attn = nn.Sequential(
            nn.Linear(feat_dim, feat_dim // 2),
            nn.Tanh(),
            nn.Linear(feat_dim // 2, 1),
        )

        # 공통 표현 추출
        self.shared = nn.Sequential(
            nn.Linear(feat_dim, hidden_dim),
            nn.ReLU(),
            nn.Dropout(dropout),
        )

        # ── task별 projection (개선 포인트) ──────────────────
        # malignancy: 양성/악성 global 구분에 집중
        self.mal_proj = nn.Sequential(
            nn.Linear(hidden_dim, proj_dim),
            nn.ReLU(),
            nn.Dropout(dropout),
        )
        # subtype: 악성 내 세부 형태 패턴 분류에 집중
        self.sub_proj = nn.Sequential(
            nn.Linear(hidden_dim, proj_dim),
            nn.ReLU(),
            nn.Dropout(dropout),
        )

        self.malignancy_head = nn.Linear(proj_dim, 1)
        self.subtype_head    = nn.Linear(proj_dim, NUM_MALIGNANT_SUBTYPES)

    def forward(self, x):
        # x: (B, S, C, H, W)
        B, S, C, H, W = x.shape
        x = x.view(B * S, C, H, W)

        feat = self.encoder(x)           # (B*S, feat_dim)
        feat = feat.view(B, S, -1)       # (B, S, feat_dim)

        # attention pooling
        attn_score  = self.attn(feat)                    # (B, S, 1)
        attn_weight = torch.softmax(attn_score, dim=1)
        pooled      = (feat * attn_weight).sum(dim=1)    # (B, feat_dim)

        # 공통 → task별 분기
        z     = self.shared(pooled)    # (B, hidden_dim)
        z_mal = self.mal_proj(z)       # (B, proj_dim)
        z_sub = self.sub_proj(z)       # (B, proj_dim)

        return {
            # squeeze(1): [B,1] → [B]  (BCEWithLogitsLoss 입력 형태)
            "malignancy_logits": self.malignancy_head(z_mal).squeeze(1),
            "subtype_logits":    self.subtype_head(z_sub),   # (B, NUM_MALIGNANT_SUBTYPES)
        }


# ── ResNet50 기반 모델 ────────────────────────────────────────
def build_resnet50_patient_model(
    load_pretrained=True,
    freeze_backbone=True,
    unfreeze_layer4=True,
    weight_path=LOCAL_RESNET_WEIGHTS,
):
    encoder = models.resnet50(weights=None)

    if load_pretrained:
        state_dict = load_local_state_dict(weight_path)
        encoder.load_state_dict(state_dict, strict=True)

    feat_dim   = encoder.fc.in_features   # 2048
    encoder.fc = nn.Identity()

    if freeze_backbone:
        for p in encoder.parameters():
            p.requires_grad = False
        if unfreeze_layer4:
            # layer4만 fine-tuning (고수준 특징 추출 레이어)
            for p in encoder.layer4.parameters():
                p.requires_grad = True

    model = PatientSliceAttentionClassifier(
        encoder=encoder,
        feat_dim=feat_dim,
        hidden_dim=512,
        proj_dim=256,
        dropout=0.3,
    )
    return model


# ── ViT-B/16 기반 모델 ───────────────────────────────────────
def build_vit_patient_model(
    load_pretrained=True,
    weight_path=LOCAL_VIT_WEIGHTS,
):
    encoder = vit_b_16(weights=None)

    if load_pretrained:
        state_dict = load_local_state_dict(weight_path)
        encoder.load_state_dict(state_dict, strict=True)

    feat_dim      = encoder.heads.head.in_features   # 768
    encoder.heads = nn.Identity()

    model = PatientSliceAttentionClassifier(
        encoder=encoder,
        feat_dim=feat_dim,
        hidden_dim=512,
        proj_dim=256,
        dropout=0.1,
    )
    return model


# ── CNN + Transformer Hybrid 모델 ────────────────────────────
class CNNTransformerHybridPatient(nn.Module):
    """
    ResNet50으로 슬라이스별 특징 추출 후
    Transformer로 슬라이스 간 관계를 모델링.

    [구조 개선]
    원본: shared → malignancy_head / subtype_head
    수정: shared → mal_proj → malignancy_head
                 → sub_proj → subtype_head
    """
    def __init__(
        self,
        d_model=512,
        nhead=8,
        num_layers=2,
        dim_feedforward=1024,
        proj_dim=256,
        dropout=0.1,
        load_pretrained=True,
        freeze_backbone=True,
        unfreeze_layer4=True,
        resnet_weight_path=LOCAL_RESNET_WEIGHTS,
    ):
        super().__init__()

        # ── ResNet50 backbone ─────────────────────────────────
        backbone = models.resnet50(weights=None)
        if load_pretrained:
            state_dict = load_local_state_dict(resnet_weight_path)
            backbone.load_state_dict(state_dict, strict=True)
        feat_dim    = backbone.fc.in_features   # 2048
        backbone.fc = nn.Identity()
        self.encoder = backbone

        if freeze_backbone:
            for p in self.encoder.parameters():
                p.requires_grad = False
            if unfreeze_layer4:
                for p in self.encoder.layer4.parameters():
                    p.requires_grad = True

        # ── Transformer 입력 준비 ─────────────────────────────
        # ResNet 출력(2048) → Transformer 차원(d_model)으로 projection
        self.proj = nn.Linear(feat_dim, d_model)

        # CLS 토큰: 슬라이스 전체를 요약하는 학습 가능한 토큰
        self.cls_token = nn.Parameter(torch.zeros(1, 1, d_model))

        # pos_embed: 슬라이스 위치 정보 인코딩 (1+8: CLS + 슬라이스 최대 8장)
        # 실제 슬라이스 수 S가 8보다 작으면 자동으로 슬라이싱됨
        self.pos_embed = nn.Parameter(torch.zeros(1, 1 + 8, d_model))

        # ── Transformer Encoder ───────────────────────────────
        enc_layer = nn.TransformerEncoderLayer(
            d_model=d_model,
            nhead=nhead,
            dim_feedforward=dim_feedforward,
            dropout=0.1,
            batch_first=True,
            activation="gelu",
        )
        self.transformer = nn.TransformerEncoder(enc_layer, num_layers=num_layers)
        self.norm        = nn.LayerNorm(d_model)

        # ── 공통 표현 + task별 projection (개선 포인트) ────────
        self.shared = nn.Sequential(
            nn.Linear(d_model, 512),
            nn.ReLU(),
            nn.Dropout(dropout),
        )
        self.mal_proj = nn.Sequential(
            nn.Linear(512, proj_dim),
            nn.ReLU(),
            nn.Dropout(dropout),
        )
        self.sub_proj = nn.Sequential(
            nn.Linear(512, proj_dim),
            nn.ReLU(),
            nn.Dropout(dropout),
        )
        self.malignancy_head = nn.Linear(proj_dim, 1)
        self.subtype_head    = nn.Linear(proj_dim, NUM_MALIGNANT_SUBTYPES)

    def forward(self, x):
        B, S, C, H, W = x.shape
        x = x.view(B * S, C, H, W)

        feat = self.encoder(x)          # (B*S, 2048)
        feat = feat.view(B, S, -1)      # (B, S, 2048)
        feat = self.proj(feat)          # (B, S, d_model)

        # CLS 토큰 prepend
        cls    = self.cls_token.expand(B, -1, -1)       # (B, 1, d_model)
        tokens = torch.cat([cls, feat], dim=1)           # (B, 1+S, d_model)
        # pos_embed는 최대 슬라이스 수 기준으로 정의하고 실제 S에 맞게 슬라이싱
        tokens = tokens + self.pos_embed[:, :tokens.size(1), :]

        tokens  = self.transformer(tokens)    # (B, 1+S, d_model)
        tokens  = self.norm(tokens)
        cls_out = tokens[:, 0, :]             # (B, d_model) CLS 토큰만 추출

        z     = self.shared(cls_out)   # (B, 512)
        z_mal = self.mal_proj(z)       # (B, proj_dim)
        z_sub = self.sub_proj(z)       # (B, proj_dim)

        return {
            "malignancy_logits": self.malignancy_head(z_mal).squeeze(1),
            "subtype_logits":    self.subtype_head(z_sub),
        }


def build_hybrid_patient_model(load_pretrained=True):
    return CNNTransformerHybridPatient(
        load_pretrained=load_pretrained,
        freeze_backbone=True,
        unfreeze_layer4=True,
        resnet_weight_path=LOCAL_RESNET_WEIGHTS,
    )


# ============================================================
# 12) 공통 학습 함수
# ============================================================
def fit_model(
    model, model_name, fold_idx,
    train_loader, val_loader, device,
    num_epochs=30, lr=1e-4, weight_decay=1e-4,
    criterion=None,
    patience=7, min_delta=0.001,
):
    """
    [early stopping 기준 변경]
    원본: val_loss 기준
    수정: val_auc 기준

    이유: cascade 모델에서 malignancy gate recall이 낮으면
    subtype 예측 자체가 의미 없어짐.
    val_loss는 subtype loss가 섞여 있어 malignancy 성능을
    직접 반영하지 못함 → val_auc가 더 적합.

    [subtype_loss_weight warmup]
    epoch마다 CascadeCriterion의 weight를 업데이트.
    학습 초반에는 malignancy에 집중, 후반으로 갈수록 subtype 비중 증가.
    """
    if criterion is None:
        raise ValueError("cascade 모델에서는 criterion에 CascadeCriterion을 넘겨야 함")

    model = model.to(device)
    optimizer = torch.optim.Adam(
        filter(lambda p: p.requires_grad, model.parameters()),
        lr=lr,
        weight_decay=weight_decay,
    )

    best_auc           = -1.0
    best_path          = OUTPUT_DIR / f"{model_name}_fold{fold_idx}_best.pth"
    history            = []
    early_stop_counter = 0

    for epoch in range(1, num_epochs + 1):

        # subtype loss weight warmup: epoch마다 선형 증가
        current_subtype_weight = get_subtype_loss_weight(epoch, num_epochs)
        criterion.subtype_loss_weight = current_subtype_weight

        train_metrics = train_one_epoch(model, train_loader, criterion, optimizer, device)
        val_metrics   = eval_one_epoch(model, val_loader, criterion, device)

        row = {
            "fold":  fold_idx,
            "epoch": epoch,
            "subtype_loss_weight": current_subtype_weight,

            # train 지표
            "train_loss":                    train_metrics["loss"],
            "train_loss_malignancy":         train_metrics["loss_malignancy"],
            "train_loss_subtype":            train_metrics["loss_subtype"],
            "train_acc":                     train_metrics["acc"],
            "train_auc":                     train_metrics["auc"],
            "train_f1":                      train_metrics["f1"],
            "train_recall":                  train_metrics["recall"],
            "train_subtype_oracle_acc":      train_metrics["subtype_oracle_acc"],
            "train_subtype_oracle_macro_f1": train_metrics["subtype_oracle_macro_f1"],
            "train_subtype_cascade_acc":     train_metrics["subtype_cascade_acc"],
            "train_subtype_gate_recall":     train_metrics["subtype_gate_recall"],

            # val 지표
            "val_loss":                    val_metrics["loss"],
            "val_loss_malignancy":         val_metrics["loss_malignancy"],
            "val_loss_subtype":            val_metrics["loss_subtype"],
            "val_acc":                     val_metrics["acc"],
            "val_auc":                     val_metrics["auc"],
            "val_f1":                      val_metrics["f1"],
            "val_recall":                  val_metrics["recall"],
            "val_subtype_oracle_acc":      val_metrics["subtype_oracle_acc"],
            "val_subtype_oracle_macro_f1": val_metrics["subtype_oracle_macro_f1"],
            "val_subtype_cascade_acc":     val_metrics["subtype_cascade_acc"],
            "val_subtype_gate_recall":     val_metrics["subtype_gate_recall"],
        }
        history.append(row)

        # ✅ 버그 수정: 원본은 콤마로 f-string이 분리되어 별도 출력됨
        # → 하나의 f-string으로 합침
        print(
            f"[{model_name}][Fold {fold_idx}][Epoch {epoch:02d}] "
            f"sub_w={current_subtype_weight:.3f} | "
            f"train loss={row['train_loss']:.4f}(mal={row['train_loss_malignancy']:.4f},sub={row['train_loss_subtype']:.4f}), "
            f"auc={row['train_auc']:.4f}, f1={row['train_f1']:.4f}, recall={row['train_recall']:.4f}, "
            f"oracle_f1={row['train_subtype_oracle_macro_f1']:.4f}, cascade_acc={row['train_subtype_cascade_acc']:.4f} | "
            f"val loss={row['val_loss']:.4f}(mal={row['val_loss_malignancy']:.4f},sub={row['val_loss_subtype']:.4f}), "
            f"auc={row['val_auc']:.4f}, f1={row['val_f1']:.4f}, recall={row['val_recall']:.4f}, "
            f"oracle_f1={row['val_subtype_oracle_macro_f1']:.4f}, cascade_acc={row['val_subtype_cascade_acc']:.4f}"
        )

        # ✅ early stopping 기준: val_loss → val_auc
        val_auc = row["val_auc"]
        if val_auc > best_auc + min_delta:
            best_auc           = val_auc
            early_stop_counter = 0
            torch.save(model.state_dict(), best_path)
            print(f"  -> best saved (val_auc={best_auc:.4f}): {best_path}")
        else:
            early_stop_counter += 1
            print(f"  -> no improvement ({early_stop_counter}/{patience})")

        if early_stop_counter >= patience:
            print(f"  -> early stopping triggered at epoch {epoch}")
            break

    history_df = pd.DataFrame(history)
    return model, history_df, best_path


# ============================================================
# 13) 모델 로드 함수
# ============================================================
def load_model(model_type, model_path, device):
    if model_type == "resnet":
        model = build_resnet50_patient_model(load_pretrained=False)
    elif model_type == "vit":
        model = build_vit_patient_model(load_pretrained=False)
    elif model_type == "hybrid":
        model = build_hybrid_patient_model(load_pretrained=False)
    else:
        raise ValueError(f"Unknown model type: {model_type}")

    model.load_state_dict(torch.load(model_path, map_location=device))
    model.to(device)
    model.eval()
    return model


# ============================================================
# 14) CV 실행 함수
# ============================================================
def run_cv_for_model(model_name, model_type, build_fn):
    fold_results   = []
    fold_histories = []

    for fold_idx in FOLDS:
        print("\n" + "=" * 80)
        print(f"Running {model_name} | Fold {fold_idx}")
        print("=" * 80)

        train_loader, val_loader, pos_weight, subtype_class_weights = make_fold_loaders(fold_idx)

        model = build_fn()

        # CascadeCriterion: subtype_loss_weight는 fit_model 내부에서 epoch마다 업데이트
        criterion = CascadeCriterion(
            pos_weight=pos_weight,
            subtype_class_weights=subtype_class_weights,
            subtype_loss_weight=SUBTYPE_LOSS_WEIGHT_START,
        )

        _, history_df, best_path = fit_model(
            model=model,
            model_name=model_name,
            fold_idx=fold_idx,
            train_loader=train_loader,
            val_loader=val_loader,
            device=device,
            num_epochs=NUM_EPOCHS,
            lr=LR,
            weight_decay=WEIGHT_DECAY,
            criterion=criterion,
            patience=PATIENCE,
            min_delta=MIN_DELTA,
        )

        best_model    = load_model(model_type, best_path, device)
        final_metrics = eval_confusion(best_model, val_loader, criterion, device, threshold=THRESHOLD)

        print(f"\n[{model_name}][Fold {fold_idx}] Final Metrics")
        print(f"Malignancy  AUC={final_metrics['auc']:.4f}, F1={final_metrics['f1']:.4f}, Recall={final_metrics['recall']:.4f}")
        print(f"Subtype Oracle  Acc={final_metrics['subtype_oracle_acc']:.4f}, MacroF1={final_metrics['subtype_oracle_macro_f1']:.4f}")
        print(f"Cascade  Acc={final_metrics['subtype_cascade_acc']:.4f}, GateRecall={final_metrics['subtype_gate_recall']:.4f}")

        fold_results.append({
            "model":                   model_name,
            "fold":                    fold_idx,
            "mal_acc":                 final_metrics["acc"],
            "mal_auc":                 final_metrics["auc"],
            "mal_f1":                  final_metrics["f1"],
            "mal_recall":              final_metrics["recall"],
            "subtype_oracle_acc":      final_metrics["subtype_oracle_acc"],
            "subtype_oracle_macro_f1": final_metrics["subtype_oracle_macro_f1"],
            "subtype_cascade_acc":     final_metrics["subtype_cascade_acc"],
            "subtype_gate_recall":     final_metrics["subtype_gate_recall"],
            "binary_cm":               final_metrics["cm"],
            "subtype_oracle_cm":       final_metrics["subtype_oracle_cm"],
        })

        history_df["model"] = model_name
        fold_histories.append(history_df)

        del model, best_model, train_loader, val_loader
        gc.collect()
        if torch.cuda.is_available():
            torch.cuda.empty_cache()

    result_df      = pd.DataFrame(fold_results)
    history_df_all = pd.concat(fold_histories, ignore_index=True)
    return result_df, history_df_all


# ============================================================
# 15) 학습 실행
# ============================================================

# ── ResNet50 ──────────────────────────────────────────────────
print(">>> Training ResNet50...")
resnet_cv_df, resnet_history_df = run_cv_for_model(
    model_name="ResNet50",
    model_type="resnet",
    build_fn=lambda: build_resnet50_patient_model(load_pretrained=True),
)
display(resnet_cv_df)

# ── ViT-B/16 ─────────────────────────────────────────────────
print(">>> Training ViT-B/16...")
vit_cv_df, vit_history_df = run_cv_for_model(
    model_name="ViT-B16",
    model_type="vit",
    build_fn=lambda: build_vit_patient_model(load_pretrained=True),
)
display(vit_cv_df)

# ── Hybrid ────────────────────────────────────────────────────
print(">>> Training Hybrid...")
hybrid_cv_df, hybrid_history_df = run_cv_for_model(
    model_name="Hybrid",
    model_type="hybrid",
    build_fn=lambda: build_hybrid_patient_model(load_pretrained=True),
)
display(hybrid_cv_df)


# ============================================================
# 16) 5-fold 평균 ± 표준편차 요약
# ============================================================
all_cv_df = pd.concat([resnet_cv_df, vit_cv_df, hybrid_cv_df], ignore_index=True)

summary_df = (
    all_cv_df.groupby("model")[[
        "mal_auc", "mal_f1", "mal_recall",
        "subtype_oracle_acc", "subtype_oracle_macro_f1",
        "subtype_cascade_acc", "subtype_gate_recall",
    ]]
    .agg(["mean", "std"])
)
display(summary_df)


# ============================================================
# 17) 학습 곡선 시각화
# ============================================================
def plot_one_model_by_fold(history_df, model_name):
    folds = sorted(history_df["fold"].unique())

    fig, axes = plt.subplots(1, 3, figsize=(18, 5))

    # Loss
    ax = axes[0]
    for fold in folds:
        df_f = history_df[history_df["fold"] == fold].sort_values("epoch")
        ax.plot(df_f["epoch"], df_f["train_loss"], linestyle="--", alpha=0.7, label=f"Fold{fold} Train")
        ax.plot(df_f["epoch"], df_f["val_loss"],   alpha=0.7,      label=f"Fold{fold} Val")
    ax.set_title(f"{model_name} - Total Loss")
    ax.set_xlabel("Epoch")
    ax.set_ylabel("Loss")
    ax.legend(fontsize=7)

    # Malignancy AUC
    ax = axes[1]
    for fold in folds:
        df_f = history_df[history_df["fold"] == fold].sort_values("epoch")
        ax.plot(df_f["epoch"], df_f["val_auc"], alpha=0.8, label=f"Fold{fold}")
    ax.set_title(f"{model_name} - Val Malignancy AUC")
    ax.set_xlabel("Epoch")
    ax.set_ylabel("AUC")
    ax.legend(fontsize=7)

    # Subtype cascade acc
    ax = axes[2]
    for fold in folds:
        df_f = history_df[history_df["fold"] == fold].sort_values("epoch")
        ax.plot(df_f["epoch"], df_f["val_subtype_cascade_acc"], alpha=0.8, label=f"Fold{fold}")
    ax.set_title(f"{model_name} - Val Subtype Cascade Acc")
    ax.set_xlabel("Epoch")
    ax.set_ylabel("Cascade Acc")
    ax.legend(fontsize=7)

    plt.suptitle(model_name, fontsize=13)
    plt.tight_layout()
    plt.show()


plot_one_model_by_fold(resnet_history_df, "ResNet50")
plot_one_model_by_fold(vit_history_df,    "ViT-B16")
plot_one_model_by_fold(hybrid_history_df, "Hybrid")
# Out:
# ============================================================
# ResNet50 build success
# Vit-B/16 build success
# ============================================================
# Device: cuda
# 현재 작업 경로: /tf/notebooks/Image Encoder/Untitled Folder
# DATA_ROOT: /tf/nasw/dataset001/preprocessed/npz_ct
# OUTPUT_DIR: /tf/notebooks/Image Encoder/Untitled Folder/ct_cascade_models
# FOLDS: [1, 2, 3, 4, 5]
# LOCAL_RESNET_WEIGHTS exists: True
# LOCAL_VIT_WEIGHTS exists: True
# malignant_type_ids: [0, 1, 3, 5, 7]
# MALIGNANT_MAP: {0: 0, 1: 1, 3: 2, 5: 3, 7: 4}
# NUM_MALIGNANT_SUBTYPES: 5
# >>> Training ResNet50...
#
# ================================================================================
# Running ResNet50 | Fold 1
# ================================================================================
# [FOLD 1] Train benign(0): 1605, malignant(1): 444, pos_weight=3.6149, subtype_counts=[34.0, 67.0, 48.0, 46.0, 249.0], subtype_class_weights=[1.617400050163269, 0.8206999897956848, 1.1455999612808228, 1.1953999996185303, 0.2207999974489212]
# [ResNet50][Fold 1][Epoch 01] sub_w=0.400 | train loss=1.3684(mal=0.8405,sub=1.3197), auc=0.8231, f1=0.5637, recall=0.6126, oracle_f1=0.1801, cascade_acc=0.3716 | val loss=0.5688(mal=0.4239,sub=0.3622), auc=0.9624, f1=0.7500, recall=0.9459, oracle_f1=0.1434, cascade_acc=0.5225
#   -> best saved (val_auc=0.9624): ct_cascade_models/ResNet50_fold1_best.pth
# [ResNet50][Fold 1][Epoch 02] sub_w=0.414 | train loss=1.1019(mal=0.5812,sub=1.2586), auc=0.9159, f1=0.6978, recall=0.8423, oracle_f1=0.1696, cascade_acc=0.4887 | val loss=0.5914(mal=0.4445,sub=0.3550), auc=0.9662, f1=0.7554, recall=0.9459, oracle_f1=0.1434, cascade_acc=0.5135
#   -> best saved (val_auc=0.9662): ct_cascade_models/ResNet50_fold1_best.pth
# [ResNet50][Fold 1][Epoch 03] sub_w=0.428 | train loss=0.9668(mal=0.4590,sub=1.1874), auc=0.9482, f1=0.7759, recall=0.8694, oracle_f1=0.1719, cascade_acc=0.5090 | val loss=0.5030(mal=0.3509,sub=0.3557), auc=0.9709, f1=0.8412, recall=0.8829, oracle_f1=0.1611, cascade_acc=0.4865
#   -> best saved (val_auc=0.9709): ct_cascade_models/ResNet50_fold1_best.pth
# [ResNet50][Fold 1][Epoch 04] sub_w=0.441 | train loss=0.9523(mal=0.4104,sub=1.2276), auc=0.9584, f1=0.7662, recall=0.8896, oracle_f1=0.1720, cascade_acc=0.5158 | val loss=0.5654(mal=0.4170,sub=0.3361), auc=0.9671, f1=0.8182, recall=0.8108, oracle_f1=0.1881, cascade_acc=0.4775
#   -> no improvement (1/7)
# [ResNet50][Fold 1][Epoch 05] sub_w=0.455 | train loss=0.8652(mal=0.3299,sub=1.1759), auc=0.9724, f1=0.8201, recall=0.9189, oracle_f1=0.2106, cascade_acc=0.5293 | val loss=0.4448(mal=0.2846,sub=0.3521), auc=0.9806, f1=0.8327, recall=0.9189, oracle_f1=0.1381, cascade_acc=0.5225
#   -> best saved (val_auc=0.9806): ct_cascade_models/ResNet50_fold1_best.pth
# [ResNet50][Fold 1][Epoch 06] sub_w=0.469 | train loss=0.8475(mal=0.3200,sub=1.1248), auc=0.9745, f1=0.8283, recall=0.9234, oracle_f1=0.2076, cascade_acc=0.5360 | val loss=0.5356(mal=0.3666,sub=0.3603), auc=0.9746, f1=0.8711, recall=0.8829, oracle_f1=0.2385, cascade_acc=0.4955
#   -> no improvement (1/7)
# [ResNet50][Fold 1][Epoch 07] sub_w=0.483 | train loss=0.8288(mal=0.3014,sub=1.0925), auc=0.9774, f1=0.8349, recall=0.9279, oracle_f1=0.2784, cascade_acc=0.5518 | val loss=0.6354(mal=0.4276,sub=0.4305), auc=0.9791, f1=0.8762, recall=0.8288, oracle_f1=0.1706, cascade_acc=0.4595
#   -> no improvement (2/7)
# [ResNet50][Fold 1][Epoch 08] sub_w=0.497 | train loss=0.7709(mal=0.2443,sub=1.0605), auc=0.9854, f1=0.8717, recall=0.9414, oracle_f1=0.3013, cascade_acc=0.5698 | val loss=0.6024(mal=0.3958,sub=0.4161), auc=0.9729, f1=0.7704, recall=0.9369, oracle_f1=0.2898, cascade_acc=0.5586
#   -> no improvement (3/7)
# [ResNet50][Fold 1][Epoch 09] sub_w=0.510 | train loss=0.7782(mal=0.2359,sub=1.0626), auc=0.9858, f1=0.8615, recall=0.9459, oracle_f1=0.2853, cascade_acc=0.5541 | val loss=0.5128(mal=0.3520,sub=0.3151), auc=0.9844, f1=0.8826, recall=0.8468, oracle_f1=0.2548, cascade_acc=0.4144
#   -> best saved (val_auc=0.9844): ct_cascade_models/ResNet50_fold1_best.pth
# [ResNet50][Fold 1][Epoch 10] sub_w=0.524 | train loss=0.7245(mal=0.2042,sub=0.9927), auc=0.9899, f1=0.8812, recall=0.9437, oracle_f1=0.3454, cascade_acc=0.5698 | val loss=0.5719(mal=0.3165,sub=0.4874), auc=0.9772, f1=0.8632, recall=0.9099, oracle_f1=0.2943, cascade_acc=0.5315
#   -> no improvement (1/7)
# [ResNet50][Fold 1][Epoch 11] sub_w=0.538 | train loss=0.6835(mal=0.1778,sub=0.9400), auc=0.9916, f1=0.8997, recall=0.9595, oracle_f1=0.3693, cascade_acc=0.5901 | val loss=0.5856(mal=0.3687,sub=0.4033), auc=0.9885, f1=0.8910, recall=0.8468, oracle_f1=0.3820, cascade_acc=0.5135
#   -> best saved (val_auc=0.9885): ct_cascade_models/ResNet50_fold1_best.pth
# [ResNet50][Fold 1][Epoch 12] sub_w=0.552 | train loss=0.7077(mal=0.1825,sub=0.9520), auc=0.9915, f1=0.8863, recall=0.9572, oracle_f1=0.3802, cascade_acc=0.5946 | val loss=0.5289(mal=0.2926,sub=0.4284), auc=0.9800, f1=0.8770, recall=0.9640, oracle_f1=0.2672, cascade_acc=0.4414
#   -> no improvement (1/7)
# [ResNet50][Fold 1][Epoch 13] sub_w=0.566 | train loss=0.6475(mal=0.1344,sub=0.9073), auc=0.9953, f1=0.9300, recall=0.9730, oracle_f1=0.4328, cascade_acc=0.5968 | val loss=0.6157(mal=0.4155,sub=0.3541), auc=0.9645, f1=0.7915, recall=0.8378, oracle_f1=0.2980, cascade_acc=0.3964
#   -> no improvement (2/7)
# [ResNet50][Fold 1][Epoch 14] sub_w=0.579 | train loss=0.6557(mal=0.1469,sub=0.8784), auc=0.9941, f1=0.9267, recall=0.9685, oracle_f1=0.4617, cascade_acc=0.6329 | val loss=0.6767(mal=0.3704,sub=0.5288), auc=0.9768, f1=0.8189, recall=0.9369, oracle_f1=0.3779, cascade_acc=0.5315
#   -> no improvement (3/7)
# [ResNet50][Fold 1][Epoch 15] sub_w=0.593 | train loss=0.6128(mal=0.1298,sub=0.8144), auc=0.9957, f1=0.9164, recall=0.9752, oracle_f1=0.5305, cascade_acc=0.6689 | val loss=0.6317(mal=0.4188,sub=0.3590), auc=0.9871, f1=0.8670, recall=0.7928, oracle_f1=0.3910, cascade_acc=0.4234
#   -> no improvement (4/7)
# [ResNet50][Fold 1][Epoch 16] sub_w=0.607 | train loss=0.5835(mal=0.1302,sub=0.7470), auc=0.9955, f1=0.9339, recall=0.9707, oracle_f1=0.5403, cascade_acc=0.6734 | val loss=0.6337(mal=0.3485,sub=0.4700), auc=0.9820, f1=0.8818, recall=0.8739, oracle_f1=0.3264, cascade_acc=0.4595
#   -> no improvement (5/7)
# [ResNet50][Fold 1][Epoch 17] sub_w=0.621 | train loss=0.5251(mal=0.0922,sub=0.6974), auc=0.9975, f1=0.9560, recall=0.9797, oracle_f1=0.6236, cascade_acc=0.7207 | val loss=0.8775(mal=0.4791,sub=0.6417), auc=0.9868, f1=0.8774, recall=0.8378, oracle_f1=0.2849, cascade_acc=0.4505
#   -> no improvement (6/7)
# [ResNet50][Fold 1][Epoch 18] sub_w=0.634 | train loss=0.5070(mal=0.0786,sub=0.6751), auc=0.9984, f1=0.9595, recall=0.9865, oracle_f1=0.6190, cascade_acc=0.7275 | val loss=0.9367(mal=0.5854,sub=0.5538), auc=0.9667, f1=0.8182, recall=0.8919, oracle_f1=0.3385, cascade_acc=0.4775
#   -> no improvement (7/7)
#   -> early stopping triggered at epoch 18
#
# -- Final Evaluation --
# [Malignancy]  AUC=0.9885, F1=0.8910, Recall=0.8468, Acc=0.9552
# [Subtype Oracle]  Acc=0.5856, MacroF1=0.3820
# [Cascade]  SubtypeAcc=0.5135, GateRecall=0.8468
# Binary CM:
# [[396   6]
#  [ 17  94]]
# Subtype Oracle CM:
# [[ 0  1  1  0  6]
#  [ 0  7  3  1  6]
#  [ 0  0  5  1  6]
#  [ 0  1  2  3  6]
#  [ 1  1 10  0 50]]
#
# [ResNet50][Fold 1] Final Metrics
# Malignancy  AUC=0.9885, F1=0.8910, Recall=0.8468
# Subtype Oracle  Acc=0.5856, MacroF1=0.3820
# Cascade  Acc=0.5135, GateRecall=0.8468
#
# ================================================================================
# Running ResNet50 | Fold 2
# ================================================================================
# [FOLD 2] Train benign(0): 1605, malignant(1): 444, pos_weight=3.6149, subtype_counts=[34.0, 67.0, 48.0, 46.0, 249.0], subtype_class_weights=[1.617400050163269, 0.8206999897956848, 1.1455999612808228, 1.1953999996185303, 0.2207999974489212]
# [ResNet50][Fold 2][Epoch 01] sub_w=0.400 | train loss=1.2365(mal=0.7045,sub=1.3301), auc=0.8791, f1=0.6445, recall=0.7860, oracle_f1=0.1680, cascade_acc=0.4099 | val loss=0.8137(mal=0.6637,sub=0.3749), auc=0.9141, f1=0.7611, recall=0.7748, oracle_f1=0.1434, cascade_acc=0.4595
#   -> best saved (val_auc=0.9141): ct_cascade_models/ResNet50_fold2_best.pth
# [ResNet50][Fold 2][Epoch 02] sub_w=0.414 | train loss=1.0664(mal=0.5613,sub=1.2207), auc=0.9217, f1=0.7363, recall=0.8649, oracle_f1=0.1512, cascade_acc=0.5023 | val loss=0.6543(mal=0.5024,sub=0.3673), auc=0.9395, f1=0.7692, recall=0.8559, oracle_f1=0.1560, cascade_acc=0.4955
#   -> best saved (val_auc=0.9395): ct_cascade_models/ResNet50_fold2_best.pth
# [ResNet50][Fold 2][Epoch 03] sub_w=0.428 | train loss=0.9537(mal=0.4445,sub=1.1910), auc=0.9514, f1=0.7691, recall=0.8964, oracle_f1=0.1940, cascade_acc=0.5315 | val loss=0.7036(mal=0.5383,sub=0.3866), auc=0.9388, f1=0.7631, recall=0.8559, oracle_f1=0.1409, cascade_acc=0.4955
#   -> no improvement (1/7)
# [ResNet50][Fold 2][Epoch 04] sub_w=0.441 | train loss=0.9002(mal=0.3951,sub=1.1444), auc=0.9609, f1=0.7929, recall=0.9009, oracle_f1=0.1894, cascade_acc=0.5135 | val loss=0.6622(mal=0.4991,sub=0.3694), auc=0.9486, f1=0.7673, recall=0.8468, oracle_f1=0.1399, cascade_acc=0.4955
#   -> best saved (val_auc=0.9486): ct_cascade_models/ResNet50_fold2_best.pth
# [ResNet50][Fold 2][Epoch 05] sub_w=0.455 | train loss=0.9055(mal=0.3640,sub=1.1896), auc=0.9671, f1=0.8129, recall=0.9054, oracle_f1=0.1807, cascade_acc=0.5248 | val loss=0.7559(mal=0.5837,sub=0.3783), auc=0.9404, f1=0.7626, recall=0.8829, oracle_f1=0.1896, cascade_acc=0.5225
#   -> no improvement (1/7)
# [ResNet50][Fold 2][Epoch 06] sub_w=0.469 | train loss=0.8708(mal=0.3383,sub=1.1356), auc=0.9706, f1=0.8310, recall=0.9414, oracle_f1=0.2247, cascade_acc=0.5518 | val loss=0.6807(mal=0.4943,sub=0.3975), auc=0.9502, f1=0.7576, recall=0.9009, oracle_f1=0.2214, cascade_acc=0.5315
#   -> best saved (val_auc=0.9502): ct_cascade_models/ResNet50_fold2_best.pth
# [ResNet50][Fold 2][Epoch 07] sub_w=0.483 | train loss=0.8156(mal=0.2767,sub=1.1164), auc=0.9799, f1=0.8571, recall=0.9392, oracle_f1=0.3233, cascade_acc=0.5541 | val loss=0.8462(mal=0.6608,sub=0.3840), auc=0.9505, f1=0.8111, recall=0.7928, oracle_f1=0.2840, cascade_acc=0.4865
#   -> no improvement (1/7)
# [ResNet50][Fold 2][Epoch 08] sub_w=0.497 | train loss=0.7870(mal=0.2440,sub=1.0936), auc=0.9852, f1=0.8708, recall=0.9414, oracle_f1=0.3743, cascade_acc=0.5991 | val loss=0.9516(mal=0.7158,sub=0.4750), auc=0.9460, f1=0.6871, recall=0.9099, oracle_f1=0.2558, cascade_acc=0.5315
#   -> no improvement (2/7)
# [ResNet50][Fold 2][Epoch 09] sub_w=0.510 | train loss=0.8183(mal=0.2739,sub=1.0666), auc=0.9802, f1=0.8510, recall=0.9392, oracle_f1=0.3747, cascade_acc=0.5901 | val loss=0.7516(mal=0.5749,sub=0.3462), auc=0.9591, f1=0.7723, recall=0.7027, oracle_f1=0.2898, cascade_acc=0.3784
#   -> best saved (val_auc=0.9591): ct_cascade_models/ResNet50_fold2_best.pth
# [ResNet50][Fold 2][Epoch 10] sub_w=0.524 | train loss=0.7796(mal=0.2248,sub=1.0584), auc=0.9874, f1=0.8814, recall=0.9459, oracle_f1=0.3535, cascade_acc=0.5721 | val loss=1.2541(mal=1.0621,sub=0.3665), auc=0.9548, f1=0.7182, recall=0.5856, oracle_f1=0.2582, cascade_acc=0.3063
#   -> no improvement (1/7)
# [ResNet50][Fold 2][Epoch 11] sub_w=0.538 | train loss=0.7402(mal=0.2074,sub=0.9904), auc=0.9888, f1=0.8861, recall=0.9459, oracle_f1=0.4052, cascade_acc=0.6126 | val loss=0.7611(mal=0.5499,sub=0.3927), auc=0.9522, f1=0.7455, recall=0.9369, oracle_f1=0.3053, cascade_acc=0.4955
#   -> no improvement (2/7)
# [ResNet50][Fold 2][Epoch 12] sub_w=0.552 | train loss=0.6548(mal=0.1745,sub=0.8706), auc=0.9920, f1=0.9083, recall=0.9707, oracle_f1=0.4239, cascade_acc=0.6396 | val loss=0.7843(mal=0.5726,sub=0.3837), auc=0.9596, f1=0.8103, recall=0.8468, oracle_f1=0.2688, cascade_acc=0.4054
#   -> no improvement (3/7)
# [ResNet50][Fold 2][Epoch 13] sub_w=0.566 | train loss=0.7077(mal=0.1441,sub=0.9967), auc=0.9946, f1=0.9175, recall=0.9640, oracle_f1=0.4143, cascade_acc=0.6194 | val loss=0.9370(mal=0.7353,sub=0.3567), auc=0.9518, f1=0.7964, recall=0.7928, oracle_f1=0.2884, cascade_acc=0.3874
#   -> no improvement (4/7)
# [ResNet50][Fold 2][Epoch 14] sub_w=0.579 | train loss=0.6454(mal=0.1333,sub=0.8840), auc=0.9953, f1=0.9359, recall=0.9707, oracle_f1=0.4302, cascade_acc=0.6396 | val loss=0.8763(mal=0.6178,sub=0.4463), auc=0.9628, f1=0.8128, recall=0.8018, oracle_f1=0.3440, cascade_acc=0.4865
#   -> best saved (val_auc=0.9628): ct_cascade_models/ResNet50_fold2_best.pth
# [ResNet50][Fold 2][Epoch 15] sub_w=0.593 | train loss=0.6093(mal=0.1038,sub=0.8523), auc=0.9965, f1=0.9423, recall=0.9752, oracle_f1=0.4944, cascade_acc=0.6577 | val loss=0.9911(mal=0.7450,sub=0.4150), auc=0.9550, f1=0.8251, recall=0.8288, oracle_f1=0.3516, cascade_acc=0.4414
#   -> no improvement (1/7)
# [ResNet50][Fold 2][Epoch 16] sub_w=0.607 | train loss=0.5868(mal=0.1463,sub=0.7259), auc=0.9933, f1=0.9262, recall=0.9752, oracle_f1=0.5596, cascade_acc=0.6982 | val loss=0.9001(mal=0.6224,sub=0.4575), auc=0.9586, f1=0.7568, recall=0.8829, oracle_f1=0.3310, cascade_acc=0.5045
#   -> no improvement (2/7)
# [ResNet50][Fold 2][Epoch 17] sub_w=0.621 | train loss=0.5809(mal=0.1190,sub=0.7442), auc=0.9963, f1=0.9364, recall=0.9775, oracle_f1=0.5253, cascade_acc=0.6982 | val loss=1.2279(mal=0.9347,sub=0.4725), auc=0.9618, f1=0.7981, recall=0.7658, oracle_f1=0.2740, cascade_acc=0.3694
#   -> no improvement (3/7)
# [ResNet50][Fold 2][Epoch 18] sub_w=0.634 | train loss=0.5868(mal=0.1203,sub=0.7351), auc=0.9958, f1=0.9351, recall=0.9730, oracle_f1=0.6111, cascade_acc=0.7207 | val loss=1.0803(mal=0.8243,sub=0.4035), auc=0.9499, f1=0.8142, recall=0.8288, oracle_f1=0.3991, cascade_acc=0.4595
#   -> no improvement (4/7)
# [ResNet50][Fold 2][Epoch 19] sub_w=0.648 | train loss=0.5066(mal=0.1065,sub=0.6171), auc=0.9971, f1=0.9381, recall=0.9730, oracle_f1=0.6566, cascade_acc=0.7477 | val loss=1.0467(mal=0.7352,sub=0.4805), auc=0.9582, f1=0.7946, recall=0.8018, oracle_f1=0.3774, cascade_acc=0.4414
#   -> no improvement (5/7)
# [ResNet50][Fold 2][Epoch 20] sub_w=0.662 | train loss=0.5237(mal=0.1162,sub=0.6155), auc=0.9963, f1=0.9351, recall=0.9730, oracle_f1=0.6405, cascade_acc=0.7545 | val loss=1.0080(mal=0.6965,sub=0.4705), auc=0.9443, f1=0.7519, recall=0.8739, oracle_f1=0.3329, cascade_acc=0.4775
#   -> no improvement (6/7)
# [ResNet50][Fold 2][Epoch 21] sub_w=0.676 | train loss=0.4184(mal=0.0799,sub=0.5009), auc=0.9983, f1=0.9491, recall=0.9865, oracle_f1=0.7420, cascade_acc=0.8108 | val loss=1.7386(mal=1.3246,sub=0.6125), auc=0.9437, f1=0.7861, recall=0.7117, oracle_f1=0.3410, cascade_acc=0.3874
#   -> no improvement (7/7)
#   -> early stopping triggered at epoch 21
#
# -- Final Evaluation --
# [Malignancy]  AUC=0.9628, F1=0.8128, Recall=0.8018, Acc=0.9201
# [Subtype Oracle]  Acc=0.5495, MacroF1=0.3440
# [Cascade]  SubtypeAcc=0.4865, GateRecall=0.8018
# Binary CM:
# [[383  19]
#  [ 22  89]]
# Subtype Oracle CM:
# [[ 0  0  2  1  5]
#  [ 0  4  3  1  9]
#  [ 0  0  5  0  7]
#  [ 1  1  4  4  2]
#  [ 0  6  6  2 48]]
#
# [ResNet50][Fold 2] Final Metrics
# Malignancy  AUC=0.9628, F1=0.8128, Recall=0.8018
# Subtype Oracle  Acc=0.5495, MacroF1=0.3440
# Cascade  Acc=0.4865, GateRecall=0.8018
#
# ================================================================================
# Running ResNet50 | Fold 3
# ================================================================================
# [FOLD 3] Train benign(0): 1606, malignant(1): 444, pos_weight=3.6171, subtype_counts=[34.0, 67.0, 48.0, 47.0, 248.0], subtype_class_weights=[1.6253000497817993, 0.8248000144958496, 1.1512999534606934, 1.1757999658584595, 0.22280000150203705]
# [ResNet50][Fold 3][Epoch 01] sub_w=0.400 | train loss=1.3556(mal=0.8328,sub=1.3070), auc=0.8329, f1=0.5813, recall=0.6284, oracle_f1=0.1494, cascade_acc=0.3716 | val loss=0.7256(mal=0.5623,sub=0.4081), auc=0.9263, f1=0.6759, recall=0.8829, oracle_f1=0.1435, cascade_acc=0.5045
#   -> best saved (val_auc=0.9263): ct_cascade_models/ResNet50_fold3_best.pth
# [ResNet50][Fold 3][Epoch 02] sub_w=0.414 | train loss=1.0851(mal=0.5724,sub=1.2389), auc=0.9187, f1=0.7080, recall=0.8356, oracle_f1=0.1918, cascade_acc=0.5023 | val loss=0.7220(mal=0.5632,sub=0.3838), auc=0.9440, f1=0.7713, recall=0.7748, oracle_f1=0.1658, cascade_acc=0.4505
#   -> best saved (val_auc=0.9440): ct_cascade_models/ResNet50_fold3_best.pth
# [ResNet50][Fold 3][Epoch 03] sub_w=0.428 | train loss=1.0466(mal=0.5194,sub=1.2330), auc=0.9322, f1=0.7527, recall=0.8604, oracle_f1=0.1796, cascade_acc=0.4932 | val loss=0.6250(mal=0.4645,sub=0.3753), auc=0.9461, f1=0.7500, recall=0.8919, oracle_f1=0.1434, cascade_acc=0.5135
#   -> best saved (val_auc=0.9461): ct_cascade_models/ResNet50_fold3_best.pth
# [ResNet50][Fold 3][Epoch 04] sub_w=0.441 | train loss=0.9740(mal=0.4396,sub=1.2107), auc=0.9513, f1=0.7771, recall=0.8874, oracle_f1=0.1655, cascade_acc=0.5135 | val loss=0.5950(mal=0.4291,sub=0.3758), auc=0.9552, f1=0.7773, recall=0.8649, oracle_f1=0.1412, cascade_acc=0.4955
#   -> best saved (val_auc=0.9552): ct_cascade_models/ResNet50_fold3_best.pth
# [ResNet50][Fold 3][Epoch 05] sub_w=0.455 | train loss=0.9445(mal=0.4177,sub=1.1575), auc=0.9575, f1=0.7901, recall=0.8986, oracle_f1=0.1870, cascade_acc=0.5180 | val loss=0.5662(mal=0.3909,sub=0.3851), auc=0.9640, f1=0.8065, recall=0.9009, oracle_f1=0.1973, cascade_acc=0.5225
#   -> best saved (val_auc=0.9640): ct_cascade_models/ResNet50_fold3_best.pth
# [ResNet50][Fold 3][Epoch 06] sub_w=0.469 | train loss=0.8723(mal=0.3310,sub=1.1541), auc=0.9724, f1=0.8321, recall=0.9099, oracle_f1=0.2212, cascade_acc=0.5383 | val loss=0.6016(mal=0.4392,sub=0.3463), auc=0.9571, f1=0.7888, recall=0.8919, oracle_f1=0.1846, cascade_acc=0.4955
#   -> no improvement (1/7)
# [ResNet50][Fold 3][Epoch 07] sub_w=0.483 | train loss=0.8504(mal=0.3255,sub=1.0873), auc=0.9740, f1=0.8325, recall=0.9234, oracle_f1=0.2707, cascade_acc=0.5518 | val loss=0.5451(mal=0.3812,sub=0.3396), auc=0.9647, f1=0.8240, recall=0.9279, oracle_f1=0.2505, cascade_acc=0.5405
#   -> no improvement (2/7)
# [ResNet50][Fold 3][Epoch 08] sub_w=0.497 | train loss=0.8241(mal=0.2903,sub=1.0750), auc=0.9784, f1=0.8478, recall=0.9347, oracle_f1=0.2622, cascade_acc=0.5563 | val loss=0.5956(mal=0.4139,sub=0.3660), auc=0.9646, f1=0.8255, recall=0.8739, oracle_f1=0.2547, cascade_acc=0.5045
#   -> no improvement (3/7)
# [ResNet50][Fold 3][Epoch 09] sub_w=0.510 | train loss=0.7707(mal=0.2170,sub=1.0849), auc=0.9881, f1=0.8814, recall=0.9459, oracle_f1=0.2969, cascade_acc=0.5721 | val loss=0.7978(mal=0.6260,sub=0.3368), auc=0.9427, f1=0.7519, recall=0.9009, oracle_f1=0.2369, cascade_acc=0.4865
#   -> no improvement (4/7)
# [ResNet50][Fold 3][Epoch 10] sub_w=0.524 | train loss=0.8120(mal=0.2673,sub=1.0393), auc=0.9821, f1=0.8678, recall=0.9459, oracle_f1=0.3163, cascade_acc=0.5608 | val loss=0.6224(mal=0.4386,sub=0.3506), auc=0.9687, f1=0.8288, recall=0.8288, oracle_f1=0.2435, cascade_acc=0.4685
#   -> best saved (val_auc=0.9687): ct_cascade_models/ResNet50_fold3_best.pth
# [ResNet50][Fold 3][Epoch 11] sub_w=0.538 | train loss=0.7561(mal=0.2104,sub=1.0145), auc=0.9888, f1=0.8847, recall=0.9414, oracle_f1=0.3439, cascade_acc=0.5653 | val loss=0.5471(mal=0.3559,sub=0.3554), auc=0.9728, f1=0.8016, recall=0.9279, oracle_f1=0.2569, cascade_acc=0.5045
#   -> best saved (val_auc=0.9728): ct_cascade_models/ResNet50_fold3_best.pth
# [ResNet50][Fold 3][Epoch 12] sub_w=0.552 | train loss=0.7470(mal=0.2039,sub=0.9844), auc=0.9894, f1=0.8891, recall=0.9482, oracle_f1=0.4086, cascade_acc=0.6149 | val loss=0.7061(mal=0.4848,sub=0.4010), auc=0.9613, f1=0.7937, recall=0.9009, oracle_f1=0.2826, cascade_acc=0.5225
#   -> no improvement (1/7)
# [ResNet50][Fold 3][Epoch 13] sub_w=0.566 | train loss=0.7299(mal=0.1686,sub=0.9926), auc=0.9925, f1=0.9039, recall=0.9640, oracle_f1=0.3887, cascade_acc=0.6126 | val loss=0.9040(mal=0.7066,sub=0.3491), auc=0.9621, f1=0.8111, recall=0.7928, oracle_f1=0.2910, cascade_acc=0.4414
#   -> no improvement (2/7)
# [ResNet50][Fold 3][Epoch 14] sub_w=0.579 | train loss=0.7094(mal=0.1678,sub=0.9350), auc=0.9924, f1=0.9155, recall=0.9640, oracle_f1=0.3969, cascade_acc=0.6081 | val loss=0.8695(mal=0.6717,sub=0.3416), auc=0.9608, f1=0.8037, recall=0.7928, oracle_f1=0.3535, cascade_acc=0.4775
#   -> no improvement (3/7)
# [ResNet50][Fold 3][Epoch 15] sub_w=0.593 | train loss=0.6755(mal=0.1488,sub=0.8881), auc=0.9931, f1=0.9335, recall=0.9797, oracle_f1=0.4344, cascade_acc=0.6216 | val loss=1.0154(mal=0.7923,sub=0.3761), auc=0.9711, f1=0.8159, recall=0.7387, oracle_f1=0.3251, cascade_acc=0.4775
#   -> no improvement (4/7)
# [ResNet50][Fold 3][Epoch 16] sub_w=0.607 | train loss=0.6539(mal=0.1435,sub=0.8410), auc=0.9943, f1=0.9325, recall=0.9640, oracle_f1=0.5067, cascade_acc=0.6554 | val loss=0.7563(mal=0.5257,sub=0.3799), auc=0.9646, f1=0.8054, recall=0.8018, oracle_f1=0.2982, cascade_acc=0.4775
#   -> no improvement (5/7)
# [ResNet50][Fold 3][Epoch 17] sub_w=0.621 | train loss=0.6204(mal=0.1379,sub=0.7774), auc=0.9950, f1=0.9289, recall=0.9707, oracle_f1=0.5114, cascade_acc=0.6712 | val loss=0.7366(mal=0.5301,sub=0.3326), auc=0.9640, f1=0.8261, recall=0.8559, oracle_f1=0.2686, cascade_acc=0.3694
#   -> no improvement (6/7)
# [ResNet50][Fold 3][Epoch 18] sub_w=0.634 | train loss=0.6164(mal=0.1360,sub=0.7572), auc=0.9941, f1=0.9365, recall=0.9640, oracle_f1=0.5486, cascade_acc=0.6914 | val loss=0.6351(mal=0.4386,sub=0.3097), auc=0.9691, f1=0.8031, recall=0.9189, oracle_f1=0.3829, cascade_acc=0.3694
#   -> no improvement (7/7)
#   -> early stopping triggered at epoch 18
#
# -- Final Evaluation --
# [Malignancy]  AUC=0.9728, F1=0.8016, Recall=0.9279, Acc=0.9004
# [Subtype Oracle]  Acc=0.5225, MacroF1=0.2569
# [Cascade]  SubtypeAcc=0.5045, GateRecall=0.9279
# Binary CM:
# [[358  43]
#  [  8 103]]
# Subtype Oracle CM:
# [[ 0  1  1  0  6]
#  [ 0  3  2  1 11]
#  [ 2  0  3  2  5]
#  [ 0  2  4  1  4]
#  [ 0  3  8  1 51]]
#
# [ResNet50][Fold 3] Final Metrics
# Malignancy  AUC=0.9728, F1=0.8016, Recall=0.9279
# Subtype Oracle  Acc=0.5225, MacroF1=0.2569
# Cascade  Acc=0.5045, GateRecall=0.9279
#
# ================================================================================
# Running ResNet50 | Fold 4
# ================================================================================
# [FOLD 4] Train benign(0): 1606, malignant(1): 444, pos_weight=3.6171, subtype_counts=[33.0, 67.0, 48.0, 47.0, 249.0], subtype_class_weights=[1.6584999561309814, 0.8169000148773193, 1.1402000188827515, 1.1644999980926514, 0.21979999542236328]
# [ResNet50][Fold 4][Epoch 01] sub_w=0.400 | train loss=1.2777(mal=0.7614,sub=1.2908), auc=0.8558, f1=0.6031, recall=0.7342, oracle_f1=0.1439, cascade_acc=0.4257 | val loss=0.7369(mal=0.5949,sub=0.3550), auc=0.9333, f1=0.6753, recall=0.9369, oracle_f1=0.1434, cascade_acc=0.5405
#   -> best saved (val_auc=0.9333): ct_cascade_models/ResNet50_fold4_best.pth
# [ResNet50][Fold 4][Epoch 02] sub_w=0.414 | train loss=1.0290(mal=0.5436,sub=1.1731), auc=0.9282, f1=0.7430, recall=0.8694, oracle_f1=0.1437, cascade_acc=0.5023 | val loss=0.6233(mal=0.4785,sub=0.3500), auc=0.9491, f1=0.7950, recall=0.8559, oracle_f1=0.1434, cascade_acc=0.5225
#   -> best saved (val_auc=0.9491): ct_cascade_models/ResNet50_fold4_best.pth
# [ResNet50][Fold 4][Epoch 03] sub_w=0.428 | train loss=1.0107(mal=0.4824,sub=1.2355), auc=0.9445, f1=0.7380, recall=0.8694, oracle_f1=0.1432, cascade_acc=0.5045 | val loss=0.5584(mal=0.4133,sub=0.3394), auc=0.9617, f1=0.7500, recall=0.9459, oracle_f1=0.1434, cascade_acc=0.5405
#   -> best saved (val_auc=0.9617): ct_cascade_models/ResNet50_fold4_best.pth
# [ResNet50][Fold 4][Epoch 04] sub_w=0.441 | train loss=0.9422(mal=0.4048,sub=1.2177), auc=0.9596, f1=0.7923, recall=0.9234, oracle_f1=0.1502, cascade_acc=0.5270 | val loss=0.5400(mal=0.3656,sub=0.3951), auc=0.9683, f1=0.8033, recall=0.8829, oracle_f1=0.1434, cascade_acc=0.5225
#   -> best saved (val_auc=0.9683): ct_cascade_models/ResNet50_fold4_best.pth
# [ResNet50][Fold 4][Epoch 05] sub_w=0.455 | train loss=0.8960(mal=0.3476,sub=1.2048), auc=0.9687, f1=0.8362, recall=0.9257, oracle_f1=0.1432, cascade_acc=0.5248 | val loss=0.6672(mal=0.5131,sub=0.3384), auc=0.9607, f1=0.8378, recall=0.8378, oracle_f1=0.1434, cascade_acc=0.5135
#   -> no improvement (1/7)
# [ResNet50][Fold 4][Epoch 06] sub_w=0.469 | train loss=0.8640(mal=0.3409,sub=1.1154), auc=0.9709, f1=0.8231, recall=0.9167, oracle_f1=0.1735, cascade_acc=0.5338 | val loss=0.5565(mal=0.3942,sub=0.3460), auc=0.9651, f1=0.8448, recall=0.8829, oracle_f1=0.2150, cascade_acc=0.4144
#   -> no improvement (2/7)
# [ResNet50][Fold 4][Epoch 07] sub_w=0.483 | train loss=0.8261(mal=0.2557,sub=1.1816), auc=0.9825, f1=0.8545, recall=0.9392, oracle_f1=0.2028, cascade_acc=0.5360 | val loss=0.7941(mal=0.6214,sub=0.3577), auc=0.9546, f1=0.6815, recall=0.9640, oracle_f1=0.3198, cascade_acc=0.6126
#   -> no improvement (3/7)
# [ResNet50][Fold 4][Epoch 08] sub_w=0.497 | train loss=0.8200(mal=0.2661,sub=1.1155), auc=0.9824, f1=0.8473, recall=0.9369, oracle_f1=0.2596, cascade_acc=0.5676 | val loss=0.5624(mal=0.3970,sub=0.3331), auc=0.9672, f1=0.8319, recall=0.8919, oracle_f1=0.2881, cascade_acc=0.4685
#   -> no improvement (4/7)
# [ResNet50][Fold 4][Epoch 09] sub_w=0.510 | train loss=0.7939(mal=0.2628,sub=1.0406), auc=0.9813, f1=0.8618, recall=0.9482, oracle_f1=0.3577, cascade_acc=0.5743 | val loss=0.5733(mal=0.3984,sub=0.3425), auc=0.9687, f1=0.7601, recall=0.9279, oracle_f1=0.2680, cascade_acc=0.4865
#   -> no improvement (5/7)
# [ResNet50][Fold 4][Epoch 10] sub_w=0.524 | train loss=0.7833(mal=0.2260,sub=1.0633), auc=0.9867, f1=0.8828, recall=0.9505, oracle_f1=0.3275, cascade_acc=0.5676 | val loss=0.6426(mal=0.4595,sub=0.3493), auc=0.9632, f1=0.8136, recall=0.8649, oracle_f1=0.3340, cascade_acc=0.5495
#   -> no improvement (6/7)
# [ResNet50][Fold 4][Epoch 11] sub_w=0.538 | train loss=0.7394(mal=0.1800,sub=1.0399), auc=0.9908, f1=0.9020, recall=0.9640, oracle_f1=0.3740, cascade_acc=0.5856 | val loss=0.7355(mal=0.5524,sub=0.3404), auc=0.9576, f1=0.8018, recall=0.8198, oracle_f1=0.3616, cascade_acc=0.5135
#   -> no improvement (7/7)
#   -> early stopping triggered at epoch 11
#
# -- Final Evaluation --
# [Malignancy]  AUC=0.9683, F1=0.8033, Recall=0.8829, Acc=0.9062
# [Subtype Oracle]  Acc=0.5586, MacroF1=0.1434
# [Cascade]  SubtypeAcc=0.5225, GateRecall=0.8829
# Binary CM:
# [[366  35]
#  [ 13  98]]
# Subtype Oracle CM:
# [[ 0  0  0  0  9]
#  [ 0  0  0  0 17]
#  [ 0  0  0  0 12]
#  [ 0  0  0  0 11]
#  [ 0  0  0  0 62]]
#
# [ResNet50][Fold 4] Final Metrics
# Malignancy  AUC=0.9683, F1=0.8033, Recall=0.8829
# Subtype Oracle  Acc=0.5586, MacroF1=0.1434
# Cascade  Acc=0.5225, GateRecall=0.8829
#
# ================================================================================
# Running ResNet50 | Fold 5
# ================================================================================
# [FOLD 5] Train benign(0): 1606, malignant(1): 444, pos_weight=3.6171, subtype_counts=[33.0, 68.0, 48.0, 46.0, 249.0], subtype_class_weights=[1.654099941253662, 0.8026999831199646, 1.1371999979019165, 1.1866999864578247, 0.219200000166893]
# [ResNet50][Fold 5][Epoch 01] sub_w=0.400 | train loss=1.3040(mal=0.7889,sub=1.2878), auc=0.8444, f1=0.5864, recall=0.6802, oracle_f1=0.1488, cascade_acc=0.3874 | val loss=0.7026(mal=0.5642,sub=0.3460), auc=0.9188, f1=0.7237, recall=0.8378, oracle_f1=0.1434, cascade_acc=0.5135
#   -> best saved (val_auc=0.9188): ct_cascade_models/ResNet50_fold5_best.pth
# [ResNet50][Fold 5][Epoch 02] sub_w=0.414 | train loss=1.0322(mal=0.5214,sub=1.2345), auc=0.9331, f1=0.7246, recall=0.8829, oracle_f1=0.1436, cascade_acc=0.5045 | val loss=0.6187(mal=0.4759,sub=0.3450), auc=0.9411, f1=0.7433, recall=0.8739, oracle_f1=0.1434, cascade_acc=0.5405
#   -> best saved (val_auc=0.9411): ct_cascade_models/ResNet50_fold5_best.pth
# [ResNet50][Fold 5][Epoch 03] sub_w=0.428 | train loss=0.9966(mal=0.4633,sub=1.2474), auc=0.9481, f1=0.7677, recall=0.8896, oracle_f1=0.1436, cascade_acc=0.5068 | val loss=0.5774(mal=0.4185,sub=0.3715), auc=0.9609, f1=0.7739, recall=0.9099, oracle_f1=0.1434, cascade_acc=0.5495
#   -> best saved (val_auc=0.9609): ct_cascade_models/ResNet50_fold5_best.pth
# [ResNet50][Fold 5][Epoch 04] sub_w=0.441 | train loss=0.9359(mal=0.3932,sub=1.2294), auc=0.9623, f1=0.7976, recall=0.9099, oracle_f1=0.1437, cascade_acc=0.5203 | val loss=0.5634(mal=0.4056,sub=0.3574), auc=0.9644, f1=0.7564, recall=0.9369, oracle_f1=0.1434, cascade_acc=0.5495
#   -> best saved (val_auc=0.9644): ct_cascade_models/ResNet50_fold5_best.pth
# [ResNet50][Fold 5][Epoch 05] sub_w=0.455 | train loss=0.9227(mal=0.3879,sub=1.1749), auc=0.9625, f1=0.7944, recall=0.8964, oracle_f1=0.1598, cascade_acc=0.5158 | val loss=0.5286(mal=0.3724,sub=0.3433), auc=0.9652, f1=0.7938, recall=0.9189, oracle_f1=0.1434, cascade_acc=0.5495
#   -> no improvement (1/7)
# [ResNet50][Fold 5][Epoch 06] sub_w=0.469 | train loss=0.8355(mal=0.2971,sub=1.1481), auc=0.9782, f1=0.8369, recall=0.9302, oracle_f1=0.2038, cascade_acc=0.5428 | val loss=0.5924(mal=0.4299,sub=0.3465), auc=0.9633, f1=0.7664, recall=0.9459, oracle_f1=0.1802, cascade_acc=0.5045
#   -> no improvement (2/7)
# [ResNet50][Fold 5][Epoch 07] sub_w=0.483 | train loss=0.8095(mal=0.2604,sub=1.1376), auc=0.9827, f1=0.8707, recall=0.9482, oracle_f1=0.2841, cascade_acc=0.5743 | val loss=0.6661(mal=0.5052,sub=0.3333), auc=0.9534, f1=0.7119, recall=0.9459, oracle_f1=0.2750, cascade_acc=0.4685
#   -> no improvement (3/7)
# [ResNet50][Fold 5][Epoch 08] sub_w=0.497 | train loss=0.7869(mal=0.2622,sub=1.0566), auc=0.9826, f1=0.8586, recall=0.9302, oracle_f1=0.3050, cascade_acc=0.5856 | val loss=0.6129(mal=0.4413,sub=0.3456), auc=0.9633, f1=0.7526, recall=0.9730, oracle_f1=0.2747, cascade_acc=0.5045
#   -> no improvement (4/7)
# [ResNet50][Fold 5][Epoch 09] sub_w=0.510 | train loss=0.8156(mal=0.2626,sub=1.0835), auc=0.9823, f1=0.8437, recall=0.9482, oracle_f1=0.3507, cascade_acc=0.5698 | val loss=0.6318(mal=0.4410,sub=0.3738), auc=0.9597, f1=0.8000, recall=0.8829, oracle_f1=0.2725, cascade_acc=0.5045
#   -> no improvement (5/7)
# [ResNet50][Fold 5][Epoch 10] sub_w=0.524 | train loss=0.7059(mal=0.1880,sub=0.9882), auc=0.9909, f1=0.8847, recall=0.9595, oracle_f1=0.3713, cascade_acc=0.6149 | val loss=0.7749(mal=0.5434,sub=0.4416), auc=0.9525, f1=0.7574, recall=0.9279, oracle_f1=0.2645, cascade_acc=0.4865
#   -> no improvement (6/7)
# [ResNet50][Fold 5][Epoch 11] sub_w=0.538 | train loss=0.7374(mal=0.2080,sub=0.9841), auc=0.9882, f1=0.8894, recall=0.9595, oracle_f1=0.3653, cascade_acc=0.5946 | val loss=0.6432(mal=0.4405,sub=0.3767), auc=0.9631, f1=0.7951, recall=0.8739, oracle_f1=0.2656, cascade_acc=0.4685
#   -> no improvement (7/7)
#   -> early stopping triggered at epoch 11
#
# -- Final Evaluation --
# [Malignancy]  AUC=0.9644, F1=0.7564, Recall=0.9369, Acc=0.8691
# [Subtype Oracle]  Acc=0.5586, MacroF1=0.1434
# [Cascade]  SubtypeAcc=0.5495, GateRecall=0.9369
# Binary CM:
# [[341  60]
#  [  7 104]]
# Subtype Oracle CM:
# [[ 0  0  0  0  9]
#  [ 0  0  0  0 16]
#  [ 0  0  0  0 12]
#  [ 0  0  0  0 12]
#  [ 0  0  0  0 62]]
#
# [ResNet50][Fold 5] Final Metrics
# Malignancy  AUC=0.9644, F1=0.7564, Recall=0.9369
# Subtype Oracle  Acc=0.5586, MacroF1=0.1434
# Cascade  Acc=0.5495, GateRecall=0.9369
#       model  fold   mal_acc   mal_auc    mal_f1  mal_recall  \
# 0  ResNet50     1  0.955166  0.988526  0.890995    0.846847
# 1  ResNet50     2  0.920078  0.962821  0.812785    0.801802
# 2  ResNet50     3  0.900391  0.972760  0.801556    0.927928
# 3  ResNet50     4  0.906250  0.968255  0.803279    0.882883
# 4  ResNet50     5  0.869141  0.964402  0.756364    0.936937
#
#    subtype_oracle_acc  subtype_oracle_macro_f1  subtype_cascade_acc  \
# 0            0.585586                 0.381957             0.513514
# 1            0.549550                 0.344004             0.486486
# 2            0.522523                 0.256868             0.504505
# 3            0.558559                 0.143353             0.522523
# 4            0.558559                 0.143353             0.549550
#
#    subtype_gate_recall              binary_cm  \
# 0             0.846847   [[396, 6], [17, 94]]
# 1             0.801802  [[383, 19], [22, 89]]
# 2             0.927928  [[358, 43], [8, 103]]
# 3             0.882883  [[366, 35], [13, 98]]
# 4             0.936937  [[341, 60], [7, 104]]
#
#                                    subtype_oracle_cm
# 0  [[0, 1, 1, 0, 6], [0, 7, 3, 1, 6], [0, 0, 5, 1...
# 1  [[0, 0, 2, 1, 5], [0, 4, 3, 1, 9], [0, 0, 5, 0...
# 2  [[0, 1, 1, 0, 6], [0, 3, 2, 1, 11], [2, 0, 3, ...
# 3  [[0, 0, 0, 0, 9], [0, 0, 0, 0, 17], [0, 0, 0, ...
# 4  [[0, 0, 0, 0, 9], [0, 0, 0, 0, 16], [0, 0, 0, ...
# >>> Training ViT-B/16...
#
# ================================================================================
# Running ViT-B16 | Fold 1
# ================================================================================
# [FOLD 1] Train benign(0): 1605, malignant(1): 444, pos_weight=3.6149, subtype_counts=[34.0, 67.0, 48.0, 46.0, 249.0], subtype_class_weights=[1.617400050163269, 0.8206999897956848, 1.1455999612808228, 1.1953999996185303, 0.2207999974489212]
# [ViT-B16][Fold 1][Epoch 01] sub_w=0.400 | train loss=1.4466(mal=0.9371,sub=1.2738), auc=0.7403, f1=0.4815, recall=0.6892, oracle_f1=0.1517, cascade_acc=0.3851 | val loss=1.1155(mal=0.9665,sub=0.3725), auc=0.8525, f1=0.4337, recall=0.3243, oracle_f1=0.1434, cascade_acc=0.1982
#   -> best saved (val_auc=0.8525): ct_cascade_models/ViT-B16_fold1_best.pth
# [ViT-B16][Fold 1][Epoch 02] sub_w=0.414 | train loss=1.3420(mal=0.8279,sub=1.2423), auc=0.8115, f1=0.5532, recall=0.8018, oracle_f1=0.1437, cascade_acc=0.4662 | val loss=0.8365(mal=0.6851,sub=0.3659), auc=0.9284, f1=0.6861, recall=0.8468, oracle_f1=0.1434, cascade_acc=0.4505
#   -> best saved (val_auc=0.9284): ct_cascade_models/ViT-B16_fold1_best.pth
# [ViT-B16][Fold 1][Epoch 03] sub_w=0.428 | train loss=1.3097(mal=0.7721,sub=1.2573), auc=0.8405, f1=0.5814, recall=0.7883, oracle_f1=0.1437, cascade_acc=0.4505 | val loss=0.7010(mal=0.5501,sub=0.3529), auc=0.9340, f1=0.7218, recall=0.8649, oracle_f1=0.1434, cascade_acc=0.4865
#   -> best saved (val_auc=0.9340): ct_cascade_models/ViT-B16_fold1_best.pth
# [ViT-B16][Fold 1][Epoch 04] sub_w=0.441 | train loss=1.2741(mal=0.7190,sub=1.2577), auc=0.8663, f1=0.6151, recall=0.8153, oracle_f1=0.1437, cascade_acc=0.4662 | val loss=0.7841(mal=0.6037,sub=0.4086), auc=0.9469, f1=0.6334, recall=0.9730, oracle_f1=0.1434, cascade_acc=0.5405
#   -> best saved (val_auc=0.9469): ct_cascade_models/ViT-B16_fold1_best.pth
# [ViT-B16][Fold 1][Epoch 05] sub_w=0.455 | train loss=1.2205(mal=0.6448,sub=1.2648), auc=0.8934, f1=0.6702, recall=0.8491, oracle_f1=0.1437, cascade_acc=0.4955 | val loss=0.7620(mal=0.5929,sub=0.3715), auc=0.9333, f1=0.7249, recall=0.7477, oracle_f1=0.1434, cascade_acc=0.4234
#   -> no improvement (1/7)
# [ViT-B16][Fold 1][Epoch 06] sub_w=0.469 | train loss=1.2086(mal=0.6183,sub=1.2587), auc=0.9026, f1=0.6709, recall=0.8333, oracle_f1=0.1437, cascade_acc=0.4775 | val loss=0.7462(mal=0.5829,sub=0.3482), auc=0.9474, f1=0.7650, recall=0.7477, oracle_f1=0.2022, cascade_acc=0.4414
#   -> no improvement (2/7)
# [ViT-B16][Fold 1][Epoch 07] sub_w=0.483 | train loss=1.1921(mal=0.5866,sub=1.2541), auc=0.9121, f1=0.6957, recall=0.8468, oracle_f1=0.1738, cascade_acc=0.4887 | val loss=0.6901(mal=0.4983,sub=0.3973), auc=0.9421, f1=0.7510, recall=0.8829, oracle_f1=0.1434, cascade_acc=0.5045
#   -> no improvement (3/7)
# [ViT-B16][Fold 1][Epoch 08] sub_w=0.497 | train loss=1.1728(mal=0.5416,sub=1.2711), auc=0.9260, f1=0.7080, recall=0.8491, oracle_f1=0.1933, cascade_acc=0.5090 | val loss=0.6662(mal=0.4715,sub=0.3922), auc=0.9498, f1=0.7232, recall=0.8829, oracle_f1=0.1419, cascade_acc=0.4865
#   -> best saved (val_auc=0.9498): ct_cascade_models/ViT-B16_fold1_best.pth
# [ViT-B16][Fold 1][Epoch 09] sub_w=0.510 | train loss=1.1856(mal=0.5570,sub=1.2318), auc=0.9221, f1=0.6960, recall=0.8559, oracle_f1=0.1766, cascade_acc=0.4842 | val loss=0.7118(mal=0.5351,sub=0.3462), auc=0.9618, f1=0.6545, recall=0.9730, oracle_f1=0.1905, cascade_acc=0.4685
#   -> best saved (val_auc=0.9618): ct_cascade_models/ViT-B16_fold1_best.pth
# [ViT-B16][Fold 1][Epoch 10] sub_w=0.524 | train loss=1.1682(mal=0.5307,sub=1.2163), auc=0.9268, f1=0.7464, recall=0.8716, oracle_f1=0.2153, cascade_acc=0.5090 | val loss=0.6834(mal=0.5005,sub=0.3491), auc=0.9540, f1=0.7822, recall=0.7928, oracle_f1=0.1818, cascade_acc=0.4505
#   -> no improvement (1/7)
# [ViT-B16][Fold 1][Epoch 11] sub_w=0.538 | train loss=1.1647(mal=0.5042,sub=1.2280), auc=0.9354, f1=0.7362, recall=0.8829, oracle_f1=0.2076, cascade_acc=0.4955 | val loss=0.6449(mal=0.4407,sub=0.3797), auc=0.9568, f1=0.7544, recall=0.9550, oracle_f1=0.1992, cascade_acc=0.5405
#   -> no improvement (2/7)
# [ViT-B16][Fold 1][Epoch 12] sub_w=0.552 | train loss=1.1885(mal=0.5225,sub=1.2071), auc=0.9311, f1=0.7222, recall=0.8694, oracle_f1=0.2137, cascade_acc=0.4977 | val loss=0.7508(mal=0.5444,sub=0.3741), auc=0.9588, f1=0.6770, recall=0.9820, oracle_f1=0.1678, cascade_acc=0.5495
#   -> no improvement (3/7)
# [ViT-B16][Fold 1][Epoch 13] sub_w=0.566 | train loss=1.1709(mal=0.4869,sub=1.2096), auc=0.9403, f1=0.7411, recall=0.8671, oracle_f1=0.2174, cascade_acc=0.5068 | val loss=0.5885(mal=0.3877,sub=0.3552), auc=0.9630, f1=0.8065, recall=0.9009, oracle_f1=0.1855, cascade_acc=0.5135
#   -> best saved (val_auc=0.9630): ct_cascade_models/ViT-B16_fold1_best.pth
# [ViT-B16][Fold 1][Epoch 14] sub_w=0.579 | train loss=1.2436(mal=0.5301,sub=1.2317), auc=0.9294, f1=0.7276, recall=0.8694, oracle_f1=0.2418, cascade_acc=0.5135 | val loss=0.7574(mal=0.5581,sub=0.3442), auc=0.9482, f1=0.7109, recall=0.6757, oracle_f1=0.1966, cascade_acc=0.4144
#   -> no improvement (1/7)
# [ViT-B16][Fold 1][Epoch 15] sub_w=0.593 | train loss=1.1964(mal=0.4618,sub=1.2386), auc=0.9461, f1=0.7643, recall=0.8874, oracle_f1=0.2163, cascade_acc=0.5158 | val loss=0.6099(mal=0.3953,sub=0.3618), auc=0.9645, f1=0.7918, recall=0.8739, oracle_f1=0.2202, cascade_acc=0.5225
#   -> best saved (val_auc=0.9645): ct_cascade_models/ViT-B16_fold1_best.pth
# [ViT-B16][Fold 1][Epoch 16] sub_w=0.607 | train loss=1.2213(mal=0.4811,sub=1.2197), auc=0.9419, f1=0.7531, recall=0.8761, oracle_f1=0.2234, cascade_acc=0.5090 | val loss=0.6411(mal=0.4297,sub=0.3483), auc=0.9566, f1=0.7920, recall=0.8919, oracle_f1=0.1992, cascade_acc=0.5225
#   -> no improvement (1/7)
# [ViT-B16][Fold 1][Epoch 17] sub_w=0.621 | train loss=1.2032(mal=0.4440,sub=1.2233), auc=0.9505, f1=0.7635, recall=0.8941, oracle_f1=0.2007, cascade_acc=0.5180 | val loss=0.6504(mal=0.4360,sub=0.3454), auc=0.9544, f1=0.7372, recall=0.9099, oracle_f1=0.2579, cascade_acc=0.5045
#   -> no improvement (2/7)
# [ViT-B16][Fold 1][Epoch 18] sub_w=0.634 | train loss=1.1768(mal=0.4379,sub=1.1645), auc=0.9490, f1=0.7933, recall=0.9077, oracle_f1=0.2324, cascade_acc=0.5315 | val loss=0.7009(mal=0.4829,sub=0.3436), auc=0.9664, f1=0.8037, recall=0.7748, oracle_f1=0.2009, cascade_acc=0.3063
#   -> best saved (val_auc=0.9664): ct_cascade_models/ViT-B16_fold1_best.pth
# [ViT-B16][Fold 1][Epoch 19] sub_w=0.648 | train loss=1.1860(mal=0.4431,sub=1.1460), auc=0.9516, f1=0.7614, recall=0.8874, oracle_f1=0.2524, cascade_acc=0.5068 | val loss=0.8820(mal=0.6563,sub=0.3482), auc=0.9478, f1=0.7245, recall=0.6396, oracle_f1=0.2672, cascade_acc=0.3784
#   -> no improvement (1/7)
# [ViT-B16][Fold 1][Epoch 20] sub_w=0.662 | train loss=1.1996(mal=0.4500,sub=1.1322), auc=0.9489, f1=0.7716, recall=0.9054, oracle_f1=0.2580, cascade_acc=0.5315 | val loss=0.6914(mal=0.4431,sub=0.3751), auc=0.9656, f1=0.7926, recall=0.7748, oracle_f1=0.2001, cascade_acc=0.4775
#   -> no improvement (2/7)
# [ViT-B16][Fold 1][Epoch 21] sub_w=0.676 | train loss=1.1913(mal=0.4093,sub=1.1570), auc=0.9565, f1=0.7849, recall=0.9122, oracle_f1=0.2609, cascade_acc=0.5338 | val loss=0.7295(mal=0.4977,sub=0.3429), auc=0.9412, f1=0.7273, recall=0.8649, oracle_f1=0.2061, cascade_acc=0.4865
#   -> no improvement (3/7)
# [ViT-B16][Fold 1][Epoch 22] sub_w=0.690 | train loss=1.2074(mal=0.4067,sub=1.1610), auc=0.9588, f1=0.7770, recall=0.9144, oracle_f1=0.2679, cascade_acc=0.5293 | val loss=0.6416(mal=0.3764,sub=0.3845), auc=0.9653, f1=0.7709, recall=0.9550, oracle_f1=0.2224, cascade_acc=0.5586
#   -> no improvement (4/7)
# [ViT-B16][Fold 1][Epoch 23] sub_w=0.703 | train loss=1.1888(mal=0.4156,sub=1.0991), auc=0.9569, f1=0.7743, recall=0.9077, oracle_f1=0.2712, cascade_acc=0.5113 | val loss=0.6632(mal=0.4244,sub=0.3396), auc=0.9594, f1=0.7589, recall=0.8649, oracle_f1=0.3144, cascade_acc=0.4685
#   -> no improvement (5/7)
# [ViT-B16][Fold 1][Epoch 24] sub_w=0.717 | train loss=1.2401(mal=0.3974,sub=1.1748), auc=0.9608, f1=0.7858, recall=0.8964, oracle_f1=0.2862, cascade_acc=0.5428 | val loss=0.7016(mal=0.4580,sub=0.3397), auc=0.9593, f1=0.8378, recall=0.8378, oracle_f1=0.2915, cascade_acc=0.4865
#   -> no improvement (6/7)
# [ViT-B16][Fold 1][Epoch 25] sub_w=0.731 | train loss=1.2342(mal=0.3917,sub=1.1524), auc=0.9612, f1=0.7892, recall=0.9234, oracle_f1=0.3127, cascade_acc=0.5248 | val loss=0.9041(mal=0.6382,sub=0.3638), auc=0.9564, f1=0.7411, recall=0.6577, oracle_f1=0.2745, cascade_acc=0.4144
#   -> no improvement (7/7)
#   -> early stopping triggered at epoch 25
#
# -- Final Evaluation --
# [Malignancy]  AUC=0.9664, F1=0.8037, Recall=0.7748, Acc=0.9181
# [Subtype Oracle]  Acc=0.3784, MacroF1=0.2009
# [Cascade]  SubtypeAcc=0.3063, GateRecall=0.7748
# Binary CM:
# [[385  17]
#  [ 25  86]]
# Subtype Oracle CM:
# [[ 0  0  1  7  0]
#  [ 0  0  0 14  3]
#  [ 0  0  1  8  3]
#  [ 0  0  0 11  1]
#  [ 0  0  1 31 30]]
#
# [ViT-B16][Fold 1] Final Metrics
# Malignancy  AUC=0.9664, F1=0.8037, Recall=0.7748
# Subtype Oracle  Acc=0.3784, MacroF1=0.2009
# Cascade  Acc=0.3063, GateRecall=0.7748
#
# ================================================================================
# Running ViT-B16 | Fold 2
# ================================================================================
# [FOLD 2] Train benign(0): 1605, malignant(1): 444, pos_weight=3.6149, subtype_counts=[34.0, 67.0, 48.0, 46.0, 249.0], subtype_class_weights=[1.617400050163269, 0.8206999897956848, 1.1455999612808228, 1.1953999996185303, 0.2207999974489212]
# [ViT-B16][Fold 2][Epoch 01] sub_w=0.400 | train loss=1.5997(mal=1.0814,sub=1.2958), auc=0.5605, f1=0.3481, recall=0.5743, oracle_f1=0.1486, cascade_acc=0.2995 | val loss=1.2384(mal=1.0846,sub=0.3845), auc=0.7962, f1=0.3558, recall=1.0000, oracle_f1=0.1434, cascade_acc=0.5586
#   -> best saved (val_auc=0.7962): ct_cascade_models/ViT-B16_fold2_best.pth
# [ViT-B16][Fold 2][Epoch 02] sub_w=0.414 | train loss=1.6103(mal=1.0838,sub=1.2725), auc=0.5361, f1=0.3296, recall=0.5653, oracle_f1=0.1437, cascade_acc=0.3086 | val loss=1.2376(mal=1.0876,sub=0.3625), auc=0.6071, f1=0.3558, recall=1.0000, oracle_f1=0.1434, cascade_acc=0.5586
#   -> no improvement (1/7)
# [ViT-B16][Fold 2][Epoch 03] sub_w=0.428 | train loss=1.6419(mal=1.0902,sub=1.2902), auc=0.4950, f1=0.3182, recall=0.5608, oracle_f1=0.1437, cascade_acc=0.3176 | val loss=1.2420(mal=1.0844,sub=0.3685), auc=0.6323, f1=0.3558, recall=1.0000, oracle_f1=0.1434, cascade_acc=0.5586
#   -> no improvement (2/7)
# [ViT-B16][Fold 2][Epoch 04] sub_w=0.441 | train loss=1.6529(mal=1.0850,sub=1.2866), auc=0.5284, f1=0.3293, recall=0.5518, oracle_f1=0.1437, cascade_acc=0.3176 | val loss=1.2571(mal=1.0858,sub=0.3883), auc=0.6267, f1=0.3558, recall=1.0000, oracle_f1=0.1434, cascade_acc=0.5586
#   -> no improvement (3/7)
# [ViT-B16][Fold 2][Epoch 05] sub_w=0.455 | train loss=1.6687(mal=1.0858,sub=1.2806), auc=0.5175, f1=0.3272, recall=0.5811, oracle_f1=0.1437, cascade_acc=0.3131 | val loss=1.2592(mal=1.0827,sub=0.3879), auc=0.6291, f1=0.0000, recall=0.0000, oracle_f1=0.1434, cascade_acc=0.0000
#   -> no improvement (4/7)
# [ViT-B16][Fold 2][Epoch 06] sub_w=0.469 | train loss=1.6511(mal=1.0849,sub=1.2073), auc=0.5270, f1=0.3121, recall=0.5023, oracle_f1=0.1437, cascade_acc=0.2860 | val loss=1.2304(mal=1.0565,sub=0.3708), auc=0.6354, f1=0.4172, recall=0.9640, oracle_f1=0.1434, cascade_acc=0.5315
#   -> no improvement (5/7)
# [ViT-B16][Fold 2][Epoch 07] sub_w=0.483 | train loss=1.7093(mal=1.0861,sub=1.2908), auc=0.5240, f1=0.3371, recall=0.6104, oracle_f1=0.1437, cascade_acc=0.3536 | val loss=1.2584(mal=1.0791,sub=0.3714), auc=0.6312, f1=0.4374, recall=0.8649, oracle_f1=0.1434, cascade_acc=0.4865
#   -> no improvement (6/7)
# [ViT-B16][Fold 2][Epoch 08] sub_w=0.497 | train loss=1.7040(mal=1.0654,sub=1.2861), auc=0.6010, f1=0.3771, recall=0.5856, oracle_f1=0.1437, cascade_acc=0.3311 | val loss=1.2453(mal=1.0638,sub=0.3657), auc=0.6004, f1=0.3676, recall=0.6126, oracle_f1=0.1434, cascade_acc=0.3604
#   -> no improvement (7/7)
#   -> early stopping triggered at epoch 8
#
# -- Final Evaluation --
# [Malignancy]  AUC=0.7962, F1=0.3558, Recall=1.0000, Acc=0.2164
# [Subtype Oracle]  Acc=0.5586, MacroF1=0.1434
# [Cascade]  SubtypeAcc=0.5586, GateRecall=1.0000
# Binary CM:
# [[  0 402]
#  [  0 111]]
# Subtype Oracle CM:
# [[ 0  0  0  0  8]
#  [ 0  0  0  0 17]
#  [ 0  0  0  0 12]
#  [ 0  0  0  0 12]
#  [ 0  0  0  0 62]]
#
# [ViT-B16][Fold 2] Final Metrics
# Malignancy  AUC=0.7962, F1=0.3558, Recall=1.0000
# Subtype Oracle  Acc=0.5586, MacroF1=0.1434
# Cascade  Acc=0.5586, GateRecall=1.0000
#
# ================================================================================
# Running ViT-B16 | Fold 3
# ================================================================================
# [FOLD 3] Train benign(0): 1606, malignant(1): 444, pos_weight=3.6171, subtype_counts=[34.0, 67.0, 48.0, 47.0, 248.0], subtype_class_weights=[1.6253000497817993, 0.8248000144958496, 1.1512999534606934, 1.1757999658584595, 0.22280000150203705]
# [ViT-B16][Fold 3][Epoch 01] sub_w=0.400 | train loss=1.6224(mal=1.0954,sub=1.3176), auc=0.4833, f1=0.2919, recall=0.5135, oracle_f1=0.1417, cascade_acc=0.2590 | val loss=1.2267(mal=1.0859,sub=0.3522), auc=0.7035, f1=0.3563, recall=1.0000, oracle_f1=0.1448, cascade_acc=0.5676
#   -> best saved (val_auc=0.7035): ct_cascade_models/ViT-B16_fold3_best.pth
# [ViT-B16][Fold 3][Epoch 02] sub_w=0.414 | train loss=1.6224(mal=1.0927,sub=1.2803), auc=0.4811, f1=0.2953, recall=0.5135, oracle_f1=0.1434, cascade_acc=0.2883 | val loss=1.2509(mal=1.0995,sub=0.3660), auc=0.6744, f1=0.0000, recall=0.0000, oracle_f1=0.1448, cascade_acc=0.0000
#   -> no improvement (1/7)
# [ViT-B16][Fold 3][Epoch 03] sub_w=0.428 | train loss=1.6373(mal=1.0933,sub=1.2722), auc=0.4611, f1=0.3088, recall=0.6374, oracle_f1=0.1430, cascade_acc=0.3514 | val loss=1.2489(mal=1.0863,sub=0.3802), auc=0.5773, f1=0.3563, recall=1.0000, oracle_f1=0.1448, cascade_acc=0.5676
#   -> no improvement (2/7)
# [ViT-B16][Fold 3][Epoch 04] sub_w=0.441 | train loss=1.6446(mal=1.0907,sub=1.2549), auc=0.4586, f1=0.2365, recall=0.3356, oracle_f1=0.1434, cascade_acc=0.2005 | val loss=1.2535(mal=1.0867,sub=0.3778), auc=0.5112, f1=0.3563, recall=1.0000, oracle_f1=0.1448, cascade_acc=0.5676
#   -> no improvement (3/7)
# [ViT-B16][Fold 3][Epoch 05] sub_w=0.455 | train loss=1.6620(mal=1.0891,sub=1.2585), auc=0.4897, f1=0.3153, recall=0.5856, oracle_f1=0.1434, cascade_acc=0.3266 | val loss=1.2513(mal=1.0873,sub=0.3604), auc=0.6474, f1=0.0000, recall=0.0000, oracle_f1=0.1448, cascade_acc=0.0000
#   -> no improvement (4/7)
# [ViT-B16][Fold 3][Epoch 06] sub_w=0.469 | train loss=1.6750(mal=1.0890,sub=1.2494), auc=0.5014, f1=0.3136, recall=0.5383, oracle_f1=0.1434, cascade_acc=0.2883 | val loss=1.2708(mal=1.0880,sub=0.3898), auc=0.6786, f1=0.0000, recall=0.0000, oracle_f1=0.1448, cascade_acc=0.0000
#   -> no improvement (5/7)
# [ViT-B16][Fold 3][Epoch 07] sub_w=0.483 | train loss=1.7164(mal=1.0895,sub=1.2987), auc=0.4802, f1=0.2895, recall=0.4685, oracle_f1=0.1434, cascade_acc=0.2703 | val loss=1.2656(mal=1.0862,sub=0.3716), auc=0.6608, f1=0.3563, recall=1.0000, oracle_f1=0.1448, cascade_acc=0.5676
#   -> no improvement (6/7)
# [ViT-B16][Fold 3][Epoch 08] sub_w=0.497 | train loss=1.7308(mal=1.0895,sub=1.2915), auc=0.4910, f1=0.3189, recall=0.5901, oracle_f1=0.1434, cascade_acc=0.3356 | val loss=1.2752(mal=1.0921,sub=0.3686), auc=0.5472, f1=0.3563, recall=1.0000, oracle_f1=0.1448, cascade_acc=0.5676
#   -> no improvement (7/7)
#   -> early stopping triggered at epoch 8
#
# -- Final Evaluation --
# [Malignancy]  AUC=0.7035, F1=0.3563, Recall=1.0000, Acc=0.2168
# [Subtype Oracle]  Acc=0.5676, MacroF1=0.1448
# [Cascade]  SubtypeAcc=0.5676, GateRecall=1.0000
# Binary CM:
# [[  0 401]
#  [  0 111]]
# Subtype Oracle CM:
# [[ 0  0  0  0  8]
#  [ 0  0  0  0 17]
#  [ 0  0  0  0 12]
#  [ 0  0  0  0 11]
#  [ 0  0  0  0 63]]
#
# [ViT-B16][Fold 3] Final Metrics
# Malignancy  AUC=0.7035, F1=0.3563, Recall=1.0000
# Subtype Oracle  Acc=0.5676, MacroF1=0.1448
# Cascade  Acc=0.5676, GateRecall=1.0000
#
# ...
#   -> no improvement (6/7)
# [Hybrid][Fold 3][Epoch 20] sub_w=0.662 | train loss=0.4174(mal=0.0805,sub=0.5090), auc=0.9979, f1=0.9492, recall=0.9887, oracle_f1=0.7157, cascade_acc=0.7860 | val loss=0.9529(mal=0.5855,sub=0.5549), auc=0.9753, f1=0.8333, recall=0.9009, oracle_f1=0.2750, cascade_acc=0.4234
#   -> no improvement (7/7)
#   -> early stopping triggered at epoch 20
#
# -- Final Evaluation --
# [Malignancy]  AUC=0.9757, F1=0.8267, Recall=0.8378, Acc=0.9238
# [Subtype Oracle]  Acc=0.5135, MacroF1=0.3120
# [Cascade]  SubtypeAcc=0.4414, GateRecall=0.8378
# Binary CM:
# [[380  21]
#  [ 18  93]]
# Subtype Oracle CM:
# [[ 1  0  0  0  7]
#  [ 0  6  1  0 10]
#  [ 3  1  3  1  4]
#  [ 0  4  2  1  4]
#  [ 4  4  7  2 46]]
#
# [Hybrid][Fold 3] Final Metrics
# Malignancy  AUC=0.9757, F1=0.8267, Recall=0.8378
# Subtype Oracle  Acc=0.5135, MacroF1=0.3120
# Cascade  Acc=0.4414, GateRecall=0.8378
#
# ================================================================================
# Running Hybrid | Fold 4
# ================================================================================
# [FOLD 4] Train benign(0): 1606, malignant(1): 444, pos_weight=3.6171, subtype_counts=[33.0, 67.0, 48.0, 47.0, 249.0], subtype_class_weights=[1.6584999561309814, 0.8169000148773193, 1.1402000188827515, 1.1644999980926514, 0.21979999542236328]
# [Hybrid][Fold 4][Epoch 01] sub_w=0.400 | train loss=1.2724(mal=0.7538,sub=1.2964), auc=0.8504, f1=0.6190, recall=0.7117, oracle_f1=0.1668, cascade_acc=0.3896 | val loss=0.6434(mal=0.5018,sub=0.3540), auc=0.9467, f1=0.7686, recall=0.8378, oracle_f1=0.1434, cascade_acc=0.5045
#   -> best saved (val_auc=0.9467): ct_cascade_models/Hybrid_fold4_best.pth
# [Hybrid][Fold 4][Epoch 02] sub_w=0.414 | train loss=1.0074(mal=0.4803,sub=1.2739), auc=0.9402, f1=0.7657, recall=0.8941, oracle_f1=0.1594, cascade_acc=0.5000 | val loss=0.5958(mal=0.4521,sub=0.3471), auc=0.9529, f1=0.8230, recall=0.8378, oracle_f1=0.1442, cascade_acc=0.5135
#   -> best saved (val_auc=0.9529): ct_cascade_models/Hybrid_fold4_best.pth
# [Hybrid][Fold 4][Epoch 03] sub_w=0.428 | train loss=0.9828(mal=0.4403,sub=1.2688), auc=0.9502, f1=0.7806, recall=0.8896, oracle_f1=0.1945, cascade_acc=0.5000 | val loss=0.6788(mal=0.5328,sub=0.3417), auc=0.9542, f1=0.6563, recall=0.9550, oracle_f1=0.1967, cascade_acc=0.5676
#   -> best saved (val_auc=0.9542): ct_cascade_models/Hybrid_fold4_best.pth
# [Hybrid][Fold 4][Epoch 04] sub_w=0.441 | train loss=0.9348(mal=0.3806,sub=1.2555), auc=0.9614, f1=0.7901, recall=0.9324, oracle_f1=0.1917, cascade_acc=0.5315 | val loss=0.5630(mal=0.4055,sub=0.3567), auc=0.9632, f1=0.7464, recall=0.9279, oracle_f1=0.2224, cascade_acc=0.5495
#   -> best saved (val_auc=0.9632): ct_cascade_models/Hybrid_fold4_best.pth
# [Hybrid][Fold 4][Epoch 05] sub_w=0.455 | train loss=0.8486(mal=0.2721,sub=1.2666), auc=0.9795, f1=0.8451, recall=0.9459, oracle_f1=0.1795, cascade_acc=0.5113 | val loss=0.5805(mal=0.4244,sub=0.3430), auc=0.9701, f1=0.8286, recall=0.7838, oracle_f1=0.1678, cascade_acc=0.4144
#   -> best saved (val_auc=0.9701): ct_cascade_models/Hybrid_fold4_best.pth
# [Hybrid][Fold 4][Epoch 06] sub_w=0.469 | train loss=0.9131(mal=0.3423,sub=1.2171), auc=0.9673, f1=0.8310, recall=0.9302, oracle_f1=0.2514, cascade_acc=0.5495 | val loss=0.6701(mal=0.5116,sub=0.3380), auc=0.9645, f1=0.7864, recall=0.7297, oracle_f1=0.2242, cascade_acc=0.4505
#   -> no improvement (1/7)
# [Hybrid][Fold 4][Epoch 07] sub_w=0.483 | train loss=0.7767(mal=0.2394,sub=1.1130), auc=0.9836, f1=0.8849, recall=0.9527, oracle_f1=0.3028, cascade_acc=0.5495 | val loss=0.6231(mal=0.4482,sub=0.3622), auc=0.9724, f1=0.8282, recall=0.8468, oracle_f1=0.3188, cascade_acc=0.5045
#   -> best saved (val_auc=0.9724): ct_cascade_models/Hybrid_fold4_best.pth
# [Hybrid][Fold 4][Epoch 08] sub_w=0.497 | train loss=0.7872(mal=0.2156,sub=1.1511), auc=0.9865, f1=0.8870, recall=0.9459, oracle_f1=0.3072, cascade_acc=0.5428 | val loss=0.6045(mal=0.4351,sub=0.3412), auc=0.9740, f1=0.8110, recall=0.9279, oracle_f1=0.2507, cascade_acc=0.4955
#   -> best saved (val_auc=0.9740): ct_cascade_models/Hybrid_fold4_best.pth
# [Hybrid][Fold 4][Epoch 09] sub_w=0.510 | train loss=0.7582(mal=0.2234,sub=1.0479), auc=0.9869, f1=0.8820, recall=0.9595, oracle_f1=0.2986, cascade_acc=0.5586 | val loss=0.8803(mal=0.7015,sub=0.3504), auc=0.9684, f1=0.8061, recall=0.7117, oracle_f1=0.3299, cascade_acc=0.4324
#   -> no improvement (1/7)
# [Hybrid][Fold 4][Epoch 10] sub_w=0.524 | train loss=0.7780(mal=0.1976,sub=1.1072), auc=0.9888, f1=0.9073, recall=0.9595, oracle_f1=0.3059, cascade_acc=0.5473 | val loss=0.6353(mal=0.4037,sub=0.4419), auc=0.9661, f1=0.7556, recall=0.9189, oracle_f1=0.3172, cascade_acc=0.5766
#   -> no improvement (2/7)
# [Hybrid][Fold 4][Epoch 11] sub_w=0.538 | train loss=0.7316(mal=0.1670,sub=1.0496), auc=0.9908, f1=0.9106, recall=0.9640, oracle_f1=0.3321, cascade_acc=0.5923 | val loss=0.7605(mal=0.5751,sub=0.3445), auc=0.9612, f1=0.8000, recall=0.8468, oracle_f1=0.4079, cascade_acc=0.4955
#   -> no improvement (3/7)
# [Hybrid][Fold 4][Epoch 12] sub_w=0.552 | train loss=0.7566(mal=0.1845,sub=1.0370), auc=0.9886, f1=0.9204, recall=0.9640, oracle_f1=0.3930, cascade_acc=0.5991 | val loss=0.6230(mal=0.4279,sub=0.3537), auc=0.9669, f1=0.8182, recall=0.8919, oracle_f1=0.1286, cascade_acc=0.1622
#   -> no improvement (4/7)
# [Hybrid][Fold 4][Epoch 13] sub_w=0.566 | train loss=0.7300(mal=0.1701,sub=0.9899), auc=0.9918, f1=0.9161, recall=0.9595, oracle_f1=0.3717, cascade_acc=0.5788 | val loss=0.7180(mal=0.5125,sub=0.3634), auc=0.9744, f1=0.8444, recall=0.8559, oracle_f1=0.3210, cascade_acc=0.5315
#   -> no improvement (5/7)
# [Hybrid][Fold 4][Epoch 14] sub_w=0.579 | train loss=0.7221(mal=0.1315,sub=1.0194), auc=0.9957, f1=0.9242, recall=0.9752, oracle_f1=0.4383, cascade_acc=0.6396 | val loss=0.6976(mal=0.5197,sub=0.3072), auc=0.9748, f1=0.8472, recall=0.8739, oracle_f1=0.3947, cascade_acc=0.4505
#   -> no improvement (6/7)
# [Hybrid][Fold 4][Epoch 15] sub_w=0.593 | train loss=0.6894(mal=0.1369,sub=0.9315), auc=0.9940, f1=0.9312, recall=0.9752, oracle_f1=0.3980, cascade_acc=0.6014 | val loss=0.9514(mal=0.6626,sub=0.4869), auc=0.9654, f1=0.8190, recall=0.8559, oracle_f1=0.3424, cascade_acc=0.5586
#   -> no improvement (7/7)
#   -> early stopping triggered at epoch 15
#
# -- Final Evaluation --
# [Malignancy]  AUC=0.9740, F1=0.8110, Recall=0.9279, Acc=0.9062
# [Subtype Oracle]  Acc=0.5225, MacroF1=0.2507
# [Cascade]  SubtypeAcc=0.4955, GateRecall=0.9279
# Binary CM:
# [[361  40]
#  [  8 103]]
# Subtype Oracle CM:
# [[ 0  0  1  2  6]
#  [ 0  0  2  8  7]
#  [ 0  0  2  7  3]
#  [ 0  0  1  7  3]
#  [ 0  0  5  8 49]]
#
# [Hybrid][Fold 4] Final Metrics
# Malignancy  AUC=0.9740, F1=0.8110, Recall=0.9279
# Subtype Oracle  Acc=0.5225, MacroF1=0.2507
# Cascade  Acc=0.4955, GateRecall=0.9279
#
# ================================================================================
# Running Hybrid | Fold 5
# ================================================================================
# [FOLD 5] Train benign(0): 1606, malignant(1): 444, pos_weight=3.6171, subtype_counts=[33.0, 68.0, 48.0, 46.0, 249.0], subtype_class_weights=[1.654099941253662, 0.8026999831199646, 1.1371999979019165, 1.1866999864578247, 0.219200000166893]
# [Hybrid][Fold 5][Epoch 01] sub_w=0.400 | train loss=1.1887(mal=0.6529,sub=1.3396), auc=0.8909, f1=0.6654, recall=0.8198, oracle_f1=0.1571, cascade_acc=0.4730 | val loss=0.5951(mal=0.4508,sub=0.3608), auc=0.9583, f1=0.7536, recall=0.9369, oracle_f1=0.1434, cascade_acc=0.5586
#   -> best saved (val_auc=0.9583): ct_cascade_models/Hybrid_fold5_best.pth
# [Hybrid][Fold 5][Epoch 02] sub_w=0.414 | train loss=1.0201(mal=0.4947,sub=1.2696), auc=0.9369, f1=0.7495, recall=0.8694, oracle_f1=0.1577, cascade_acc=0.4977 | val loss=0.5498(mal=0.4040,sub=0.3523), auc=0.9619, f1=0.7799, recall=0.9099, oracle_f1=0.1420, cascade_acc=0.5405
#   -> best saved (val_auc=0.9619): ct_cascade_models/Hybrid_fold5_best.pth
# [Hybrid][Fold 5][Epoch 03] sub_w=0.428 | train loss=0.9454(mal=0.4257,sub=1.2155), auc=0.9528, f1=0.7878, recall=0.8986, oracle_f1=0.2247, cascade_acc=0.4977 | val loss=0.5988(mal=0.4459,sub=0.3574), auc=0.9657, f1=0.7840, recall=0.8829, oracle_f1=0.1713, cascade_acc=0.5405
#   -> best saved (val_auc=0.9657): ct_cascade_models/Hybrid_fold5_best.pth
# [Hybrid][Fold 5][Epoch 04] sub_w=0.441 | train loss=0.8576(mal=0.3319,sub=1.1910), auc=0.9723, f1=0.8152, recall=0.9392, oracle_f1=0.2777, cascade_acc=0.5405 | val loss=0.7854(mal=0.6278,sub=0.3569), auc=0.9595, f1=0.7931, recall=0.8288, oracle_f1=0.2414, cascade_acc=0.4865
#   -> no improvement (1/7)
# [Hybrid][Fold 5][Epoch 05] sub_w=0.455 | train loss=0.8398(mal=0.3097,sub=1.1645), auc=0.9749, f1=0.8345, recall=0.9369, oracle_f1=0.2562, cascade_acc=0.4932 | val loss=0.6015(mal=0.4458,sub=0.3420), auc=0.9672, f1=0.7876, recall=0.8018, oracle_f1=0.2756, cascade_acc=0.3604
#   -> best saved (val_auc=0.9672): ct_cascade_models/Hybrid_fold5_best.pth
# [Hybrid][Fold 5][Epoch 06] sub_w=0.469 | train loss=0.7905(mal=0.2654,sub=1.1196), auc=0.9807, f1=0.8720, recall=0.9437, oracle_f1=0.3314, cascade_acc=0.5653 | val loss=0.5861(mal=0.4291,sub=0.3347), auc=0.9699, f1=0.8216, recall=0.8919, oracle_f1=0.1947, cascade_acc=0.4595
#   -> best saved (val_auc=0.9699): ct_cascade_models/Hybrid_fold5_best.pth
# [Hybrid][Fold 5][Epoch 07] sub_w=0.483 | train loss=0.7834(mal=0.2600,sub=1.0842), auc=0.9827, f1=0.8533, recall=0.9369, oracle_f1=0.3469, cascade_acc=0.5878 | val loss=0.7379(mal=0.5476,sub=0.3941), auc=0.9526, f1=0.7739, recall=0.8018, oracle_f1=0.2269, cascade_acc=0.4955
#   -> no improvement (1/7)
# [Hybrid][Fold 5][Epoch 08] sub_w=0.497 | train loss=0.7378(mal=0.2251,sub=1.0326), auc=0.9840, f1=0.8903, recall=0.9505, oracle_f1=0.3650, cascade_acc=0.5878 | val loss=0.7730(mal=0.5921,sub=0.3645), auc=0.9601, f1=0.7982, recall=0.7838, oracle_f1=0.2143, cascade_acc=0.4414
#   -> no improvement (2/7)
# [Hybrid][Fold 5][Epoch 09] sub_w=0.510 | train loss=0.6973(mal=0.1645,sub=1.0441), auc=0.9931, f1=0.8956, recall=0.9662, oracle_f1=0.4090, cascade_acc=0.6216 | val loss=0.7632(mal=0.5517,sub=0.4144), auc=0.9623, f1=0.8097, recall=0.9009, oracle_f1=0.2381, cascade_acc=0.5225
#   -> no improvement (3/7)
# [Hybrid][Fold 5][Epoch 10] sub_w=0.524 | train loss=0.7341(mal=0.2166,sub=0.9873), auc=0.9848, f1=0.8882, recall=0.9572, oracle_f1=0.4230, cascade_acc=0.6216 | val loss=0.5396(mal=0.3370,sub=0.3865), auc=0.9729, f1=0.8347, recall=0.9099, oracle_f1=0.2387, cascade_acc=0.4234
#   -> best saved (val_auc=0.9729): ct_cascade_models/Hybrid_fold5_best.pth
# [Hybrid][Fold 5][Epoch 11] sub_w=0.538 | train loss=0.6710(mal=0.1762,sub=0.9197), auc=0.9919, f1=0.9039, recall=0.9640, oracle_f1=0.4762, cascade_acc=0.6667 | val loss=0.7825(mal=0.5171,sub=0.4933), auc=0.9595, f1=0.8190, recall=0.8559, oracle_f1=0.1836, cascade_acc=0.2703
#   -> no improvement (1/7)
# [Hybrid][Fold 5][Epoch 12] sub_w=0.552 | train loss=0.7032(mal=0.1618,sub=0.9813), auc=0.9919, f1=0.9236, recall=0.9662, oracle_f1=0.4136, cascade_acc=0.6216 | val loss=0.9921(mal=0.7650,sub=0.4115), auc=0.9680, f1=0.7847, recall=0.7387, oracle_f1=0.3294, cascade_acc=0.4505
#   -> no improvement (2/7)
# [Hybrid][Fold 5][Epoch 13] sub_w=0.566 | train loss=0.6532(mal=0.1640,sub=0.8651), auc=0.9921, f1=0.9110, recall=0.9685, oracle_f1=0.4990, cascade_acc=0.6622 | val loss=0.6542(mal=0.4407,sub=0.3776), auc=0.9682, f1=0.8230, recall=0.9009, oracle_f1=0.3174, cascade_acc=0.4324
#   -> no improvement (3/7)
# [Hybrid][Fold 5][Epoch 14] sub_w=0.579 | train loss=0.5806(mal=0.1201,sub=0.7948), auc=0.9951, f1=0.9283, recall=0.9775, oracle_f1=0.5397, cascade_acc=0.7027 | val loss=0.9312(mal=0.6745,sub=0.4432), auc=0.9683, f1=0.8458, recall=0.8649, oracle_f1=0.2810, cascade_acc=0.4054
#   -> no improvement (4/7)
# [Hybrid][Fold 5][Epoch 15] sub_w=0.593 | train loss=0.6635(mal=0.1767,sub=0.8208), auc=0.9911, f1=0.8962, recall=0.9527, oracle_f1=0.5282, cascade_acc=0.6532 | val loss=0.7273(mal=0.4877,sub=0.4040), auc=0.9726, f1=0.8333, recall=0.8559, oracle_f1=0.3517, cascade_acc=0.4595
#   -> no improvement (5/7)
# [Hybrid][Fold 5][Epoch 16] sub_w=0.607 | train loss=0.5865(mal=0.1417,sub=0.7329), auc=0.9940, f1=0.9328, recall=0.9685, oracle_f1=0.5472, cascade_acc=0.6914 | val loss=0.8047(mal=0.5530,sub=0.4146), auc=0.9683, f1=0.8403, recall=0.9009, oracle_f1=0.3270, cascade_acc=0.5225
#   -> no improvement (6/7)
# [Hybrid][Fold 5][Epoch 17] sub_w=0.621 | train loss=0.5484(mal=0.1290,sub=0.6758), auc=0.9962, f1=0.9180, recall=0.9707, oracle_f1=0.6561, cascade_acc=0.7635 | val loss=0.9032(mal=0.5721,sub=0.5334), auc=0.9698, f1=0.8522, recall=0.8829, oracle_f1=0.3401, cascade_acc=0.5586
#   -> no improvement (7/7)
#   -> early stopping triggered at epoch 17
#
# -- Final Evaluation --
# [Malignancy]  AUC=0.9729, F1=0.8347, Recall=0.9099, Acc=0.9219
# [Subtype Oracle]  Acc=0.4414, MacroF1=0.2387
# [Cascade]  SubtypeAcc=0.4234, GateRecall=0.9099
# Binary CM:
# [[371  30]
#  [ 10 101]]
# Subtype Oracle CM:
# [[ 0  4  1  2  2]
#  [ 0  8  1  2  5]
#  [ 0  4  2  5  1]
#  [ 0 11  0  0  1]
#  [ 0 18  2  3 39]]
#
# [Hybrid][Fold 5] Final Metrics
# Malignancy  AUC=0.9729, F1=0.8347, Recall=0.9099
# Subtype Oracle  Acc=0.4414, MacroF1=0.2387
# Cascade  Acc=0.4234, GateRecall=0.9099
#     model  fold   mal_acc   mal_auc    mal_f1  mal_recall  subtype_oracle_acc  \
# 0  Hybrid     1  0.943470  0.981769  0.877637    0.936937            0.522523
# 1  Hybrid     2  0.910331  0.954820  0.788991    0.774775            0.378378
# 2  Hybrid     3  0.923828  0.975725  0.826667    0.837838            0.513514
# 3  Hybrid     4  0.906250  0.973973  0.811024    0.927928            0.522523
# 4  Hybrid     5  0.921875  0.972872  0.834711    0.909910            0.441441
#
#    subtype_oracle_macro_f1  subtype_cascade_acc  subtype_gate_recall  \
# 0                 0.222165             0.477477             0.936937
# 1                 0.265690             0.324324             0.774775
# 2                 0.311980             0.441441             0.837838
# 3                 0.250668             0.495495             0.927928
# 4                 0.238722             0.423423             0.909910
#
#                 binary_cm                                  subtype_oracle_cm
# 0   [[380, 22], [7, 104]]  [[0, 0, 0, 0, 8], [0, 0, 4, 0, 13], [0, 0, 2, ...
# 1   [[381, 21], [25, 86]]  [[0, 2, 3, 3, 0], [0, 5, 4, 8, 0], [0, 3, 6, 2...
# 2   [[380, 21], [18, 93]]  [[1, 0, 0, 0, 7], [0, 6, 1, 0, 10], [3, 1, 3, ...
# 3   [[361, 40], [8, 103]]  [[0, 0, 1, 2, 6], [0, 0, 2, 8, 7], [0, 0, 2, 7...
# 4  [[371, 30], [10, 101]]  [[0, 4, 1, 2, 2], [0, 8, 1, 2, 5], [0, 4, 2, 5...
#            mal_auc              mal_f1           mal_recall            \
#               mean       std      mean       std       mean       std
# model
# Hybrid    0.971832  0.010111  0.827806  0.032865   0.877477  0.069375
# ResNet50  0.971353  0.010339  0.812996  0.048776   0.879279  0.056477
# ViT-B16   0.775075  0.115413  0.464394  0.193984   0.940541  0.097780
#
#          subtype_oracle_acc           subtype_oracle_macro_f1            \
#                        mean       std                    mean       std
# model
# Hybrid             0.475676  0.064148                0.257845  0.034214
# ResNet50           0.554955  0.022612                0.253907  0.110643
# ViT-B16            0.524324  0.081679                0.155155  0.025575
#
#          subtype_cascade_acc           subtype_gate_recall
#                         mean       std                mean       std
# model
# Hybrid              0.432432  0.066813            0.877477  0.069375
# ResNet50            0.515315  0.023319            0.879279  0.056477
# ViT-B16             0.500901  0.110814            0.940541  0.097780
