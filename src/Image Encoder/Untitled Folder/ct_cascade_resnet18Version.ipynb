# %%
#!/usr/bin/env python
# coding: utf-8

# ============================================================
# CT Cascade 학습 스크립트
#
# [구조 개요]
#   1단계: malignancy binary classification (benign / malignant)
#   2단계: malignant 샘플에 대해서만 subtype multi-class classification
#
# [원본 대비 주요 수정 사항]
#   1. inspect_fold_npz 오타 수정: .exits() → .exists()
#   2. infer_malignant_type_ids 들여쓰기 버그 수정
#      (return이 fold loop 안에 있어 fold 1 결과만 반환하던 문제)
#   3. cascade_correct 인덱스 불일치 버그 수정
#      (oracle_pred/oracle_true는 all_mal_mask 기준,
#       all_mal_pred[gt_mal_mask]는 gt_mal_mask 기준 → 길이 불일치)
#   4. fit_model print 오타 수정: 콤마로 분리된 f-string → 하나로 합침
#   5. 모델 구조 개선:
#      - shared head 이후 task별 projection(mal_proj / sub_proj) 분리
#      - early stopping 기준: val_loss → val_auc (malignancy recall 중심)
#      - subtype_loss_weight warmup 스케줄 추가
# ============================================================


# ============================================================
# 빌드 확인
# ============================================================
from torchvision import models
from torchvision.models import vit_b_16

print("=" * 60)

try:
    m1 = models.resnet18(weights=None)
    print("ResNet18 build success")
except Exception as e:
    print("Fail", e)

try:
    m2 = vit_b_16(weights=None)
    print("Vit-B/16 build success")
except Exception as e:
    print("Fail", e)

print("=" * 60)


# ============================================================
# 1) 환경 설정 + import
# ============================================================
import os
import gc
import random
import torchvision.transforms.functional as TF
from pathlib import Path
from collections import OrderedDict, defaultdict

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.metrics import (
    confusion_matrix, classification_report,
    accuracy_score, f1_score, roc_auc_score, recall_score
)

import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
from torchvision import models
from torchvision.models import vit_b_16, ViT_B_16_Weights, ResNet18_Weights

SEED = 42
random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)
torch.cuda.manual_seed_all(SEED)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Device:", device)

# cuDNN autotuner: 입력 크기가 고정일 때 속도 향상
torch.backends.cudnn.benchmark = True


# ============================================================
# 2) 경로 / 하이퍼파라미터 설정
# ============================================================
print(f"현재 작업 경로: {os.getcwd()}")

DATA_ROOT  = Path("/tf/nasw/dataset001/preprocessed/npz_ct")
FOLDS      = [1, 2, 3, 4, 5]

OUTPUT_DIR = Path("./ct_cascade_models18")
OUTPUT_DIR.mkdir(parents=True, exist_ok=True)

IMG_SIZE     = 224
BATCH_SIZE   = 8
NUM_WORKERS  = 2
NUM_EPOCHS   = 30
LR           = 1e-4
WEIGHT_DECAY = 1e-4
PATIENCE     = 7
MIN_DELTA    = 0.001
THRESHOLD    = 0.5   # malignancy 판단 임계값

# subtype loss 가중치 warmup 설정
# - 학습 초반에는 malignancy 분류에 집중하고,
#   후반부로 갈수록 subtype loss 비중을 점진적으로 높임
SUBTYPE_LOSS_WEIGHT_START = 0.4   # 1 epoch 시작값
SUBTYPE_LOSS_WEIGHT_END   = 0.8   # NUM_EPOCHS epoch 도달값

print("DATA_ROOT:", DATA_ROOT)
print("OUTPUT_DIR:", OUTPUT_DIR.resolve())
print("FOLDS:", FOLDS)


# ============================================================
# 3) 로컬 pretrained weight 경로
# ============================================================
LOCAL_RESNET18_WEIGHTS = Path("/tf/pretrained_model/resnet18-f37072fd.pth")
LOCAL_VIT_WEIGHTS    = Path("/tf/pretrained_model/vit_b_16-c867db91.pth")

print("LOCAL_RESNET18_WEIGHTS exists:", LOCAL_RESNET18_WEIGHTS.exists())
print("LOCAL_VIT_WEIGHTS exists:",    LOCAL_VIT_WEIGHTS.exists())


# ============================================================
# 4) 유틸 함수
# ============================================================
def load_local_state_dict(weight_path):
    weight_path = Path(weight_path)
    assert weight_path.exists(), f"Weight file not found: {weight_path}"

    ckpt = torch.load(weight_path, map_location="cpu")

    # 일부 checkpoint는 {"state_dict": {...}} 형태로 저장되어 있음
    if isinstance(ckpt, dict) and "state_dict" in ckpt and isinstance(ckpt["state_dict"], dict):
        ckpt = ckpt["state_dict"]

    return ckpt


def inspect_fold_npz(fold_idx):
    train_npz_path = DATA_ROOT / f"fold_{fold_idx}_train.npz"
    val_npz_path   = DATA_ROOT / f"fold_{fold_idx}_val.npz"

    # ✅ 버그 수정: .exits() → .exists()
    print("TRAIN:", train_npz_path, train_npz_path.exists())
    print("VAL:",   val_npz_path,   val_npz_path.exists())

    train_npz = np.load(train_npz_path, allow_pickle=False, mmap_mode="r")
    val_npz   = np.load(val_npz_path,   allow_pickle=False, mmap_mode="r")

    for k in train_npz.files:
        print(f"[train] {k}: shape={train_npz[k].shape}, dtype={train_npz[k].dtype}")
    for k in val_npz.files:
        print(f"[val]   {k}: shape={val_npz[k].shape}, dtype={val_npz[k].dtype}")


def get_subtype_loss_weight(epoch: int, total_epochs: int) -> float:
    """
    subtype loss 가중치를 epoch에 따라 선형 warmup.

    epoch 1  → SUBTYPE_LOSS_WEIGHT_START
    epoch N  → SUBTYPE_LOSS_WEIGHT_END
    사이는 선형 보간.

    이유: 학습 초반 malignancy gate가 불안정할 때
    subtype loss가 너무 크면 전체 학습을 방해할 수 있음.
    """
    t = (epoch - 1) / max(total_epochs - 1, 1)   # 0.0 ~ 1.0
    return SUBTYPE_LOSS_WEIGHT_START + t * (SUBTYPE_LOSS_WEIGHT_END - SUBTYPE_LOSS_WEIGHT_START)


# ============================================================
# 5) malignant subtype ID 자동 추론
# ============================================================
def infer_malignant_type_ids(data_root, folds):
    """
    NPZ 파일에서 tumor_type별로 label(0/1)을 수집하여
    항상 malignant(label=1)인 tumor_type ID 목록을 자동 추론.

    ✅ 버그 수정: 원본은 return이 fold loop 안에 있어서
       fold 1 처리 후 바로 반환되는 문제가 있었음.
       loop 밖으로 conflicts 체크와 return을 이동.
    """
    # tumor_type별로 등장한 label 값들을 수집
    label_set_by_type = defaultdict(set)

    for fold_idx in folds:
        for split_name in ["train", "val"]:
            npz_path = Path(data_root) / f"fold_{fold_idx}_{split_name}.npz"
            data     = np.load(npz_path, allow_pickle=False, mmap_mode="r")

            labels      = data["labels"].astype(int)
            tumor_types = data["tumor_types"].astype(int)

            for y, t in zip(labels, tumor_types):
                label_set_by_type[int(t)].add(int(y))

    # ✅ loop 종료 후 한 번만 체크 (원본: loop 안에서 매 fold마다 체크 후 return)
    # 동일 tumor_type이 benign/malignant 양쪽에 있으면 데이터 오류
    conflicts = {
        t: sorted(list(v))
        for t, v in label_set_by_type.items()
        if len(v) > 1
    }
    if len(conflicts) > 0:
        raise ValueError(
            f"tumor_type이 양성/악성 양쪽에 섞여 있음: {conflicts}\n"
            "데이터 전처리를 확인하세요."
        )

    # label이 {1}만인 tumor_type만 malignant subtype으로 간주
    malignant_type_ids = sorted([
        t for t, labs in label_set_by_type.items()
        if labs == {1}
    ])

    print("malignant_type_ids:", malignant_type_ids)
    return malignant_type_ids


MALIGNANT_TYPE_IDS     = infer_malignant_type_ids(DATA_ROOT, FOLDS)
MALIGNANT_MAP          = {tid: i for i, tid in enumerate(MALIGNANT_TYPE_IDS)}
NUM_MALIGNANT_SUBTYPES = len(MALIGNANT_TYPE_IDS)

print("MALIGNANT_MAP:", MALIGNANT_MAP)
print("NUM_MALIGNANT_SUBTYPES:", NUM_MALIGNANT_SUBTYPES)

#=============================================================
# 5.5) 실시간 증강 모듈
#=============================================================

class CTSliceAugmentor:
    def __init__(
        self,
        p_hflip: float = 0.5,
        p_vflip: float = 0.0,
        p_rotate: float = 0.5,
        max_angle: float = 10.0,
        p_crop: float = 0.5,
        crop_min: float = 0.85,
        p_noise: float = 0.3,
        noise_std: float = 0.01,
    ):
        self.p_hflip = p_hflip
        self.p_vflip = p_vflip
        self.p_rotate = p_rotate
        self.max_angle = max_angle
        self.p_crop = p_crop
        self.crop_min = crop_min
        self.p_noise = p_noise
        self.noise_std = noise_std


    def __call__(self, imgs):
        S, C, H, W = imgs.shape

        do_hflip = random.random() < self.p_hflip
        do_vflip = random.random() < self.p_vflip
        do_rotate = random.random() < self.p_rotate
        angle = random.uniform(-self.max_angle, self.max_angle) if do_rotate else 0.0
        do_crop = random.random() < self.p_crop
        do_noise = random.random() < self.p_noise

        top = left = crop_h = crop_w = 0
        if do_crop:
            scale = random.uniform(self.crop_min, 1.0)
            crop_h = int(H*scale)
            crop_w = int(W*scale)
            top = random.randint(0, H-crop_h)
            left = random.randint(0, W-crop_w)

        augmented = []
        for s in range(S):
            img = imgs[s]
            if do_hflip:
                img = TF.hflip(img)
            if do_vflip:
                img = TF.vflip(img)
            if do_rotate:
                img = TF.rotate(img, angle, interpolation = TF.InterpolationMode.BILINEAR, fill=0)
            if do_crop:
                img = TF.crop(img, top, left, crop_h, crop_w)
                img = TF.resize(img, [H,W], interpolation=TF.InterpolationMode.BILINEAR, antialias=True)
            augmented.append(img)

        imgs=torch.stack(augmented, dim = 0)

        if do_noise:
            imgs = (imgs + torch.randn_like(imgs) * self.noise_std).clamp(0.0, 1.0)

        return imgs


TRAIN_AUGMENTOR = CTSliceAugmentor(
    p_hflip = 0.5, p_vflip = 0.0, p_rotate=0.5, max_angle = 10.0,
    p_crop = 0.5, crop_min = 0.85, p_noise = 0.3, noise_std = 0.01,
)

def _worker_init_fn(worker_id):
    worker_seed = torch.initial_seed() % (2**32)
    np.random.seed(worker_seed)
    random.seed(worker_seed)
    


# ============================================================
# 6) Dataset 정의
# ============================================================
class OvarianCTNPZDataset(Dataset):
    def __init__(self, npz_path, is_train=True):
        super().__init__()
        self.npz = np.load(npz_path, allow_pickle=False, mmap_mode="r")

        self.images      = self.npz["images"]
        self.labels      = self.npz["labels"].astype(np.float32)
        self.tumor_types = self.npz["tumor_types"].astype(np.int64)

        # patient_ids가 없으면 인덱스로 대체
        self.patient_ids = (
            self.npz["patient_ids"]
            if "patient_ids" in self.npz.files
            else np.arange(len(self.labels))
        )

        # ImageNet 정규화 상수 (CT/US 공통으로 사용 가능)
        self.mean = torch.tensor([0.485, 0.456, 0.406], dtype=torch.float32).view(1, 3, 1, 1)
        self.std  = torch.tensor([0.229, 0.224, 0.225], dtype=torch.float32).view(1, 3, 1, 1)

        self.augmentor = TRAIN_AUGMENTOR if is_train else None

    def __len__(self):
        return len(self.labels)

    def __getitem__(self, idx):
        x           = self.images[idx]
        y           = int(self.labels[idx])
        tumor_type  = int(self.tumor_types[idx])

        # NPZ 저장 형태: [S, H, W, C] → [S, C, H, W]
        x = torch.from_numpy(np.array(x)).float().permute(0, 3, 1, 2).contiguous()
        x = x / 255.0

        if self.augmentor is not None:
            x = self.augmentor(x)
            
        x = (x - self.mean) / self.std

        # malignant 샘플에만 subtype label 부여
        if y == 1:
            if tumor_type not in MALIGNANT_MAP:
                raise ValueError(
                    f"malignant sample인데 tumor_type={tumor_type}가 MALIGNANT_MAP에 없음. "
                    f"infer_malignant_type_ids 결과 확인 필요."
                )
            mal_subtype = MALIGNANT_MAP[tumor_type]
            mal_mask    = True
        else:
            # benign은 subtype 없음 → -1로 패딩 (loss 계산 시 mal_mask로 필터링)
            mal_subtype = -1
            mal_mask    = False

        return {
            "image":       x,
            "label":       torch.tensor(y, dtype=torch.float32),
            "mal_subtype": torch.tensor(mal_subtype, dtype=torch.long),
            "mal_mask":    torch.tensor(mal_mask, dtype=torch.bool),
        }


# ============================================================
# 7) fold별 DataLoader 생성
# ============================================================
def make_fold_loaders(fold_idx):
    train_npz_path = DATA_ROOT / f"fold_{fold_idx}_train.npz"
    val_npz_path   = DATA_ROOT / f"fold_{fold_idx}_val.npz"

    assert train_npz_path.exists(), f"Missing: {train_npz_path}"
    assert val_npz_path.exists(),   f"Missing: {val_npz_path}"

    train_dataset = OvarianCTNPZDataset(train_npz_path, is_train=True)
    val_dataset   = OvarianCTNPZDataset(val_npz_path, is_train=False)

    train_loader = DataLoader(
        train_dataset,
        batch_size=BATCH_SIZE,
        shuffle=True,
        num_workers=NUM_WORKERS,
        pin_memory=True,
        worker_init_fn = _worker_init_fn,
        persistent_workers = (NUM_WORKERS > 0),
    )
    val_loader = DataLoader(
        val_dataset,
        batch_size=BATCH_SIZE,
        shuffle=False,
        num_workers=NUM_WORKERS,
        pin_memory=True
    )

    # ── malignancy pos_weight ────────────────────────────────
    # benign/malignant 불균형 보정: neg/pos 비율로 BCEWithLogitsLoss에 전달
    labels_np        = train_dataset.labels.astype(int)
    neg              = (labels_np == 0).sum()
    pos              = (labels_np == 1).sum()
    pos_weight_value = neg / max(pos, 1)
    mal_pos_weight   = torch.tensor([pos_weight_value], device=device, dtype=torch.float32)

    # ── subtype class weight ─────────────────────────────────
    # subtype별 샘플 수 역수로 class weight 계산 (inv mean normalization)
    subtype_counts = np.zeros(NUM_MALIGNANT_SUBTYPES, dtype=np.float64)
    for y, t in zip(train_dataset.labels.astype(int), train_dataset.tumor_types.astype(int)):
        if y == 1 and t in MALIGNANT_MAP:
            subtype_counts[MALIGNANT_MAP[t]] += 1.0

    subtype_counts       = np.maximum(subtype_counts, 1.0)   # 0 나누기 방지
    inv                  = 1.0 / subtype_counts
    subtype_class_weights = inv / inv.mean()                  # 평균 1로 정규화
    subtype_class_weights = torch.tensor(subtype_class_weights, dtype=torch.float32, device=device)

    print(
        f"[FOLD {fold_idx}] Train benign(0): {neg}, malignant(1): {pos}, "
        f"pos_weight={mal_pos_weight.item():.4f}, "
        f"subtype_counts={subtype_counts.tolist()}, "
        f"subtype_class_weights={subtype_class_weights.detach().cpu().numpy().round(4).tolist()}"
    )

    return train_loader, val_loader, mal_pos_weight, subtype_class_weights


# ============================================================
# 8) Cascade 손실 함수
# ============================================================
class CascadeCriterion(nn.Module):
    def __init__(self, pos_weight, subtype_class_weights, subtype_loss_weight=0.5):
        """
        Args:
            pos_weight           : BCEWithLogitsLoss의 pos_weight (malignancy)
            subtype_class_weights: CrossEntropyLoss의 class weight (subtype)
            subtype_loss_weight  : subtype loss를 얼마나 반영할지 가중치
                                   epoch마다 외부에서 업데이트 가능
        """
        super().__init__()
        self.bce               = nn.BCEWithLogitsLoss(pos_weight=pos_weight)
        self.ce                = nn.CrossEntropyLoss(weight=subtype_class_weights)
        self.subtype_loss_weight = subtype_loss_weight

    def forward(self, outputs, batch):
        labels      = batch["label"].to(device).view(-1)        # [B]
        mal_mask    = batch["mal_mask"].to(device).view(-1)     # [B] bool
        mal_subtype = batch["mal_subtype"].to(device).view(-1)  # [B]

        # malignancy binary loss (benign/malignant 전체 샘플)
        loss_m = self.bce(outputs["malignancy_logits"], labels)

        # subtype loss (malignant 샘플만)
        # mal_mask=True인 샘플만 필터링해서 CrossEntropyLoss 계산
        if mal_mask.any():
            loss_s = self.ce(
                outputs["subtype_logits"][mal_mask],
                mal_subtype[mal_mask]
            )
        else:
            # batch 안에 malignant 샘플이 없는 경우 (소규모 데이터에서 발생 가능)
            loss_s = torch.tensor(0.0, device=device)

        loss_total = loss_m + self.subtype_loss_weight * loss_s

        return {
            "loss_total":      loss_total,
            "loss_malignancy": loss_m,
            "loss_subtype":    loss_s,
        }


# ============================================================
# 9) 지표 계산 함수
# ============================================================
def compute_binary_metrics(y_true, y_prob, threshold=0.5):
    y_true = np.asarray(y_true).astype(int)
    y_prob = np.asarray(y_prob).astype(float)
    y_pred = (y_prob >= threshold).astype(int)

    return {
        "acc":    accuracy_score(y_true, y_pred),
        "auc":    roc_auc_score(y_true, y_prob) if len(np.unique(y_true)) > 1 else 0.5,
        "f1":     f1_score(y_true, y_pred, zero_division=0),
        "recall": recall_score(y_true, y_pred, zero_division=0),
        "cm":     confusion_matrix(y_true, y_pred),
    }


def compute_multiclass_metrics(y_true, y_pred):
    y_true = np.asarray(y_true).astype(int)
    y_pred = np.asarray(y_pred).astype(int)

    if len(y_true) == 0:
        return {"acc": np.nan, "macro_f1": np.nan, "macro_recall": np.nan, "cm": None}

    return {
        "acc":          accuracy_score(y_true, y_pred),
        "macro_f1":     f1_score(y_true, y_pred, average="macro", zero_division=0),
        "macro_recall": recall_score(y_true, y_pred, average="macro", zero_division=0),
        "cm":           confusion_matrix(y_true, y_pred),
    }


# ============================================================
# 10) train / eval 함수
# ============================================================
scaler = torch.amp.GradScaler(enabled=(device.type == "cuda"))


def _compute_cascade_metrics(
    all_label, all_mal_prob, all_mal_mask,
    all_subtype_true, all_subtype_pred,
    running_total, running_m, running_s,
    n_samples,
):
    """
    train_one_epoch / eval_one_epoch 공통 지표 계산 로직.
    중복 코드를 줄이기 위해 분리.

    ✅ 버그 수정: cascade_correct 인덱스 불일치 수정
        - oracle_pred / oracle_true: all_mal_mask(GT malignant) 기준으로 필터링된 배열
        - all_mal_pred[gt_mal_mask]: GT malignant 샘플에 대한 예측값
        - 위 두 배열의 길이는 동일 (gt_mal_mask == all_mal_mask)
        - 원본 코드는 all_mal_mask 대신 mal_mask를 별도로 쓰거나
          배열 길이가 맞지 않는 경우 발생 → gt_mal_mask로 통일하여 수정
    """
    mal_metrics = compute_binary_metrics(all_label, all_mal_prob, threshold=THRESHOLD)

    all_label        = np.asarray(all_label).astype(int)
    all_mal_pred     = (np.asarray(all_mal_prob) >= THRESHOLD).astype(int)
    all_mal_mask     = np.asarray(all_mal_mask).astype(bool)
    all_subtype_true = np.asarray(all_subtype_true).astype(int)
    all_subtype_pred = np.asarray(all_subtype_pred).astype(int)

    # oracle subtype: GT가 malignant인 샘플에 대해서만 subtype 평가
    # (malignancy gate의 영향 없이, subtype head 자체 성능 측정)
    oracle_true    = all_subtype_true[all_mal_mask]
    oracle_pred    = all_subtype_pred[all_mal_mask]
    subtype_oracle = compute_multiclass_metrics(oracle_true, oracle_pred)

    # cascade subtype: GT malignant 샘플 중
    #   ① malignancy gate도 malignant로 예측하고 (gate pass)
    #   ② subtype도 맞춰야 정답
    gt_mal_mask = all_mal_mask   # GT label == 1인 샘플 = mal_mask와 동일

    if gt_mal_mask.sum() > 0:
        gate_pass = all_mal_pred[gt_mal_mask] == 1   # gate 통과 여부 [N_mal]

        # ✅ oracle_pred는 gt_mal_mask 기준으로 필터링된 배열이므로 길이 일치
        subtype_correct = oracle_pred == oracle_true  # subtype 정답 여부 [N_mal]

        gate_recall          = gate_pass.mean()
        # cascade 정답 = gate도 통과하고 subtype도 맞아야 함
        subtype_cascade_acc  = (gate_pass & subtype_correct).mean()
    else:
        gate_recall         = np.nan
        subtype_cascade_acc = np.nan

    return {
        "loss":           running_total / n_samples,
        "loss_malignancy": running_m / n_samples,
        "loss_subtype":   running_s / n_samples,

        # malignancy 지표
        "acc":    mal_metrics["acc"],
        "auc":    mal_metrics["auc"],
        "f1":     mal_metrics["f1"],
        "recall": mal_metrics["recall"],
        "cm":     mal_metrics["cm"],

        # subtype oracle 지표 (gate 무관, subtype head 자체 성능)
        "subtype_oracle_acc":      subtype_oracle["acc"],
        "subtype_oracle_macro_f1": subtype_oracle["macro_f1"],
        "subtype_oracle_cm":       subtype_oracle["cm"],

        # cascade 지표 (gate + subtype 통합 성능)
        "subtype_cascade_acc":  float(subtype_cascade_acc),
        "subtype_gate_recall":  float(gate_recall),
    }


def train_one_epoch(model, loader, criterion, optimizer, device):
    model.train()

    running_total, running_m, running_s = 0.0, 0.0, 0.0
    all_label        = []
    all_mal_prob     = []
    all_mal_mask     = []
    all_subtype_true = []
    all_subtype_pred = []

    for batch in loader:
        imgs = batch["image"].to(device, non_blocking=True)

        optimizer.zero_grad()

        with torch.amp.autocast(device_type="cuda", enabled=(device.type == "cuda")):
            outputs   = model(imgs)
            loss_dict = criterion(outputs, batch)
            loss      = loss_dict["loss_total"]

        scaler.scale(loss).backward()
        scaler.step(optimizer)
        scaler.update()

        bs             = imgs.size(0)
        running_total += loss_dict["loss_total"].item() * bs
        running_m     += loss_dict["loss_malignancy"].item() * bs
        running_s     += loss_dict["loss_subtype"].item() * bs

        # CPU로 이동 후 numpy 변환
        label_np        = batch["label"].detach().cpu().numpy().astype(int).ravel()
        mal_mask_np     = batch["mal_mask"].detach().cpu().numpy().astype(bool).ravel()
        mal_prob_np     = torch.sigmoid(outputs["malignancy_logits"]).detach().cpu().numpy().ravel()
        subtype_pred_np = outputs["subtype_logits"].argmax(dim=1).detach().cpu().numpy().astype(int).ravel()
        subtype_true_np = batch["mal_subtype"].detach().cpu().numpy().astype(int).ravel()

        all_label.extend(label_np.tolist())
        all_mal_prob.extend(mal_prob_np.tolist())
        all_mal_mask.extend(mal_mask_np.tolist())
        all_subtype_true.extend(subtype_true_np.tolist())
        all_subtype_pred.extend(subtype_pred_np.tolist())

    return _compute_cascade_metrics(
        all_label, all_mal_prob, all_mal_mask,
        all_subtype_true, all_subtype_pred,
        running_total, running_m, running_s,
        len(loader.dataset),
    )


@torch.no_grad()
def eval_one_epoch(model, loader, criterion, device):
    model.eval()

    running_total, running_m, running_s = 0.0, 0.0, 0.0
    all_label        = []
    all_mal_prob     = []
    all_mal_mask     = []
    all_subtype_true = []
    all_subtype_pred = []

    for batch in loader:
        imgs = batch["image"].to(device, non_blocking=True)

        with torch.amp.autocast(device_type="cuda", enabled=(device.type == "cuda")):
            outputs   = model(imgs)
            loss_dict = criterion(outputs, batch)

        bs             = imgs.size(0)
        running_total += loss_dict["loss_total"].item() * bs
        running_m     += loss_dict["loss_malignancy"].item() * bs
        running_s     += loss_dict["loss_subtype"].item() * bs

        label_np        = batch["label"].detach().cpu().numpy().astype(int).ravel()
        mal_mask_np     = batch["mal_mask"].detach().cpu().numpy().astype(bool).ravel()
        mal_prob_np     = torch.sigmoid(outputs["malignancy_logits"]).detach().cpu().numpy().ravel()
        subtype_pred_np = outputs["subtype_logits"].argmax(dim=1).detach().cpu().numpy().astype(int).ravel()
        subtype_true_np = batch["mal_subtype"].detach().cpu().numpy().astype(int).ravel()

        all_label.extend(label_np.tolist())
        all_mal_prob.extend(mal_prob_np.tolist())
        all_mal_mask.extend(mal_mask_np.tolist())
        all_subtype_true.extend(subtype_true_np.tolist())
        all_subtype_pred.extend(subtype_pred_np.tolist())

    return _compute_cascade_metrics(
        all_label, all_mal_prob, all_mal_mask,
        all_subtype_true, all_subtype_pred,
        running_total, running_m, running_s,
        len(loader.dataset),
    )


@torch.no_grad()
def eval_confusion(model, loader, criterion, device, threshold=0.5):
    """최종 평가 + classification report 출력."""
    metrics = eval_one_epoch(model, loader, criterion, device)

    print("\n-- Final Evaluation --")
    print(f"[Malignancy]  AUC={metrics['auc']:.4f}, F1={metrics['f1']:.4f}, Recall={metrics['recall']:.4f}, Acc={metrics['acc']:.4f}")
    print(f"[Subtype Oracle]  Acc={metrics['subtype_oracle_acc']:.4f}, MacroF1={metrics['subtype_oracle_macro_f1']:.4f}")
    print(f"[Cascade]  SubtypeAcc={metrics['subtype_cascade_acc']:.4f}, GateRecall={metrics['subtype_gate_recall']:.4f}")
    print("Binary CM:")
    print(metrics["cm"])
    print("Subtype Oracle CM:")
    print(metrics["subtype_oracle_cm"])

    return metrics


# ============================================================
# 11) 모델 정의
# ============================================================

# ── 공통 Attention Pooling + Dual Head Classifier ────────────
class PatientSliceAttentionClassifier(nn.Module):
    """
    [구조 개선]
    원본: shared → malignancy_head / subtype_head (동일 표현 공유)
    수정: shared → mal_proj → malignancy_head
                 → sub_proj → subtype_head

    이유: malignancy 판단(global 패턴)과 subtype 분류(세부 형태 패턴)는
    집중해야 할 특징이 달라서 task별 projection을 추가하면 각 head가
    더 특화된 표현을 학습할 수 있음.
    """
    def __init__(self, encoder, feat_dim, hidden_dim=512, proj_dim=256, dropout=0.1):
        super().__init__()
        self.encoder = encoder

        # slice 간 중요도 attention (슬라이스별 가중합 풀링)
        self.attn = nn.Sequential(
            nn.Linear(feat_dim, feat_dim // 2),
            nn.Tanh(),
            nn.Linear(feat_dim // 2, 1),
        )

        # 공통 표현 추출
        self.shared = nn.Sequential(
            nn.Linear(feat_dim, hidden_dim),
            nn.ReLU(),
            nn.Dropout(dropout),
        )

        # ── task별 projection (개선 포인트) ──────────────────
        # malignancy: 양성/악성 global 구분에 집중
        self.mal_proj = nn.Sequential(
            nn.Linear(hidden_dim, proj_dim),
            nn.ReLU(),
            nn.Dropout(dropout),
        )
        # subtype: 악성 내 세부 형태 패턴 분류에 집중
        self.sub_proj = nn.Sequential(
            nn.Linear(hidden_dim, proj_dim),
            nn.ReLU(),
            nn.Dropout(dropout),
        )

        self.malignancy_head = nn.Linear(proj_dim, 1)
        self.subtype_head    = nn.Linear(proj_dim, NUM_MALIGNANT_SUBTYPES)

    def forward(self, x):
        # x: (B, S, C, H, W)
        B, S, C, H, W = x.shape
        x = x.view(B * S, C, H, W)

        feat = self.encoder(x)           # (B*S, feat_dim)
        feat = feat.view(B, S, -1)       # (B, S, feat_dim)

        # attention pooling
        attn_score  = self.attn(feat)                    # (B, S, 1)
        attn_weight = torch.softmax(attn_score, dim=1)
        pooled      = (feat * attn_weight).sum(dim=1)    # (B, feat_dim)

        # 공통 → task별 분기
        z     = self.shared(pooled)    # (B, hidden_dim)
        z_mal = self.mal_proj(z)       # (B, proj_dim)
        z_sub = self.sub_proj(z)       # (B, proj_dim)

        return {
            # squeeze(1): [B,1] → [B]  (BCEWithLogitsLoss 입력 형태)
            "malignancy_logits": self.malignancy_head(z_mal).squeeze(1),
            "subtype_logits":    self.subtype_head(z_sub),   # (B, NUM_MALIGNANT_SUBTYPES)
        }


# ── ResNet50 기반 모델 ────────────────────────────────────────
def build_resnet18_patient_model(
    load_pretrained=True,
    freeze_backbone=True,
    unfreeze_layer4=True,
    weight_path=LOCAL_RESNET18_WEIGHTS,
):
    encoder = models.resnet18(weights=None)

    if load_pretrained:
        state_dict = load_local_state_dict(weight_path)
        encoder.load_state_dict(state_dict, strict=True)

    feat_dim   = encoder.fc.in_features   # 512
    encoder.fc = nn.Identity()

    if freeze_backbone:
        for p in encoder.parameters():
            p.requires_grad = False
        if unfreeze_layer4:
            # layer4만 fine-tuning (고수준 특징 추출 레이어)
            for p in encoder.layer4.parameters():
                p.requires_grad = True

    model = PatientSliceAttentionClassifier(
        encoder=encoder,
        feat_dim=feat_dim,
        hidden_dim=256,
        proj_dim=128,
        dropout=0.3,
    )
    return model


# ── ViT-B/16 기반 모델 ───────────────────────────────────────
def build_vit_patient_model(
    load_pretrained=True,
    weight_path=LOCAL_VIT_WEIGHTS,
):
    encoder = vit_b_16(weights=None)

    if load_pretrained:
        state_dict = load_local_state_dict(weight_path)
        encoder.load_state_dict(state_dict, strict=True)

    feat_dim      = encoder.heads.head.in_features   # 768
    encoder.heads = nn.Identity()

    model = PatientSliceAttentionClassifier(
        encoder=encoder,
        feat_dim=feat_dim,
        hidden_dim=512,
        proj_dim=256,
        dropout=0.1,
    )
    return model


# ── CNN + Transformer Hybrid 모델 ────────────────────────────
class CNNTransformerHybridPatient(nn.Module):
    """
    ResNet18으로 슬라이스별 특징 추출 후
    Transformer로 슬라이스 간 관계를 모델링.

    [구조 개선]
    원본: shared → malignancy_head / subtype_head
    수정: shared → mal_proj → malignancy_head
                 → sub_proj → subtype_head
    """
    def __init__(
        self,
        d_model=512,
        nhead=8,
        num_layers=2,
        dim_feedforward=1024,
        proj_dim=256,
        dropout=0.1,
        load_pretrained=True,
        freeze_backbone=True,
        unfreeze_layer4=True,
        resnet_weight_path=LOCAL_RESNET18_WEIGHTS,
    ):
        super().__init__()

        # ── ResNet50 backbone ─────────────────────────────────
        backbone = models.resnet18(weights=None)
        if load_pretrained:
            state_dict = load_local_state_dict(resnet_weight_path)
            backbone.load_state_dict(state_dict, strict=True)
        feat_dim    = backbone.fc.in_features   # 2048
        backbone.fc = nn.Identity()
        self.encoder = backbone

        if freeze_backbone:
            for p in self.encoder.parameters():
                p.requires_grad = False
            if unfreeze_layer4:
                for p in self.encoder.layer4.parameters():
                    p.requires_grad = True

        # ── Transformer 입력 준비 ─────────────────────────────
        # ResNet 출력(2048) → Transformer 차원(d_model)으로 projection
        self.proj = nn.Linear(feat_dim, d_model)

        # CLS 토큰: 슬라이스 전체를 요약하는 학습 가능한 토큰
        self.cls_token = nn.Parameter(torch.zeros(1, 1, d_model))

        # pos_embed: 슬라이스 위치 정보 인코딩 (1+8: CLS + 슬라이스 최대 8장)
        # 실제 슬라이스 수 S가 8보다 작으면 자동으로 슬라이싱됨
        self.pos_embed = nn.Parameter(torch.zeros(1, 1 + 8, d_model))

        # ── Transformer Encoder ───────────────────────────────
        enc_layer = nn.TransformerEncoderLayer(
            d_model=d_model,
            nhead=nhead,
            dim_feedforward=dim_feedforward,
            dropout=0.1,
            batch_first=True,
            activation="gelu",
        )
        self.transformer = nn.TransformerEncoder(enc_layer, num_layers=num_layers)
        self.norm        = nn.LayerNorm(d_model)

        # ── 공통 표현 + task별 projection (개선 포인트) ────────
        self.shared = nn.Sequential(
            nn.Linear(d_model, 512),
            nn.ReLU(),
            nn.Dropout(dropout),
        )
        self.mal_proj = nn.Sequential(
            nn.Linear(512, proj_dim),
            nn.ReLU(),
            nn.Dropout(dropout),
        )
        self.sub_proj = nn.Sequential(
            nn.Linear(512, proj_dim),
            nn.ReLU(),
            nn.Dropout(dropout),
        )
        self.malignancy_head = nn.Linear(proj_dim, 1)
        self.subtype_head    = nn.Linear(proj_dim, NUM_MALIGNANT_SUBTYPES)

    def forward(self, x):
        B, S, C, H, W = x.shape
        x = x.view(B * S, C, H, W)

        feat = self.encoder(x)          # (B*S, 2048)
        feat = feat.view(B, S, -1)      # (B, S, 2048)
        feat = self.proj(feat)          # (B, S, d_model)

        # CLS 토큰 prepend
        cls    = self.cls_token.expand(B, -1, -1)       # (B, 1, d_model)
        tokens = torch.cat([cls, feat], dim=1)           # (B, 1+S, d_model)
        # pos_embed는 최대 슬라이스 수 기준으로 정의하고 실제 S에 맞게 슬라이싱
        tokens = tokens + self.pos_embed[:, :tokens.size(1), :]

        tokens  = self.transformer(tokens)    # (B, 1+S, d_model)
        tokens  = self.norm(tokens)
        cls_out = tokens[:, 0, :]             # (B, d_model) CLS 토큰만 추출

        z     = self.shared(cls_out)   # (B, 512)
        z_mal = self.mal_proj(z)       # (B, proj_dim)
        z_sub = self.sub_proj(z)       # (B, proj_dim)

        return {
            "malignancy_logits": self.malignancy_head(z_mal).squeeze(1),
            "subtype_logits":    self.subtype_head(z_sub),
        }


def build_hybrid_patient_model(load_pretrained=True):
    return CNNTransformerHybridPatient(
        load_pretrained=load_pretrained,
        freeze_backbone=True,
        unfreeze_layer4=True,
        resnet_weight_path=LOCAL_RESNET_WEIGHTS,
    )


# ============================================================
# 12) 공통 학습 함수
# ============================================================
def fit_model(
    model, model_name, fold_idx,
    train_loader, val_loader, device,
    num_epochs=30, lr=1e-4, weight_decay=1e-4,
    criterion=None,
    patience=7, min_delta=0.001,
):
    """
    [early stopping 기준 변경]
    원본: val_loss 기준
    수정: val_auc 기준

    이유: cascade 모델에서 malignancy gate recall이 낮으면
    subtype 예측 자체가 의미 없어짐.
    val_loss는 subtype loss가 섞여 있어 malignancy 성능을
    직접 반영하지 못함 → val_auc가 더 적합.

    [subtype_loss_weight warmup]
    epoch마다 CascadeCriterion의 weight를 업데이트.
    학습 초반에는 malignancy에 집중, 후반으로 갈수록 subtype 비중 증가.
    """
    if criterion is None:
        raise ValueError("cascade 모델에서는 criterion에 CascadeCriterion을 넘겨야 함")

    model = model.to(device)
    optimizer = torch.optim.Adam(
        filter(lambda p: p.requires_grad, model.parameters()),
        lr=lr,
        weight_decay=weight_decay,
    )

    best_auc           = -1.0
    best_path          = OUTPUT_DIR / f"{model_name}_fold{fold_idx}_best.pth"
    history            = []
    early_stop_counter = 0

    for epoch in range(1, num_epochs + 1):

        # subtype loss weight warmup: epoch마다 선형 증가
        current_subtype_weight = get_subtype_loss_weight(epoch, num_epochs)
        criterion.subtype_loss_weight = current_subtype_weight

        train_metrics = train_one_epoch(model, train_loader, criterion, optimizer, device)
        val_metrics   = eval_one_epoch(model, val_loader, criterion, device)

        row = {
            "fold":  fold_idx,
            "epoch": epoch,
            "subtype_loss_weight": current_subtype_weight,

            # train 지표
            "train_loss":                    train_metrics["loss"],
            "train_loss_malignancy":         train_metrics["loss_malignancy"],
            "train_loss_subtype":            train_metrics["loss_subtype"],
            "train_acc":                     train_metrics["acc"],
            "train_auc":                     train_metrics["auc"],
            "train_f1":                      train_metrics["f1"],
            "train_recall":                  train_metrics["recall"],
            "train_subtype_oracle_acc":      train_metrics["subtype_oracle_acc"],
            "train_subtype_oracle_macro_f1": train_metrics["subtype_oracle_macro_f1"],
            "train_subtype_cascade_acc":     train_metrics["subtype_cascade_acc"],
            "train_subtype_gate_recall":     train_metrics["subtype_gate_recall"],

            # val 지표
            "val_loss":                    val_metrics["loss"],
            "val_loss_malignancy":         val_metrics["loss_malignancy"],
            "val_loss_subtype":            val_metrics["loss_subtype"],
            "val_acc":                     val_metrics["acc"],
            "val_auc":                     val_metrics["auc"],
            "val_f1":                      val_metrics["f1"],
            "val_recall":                  val_metrics["recall"],
            "val_subtype_oracle_acc":      val_metrics["subtype_oracle_acc"],
            "val_subtype_oracle_macro_f1": val_metrics["subtype_oracle_macro_f1"],
            "val_subtype_cascade_acc":     val_metrics["subtype_cascade_acc"],
            "val_subtype_gate_recall":     val_metrics["subtype_gate_recall"],
        }
        history.append(row)

        # ✅ 버그 수정: 원본은 콤마로 f-string이 분리되어 별도 출력됨
        # → 하나의 f-string으로 합침
        print(
            f"[{model_name}][Fold {fold_idx}][Epoch {epoch:02d}] "
            f"sub_w={current_subtype_weight:.3f} | "
            f"train loss={row['train_loss']:.4f}(mal={row['train_loss_malignancy']:.4f},sub={row['train_loss_subtype']:.4f}), "
            f"auc={row['train_auc']:.4f}, f1={row['train_f1']:.4f}, recall={row['train_recall']:.4f}, "
            f"oracle_f1={row['train_subtype_oracle_macro_f1']:.4f}, cascade_acc={row['train_subtype_cascade_acc']:.4f} | "
            f"val loss={row['val_loss']:.4f}(mal={row['val_loss_malignancy']:.4f},sub={row['val_loss_subtype']:.4f}), "
            f"auc={row['val_auc']:.4f}, f1={row['val_f1']:.4f}, recall={row['val_recall']:.4f}, "
            f"oracle_f1={row['val_subtype_oracle_macro_f1']:.4f}, cascade_acc={row['val_subtype_cascade_acc']:.4f}"
        )

        # ✅ early stopping 기준: val_loss → val_auc
        val_auc = row["val_auc"]
        if val_auc > best_auc + min_delta:
            best_auc           = val_auc
            early_stop_counter = 0
            torch.save(model.state_dict(), best_path)
            print(f"  -> best saved (val_auc={best_auc:.4f}): {best_path}")
        else:
            early_stop_counter += 1
            print(f"  -> no improvement ({early_stop_counter}/{patience})")

        if early_stop_counter >= patience:
            print(f"  -> early stopping triggered at epoch {epoch}")
            break

    history_df = pd.DataFrame(history)
    return model, history_df, best_path


# ============================================================
# 13) 모델 로드 함수
# ============================================================
def load_model(model_type, model_path, device):
    if model_type == "resnet":
        model = build_resnet18_patient_model(load_pretrained=False)
    elif model_type == "vit":
        model = build_vit_patient_model(load_pretrained=False)
    elif model_type == "hybrid":
        model = build_hybrid_patient_model(load_pretrained=False)
    else:
        raise ValueError(f"Unknown model type: {model_type}")

    model.load_state_dict(torch.load(model_path, map_location=device))
    model.to(device)
    model.eval()
    return model


# ============================================================
# 14) CV 실행 함수
# ============================================================
def run_cv_for_model(model_name, model_type, build_fn):
    fold_results   = []
    fold_histories = []

    for fold_idx in FOLDS:
        print("\n" + "=" * 80)
        print(f"Running {model_name} | Fold {fold_idx}")
        print("=" * 80)

        train_loader, val_loader, pos_weight, subtype_class_weights = make_fold_loaders(fold_idx)

        model = build_fn()

        # CascadeCriterion: subtype_loss_weight는 fit_model 내부에서 epoch마다 업데이트
        criterion = CascadeCriterion(
            pos_weight=pos_weight,
            subtype_class_weights=subtype_class_weights,
            subtype_loss_weight=SUBTYPE_LOSS_WEIGHT_START,
        )

        _, history_df, best_path = fit_model(
            model=model,
            model_name=model_name,
            fold_idx=fold_idx,
            train_loader=train_loader,
            val_loader=val_loader,
            device=device,
            num_epochs=NUM_EPOCHS,
            lr=LR,
            weight_decay=WEIGHT_DECAY,
            criterion=criterion,
            patience=PATIENCE,
            min_delta=MIN_DELTA,
        )

        best_model    = load_model(model_type, best_path, device)
        final_metrics = eval_confusion(best_model, val_loader, criterion, device, threshold=THRESHOLD)

        print(f"\n[{model_name}][Fold {fold_idx}] Final Metrics")
        print(f"Malignancy  AUC={final_metrics['auc']:.4f}, F1={final_metrics['f1']:.4f}, Recall={final_metrics['recall']:.4f}")
        print(f"Subtype Oracle  Acc={final_metrics['subtype_oracle_acc']:.4f}, MacroF1={final_metrics['subtype_oracle_macro_f1']:.4f}")
        print(f"Cascade  Acc={final_metrics['subtype_cascade_acc']:.4f}, GateRecall={final_metrics['subtype_gate_recall']:.4f}")

        fold_results.append({
            "model":                   model_name,
            "fold":                    fold_idx,
            "mal_acc":                 final_metrics["acc"],
            "mal_auc":                 final_metrics["auc"],
            "mal_f1":                  final_metrics["f1"],
            "mal_recall":              final_metrics["recall"],
            "subtype_oracle_acc":      final_metrics["subtype_oracle_acc"],
            "subtype_oracle_macro_f1": final_metrics["subtype_oracle_macro_f1"],
            "subtype_cascade_acc":     final_metrics["subtype_cascade_acc"],
            "subtype_gate_recall":     final_metrics["subtype_gate_recall"],
            "binary_cm":               final_metrics["cm"],
            "subtype_oracle_cm":       final_metrics["subtype_oracle_cm"],
        })

        history_df["model"] = model_name
        fold_histories.append(history_df)

        del model, best_model, train_loader, val_loader
        gc.collect()
        if torch.cuda.is_available():
            torch.cuda.empty_cache()

    result_df      = pd.DataFrame(fold_results)
    history_df_all = pd.concat(fold_histories, ignore_index=True)
    return result_df, history_df_all


# ============================================================
# 15) 학습 실행
# ============================================================

# ── ResNet50 ──────────────────────────────────────────────────
print(">>> Training ResNet18...")
resnet_cv_df, resnet_history_df = run_cv_for_model(
    model_name="ResNet18",
    model_type="resnet",
    build_fn=lambda: build_resnet18_patient_model(load_pretrained=True),
)
display(resnet_cv_df)

# ── ViT-B/16 ─────────────────────────────────────────────────
print(">>> Training ViT-B/16...")
vit_cv_df, vit_history_df = run_cv_for_model(
    model_name="ViT-B16",
    model_type="vit",
    build_fn=lambda: build_vit_patient_model(load_pretrained=True),
)
display(vit_cv_df)

# ── Hybrid ────────────────────────────────────────────────────
print(">>> Training Hybrid...")
hybrid_cv_df, hybrid_history_df = run_cv_for_model(
    model_name="Hybrid",
    model_type="hybrid",
    build_fn=lambda: build_hybrid_patient_model(load_pretrained=True),
)
display(hybrid_cv_df)


# ============================================================
# 16) 5-fold 평균 ± 표준편차 요약
# ============================================================
all_cv_df = pd.concat([resnet_cv_df, vit_cv_df, hybrid_cv_df], ignore_index=True)

summary_df = (
    all_cv_df.groupby("model")[[
        "mal_auc", "mal_f1", "mal_recall",
        "subtype_oracle_acc", "subtype_oracle_macro_f1",
        "subtype_cascade_acc", "subtype_gate_recall",
    ]]
    .agg(["mean", "std"])
)
display(summary_df)


# ============================================================
# 17) 학습 곡선 시각화
# ============================================================
def plot_one_model_by_fold(history_df, model_name):
    folds = sorted(history_df["fold"].unique())

    fig, axes = plt.subplots(1, 3, figsize=(18, 5))

    # Loss
    ax = axes[0]
    for fold in folds:
        df_f = history_df[history_df["fold"] == fold].sort_values("epoch")
        ax.plot(df_f["epoch"], df_f["train_loss"], linestyle="--", alpha=0.7, label=f"Fold{fold} Train")
        ax.plot(df_f["epoch"], df_f["val_loss"],   alpha=0.7,      label=f"Fold{fold} Val")
    ax.set_title(f"{model_name} - Total Loss")
    ax.set_xlabel("Epoch")
    ax.set_ylabel("Loss")
    ax.legend(fontsize=7)

    # Malignancy AUC
    ax = axes[1]
    for fold in folds:
        df_f = history_df[history_df["fold"] == fold].sort_values("epoch")
        ax.plot(df_f["epoch"], df_f["val_auc"], alpha=0.8, label=f"Fold{fold}")
    ax.set_title(f"{model_name} - Val Malignancy AUC")
    ax.set_xlabel("Epoch")
    ax.set_ylabel("AUC")
    ax.legend(fontsize=7)

    # Subtype cascade acc
    ax = axes[2]
    for fold in folds:
        df_f = history_df[history_df["fold"] == fold].sort_values("epoch")
        ax.plot(df_f["epoch"], df_f["val_subtype_cascade_acc"], alpha=0.8, label=f"Fold{fold}")
    ax.set_title(f"{model_name} - Val Subtype Cascade Acc")
    ax.set_xlabel("Epoch")
    ax.set_ylabel("Cascade Acc")
    ax.legend(fontsize=7)

    plt.suptitle(model_name, fontsize=13)
    plt.tight_layout()
    plt.show()


plot_one_model_by_fold(resnet_history_df, "ResNet50")
plot_one_model_by_fold(vit_history_df,    "ViT-B16")
plot_one_model_by_fold(hybrid_history_df, "Hybrid")
# Out:
# ============================================================
# ResNet18 build success
# Vit-B/16 build success
# ============================================================
# Device: cuda
# 현재 작업 경로: /tf/notebooks/Image Encoder/Untitled Folder
# DATA_ROOT: /tf/nasw/dataset001/preprocessed/npz_ct
# OUTPUT_DIR: /tf/notebooks/Image Encoder/Untitled Folder/ct_cascade_models18
# FOLDS: [1, 2, 3, 4, 5]
# LOCAL_RESNET18_WEIGHTS exists: True
# LOCAL_VIT_WEIGHTS exists: True
# malignant_type_ids: [0, 1, 3, 5, 7]
# MALIGNANT_MAP: {0: 0, 1: 1, 3: 2, 5: 3, 7: 4}
# NUM_MALIGNANT_SUBTYPES: 5
# >>> Training ResNet18...
#
# ================================================================================
# Running ResNet18 | Fold 1
# ================================================================================
# [FOLD 1] Train benign(0): 1605, malignant(1): 444, pos_weight=3.6149, subtype_counts=[34.0, 67.0, 48.0, 46.0, 249.0], subtype_class_weights=[1.617400050163269, 0.8206999897956848, 1.1455999612808228, 1.1953999996185303, 0.2207999974489212]
# [ResNet18][Fold 1][Epoch 01] sub_w=0.400 | train loss=1.2032(mal=0.6946,sub=1.2717), auc=0.8828, f1=0.6305, recall=0.8514, oracle_f1=0.1611, cascade_acc=0.4887 | val loss=0.5486(mal=0.4068,sub=0.3543), auc=0.9619, f1=0.8016, recall=0.8919, oracle_f1=0.2059, cascade_acc=0.5676
#   -> best saved (val_auc=0.9619): ct_cascade_models18/ResNet18_fold1_best.pth
# [ResNet18][Fold 1][Epoch 02] sub_w=0.414 | train loss=1.0134(mal=0.5236,sub=1.1837), auc=0.9311, f1=0.7278, recall=0.8671, oracle_f1=0.2018, cascade_acc=0.4977 | val loss=0.4476(mal=0.2997,sub=0.3575), auc=0.9789, f1=0.8308, recall=0.9730, oracle_f1=0.1434, cascade_acc=0.5405
#   -> best saved (val_auc=0.9789): ct_cascade_models18/ResNet18_fold1_best.pth
# [ResNet18][Fold 1][Epoch 03] sub_w=0.428 | train loss=0.9912(mal=0.4612,sub=1.2395), auc=0.9471, f1=0.7592, recall=0.8874, oracle_f1=0.2287, cascade_acc=0.5113 | val loss=0.4861(mal=0.3390,sub=0.3441), auc=0.9738, f1=0.7925, recall=0.9459, oracle_f1=0.2217, cascade_acc=0.5676
#   -> no improvement (1/7)
# [ResNet18][Fold 1][Epoch 04] sub_w=0.441 | train loss=0.9183(mal=0.4109,sub=1.1496), auc=0.9576, f1=0.7765, recall=0.9077, oracle_f1=0.2491, cascade_acc=0.5428 | val loss=0.4365(mal=0.2870,sub=0.3388), auc=0.9792, f1=0.8387, recall=0.9369, oracle_f1=0.2640, cascade_acc=0.5676
#   -> no improvement (2/7)
# [ResNet18][Fold 1][Epoch 05] sub_w=0.455 | train loss=0.9046(mal=0.3946,sub=1.1206), auc=0.9610, f1=0.7891, recall=0.9099, oracle_f1=0.2795, cascade_acc=0.5405 | val loss=0.4724(mal=0.3192,sub=0.3367), auc=0.9745, f1=0.8268, recall=0.9459, oracle_f1=0.2777, cascade_acc=0.5586
#   -> no improvement (3/7)
# [ResNet18][Fold 1][Epoch 06] sub_w=0.469 | train loss=0.8354(mal=0.3420,sub=1.0521), auc=0.9699, f1=0.7972, recall=0.9122, oracle_f1=0.3201, cascade_acc=0.5473 | val loss=0.6458(mal=0.4795,sub=0.3546), auc=0.9744, f1=0.8447, recall=0.7838, oracle_f1=0.3206, cascade_acc=0.4685
#   -> no improvement (4/7)
# [ResNet18][Fold 1][Epoch 07] sub_w=0.483 | train loss=0.8429(mal=0.3005,sub=1.1236), auc=0.9767, f1=0.8421, recall=0.9369, oracle_f1=0.3288, cascade_acc=0.5698 | val loss=0.4958(mal=0.3255,sub=0.3527), auc=0.9742, f1=0.8729, recall=0.9279, oracle_f1=0.3585, cascade_acc=0.5856
#   -> no improvement (5/7)
# [ResNet18][Fold 1][Epoch 08] sub_w=0.497 | train loss=0.7898(mal=0.2786,sub=1.0295), auc=0.9804, f1=0.8530, recall=0.9347, oracle_f1=0.3464, cascade_acc=0.5721 | val loss=0.5896(mal=0.4151,sub=0.3514), auc=0.9749, f1=0.7458, recall=0.9910, oracle_f1=0.3111, cascade_acc=0.5676
#   -> no improvement (6/7)
# [ResNet18][Fold 1][Epoch 09] sub_w=0.510 | train loss=0.7493(mal=0.2417,sub=0.9947), auc=0.9847, f1=0.8523, recall=0.9617, oracle_f1=0.3956, cascade_acc=0.5991 | val loss=0.5860(mal=0.4025,sub=0.3596), auc=0.9741, f1=0.8684, recall=0.8919, oracle_f1=0.3349, cascade_acc=0.5135
#   -> no improvement (7/7)
#   -> early stopping triggered at epoch 9
#
# -- Final Evaluation --
# [Malignancy]  AUC=0.9789, F1=0.8308, Recall=0.9730, Acc=0.9142
# [Subtype Oracle]  Acc=0.5586, MacroF1=0.1434
# [Cascade]  SubtypeAcc=0.5405, GateRecall=0.9730
# Binary CM:
# [[361  41]
#  [  3 108]]
# Subtype Oracle CM:
# [[ 0  0  0  0  8]
#  [ 0  0  0  0 17]
#  [ 0  0  0  0 12]
#  [ 0  0  0  0 12]
#  [ 0  0  0  0 62]]
#
# [ResNet18][Fold 1] Final Metrics
# Malignancy  AUC=0.9789, F1=0.8308, Recall=0.9730
# Subtype Oracle  Acc=0.5586, MacroF1=0.1434
# Cascade  Acc=0.5405, GateRecall=0.9730
#
# ================================================================================
# Running ResNet18 | Fold 2
# ================================================================================
# [FOLD 2] Train benign(0): 1605, malignant(1): 444, pos_weight=3.6149, subtype_counts=[34.0, 67.0, 48.0, 46.0, 249.0], subtype_class_weights=[1.617400050163269, 0.8206999897956848, 1.1455999612808228, 1.1953999996185303, 0.2207999974489212]
# [ResNet18][Fold 2][Epoch 01] sub_w=0.400 | train loss=1.1674(mal=0.6800,sub=1.2185), auc=0.8851, f1=0.6448, recall=0.8401, oracle_f1=0.1900, cascade_acc=0.4617 | val loss=0.8674(mal=0.7207,sub=0.3666), auc=0.9292, f1=0.7374, recall=0.6577, oracle_f1=0.2017, cascade_acc=0.3874
#   -> best saved (val_auc=0.9292): ct_cascade_models18/ResNet18_fold2_best.pth
# [ResNet18][Fold 2][Epoch 02] sub_w=0.414 | train loss=1.0091(mal=0.4958,sub=1.2403), auc=0.9385, f1=0.7381, recall=0.8761, oracle_f1=0.2001, cascade_acc=0.4910 | val loss=0.7197(mal=0.5705,sub=0.3607), auc=0.9300, f1=0.7250, recall=0.7838, oracle_f1=0.2263, cascade_acc=0.4865
#   -> no improvement (1/7)
# [ResNet18][Fold 2][Epoch 03] sub_w=0.428 | train loss=0.9437(mal=0.4368,sub=1.1854), auc=0.9525, f1=0.7574, recall=0.8964, oracle_f1=0.2473, cascade_acc=0.5315 | val loss=0.8410(mal=0.6881,sub=0.3577), auc=0.9365, f1=0.7589, recall=0.7658, oracle_f1=0.1692, cascade_acc=0.4595
#   -> best saved (val_auc=0.9365): ct_cascade_models18/ResNet18_fold2_best.pth
# [ResNet18][Fold 2][Epoch 04] sub_w=0.441 | train loss=0.8688(mal=0.3546,sub=1.1651), auc=0.9681, f1=0.8130, recall=0.9302, oracle_f1=0.2635, cascade_acc=0.5383 | val loss=0.7273(mal=0.5689,sub=0.3587), auc=0.9389, f1=0.7452, recall=0.8829, oracle_f1=0.3102, cascade_acc=0.5045
#   -> best saved (val_auc=0.9389): ct_cascade_models18/ResNet18_fold2_best.pth
# [ResNet18][Fold 2][Epoch 05] sub_w=0.455 | train loss=0.8864(mal=0.3760,sub=1.1214), auc=0.9646, f1=0.8004, recall=0.9167, oracle_f1=0.3247, cascade_acc=0.5518 | val loss=0.6863(mal=0.5265,sub=0.3510), auc=0.9524, f1=0.8052, recall=0.8378, oracle_f1=0.3038, cascade_acc=0.5045
#   -> best saved (val_auc=0.9524): ct_cascade_models18/ResNet18_fold2_best.pth
# [ResNet18][Fold 2][Epoch 06] sub_w=0.469 | train loss=0.8300(mal=0.2996,sub=1.1309), auc=0.9766, f1=0.8310, recall=0.9302, oracle_f1=0.3078, cascade_acc=0.5563 | val loss=0.6993(mal=0.5345,sub=0.3514), auc=0.9502, f1=0.7433, recall=0.8739, oracle_f1=0.3666, cascade_acc=0.5586
#   -> no improvement (1/7)
# [ResNet18][Fold 2][Epoch 07] sub_w=0.483 | train loss=0.8020(mal=0.2931,sub=1.0543), auc=0.9785, f1=0.8238, recall=0.9212, oracle_f1=0.3586, cascade_acc=0.5608 | val loss=0.9372(mal=0.7482,sub=0.3915), auc=0.9551, f1=0.8018, recall=0.7838, oracle_f1=0.2823, cascade_acc=0.4955
#   -> best saved (val_auc=0.9551): ct_cascade_models18/ResNet18_fold2_best.pth
# [ResNet18][Fold 2][Epoch 08] sub_w=0.497 | train loss=0.7795(mal=0.2624,sub=1.0414), auc=0.9826, f1=0.8471, recall=0.9482, oracle_f1=0.3770, cascade_acc=0.5923 | val loss=0.7322(mal=0.5124,sub=0.4426), auc=0.9584, f1=0.7983, recall=0.8559, oracle_f1=0.2540, cascade_acc=0.5315
#   -> best saved (val_auc=0.9584): ct_cascade_models18/ResNet18_fold2_best.pth
# [ResNet18][Fold 2][Epoch 09] sub_w=0.510 | train loss=0.7409(mal=0.2567,sub=0.9487), auc=0.9833, f1=0.8636, recall=0.9414, oracle_f1=0.4103, cascade_acc=0.6126 | val loss=0.6687(mal=0.4446,sub=0.4392), auc=0.9634, f1=0.8065, recall=0.9009, oracle_f1=0.2923, cascade_acc=0.5495
#   -> best saved (val_auc=0.9634): ct_cascade_models18/ResNet18_fold2_best.pth
# [ResNet18][Fold 2][Epoch 10] sub_w=0.524 | train loss=0.7192(mal=0.2381,sub=0.9178), auc=0.9850, f1=0.8755, recall=0.9505, oracle_f1=0.4007, cascade_acc=0.6014 | val loss=0.8458(mal=0.6416,sub=0.3896), auc=0.9608, f1=0.8318, recall=0.8018, oracle_f1=0.3087, cascade_acc=0.4775
#   -> no improvement (1/7)
# [ResNet18][Fold 2][Epoch 11] sub_w=0.538 | train loss=0.7137(mal=0.2192,sub=0.9191), auc=0.9876, f1=0.8788, recall=0.9550, oracle_f1=0.4329, cascade_acc=0.6194 | val loss=0.7924(mal=0.5995,sub=0.3586), auc=0.9570, f1=0.7837, recall=0.8649, oracle_f1=0.3300, cascade_acc=0.5135
#   -> no improvement (2/7)
# [ResNet18][Fold 2][Epoch 12] sub_w=0.552 | train loss=0.7082(mal=0.2093,sub=0.9043), auc=0.9882, f1=0.8726, recall=0.9640, oracle_f1=0.4435, cascade_acc=0.6532 | val loss=0.8111(mal=0.5792,sub=0.4204), auc=0.9568, f1=0.8000, recall=0.8829, oracle_f1=0.3131, cascade_acc=0.4955
#   -> no improvement (3/7)
# [ResNet18][Fold 2][Epoch 13] sub_w=0.566 | train loss=0.6698(mal=0.1658,sub=0.8913), auc=0.9924, f1=0.9155, recall=0.9640, oracle_f1=0.4818, cascade_acc=0.6644 | val loss=0.8583(mal=0.5994,sub=0.4578), auc=0.9563, f1=0.7948, recall=0.8198, oracle_f1=0.2707, cascade_acc=0.4955
#   -> no improvement (4/7)
# [ResNet18][Fold 2][Epoch 14] sub_w=0.579 | train loss=0.6379(mal=0.1769,sub=0.7958), auc=0.9909, f1=0.9170, recall=0.9707, oracle_f1=0.5239, cascade_acc=0.7095 | val loss=0.7575(mal=0.5277,sub=0.3968), auc=0.9595, f1=0.7619, recall=0.8649, oracle_f1=0.3490, cascade_acc=0.5405
#   -> no improvement (5/7)
# [ResNet18][Fold 2][Epoch 15] sub_w=0.593 | train loss=0.5675(mal=0.1630,sub=0.6820), auc=0.9926, f1=0.9062, recall=0.9685, oracle_f1=0.5772, cascade_acc=0.7095 | val loss=0.9081(mal=0.6722,sub=0.3978), auc=0.9474, f1=0.7805, recall=0.8649, oracle_f1=0.3097, cascade_acc=0.4595
#   -> no improvement (6/7)
# [ResNet18][Fold 2][Epoch 16] sub_w=0.607 | train loss=0.5726(mal=0.1270,sub=0.7342), auc=0.9956, f1=0.9423, recall=0.9752, oracle_f1=0.5932, cascade_acc=0.7095 | val loss=1.0604(mal=0.8134,sub=0.4071), auc=0.9572, f1=0.8019, recall=0.7477, oracle_f1=0.3122, cascade_acc=0.4414
#   -> no improvement (7/7)
#   -> early stopping triggered at epoch 16
#
# -- Final Evaluation --
# [Malignancy]  AUC=0.9634, F1=0.8065, Recall=0.9009, Acc=0.9064
# [Subtype Oracle]  Acc=0.5856, MacroF1=0.2923
# [Cascade]  SubtypeAcc=0.5495, GateRecall=0.9009
# Binary CM:
# [[365  37]
#  [ 11 100]]
# Subtype Oracle CM:
# [[ 0  0  0  0  8]
#  [ 0  6  2  1  8]
#  [ 0  1  0  1 10]
#  [ 0  0  3  2  7]
#  [ 0  2  3  0 57]]
#
# [ResNet18][Fold 2] Final Metrics
# Malignancy  AUC=0.9634, F1=0.8065, Recall=0.9009
# Subtype Oracle  Acc=0.5856, MacroF1=0.2923
# Cascade  Acc=0.5495, GateRecall=0.9009
#
# ================================================================================
# Running ResNet18 | Fold 3
# ================================================================================
# [FOLD 3] Train benign(0): 1606, malignant(1): 444, pos_weight=3.6171, subtype_counts=[34.0, 67.0, 48.0, 47.0, 248.0], subtype_class_weights=[1.6253000497817993, 0.8248000144958496, 1.1512999534606934, 1.1757999658584595, 0.22280000150203705]
# [ResNet18][Fold 3][Epoch 01] sub_w=0.400 | train loss=1.2234(mal=0.7070,sub=1.2910), auc=0.8776, f1=0.6464, recall=0.8131, oracle_f1=0.1903, cascade_acc=0.4730 | val loss=0.5977(mal=0.4570,sub=0.3518), auc=0.9542, f1=0.7652, recall=0.9099, oracle_f1=0.1420, cascade_acc=0.5135
#   -> best saved (val_auc=0.9542): ct_cascade_models18/ResNet18_fold3_best.pth
# [ResNet18][Fold 3][Epoch 02] sub_w=0.414 | train loss=0.9811(mal=0.5181,sub=1.1190), auc=0.9327, f1=0.7298, recall=0.8761, oracle_f1=0.2038, cascade_acc=0.5158 | val loss=0.6084(mal=0.4394,sub=0.4084), auc=0.9590, f1=0.8174, recall=0.8468, oracle_f1=0.1350, cascade_acc=0.4685
#   -> best saved (val_auc=0.9590): ct_cascade_models18/ResNet18_fold3_best.pth
# [ResNet18][Fold 3][Epoch 03] sub_w=0.428 | train loss=1.0126(mal=0.4815,sub=1.2422), auc=0.9415, f1=0.7539, recall=0.8761, oracle_f1=0.2618, cascade_acc=0.4932 | val loss=0.7454(mal=0.5971,sub=0.3467), auc=0.9616, f1=0.7653, recall=0.6757, oracle_f1=0.2307, cascade_acc=0.4054
#   -> best saved (val_auc=0.9616): ct_cascade_models18/ResNet18_fold3_best.pth
# [ResNet18][Fold 3][Epoch 04] sub_w=0.441 | train loss=0.9437(mal=0.4261,sub=1.1727), auc=0.9557, f1=0.7737, recall=0.9009, oracle_f1=0.2964, cascade_acc=0.5360 | val loss=0.5305(mal=0.3809,sub=0.3390), auc=0.9653, f1=0.7951, recall=0.8739, oracle_f1=0.2735, cascade_acc=0.4955
#   -> best saved (val_auc=0.9653): ct_cascade_models18/ResNet18_fold3_best.pth
# [ResNet18][Fold 3][Epoch 05] sub_w=0.455 | train loss=0.9105(mal=0.4020,sub=1.1171), auc=0.9591, f1=0.7863, recall=0.9077, oracle_f1=0.2944, cascade_acc=0.5383 | val loss=0.5865(mal=0.4291,sub=0.3457), auc=0.9582, f1=0.7826, recall=0.8919, oracle_f1=0.2873, cascade_acc=0.5135
#   -> no improvement (1/7)
# [ResNet18][Fold 3][Epoch 06] sub_w=0.469 | train loss=0.8776(mal=0.3396,sub=1.1473), auc=0.9721, f1=0.8268, recall=0.9302, oracle_f1=0.3217, cascade_acc=0.5541 | val loss=0.5597(mal=0.3972,sub=0.3464), auc=0.9656, f1=0.8326, recall=0.8739, oracle_f1=0.2779, cascade_acc=0.5045
#   -> no improvement (2/7)
# [ResNet18][Fold 3][Epoch 07] sub_w=0.483 | train loss=0.8635(mal=0.3587,sub=1.0456), auc=0.9674, f1=0.8128, recall=0.9144, oracle_f1=0.3286, cascade_acc=0.5608 | val loss=0.5914(mal=0.4262,sub=0.3421), auc=0.9599, f1=0.7658, recall=0.9279, oracle_f1=0.1994, cascade_acc=0.4414
#   -> no improvement (3/7)
# [ResNet18][Fold 3][Epoch 08] sub_w=0.497 | train loss=0.8433(mal=0.3085,sub=1.0771), auc=0.9756, f1=0.8296, recall=0.9212, oracle_f1=0.3514, cascade_acc=0.5653 | val loss=0.6106(mal=0.4224,sub=0.3790), auc=0.9670, f1=0.8333, recall=0.9009, oracle_f1=0.1959, cascade_acc=0.4865
#   -> best saved (val_auc=0.9670): ct_cascade_models18/ResNet18_fold3_best.pth
# [ResNet18][Fold 3][Epoch 09] sub_w=0.510 | train loss=0.7932(mal=0.2719,sub=1.0216), auc=0.9808, f1=0.8433, recall=0.9392, oracle_f1=0.3492, cascade_acc=0.5698 | val loss=0.6080(mal=0.4177,sub=0.3728), auc=0.9641, f1=0.8145, recall=0.9099, oracle_f1=0.2466, cascade_acc=0.4955
#   -> no improvement (1/7)
# [ResNet18][Fold 3][Epoch 10] sub_w=0.524 | train loss=0.7639(mal=0.2375,sub=1.0043), auc=0.9850, f1=0.8671, recall=0.9482, oracle_f1=0.3754, cascade_acc=0.5901 | val loss=0.7104(mal=0.5146,sub=0.3736), auc=0.9650, f1=0.7138, recall=0.9550, oracle_f1=0.2772, cascade_acc=0.5135
#   -> no improvement (2/7)
# [ResNet18][Fold 3][Epoch 11] sub_w=0.538 | train loss=0.7606(mal=0.2361,sub=0.9751), auc=0.9855, f1=0.8638, recall=0.9572, oracle_f1=0.3866, cascade_acc=0.6081 | val loss=0.6943(mal=0.4681,sub=0.4205), auc=0.9632, f1=0.7886, recall=0.8739, oracle_f1=0.3028, cascade_acc=0.4955
#   -> no improvement (3/7)
# [ResNet18][Fold 3][Epoch 12] sub_w=0.552 | train loss=0.8033(mal=0.2621,sub=0.9809), auc=0.9824, f1=0.8539, recall=0.9414, oracle_f1=0.4663, cascade_acc=0.6419 | val loss=0.7929(mal=0.5487,sub=0.4426), auc=0.9575, f1=0.7932, recall=0.8468, oracle_f1=0.2967, cascade_acc=0.4865
#   -> no improvement (4/7)
# [ResNet18][Fold 3][Epoch 13] sub_w=0.566 | train loss=0.7048(mal=0.2173,sub=0.8620), auc=0.9873, f1=0.8850, recall=0.9617, oracle_f1=0.4123, cascade_acc=0.6081 | val loss=0.7463(mal=0.5533,sub=0.3413), auc=0.9596, f1=0.8106, recall=0.8288, oracle_f1=0.3089, cascade_acc=0.4685
#   -> no improvement (5/7)
# [ResNet18][Fold 3][Epoch 14] sub_w=0.579 | train loss=0.7098(mal=0.2069,sub=0.8682), auc=0.9882, f1=0.8880, recall=0.9550, oracle_f1=0.4943, cascade_acc=0.6509 | val loss=0.6448(mal=0.4467,sub=0.3420), auc=0.9651, f1=0.7774, recall=0.9279, oracle_f1=0.3364, cascade_acc=0.4685
#   -> no improvement (6/7)
# [ResNet18][Fold 3][Epoch 15] sub_w=0.593 | train loss=0.6427(mal=0.1741,sub=0.7901), auc=0.9922, f1=0.8971, recall=0.9617, oracle_f1=0.5264, cascade_acc=0.6599 | val loss=0.9408(mal=0.6832,sub=0.4343), auc=0.9562, f1=0.8205, recall=0.8649, oracle_f1=0.2813, cascade_acc=0.4865
#   -> no improvement (7/7)
#   -> early stopping triggered at epoch 15
#
# -- Final Evaluation --
# [Malignancy]  AUC=0.9670, F1=0.8333, Recall=0.9009, Acc=0.9219
# [Subtype Oracle]  Acc=0.4865, MacroF1=0.1959
# [Cascade]  SubtypeAcc=0.4865, GateRecall=0.9009
# Binary CM:
# [[372  29]
#  [ 11 100]]
# Subtype Oracle CM:
# [[ 0  0  0  0  8]
#  [ 0  2  2  1 12]
#  [ 0  1  0  1 10]
#  [ 0  5  3  1  2]
#  [ 0  4  8  0 51]]
#
# [ResNet18][Fold 3] Final Metrics
# Malignancy  AUC=0.9670, F1=0.8333, Recall=0.9009
# Subtype Oracle  Acc=0.4865, MacroF1=0.1959
# Cascade  Acc=0.4865, GateRecall=0.9009
#
# ================================================================================
# Running ResNet18 | Fold 4
# ================================================================================
# [FOLD 4] Train benign(0): 1606, malignant(1): 444, pos_weight=3.6171, subtype_counts=[33.0, 67.0, 48.0, 47.0, 249.0], subtype_class_weights=[1.6584999561309814, 0.8169000148773193, 1.1402000188827515, 1.1644999980926514, 0.21979999542236328]
# [ResNet18][Fold 4][Epoch 01] sub_w=0.400 | train loss=1.2219(mal=0.7016,sub=1.3008), auc=0.8800, f1=0.6391, recall=0.8694, oracle_f1=0.1402, cascade_acc=0.4820 | val loss=0.6339(mal=0.4944,sub=0.3488), auc=0.9506, f1=0.6983, recall=0.9279, oracle_f1=0.1434, cascade_acc=0.5405
#   -> best saved (val_auc=0.9506): ct_cascade_models18/ResNet18_fold4_best.pth
# [ResNet18][Fold 4][Epoch 02] sub_w=0.414 | train loss=0.9960(mal=0.5005,sub=1.1973), auc=0.9369, f1=0.7393, recall=0.8716, oracle_f1=0.1438, cascade_acc=0.4910 | val loss=0.6903(mal=0.5493,sub=0.3408), auc=0.9522, f1=0.8095, recall=0.7658, oracle_f1=0.1835, cascade_acc=0.4685
#   -> best saved (val_auc=0.9522): ct_cascade_models18/ResNet18_fold4_best.pth
# [ResNet18][Fold 4][Epoch 03] sub_w=0.428 | train loss=0.9444(mal=0.4353,sub=1.1906), auc=0.9528, f1=0.7559, recall=0.9032, oracle_f1=0.1815, cascade_acc=0.5225 | val loss=0.5760(mal=0.4210,sub=0.3626), auc=0.9599, f1=0.7795, recall=0.8919, oracle_f1=0.1775, cascade_acc=0.5315
#   -> best saved (val_auc=0.9599): ct_cascade_models18/ResNet18_fold4_best.pth
# [ResNet18][Fold 4][Epoch 04] sub_w=0.441 | train loss=0.9144(mal=0.3912,sub=1.1854), auc=0.9614, f1=0.7809, recall=0.9032, oracle_f1=0.2140, cascade_acc=0.5180 | val loss=0.6430(mal=0.4866,sub=0.3544), auc=0.9571, f1=0.7047, recall=0.9459, oracle_f1=0.3660, cascade_acc=0.6126
#   -> no improvement (1/7)
# [ResNet18][Fold 4][Epoch 05] sub_w=0.455 | train loss=0.8941(mal=0.3767,sub=1.1365), auc=0.9630, f1=0.8064, recall=0.9144, oracle_f1=0.2404, cascade_acc=0.5270 | val loss=0.6174(mal=0.4658,sub=0.3330), auc=0.9529, f1=0.7353, recall=0.9009, oracle_f1=0.3375, cascade_acc=0.4955
#   -> no improvement (2/7)
# [ResNet18][Fold 4][Epoch 06] sub_w=0.469 | train loss=0.8328(mal=0.2922,sub=1.1529), auc=0.9781, f1=0.8516, recall=0.9369, oracle_f1=0.2794, cascade_acc=0.5586 | val loss=0.6512(mal=0.4900,sub=0.3437), auc=0.9642, f1=0.7715, recall=0.9279, oracle_f1=0.3789, cascade_acc=0.5676
#   -> best saved (val_auc=0.9642): ct_cascade_models18/ResNet18_fold4_best.pth
# [ResNet18][Fold 4][Epoch 07] sub_w=0.483 | train loss=0.8042(mal=0.2812,sub=1.0832), auc=0.9792, f1=0.8419, recall=0.9414, oracle_f1=0.2939, cascade_acc=0.5563 | val loss=0.6264(mal=0.4572,sub=0.3504), auc=0.9607, f1=0.8033, recall=0.8829, oracle_f1=0.3865, cascade_acc=0.5405
#   -> no improvement (1/7)
# [ResNet18][Fold 4][Epoch 08] sub_w=0.497 | train loss=0.7701(mal=0.2730,sub=1.0010), auc=0.9808, f1=0.8522, recall=0.9414, oracle_f1=0.3265, cascade_acc=0.5766 | val loss=0.6950(mal=0.5163,sub=0.3598), auc=0.9544, f1=0.7920, recall=0.8919, oracle_f1=0.2831, cascade_acc=0.5225
#   -> no improvement (2/7)
# [ResNet18][Fold 4][Epoch 09] sub_w=0.510 | train loss=0.7840(mal=0.2668,sub=1.0133), auc=0.9814, f1=0.8520, recall=0.9527, oracle_f1=0.3114, cascade_acc=0.5766 | val loss=0.6166(mal=0.4488,sub=0.3289), auc=0.9596, f1=0.7891, recall=0.9099, oracle_f1=0.3669, cascade_acc=0.4955
#   -> no improvement (3/7)
# [ResNet18][Fold 4][Epoch 10] sub_w=0.524 | train loss=0.7278(mal=0.1950,sub=1.0166), auc=0.9896, f1=0.8907, recall=0.9640, oracle_f1=0.3919, cascade_acc=0.6261 | val loss=0.7592(mal=0.5621,sub=0.3761), auc=0.9658, f1=0.8145, recall=0.8108, oracle_f1=0.3894, cascade_acc=0.4685
#   -> best saved (val_auc=0.9658): ct_cascade_models18/ResNet18_fold4_best.pth
# [ResNet18][Fold 4][Epoch 11] sub_w=0.538 | train loss=0.6856(mal=0.1925,sub=0.9167), auc=0.9891, f1=0.8975, recall=0.9662, oracle_f1=0.4221, cascade_acc=0.6374 | val loss=0.7094(mal=0.5150,sub=0.3613), auc=0.9709, f1=0.8364, recall=0.8288, oracle_f1=0.4178, cascade_acc=0.5225
#   -> best saved (val_auc=0.9709): ct_cascade_models18/ResNet18_fold4_best.pth
# [ResNet18][Fold 4][Epoch 12] sub_w=0.552 | train loss=0.7449(mal=0.2193,sub=0.9526), auc=0.9871, f1=0.8912, recall=0.9595, oracle_f1=0.4227, cascade_acc=0.6149 | val loss=0.6428(mal=0.4489,sub=0.3515), auc=0.9706, f1=0.8487, recall=0.9099, oracle_f1=0.3183, cascade_acc=0.4685
#   -> no improvement (1/7)
# [ResNet18][Fold 4][Epoch 13] sub_w=0.566 | train loss=0.6641(mal=0.1985,sub=0.8233), auc=0.9895, f1=0.8849, recall=0.9527, oracle_f1=0.4652, cascade_acc=0.6374 | val loss=0.6813(mal=0.4926,sub=0.3338), auc=0.9679, f1=0.8348, recall=0.8649, oracle_f1=0.3657, cascade_acc=0.4324
#   -> no improvement (2/7)
# [ResNet18][Fold 4][Epoch 14] sub_w=0.579 | train loss=0.6385(mal=0.1515,sub=0.8407), auc=0.9932, f1=0.9208, recall=0.9820, oracle_f1=0.5024, cascade_acc=0.6712 | val loss=0.7433(mal=0.5385,sub=0.3535), auc=0.9608, f1=0.8033, recall=0.8829, oracle_f1=0.3666, cascade_acc=0.5315
#   -> no improvement (3/7)
# [ResNet18][Fold 4][Epoch 15] sub_w=0.593 | train loss=0.6647(mal=0.1783,sub=0.8201), auc=0.9914, f1=0.9045, recall=0.9595, oracle_f1=0.5006, cascade_acc=0.6532 | val loss=0.6266(mal=0.4217,sub=0.3455), auc=0.9729, f1=0.8509, recall=0.8739, oracle_f1=0.4212, cascade_acc=0.5045
#   -> best saved (val_auc=0.9729): ct_cascade_models18/ResNet18_fold4_best.pth
# [ResNet18][Fold 4][Epoch 16] sub_w=0.607 | train loss=0.5891(mal=0.1434,sub=0.7344), auc=0.9941, f1=0.9219, recall=0.9707, oracle_f1=0.5884, cascade_acc=0.7095 | val loss=0.7092(mal=0.4568,sub=0.4158), auc=0.9683, f1=0.8279, recall=0.9099, oracle_f1=0.4060, cascade_acc=0.4955
#   -> no improvement (1/7)
# [ResNet18][Fold 4][Epoch 17] sub_w=0.621 | train loss=0.5620(mal=0.1553,sub=0.6551), auc=0.9936, f1=0.9196, recall=0.9662, oracle_f1=0.5792, cascade_acc=0.7230 | val loss=0.6818(mal=0.4453,sub=0.3811), auc=0.9715, f1=0.8452, recall=0.9099, oracle_f1=0.3148, cascade_acc=0.3514
#   -> no improvement (2/7)
# [ResNet18][Fold 4][Epoch 18] sub_w=0.634 | train loss=0.5494(mal=0.1456,sub=0.6365), auc=0.9944, f1=0.9226, recall=0.9662, oracle_f1=0.6130, cascade_acc=0.7252 | val loss=0.6726(mal=0.4181,sub=0.4011), auc=0.9737, f1=0.7969, recall=0.9189, oracle_f1=0.3871, cascade_acc=0.5135
#   -> no improvement (3/7)
# [ResNet18][Fold 4][Epoch 19] sub_w=0.648 | train loss=0.5283(mal=0.1316,sub=0.6119), auc=0.9948, f1=0.9293, recall=0.9775, oracle_f1=0.6969, cascade_acc=0.7770 | val loss=0.9697(mal=0.5801,sub=0.6009), auc=0.9649, f1=0.8276, recall=0.8649, oracle_f1=0.3991, cascade_acc=0.5225
#   -> no improvement (4/7)
# [ResNet18][Fold 4][Epoch 20] sub_w=0.662 | train loss=0.3894(mal=0.0781,sub=0.4702), auc=0.9984, f1=0.9520, recall=0.9820, oracle_f1=0.7705, cascade_acc=0.8378 | val loss=0.8480(mal=0.5879,sub=0.3927), auc=0.9694, f1=0.8304, recall=0.8378, oracle_f1=0.4195, cascade_acc=0.4685
#   -> no improvement (5/7)
# [ResNet18][Fold 4][Epoch 21] sub_w=0.676 | train loss=0.4904(mal=0.1249,sub=0.5407), auc=0.9959, f1=0.9349, recall=0.9707, oracle_f1=0.7202, cascade_acc=0.7680 | val loss=1.2360(mal=0.9835,sub=0.3737), auc=0.9659, f1=0.8000, recall=0.7568, oracle_f1=0.3819, cascade_acc=0.3964
#   -> no improvement (6/7)
# [ResNet18][Fold 4][Epoch 22] sub_w=0.690 | train loss=0.4612(mal=0.1541,sub=0.4452), auc=0.9934, f1=0.9229, recall=0.9707, oracle_f1=0.7728, cascade_acc=0.8266 | val loss=0.7526(mal=0.4820,sub=0.3923), auc=0.9675, f1=0.8174, recall=0.8468, oracle_f1=0.3557, cascade_acc=0.4144
#   -> no improvement (7/7)
#   -> early stopping triggered at epoch 22
#
# -- Final Evaluation --
# [Malignancy]  AUC=0.9729, F1=0.8509, Recall=0.8739, Acc=0.9336
# [Subtype Oracle]  Acc=0.5586, MacroF1=0.4212
# [Cascade]  SubtypeAcc=0.5045, GateRecall=0.8739
# Binary CM:
# [[381  20]
#  [ 14  97]]
# Subtype Oracle CM:
# [[ 1  1  0  0  7]
#  [ 0 11  3  0  3]
#  [ 2  3  5  0  2]
#  [ 0  2  3  3  3]
#  [ 2 14  4  0 42]]
#
# [ResNet18][Fold 4] Final Metrics
# Malignancy  AUC=0.9729, F1=0.8509, Recall=0.8739
# Subtype Oracle  Acc=0.5586, MacroF1=0.4212
# Cascade  Acc=0.5045, GateRecall=0.8739
#
# ================================================================================
# Running ResNet18 | Fold 5
# ================================================================================
# [FOLD 5] Train benign(0): 1606, malignant(1): 444, pos_weight=3.6171, subtype_counts=[33.0, 68.0, 48.0, 46.0, 249.0], subtype_class_weights=[1.654099941253662, 0.8026999831199646, 1.1371999979019165, 1.1866999864578247, 0.219200000166893]
# [ResNet18][Fold 5][Epoch 01] sub_w=0.400 | train loss=1.1913(mal=0.7042,sub=1.2179), auc=0.8750, f1=0.6210, recall=0.8063, oracle_f1=0.1698, cascade_acc=0.4662 | val loss=0.6504(mal=0.5143,sub=0.3401), auc=0.9337, f1=0.7365, recall=0.9189, oracle_f1=0.1412, cascade_acc=0.5225
#   -> best saved (val_auc=0.9337): ct_cascade_models18/ResNet18_fold5_best.pth
# [ResNet18][Fold 5][Epoch 02] sub_w=0.414 | train loss=0.9820(mal=0.4835,sub=1.2049), auc=0.9415, f1=0.7361, recall=0.8671, oracle_f1=0.2103, cascade_acc=0.5023 | val loss=0.6504(mal=0.5055,sub=0.3502), auc=0.9396, f1=0.7464, recall=0.9279, oracle_f1=0.1888, cascade_acc=0.5586
#   -> best saved (val_auc=0.9396): ct_cascade_models18/ResNet18_fold5_best.pth
# [ResNet18][Fold 5][Epoch 03] sub_w=0.428 | train loss=0.9219(mal=0.4145,sub=1.1866), auc=0.9566, f1=0.7857, recall=0.9167, oracle_f1=0.2755, cascade_acc=0.5405 | val loss=0.7412(mal=0.5886,sub=0.3569), auc=0.9294, f1=0.7429, recall=0.8198, oracle_f1=0.1890, cascade_acc=0.5135
#   -> no improvement (1/7)
# [ResNet18][Fold 5][Epoch 04] sub_w=0.441 | train loss=0.9013(mal=0.4176,sub=1.0959), auc=0.9558, f1=0.7793, recall=0.8986, oracle_f1=0.2602, cascade_acc=0.5450 | val loss=0.6466(mal=0.4939,sub=0.3460), auc=0.9432, f1=0.7549, recall=0.8739, oracle_f1=0.2227, cascade_acc=0.5315
#   -> best saved (val_auc=0.9432): ct_cascade_models18/ResNet18_fold5_best.pth
# [ResNet18][Fold 5][Epoch 05] sub_w=0.455 | train loss=0.8519(mal=0.3646,sub=1.0705), auc=0.9662, f1=0.8055, recall=0.9189, oracle_f1=0.3097, cascade_acc=0.5518 | val loss=0.7323(mal=0.5694,sub=0.3579), auc=0.9450, f1=0.7964, recall=0.7928, oracle_f1=0.2639, cascade_acc=0.4595
#   -> best saved (val_auc=0.9450): ct_cascade_models18/ResNet18_fold5_best.pth
# [ResNet18][Fold 5][Epoch 06] sub_w=0.469 | train loss=0.8194(mal=0.3302,sub=1.0430), auc=0.9715, f1=0.8222, recall=0.9324, oracle_f1=0.3261, cascade_acc=0.5653 | val loss=0.8223(mal=0.6286,sub=0.4130), auc=0.9360, f1=0.6645, recall=0.9099, oracle_f1=0.2556, cascade_acc=0.5315
#   -> no improvement (1/7)
# [ResNet18][Fold 5][Epoch 07] sub_w=0.483 | train loss=0.7715(mal=0.2696,sub=1.0396), auc=0.9806, f1=0.8534, recall=0.9437, oracle_f1=0.3725, cascade_acc=0.5631 | val loss=0.7437(mal=0.5630,sub=0.3742), auc=0.9436, f1=0.7462, recall=0.8739, oracle_f1=0.2558, cascade_acc=0.4595
#   -> no improvement (2/7)
# [ResNet18][Fold 5][Epoch 08] sub_w=0.497 | train loss=0.7575(mal=0.2756,sub=0.9705), auc=0.9806, f1=0.8402, recall=0.9414, oracle_f1=0.4117, cascade_acc=0.6059 | val loss=0.6875(mal=0.5035,sub=0.3707), auc=0.9493, f1=0.7481, recall=0.9099, oracle_f1=0.2373, cascade_acc=0.4234
#   -> best saved (val_auc=0.9493): ct_cascade_models18/ResNet18_fold5_best.pth
# [ResNet18][Fold 5][Epoch 09] sub_w=0.510 | train loss=0.7137(mal=0.2570,sub=0.8948), auc=0.9827, f1=0.8574, recall=0.9550, oracle_f1=0.4067, cascade_acc=0.6036 | val loss=0.8159(mal=0.5883,sub=0.4460), auc=0.9453, f1=0.7918, recall=0.8739, oracle_f1=0.2842, cascade_acc=0.4505
#   -> no improvement (1/7)
# [ResNet18][Fold 5][Epoch 10] sub_w=0.524 | train loss=0.7494(mal=0.2443,sub=0.9637), auc=0.9849, f1=0.8678, recall=0.9459, oracle_f1=0.4388, cascade_acc=0.6149 | val loss=0.8008(mal=0.5807,sub=0.4199), auc=0.9489, f1=0.7983, recall=0.8559, oracle_f1=0.3543, cascade_acc=0.4955
#   -> no improvement (2/7)
# [ResNet18][Fold 5][Epoch 11] sub_w=0.538 | train loss=0.7194(mal=0.2314,sub=0.9070), auc=0.9858, f1=0.8803, recall=0.9527, oracle_f1=0.4890, cascade_acc=0.6509 | val loss=0.7616(mal=0.5530,sub=0.3878), auc=0.9495, f1=0.7729, recall=0.8739, oracle_f1=0.3035, cascade_acc=0.4775
#   -> no improvement (3/7)
# [ResNet18][Fold 5][Epoch 12] sub_w=0.552 | train loss=0.6506(mal=0.1987,sub=0.8190), auc=0.9899, f1=0.8836, recall=0.9572, oracle_f1=0.4905, cascade_acc=0.6644 | val loss=0.7315(mal=0.4967,sub=0.4257), auc=0.9585, f1=0.7920, recall=0.8919, oracle_f1=0.2536, cascade_acc=0.4414
#   -> best saved (val_auc=0.9585): ct_cascade_models18/ResNet18_fold5_best.pth
# [ResNet18][Fold 5][Epoch 13] sub_w=0.566 | train loss=0.5812(mal=0.1809,sub=0.7078), auc=0.9910, f1=0.9045, recall=0.9707, oracle_f1=0.5174, cascade_acc=0.6802 | val loss=0.9825(mal=0.6927,sub=0.5125), auc=0.9467, f1=0.7729, recall=0.8739, oracle_f1=0.2796, cascade_acc=0.4505
#   -> no improvement (1/7)
# [ResNet18][Fold 5][Epoch 14] sub_w=0.579 | train loss=0.6182(mal=0.1675,sub=0.7780), auc=0.9924, f1=0.9025, recall=0.9595, oracle_f1=0.5020, cascade_acc=0.6329 | val loss=1.0112(mal=0.7423,sub=0.4641), auc=0.9412, f1=0.7692, recall=0.8108, oracle_f1=0.3654, cascade_acc=0.5225
#   -> no improvement (2/7)
# [ResNet18][Fold 5][Epoch 15] sub_w=0.593 | train loss=0.6386(mal=0.2417,sub=0.6692), auc=0.9852, f1=0.8705, recall=0.9459, oracle_f1=0.5518, cascade_acc=0.6824 | val loss=0.7817(mal=0.5129,sub=0.4532), auc=0.9569, f1=0.8016, recall=0.8919, oracle_f1=0.3612, cascade_acc=0.4955
#   -> no improvement (3/7)
# [ResNet18][Fold 5][Epoch 16] sub_w=0.607 | train loss=0.5579(mal=0.1780,sub=0.6260), auc=0.9915, f1=0.9064, recall=0.9595, oracle_f1=0.6346, cascade_acc=0.7320 | val loss=0.8592(mal=0.5406,sub=0.5250), auc=0.9561, f1=0.8000, recall=0.8829, oracle_f1=0.2494, cascade_acc=0.3694
#   -> no improvement (4/7)
# [ResNet18][Fold 5][Epoch 17] sub_w=0.621 | train loss=0.5234(mal=0.1585,sub=0.5880), auc=0.9935, f1=0.9068, recall=0.9640, oracle_f1=0.6402, cascade_acc=0.7320 | val loss=0.9843(mal=0.6718,sub=0.5035), auc=0.9541, f1=0.8072, recall=0.8108, oracle_f1=0.2903, cascade_acc=0.3874
#   -> no improvement (5/7)
# [ResNet18][Fold 5][Epoch 18] sub_w=0.634 | train loss=0.4963(mal=0.1268,sub=0.5823), auc=0.9960, f1=0.9309, recall=0.9707, oracle_f1=0.6426, cascade_acc=0.7432 | val loss=0.9429(mal=0.5928,sub=0.5518), auc=0.9535, f1=0.7918, recall=0.8739, oracle_f1=0.3614, cascade_acc=0.5135
#   -> no improvement (6/7)
# [ResNet18][Fold 5][Epoch 19] sub_w=0.648 | train loss=0.4956(mal=0.1299,sub=0.5641), auc=0.9951, f1=0.9353, recall=0.9775, oracle_f1=0.6866, cascade_acc=0.7568 | val loss=1.0503(mal=0.6597,sub=0.6025), auc=0.9496, f1=0.7899, recall=0.8468, oracle_f1=0.3332, cascade_acc=0.4865
#   -> no improvement (7/7)
#   -> early stopping triggered at epoch 19
#
# -- Final Evaluation --
# [Malignancy]  AUC=0.9585, F1=0.7920, Recall=0.8919, Acc=0.8984
# [Subtype Oracle]  Acc=0.4775, MacroF1=0.2536
# [Cascade]  SubtypeAcc=0.4414, GateRecall=0.8919
# Binary CM:
# [[361  40]
#  [ 12  99]]
# Subtype Oracle CM:
# [[ 0  1  1  1  6]
#  [ 0  4  1  3  8]
#  [ 0  2  1  4  5]
#  [ 0  1  1  3  7]
#  [ 4 10  0  3 45]]
#
# [ResNet18][Fold 5] Final Metrics
# Malignancy  AUC=0.9585, F1=0.7920, Recall=0.8919
# Subtype Oracle  Acc=0.4775, MacroF1=0.2536
# Cascade  Acc=0.4414, GateRecall=0.8919
#       model  fold   mal_acc   mal_auc    mal_f1  mal_recall  \
# 0  ResNet18     1  0.914230  0.978901  0.830769    0.972973
# 1  ResNet18     2  0.906433  0.963437  0.806452    0.900901
# 2  ResNet18     3  0.921875  0.966986  0.833333    0.900901
# 3  ResNet18     4  0.933594  0.972906  0.850877    0.873874
# 4  ResNet18     5  0.898438  0.958516  0.792000    0.891892
#
#    subtype_oracle_acc  subtype_oracle_macro_f1  subtype_cascade_acc  \
# 0            0.558559                 0.143353             0.540541
# 1            0.585586                 0.292308             0.549550
# 2            0.486486                 0.195884             0.486486
# 3            0.558559                 0.421203             0.504505
# 4            0.477477                 0.253551             0.441441
#
#    subtype_gate_recall               binary_cm  \
# 0             0.972973   [[361, 41], [3, 108]]
# 1             0.900901  [[365, 37], [11, 100]]
# 2             0.900901  [[372, 29], [11, 100]]
# 3             0.873874   [[381, 20], [14, 97]]
# 4             0.891892   [[361, 40], [12, 99]]
#
#                                    subtype_oracle_cm
# 0  [[0, 0, 0, 0, 8], [0, 0, 0, 0, 17], [0, 0, 0, ...
# 1  [[0, 0, 0, 0, 8], [0, 6, 2, 1, 8], [0, 1, 0, 1...
# 2  [[0, 0, 0, 0, 8], [0, 2, 2, 1, 12], [0, 1, 0, ...
# 3  [[1, 1, 0, 0, 7], [0, 11, 3, 0, 3], [2, 3, 5, ...
# 4  [[0, 1, 1, 1, 6], [0, 4, 1, 3, 8], [0, 2, 1, 4...
# >>> Training ViT-B/16...
#
# ================================================================================
# Running ViT-B16 | Fold 1
# ================================================================================
# [FOLD 1] Train benign(0): 1605, malignant(1): 444, pos_weight=3.6149, subtype_counts=[34.0, 67.0, 48.0, 46.0, 249.0], subtype_class_weights=[1.617400050163269, 0.8206999897956848, 1.1455999612808228, 1.1953999996185303, 0.2207999974489212]
# [ViT-B16][Fold 1][Epoch 01] sub_w=0.400 | train loss=1.6075(mal=1.0939,sub=1.2841), auc=0.5001, f1=0.3150, recall=0.5495, oracle_f1=0.1481, cascade_acc=0.2950 | val loss=1.2301(mal=1.0872,sub=0.3573), auc=0.5805, f1=0.3558, recall=1.0000, oracle_f1=0.1434, cascade_acc=0.5586
#   -> best saved (val_auc=0.5805): ct_cascade_models18/ViT-B16_fold1_best.pth
# [ViT-B16][Fold 1][Epoch 02] sub_w=0.414 | train loss=1.6163(mal=1.0872,sub=1.2788), auc=0.5176, f1=0.3370, recall=0.6577, oracle_f1=0.1437, cascade_acc=0.3604 | val loss=1.2491(mal=1.0945,sub=0.3736), auc=0.6186, f1=0.3558, recall=1.0000, oracle_f1=0.1434, cascade_acc=0.5586
#   -> best saved (val_auc=0.6186): ct_cascade_models18/ViT-B16_fold1_best.pth
# [ViT-B16][Fold 1][Epoch 03] sub_w=0.428 | train loss=1.6291(mal=1.0910,sub=1.2584), auc=0.4830, f1=0.3077, recall=0.5315, oracle_f1=0.1437, cascade_acc=0.2838 | val loss=1.2506(mal=1.0887,sub=0.3788), auc=0.6539, f1=0.0000, recall=0.0000, oracle_f1=0.1434, cascade_acc=0.0000
#   -> best saved (val_auc=0.6539): ct_cascade_models18/ViT-B16_fold1_best.pth
# [ViT-B16][Fold 1][Epoch 04] sub_w=0.441 | train loss=1.6385(mal=1.0890,sub=1.2449), auc=0.4930, f1=0.3047, recall=0.5315, oracle_f1=0.1437, cascade_acc=0.3041 | val loss=1.2398(mal=1.0818,sub=0.3579), auc=0.6781, f1=0.4454, recall=0.9189, oracle_f1=0.1434, cascade_acc=0.5045
#   -> best saved (val_auc=0.6781): ct_cascade_models18/ViT-B16_fold1_best.pth
# [ViT-B16][Fold 1][Epoch 05] sub_w=0.455 | train loss=1.6708(mal=1.0894,sub=1.2774), auc=0.4998, f1=0.3080, recall=0.5563, oracle_f1=0.1437, cascade_acc=0.2928 | val loss=1.2553(mal=1.0854,sub=0.3733), auc=0.6805, f1=0.0000, recall=0.0000, oracle_f1=0.1434, cascade_acc=0.0000
#   -> best saved (val_auc=0.6805): ct_cascade_models18/ViT-B16_fold1_best.pth
# [ViT-B16][Fold 1][Epoch 06] sub_w=0.469 | train loss=1.7230(mal=1.1007,sub=1.3269), auc=0.4741, f1=0.2630, recall=0.3761, oracle_f1=0.1658, cascade_acc=0.2185 | val loss=1.2593(mal=1.0922,sub=0.3562), auc=0.3602, f1=0.3558, recall=1.0000, oracle_f1=0.1434, cascade_acc=0.5586
#   -> no improvement (1/7)
# [ViT-B16][Fold 1][Epoch 07] sub_w=0.483 | train loss=1.7172(mal=1.0900,sub=1.2992), auc=0.4775, f1=0.2916, recall=0.5068, oracle_f1=0.1437, cascade_acc=0.2860 | val loss=1.2605(mal=1.0846,sub=0.3643), auc=0.6757, f1=0.3558, recall=1.0000, oracle_f1=0.1434, cascade_acc=0.5586
#   -> no improvement (2/7)
# [ViT-B16][Fold 1][Epoch 08] sub_w=0.497 | train loss=1.7327(mal=1.0877,sub=1.2990), auc=0.4900, f1=0.3106, recall=0.5383, oracle_f1=0.1437, cascade_acc=0.2950 | val loss=1.2697(mal=1.0838,sub=0.3743), auc=0.6780, f1=0.0175, recall=0.0090, oracle_f1=0.1434, cascade_acc=0.0000
#   -> no improvement (3/7)
# [ViT-B16][Fold 1][Epoch 09] sub_w=0.510 | train loss=1.7320(mal=1.0880,sub=1.2618), auc=0.4966, f1=0.2790, recall=0.4009, oracle_f1=0.1437, cascade_acc=0.2207 | val loss=1.2730(mal=1.0853,sub=0.3678), auc=0.6798, f1=0.0000, recall=0.0000, oracle_f1=0.1434, cascade_acc=0.0000
#   -> no improvement (4/7)
# [ViT-B16][Fold 1][Epoch 10] sub_w=0.524 | train loss=1.7609(mal=1.0880,sub=1.2838), auc=0.4817, f1=0.2599, recall=0.3559, oracle_f1=0.1439, cascade_acc=0.1982 | val loss=1.2756(mal=1.0831,sub=0.3673), auc=0.6919, f1=0.0513, recall=0.0270, oracle_f1=0.1434, cascade_acc=0.0090
#   -> best saved (val_auc=0.6919): ct_cascade_models18/ViT-B16_fold1_best.pth
# [ViT-B16][Fold 1][Epoch 11] sub_w=0.538 | train loss=1.7604(mal=1.0843,sub=1.2570), auc=0.5452, f1=0.3308, recall=0.5428, oracle_f1=0.1432, cascade_acc=0.3176 | val loss=1.3326(mal=1.1254,sub=0.3853), auc=0.5867, f1=0.0000, recall=0.0000, oracle_f1=0.1434, cascade_acc=0.0000
#   -> no improvement (1/7)
# [ViT-B16][Fold 1][Epoch 12] sub_w=0.552 | train loss=1.7755(mal=1.0906,sub=1.2413), auc=0.4971, f1=0.2644, recall=0.3311, oracle_f1=0.1437, cascade_acc=0.1937 | val loss=1.2889(mal=1.0841,sub=0.3713), auc=0.6817, f1=0.4528, recall=0.7568, oracle_f1=0.1434, cascade_acc=0.3694
#   -> no improvement (2/7)
# [ViT-B16][Fold 1][Epoch 13] sub_w=0.566 | train loss=1.8139(mal=1.0864,sub=1.2864), auc=0.5193, f1=0.3311, recall=0.6261, oracle_f1=0.1437, cascade_acc=0.3626 | val loss=1.3137(mal=1.0894,sub=0.3966), auc=0.6203, f1=0.0000, recall=0.0000, oracle_f1=0.1434, cascade_acc=0.0000
#   -> no improvement (3/7)
# [ViT-B16][Fold 1][Epoch 14] sub_w=0.579 | train loss=1.8004(mal=1.0884,sub=1.2291), auc=0.5038, f1=0.2970, recall=0.4820, oracle_f1=0.1437, cascade_acc=0.2725 | val loss=1.2981(mal=1.0870,sub=0.3644), auc=0.5586, f1=0.3558, recall=1.0000, oracle_f1=0.1434, cascade_acc=0.5586
#   -> no improvement (4/7)
# [ViT-B16][Fold 1][Epoch 15] sub_w=0.593 | train loss=1.8384(mal=1.0866,sub=1.2676), auc=0.5129, f1=0.3311, recall=0.6059, oracle_f1=0.1437, cascade_acc=0.3333 | val loss=1.3007(mal=1.0851,sub=0.3635), auc=0.6037, f1=0.3558, recall=1.0000, oracle_f1=0.1434, cascade_acc=0.5586
#   -> no improvement (5/7)
# [ViT-B16][Fold 1][Epoch 16] sub_w=0.607 | train loss=1.8741(mal=1.0864,sub=1.2980), auc=0.4955, f1=0.3354, recall=0.7162, oracle_f1=0.1437, cascade_acc=0.4032 | val loss=1.3194(mal=1.0906,sub=0.3770), auc=0.6788, f1=0.0000, recall=0.0000, oracle_f1=0.1434, cascade_acc=0.0000
#   -> no improvement (6/7)
# [ViT-B16][Fold 1][Epoch 17] sub_w=0.621 | train loss=1.8711(mal=1.0889,sub=1.2601), auc=0.4800, f1=0.2773, recall=0.4054, oracle_f1=0.1437, cascade_acc=0.2185 | val loss=1.3184(mal=1.0851,sub=0.3758), auc=0.6703, f1=0.0000, recall=0.0000, oracle_f1=0.1434, cascade_acc=0.0000
#   -> no improvement (7/7)
#   -> early stopping triggered at epoch 17
#
# -- Final Evaluation --
# [Malignancy]  AUC=0.6919, F1=0.0513, Recall=0.0270, Acc=0.7836
# [Subtype Oracle]  Acc=0.5586, MacroF1=0.1434
# [Cascade]  SubtypeAcc=0.0090, GateRecall=0.0270
# Binary CM:
# [[399   3]
#  [108   3]]
# Subtype Oracle CM:
# [[ 0  0  0  0  8]
#  [ 0  0  0  0 17]
#  [ 0  0  0  0 12]
#  [ 0  0  0  0 12]
#  [ 0  0  0  0 62]]
#
# [ViT-B16][Fold 1] Final Metrics
# Malignancy  AUC=0.6919, F1=0.0513, Recall=0.0270
# Subtype Oracle  Acc=0.5586, MacroF1=0.1434
# Cascade  Acc=0.0090, GateRecall=0.0270
#
# ================================================================================
# Running ViT-B16 | Fold 2
# ================================================================================
# [FOLD 2] Train benign(0): 1605, malignant(1): 444, pos_weight=3.6149, subtype_counts=[34.0, 67.0, 48.0, 46.0, 249.0], subtype_class_weights=[1.617400050163269, 0.8206999897956848, 1.1455999612808228, 1.1953999996185303, 0.2207999974489212]
# [ViT-B16][Fold 2][Epoch 01] sub_w=0.400 | train loss=1.6104(mal=1.0889,sub=1.3038), auc=0.5236, f1=0.3171, recall=0.4977, oracle_f1=0.1414, cascade_acc=0.2658 | val loss=1.2270(mal=1.0833,sub=0.3591), auc=0.6883, f1=0.3558, recall=1.0000, oracle_f1=0.1434, cascade_acc=0.5586
#   -> best saved (val_auc=0.6883): ct_cascade_models18/ViT-B16_fold2_best.pth
# [ViT-B16][Fold 2][Epoch 02] sub_w=0.414 | train loss=1.6056(mal=1.0897,sub=1.2467), auc=0.5215, f1=0.3272, recall=0.5608, oracle_f1=0.1437, cascade_acc=0.2973 | val loss=1.2389(mal=1.0851,sub=0.3716), auc=0.6276, f1=0.3558, recall=1.0000, oracle_f1=0.1434, cascade_acc=0.5586
#   -> no improvement (1/7)
# [ViT-B16][Fold 2][Epoch 03] sub_w=0.428 | train loss=1.5907(mal=1.0813,sub=1.1914), auc=0.5467, f1=0.3426, recall=0.6104, oracle_f1=0.1640, cascade_acc=0.3266 | val loss=1.2330(mal=1.0537,sub=0.4194), auc=0.6561, f1=0.4130, recall=0.6847, oracle_f1=0.1434, cascade_acc=0.3964
#   -> no improvement (2/7)
# [ViT-B16][Fold 2][Epoch 04] sub_w=0.441 | train loss=1.6437(mal=1.0785,sub=1.2804), auc=0.5587, f1=0.3282, recall=0.4820, oracle_f1=0.1437, cascade_acc=0.2905 | val loss=1.2632(mal=1.1018,sub=0.3656), auc=0.6112, f1=0.3558, recall=1.0000, oracle_f1=0.1434, cascade_acc=0.5586
#   -> no improvement (3/7)
# [ViT-B16][Fold 2][Epoch 05] sub_w=0.455 | train loss=1.6649(mal=1.0974,sub=1.2468), auc=0.4954, f1=0.3268, recall=0.6194, oracle_f1=0.1437, cascade_acc=0.3446 | val loss=1.2499(mal=1.0847,sub=0.3630), auc=0.6075, f1=0.3558, recall=1.0000, oracle_f1=0.1434, cascade_acc=0.5586
#   -> no improvement (4/7)
# [ViT-B16][Fold 2][Epoch 06] sub_w=0.469 | train loss=1.6922(mal=1.0924,sub=1.2790), auc=0.5159, f1=0.3244, recall=0.5833, oracle_f1=0.1437, cascade_acc=0.3514 | val loss=1.2645(mal=1.0892,sub=0.3737), auc=0.4150, f1=0.3558, recall=1.0000, oracle_f1=0.1434, cascade_acc=0.5586
#   -> no improvement (5/7)
# [ViT-B16][Fold 2][Epoch 07] sub_w=0.483 | train loss=1.7254(mal=1.0889,sub=1.3183), auc=0.5002, f1=0.3052, recall=0.5450, oracle_f1=0.1437, cascade_acc=0.3041 | val loss=1.2671(mal=1.0853,sub=0.3765), auc=0.6111, f1=0.0000, recall=0.0000, oracle_f1=0.1434, cascade_acc=0.0000
#   -> no improvement (6/7)
# [ViT-B16][Fold 2][Epoch 08] sub_w=0.497 | train loss=1.7130(mal=1.0885,sub=1.2577), auc=0.4895, f1=0.2710, recall=0.3851, oracle_f1=0.1437, cascade_acc=0.2275 | val loss=1.2749(mal=1.0845,sub=0.3835), auc=0.6140, f1=0.3558, recall=1.0000, oracle_f1=0.1434, cascade_acc=0.5586
#   -> no improvement (7/7)
#   -> early stopping triggered at epoch 8
#
# -- Final Evaluation --
# [Malignancy]  AUC=0.6883, F1=0.3558, Recall=1.0000, Acc=0.2164
# [Subtype Oracle]  Acc=0.5586, MacroF1=0.1434
# [Cascade]  SubtypeAcc=0.5586, GateRecall=1.0000
# Binary CM:
# [[  0 402]
#  [  0 111]]
# Subtype Oracle CM:
# [[ 0  0  0  0  8]
#  [ 0  0  0  0 17]
#  [ 0  0  0  0 12]
#  [ 0  0  0  0 12]
#  [ 0  0  0  0 62]]
#
# [ViT-B16][Fold 2] Final Metrics
# Malignancy  AUC=0.6883, F1=0.3558, Recall=1.0000
# Subtype Oracle  Acc=0.5586, MacroF1=0.1434
# Cascade  Acc=0.5586, GateRecall=1.0000
#
# ================================================================================
# Running ViT-B16 | Fold 3
# ================================================================================
# [FOLD 3] Train benign(0): 1606, malignant(1): 444, pos_weight=3.6171, subtype_counts=[34.0, 67.0, 48.0, 47.0, 248.0], subtype_class_weights=[1.6253000497817993, 0.8248000144958496, 1.1512999534606934, 1.1757999658584595, 0.22280000150203705]
# [ViT-B16][Fold 3][Epoch 01] sub_w=0.400 | train loss=1.6022(mal=1.0931,sub=1.2729), auc=0.4899, f1=0.2727, recall=0.3919, oracle_f1=0.1498, cascade_acc=0.2095 | val loss=1.2425(mal=1.0870,sub=0.3889), auc=0.7254, f1=0.3563, recall=1.0000, oracle_f1=0.1448, cascade_acc=0.5676
#   -> best saved (val_auc=0.7254): ct_cascade_models18/ViT-B16_fold3_best.pth
# [ViT-B16][Fold 3][Epoch 02] sub_w=0.414 | train loss=1.6132(mal=1.0952,sub=1.2519), auc=0.4914, f1=0.3074, recall=0.5608, oracle_f1=0.1434, cascade_acc=0.3333 | val loss=1.2443(mal=1.0940,sub=0.3633), auc=0.6348, f1=0.3563, recall=1.0000, oracle_f1=0.1448, cascade_acc=0.5676
#   -> no improvement (1/7)
# [ViT-B16][Fold 3][Epoch 03] sub_w=0.428 | train loss=1.6391(mal=1.0885,sub=1.2878), auc=0.5056, f1=0.3080, recall=0.5293, oracle_f1=0.1434, cascade_acc=0.2973 | val loss=1.2453(mal=1.0871,sub=0.3700), auc=0.6232, f1=0.3563, recall=1.0000, oracle_f1=0.1448, cascade_acc=0.5676
#   -> no improvement (2/7)
# [ViT-B16][Fold 3][Epoch 04] sub_w=0.441 | train loss=1.6600(mal=1.0887,sub=1.2945), auc=0.5166, f1=0.3405, recall=0.7095, oracle_f1=0.1434, cascade_acc=0.4099 | val loss=1.2476(mal=1.0892,sub=0.3590), auc=0.6452, f1=0.0000, recall=0.0000, oracle_f1=0.1448, cascade_acc=0.0000
#   -> no improvement (3/7)
# [ViT-B16][Fold 3][Epoch 05] sub_w=0.455 | train loss=1.6625(mal=1.0896,sub=1.2587), auc=0.4936, f1=0.2676, recall=0.3559, oracle_f1=0.1434, cascade_acc=0.2050 | val loss=1.2520(mal=1.0863,sub=0.3640), auc=0.4749, f1=0.3563, recall=1.0000, oracle_f1=0.1448, cascade_acc=0.5676
#   -> no improvement (4/7)
# [ViT-B16][Fold 3][Epoch 06] sub_w=0.469 | train loss=1.6945(mal=1.0885,sub=1.2923), auc=0.4923, f1=0.3178, recall=0.5833, oracle_f1=0.1434, cascade_acc=0.3333 | val loss=1.2693(mal=1.0867,sub=0.3893), auc=0.6334, f1=0.3563, recall=1.0000, oracle_f1=0.1448, cascade_acc=0.5676
#   -> no improvement (5/7)
# [ViT-B16][Fold 3][Epoch 07] sub_w=0.483 | train loss=1.7087(mal=1.0889,sub=1.2839), auc=0.4892, f1=0.3179, recall=0.5878, oracle_f1=0.1434, cascade_acc=0.3311 | val loss=1.2653(mal=1.0876,sub=0.3683), auc=0.6597, f1=0.0000, recall=0.0000, oracle_f1=0.1448, cascade_acc=0.0000
#   -> no improvement (6/7)
# [ViT-B16][Fold 3][Epoch 08] sub_w=0.497 | train loss=1.6996(mal=1.0895,sub=1.2286), auc=0.4943, f1=0.3070, recall=0.5293, oracle_f1=0.1434, cascade_acc=0.3041 | val loss=1.2696(mal=1.0888,sub=0.3642), auc=0.6438, f1=0.0000, recall=0.0000, oracle_f1=0.1448, cascade_acc=0.0000
#   -> no improvement (7/7)
#   -> early stopping triggered at epoch 8
#
# -- Final Evaluation --
# [Malignancy]  AUC=0.7254, F1=0.3563, Recall=1.0000, Acc=0.2168
# [Subtype Oracle]  Acc=0.5676, MacroF1=0.1448
# [Cascade]  SubtypeAcc=0.5676, GateRecall=1.0000
# Binary CM:
# [[  0 401]
#  [  0 111]]
# Subtype Oracle CM:
# [[ 0  0  0  0  8]
#  [ 0  0  0  0 17]
#  [ 0  0  0  0 12]
#  [ 0  0  0  0 11]
#  [ 0  0  0  0 63]]
#
# [ViT-B16][Fold 3] Final Metrics
# Malignancy  AUC=0.7254, F1=0.3563, Recall=1.0000
# Subtype Oracle  Acc=0.5676, MacroF1=0.1448
# Cascade  Acc=0.5676, GateRecall=1.0000
#
# ================================================================================
# Running ViT-B16 | Fold 4
# ================================================================================
# [FOLD 4] Train benign(0): 1606, malignant(1): 444, pos_weight=3.6171, subtype_counts=[33.0, 67.0, 48.0, 47.0, 249.0], subtype_class_weights=[1.6584999561309814, 0.8169000148773193, 1.1402000188827515, 1.1644999980926514, 0.21979999542236328]
# [ViT-B16][Fold 4][Epoch 01] sub_w=0.400 | train loss=1.6157(mal=1.0931,sub=1.3066), auc=0.5105, f1=0.3134, recall=0.5248, oracle_f1=0.1389, cascade_acc=0.2928 | val loss=1.2250(mal=1.0830,sub=0.3550), auc=0.6779, f1=0.2981, recall=0.2793, oracle_f1=0.1434, cascade_acc=0.1441
#   -> best saved (val_auc=0.6779): ct_cascade_models18/ViT-B16_fold4_best.pth
# [ViT-B16][Fold 4][Epoch 02] sub_w=0.414 | train loss=1.6259(mal=1.0864,sub=1.3039), auc=0.5255, f1=0.3188, recall=0.5090, oracle_f1=0.1437, cascade_acc=0.2905 | val loss=1.2353(mal=1.0886,sub=0.3544), auc=0.6333, f1=0.0000, recall=0.0000, oracle_f1=0.1434, cascade_acc=0.0000
#   -> no improvement (1/7)
# [ViT-B16][Fold 4][Epoch 03] sub_w=0.428 | train loss=1.6307(mal=1.0900,sub=1.2645), auc=0.5052, f1=0.3255, recall=0.5901, oracle_f1=0.1437, cascade_acc=0.3423 | val loss=1.2416(mal=1.0861,sub=0.3637), auc=0.6581, f1=0.0000, recall=0.0000, oracle_f1=0.1434, cascade_acc=0.0000
#   -> no improvement (2/7)
# [ViT-B16][Fold 4][Epoch 04] sub_w=0.441 | train loss=1.6467(mal=1.0823,sub=1.2789), auc=0.5546, f1=0.3210, recall=0.4685, oracle_f1=0.1515, cascade_acc=0.2477 | val loss=1.2509(mal=1.0876,sub=0.3701), auc=0.5377, f1=0.0000, recall=0.0000, oracle_f1=0.1434, cascade_acc=0.0000
#   -> no improvement (3/7)
# ...
#   -> no improvement (6/7)
# [Hybrid][Fold 3][Epoch 17] sub_w=0.621 | train loss=0.8894(mal=0.2464,sub=1.0359), auc=0.9840, f1=0.8699, recall=0.9414, oracle_f1=0.3298, cascade_acc=0.5676 | val loss=0.7623(mal=0.5301,sub=0.3740), auc=0.9596, f1=0.7757, recall=0.9189, oracle_f1=0.2549, cascade_acc=0.4865
#   -> no improvement (7/7)
#   -> early stopping triggered at epoch 17
#
# -- Final Evaluation --
# [Malignancy]  AUC=0.9752, F1=0.7749, Recall=0.9459, Acc=0.8809
# [Subtype Oracle]  Acc=0.5135, MacroF1=0.2335
# [Cascade]  SubtypeAcc=0.5135, GateRecall=0.9459
# Binary CM:
# [[346  55]
#  [  6 105]]
# Subtype Oracle CM:
# [[ 0  0  0  0  8]
#  [ 0  1  2  1 13]
#  [ 0  3  0  2  7]
#  [ 0  2  2  4  3]
#  [ 0  4  4  3 52]]
#
# [Hybrid][Fold 3] Final Metrics
# Malignancy  AUC=0.9752, F1=0.7749, Recall=0.9459
# Subtype Oracle  Acc=0.5135, MacroF1=0.2335
# Cascade  Acc=0.5135, GateRecall=0.9459
#
# ================================================================================
# Running Hybrid | Fold 4
# ================================================================================
# [FOLD 4] Train benign(0): 1606, malignant(1): 444, pos_weight=3.6171, subtype_counts=[33.0, 67.0, 48.0, 47.0, 249.0], subtype_class_weights=[1.6584999561309814, 0.8169000148773193, 1.1402000188827515, 1.1644999980926514, 0.21979999542236328]
# [Hybrid][Fold 4][Epoch 01] sub_w=0.400 | train loss=1.1922(mal=0.6991,sub=1.2329), auc=0.8720, f1=0.6455, recall=0.8243, oracle_f1=0.1555, cascade_acc=0.4707 | val loss=0.6576(mal=0.5214,sub=0.3405), auc=0.9480, f1=0.7866, recall=0.8468, oracle_f1=0.1805, cascade_acc=0.5135
#   -> best saved (val_auc=0.9480): ct_cascade_models18/Hybrid_fold4_best.pth
# [Hybrid][Fold 4][Epoch 02] sub_w=0.414 | train loss=1.0430(mal=0.5110,sub=1.2856), auc=0.9322, f1=0.7434, recall=0.8874, oracle_f1=0.1551, cascade_acc=0.5000 | val loss=0.6976(mal=0.5532,sub=0.3489), auc=0.9455, f1=0.7848, recall=0.8378, oracle_f1=0.2225, cascade_acc=0.4775
#   -> no improvement (1/7)
# [Hybrid][Fold 4][Epoch 03] sub_w=0.428 | train loss=1.0387(mal=0.4903,sub=1.2825), auc=0.9368, f1=0.7507, recall=0.9054, oracle_f1=0.1748, cascade_acc=0.5135 | val loss=0.6808(mal=0.5366,sub=0.3371), auc=0.9536, f1=0.7350, recall=0.9369, oracle_f1=0.1434, cascade_acc=0.5495
#   -> best saved (val_auc=0.9536): ct_cascade_models18/Hybrid_fold4_best.pth
# [Hybrid][Fold 4][Epoch 04] sub_w=0.441 | train loss=1.0150(mal=0.4648,sub=1.2465), auc=0.9430, f1=0.7715, recall=0.9009, oracle_f1=0.1507, cascade_acc=0.5068 | val loss=0.5955(mal=0.4343,sub=0.3653), auc=0.9655, f1=0.8000, recall=0.8829, oracle_f1=0.2654, cascade_acc=0.5315
#   -> best saved (val_auc=0.9655): ct_cascade_models18/Hybrid_fold4_best.pth
# [Hybrid][Fold 4][Epoch 05] sub_w=0.455 | train loss=0.9891(mal=0.4503,sub=1.1838), auc=0.9473, f1=0.7783, recall=0.8896, oracle_f1=0.1979, cascade_acc=0.4932 | val loss=0.6347(mal=0.4808,sub=0.3380), auc=0.9500, f1=0.7454, recall=0.9099, oracle_f1=0.2640, cascade_acc=0.5676
#   -> no improvement (1/7)
# [Hybrid][Fold 4][Epoch 06] sub_w=0.469 | train loss=0.9585(mal=0.3855,sub=1.2218), auc=0.9616, f1=0.8039, recall=0.9189, oracle_f1=0.2085, cascade_acc=0.5023 | val loss=0.6004(mal=0.4388,sub=0.3445), auc=0.9558, f1=0.7656, recall=0.8829, oracle_f1=0.2253, cascade_acc=0.5225
#   -> no improvement (2/7)
# [Hybrid][Fold 4][Epoch 07] sub_w=0.483 | train loss=0.9218(mal=0.3638,sub=1.1558), auc=0.9658, f1=0.7943, recall=0.9347, oracle_f1=0.2399, cascade_acc=0.5270 | val loss=0.7415(mal=0.5826,sub=0.3292), auc=0.9394, f1=0.7707, recall=0.7117, oracle_f1=0.3087, cascade_acc=0.4685
#   -> no improvement (3/7)
# [Hybrid][Fold 4][Epoch 08] sub_w=0.497 | train loss=0.9694(mal=0.3785,sub=1.1902), auc=0.9643, f1=0.7960, recall=0.9009, oracle_f1=0.2265, cascade_acc=0.4887 | val loss=0.6073(mal=0.4432,sub=0.3304), auc=0.9535, f1=0.7556, recall=0.9189, oracle_f1=0.3157, cascade_acc=0.5495
#   -> no improvement (4/7)
# [Hybrid][Fold 4][Epoch 09] sub_w=0.510 | train loss=0.9041(mal=0.3058,sub=1.1722), auc=0.9758, f1=0.8218, recall=0.9347, oracle_f1=0.2202, cascade_acc=0.5338 | val loss=0.6424(mal=0.4665,sub=0.3447), auc=0.9597, f1=0.7953, recall=0.9099, oracle_f1=0.3195, cascade_acc=0.5946
#   -> no improvement (5/7)
# [Hybrid][Fold 4][Epoch 10] sub_w=0.524 | train loss=0.9365(mal=0.3142,sub=1.1873), auc=0.9728, f1=0.8322, recall=0.9437, oracle_f1=0.2305, cascade_acc=0.5428 | val loss=0.7379(mal=0.5655,sub=0.3289), auc=0.9501, f1=0.7787, recall=0.8559, oracle_f1=0.2948, cascade_acc=0.4865
#   -> no improvement (6/7)
# [Hybrid][Fold 4][Epoch 11] sub_w=0.538 | train loss=0.8852(mal=0.2952,sub=1.0968), auc=0.9761, f1=0.8545, recall=0.9459, oracle_f1=0.2471, cascade_acc=0.5450 | val loss=1.0055(mal=0.8274,sub=0.3311), auc=0.9627, f1=0.7861, recall=0.7117, oracle_f1=0.2865, cascade_acc=0.3964
#   -> no improvement (7/7)
#   -> early stopping triggered at epoch 11
#
# -- Final Evaluation --
# [Malignancy]  AUC=0.9655, F1=0.8000, Recall=0.8829, Acc=0.9043
# [Subtype Oracle]  Acc=0.5946, MacroF1=0.2654
# [Cascade]  SubtypeAcc=0.5315, GateRecall=0.8829
# Binary CM:
# [[365  36]
#  [ 13  98]]
# Subtype Oracle CM:
# [[ 0  0  0  0  9]
#  [ 0  0  2  0 15]
#  [ 0  0  4  0  8]
#  [ 0  0  0  1 10]
#  [ 0  0  1  0 61]]
#
# [Hybrid][Fold 4] Final Metrics
# Malignancy  AUC=0.9655, F1=0.8000, Recall=0.8829
# Subtype Oracle  Acc=0.5946, MacroF1=0.2654
# Cascade  Acc=0.5315, GateRecall=0.8829
#
# ================================================================================
# Running Hybrid | Fold 5
# ================================================================================
# [FOLD 5] Train benign(0): 1606, malignant(1): 444, pos_weight=3.6171, subtype_counts=[33.0, 68.0, 48.0, 46.0, 249.0], subtype_class_weights=[1.654099941253662, 0.8026999831199646, 1.1371999979019165, 1.1866999864578247, 0.219200000166893]
# [Hybrid][Fold 5][Epoch 01] sub_w=0.400 | train loss=1.2256(mal=0.7209,sub=1.2617), auc=0.8618, f1=0.6530, recall=0.8221, oracle_f1=0.1678, cascade_acc=0.4662 | val loss=0.7194(mal=0.5810,sub=0.3459), auc=0.9293, f1=0.7279, recall=0.8919, oracle_f1=0.1434, cascade_acc=0.5405
#   -> best saved (val_auc=0.9293): ct_cascade_models18/Hybrid_fold5_best.pth
# [Hybrid][Fold 5][Epoch 02] sub_w=0.414 | train loss=1.0836(mal=0.5602,sub=1.2648), auc=0.9195, f1=0.7317, recall=0.8536, oracle_f1=0.1716, cascade_acc=0.5023 | val loss=0.6784(mal=0.5340,sub=0.3491), auc=0.9452, f1=0.7491, recall=0.9009, oracle_f1=0.2416, cascade_acc=0.5405
#   -> best saved (val_auc=0.9452): ct_cascade_models18/Hybrid_fold5_best.pth
# [Hybrid][Fold 5][Epoch 03] sub_w=0.428 | train loss=1.0005(mal=0.4668,sub=1.2482), auc=0.9435, f1=0.7750, recall=0.8649, oracle_f1=0.1916, cascade_acc=0.4932 | val loss=0.9726(mal=0.8234,sub=0.3489), auc=0.9376, f1=0.6939, recall=0.6126, oracle_f1=0.1726, cascade_acc=0.3514
#   -> no improvement (1/7)
# [Hybrid][Fold 5][Epoch 04] sub_w=0.441 | train loss=1.0171(mal=0.4919,sub=1.1897), auc=0.9389, f1=0.7546, recall=0.8761, oracle_f1=0.2186, cascade_acc=0.4662 | val loss=0.7400(mal=0.5837,sub=0.3540), auc=0.9425, f1=0.7705, recall=0.8468, oracle_f1=0.2587, cascade_acc=0.5225
#   -> no improvement (2/7)
# [Hybrid][Fold 5][Epoch 05] sub_w=0.455 | train loss=0.9579(mal=0.4163,sub=1.1899), auc=0.9531, f1=0.7976, recall=0.8874, oracle_f1=0.2275, cascade_acc=0.5135 | val loss=0.6114(mal=0.4536,sub=0.3465), auc=0.9527, f1=0.8151, recall=0.8739, oracle_f1=0.1420, cascade_acc=0.5045
#   -> best saved (val_auc=0.9527): ct_cascade_models18/Hybrid_fold5_best.pth
# [Hybrid][Fold 5][Epoch 06] sub_w=0.469 | train loss=0.9260(mal=0.3632,sub=1.2001), auc=0.9637, f1=0.8164, recall=0.9167, oracle_f1=0.2295, cascade_acc=0.5203 | val loss=0.6767(mal=0.5157,sub=0.3432), auc=0.9426, f1=0.7791, recall=0.8739, oracle_f1=0.1890, cascade_acc=0.4955
#   -> no improvement (1/7)
# [Hybrid][Fold 5][Epoch 07] sub_w=0.483 | train loss=0.9761(mal=0.4228,sub=1.1461), auc=0.9539, f1=0.7896, recall=0.8919, oracle_f1=0.2642, cascade_acc=0.5270 | val loss=0.6354(mal=0.4550,sub=0.3737), auc=0.9536, f1=0.7966, recall=0.8468, oracle_f1=0.1813, cascade_acc=0.4865
#   -> no improvement (2/7)
# [Hybrid][Fold 5][Epoch 08] sub_w=0.497 | train loss=0.8917(mal=0.3310,sub=1.1292), auc=0.9711, f1=0.8182, recall=0.9122, oracle_f1=0.2614, cascade_acc=0.5338 | val loss=0.6741(mal=0.5010,sub=0.3487), auc=0.9501, f1=0.7840, recall=0.8829, oracle_f1=0.2647, cascade_acc=0.5135
#   -> no improvement (3/7)
# [Hybrid][Fold 5][Epoch 09] sub_w=0.510 | train loss=0.8996(mal=0.3219,sub=1.1320), auc=0.9715, f1=0.8374, recall=0.9279, oracle_f1=0.2908, cascade_acc=0.5473 | val loss=0.7130(mal=0.5021,sub=0.4132), auc=0.9519, f1=0.7764, recall=0.8288, oracle_f1=0.2352, cascade_acc=0.4955
#   -> no improvement (4/7)
# [Hybrid][Fold 5][Epoch 10] sub_w=0.524 | train loss=0.8824(mal=0.2957,sub=1.1193), auc=0.9784, f1=0.8403, recall=0.9302, oracle_f1=0.3239, cascade_acc=0.5541 | val loss=0.6710(mal=0.4757,sub=0.3726), auc=0.9546, f1=0.7778, recall=0.8829, oracle_f1=0.3265, cascade_acc=0.5045
#   -> best saved (val_auc=0.9546): ct_cascade_models18/Hybrid_fold5_best.pth
# [Hybrid][Fold 5][Epoch 11] sub_w=0.538 | train loss=0.9048(mal=0.3271,sub=1.0739), auc=0.9728, f1=0.8347, recall=0.9324, oracle_f1=0.3301, cascade_acc=0.5360 | val loss=0.7169(mal=0.5329,sub=0.3421), auc=0.9555, f1=0.7837, recall=0.8649, oracle_f1=0.2920, cascade_acc=0.3874
#   -> no improvement (1/7)
# [Hybrid][Fold 5][Epoch 12] sub_w=0.552 | train loss=0.8443(mal=0.2746,sub=1.0326), auc=0.9795, f1=0.8649, recall=0.9369, oracle_f1=0.3228, cascade_acc=0.5631 | val loss=0.9039(mal=0.7045,sub=0.3614), auc=0.9474, f1=0.7560, recall=0.7117, oracle_f1=0.2687, cascade_acc=0.4324
#   -> no improvement (2/7)
# [Hybrid][Fold 5][Epoch 13] sub_w=0.566 | train loss=0.8494(mal=0.2603,sub=1.0418), auc=0.9807, f1=0.8762, recall=0.9482, oracle_f1=0.3442, cascade_acc=0.5743 | val loss=0.6639(mal=0.4624,sub=0.3563), auc=0.9550, f1=0.7938, recall=0.9189, oracle_f1=0.2136, cascade_acc=0.4595
#   -> no improvement (3/7)
# [Hybrid][Fold 5][Epoch 14] sub_w=0.579 | train loss=0.8082(mal=0.1981,sub=1.0532), auc=0.9889, f1=0.9041, recall=0.9550, oracle_f1=0.3531, cascade_acc=0.5946 | val loss=0.7965(mal=0.5839,sub=0.3669), auc=0.9512, f1=0.7343, recall=0.9459, oracle_f1=0.2241, cascade_acc=0.4775
#   -> no improvement (4/7)
# [Hybrid][Fold 5][Epoch 15] sub_w=0.593 | train loss=0.8964(mal=0.2558,sub=1.0801), auc=0.9824, f1=0.8610, recall=0.9414, oracle_f1=0.3326, cascade_acc=0.5653 | val loss=0.7552(mal=0.5486,sub=0.3483), auc=0.9572, f1=0.8036, recall=0.8108, oracle_f1=0.2287, cascade_acc=0.4595
#   -> best saved (val_auc=0.9572): ct_cascade_models18/Hybrid_fold5_best.pth
# [Hybrid][Fold 5][Epoch 16] sub_w=0.607 | train loss=0.8958(mal=0.2643,sub=1.0405), auc=0.9815, f1=0.8772, recall=0.9414, oracle_f1=0.3645, cascade_acc=0.5788 | val loss=0.6898(mal=0.4800,sub=0.3459), auc=0.9550, f1=0.8155, recall=0.8559, oracle_f1=0.2428, cascade_acc=0.2973
#   -> no improvement (1/7)
# [Hybrid][Fold 5][Epoch 17] sub_w=0.621 | train loss=0.7942(mal=0.1868,sub=0.9787), auc=0.9897, f1=0.9136, recall=0.9640, oracle_f1=0.4194, cascade_acc=0.6104 | val loss=0.8090(mal=0.5834,sub=0.3634), auc=0.9558, f1=0.7967, recall=0.8649, oracle_f1=0.3416, cascade_acc=0.4775
#   -> no improvement (2/7)
# [Hybrid][Fold 5][Epoch 18] sub_w=0.634 | train loss=0.8374(mal=0.2106,sub=0.9880), auc=0.9879, f1=0.8997, recall=0.9595, oracle_f1=0.3724, cascade_acc=0.5946 | val loss=0.8128(mal=0.5736,sub=0.3771), auc=0.9576, f1=0.8000, recall=0.8288, oracle_f1=0.2673, cascade_acc=0.3153
#   -> no improvement (3/7)
# [Hybrid][Fold 5][Epoch 19] sub_w=0.648 | train loss=0.8339(mal=0.1863,sub=0.9989), auc=0.9900, f1=0.9087, recall=0.9527, oracle_f1=0.3935, cascade_acc=0.6036 | val loss=0.7587(mal=0.5343,sub=0.3460), auc=0.9479, f1=0.7931, recall=0.8288, oracle_f1=0.2212, cascade_acc=0.3874
#   -> no improvement (4/7)
# [Hybrid][Fold 5][Epoch 20] sub_w=0.662 | train loss=0.8404(mal=0.2017,sub=0.9646), auc=0.9898, f1=0.8741, recall=0.9459, oracle_f1=0.4090, cascade_acc=0.6081 | val loss=0.8047(mal=0.5514,sub=0.3826), auc=0.9539, f1=0.7586, recall=0.8919, oracle_f1=0.2598, cascade_acc=0.3063
#   -> no improvement (5/7)
# [Hybrid][Fold 5][Epoch 21] sub_w=0.676 | train loss=0.8152(mal=0.1722,sub=0.9513), auc=0.9905, f1=0.9101, recall=0.9685, oracle_f1=0.4200, cascade_acc=0.6329 | val loss=1.0534(mal=0.7639,sub=0.4282), auc=0.9560, f1=0.8073, recall=0.7928, oracle_f1=0.2769, cascade_acc=0.4595
#   -> no improvement (6/7)
# [Hybrid][Fold 5][Epoch 22] sub_w=0.690 | train loss=0.8429(mal=0.2013,sub=0.9304), auc=0.9890, f1=0.8929, recall=0.9572, oracle_f1=0.4455, cascade_acc=0.6351 | val loss=0.7209(mal=0.4604,sub=0.3777), auc=0.9539, f1=0.7581, recall=0.8468, oracle_f1=0.2862, cascade_acc=0.3874
#   -> no improvement (7/7)
#   -> early stopping triggered at epoch 22
#
# -- Final Evaluation --
# [Malignancy]  AUC=0.9572, F1=0.8036, Recall=0.8108, Acc=0.9141
# [Subtype Oracle]  Acc=0.5225, MacroF1=0.2287
# [Cascade]  SubtypeAcc=0.4595, GateRecall=0.8108
# Binary CM:
# [[378  23]
#  [ 21  90]]
# Subtype Oracle CM:
# [[ 0  0  0  1  8]
#  [ 0  0  2  2 12]
#  [ 0  0  2  5  5]
#  [ 0  0  2  3  7]
#  [ 0  3  2  4 53]]
#
# [Hybrid][Fold 5] Final Metrics
# Malignancy  AUC=0.9572, F1=0.8036, Recall=0.8108
# Subtype Oracle  Acc=0.5225, MacroF1=0.2287
# Cascade  Acc=0.4595, GateRecall=0.8108
#     model  fold   mal_acc   mal_auc    mal_f1  mal_recall  subtype_oracle_acc  \
# 0  Hybrid     1  0.927875  0.981007  0.850202    0.945946            0.522523
# 1  Hybrid     2  0.886940  0.949050  0.764228    0.846847            0.522523
# 2  Hybrid     3  0.880859  0.975242  0.774908    0.945946            0.513514
# 3  Hybrid     4  0.904297  0.965548  0.800000    0.882883            0.594595
# 4  Hybrid     5  0.914062  0.957224  0.803571    0.810811            0.522523
#
#    subtype_oracle_macro_f1  subtype_cascade_acc  subtype_gate_recall  \
# 0                 0.255229             0.513514             0.945946
# 1                 0.253832             0.504505             0.846847
# 2                 0.233471             0.513514             0.945946
# 3                 0.265423             0.531532             0.882883
# 4                 0.228662             0.459459             0.810811
#
#                binary_cm                                  subtype_oracle_cm
# 0  [[371, 31], [6, 105]]  [[0, 1, 0, 1, 6], [0, 4, 0, 4, 9], [0, 3, 0, 2...
# 1  [[361, 41], [17, 94]]  [[0, 4, 2, 0, 2], [0, 6, 4, 2, 5], [0, 3, 1, 1...
# 2  [[346, 55], [6, 105]]  [[0, 0, 0, 0, 8], [0, 1, 2, 1, 13], [0, 3, 0, ...
# 3  [[365, 36], [13, 98]]  [[0, 0, 0, 0, 9], [0, 0, 2, 0, 15], [0, 0, 4, ...
# 4  [[378, 23], [21, 90]]  [[0, 0, 0, 1, 8], [0, 0, 2, 2, 12], [0, 0, 2, ...
#            mal_auc              mal_f1           mal_recall            \
#               mean       std      mean       std       mean       std
# model
# Hybrid    0.965614  0.012985  0.798582  0.033288   0.886486  0.059962
# ResNet18  0.968149  0.007978  0.822686  0.023338   0.908108  0.037902
# ViT-B16   0.692664  0.019199  0.283562  0.132261   0.661261  0.472333
#
#          subtype_oracle_acc           subtype_oracle_macro_f1            \
#                        mean       std                    mean       std
# model
# Hybrid             0.535135  0.033467                0.247323  0.015593
# ResNet18           0.533333  0.048263                0.261260  0.105808
# ViT-B16            0.560360  0.004029                0.143648  0.000660
#
#          subtype_cascade_acc           subtype_gate_recall
#                         mean       std                mean       std
# model
# Hybrid              0.504505  0.027027            0.886486  0.059962
# ResNet18            0.504505  0.043673            0.908108  0.037902
# ViT-B16             0.367568  0.269925            0.661261  0.472333
