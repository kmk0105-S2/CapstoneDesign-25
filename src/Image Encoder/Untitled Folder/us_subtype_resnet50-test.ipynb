# %%
#!/usr/bin/env python
# coding: utf-8

# ============================================================
# Ultrasound subtype-only 5-class CV training script
# - CT binary 코드 스타일 / 함수명 최대한 유지
# - US 전처리(3채널 생성, CLAHE, edge, mask crop) 없음
# - 입력 NPZ가 이미 전처리된 US 이미지를 담고 있다고 가정
# - fold 파일은 patient-level split 이 완료되어 있다고 가정
# ============================================================

from torchvision import models
from torchvision.models import vit_b_16

print("=" * 60)

try:
    m1 = models.resnet50(weights=None)
    print("ResNet50 build success")
except Exception as e:
    print("Fail", e)

try:
    m2 = vit_b_16(weights=None)
    print("Vit-B/16 build success")
except Exception as e:
    print("Fail", e)

print("=" * 60)

# ============================================================
# 1) 환경 설정 + import
# ============================================================
import os
import gc
import random
import torchvision.transforms.functional as TF
from pathlib import Path

import numpy as np
import pandas as pd

from sklearn.metrics import (
    confusion_matrix, classification_report,
    accuracy_score, f1_score, recall_score, balanced_accuracy_score
)

import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
from torchvision import models
from torchvision.models import vit_b_16

SEED = 42
random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)
torch.cuda.manual_seed_all(SEED)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Device:", device)

torch.backends.cudnn.benchmark = True


# ============================================================
# 2) 경로 / 하이퍼파라미터 설정
# ============================================================
print(f"현재 작업 경로: {os.getcwd()}")

# TODO: 사용자 환경에 맞게 수정
DATA_ROOT = Path("/tf/nasw/dataset001/preprocessed/npz_us")
FOLDS = [1, 2, 3, 4, 5]

OUTPUT_DIR = Path("./us_subtype_models50")
OUTPUT_DIR.mkdir(parents=True, exist_ok=True)

IMG_SIZE = 224
BATCH_SIZE = 8
NUM_WORKERS = 2
NUM_EPOCHS = 30
LR = 1e-4
WEIGHT_DECAY = 1e-4
PATIENCE = 7

# Local pretrained weights
LOCAL_RESNET_WEIGHTS = Path("/tf/pretrained_model/resnet50-11ad3fa6.pth")
LOCAL_VIT_WEIGHTS = Path("/tf/pretrained_model/vit_b_16-c867db91.pth")

# ------------------------------------------------------------
# 데이터셋 key / subtype remap 설정
# ------------------------------------------------------------
IMAGE_KEY = "images"
LABEL_KEY = "labels"          # 있을 경우 malignant filtering용
SUBTYPE_KEY = "tumor_types"   # 원본 subtype id
PATIENT_ID_KEY = "patient_ids"  # optional, 체크용

# 원본 subtype id -> 0..K-1 remap
# 예시: 0 clear, 1 endometrioid, 3 etc, 5 mucinous, 7 serous
SUBTYPE_ID_MAP = {
    0: 0,
    1: 1,
    3: 2,
    5: 3,
    7: 4,
}

CLASS_NAMES = [
    "clear_cell",
    "endometrioid",
    "etc",
    "mucinous",
    "serous",
]
NUM_CLASSES = len(SUBTYPE_ID_MAP)

# 다중 view/frame 처리
MAX_VIEWS = None  # None이면 npz에 들어있는 view 수 그대로 사용

print("DATA_ROOT:", DATA_ROOT)
print("OUTPUT_DIR:", OUTPUT_DIR.resolve())
print("FOLDS:", FOLDS)
print("LOCAL_RESNET_WEIGHTS exists:", LOCAL_RESNET_WEIGHTS.exists())
print("LOCAL_VIT_WEIGHTS exists:", LOCAL_VIT_WEIGHTS.exists())
print("NUM_CLASSES:", NUM_CLASSES)
print("SUBTYPE_ID_MAP:", SUBTYPE_ID_MAP)


# ============================================================
# 3) 유틸 함수
# ============================================================
def inspect_fold_npz(fold_idx):
    train_npz_path = DATA_ROOT / f"fold_{fold_idx}_train.npz"
    val_npz_path = DATA_ROOT / f"fold_{fold_idx}_val.npz"

    print("TRAIN:", train_npz_path, train_npz_path.exists())
    print("VAL:", val_npz_path, val_npz_path.exists())

    train_npz = np.load(train_npz_path, allow_pickle=False, mmap_mode="r")
    val_npz = np.load(val_npz_path, allow_pickle=False, mmap_mode="r")

    for k in train_npz.files:
        print(f"[train] {k}: shape={train_npz[k].shape}, dtype={train_npz[k].dtype}")
    for k in val_npz.files:
        print(f"[val] {k}: shape={val_npz[k].shape}, dtype={val_npz[k].dtype}")

    if PATIENT_ID_KEY in train_npz.files:
        print(f"[train] patient ids unique={len(np.unique(train_npz[PATIENT_ID_KEY]))}")
    if PATIENT_ID_KEY in val_npz.files:
        print(f"[val] patient ids unique={len(np.unique(val_npz[PATIENT_ID_KEY]))}")


def load_local_state_dict(weight_path):
    weight_path = Path(weight_path)
    assert weight_path.exists(), f"Weight file not found: {weight_path}"

    ckpt = torch.load(weight_path, map_location="cpu")

    if isinstance(ckpt, dict) and "state_dict" in ckpt and isinstance(ckpt["state_dict"], dict):
        ckpt = ckpt["state_dict"]

    return ckpt


def compute_multiclass_metrics(y_true, y_pred):
    y_true = np.array(y_true).astype(int)
    y_pred = np.array(y_pred).astype(int)

    if len(y_true) == 0:
        return {
            "acc": np.nan,
            "macro_f1": np.nan,
            "macro_recall": np.nan,
            "balanced_acc": np.nan,
            "cm": None,
        }

    metrics = {
        "acc": accuracy_score(y_true, y_pred),
        "macro_f1": f1_score(y_true, y_pred, average="macro", zero_division=0),
        "macro_recall": recall_score(y_true, y_pred, average="macro", zero_division=0),
        "balanced_acc": balanced_accuracy_score(y_true, y_pred),
        "cm": confusion_matrix(y_true, y_pred),
    }
    return metrics


def prepare_train_mode(model):
    model.train()

    if not hasattr(model, "encoder"):
        return

    for name, module in model.encoder.named_modules():
        if name.startswith("layer4"):
            continue
        if isinstance(module, nn.BatchNorm2d):
            module.eval()


def normalize_imagenet_tensor(x):
    # x: [S, 3, H, W]
    mean = torch.tensor([0.485, 0.456, 0.406], dtype=torch.float32).view(1, 3, 1, 1)
    std = torch.tensor([0.229, 0.224, 0.225], dtype=torch.float32).view(1, 3, 1, 1)
    return (x - mean) / std


def ensure_float01(img):
    img = np.asarray(img)
    if img.dtype == np.uint8:
        return img.astype(np.float32) / 255.0

    img = img.astype(np.float32)
    vmax = float(img.max()) if img.size > 0 else 0.0
    vmin = float(img.min()) if img.size > 0 else 0.0

    # 이미 0~1 범위면 그대로 사용
    if vmin >= 0.0 and vmax <= 1.0:
        return img

    # 0~255 범위처럼 보이면 255로 정규화
    if vmin >= 0.0 and vmax <= 255.0:
        return img / 255.0

    # 그 외는 min-max 정규화
    denom = max(vmax - vmin, 1e-6)
    return (img - vmin) / denom

#=============================================================
# 3.5) 실시간 증강 모듈
#=============================================================

class CTSliceAugmentor:
    def __init__(
        self,
        p_hflip: float = 0.5,
        p_vflip: float = 0.0,
        p_rotate: float = 0.5,
        max_angle: float = 10.0,
        p_crop: float = 0.5,
        crop_min: float = 0.85,
        p_noise: float = 0.3,
        noise_std: float = 0.01,
    ):
        self.p_hflip = p_hflip
        self.p_vflip = p_vflip
        self.p_rotate = p_rotate
        self.max_angle = max_angle
        self.p_crop = p_crop
        self.crop_min = crop_min
        self.p_noise = p_noise
        self.noise_std = noise_std


    def __call__(self, imgs):
        S, C, H, W = imgs.shape

        do_hflip = random.random() < self.p_hflip
        do_vflip = random.random() < self.p_vflip
        do_rotate = random.random() < self.p_rotate
        angle = random.uniform(-self.max_angle, self.max_angle) if do_rotate else 0.0
        do_crop = random.random() < self.p_crop
        do_noise = random.random() < self.p_noise

        top = left = crop_h = crop_w = 0
        if do_crop:
            scale = random.uniform(self.crop_min, 1.0)
            crop_h = int(H*scale)
            crop_w = int(W*scale)
            top = random.randint(0, H-crop_h)
            left = random.randint(0, W-crop_w)

        augmented = []
        for s in range(S):
            img = imgs[s]
            if do_hflip:
                img = TF.hflip(img)
            if do_vflip:
                img = TF.vflip(img)
            if do_rotate:
                img = TF.rotate(img, angle, interpolation = TF.InterpolationMode.BILINEAR, fill=0)
            if do_crop:
                img = TF.crop(img, top, left, crop_h, crop_w)
                img = TF.resize(img, [H,W], interpolation=TF.InterpolationMode.BILINEAR, antialias=True)
            augmented.append(img)

        imgs=torch.stack(augmented, dim = 0)

        if do_noise:
            imgs = (imgs + torch.randn_like(imgs) * self.noise_std).clamp(0.0, 1.0)

        return imgs


TRAIN_AUGMENTOR = CTSliceAugmentor(
    p_hflip = 0.5, p_vflip = 0.0, p_rotate=0.5, max_angle = 10.0,
    p_crop = 0.5, crop_min = 0.85, p_noise = 0.3, noise_std = 0.01,
)

def _worker_init_fn(worker_id):
    worker_seed = torch.initial_seed() % (2**32)
    np.random.seed(worker_seed)
    random.seed(worker_seed)
    

# ============================================================
# 4) Dataset 정의
# ============================================================
class OvarianUSNPZDataset(Dataset):
    def __init__(self, npz_path, is_train = True):
        super().__init__()
        self.npz = np.load(npz_path, allow_pickle=False, mmap_mode="r")

        self.images = self.npz[IMAGE_KEY]
        self.labels = self.npz[LABEL_KEY].astype(np.float32) if LABEL_KEY in self.npz.files else None
        self.tumor_types = self.npz[SUBTYPE_KEY].astype(np.int64)
        self.patient_ids = self.npz[PATIENT_ID_KEY] if PATIENT_ID_KEY in self.npz.files else None

        self.keep_indices = []
        self.remapped_subtypes = []

        for i, t in enumerate(self.tumor_types.astype(int)):
            if t not in SUBTYPE_ID_MAP:
                continue
            # label이 있으면 malignant만 학습에 사용
            if self.labels is not None:
                if int(self.labels[i]) != 1:
                    continue
            self.keep_indices.append(i)
            self.remapped_subtypes.append(SUBTYPE_ID_MAP[t])

        self.keep_indices = np.asarray(self.keep_indices, dtype=np.int64)
        self.remapped_subtypes = np.asarray(self.remapped_subtypes, dtype=np.int64)

        print(f"Loaded {npz_path.name}: total={len(self.tumor_types)}, kept={len(self.keep_indices)}")

        self.augmentor = TRAIN_AUGMENTOR if is_train else None

    def __len__(self):
        return len(self.keep_indices)

    def _get_views(self, idx):
        raw_idx = int(self.keep_indices[idx])
        imgs = self.images[raw_idx]
        imgs = np.asarray(imgs)

        # 허용 shape
        # [H, W]                  -> [1, H, W, 1]
        # [H, W, C]               -> [1, H, W, C]
        # [S, H, W]               -> [S, H, W, 1]
        # [S, H, W, C]            -> 그대로
        if imgs.ndim == 2:
            imgs = imgs[None, ..., None]
        elif imgs.ndim == 3:
            if imgs.shape[-1] in [1, 3]:
                imgs = imgs[None, ...]
            else:
                imgs = imgs[..., None]
        elif imgs.ndim == 4:
            pass
        else:
            raise ValueError(f"Unsupported image ndim: {imgs.ndim}, shape={imgs.shape}")

        if imgs.shape[-1] == 1:
            imgs = np.repeat(imgs, 3, axis=-1)
        elif imgs.shape[-1] != 3:
            raise ValueError(f"Expected channel=1 or 3, got shape={imgs.shape}")

        if MAX_VIEWS is not None and len(imgs) > MAX_VIEWS:
            idxs = np.linspace(0, len(imgs) - 1, MAX_VIEWS).round().astype(int)
            imgs = imgs[idxs]

        return imgs

    def __getitem__(self, idx):
        imgs = self._get_views(idx)
        y = int(self.remapped_subtypes[idx])

        view_tensors = []
        for view in imgs:
            x = ensure_float01(view)
            x = torch.from_numpy(x).float().permute(2, 0, 1).contiguous()  # [3,H,W]
            view_tensors.append(x)

        x = torch.stack(view_tensors, dim=0)  # [S,3,H,W]

        if self.augmentor is not None:
            x = self.augmentor(x)
            
        x = normalize_imagenet_tensor(x)
        y = torch.tensor(y, dtype=torch.long)
        return x, y


# ============================================================
# 5) fold별 DataLoader 생성
# ============================================================
def make_fold_loaders(fold_idx):
    train_npz_path = DATA_ROOT / f"fold_{fold_idx}_train.npz"
    val_npz_path = DATA_ROOT / f"fold_{fold_idx}_val.npz"

    assert train_npz_path.exists(), f"Missing: {train_npz_path}"
    assert val_npz_path.exists(), f"Missing: {val_npz_path}"

    train_dataset = OvarianUSNPZDataset(train_npz_path, is_train = True)
    val_dataset = OvarianUSNPZDataset(val_npz_path, is_train = False)

    train_loader = DataLoader(
        train_dataset,
        batch_size=BATCH_SIZE,
        shuffle=True,
        num_workers=NUM_WORKERS,
        pin_memory=True,
        worker_init_fn = _worker_init_fn,
        persistent_workers = (NUM_WORKERS > 0),
    )

    val_loader = DataLoader(
        val_dataset,
        batch_size=BATCH_SIZE,
        shuffle=False,
        num_workers=NUM_WORKERS,
        pin_memory=True,
    )

    subtype_np = train_dataset.remapped_subtypes.astype(int)
    counts = np.bincount(subtype_np, minlength=NUM_CLASSES).astype(np.float32)
    counts = np.maximum(counts, 1.0)

    # inverse sqrt weight가 보통 덜 과격해서 안정적
    class_weight_value = 1.0 / np.sqrt(counts)
    class_weight_value = class_weight_value / class_weight_value.mean()
    class_weight = torch.tensor(class_weight_value, device=device, dtype=torch.float32)

    print(f"[FOLD {fold_idx}] subtype counts={counts.tolist()}, class_weight={class_weight.cpu().numpy().round(4).tolist()}")
    print(f"[FOLD {fold_idx}] patient-level split assumed from fold_{fold_idx}_train/val.npz")

    return train_loader, val_loader, class_weight


# ============================================================
# 6) train / eval 함수
# ============================================================
scaler = torch.amp.GradScaler(enabled=(device.type == "cuda"))


def train_one_epoch(model, loader, criterion, optimizer, device):
    prepare_train_mode(model)
    running_loss = 0.0
    y_true, y_pred = [], []

    for imgs, labels in loader:
        imgs = imgs.to(device, non_blocking=True)
        labels = labels.to(device, non_blocking=True)

        optimizer.zero_grad()

        with torch.amp.autocast(device_type="cuda", enabled=(device.type == "cuda")):
            logits = model(imgs)
            loss = criterion(logits, labels)

        scaler.scale(loss).backward()
        scaler.step(optimizer)
        scaler.update()

        running_loss += loss.item() * imgs.size(0)

        preds = torch.argmax(logits, dim=1)
        y_true.extend(labels.detach().cpu().numpy().ravel())
        y_pred.extend(preds.detach().cpu().numpy().ravel())

    metric_vals = compute_multiclass_metrics(y_true, y_pred)

    metrics = {
        "loss": running_loss / len(loader.dataset),
        "acc": metric_vals["acc"],
        "macro_f1": metric_vals["macro_f1"],
        "macro_recall": metric_vals["macro_recall"],
        "balanced_acc": metric_vals["balanced_acc"],
        "cm": metric_vals["cm"],
    }
    return metrics


@torch.no_grad()
def eval_one_epoch(model, loader, criterion, device):
    model.eval()
    running_loss = 0.0
    y_true, y_pred = [], []

    for imgs, labels in loader:
        imgs = imgs.to(device, non_blocking=True)
        labels = labels.to(device, non_blocking=True)

        with torch.amp.autocast(device_type="cuda", enabled=(device.type == "cuda")):
            logits = model(imgs)
            loss = criterion(logits, labels)

        running_loss += loss.item() * imgs.size(0)

        preds = torch.argmax(logits, dim=1)
        y_true.extend(labels.detach().cpu().numpy().ravel())
        y_pred.extend(preds.detach().cpu().numpy().ravel())

    metric_vals = compute_multiclass_metrics(y_true, y_pred)

    metrics = {
        "loss": running_loss / len(loader.dataset),
        "acc": metric_vals["acc"],
        "macro_f1": metric_vals["macro_f1"],
        "macro_recall": metric_vals["macro_recall"],
        "balanced_acc": metric_vals["balanced_acc"],
        "cm": metric_vals["cm"],
    }
    return metrics


@torch.no_grad()
def eval_confusion(model, loader, device):
    model.eval()
    y_true, y_pred = [], []

    for imgs, labels in loader:
        imgs = imgs.to(device, non_blocking=True)
        labels = labels.to(device, non_blocking=True)

        logits = model(imgs)
        preds = torch.argmax(logits, dim=1)

        y_true.extend(labels.cpu().numpy().ravel())
        y_pred.extend(preds.cpu().numpy().ravel())

    metric_vals = compute_multiclass_metrics(y_true, y_pred)

    print("\n-- Final Evaluation --")
    print(f"Accuracy      : {metric_vals['acc']:.4f}")
    print(f"Macro-F1      : {metric_vals['macro_f1']:.4f}")
    print(f"Macro-Recall  : {metric_vals['macro_recall']:.4f}")
    print(f"Balanced Acc  : {metric_vals['balanced_acc']:.4f}")
    print(metric_vals["cm"])

    print("\nClassification report:")
    print(classification_report(np.array(y_true).astype(int), np.array(y_pred).astype(int), target_names=CLASS_NAMES, digits=4, zero_division=0))

    return metric_vals


# ============================================================
# 7) model 정의 (CT binary 코드 구조 최대한 유지)
# ============================================================
class PatientSliceAttentionClassifier(nn.Module):
    def __init__(self, encoder, feat_dim, hidden_dim=512, dropout=0.3, num_classes=NUM_CLASSES):
        super().__init__()
        self.encoder = encoder

        self.attn = nn.Sequential(
            nn.Linear(feat_dim, feat_dim // 2),
            nn.Tanh(),
            nn.Linear(feat_dim // 2, 1),
        )

        self.classifier = nn.Sequential(
            nn.Linear(feat_dim, hidden_dim),
            nn.ReLU(),
            nn.Dropout(dropout),
            nn.Linear(hidden_dim, num_classes),
        )

    def forward(self, x):
        # x: (B, S, C, H, W)
        B, S, C, H, W = x.shape
        x = x.view(B * S, C, H, W)

        feat = self.encoder(x)
        feat = feat.view(B, S, -1)

        attn_score = self.attn(feat)
        attn_weight = torch.softmax(attn_score, dim=1)

        pooled = (feat * attn_weight).sum(dim=1)
        logits = self.classifier(pooled)
        return logits


# ============================================================
# 8) build 함수들
# ============================================================
def build_resnet50_patient_model(load_pretrained=True, freeze_backbone=True, unfreeze_layer4=True, weight_path=LOCAL_RESNET_WEIGHTS):
    encoder = models.resnet50(weights=None)

    if load_pretrained:
        state_dict = load_local_state_dict(weight_path)
        encoder.load_state_dict(state_dict, strict=True)

    feat_dim = encoder.fc.in_features
    encoder.fc = nn.Identity()

    if freeze_backbone:
        for p in encoder.parameters():
            p.requires_grad = False

        if unfreeze_layer4:
            for p in encoder.layer4.parameters():
                p.requires_grad = True

    model = PatientSliceAttentionClassifier(
        encoder=encoder,
        feat_dim=feat_dim,
        hidden_dim=512,
        dropout=0.1,
        num_classes=NUM_CLASSES,
    )

    return model


def build_vit_patient_model(load_pretrained=True, weight_path=LOCAL_VIT_WEIGHTS):
    encoder = vit_b_16(weights=None)
    if load_pretrained:
        state_dict = load_local_state_dict(weight_path)
        encoder.load_state_dict(state_dict, strict=True)

    feat_dim = encoder.heads.head.in_features
    encoder.heads = nn.Identity()

    model = PatientSliceAttentionClassifier(
        encoder=encoder,
        feat_dim=feat_dim,
        hidden_dim=512,
        dropout=0.3,
        num_classes=NUM_CLASSES,
    )
    return model


class CNNTransformerHybridPatient(nn.Module):
    def __init__(
        self,
        d_model=512,
        nhead=8,
        num_layers=2,
        dim_feedforward=1024,
        dropout=0.3,
        load_pretrained=True,
        freeze_backbone=True,
        unfreeze_layer4=True,
        resnet_weight_path=LOCAL_RESNET_WEIGHTS,
        num_classes=NUM_CLASSES,
    ):
        super().__init__()
        backbone = models.resnet50(weights=None)
        if load_pretrained:
            state_dict = load_local_state_dict(resnet_weight_path)
            backbone.load_state_dict(state_dict, strict=True)
        feat_dim = backbone.fc.in_features
        backbone.fc = nn.Identity()
        self.encoder = backbone

        if freeze_backbone:
            for p in self.encoder.parameters():
                p.requires_grad = False

            if unfreeze_layer4:
                for p in self.encoder.layer4.parameters():
                    p.requires_grad = True

        self.proj = nn.Linear(feat_dim, d_model)
        self.cls_token = nn.Parameter(torch.zeros(1, 1, d_model))
        self.pos_embed = nn.Parameter(torch.zeros(1, 1 + 16, d_model))

        encoder_layer = nn.TransformerEncoderLayer(
            d_model=d_model,
            nhead=nhead,
            dim_feedforward=dim_feedforward,
            dropout=0.1,
            batch_first=True,
            activation="gelu",
        )

        self.transformer = nn.TransformerEncoder(encoder_layer, num_layers=num_layers)
        self.norm = nn.LayerNorm(d_model)

        self.classifier = nn.Sequential(
            nn.Linear(d_model, 512),
            nn.ReLU(),
            nn.Dropout(dropout),
            nn.Linear(512, num_classes),
        )

    def forward(self, x):
        B, S, C, H, W = x.shape
        x = x.view(B * S, C, H, W)

        feat = self.encoder(x)
        feat = feat.view(B, S, -1)
        feat = self.proj(feat)

        cls = self.cls_token.expand(B, -1, -1)
        tokens = torch.cat([cls, feat], dim=1)
        tokens = tokens + self.pos_embed[:, :tokens.size(1), :]

        tokens = self.transformer(tokens)
        tokens = self.norm(tokens)

        cls_out = tokens[:, 0, :]
        logits = self.classifier(cls_out)
        return logits


def build_hybrid_patient_model(load_pretrained=True):
    return CNNTransformerHybridPatient(
        load_pretrained=load_pretrained,
        freeze_backbone=True,
        unfreeze_layer4=True,
        resnet_weight_path=LOCAL_RESNET_WEIGHTS,
        num_classes=NUM_CLASSES,
    )


# ============================================================
# 9) 공통 학습 함수
# ============================================================
def fit_model(
    model,
    model_name,
    fold_idx,
    train_loader,
    val_loader,
    device,
    num_epochs=30,
    lr=1e-4,
    weight_decay=1e-4,
    pos_weight=None,      # 함수명 호환용. 실제로는 class_weight를 넘겨도 됨.
    patience=7,
    min_delta=0.001,
):
    model = model.to(device)

    # CT binary 코드와 이름 맞추기 위해 pos_weight 인자명을 유지
    # 여기서는 multiclass class_weight로 사용
    criterion = nn.CrossEntropyLoss(weight=pos_weight)
    optimizer = torch.optim.Adam(
        filter(lambda p: p.requires_grad, model.parameters()),
        lr=lr,
        weight_decay=weight_decay,
    )

    best_score = -np.inf
    best_path = OUTPUT_DIR / f"{model_name}_fold{fold_idx}_best.pth"
    history = []
    early_stop_counter = 0

    for epoch in range(1, num_epochs + 1):
        train_metrics = train_one_epoch(model, train_loader, criterion, optimizer, device)
        val_metrics = eval_one_epoch(model, val_loader, criterion, device)

        row = {
            "fold": fold_idx,
            "epoch": epoch,
            "train_loss": train_metrics["loss"],
            "train_acc": train_metrics["acc"],
            "train_macro_f1": train_metrics["macro_f1"],
            "train_macro_recall": train_metrics["macro_recall"],
            "train_balanced_acc": train_metrics["balanced_acc"],
            "val_loss": val_metrics["loss"],
            "val_acc": val_metrics["acc"],
            "val_macro_f1": val_metrics["macro_f1"],
            "val_macro_recall": val_metrics["macro_recall"],
            "val_balanced_acc": val_metrics["balanced_acc"],
        }
        history.append(row)

        print(
            f"[{model_name}][Fold {fold_idx}][Epoch {epoch:02d}] "
            f"train loss={row['train_loss']:.4f}, acc={row['train_acc']:.4f}, "
            f"macro_f1={row['train_macro_f1']:.4f}, macro_recall={row['train_macro_recall']:.4f}, balanced_acc={row['train_balanced_acc']:.4f} | "
            f"val loss={row['val_loss']:.4f}, acc={row['val_acc']:.4f}, "
            f"macro_f1={row['val_macro_f1']:.4f}, macro_recall={row['val_macro_recall']:.4f}, balanced_acc={row['val_balanced_acc']:.4f}"
        )

        score = row["val_macro_f1"]
        if score > best_score + min_delta:
            best_score = score
            early_stop_counter = 0
            torch.save(model.state_dict(), best_path)
            print(f"  -> best saved by val_macro_f1: {best_path}")
        else:
            early_stop_counter += 1
            print(f"  -> no improvement ({early_stop_counter}/{patience})")

        if early_stop_counter >= patience:
            print(f"  -> early stopping triggered at epoch {epoch}")
            break

    history_df = pd.DataFrame(history)
    return model, history_df, best_path


# ============================================================
# 10) model 로드 함수
# ============================================================
def load_model(model_type, model_path, device):
    if model_type == "resnet":
        model = build_resnet50_patient_model()
    elif model_type == "vit":
        model = build_vit_patient_model()
    elif model_type == "hybrid":
        model = build_hybrid_patient_model()
    else:
        raise ValueError("Unknown model type")

    model.load_state_dict(torch.load(model_path, map_location=device))
    model.to(device)
    model.eval()
    return model


# ============================================================
# 11) CV 실행 함수
# ============================================================
def run_cv_for_model(model_name, model_type, build_fn):
    fold_results = []
    fold_histories = []

    for fold_idx in FOLDS:
        print("\n" + "=" * 80)
        print(f"Running {model_name} | Fold {fold_idx}")
        print("=" * 80)

        train_loader, val_loader, class_weight = make_fold_loaders(fold_idx)
        model = build_fn()

        _, history_df, best_path = fit_model(
            model=model,
            model_name=model_name,
            fold_idx=fold_idx,
            train_loader=train_loader,
            val_loader=val_loader,
            device=device,
            num_epochs=NUM_EPOCHS,
            lr=LR,
            weight_decay=WEIGHT_DECAY,
            pos_weight=class_weight,   # 함수명 유지, 실제는 class weight
            patience=PATIENCE,
        )

        best_model = load_model(model_type, best_path, device)
        final_metrics = eval_confusion(best_model, val_loader, device)

        print(f"\n[{model_name}][Fold {fold_idx}] Final Metrics")
        print(f"Accuracy      : {final_metrics['acc']:.4f}")
        print(f"Macro-F1      : {final_metrics['macro_f1']:.4f}")
        print(f"Macro-Recall  : {final_metrics['macro_recall']:.4f}")
        print(f"Balanced Acc  : {final_metrics['balanced_acc']:.4f}")
        print("Confusion Matrix:")
        print(final_metrics["cm"])

        fold_results.append({
            "model": model_name,
            "fold": fold_idx,
            "acc": final_metrics["acc"],
            "macro_f1": final_metrics["macro_f1"],
            "macro_recall": final_metrics["macro_recall"],
            "balanced_acc": final_metrics["balanced_acc"],
            "Confusion Matrix": final_metrics["cm"],
        })

        history_df["model"] = model_name
        fold_histories.append(history_df)

        del model
        del best_model
        del train_loader
        del val_loader
        gc.collect()
        if torch.cuda.is_available():
            torch.cuda.empty_cache()

    result_df = pd.DataFrame(fold_results)
    history_df_all = pd.concat(fold_histories, ignore_index=True)
    return result_df, history_df_all


# ============================================================
# 12) 실행 예시
# ============================================================
if __name__ == "__main__":
    print(">>> Training ResNet50...")
    resnet_cv_df, resnet_history_df = run_cv_for_model(
        model_name="ResNet50_US_Subtype",
        model_type="resnet",
        build_fn=lambda: build_resnet50_patient_model(load_pretrained=True),
    )
    print(resnet_cv_df)

    # 필요하면 아래 해제
    # print(">>> Training ViT...")
    # vit_cv_df, vit_history_df = run_cv_for_model(
    #     model_name="ViT-B16_US_Subtype",
    #     model_type="vit",
    #     build_fn=lambda: build_vit_patient_model(load_pretrained=True),
    # )
    # print(vit_cv_df)

    # print(">>> Training Hybrid...")
    # hybrid_cv_df, hybrid_history_df = run_cv_for_model(
    #     model_name="Hybrid_US_Subtype",
    #     model_type="hybrid",
    #     build_fn=lambda: build_hybrid_patient_model(load_pretrained=True),
    # )
    # print(hybrid_cv_df)

    # 5-fold 요약
    all_cv_df = pd.concat([resnet_cv_df], ignore_index=True)
    summary_df = (
        all_cv_df.groupby("model")[["acc", "macro_f1", "macro_recall", "balanced_acc"]]
        .agg(["mean", "std"])
    )
    print("\n===== 5-Fold Summary =====")
    print(summary_df)
# Out:
# ============================================================
# ResNet50 build success
# Vit-B/16 build success
# ============================================================
# Device: cuda
# 현재 작업 경로: /tf/notebooks/Image Encoder/Untitled Folder
# DATA_ROOT: /tf/nasw/dataset001/preprocessed/npz_us
# OUTPUT_DIR: /tf/notebooks/Image Encoder/Untitled Folder/us_subtype_models50
# FOLDS: [1, 2, 3, 4, 5]
# LOCAL_RESNET_WEIGHTS exists: True
# LOCAL_VIT_WEIGHTS exists: True
# NUM_CLASSES: 5
# SUBTYPE_ID_MAP: {0: 0, 1: 1, 3: 2, 5: 3, 7: 4}
# >>> Training ResNet50...
#
# ================================================================================
# Running ResNet50_US_Subtype | Fold 1
# ================================================================================
# Loaded fold_1_train.npz: total=2472, kept=395
# Loaded fold_1_val.npz: total=618, kept=98
# [FOLD 1] subtype counts=[32.0, 22.0, 67.0, 25.0, 249.0], class_weight=[1.1397000551223755, 1.3746000528335571, 0.7876999974250793, 1.2894999980926514, 0.40860000252723694]
# [FOLD 1] patient-level split assumed from fold_1_train/val.npz
# [ResNet50_US_Subtype][Fold 1][Epoch 01] train loss=1.4523, acc=0.5620, macro_f1=0.2081, macro_recall=0.2331, balanced_acc=0.2331 | val loss=1.3642, acc=0.6327, macro_f1=0.1550, macro_recall=0.2000, balanced_acc=0.2000
#   -> best saved by val_macro_f1: us_subtype_models50/ResNet50_US_Subtype_fold1_best.pth
# [ResNet50_US_Subtype][Fold 1][Epoch 02] train loss=1.3841, acc=0.6304, macro_f1=0.1547, macro_recall=0.2000, balanced_acc=0.2000 | val loss=1.3750, acc=0.6122, macro_f1=0.1538, macro_recall=0.1935, balanced_acc=0.1935
#   -> no improvement (1/7)
# [ResNet50_US_Subtype][Fold 1][Epoch 03] train loss=1.2604, acc=0.6405, macro_f1=0.2026, macro_recall=0.2250, balanced_acc=0.2250 | val loss=1.4110, acc=0.6224, macro_f1=0.1729, macro_recall=0.2053, balanced_acc=0.2053
#   -> best saved by val_macro_f1: us_subtype_models50/ResNet50_US_Subtype_fold1_best.pth
# [ResNet50_US_Subtype][Fold 1][Epoch 04] train loss=1.2097, acc=0.6709, macro_f1=0.3113, macro_recall=0.3104, balanced_acc=0.3104 | val loss=1.4707, acc=0.5918, macro_f1=0.2139, macro_recall=0.2383, balanced_acc=0.2383
#   -> best saved by val_macro_f1: us_subtype_models50/ResNet50_US_Subtype_fold1_best.pth
# [ResNet50_US_Subtype][Fold 1][Epoch 05] train loss=1.0976, acc=0.6987, macro_f1=0.3782, macro_recall=0.3746, balanced_acc=0.3746 | val loss=1.4538, acc=0.5816, macro_f1=0.2320, macro_recall=0.2351, balanced_acc=0.2351
#   -> best saved by val_macro_f1: us_subtype_models50/ResNet50_US_Subtype_fold1_best.pth
# [ResNet50_US_Subtype][Fold 1][Epoch 06] train loss=1.0632, acc=0.7241, macro_f1=0.4818, macro_recall=0.4567, balanced_acc=0.4567 | val loss=1.6172, acc=0.6224, macro_f1=0.2992, macro_recall=0.2848, balanced_acc=0.2848
#   -> best saved by val_macro_f1: us_subtype_models50/ResNet50_US_Subtype_fold1_best.pth
# [ResNet50_US_Subtype][Fold 1][Epoch 07] train loss=1.0839, acc=0.7190, macro_f1=0.5188, macro_recall=0.4946, balanced_acc=0.4946 | val loss=1.4677, acc=0.4592, macro_f1=0.1731, macro_recall=0.1708, balanced_acc=0.1708
#   -> no improvement (1/7)
# [ResNet50_US_Subtype][Fold 1][Epoch 08] train loss=0.8473, acc=0.7823, macro_f1=0.6361, macro_recall=0.6335, balanced_acc=0.6335 | val loss=1.6787, acc=0.4286, macro_f1=0.2181, macro_recall=0.2603, balanced_acc=0.2603
#   -> no improvement (2/7)
# [ResNet50_US_Subtype][Fold 1][Epoch 09] train loss=0.6613, acc=0.8278, macro_f1=0.7182, macro_recall=0.7431, balanced_acc=0.7431 | val loss=2.1601, acc=0.5000, macro_f1=0.1968, macro_recall=0.2093, balanced_acc=0.2093
#   -> no improvement (3/7)
# [ResNet50_US_Subtype][Fold 1][Epoch 10] train loss=0.6348, acc=0.8127, macro_f1=0.7354, macro_recall=0.7517, balanced_acc=0.7517 | val loss=2.3505, acc=0.3980, macro_f1=0.1626, macro_recall=0.1711, balanced_acc=0.1711
#   -> no improvement (4/7)
# [ResNet50_US_Subtype][Fold 1][Epoch 11] train loss=0.6020, acc=0.8532, macro_f1=0.7493, macro_recall=0.7665, balanced_acc=0.7665 | val loss=2.0672, acc=0.3673, macro_f1=0.2191, macro_recall=0.2239, balanced_acc=0.2239
#   -> no improvement (5/7)
# [ResNet50_US_Subtype][Fold 1][Epoch 12] train loss=0.4490, acc=0.8759, macro_f1=0.7945, macro_recall=0.8141, balanced_acc=0.8141 | val loss=2.0254, acc=0.4694, macro_f1=0.2489, macro_recall=0.2391, balanced_acc=0.2391
#   -> no improvement (6/7)
# [ResNet50_US_Subtype][Fold 1][Epoch 13] train loss=0.3488, acc=0.9013, macro_f1=0.8508, macro_recall=0.8677, balanced_acc=0.8677 | val loss=2.2759, acc=0.3980, macro_f1=0.2220, macro_recall=0.2157, balanced_acc=0.2157
#   -> no improvement (7/7)
#   -> early stopping triggered at epoch 13
#
# -- Final Evaluation --
# Accuracy      : 0.6224
# Macro-F1      : 0.2992
# Macro-Recall  : 0.2848
# Balanced Acc  : 0.2848
# [[ 0  1  0  0  7]
#  [ 0  1  0  0  4]
#  [ 0  0  6  0 11]
#  [ 3  0  0  0  3]
#  [ 4  0  4  0 54]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#   clear_cell     0.0000    0.0000    0.0000         8
# endometrioid     0.5000    0.2000    0.2857         5
#          etc     0.6000    0.3529    0.4444        17
#     mucinous     0.0000    0.0000    0.0000         6
#       serous     0.6835    0.8710    0.7660        62
#
#     accuracy                         0.6224        98
#    macro avg     0.3567    0.2848    0.2992        98
# weighted avg     0.5620    0.6224    0.5763        98
#
#
# [ResNet50_US_Subtype][Fold 1] Final Metrics
# Accuracy      : 0.6224
# Macro-F1      : 0.2992
# Macro-Recall  : 0.2848
# Balanced Acc  : 0.2848
# Confusion Matrix:
# [[ 0  1  0  0  7]
#  [ 0  1  0  0  4]
#  [ 0  0  6  0 11]
#  [ 3  0  0  0  3]
#  [ 4  0  4  0 54]]
#
# ================================================================================
# Running ResNet50_US_Subtype | Fold 2
# ================================================================================
# Loaded fold_2_train.npz: total=2472, kept=395
# Loaded fold_2_val.npz: total=618, kept=98
# [FOLD 2] subtype counts=[32.0, 22.0, 67.0, 25.0, 249.0], class_weight=[1.1397000551223755, 1.3746000528335571, 0.7876999974250793, 1.2894999980926514, 0.40860000252723694]
# [FOLD 2] patient-level split assumed from fold_2_train/val.npz
# [ResNet50_US_Subtype][Fold 2][Epoch 01] train loss=1.4512, acc=0.5975, macro_f1=0.1620, macro_recall=0.1968, balanced_acc=0.1968 | val loss=1.4256, acc=0.6327, macro_f1=0.1550, macro_recall=0.2000, balanced_acc=0.2000
#   -> best saved by val_macro_f1: us_subtype_models50/ResNet50_US_Subtype_fold2_best.pth
# [ResNet50_US_Subtype][Fold 2][Epoch 02] train loss=1.3449, acc=0.6329, macro_f1=0.1608, macro_recall=0.2030, balanced_acc=0.2030 | val loss=1.5038, acc=0.6429, macro_f1=0.1782, macro_recall=0.2118, balanced_acc=0.2118
#   -> best saved by val_macro_f1: us_subtype_models50/ResNet50_US_Subtype_fold2_best.pth
# [ResNet50_US_Subtype][Fold 2][Epoch 03] train loss=1.2239, acc=0.6430, macro_f1=0.2069, macro_recall=0.2302, balanced_acc=0.2302 | val loss=1.9622, acc=0.6327, macro_f1=0.1550, macro_recall=0.2000, balanced_acc=0.2000
#   -> no improvement (1/7)
# [ResNet50_US_Subtype][Fold 2][Epoch 04] train loss=1.2407, acc=0.6329, macro_f1=0.2273, macro_recall=0.2429, balanced_acc=0.2429 | val loss=1.9008, acc=0.6531, macro_f1=0.2605, macro_recall=0.3004, balanced_acc=0.3004
#   -> best saved by val_macro_f1: us_subtype_models50/ResNet50_US_Subtype_fold2_best.pth
# [ResNet50_US_Subtype][Fold 2][Epoch 05] train loss=1.1024, acc=0.6785, macro_f1=0.2944, macro_recall=0.3045, balanced_acc=0.3045 | val loss=2.0292, acc=0.6633, macro_f1=0.2677, macro_recall=0.3036, balanced_acc=0.3036
#   -> best saved by val_macro_f1: us_subtype_models50/ResNet50_US_Subtype_fold2_best.pth
# [ResNet50_US_Subtype][Fold 2][Epoch 06] train loss=0.9648, acc=0.7139, macro_f1=0.4226, macro_recall=0.4075, balanced_acc=0.4075 | val loss=2.0486, acc=0.6429, macro_f1=0.3233, macro_recall=0.3149, balanced_acc=0.3149
#   -> best saved by val_macro_f1: us_subtype_models50/ResNet50_US_Subtype_fold2_best.pth
# [ResNet50_US_Subtype][Fold 2][Epoch 07] train loss=0.8396, acc=0.7848, macro_f1=0.6295, macro_recall=0.6160, balanced_acc=0.6160 | val loss=2.4853, acc=0.6122, macro_f1=0.2849, macro_recall=0.3007, balanced_acc=0.3007
#   -> no improvement (1/7)
# [ResNet50_US_Subtype][Fold 2][Epoch 08] train loss=0.6500, acc=0.8405, macro_f1=0.6921, macro_recall=0.6925, balanced_acc=0.6925 | val loss=2.0128, acc=0.3673, macro_f1=0.2035, macro_recall=0.2489, balanced_acc=0.2489
#   -> no improvement (2/7)
# [ResNet50_US_Subtype][Fold 2][Epoch 09] train loss=0.7026, acc=0.8203, macro_f1=0.7086, macro_recall=0.7168, balanced_acc=0.7168 | val loss=2.7052, acc=0.6633, macro_f1=0.2932, macro_recall=0.3083, balanced_acc=0.3083
#   -> no improvement (3/7)
# [ResNet50_US_Subtype][Fold 2][Epoch 10] train loss=0.4210, acc=0.8937, macro_f1=0.8071, macro_recall=0.8370, balanced_acc=0.8370 | val loss=2.9556, acc=0.6327, macro_f1=0.3107, macro_recall=0.2946, balanced_acc=0.2946
#   -> no improvement (4/7)
# [ResNet50_US_Subtype][Fold 2][Epoch 11] train loss=0.2567, acc=0.9215, macro_f1=0.8847, macro_recall=0.9014, balanced_acc=0.9014 | val loss=2.7347, acc=0.5306, macro_f1=0.2861, macro_recall=0.3048, balanced_acc=0.3048
#   -> no improvement (5/7)
# [ResNet50_US_Subtype][Fold 2][Epoch 12] train loss=0.1965, acc=0.9392, macro_f1=0.9394, macro_recall=0.9600, balanced_acc=0.9600 | val loss=3.0730, acc=0.6429, macro_f1=0.3523, macro_recall=0.3450, balanced_acc=0.3450
#   -> best saved by val_macro_f1: us_subtype_models50/ResNet50_US_Subtype_fold2_best.pth
# [ResNet50_US_Subtype][Fold 2][Epoch 13] train loss=0.2220, acc=0.9468, macro_f1=0.9158, macro_recall=0.9162, balanced_acc=0.9162 | val loss=3.1357, acc=0.5612, macro_f1=0.2356, macro_recall=0.2547, balanced_acc=0.2547
#   -> no improvement (1/7)
# [ResNet50_US_Subtype][Fold 2][Epoch 14] train loss=0.1957, acc=0.9544, macro_f1=0.9331, macro_recall=0.9417, balanced_acc=0.9417 | val loss=2.7006, acc=0.6327, macro_f1=0.2944, macro_recall=0.3070, balanced_acc=0.3070
#   -> no improvement (2/7)
# [ResNet50_US_Subtype][Fold 2][Epoch 15] train loss=0.1000, acc=0.9747, macro_f1=0.9677, macro_recall=0.9760, balanced_acc=0.9760 | val loss=3.2837, acc=0.6327, macro_f1=0.3044, macro_recall=0.3114, balanced_acc=0.3114
#   -> no improvement (3/7)
# [ResNet50_US_Subtype][Fold 2][Epoch 16] train loss=0.1499, acc=0.9494, macro_f1=0.9325, macro_recall=0.9545, balanced_acc=0.9545 | val loss=3.5132, acc=0.6633, macro_f1=0.3358, macro_recall=0.3126, balanced_acc=0.3126
#   -> no improvement (4/7)
# [ResNet50_US_Subtype][Fold 2][Epoch 17] train loss=0.0731, acc=0.9823, macro_f1=0.9721, macro_recall=0.9691, balanced_acc=0.9691 | val loss=3.3787, acc=0.6327, macro_f1=0.3006, macro_recall=0.2944, balanced_acc=0.2944
#   -> no improvement (5/7)
# [ResNet50_US_Subtype][Fold 2][Epoch 18] train loss=0.0695, acc=0.9823, macro_f1=0.9687, macro_recall=0.9730, balanced_acc=0.9730 | val loss=3.3165, acc=0.6327, macro_f1=0.3311, macro_recall=0.3200, balanced_acc=0.3200
#   -> no improvement (6/7)
# [ResNet50_US_Subtype][Fold 2][Epoch 19] train loss=0.0343, acc=0.9949, macro_f1=0.9933, macro_recall=0.9984, balanced_acc=0.9984 | val loss=3.2925, acc=0.7041, macro_f1=0.3293, macro_recall=0.3210, balanced_acc=0.3210
#   -> no improvement (7/7)
#   -> early stopping triggered at epoch 19
#
# -- Final Evaluation --
# Accuracy      : 0.6429
# Macro-F1      : 0.3523
# Macro-Recall  : 0.3450
# Balanced Acc  : 0.3450
# [[ 1  0  0  1  6]
#  [ 0  0  1  0  4]
#  [ 1  1  7  1  7]
#  [ 0  0  0  2  4]
#  [ 2  0  6  1 53]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#   clear_cell     0.2500    0.1250    0.1667         8
# endometrioid     0.0000    0.0000    0.0000         5
#          etc     0.5000    0.4118    0.4516        17
#     mucinous     0.4000    0.3333    0.3636         6
#       serous     0.7162    0.8548    0.7794        62
#
#     accuracy                         0.6429        98
#    macro avg     0.3732    0.3450    0.3523        98
# weighted avg     0.5847    0.6429    0.6073        98
#
#
# [ResNet50_US_Subtype][Fold 2] Final Metrics
# Accuracy      : 0.6429
# Macro-F1      : 0.3523
# Macro-Recall  : 0.3450
# Balanced Acc  : 0.3450
# Confusion Matrix:
# [[ 1  0  0  1  6]
#  [ 0  0  1  0  4]
#  [ 1  1  7  1  7]
#  [ 0  0  0  2  4]
#  [ 2  0  6  1 53]]
#
# ================================================================================
# Running ResNet50_US_Subtype | Fold 3
# ================================================================================
# Loaded fold_3_train.npz: total=2472, kept=394
# Loaded fold_3_val.npz: total=618, kept=99
# [FOLD 3] subtype counts=[32.0, 21.0, 68.0, 25.0, 248.0], class_weight=[1.1334999799728394, 1.3992999792099, 0.7775999903678894, 1.2824000120162964, 0.40720000863075256]
# [FOLD 3] patient-level split assumed from fold_3_train/val.npz
# [ResNet50_US_Subtype][Fold 3][Epoch 01] train loss=1.4731, acc=0.6117, macro_f1=0.1636, macro_recall=0.1986, balanced_acc=0.1986 | val loss=1.3928, acc=0.6364, macro_f1=0.1556, macro_recall=0.2000, balanced_acc=0.2000
#   -> best saved by val_macro_f1: us_subtype_models50/ResNet50_US_Subtype_fold3_best.pth
# [ResNet50_US_Subtype][Fold 3][Epoch 02] train loss=1.3433, acc=0.6320, macro_f1=0.1606, macro_recall=0.2029, balanced_acc=0.2029 | val loss=1.3235, acc=0.5960, macro_f1=0.1917, macro_recall=0.2153, balanced_acc=0.2153
#   -> best saved by val_macro_f1: us_subtype_models50/ResNet50_US_Subtype_fold3_best.pth
# [ResNet50_US_Subtype][Fold 3][Epoch 03] train loss=1.2846, acc=0.6371, macro_f1=0.2310, macro_recall=0.2537, balanced_acc=0.2537 | val loss=1.4254, acc=0.6162, macro_f1=0.2091, macro_recall=0.2310, balanced_acc=0.2310
#   -> best saved by val_macro_f1: us_subtype_models50/ResNet50_US_Subtype_fold3_best.pth
# [ResNet50_US_Subtype][Fold 3][Epoch 04] train loss=1.2174, acc=0.6701, macro_f1=0.2624, macro_recall=0.2940, balanced_acc=0.2940 | val loss=1.5216, acc=0.6263, macro_f1=0.2014, macro_recall=0.2248, balanced_acc=0.2248
#   -> no improvement (1/7)
# [ResNet50_US_Subtype][Fold 3][Epoch 05] train loss=1.1237, acc=0.6751, macro_f1=0.2796, macro_recall=0.3071, balanced_acc=0.3071 | val loss=1.5506, acc=0.5657, macro_f1=0.2196, macro_recall=0.2617, balanced_acc=0.2617
#   -> best saved by val_macro_f1: us_subtype_models50/ResNet50_US_Subtype_fold3_best.pth
# [ResNet50_US_Subtype][Fold 3][Epoch 06] train loss=1.0280, acc=0.7208, macro_f1=0.3581, macro_recall=0.3601, balanced_acc=0.3601 | val loss=1.5008, acc=0.5253, macro_f1=0.2290, macro_recall=0.2512, balanced_acc=0.2512
#   -> best saved by val_macro_f1: us_subtype_models50/ResNet50_US_Subtype_fold3_best.pth
# [ResNet50_US_Subtype][Fold 3][Epoch 07] train loss=0.8475, acc=0.7995, macro_f1=0.5881, macro_recall=0.5515, balanced_acc=0.5515 | val loss=1.7605, acc=0.5960, macro_f1=0.2577, macro_recall=0.2548, balanced_acc=0.2548
#   -> best saved by val_macro_f1: us_subtype_models50/ResNet50_US_Subtype_fold3_best.pth
# [ResNet50_US_Subtype][Fold 3][Epoch 08] train loss=0.7395, acc=0.8198, macro_f1=0.6722, macro_recall=0.6652, balanced_acc=0.6652 | val loss=1.9563, acc=0.4949, macro_f1=0.1845, macro_recall=0.2159, balanced_acc=0.2159
#   -> no improvement (1/7)
# [ResNet50_US_Subtype][Fold 3][Epoch 09] train loss=0.6937, acc=0.7665, macro_f1=0.5894, macro_recall=0.6059, balanced_acc=0.6059 | val loss=2.6160, acc=0.5859, macro_f1=0.2161, macro_recall=0.2214, balanced_acc=0.2214
#   -> no improvement (2/7)
# [ResNet50_US_Subtype][Fold 3][Epoch 10] train loss=0.5210, acc=0.8832, macro_f1=0.8086, macro_recall=0.8060, balanced_acc=0.8060 | val loss=2.0964, acc=0.4747, macro_f1=0.2175, macro_recall=0.2353, balanced_acc=0.2353
#   -> no improvement (3/7)
# [ResNet50_US_Subtype][Fold 3][Epoch 11] train loss=0.3668, acc=0.9061, macro_f1=0.8449, macro_recall=0.8190, balanced_acc=0.8190 | val loss=2.7476, acc=0.4141, macro_f1=0.2023, macro_recall=0.2266, balanced_acc=0.2266
#   -> no improvement (4/7)
# [ResNet50_US_Subtype][Fold 3][Epoch 12] train loss=0.3586, acc=0.9086, macro_f1=0.8512, macro_recall=0.8646, balanced_acc=0.8646 | val loss=2.9577, acc=0.5758, macro_f1=0.2630, macro_recall=0.2867, balanced_acc=0.2867
#   -> best saved by val_macro_f1: us_subtype_models50/ResNet50_US_Subtype_fold3_best.pth
# [ResNet50_US_Subtype][Fold 3][Epoch 13] train loss=0.2199, acc=0.9340, macro_f1=0.9067, macro_recall=0.9285, balanced_acc=0.9285 | val loss=3.5209, acc=0.5556, macro_f1=0.2664, macro_recall=0.2897, balanced_acc=0.2897
#   -> best saved by val_macro_f1: us_subtype_models50/ResNet50_US_Subtype_fold3_best.pth
# [ResNet50_US_Subtype][Fold 3][Epoch 14] train loss=0.1767, acc=0.9543, macro_f1=0.9359, macro_recall=0.9445, balanced_acc=0.9445 | val loss=3.1183, acc=0.5758, macro_f1=0.3086, macro_recall=0.3107, balanced_acc=0.3107
#   -> best saved by val_macro_f1: us_subtype_models50/ResNet50_US_Subtype_fold3_best.pth
# [ResNet50_US_Subtype][Fold 3][Epoch 15] train loss=0.1630, acc=0.9594, macro_f1=0.9464, macro_recall=0.9623, balanced_acc=0.9623 | val loss=2.9538, acc=0.6263, macro_f1=0.2575, macro_recall=0.2653, balanced_acc=0.2653
#   -> no improvement (1/7)
# [ResNet50_US_Subtype][Fold 3][Epoch 16] train loss=0.0934, acc=0.9721, macro_f1=0.9680, macro_recall=0.9700, balanced_acc=0.9700 | val loss=3.2129, acc=0.6263, macro_f1=0.3067, macro_recall=0.2986, balanced_acc=0.2986
#   -> no improvement (2/7)
# [ResNet50_US_Subtype][Fold 3][Epoch 17] train loss=0.0893, acc=0.9721, macro_f1=0.9593, macro_recall=0.9694, balanced_acc=0.9694 | val loss=3.0316, acc=0.5960, macro_f1=0.3099, macro_recall=0.3077, balanced_acc=0.3077
#   -> best saved by val_macro_f1: us_subtype_models50/ResNet50_US_Subtype_fold3_best.pth
# [ResNet50_US_Subtype][Fold 3][Epoch 18] train loss=0.0928, acc=0.9797, macro_f1=0.9783, macro_recall=0.9763, balanced_acc=0.9763 | val loss=3.2456, acc=0.5960, macro_f1=0.2969, macro_recall=0.2859, balanced_acc=0.2859
#   -> no improvement (1/7)
# [ResNet50_US_Subtype][Fold 3][Epoch 19] train loss=0.0579, acc=0.9822, macro_f1=0.9871, macro_recall=0.9901, balanced_acc=0.9901 | val loss=3.1651, acc=0.5758, macro_f1=0.2770, macro_recall=0.2796, balanced_acc=0.2796
#   -> no improvement (2/7)
# [ResNet50_US_Subtype][Fold 3][Epoch 20] train loss=0.0323, acc=0.9949, macro_f1=0.9922, macro_recall=0.9984, balanced_acc=0.9984 | val loss=3.5850, acc=0.6061, macro_f1=0.2442, macro_recall=0.2496, balanced_acc=0.2496
#   -> no improvement (3/7)
# [ResNet50_US_Subtype][Fold 3][Epoch 21] train loss=0.0202, acc=0.9949, macro_f1=0.9963, macro_recall=0.9963, balanced_acc=0.9963 | val loss=3.5639, acc=0.5960, macro_f1=0.2601, macro_recall=0.2651, balanced_acc=0.2651
#   -> no improvement (4/7)
# [ResNet50_US_Subtype][Fold 3][Epoch 22] train loss=0.0554, acc=0.9873, macro_f1=0.9889, macro_recall=0.9863, balanced_acc=0.9863 | val loss=4.0830, acc=0.5758, macro_f1=0.2442, macro_recall=0.2494, balanced_acc=0.2494
#   -> no improvement (5/7)
# [ResNet50_US_Subtype][Fold 3][Epoch 23] train loss=0.0637, acc=0.9721, macro_f1=0.9748, macro_recall=0.9826, balanced_acc=0.9826 | val loss=3.3498, acc=0.5556, macro_f1=0.2745, macro_recall=0.2732, balanced_acc=0.2732
#   -> no improvement (6/7)
# [ResNet50_US_Subtype][Fold 3][Epoch 24] train loss=0.0587, acc=0.9848, macro_f1=0.9821, macro_recall=0.9821, balanced_acc=0.9821 | val loss=3.3127, acc=0.5051, macro_f1=0.2179, macro_recall=0.2169, balanced_acc=0.2169
#   -> no improvement (7/7)
#   -> early stopping triggered at epoch 24
#
# -- Final Evaluation --
# Accuracy      : 0.5960
# Macro-F1      : 0.3099
# Macro-Recall  : 0.3077
# Balanced Acc  : 0.3077
# [[ 2  0  0  1  5]
#  [ 2  0  1  0  3]
#  [ 0  0  5  2  9]
#  [ 1  1  3  1  0]
#  [ 2  3  6  1 51]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#   clear_cell     0.2857    0.2500    0.2667         8
# endometrioid     0.0000    0.0000    0.0000         6
#          etc     0.3333    0.3125    0.3226        16
#     mucinous     0.2000    0.1667    0.1818         6
#       serous     0.7500    0.8095    0.7786        63
#
#     accuracy                         0.5960        99
#    macro avg     0.3138    0.3077    0.3099        99
# weighted avg     0.5664    0.5960    0.5802        99
#
#
# [ResNet50_US_Subtype][Fold 3] Final Metrics
# Accuracy      : 0.5960
# Macro-F1      : 0.3099
# Macro-Recall  : 0.3077
# Balanced Acc  : 0.3077
# Confusion Matrix:
# [[ 2  0  0  1  5]
#  [ 2  0  1  0  3]
#  [ 0  0  5  2  9]
#  [ 1  1  3  1  0]
#  [ 2  3  6  1 51]]
#
# ================================================================================
# Running ResNet50_US_Subtype | Fold 4
# ================================================================================
# Loaded fold_4_train.npz: total=2472, kept=394
# Loaded fold_4_val.npz: total=618, kept=99
# [FOLD 4] subtype counts=[32.0, 21.0, 67.0, 25.0, 249.0], class_weight=[1.1324000358581543, 1.3978999853134155, 0.7825999855995178, 1.2812000513076782, 0.4059999883174896]
# [FOLD 4] patient-level split assumed from fold_4_train/val.npz
# [ResNet50_US_Subtype][Fold 4][Epoch 01] train loss=1.4740, acc=0.6091, macro_f1=0.1531, macro_recall=0.1928, balanced_acc=0.1928 | val loss=1.4104, acc=0.6263, macro_f1=0.1540, macro_recall=0.2000, balanced_acc=0.2000
#   -> best saved by val_macro_f1: us_subtype_models50/ResNet50_US_Subtype_fold4_best.pth
# [ResNet50_US_Subtype][Fold 4][Epoch 02] train loss=1.3721, acc=0.6320, macro_f1=0.1549, macro_recall=0.2000, balanced_acc=0.2000 | val loss=1.4117, acc=0.6364, macro_f1=0.1772, macro_recall=0.2118, balanced_acc=0.2118
#   -> best saved by val_macro_f1: us_subtype_models50/ResNet50_US_Subtype_fold4_best.pth
# [ResNet50_US_Subtype][Fold 4][Epoch 03] train loss=1.2661, acc=0.6548, macro_f1=0.2184, macro_recall=0.2378, balanced_acc=0.2378 | val loss=1.4962, acc=0.6263, macro_f1=0.1745, macro_recall=0.2085, balanced_acc=0.2085
#   -> no improvement (1/7)
# [ResNet50_US_Subtype][Fold 4][Epoch 04] train loss=1.1466, acc=0.6675, macro_f1=0.2439, macro_recall=0.2658, balanced_acc=0.2658 | val loss=1.7576, acc=0.5657, macro_f1=0.1827, macro_recall=0.2063, balanced_acc=0.2063
#   -> best saved by val_macro_f1: us_subtype_models50/ResNet50_US_Subtype_fold4_best.pth
# [ResNet50_US_Subtype][Fold 4][Epoch 05] train loss=1.0525, acc=0.6777, macro_f1=0.2758, macro_recall=0.3028, balanced_acc=0.3028 | val loss=1.8025, acc=0.6162, macro_f1=0.2180, macro_recall=0.2395, balanced_acc=0.2395
#   -> best saved by val_macro_f1: us_subtype_models50/ResNet50_US_Subtype_fold4_best.pth
# [ResNet50_US_Subtype][Fold 4][Epoch 06] train loss=0.9637, acc=0.7360, macro_f1=0.4452, macro_recall=0.4262, balanced_acc=0.4262 | val loss=1.8370, acc=0.5354, macro_f1=0.2048, macro_recall=0.2393, balanced_acc=0.2393
#   -> no improvement (1/7)
# [ResNet50_US_Subtype][Fold 4][Epoch 07] train loss=0.9166, acc=0.7640, macro_f1=0.5483, macro_recall=0.5202, balanced_acc=0.5202 | val loss=1.8747, acc=0.5758, macro_f1=0.2277, macro_recall=0.2607, balanced_acc=0.2607
#   -> best saved by val_macro_f1: us_subtype_models50/ResNet50_US_Subtype_fold4_best.pth
# [ResNet50_US_Subtype][Fold 4][Epoch 08] train loss=0.7419, acc=0.8198, macro_f1=0.6435, macro_recall=0.6338, balanced_acc=0.6338 | val loss=2.2901, acc=0.5859, macro_f1=0.1921, macro_recall=0.2127, balanced_acc=0.2127
#   -> no improvement (1/7)
# [ResNet50_US_Subtype][Fold 4][Epoch 09] train loss=0.6409, acc=0.8401, macro_f1=0.7125, macro_recall=0.7098, balanced_acc=0.7098 | val loss=2.5156, acc=0.5859, macro_f1=0.2456, macro_recall=0.2516, balanced_acc=0.2516
#   -> best saved by val_macro_f1: us_subtype_models50/ResNet50_US_Subtype_fold4_best.pth
# [ResNet50_US_Subtype][Fold 4][Epoch 10] train loss=0.5123, acc=0.8604, macro_f1=0.7466, macro_recall=0.7659, balanced_acc=0.7659 | val loss=2.5022, acc=0.5253, macro_f1=0.2133, macro_recall=0.2361, balanced_acc=0.2361
#   -> no improvement (1/7)
# [ResNet50_US_Subtype][Fold 4][Epoch 11] train loss=0.3591, acc=0.8934, macro_f1=0.7764, macro_recall=0.7751, balanced_acc=0.7751 | val loss=2.5356, acc=0.5859, macro_f1=0.2933, macro_recall=0.2990, balanced_acc=0.2990
#   -> best saved by val_macro_f1: us_subtype_models50/ResNet50_US_Subtype_fold4_best.pth
# [ResNet50_US_Subtype][Fold 4][Epoch 12] train loss=0.3417, acc=0.9213, macro_f1=0.8857, macro_recall=0.8796, balanced_acc=0.8796 | val loss=2.4525, acc=0.5657, macro_f1=0.2230, macro_recall=0.2575, balanced_acc=0.2575
#   -> no improvement (1/7)
# [ResNet50_US_Subtype][Fold 4][Epoch 13] train loss=0.2320, acc=0.9315, macro_f1=0.9135, macro_recall=0.9122, balanced_acc=0.9122 | val loss=2.6403, acc=0.5657, macro_f1=0.2627, macro_recall=0.2534, balanced_acc=0.2534
#   -> no improvement (2/7)
# [ResNet50_US_Subtype][Fold 4][Epoch 14] train loss=0.2329, acc=0.9340, macro_f1=0.8833, macro_recall=0.8989, balanced_acc=0.8989 | val loss=2.5759, acc=0.5152, macro_f1=0.2197, macro_recall=0.2418, balanced_acc=0.2418
#   -> no improvement (3/7)
# [ResNet50_US_Subtype][Fold 4][Epoch 15] train loss=0.1629, acc=0.9619, macro_f1=0.9343, macro_recall=0.9426, balanced_acc=0.9426 | val loss=2.7395, acc=0.5859, macro_f1=0.2731, macro_recall=0.2686, balanced_acc=0.2686
#   -> no improvement (4/7)
# [ResNet50_US_Subtype][Fold 4][Epoch 16] train loss=0.0942, acc=0.9746, macro_f1=0.9673, macro_recall=0.9767, balanced_acc=0.9767 | val loss=2.9671, acc=0.5556, macro_f1=0.2810, macro_recall=0.2852, balanced_acc=0.2852
#   -> no improvement (5/7)
# [ResNet50_US_Subtype][Fold 4][Epoch 17] train loss=0.1513, acc=0.9594, macro_f1=0.9434, macro_recall=0.9653, balanced_acc=0.9653 | val loss=2.9821, acc=0.5657, macro_f1=0.2516, macro_recall=0.2537, balanced_acc=0.2537
#   -> no improvement (6/7)
# [ResNet50_US_Subtype][Fold 4][Epoch 18] train loss=0.1113, acc=0.9746, macro_f1=0.9678, macro_recall=0.9767, balanced_acc=0.9767 | val loss=3.1037, acc=0.5960, macro_f1=0.2482, macro_recall=0.2633, balanced_acc=0.2633
#   -> no improvement (7/7)
#   -> early stopping triggered at epoch 18
#
# -- Final Evaluation --
# Accuracy      : 0.5859
# Macro-F1      : 0.2933
# Macro-Recall  : 0.2990
# Balanced Acc  : 0.2990
# [[ 2  0  0  0  6]
#  [ 1  0  0  0  5]
#  [ 3  0  8  0  6]
#  [ 2  0  0  0  4]
#  [ 6  2  4  2 48]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#   clear_cell     0.1429    0.2500    0.1818         8
# endometrioid     0.0000    0.0000    0.0000         6
#          etc     0.6667    0.4706    0.5517        17
#     mucinous     0.0000    0.0000    0.0000         6
#       serous     0.6957    0.7742    0.7328        62
#
#     accuracy                         0.5859        99
#    macro avg     0.3010    0.2990    0.2933        99
# weighted avg     0.5617    0.5859    0.5684        99
#
#
# [ResNet50_US_Subtype][Fold 4] Final Metrics
# Accuracy      : 0.5859
# Macro-F1      : 0.2933
# Macro-Recall  : 0.2990
# Balanced Acc  : 0.2990
# Confusion Matrix:
# [[ 2  0  0  0  6]
#  [ 1  0  0  0  5]
#  [ 3  0  8  0  6]
#  [ 2  0  0  0  4]
#  [ 6  2  4  2 48]]
#
# ================================================================================
# Running ResNet50_US_Subtype | Fold 5
# ================================================================================
# Loaded fold_5_train.npz: total=2472, kept=394
# Loaded fold_5_val.npz: total=618, kept=99
# [FOLD 5] subtype counts=[32.0, 22.0, 67.0, 24.0, 249.0], class_weight=[1.1337000131607056, 1.367300033569336, 0.7835000157356262, 1.3091000318527222, 0.40639999508857727]
# [FOLD 5] patient-level split assumed from fold_5_train/val.npz
# [ResNet50_US_Subtype][Fold 5][Epoch 01] train loss=1.4601, acc=0.6269, macro_f1=0.1915, macro_recall=0.2154, balanced_acc=0.2154 | val loss=1.4331, acc=0.6263, macro_f1=0.1540, macro_recall=0.2000, balanced_acc=0.2000
#   -> best saved by val_macro_f1: us_subtype_models50/ResNet50_US_Subtype_fold5_best.pth
# [ResNet50_US_Subtype][Fold 5][Epoch 02] train loss=1.3521, acc=0.6345, macro_f1=0.1610, macro_recall=0.2030, balanced_acc=0.2030 | val loss=1.3681, acc=0.6263, macro_f1=0.1540, macro_recall=0.2000, balanced_acc=0.2000
#   -> no improvement (1/7)
# [ResNet50_US_Subtype][Fold 5][Epoch 03] train loss=1.3066, acc=0.6371, macro_f1=0.1990, macro_recall=0.2234, balanced_acc=0.2234 | val loss=1.5154, acc=0.6263, macro_f1=0.1744, macro_recall=0.2085, balanced_acc=0.2085
#   -> best saved by val_macro_f1: us_subtype_models50/ResNet50_US_Subtype_fold5_best.pth
# [ResNet50_US_Subtype][Fold 5][Epoch 04] train loss=1.1742, acc=0.6396, macro_f1=0.2174, macro_recall=0.2395, balanced_acc=0.2395 | val loss=1.9484, acc=0.6162, macro_f1=0.2368, macro_recall=0.2651, balanced_acc=0.2651
#   -> best saved by val_macro_f1: us_subtype_models50/ResNet50_US_Subtype_fold5_best.pth
# [ResNet50_US_Subtype][Fold 5][Epoch 05] train loss=1.1959, acc=0.6523, macro_f1=0.3346, macro_recall=0.3343, balanced_acc=0.3343 | val loss=1.5433, acc=0.5859, macro_f1=0.2369, macro_recall=0.2725, balanced_acc=0.2725
#   -> no improvement (1/7)
# [ResNet50_US_Subtype][Fold 5][Epoch 06] train loss=1.0554, acc=0.7183, macro_f1=0.4855, macro_recall=0.4657, balanced_acc=0.4657 | val loss=1.5682, acc=0.5556, macro_f1=0.3297, macro_recall=0.3517, balanced_acc=0.3517
#   -> best saved by val_macro_f1: us_subtype_models50/ResNet50_US_Subtype_fold5_best.pth
# [ResNet50_US_Subtype][Fold 5][Epoch 07] train loss=0.9297, acc=0.7462, macro_f1=0.5333, macro_recall=0.5328, balanced_acc=0.5328 | val loss=2.3656, acc=0.6263, macro_f1=0.2435, macro_recall=0.2598, balanced_acc=0.2598
#   -> no improvement (1/7)
# [ResNet50_US_Subtype][Fold 5][Epoch 08] train loss=0.8730, acc=0.7766, macro_f1=0.5655, macro_recall=0.5699, balanced_acc=0.5699 | val loss=1.9688, acc=0.5152, macro_f1=0.2611, macro_recall=0.2629, balanced_acc=0.2629
#   -> no improvement (2/7)
# [ResNet50_US_Subtype][Fold 5][Epoch 09] train loss=0.7625, acc=0.8122, macro_f1=0.6837, macro_recall=0.6878, balanced_acc=0.6878 | val loss=2.4256, acc=0.4949, macro_f1=0.2711, macro_recall=0.2991, balanced_acc=0.2991
#   -> no improvement (3/7)
# [ResNet50_US_Subtype][Fold 5][Epoch 10] train loss=0.6448, acc=0.8325, macro_f1=0.6775, macro_recall=0.6863, balanced_acc=0.6863 | val loss=2.0405, acc=0.4545, macro_f1=0.2779, macro_recall=0.3080, balanced_acc=0.3080
#   -> no improvement (4/7)
# [ResNet50_US_Subtype][Fold 5][Epoch 11] train loss=0.5048, acc=0.8756, macro_f1=0.7797, macro_recall=0.7761, balanced_acc=0.7761 | val loss=1.9889, acc=0.4949, macro_f1=0.2874, macro_recall=0.2914, balanced_acc=0.2914
#   -> no improvement (5/7)
# [ResNet50_US_Subtype][Fold 5][Epoch 12] train loss=0.4325, acc=0.8782, macro_f1=0.7744, macro_recall=0.7908, balanced_acc=0.7908 | val loss=2.2091, acc=0.4646, macro_f1=0.3011, macro_recall=0.2965, balanced_acc=0.2965
#   -> no improvement (6/7)
# [ResNet50_US_Subtype][Fold 5][Epoch 13] train loss=0.3443, acc=0.9264, macro_f1=0.8778, macro_recall=0.8741, balanced_acc=0.8741 | val loss=2.5577, acc=0.4949, macro_f1=0.2789, macro_recall=0.2976, balanced_acc=0.2976
#   -> no improvement (7/7)
#   -> early stopping triggered at epoch 13
#
# -- Final Evaluation --
# Accuracy      : 0.5556
# Macro-F1      : 0.3297
# Macro-Recall  : 0.3517
# Balanced Acc  : 0.3517
# [[ 2  1  3  0  2]
#  [ 0  1  1  0  3]
#  [ 0  1 11  1  4]
#  [ 1  0  5  0  1]
#  [ 5  0 15  1 41]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#   clear_cell     0.2500    0.2500    0.2500         8
# endometrioid     0.3333    0.2000    0.2500         5
#          etc     0.3143    0.6471    0.4231        17
#     mucinous     0.0000    0.0000    0.0000         7
#       serous     0.8039    0.6613    0.7257        62
#
#     accuracy                         0.5556        99
#    macro avg     0.3403    0.3517    0.3297        99
# weighted avg     0.5945    0.5556    0.5599        99
#
#
# [ResNet50_US_Subtype][Fold 5] Final Metrics
# Accuracy      : 0.5556
# Macro-F1      : 0.3297
# Macro-Recall  : 0.3517
# Balanced Acc  : 0.3517
# Confusion Matrix:
# [[ 2  1  3  0  2]
#  [ 0  1  1  0  3]
#  [ 0  1 11  1  4]
#  [ 1  0  5  0  1]
#  [ 5  0 15  1 41]]
#                  model  fold       acc  macro_f1  macro_recall  balanced_acc  \
# 0  ResNet50_US_Subtype     1  0.622449  0.299223      0.284782      0.284782
# 1  ResNet50_US_Subtype     2  0.642857  0.352266      0.344987      0.344987
# 2  ResNet50_US_Subtype     3  0.595960  0.309938      0.307738      0.307738
# 3  ResNet50_US_Subtype     4  0.585859  0.293273      0.298956      0.298956
# 4  ResNet50_US_Subtype     5  0.555556  0.329748      0.351670      0.351670
#
#                                     Confusion Matrix
# 0  [[0, 1, 0, 0, 7], [0, 1, 0, 0, 4], [0, 0, 6, 0...
# 1  [[1, 0, 0, 1, 6], [0, 0, 1, 0, 4], [1, 1, 7, 1...
# 2  [[2, 0, 0, 1, 5], [2, 0, 1, 0, 3], [0, 0, 5, 2...
# 3  [[2, 0, 0, 0, 6], [1, 0, 0, 0, 5], [3, 0, 8, 0...
# 4  [[2, 1, 3, 0, 2], [0, 1, 1, 0, 3], [0, 1, 11, ...
#
# ===== 5-Fold Summary =====
#                           acc           macro_f1           macro_recall  \
#                          mean       std     mean       std         mean
# model
# ResNet50_US_Subtype  0.600536  0.033656  0.31689  0.024161     0.317627
#
#                               balanced_acc
#                           std         mean       std
# model
# ResNet50_US_Subtype  0.029295     0.317627  0.029295
