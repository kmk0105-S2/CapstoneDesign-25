# %%
from torchvision import models
from torchvision.models import vit_b_16

print("=" * 60)

try:
    m1 = models.resnet50(weights=None)
    print("ResNet50 build success")
except Exception as e:
    print("Fail", e)

try:
    m2 = vit_b_16(weights=None)
    print("Vit-B/16 build success")
except Exception as e:
    print("Fail",e)

print("=" * 60)
# Out:
# ============================================================
# ResNet50 build success
# Vit-B/16 build success
# ============================================================

# %%
# 1. Import & Settings
import os
import gc
import random
from pathlib import Path
from collections import OrderedDict

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.metrics import (
    confusion_matrix, classification_report,
    accuracy_score, f1_score, roc_auc_score, recall_score,
    roc_curve, ConfusionMatrixDisplay
)

import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
from torchvision import models
from torchvision.models import vit_b_16, ViT_B_16_Weights, ResNet50_Weights

SEED = 42
random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)
torch.cuda.manual_seed_all(SEED)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Device:", device)

torch.backends.cudnn.benchmark = True
# Out:
# Device: cuda

# %%
print(f"현재 작업 경로: {os.getcwd()}")

test_relative = '/tf/nasw/dataset001/preprocessed/npz/fold_1_train.npz'
print(f"상대경로: {os.path.exists(test_relative)}")
# Out:
# 현재 작업 경로: /tf/notebooks/Image Encoder/Untitled Folder
# 상대경로: False

# %%
#2. Hyperparameters & Paths
DATA_ROOT = Path("/tf/nasw/dataset001/preprocessed/npz_ct_no_3channel")

FOLDS = [1, 2, 3, 4, 5]

OUTPUT_DIR = Path("./ct_binary_models_filter_ablation")
OUTPUT_DIR.mkdir(parents=True, exist_ok=True)

FIGURE_DIR = Path("./ct_binary_figures_filter_ablation")
FIGURE_DIR.mkdir(parents=True, exist_ok=True)

IMG_SIZE = 224
BATCH_SIZE = 8
NUM_WORKERS = 2
NUM_EPOCHS = 30
LR = 1e-4
WEIGHT_DECAY = 1e-4
PATIENCE = 7

print("DATA_ROOT:", DATA_ROOT)
print("OUTPUT_DIR:", OUTPUT_DIR.resolve())
print("FIGURE_DIR:", FIGURE_DIR.resolve())
print("FOLDS:", FOLDS)
# Out:
# DATA_ROOT: /tf/nasw/dataset001/preprocessed/npz_ct_no_3channel
# OUTPUT_DIR: /tf/notebooks/Image Encoder/Untitled Folder/ct_binary_models_filter_ablation
# FIGURE_DIR: /tf/notebooks/Image Encoder/Untitled Folder/ct_binary_figures_filter_ablation
# FOLDS: [1, 2, 3, 4, 5]

# %%
def inspect_fold_npz(fold_idx):
    train_npz_path = DATA_ROOT / f"fold_{fold_idx}_train.npz"
    val_npz_path = DATA_ROOT / f"fold_{fold_idx}_val.npz"

    print("TRAIN:", train_npz_path, train_npz_path.exits())
    print("VAL:", val_npz_path, val_npz_path.exists())

    train_npz = np.load(train_npz_path, allow_pickle=False, mmap_mode="r")
    val_npz = np.load(val_npz_path, allow_pickle=False, mmap_mode="r")

    for k in train_npz.files:
        print(f"[train] {k}: shape={train_npz[k].shape}, dtype={train_npz[k].dtype}")
    for k in val_npz.files:
        print(f"[val] {k}: shape={val_npz[k].shape}, dtype={val_npz[k].dtype}")

# %%
# local pretrained weight paths
LOCAL_RESNET18_IMAGENET_WEIGHTS = Path("/tf/pretrained_model/resnet18-f37072fd.pth")
LOCAL_RESNET50_IMAGENET_WEIGHTS = Path("/tf/pretrained_model/resnet50-11ad3fa6.pth")
LOCAL_RESNET18_RADIMAGENET_WEIGHTS = Path("/tf/pretrained_model/RadImageNet_resnet18.pth")
LOCAL_RESNET50_RADIMAGENET_WEIGHTS = Path("/tf/pretrained_model/RadImageNet_resnet50.pth")
LOCAL_VIT_WEIGHTS = Path("/tf/pretrained_model/vit_b_16-c867db91.pth")

print("LOCAL_RESNET18_IMAGENET_WEIGHTS exists:", LOCAL_RESNET18_IMAGENET_WEIGHTS.exists())
print("LOCAL_RESNET50_IMAGENET_WEIGHTS exists:", LOCAL_RESNET50_IMAGENET_WEIGHTS.exists())
print("LOCAL_RESNET18_RADIMAGENET_WEIGHTS exists:", LOCAL_RESNET18_RADIMAGENET_WEIGHTS.exists())
print("LOCAL_RESNET50_RADIMAGENET_WEIGHTS exists:", LOCAL_RESNET50_RADIMAGENET_WEIGHTS.exists())
print("LOCAL_VIT_WEIGHTS exists:", LOCAL_VIT_WEIGHTS.exists())
# Out:
# LOCAL_RESNET18_IMAGENET_WEIGHTS exists: True
# LOCAL_RESNET50_IMAGENET_WEIGHTS exists: True
# LOCAL_RESNET18_RADIMAGENET_WEIGHTS exists: True
# LOCAL_RESNET50_RADIMAGENET_WEIGHTS exists: True
# LOCAL_VIT_WEIGHTS exists: True

# %%
def load_local_state_dict(weight_path):
    weight_path = Path(weight_path)
    assert weight_path.exists(), f"Weight file not found: {weight_path}"

    ckpt = torch.load(weight_path, map_location="cpu")

    if isinstance(ckpt, dict) and "state_dict" in ckpt and isinstance(ckpt["state_dict"], dict):
        ckpt = ckpt["state_dict"]

    return ckpt

# %%
# 3. Dataset

NORM_STATS = {
    "imagenet": {"mean": [0.485, 0.456, 0.406], "std": [0.229, 0.224, 0.225]},
    "radimagenet": {"mean": [0.204, 0.204, 0.204], "std": [0.286, 0.286, 0.286]}
}

class OvarianCTNPZDataset(Dataset):
    def __init__(self, npz_path, norm_type="imagenet"):
        super().__init__()
        assert norm_type in NORM_STATS, f"norm_type must be one of {list(NORM_STATS.keys())}"
        
        self.npz = np.load(npz_path, allow_pickle=False, mmap_mode="r")

        self.images = self.npz["images"]
        self.labels = self.npz["labels"].astype(np.float32)

        stats = NORM_STATS[norm_type]
        self.mean = torch.tensor(stats["mean"], dtype=torch.float32).view(1, 3, 1, 1)
        self.std = torch.tensor(stats["std"], dtype=torch.float32).view(1, 3, 1, 1)

        self.tumor_types = self.npz["tumor_types"] if "tumor_types" in self.npz.files else None
        self.recurrences = self.npz["recurrences"] if "recurrences" in self.npz.files else None

    def __len__(self):
        return len(self.labels)

    def __getitem__(self, idx):
        x = self.images[idx]
        y = self.labels[idx]

        x = torch.from_numpy(x).float().permute(0, 3, 1, 2).contiguous()

        x = x / 255.0
        x = (x-self.mean) / self.std

        y = torch.tensor([y], dtype=torch.float32)

        return x, y

# %%
# 4. fold별 dataLoader 생성
def make_fold_loaders(fold_idx, norm_type="imagenet"):
    train_npz_path = DATA_ROOT / f"fold_{fold_idx}_train.npz"
    val_npz_path = DATA_ROOT / f"fold_{fold_idx}_val.npz"

    assert train_npz_path.exists(), f"Missing: {train_npz_path}"
    assert val_npz_path.exists(), f"Missing: {val_npz_path}"

    train_dataset = OvarianCTNPZDataset(train_npz_path, norm_type=norm_type)
    val_dataset = OvarianCTNPZDataset(val_npz_path, norm_type=norm_type)

    train_loader = DataLoader(
        train_dataset,
        batch_size = BATCH_SIZE,
        shuffle = True,
        num_workers = NUM_WORKERS,
        pin_memory = True
    )

    val_loader = DataLoader(
        val_dataset,
        batch_size = BATCH_SIZE,
        shuffle = False,
        num_workers = NUM_WORKERS,
        pin_memory = True
    )

    labels_np = train_dataset.labels.astype(int)
    neg = (labels_np == 0).sum()
    pos = (labels_np == 1).sum()

    pos_weight_value = neg / max(pos, 1)
    pos_weight = torch.tensor([pos_weight_value], device = device, dtype = torch.float32)

    print(f"[FOLD {fold_idx}] Train benign(0): {neg}, malignant(1): {pos}, pos_weight={pos_weight.item():.4f}")

    return train_loader, val_loader, pos_weight

# %%
# 5. train/eval 함수

scaler = torch.amp.GradScaler(enabled=(device.type == "cuda"))

def compute_binary_metrics(y_true, y_prob, threshold = 0.5):
    y_true = np.array(y_true).astype(int)
    y_prob = np.array(y_prob).astype(float)
    y_pred = (y_prob > threshold).astype(int)

    metrics = {
        "acc": accuracy_score(y_true, y_pred),
        "auc": roc_auc_score(y_true, y_prob) if len(np.unique(y_true)) > 1 else 0.5,
        "f1": f1_score(y_true, y_pred, zero_division=0),
        "recall": recall_score(y_true, y_pred, zero_division=0),
        "cm": confusion_matrix(y_true, y_pred)
    }
    return metrics

def train_one_epoch(model, loader, criterion, optimizer, device):
    model.train()
    running_loss = 0.0
    y_true, y_prob = [], []

    for imgs, labels in loader:
        imgs = imgs.to(device, non_blocking=True)
        labels = labels.to(device, non_blocking=True)

        optimizer.zero_grad()

        with torch.amp.autocast(device_type="cuda", enabled=(device.type == "cuda")):
            logits = model(imgs)
            loss = criterion(logits, labels)

        scaler.scale(loss).backward()
        scaler.step(optimizer)
        scaler.update()

        running_loss += loss.item() * imgs.size(0)

        probs = torch.sigmoid(logits)
        y_true.extend(labels.detach().cpu().numpy().ravel())
        y_prob.extend(probs.detach().cpu().numpy().ravel())

    metric_vals = compute_binary_metrics(y_true, y_prob, threshold = 0.5)

    metrics = {
        "loss": running_loss / len(loader.dataset),
        "acc": metric_vals["acc"],
        "auc": metric_vals["auc"],
        "f1": metric_vals["f1"],
        "recall": metric_vals["recall"],
        "cm": metric_vals["cm"]
    }
    return metrics

@torch.no_grad()
def eval_one_epoch(model, loader, criterion, device):
    model.eval()
    running_loss = 0.0
    y_true, y_prob = [], []

    for imgs, labels in loader:
        imgs = imgs.to(device, non_blocking = True)
        labels = labels.to(device, non_blocking = True)

        with torch.amp.autocast(device_type="cuda", enabled=(device.type == "cuda")):
            logits = model(imgs)
            loss = criterion(logits, labels)

        running_loss += loss.item() * imgs.size(0)

        probs = torch.sigmoid(logits)
        y_true.extend(labels.detach().cpu().numpy().ravel())
        y_prob.extend(probs.detach().cpu().numpy().ravel())

    metric_vals = compute_binary_metrics(y_true, y_prob, threshold = 0.5)

    metrics = {
        "loss": running_loss / len(loader.dataset),
        "auc": metric_vals["auc"],
        "acc": metric_vals["acc"],
        "f1": metric_vals["f1"],
        "recall": metric_vals["recall"],
        "cm": metric_vals["cm"]
    }
    return metrics

@torch.no_grad()
def eval_confusion(model, loader, device, threshold = 0.5):
    model.eval()
    y_true, y_prob = [], []

    for imgs, labels in loader:
        imgs = imgs.to(device, non_blocking = True)
        labels = labels.to(device, non_blocking = True)

        logits = model(imgs)
        probs = torch.sigmoid(logits)

        y_true.extend(labels.cpu().numpy().ravel())
        y_prob.extend(probs.cpu().numpy().ravel())

    metric_vals = compute_binary_metrics(y_true, y_prob, threshold = 0.5)

    print(f"\n--Final Evaluation (threshold={threshold}) --")
    print(f"Accuracy: {metric_vals['acc']:.4f}")
    print(f"ROC-AUC : {metric_vals['auc']:.4f}")
    print(f"F1-score : {metric_vals['f1']:.4f}")
    print(f"Sensitivity : {metric_vals['recall']:.4f}")
    print("Confusion Matrix:")
    print(metric_vals["cm"])

    print("\nClassification report:")
    y_pred = (np.array(y_prob) > threshold).astype(int)
    print(classification_report(np.array(y_true).astype(int), y_pred, digits = 4, zero_division = 0))

    metric_vals["y_true"] = np.array(y_true).astype(int)
    metric_vals["y_prob"] = np.array(y_prob).astype(float)

    return metric_vals

# %%
# 6. slice encoder + patient-level pooling wrapper

class PatientSliceAttentionClassifier(nn.Module):
    def __init__(self, encoder, feat_dim, hidden_dim=512, dropout=0.3):
        super().__init__()
        self.encoder = encoder

        self.attn = nn.Sequential(
            nn.Linear(feat_dim, feat_dim // 2),
            nn.Tanh(),
            nn.Linear(feat_dim // 2, 1)
        )

        self.classifier = nn.Sequential(
            nn.Linear(feat_dim, hidden_dim),
            nn.ReLU(),
            nn.Dropout(dropout),
            nn.Linear(hidden_dim, 1)
        )

    def forward(self, x):
        # x: (B, S, C, H, W)
        B, S, C, H, W = x.shape
        x = x.view(B * S, C, H, W)

        feat = self.encoder(x)
        feat = feat.view(B, S, -1)

        attn_score = self.attn(feat)
        attn_weight = torch.softmax(attn_score, dim=1)

        pooled = (feat * attn_weight).sum(dim=1)
        logits = self.classifier(pooled)

        return logits

# %%
# 7. model define
def build_resnet18_patient_model(load_pretrained=True, freeze_backbone=True, 
                                 unfreeze_layer4=True, 
                                 weight_path=LOCAL_RESNET18_IMAGENET_WEIGHTS):
    encoder = models.resnet18(weights=None)

    if load_pretrained:
        state_dict = load_local_state_dict(weight_path)
        encoder.load_state_dict(state_dict, strict = True)
        
    feat_dim = encoder.fc.in_features
    encoder.fc = nn.Identity()

    if freeze_backbone:
        for p in encoder.parameters():
            p.requires_grad = False

        if unfreeze_layer4:
            for p in encoder.layer4.parameters():
                p.requires_grad = True
    
    model = PatientSliceAttentionClassifier(
        encoder = encoder,
        feat_dim = feat_dim,
        hidden_dim = 256,
        dropout=0.1
    )
    
    return model
    
def build_resnet50_patient_model(load_pretrained=True, freeze_backbone=True, 
                                 unfreeze_layer4=True, 
                                 weight_path=LOCAL_RESNET50_IMAGENET_WEIGHTS):
    encoder = models.resnet50(weights=None)

    if load_pretrained:
        state_dict = load_local_state_dict(weight_path)
        encoder.load_state_dict(state_dict, strict = True)
        
    feat_dim = encoder.fc.in_features
    encoder.fc = nn.Identity()

    if freeze_backbone:
        for p in encoder.parameters():
            p.requires_grad = False

        if unfreeze_layer4:
            for p in encoder.layer4.parameters():
                p.requires_grad = True
    
    model = PatientSliceAttentionClassifier(
        encoder = encoder,
        feat_dim = feat_dim,
        hidden_dim = 512,
        dropout=0.1
    )
    
    return model

def _load_radimagenet_weights(resnet_model, weight_path):
    ckpt = torch.load(path, map_location="cpu", weights_only=False)

    if isinstance(ckpt, dict):
        if "model" in ckpt:
            state = ckpt["model"]
        elif "state_dict" in ckpt:
            state = ckpt["state_dict"]
        else:
            state = ckpt

    else:
        raise ValueError(f"Unexpected checkpoint type: {type(ckpt)}")

    # _orig_mod. prefix 제거
    state = {k.replace("_orig_mod.", ""): v 
             for k, v in state.items()
            }

    # fc layer 제외
    state = {k: v for k, v in state.items() if not k.startswith("fc.")}

    missing, unexpected = model.load_state_dict(state, strict=False)
    print(f"  [RadImageNet] loaded {path.name}")
    if missing:
        print(f"   missing keys ({len(missing)}): {missing[:3]}{'...' if len(missing) > 3 else ''}")
    if unexpected:
        print(f"   unexpected keys ({len(unexpected)}): {unexpected[:3]}{'...' if len(unexpected) > 3 else ''}")

    return model

def build_resnet18_radimagenet_patient_model(load_pretrained=True, freeze_backbone=True, 
                                             unfreeze_layer4=True, 
                                             weight_path=LOCAL_RESNET18_RADIMAGENET_WEIGHTS):
    encoder = models.resnet18(weights=None)

    if load_pretrained:
        state_dict = load_local_state_dict(weight_path)
        encoder.load_state_dict(state_dict, strict = True)
        
    feat_dim = encoder.fc.in_features
    encoder.fc = nn.Identity()

    if freeze_backbone:
        for p in encoder.parameters():
            p.requires_grad = False

        if unfreeze_layer4:
            for p in encoder.layer4.parameters():
                p.requires_grad = True
    
    model = PatientSliceAttentionClassifier(
        encoder = encoder,
        feat_dim = feat_dim,
        hidden_dim = 256,
        dropout=0.1
    )
    
    return model

def build_resnet50_radimagenet_patient_model(load_pretrained=True, freeze_backbone=True, 
                                             unfreeze_layer4=True, 
                                             weight_path=LOCAL_RESNET50_RADIMAGENET_WEIGHTS):
    encoder = models.resnet50(weights=None)

    if load_pretrained:
        state_dict = load_local_state_dict(weight_path)
        encoder.load_state_dict(state_dict, strict = True)
        
    feat_dim = encoder.fc.in_features
    encoder.fc = nn.Identity()

    if freeze_backbone:
        for p in encoder.parameters():
            p.requires_grad = False

        if unfreeze_layer4:
            for p in encoder.layer4.parameters():
                p.requires_grad = True
    
    model = PatientSliceAttentionClassifier(
        encoder = encoder,
        feat_dim = feat_dim,
        hidden_dim = 512,
        dropout=0.1
    )
    
    return model

    
def build_vit_patient_model(load_pretrained=True, weight_path=LOCAL_VIT_WEIGHTS,
                            freeze_backbone=True, unfreeze_last_n_blocks=2):
    encoder = vit_b_16(weights=None)
    if load_pretrained:
        state_dict = load_local_state_dict(weight_path)
        encoder.load_state_dict(state_dict, strict = True)
    
    feat_dim = encoder.heads.head.in_features
    encoder.heads = nn.Identity()

    if freeze_backbone:
        for p in encoder.parameters():
            p.requires_grad = False
        for block in encoder.encoder.layers[-unfreeze_last_n_blocks:]:
            for p in block.parameters():
                p.requires_grad = True
        for p in encoder.encoder.ln.parameters():
            p.requires_grad = True

    
    model = PatientSliceAttentionClassifier(
        encoder = encoder,
        feat_dim = feat_dim,
        hidden_dim = 512,
        dropout=0.3
    )
    return model

class CNNTransformerHybridPatient(nn.Module):
    def __init__(self,backbone_builder, d_model=512, nhead=8, num_layers=2, 
                 dim_feedforward=1024, dropout=0.3, 
                 load_pretrained=True, freeze_backbone=True, unfreeze_layer4=True, 
                 resnet_weight_path=LOCAL_RESNET50_IMAGENET_WEIGHTS):
        super().__init__()

        if backbone_builder == "resnet18_imagenet":
            backbone = models.resnet18(weights=None)
            if load_pretrained:
                state_dict = load_local_state_dict(resnet_weight_path)
                backbone.load_state_dict(state_dict, strict = True)
            feat_dim = backbone.fc.in_features
        
        elif backbone_builder == "resnet50_imagenet":
            backbone = models.resnet50(weights=None)
            if load_pretrained:
                state_dict = load_local_state_dict(resnet_weight_path)
                backbone.load_state_dict(state_dict, strict = True)
            feat_dim = backbone.fc.in_features

        elif backbone_builder == "resnet18_radimagenet":
            backbone = models.resnet18(weights=None)
            if load_pretrained:
                backbone = load_radimagent_resnet(backbone, resnet_weight_path)
            feat_dim = backbone.fc.in_features
            
        elif backbone_builder == "resnet50_radimagenet":
            backbone = models.resnet50(weights=None)
            if load_pretrained:
                backbone = load_radimagent_resnet(backbone, resnet_weight_path)
            feat_dim = backbone.fc.in_features

        else:
            raise ValueError(f"Unknown backbone_builder: {backbone_builder}")

        backbone.fc = nn.Identity()
        self.encoder = backbone
        
        if freeze_backbone:
            for p in self.encoder.parameters():
                p.requires_grad = False

            if unfreeze_layer4:
                for p in self.encoder.layer4.parameters():
                    p.requires_grad = True

        self.proj = nn.Linear(feat_dim, d_model)
        self.cls_token = nn.Parameter(torch.zeros(1, 1, d_model))
        self.pos_embed = nn.Parameter(torch.zeros(1, 1+8, d_model))

        encoder_layer = nn.TransformerEncoderLayer(
            d_model=d_model,
            nhead=nhead,
            dim_feedforward=dim_feedforward,
            dropout=0.1,
            batch_first=True,
            activation="gelu"
        )

        self.transformer = nn.TransformerEncoder(encoder_layer, num_layers= num_layers)
        self.norm = nn.LayerNorm(d_model)

        self.classifier = nn.Sequential(
            nn.Linear(d_model, 512),
            nn.ReLU(),
            nn.Dropout(dropout),
            nn.Linear(512, 1)
        )

    def forward(self, x):
        B, S, C, H, W = x.shape
        x = x.view(B * S, C, H, W)

        feat = self.encoder(x)
        feat = feat.view(B, S, -1)
        feat = self.proj(feat)

        cls = self.cls_token.expand(B, -1, -1)
        tokens = torch.cat([cls, feat], dim=1)
        tokens = tokens + self.pos_embed[:, :tokens.size(1), :]

        tokens = self.transformer(tokens)
        tokens = self.norm(tokens)

        cls_out = tokens[:, 0, :]
        logits = self.classifier(cls_out)

        return logits

        

def build_hybrid_patient_model(load_pretrained=True):
    return CNNTransformerHybridPatient(
        backbone_builder="resnet50_imagenet",
        load_pretrained=load_pretrained,
        freeze_backbone = True,
        unfreeze_layer4 = True,
        resnet_weight_path=LOCAL_RESNET50_IMAGENET_WEIGHTS
    )

def build_hybrid_r18_patient_model(load_pretrained=True):
    return CNNTransformerHybridPatient(
        backbone_builder="resnet18_imagenet",
        load_pretrained=load_pretrained,
        freeze_backbone = True,
        unfreeze_layer4 = True,
        resnet_weight_path=LOCAL_RESNET18_IMAGENET_WEIGHTS
    )

# %%
# 8. 공통 학습 함수
def fit_model(model, model_name, fold_idx, train_loader, val_loader, device, 
              num_epochs=30, lr = 1e-4, weight_decay=1e-4, 
              pos_weight=None, patience = 7, min_delta=0.001):
    model = model.to(device)
    criterion = nn.BCEWithLogitsLoss(pos_weight = pos_weight)
    optimizer = torch.optim.Adam(
        filter(lambda p: p.requires_grad, model.parameters()),
        lr = lr,
        weight_decay = weight_decay
    )

    best_auc = -1
    best_val_loss = np.inf
    best_path = OUTPUT_DIR / f"{model_name}_fold{fold_idx}_best.pth"
    history = []
    early_stop_counter = 0

    for epoch in range(1, num_epochs+1):
        train_metrics = train_one_epoch(model, train_loader, criterion, optimizer, device)
        val_metrics = eval_one_epoch(model, val_loader, criterion, device)

        row = {
            "fold": fold_idx,
            "epoch": epoch,
            "train_loss": train_metrics["loss"],
            "train_acc": train_metrics["acc"],
            "train_f1": train_metrics["f1"],
            "train_recall": train_metrics["recall"],
            "train_auc": train_metrics["auc"],
            "val_loss":val_metrics["loss"],
            "val_acc": val_metrics["acc"],
            "val_f1": val_metrics["f1"],
            "val_auc": val_metrics["auc"],
            "val_recall": val_metrics["recall"],
        }
        history.append(row)

        print(
            f"[{model_name}][Fold {fold_idx}][Epoch {epoch:02d}]"
            f"train loss = {row['train_loss']:.4f}, acc={row['train_acc']:.4f}, auc={row['train_auc']:.4f},"
            f"f1 = {row['train_f1']:.4f}, recall={row['train_recall']:.4f} | "
            f"val loss = {row['val_loss']:.4f}, acc = {row['val_acc']:.4f}, auc = {row['val_auc']:.4f}, "
            f"f1 = {row['val_f1']:.4f}, recall={row['val_recall']:.4f}"
        )

        if row["val_auc"] > best_auc:
            best_auc = row["val_auc"]

        if row["val_loss"] < best_val_loss - min_delta:
            best_val_loss = row["val_loss"]
            early_stop_counter = 0
            torch.save(model.state_dict(), best_path)
            print(f"  -> best saved by val_loss: {best_path}")
        else:
            early_stop_counter += 1
            print(f"  -> no improvement ({early_stop_counter}/{patience})")

        if early_stop_counter >= patience:
            print(f"  -> early stopping triggered at epoch {epoch}")
            break

    history_df = pd.DataFrame(history)
    return model, history_df, best_path

# %%
# 9. model 로드 함수
def load_model(model_type, model_path, device):
    if model_type == "resnet18_imagenet":
        model = build_resnet18_patient_model(load_pretrained=False)
    elif model_type == "resnet50_imagenet":
        model = build_resnet50_patient_model(load_pretrained=False)
    elif model_type == "resnet18_radimagenet":
        model = build_resnet18_radimagenet_patient_model(load_pretrained=False)
    elif model_type == "resnet50_radimagenet":
        model = build_resnet50_radimagenet_patient_model(load_pretrained=False)
    elif model_type == "vit":
        model = build_vit_patient_model(load_pretrained=False)
    elif model_type == "hybrid_r50":
        model = build_hybrid_patient_model(load_pretrained=False)
    elif model_type == "hybrid_r18":
        model = build_hybrid_r18_patient_model(load_pretrained=False)
    else:
        raise ValueError(f"Unknown model type: {model_type}")

    model.load_state_dict(torch.load(model_path, map_location=device))
    model.to(device)
    model.eval()
    return model

# %%
# 10. 5-Fold CV
def run_cv_for_model(model_name, model_type, build_fn, norm_type="imagenet", lr=None):
    fold_results = []
    fold_histories = []
    effective_lr = lr if lr is not None else LR

    for fold_idx in FOLDS:
        print("\n" + "=" * 80)
        print(f"Running {model_name} | Fold {fold_idx} | norm={norm_type}")
        print("=" * 80)

        train_loader, val_loader, pos_weight = make_fold_loaders(fold_idx, norm_type=norm_type)

        model = build_fn()

        _, history_df, best_path = fit_model(
            model=model,
            model_name=model_name,
            fold_idx = fold_idx,
            train_loader=train_loader,
            val_loader=val_loader,
            device=device,
            num_epochs=NUM_EPOCHS,
            lr=effective_lr,
            weight_decay=WEIGHT_DECAY,
            pos_weight=pos_weight,
            patience=PATIENCE
            
        )

        best_model = load_model(model_type, best_path, device)
        final_metrics = eval_confusion(best_model, val_loader, device, threshold=0.5)

        print(f"\n[{model_name}][Fold {fold_idx}] Final Metrics")
        print(f"Accuracy: {final_metrics['acc']:.4f}")
        print(f"ROC-AUC: {final_metrics['auc']:.4f}")
        print(f"F1-score : {final_metrics['f1']:.4f}")
        print(f"Sensitivity : {final_metrics['recall']:.4f}")
        print("Confusion Matrix:")
        print(final_metrics["cm"])

        fold_results.append({
            "model": model_name,
            "fold": fold_idx,
            "acc": final_metrics["acc"],
            "ROC-AUC": final_metrics["auc"],
            "F1-score": final_metrics["f1"],
            "Sensitivity": final_metrics["recall"],
            "Confusion Matrix": final_metrics["cm"]
        })

        history_df["model"] = model_name
        fold_histories.append(history_df)

        del model
        del best_model
        del train_loader
        del val_loader
        gc.collect()
        if torch.cuda.is_available():
            torch.cuda.empty_cache()
            
    result_df = pd.DataFrame(fold_results)
    history_df_all = pd.concat(fold_histories, ignore_index=True)
    return result_df, history_df_all

# %%
print(">>> Training ResNet18 (ImageNet)...")
resnet18_imagenet_cv_df, resnet18_imagenet_history_df = run_cv_for_model(
    model_name="ResNet18_ImageNet",
    model_type="resnet18_imagenet",
    build_fn=lambda: build_resnet18_patient_model(load_pretrained=True),
    norm_type="imagenet"
)
display(resnet18_imagenet_cv_df)
# Out:
# >>> Training ResNet18 (ImageNet)...
#
# ================================================================================
# Running ResNet18_ImageNet | Fold 1 | norm=imagenet
# ================================================================================
# [FOLD 1] Train benign(0): 1605, malignant(1): 444, pos_weight=3.6149
# [ResNet18_ImageNet][Fold 1][Epoch 01]train loss = 0.6105, acc=0.8297, auc=0.9062,f1 = 0.6819, recall=0.8423 | val loss = 0.3536, acc = 0.8830, auc = 0.9756, f1 = 0.7794, recall=0.9550
#   -> best saved by val_loss: ct_binary_models_filter_ablation/ResNet18_ImageNet_fold1_best.pth
# [ResNet18_ImageNet][Fold 1][Epoch 02]train loss = 0.3815, acc=0.9000, auc=0.9628,f1 = 0.7996, recall=0.9212 | val loss = 0.3305, acc = 0.9318, auc = 0.9723, f1 = 0.8560, recall=0.9369
#   -> best saved by val_loss: ct_binary_models_filter_ablation/ResNet18_ImageNet_fold1_best.pth
# [ResNet18_ImageNet][Fold 1][Epoch 03]train loss = 0.2842, acc=0.9195, auc=0.9789,f1 = 0.8355, recall=0.9437 | val loss = 0.3136, acc = 0.9084, auc = 0.9772, f1 = 0.8157, recall=0.9369
#   -> best saved by val_loss: ct_binary_models_filter_ablation/ResNet18_ImageNet_fold1_best.pth
# [ResNet18_ImageNet][Fold 1][Epoch 04]train loss = 0.2036, acc=0.9439, auc=0.9899,f1 = 0.8806, recall=0.9550 | val loss = 0.3189, acc = 0.9337, auc = 0.9804, f1 = 0.8559, recall=0.9099
#   -> no improvement (1/7)
# [ResNet18_ImageNet][Fold 1][Epoch 05]train loss = 0.1414, acc=0.9605, auc=0.9948,f1 = 0.9145, recall=0.9752 | val loss = 0.4052, acc = 0.8967, auc = 0.9731, f1 = 0.7969, recall=0.9369
#   -> no improvement (2/7)
# [ResNet18_ImageNet][Fold 1][Epoch 06]train loss = 0.1546, acc=0.9614, auc=0.9933,f1 = 0.9157, recall=0.9662 | val loss = 0.8553, acc = 0.9201, auc = 0.9707, f1 = 0.7831, recall=0.6667
#   -> no improvement (3/7)
# [ResNet18_ImageNet][Fold 1][Epoch 07]train loss = 0.1065, acc=0.9722, auc=0.9971,f1 = 0.9385, recall=0.9797 | val loss = 0.5842, acc = 0.9220, auc = 0.9553, f1 = 0.8198, recall=0.8198
#   -> no improvement (4/7)
# [ResNet18_ImageNet][Fold 1][Epoch 08]train loss = 0.0712, acc=0.9824, auc=0.9986,f1 = 0.9607, recall=0.9910 | val loss = 0.5230, acc = 0.9123, auc = 0.9628, f1 = 0.8178, recall=0.9099
#   -> no improvement (5/7)
# [ResNet18_ImageNet][Fold 1][Epoch 09]train loss = 0.0576, acc=0.9854, auc=0.9992,f1 = 0.9668, recall=0.9842 | val loss = 0.3593, acc = 0.9298, auc = 0.9824, f1 = 0.8500, recall=0.9189
#   -> no improvement (6/7)
# [ResNet18_ImageNet][Fold 1][Epoch 10]train loss = 0.0453, acc=0.9888, auc=0.9993,f1 = 0.9745, recall=0.9910 | val loss = 0.7298, acc = 0.9006, auc = 0.9597, f1 = 0.7692, recall=0.7658
#   -> no improvement (7/7)
#   -> early stopping triggered at epoch 10
#
# --Final Evaluation (threshold=0.5) --
# Accuracy: 0.9064
# ROC-AUC : 0.9772
# F1-score : 0.8110
# Sensitivity : 0.9279
# Confusion Matrix:
# [[362  40]
#  [  8 103]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0     0.9784    0.9005    0.9378       402
#            1     0.7203    0.9279    0.8110       111
#
#     accuracy                         0.9064       513
#    macro avg     0.8493    0.9142    0.8744       513
# weighted avg     0.9225    0.9064    0.9104       513
#
#
# [ResNet18_ImageNet][Fold 1] Final Metrics
# Accuracy: 0.9064
# ROC-AUC: 0.9772
# F1-score : 0.8110
# Sensitivity : 0.9279
# Confusion Matrix:
# [[362  40]
#  [  8 103]]
#
# ================================================================================
# Running ResNet18_ImageNet | Fold 2 | norm=imagenet
# ================================================================================
# [FOLD 2] Train benign(0): 1605, malignant(1): 444, pos_weight=3.6149
# [ResNet18_ImageNet][Fold 2][Epoch 01]train loss = 0.5708, acc=0.8419, auc=0.9191,f1 = 0.7028, recall=0.8626 | val loss = 0.4772, acc = 0.8596, auc = 0.9515, f1 = 0.7372, recall=0.9099
#   -> best saved by val_loss: ct_binary_models_filter_ablation/ResNet18_ImageNet_fold2_best.pth
# [ResNet18_ImageNet][Fold 2][Epoch 02]train loss = 0.3833, acc=0.8985, auc=0.9624,f1 = 0.7977, recall=0.9234 | val loss = 0.5668, acc = 0.8869, auc = 0.9394, f1 = 0.7623, recall=0.8378
#   -> no improvement (1/7)
# [ResNet18_ImageNet][Fold 2][Epoch 03]train loss = 0.2369, acc=0.9390, auc=0.9850,f1 = 0.8718, recall=0.9572 | val loss = 0.5887, acc = 0.8850, auc = 0.9389, f1 = 0.7631, recall=0.8559
#   -> no improvement (2/7)
# [ResNet18_ImageNet][Fold 2][Epoch 04]train loss = 0.1698, acc=0.9551, auc=0.9924,f1 = 0.9040, recall=0.9752 | val loss = 0.5994, acc = 0.8635, auc = 0.9524, f1 = 0.7426, recall=0.9099
#   -> no improvement (3/7)
# [ResNet18_ImageNet][Fold 2][Epoch 05]train loss = 0.1415, acc=0.9610, auc=0.9948,f1 = 0.9156, recall=0.9775 | val loss = 0.5876, acc = 0.8908, auc = 0.9516, f1 = 0.7686, recall=0.8378
#   -> no improvement (4/7)
# [ResNet18_ImageNet][Fold 2][Epoch 06]train loss = 0.0777, acc=0.9805, auc=0.9984,f1 = 0.9562, recall=0.9842 | val loss = 0.5856, acc = 0.8733, auc = 0.9521, f1 = 0.7566, recall=0.9099
#   -> no improvement (5/7)
# [ResNet18_ImageNet][Fold 2][Epoch 07]train loss = 0.1514, acc=0.9746, auc=0.9944,f1 = 0.9426, recall=0.9617 | val loss = 0.6349, acc = 0.9006, auc = 0.9516, f1 = 0.7918, recall=0.8739
#   -> no improvement (6/7)
# [ResNet18_ImageNet][Fold 2][Epoch 08]train loss = 0.0750, acc=0.9790, auc=0.9983,f1 = 0.9534, recall=0.9910 | val loss = 0.6209, acc = 0.9142, auc = 0.9620, f1 = 0.8120, recall=0.8559
#   -> no improvement (7/7)
#   -> early stopping triggered at epoch 8
#
# --Final Evaluation (threshold=0.5) --
# Accuracy: 0.8596
# ROC-AUC : 0.9515
# F1-score : 0.7372
# Sensitivity : 0.9099
# Confusion Matrix:
# [[340  62]
#  [ 10 101]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0     0.9714    0.8458    0.9043       402
#            1     0.6196    0.9099    0.7372       111
#
#     accuracy                         0.8596       513
#    macro avg     0.7955    0.8778    0.8207       513
# weighted avg     0.8953    0.8596    0.8681       513
#
#
# [ResNet18_ImageNet][Fold 2] Final Metrics
# Accuracy: 0.8596
# ROC-AUC: 0.9515
# F1-score : 0.7372
# Sensitivity : 0.9099
# Confusion Matrix:
# [[340  62]
#  [ 10 101]]
#
# ================================================================================
# Running ResNet18_ImageNet | Fold 3 | norm=imagenet
# ================================================================================
# [FOLD 3] Train benign(0): 1606, malignant(1): 444, pos_weight=3.6171
# [ResNet18_ImageNet][Fold 3][Epoch 01]train loss = 0.5993, acc=0.8444, auc=0.9093,f1 = 0.7005, recall=0.8401 | val loss = 0.4022, acc = 0.8906, auc = 0.9634, f1 = 0.7705, recall=0.8468
#   -> best saved by val_loss: ct_binary_models_filter_ablation/ResNet18_ImageNet_fold3_best.pth
# [ResNet18_ImageNet][Fold 3][Epoch 02]train loss = 0.3904, acc=0.8990, auc=0.9618,f1 = 0.7948, recall=0.9032 | val loss = 0.3775, acc = 0.9121, auc = 0.9676, f1 = 0.8101, recall=0.8649
#   -> best saved by val_loss: ct_binary_models_filter_ablation/ResNet18_ImageNet_fold3_best.pth
# [ResNet18_ImageNet][Fold 3][Epoch 03]train loss = 0.2874, acc=0.9180, auc=0.9788,f1 = 0.8323, recall=0.9392 | val loss = 0.5114, acc = 0.9121, auc = 0.9631, f1 = 0.7945, recall=0.7838
#   -> no improvement (1/7)
# [ResNet18_ImageNet][Fold 3][Epoch 04]train loss = 0.2256, acc=0.9395, auc=0.9868,f1 = 0.8716, recall=0.9482 | val loss = 0.3973, acc = 0.9199, auc = 0.9703, f1 = 0.8255, recall=0.8739
#   -> no improvement (2/7)
# [ResNet18_ImageNet][Fold 3][Epoch 05]train loss = 0.1666, acc=0.9541, auc=0.9937,f1 = 0.9008, recall=0.9617 | val loss = 0.4985, acc = 0.9043, auc = 0.9565, f1 = 0.7915, recall=0.8378
#   -> no improvement (3/7)
# [ResNet18_ImageNet][Fold 3][Epoch 06]train loss = 0.1382, acc=0.9668, auc=0.9948,f1 = 0.9277, recall=0.9820 | val loss = 0.4747, acc = 0.9238, auc = 0.9653, f1 = 0.8354, recall=0.8919
#   -> no improvement (4/7)
# [ResNet18_ImageNet][Fold 3][Epoch 07]train loss = 0.0975, acc=0.9771, auc=0.9969,f1 = 0.9490, recall=0.9842 | val loss = 0.5935, acc = 0.9141, auc = 0.9617, f1 = 0.8053, recall=0.8198
#   -> no improvement (5/7)
# [ResNet18_ImageNet][Fold 3][Epoch 08]train loss = 0.0758, acc=0.9815, auc=0.9983,f1 = 0.9586, recall=0.9910 | val loss = 0.6609, acc = 0.9199, auc = 0.9685, f1 = 0.8161, recall=0.8198
#   -> no improvement (6/7)
# [ResNet18_ImageNet][Fold 3][Epoch 09]train loss = 0.0485, acc=0.9898, auc=0.9992,f1 = 0.9767, recall=0.9932 | val loss = 0.7672, acc = 0.9121, auc = 0.9614, f1 = 0.8018, recall=0.8198
#   -> no improvement (7/7)
#   -> early stopping triggered at epoch 9
#
# --Final Evaluation (threshold=0.5) --
# Accuracy: 0.9121
# ROC-AUC : 0.9674
# F1-score : 0.8101
# Sensitivity : 0.8649
# Confusion Matrix:
# [[371  30]
#  [ 15  96]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0     0.9611    0.9252    0.9428       401
#            1     0.7619    0.8649    0.8101       111
#
#     accuracy                         0.9121       512
#    macro avg     0.8615    0.8950    0.8765       512
# weighted avg     0.9179    0.9121    0.9141       512
#
#
# [ResNet18_ImageNet][Fold 3] Final Metrics
# Accuracy: 0.9121
# ROC-AUC: 0.9674
# F1-score : 0.8101
# Sensitivity : 0.8649
# Confusion Matrix:
# [[371  30]
#  [ 15  96]]
#
# ================================================================================
# Running ResNet18_ImageNet | Fold 4 | norm=imagenet
# ================================================================================
# [FOLD 4] Train benign(0): 1606, malignant(1): 444, pos_weight=3.6171
# [ResNet18_ImageNet][Fold 4][Epoch 01]train loss = 0.5774, acc=0.8351, auc=0.9179,f1 = 0.6938, recall=0.8626 | val loss = 0.4650, acc = 0.8613, auc = 0.9471, f1 = 0.7399, recall=0.9099
#   -> best saved by val_loss: ct_binary_models_filter_ablation/ResNet18_ImageNet_fold4_best.pth
# [ResNet18_ImageNet][Fold 4][Epoch 02]train loss = 0.3720, acc=0.8951, auc=0.9649,f1 = 0.7931, recall=0.9279 | val loss = 0.4098, acc = 0.8770, auc = 0.9586, f1 = 0.7568, recall=0.8829
#   -> best saved by val_loss: ct_binary_models_filter_ablation/ResNet18_ImageNet_fold4_best.pth
# [ResNet18_ImageNet][Fold 4][Epoch 03]train loss = 0.2610, acc=0.9332, auc=0.9827,f1 = 0.8592, recall=0.9414 | val loss = 0.5129, acc = 0.9141, auc = 0.9630, f1 = 0.7925, recall=0.7568
#   -> no improvement (1/7)
# [ResNet18_ImageNet][Fold 4][Epoch 04]train loss = 0.1830, acc=0.9527, auc=0.9911,f1 = 0.8976, recall=0.9572 | val loss = 0.5574, acc = 0.8320, auc = 0.9497, f1 = 0.7034, recall=0.9189
#   -> no improvement (2/7)
# [ResNet18_ImageNet][Fold 4][Epoch 05]train loss = 0.1520, acc=0.9610, auc=0.9942,f1 = 0.9149, recall=0.9685 | val loss = 0.5416, acc = 0.8867, auc = 0.9565, f1 = 0.7680, recall=0.8649
#   -> no improvement (3/7)
# [ResNet18_ImageNet][Fold 4][Epoch 06]train loss = 0.1082, acc=0.9761, auc=0.9966,f1 = 0.9466, recall=0.9775 | val loss = 0.5517, acc = 0.8926, auc = 0.9565, f1 = 0.7718, recall=0.8378
#   -> no improvement (4/7)
# [ResNet18_ImageNet][Fold 4][Epoch 07]train loss = 0.1072, acc=0.9732, auc=0.9972,f1 = 0.9405, recall=0.9797 | val loss = 0.5802, acc = 0.9121, auc = 0.9599, f1 = 0.7982, recall=0.8018
#   -> no improvement (5/7)
# [ResNet18_ImageNet][Fold 4][Epoch 08]train loss = 0.0770, acc=0.9805, auc=0.9985,f1 = 0.9561, recall=0.9820 | val loss = 0.6534, acc = 0.8965, auc = 0.9605, f1 = 0.7665, recall=0.7838
#   -> no improvement (6/7)
# [ResNet18_ImageNet][Fold 4][Epoch 09]train loss = 0.1274, acc=0.9771, auc=0.9940,f1 = 0.9486, recall=0.9775 | val loss = 1.0745, acc = 0.9062, auc = 0.9589, f1 = 0.7600, recall=0.6847
#   -> no improvement (7/7)
#   -> early stopping triggered at epoch 9
#
# --Final Evaluation (threshold=0.5) --
# Accuracy: 0.8770
# ROC-AUC : 0.9587
# F1-score : 0.7549
# Sensitivity : 0.8739
# Confusion Matrix:
# [[352  49]
#  [ 14  97]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0     0.9617    0.8778    0.9179       401
#            1     0.6644    0.8739    0.7549       111
#
#     accuracy                         0.8770       512
#    macro avg     0.8131    0.8758    0.8364       512
# weighted avg     0.8973    0.8770    0.8825       512
#
#
# [ResNet18_ImageNet][Fold 4] Final Metrics
# Accuracy: 0.8770
# ROC-AUC: 0.9587
# F1-score : 0.7549
# Sensitivity : 0.8739
# Confusion Matrix:
# [[352  49]
#  [ 14  97]]
#
# ================================================================================
# Running ResNet18_ImageNet | Fold 5 | norm=imagenet
# ================================================================================
# [FOLD 5] Train benign(0): 1606, malignant(1): 444, pos_weight=3.6171
# [ResNet18_ImageNet][Fold 5][Epoch 01]train loss = 0.5807, acc=0.8312, auc=0.9155,f1 = 0.6905, recall=0.8694 | val loss = 0.4224, acc = 0.8926, auc = 0.9569, f1 = 0.7860, recall=0.9099
#   -> best saved by val_loss: ct_binary_models_filter_ablation/ResNet18_ImageNet_fold5_best.pth
# [ResNet18_ImageNet][Fold 5][Epoch 02]train loss = 0.3699, acc=0.9010, auc=0.9649,f1 = 0.8008, recall=0.9189 | val loss = 0.5613, acc = 0.8926, auc = 0.9378, f1 = 0.7718, recall=0.8378
#   -> no improvement (1/7)
# [ResNet18_ImageNet][Fold 5][Epoch 03]train loss = 0.2580, acc=0.9263, auc=0.9828,f1 = 0.8479, recall=0.9482 | val loss = 0.4865, acc = 0.9062, auc = 0.9601, f1 = 0.7983, recall=0.8559
#   -> no improvement (2/7)
# [ResNet18_ImageNet][Fold 5][Epoch 04]train loss = 0.1828, acc=0.9561, auc=0.9909,f1 = 0.9047, recall=0.9617 | val loss = 0.5185, acc = 0.9121, auc = 0.9584, f1 = 0.8178, recall=0.9099
#   -> no improvement (3/7)
# [ResNet18_ImageNet][Fold 5][Epoch 05]train loss = 0.1556, acc=0.9620, auc=0.9926,f1 = 0.9172, recall=0.9730 | val loss = 0.5888, acc = 0.9004, auc = 0.9508, f1 = 0.7901, recall=0.8649
#   -> no improvement (4/7)
# [ResNet18_ImageNet][Fold 5][Epoch 06]train loss = 0.1336, acc=0.9683, auc=0.9951,f1 = 0.9303, recall=0.9775 | val loss = 0.5009, acc = 0.9004, auc = 0.9545, f1 = 0.7773, recall=0.8018
#   -> no improvement (5/7)
# [ResNet18_ImageNet][Fold 5][Epoch 07]train loss = 0.1211, acc=0.9654, auc=0.9962,f1 = 0.9242, recall=0.9752 | val loss = 0.7224, acc = 0.9062, auc = 0.9503, f1 = 0.7818, recall=0.7748
#   -> no improvement (6/7)
# [ResNet18_ImageNet][Fold 5][Epoch 08]train loss = 0.0567, acc=0.9854, auc=0.9993,f1 = 0.9670, recall=0.9887 | val loss = 0.6764, acc = 0.9004, auc = 0.9536, f1 = 0.7848, recall=0.8378
#   -> no improvement (7/7)
#   -> early stopping triggered at epoch 8
#
# --Final Evaluation (threshold=0.5) --
# Accuracy: 0.8945
# ROC-AUC : 0.9569
# F1-score : 0.7891
# Sensitivity : 0.9099
# Confusion Matrix:
# [[357  44]
#  [ 10 101]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0     0.9728    0.8903    0.9297       401
#            1     0.6966    0.9099    0.7891       111
#
#     accuracy                         0.8945       512
#    macro avg     0.8347    0.9001    0.8594       512
# weighted avg     0.9129    0.8945    0.8992       512
#
#
# [ResNet18_ImageNet][Fold 5] Final Metrics
# Accuracy: 0.8945
# ROC-AUC: 0.9569
# F1-score : 0.7891
# Sensitivity : 0.9099
# Confusion Matrix:
# [[357  44]
#  [ 10 101]]
#                model  fold       acc   ROC-AUC  F1-score  Sensitivity  \
# 0  ResNet18_ImageNet     1  0.906433  0.977186  0.811024     0.927928
# 1  ResNet18_ImageNet     2  0.859649  0.951526  0.737226     0.909910
# 2  ResNet18_ImageNet     3  0.912109  0.967401  0.810127     0.864865
# 3  ResNet18_ImageNet     4  0.876953  0.958662  0.754864     0.873874
# 4  ResNet18_ImageNet     5  0.894531  0.956910  0.789062     0.909910
#
#          Confusion Matrix
# 0   [[362, 40], [8, 103]]
# 1  [[340, 62], [10, 101]]
# 2   [[371, 30], [15, 96]]
# 3   [[352, 49], [14, 97]]
# 4  [[357, 44], [10, 101]]

# %%
print(">>> Training ResNet50 (ImageNet)...")
resnet50_imagenet_cv_df, resnet50_imagenet_history_df = run_cv_for_model(
    model_name="ResNet50_ImageNet",
    model_type="resnet50_imagenet",
    build_fn=lambda: build_resnet50_patient_model(load_pretrained=True),
    norm_type="imagenet"
)
display(resnet50_imagenet_cv_df)
# Out:
# >>> Training ResNet50 (ImageNet)...
#
# ================================================================================
# Running ResNet50_ImageNet | Fold 1 | norm=imagenet
# ================================================================================
# [FOLD 1] Train benign(0): 1605, malignant(1): 444, pos_weight=3.6149
# [ResNet50_ImageNet][Fold 1][Epoch 01]train loss = 0.6987, acc=0.8097, auc=0.8795,f1 = 0.6362, recall=0.7680 | val loss = 0.5250, acc = 0.9084, auc = 0.9493, f1 = 0.7873, recall=0.7838
#   -> best saved by val_loss: ct_binary_models_filter_ablation/ResNet50_ImageNet_fold1_best.pth
# [ResNet50_ImageNet][Fold 1][Epoch 02]train loss = 0.4261, acc=0.8838, auc=0.9560,f1 = 0.7742, recall=0.9189 | val loss = 0.3127, acc = 0.9201, auc = 0.9776, f1 = 0.8353, recall=0.9369
#   -> best saved by val_loss: ct_binary_models_filter_ablation/ResNet50_ImageNet_fold1_best.pth
# [ResNet50_ImageNet][Fold 1][Epoch 03]train loss = 0.2990, acc=0.9258, auc=0.9776,f1 = 0.8465, recall=0.9437 | val loss = 0.3637, acc = 0.8986, auc = 0.9667, f1 = 0.7920, recall=0.8919
#   -> no improvement (1/7)
# [ResNet50_ImageNet][Fold 1][Epoch 04]train loss = 0.2174, acc=0.9366, auc=0.9883,f1 = 0.8665, recall=0.9505 | val loss = 0.2565, acc = 0.9181, auc = 0.9861, f1 = 0.8359, recall=0.9640
#   -> best saved by val_loss: ct_binary_models_filter_ablation/ResNet50_ImageNet_fold1_best.pth
# [ResNet50_ImageNet][Fold 1][Epoch 05]train loss = 0.1850, acc=0.9624, auc=0.9901,f1 = 0.9176, recall=0.9662 | val loss = 0.3967, acc = 0.9298, auc = 0.9698, f1 = 0.8421, recall=0.8649
#   -> no improvement (1/7)
# [ResNet50_ImageNet][Fold 1][Epoch 06]train loss = 0.1099, acc=0.9756, auc=0.9964,f1 = 0.9460, recall=0.9865 | val loss = 0.3965, acc = 0.9415, auc = 0.9778, f1 = 0.8624, recall=0.8468
#   -> no improvement (2/7)
# [ResNet50_ImageNet][Fold 1][Epoch 07]train loss = 0.0509, acc=0.9893, auc=0.9993,f1 = 0.9758, recall=0.9977 | val loss = 0.4510, acc = 0.9415, auc = 0.9802, f1 = 0.8611, recall=0.8378
#   -> no improvement (3/7)
# [ResNet50_ImageNet][Fold 1][Epoch 08]train loss = 0.0954, acc=0.9819, auc=0.9967,f1 = 0.9595, recall=0.9865 | val loss = 0.5582, acc = 0.9318, auc = 0.9807, f1 = 0.8259, recall=0.7477
#   -> no improvement (4/7)
# [ResNet50_ImageNet][Fold 1][Epoch 09]train loss = 0.1200, acc=0.9702, auc=0.9958,f1 = 0.9341, recall=0.9730 | val loss = 0.3033, acc = 0.9201, auc = 0.9799, f1 = 0.8340, recall=0.9279
#   -> no improvement (5/7)
# [ResNet50_ImageNet][Fold 1][Epoch 10]train loss = 0.0300, acc=0.9966, auc=0.9997,f1 = 0.9922, recall=0.9977 | val loss = 0.5047, acc = 0.9357, auc = 0.9772, f1 = 0.8493, recall=0.8378
#   -> no improvement (6/7)
# [ResNet50_ImageNet][Fold 1][Epoch 11]train loss = 0.0680, acc=0.9829, auc=0.9986,f1 = 0.9619, recall=0.9955 | val loss = 0.5745, acc = 0.9298, auc = 0.9813, f1 = 0.8218, recall=0.7477
#   -> no improvement (7/7)
#   -> early stopping triggered at epoch 11
#
# --Final Evaluation (threshold=0.5) --
# Accuracy: 0.9162
# ROC-AUC : 0.9859
# F1-score : 0.8340
# Sensitivity : 0.9730
# Confusion Matrix:
# [[362  40]
#  [  3 108]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0     0.9918    0.9005    0.9439       402
#            1     0.7297    0.9730    0.8340       111
#
#     accuracy                         0.9162       513
#    macro avg     0.8608    0.9367    0.8890       513
# weighted avg     0.9351    0.9162    0.9201       513
#
#
# [ResNet50_ImageNet][Fold 1] Final Metrics
# Accuracy: 0.9162
# ROC-AUC: 0.9859
# F1-score : 0.8340
# Sensitivity : 0.9730
# Confusion Matrix:
# [[362  40]
#  [  3 108]]
#
# ================================================================================
# Running ResNet50_ImageNet | Fold 2 | norm=imagenet
# ================================================================================
# [FOLD 2] Train benign(0): 1605, malignant(1): 444, pos_weight=3.6149
# [ResNet50_ImageNet][Fold 2][Epoch 01]train loss = 0.7691, acc=0.8214, auc=0.8581,f1 = 0.6180, recall=0.6667 | val loss = 0.5846, acc = 0.7953, auc = 0.9255, f1 = 0.6580, recall=0.9099
#   -> best saved by val_loss: ct_binary_models_filter_ablation/ResNet50_ImageNet_fold2_best.pth
# [ResNet50_ImageNet][Fold 2][Epoch 02]train loss = 0.4269, acc=0.8824, auc=0.9556,f1 = 0.7698, recall=0.9077 | val loss = 0.5378, acc = 0.8830, auc = 0.9337, f1 = 0.7500, recall=0.8108
#   -> best saved by val_loss: ct_binary_models_filter_ablation/ResNet50_ImageNet_fold2_best.pth
# [ResNet50_ImageNet][Fold 2][Epoch 03]train loss = 0.3040, acc=0.9107, auc=0.9773,f1 = 0.8211, recall=0.9459 | val loss = 0.5729, acc = 0.8830, auc = 0.9434, f1 = 0.7674, recall=0.8919
#   -> no improvement (1/7)
# [ResNet50_ImageNet][Fold 2][Epoch 04]train loss = 0.2318, acc=0.9429, auc=0.9858,f1 = 0.8793, recall=0.9595 | val loss = 0.6615, acc = 0.9025, auc = 0.9378, f1 = 0.7826, recall=0.8108
#   -> no improvement (2/7)
# [ResNet50_ImageNet][Fold 2][Epoch 05]train loss = 0.1720, acc=0.9580, auc=0.9923,f1 = 0.9095, recall=0.9730 | val loss = 0.7907, acc = 0.9045, auc = 0.9444, f1 = 0.7633, recall=0.7117
#   -> no improvement (3/7)
# [ResNet50_ImageNet][Fold 2][Epoch 06]train loss = 0.1451, acc=0.9722, auc=0.9933,f1 = 0.9378, recall=0.9685 | val loss = 0.6983, acc = 0.8967, auc = 0.9371, f1 = 0.7602, recall=0.7568
#   -> no improvement (4/7)
# [ResNet50_ImageNet][Fold 2][Epoch 07]train loss = 0.0727, acc=0.9849, auc=0.9988,f1 = 0.9659, recall=0.9887 | val loss = 0.7759, acc = 0.8986, auc = 0.9424, f1 = 0.7778, recall=0.8198
#   -> no improvement (5/7)
# [ResNet50_ImageNet][Fold 2][Epoch 08]train loss = 0.0741, acc=0.9819, auc=0.9985,f1 = 0.9595, recall=0.9865 | val loss = 0.8722, acc = 0.8986, auc = 0.9445, f1 = 0.7658, recall=0.7658
#   -> no improvement (6/7)
# [ResNet50_ImageNet][Fold 2][Epoch 09]train loss = 0.0311, acc=0.9917, auc=0.9998,f1 = 0.9810, recall=0.9910 | val loss = 1.0789, acc = 0.8947, auc = 0.9465, f1 = 0.7545, recall=0.7477
#   -> no improvement (7/7)
#   -> early stopping triggered at epoch 9
#
# --Final Evaluation (threshold=0.5) --
# Accuracy: 0.8889
# ROC-AUC : 0.9335
# F1-score : 0.7635
# Sensitivity : 0.8288
# Confusion Matrix:
# [[364  38]
#  [ 19  92]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0     0.9504    0.9055    0.9274       402
#            1     0.7077    0.8288    0.7635       111
#
#     accuracy                         0.8889       513
#    macro avg     0.8290    0.8672    0.8454       513
# weighted avg     0.8979    0.8889    0.8919       513
#
#
# [ResNet50_ImageNet][Fold 2] Final Metrics
# Accuracy: 0.8889
# ROC-AUC: 0.9335
# F1-score : 0.7635
# Sensitivity : 0.8288
# Confusion Matrix:
# [[364  38]
#  [ 19  92]]
#
# ================================================================================
# Running ResNet50_ImageNet | Fold 3 | norm=imagenet
# ================================================================================
# [FOLD 3] Train benign(0): 1606, malignant(1): 444, pos_weight=3.6171
# [ResNet50_ImageNet][Fold 3][Epoch 01]train loss = 0.7225, acc=0.8176, auc=0.8734,f1 = 0.6492, recall=0.7793 | val loss = 0.4893, acc = 0.8340, auc = 0.9494, f1 = 0.7119, recall=0.9459
#   -> best saved by val_loss: ct_binary_models_filter_ablation/ResNet50_ImageNet_fold3_best.pth
# [ResNet50_ImageNet][Fold 3][Epoch 02]train loss = 0.4711, acc=0.8659, auc=0.9469,f1 = 0.7451, recall=0.9054 | val loss = 0.4232, acc = 0.8730, auc = 0.9580, f1 = 0.7584, recall=0.9189
#   -> best saved by val_loss: ct_binary_models_filter_ablation/ResNet50_ImageNet_fold3_best.pth
# [ResNet50_ImageNet][Fold 3][Epoch 03]train loss = 0.3451, acc=0.9107, auc=0.9703,f1 = 0.8211, recall=0.9459 | val loss = 0.4185, acc = 0.9199, auc = 0.9595, f1 = 0.8285, recall=0.8919
#   -> best saved by val_loss: ct_binary_models_filter_ablation/ResNet50_ImageNet_fold3_best.pth
# [ResNet50_ImageNet][Fold 3][Epoch 04]train loss = 0.2532, acc=0.9390, auc=0.9833,f1 = 0.8718, recall=0.9572 | val loss = 0.4244, acc = 0.8945, auc = 0.9611, f1 = 0.7907, recall=0.9189
#   -> no improvement (1/7)
# [ResNet50_ImageNet][Fold 3][Epoch 05]train loss = 0.1854, acc=0.9585, auc=0.9910,f1 = 0.9095, recall=0.9617 | val loss = 0.5697, acc = 0.8711, auc = 0.9514, f1 = 0.7574, recall=0.9279
#   -> no improvement (2/7)
# [ResNet50_ImageNet][Fold 3][Epoch 06]train loss = 0.1934, acc=0.9600, auc=0.9895,f1 = 0.9128, recall=0.9662 | val loss = 0.4404, acc = 0.9219, auc = 0.9601, f1 = 0.8291, recall=0.8739
#   -> no improvement (3/7)
# [ResNet50_ImageNet][Fold 3][Epoch 07]train loss = 0.1202, acc=0.9741, auc=0.9959,f1 = 0.9425, recall=0.9775 | val loss = 0.4942, acc = 0.9043, auc = 0.9529, f1 = 0.8048, recall=0.9099
#   -> no improvement (4/7)
# [ResNet50_ImageNet][Fold 3][Epoch 08]train loss = 0.0459, acc=0.9878, auc=0.9996,f1 = 0.9723, recall=0.9887 | val loss = 0.6553, acc = 0.9238, auc = 0.9591, f1 = 0.8354, recall=0.8919
#   -> no improvement (5/7)
# [ResNet50_ImageNet][Fold 3][Epoch 09]train loss = 0.0504, acc=0.9893, auc=0.9992,f1 = 0.9755, recall=0.9865 | val loss = 0.5846, acc = 0.9082, auc = 0.9527, f1 = 0.8142, recall=0.9279
#   -> no improvement (6/7)
# [ResNet50_ImageNet][Fold 3][Epoch 10]train loss = 0.0615, acc=0.9868, auc=0.9985,f1 = 0.9702, recall=0.9887 | val loss = 0.9309, acc = 0.9199, auc = 0.9450, f1 = 0.8210, recall=0.8468
#   -> no improvement (7/7)
#   -> early stopping triggered at epoch 10
#
# --Final Evaluation (threshold=0.5) --
# Accuracy: 0.9160
# ROC-AUC : 0.9585
# F1-score : 0.8216
# Sensitivity : 0.8919
# Confusion Matrix:
# [[370  31]
#  [ 12  99]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0     0.9686    0.9227    0.9451       401
#            1     0.7615    0.8919    0.8216       111
#
#     accuracy                         0.9160       512
#    macro avg     0.8651    0.9073    0.8833       512
# weighted avg     0.9237    0.9160    0.9183       512
#
#
# [ResNet50_ImageNet][Fold 3] Final Metrics
# Accuracy: 0.9160
# ROC-AUC: 0.9585
# F1-score : 0.8216
# Sensitivity : 0.8919
# Confusion Matrix:
# [[370  31]
#  [ 12  99]]
#
# ================================================================================
# Running ResNet50_ImageNet | Fold 4 | norm=imagenet
# ================================================================================
# [FOLD 4] Train benign(0): 1606, malignant(1): 444, pos_weight=3.6171
# [ResNet50_ImageNet][Fold 4][Epoch 01]train loss = 0.7379, acc=0.7702, auc=0.8565,f1 = 0.5836, recall=0.7432 | val loss = 0.7385, acc = 0.8613, auc = 0.9171, f1 = 0.7078, recall=0.7748
#   -> best saved by val_loss: ct_binary_models_filter_ablation/ResNet50_ImageNet_fold4_best.pth
# [ResNet50_ImageNet][Fold 4][Epoch 02]train loss = 0.4645, acc=0.8595, auc=0.9467,f1 = 0.7387, recall=0.9167 | val loss = 0.4074, acc = 0.8984, auc = 0.9602, f1 = 0.7937, recall=0.9009
#   -> best saved by val_loss: ct_binary_models_filter_ablation/ResNet50_ImageNet_fold4_best.pth
# [ResNet50_ImageNet][Fold 4][Epoch 03]train loss = 0.2788, acc=0.9229, auc=0.9805,f1 = 0.8423, recall=0.9505 | val loss = 0.4802, acc = 0.9082, auc = 0.9493, f1 = 0.7911, recall=0.8018
#   -> no improvement (1/7)
# [ResNet50_ImageNet][Fold 4][Epoch 04]train loss = 0.2078, acc=0.9473, auc=0.9898,f1 = 0.8868, recall=0.9527 | val loss = 0.6091, acc = 0.8926, auc = 0.9506, f1 = 0.7809, recall=0.8829
#   -> no improvement (2/7)
# [ResNet50_ImageNet][Fold 4][Epoch 05]train loss = 0.1549, acc=0.9615, auc=0.9934,f1 = 0.9162, recall=0.9730 | val loss = 0.5780, acc = 0.9082, auc = 0.9646, f1 = 0.7892, recall=0.7928
#   -> no improvement (3/7)
# [ResNet50_ImageNet][Fold 4][Epoch 06]train loss = 0.1588, acc=0.9673, auc=0.9931,f1 = 0.9280, recall=0.9730 | val loss = 0.4202, acc = 0.9043, auc = 0.9597, f1 = 0.8016, recall=0.8919
#   -> no improvement (4/7)
# [ResNet50_ImageNet][Fold 4][Epoch 07]train loss = 0.1146, acc=0.9683, auc=0.9968,f1 = 0.9302, recall=0.9752 | val loss = 0.4576, acc = 0.9062, auc = 0.9681, f1 = 0.8000, recall=0.8649
#   -> no improvement (5/7)
# [ResNet50_ImageNet][Fold 4][Epoch 08]train loss = 0.0269, acc=0.9932, auc=0.9998,f1 = 0.9844, recall=0.9955 | val loss = 0.7249, acc = 0.9199, auc = 0.9676, f1 = 0.8111, recall=0.7928
#   -> no improvement (6/7)
# [ResNet50_ImageNet][Fold 4][Epoch 09]train loss = 0.0350, acc=0.9912, auc=0.9997,f1 = 0.9800, recall=0.9955 | val loss = 0.9576, acc = 0.9219, auc = 0.9666, f1 = 0.8058, recall=0.7477
#   -> no improvement (7/7)
#   -> early stopping triggered at epoch 9
#
# --Final Evaluation (threshold=0.5) --
# Accuracy: 0.8984
# ROC-AUC : 0.9599
# F1-score : 0.7937
# Sensitivity : 0.9009
# Confusion Matrix:
# [[360  41]
#  [ 11 100]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0     0.9704    0.8978    0.9326       401
#            1     0.7092    0.9009    0.7937       111
#
#     accuracy                         0.8984       512
#    macro avg     0.8398    0.8993    0.8631       512
# weighted avg     0.9137    0.8984    0.9025       512
#
#
# [ResNet50_ImageNet][Fold 4] Final Metrics
# Accuracy: 0.8984
# ROC-AUC: 0.9599
# F1-score : 0.7937
# Sensitivity : 0.9009
# Confusion Matrix:
# [[360  41]
#  [ 11 100]]
#
# ================================================================================
# Running ResNet50_ImageNet | Fold 5 | norm=imagenet
# ================================================================================
# [FOLD 5] Train benign(0): 1606, malignant(1): 444, pos_weight=3.6171
# [ResNet50_ImageNet][Fold 5][Epoch 01]train loss = 0.6956, acc=0.8161, auc=0.8768,f1 = 0.6385, recall=0.7500 | val loss = 0.5212, acc = 0.8652, auc = 0.9404, f1 = 0.7229, recall=0.8108
#   -> best saved by val_loss: ct_binary_models_filter_ablation/ResNet50_ImageNet_fold5_best.pth
# [ResNet50_ImageNet][Fold 5][Epoch 02]train loss = 0.3696, acc=0.8961, auc=0.9666,f1 = 0.7910, recall=0.9077 | val loss = 0.4017, acc = 0.8906, auc = 0.9592, f1 = 0.7829, recall=0.9099
#   -> best saved by val_loss: ct_binary_models_filter_ablation/ResNet50_ImageNet_fold5_best.pth
# [ResNet50_ImageNet][Fold 5][Epoch 03]train loss = 0.2412, acc=0.9380, auc=0.9851,f1 = 0.8700, recall=0.9572 | val loss = 0.5087, acc = 0.8789, auc = 0.9481, f1 = 0.7540, recall=0.8559
#   -> no improvement (1/7)
# [ResNet50_ImageNet][Fold 5][Epoch 04]train loss = 0.1924, acc=0.9532, auc=0.9901,f1 = 0.8994, recall=0.9662 | val loss = 0.4865, acc = 0.9121, auc = 0.9625, f1 = 0.8069, recall=0.8468
#   -> no improvement (2/7)
# [ResNet50_ImageNet][Fold 5][Epoch 05]train loss = 0.1145, acc=0.9756, auc=0.9964,f1 = 0.9455, recall=0.9775 | val loss = 0.5282, acc = 0.9102, auc = 0.9579, f1 = 0.8000, recall=0.8288
#   -> no improvement (3/7)
# [ResNet50_ImageNet][Fold 5][Epoch 06]train loss = 0.1372, acc=0.9737, auc=0.9945,f1 = 0.9416, recall=0.9797 | val loss = 0.5270, acc = 0.8848, auc = 0.9499, f1 = 0.7489, recall=0.7928
#   -> no improvement (4/7)
# [ResNet50_ImageNet][Fold 5][Epoch 07]train loss = 0.0969, acc=0.9746, auc=0.9972,f1 = 0.9436, recall=0.9797 | val loss = 0.5136, acc = 0.8926, auc = 0.9539, f1 = 0.7826, recall=0.8919
#   -> no improvement (5/7)
# [ResNet50_ImageNet][Fold 5][Epoch 08]train loss = 0.0626, acc=0.9883, auc=0.9987,f1 = 0.9733, recall=0.9865 | val loss = 0.7091, acc = 0.8574, auc = 0.9569, f1 = 0.7384, recall=0.9279
#   -> no improvement (6/7)
# [ResNet50_ImageNet][Fold 5][Epoch 09]train loss = 0.0885, acc=0.9780, auc=0.9979,f1 = 0.9507, recall=0.9775 | val loss = 0.5652, acc = 0.9121, auc = 0.9622, f1 = 0.8018, recall=0.8198
#   -> no improvement (7/7)
#   -> early stopping triggered at epoch 9
#
# --Final Evaluation (threshold=0.5) --
# Accuracy: 0.8848
# ROC-AUC : 0.9584
# F1-score : 0.7739
# Sensitivity : 0.9099
# Confusion Matrix:
# [[352  49]
#  [ 10 101]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0     0.9724    0.8778    0.9227       401
#            1     0.6733    0.9099    0.7739       111
#
#     accuracy                         0.8848       512
#    macro avg     0.8229    0.8939    0.8483       512
# weighted avg     0.9075    0.8848    0.8904       512
#
#
# [ResNet50_ImageNet][Fold 5] Final Metrics
# Accuracy: 0.8848
# ROC-AUC: 0.9584
# F1-score : 0.7739
# Sensitivity : 0.9099
# Confusion Matrix:
# [[352  49]
#  [ 10 101]]
#                model  fold       acc   ROC-AUC  F1-score  Sensitivity  \
# 0  ResNet50_ImageNet     1  0.916179  0.985904  0.833977     0.972973
# 1  ResNet50_ImageNet     2  0.888889  0.933486  0.763485     0.828829
# 2  ResNet50_ImageNet     3  0.916016  0.958482  0.821577     0.891892
# 3  ResNet50_ImageNet     4  0.898438  0.959920  0.793651     0.900901
# 4  ResNet50_ImageNet     5  0.884766  0.958437  0.773946     0.909910
#
#          Confusion Matrix
# 0   [[362, 40], [3, 108]]
# 1   [[364, 38], [19, 92]]
# 2   [[370, 31], [12, 99]]
# 3  [[360, 41], [11, 100]]
# 4  [[352, 49], [10, 101]]

# %%
print(">>> Training ResNet18 (RadImageNet)...")
resnet18_rad_cv_df, resnet18_rad_history_df = run_cv_for_model(
    model_name="ResNet18_RadImageNet",
    model_type="resnet18_radimagenet",
    build_fn=lambda: build_resnet18_patient_model(load_pretrained=True),
    norm_type="radimagenet"
)
display(resnet18_rad_cv_df)
# Out:
# >>> Training ResNet18 (RadImageNet)...
#
# ================================================================================
# Running ResNet18_RadImageNet | Fold 1 | norm=radimagenet
# ================================================================================
# [FOLD 1] Train benign(0): 1605, malignant(1): 444, pos_weight=3.6149
# [ResNet18_RadImageNet][Fold 1][Epoch 01]train loss = 0.6002, acc=0.8326, auc=0.9091,f1 = 0.6885, recall=0.8536 | val loss = 0.3448, acc = 0.9142, auc = 0.9733, f1 = 0.8226, recall=0.9189
#   -> best saved by val_loss: ct_binary_models_filter_ablation/ResNet18_RadImageNet_fold1_best.pth
# [ResNet18_RadImageNet][Fold 1][Epoch 02]train loss = 0.4132, acc=0.8912, auc=0.9578,f1 = 0.7837, recall=0.9099 | val loss = 0.2483, acc = 0.9474, auc = 0.9873, f1 = 0.8861, recall=0.9459
#   -> best saved by val_loss: ct_binary_models_filter_ablation/ResNet18_RadImageNet_fold1_best.pth
# [ResNet18_RadImageNet][Fold 1][Epoch 03]train loss = 0.2749, acc=0.9287, auc=0.9815,f1 = 0.8485, recall=0.9212 | val loss = 0.3714, acc = 0.8635, auc = 0.9789, f1 = 0.7569, recall=0.9820
#   -> no improvement (1/7)
# [ResNet18_RadImageNet][Fold 1][Epoch 04]train loss = 0.2044, acc=0.9439, auc=0.9887,f1 = 0.8816, recall=0.9640 | val loss = 0.4134, acc = 0.9201, auc = 0.9731, f1 = 0.8161, recall=0.8198
#   -> no improvement (2/7)
# [ResNet18_RadImageNet][Fold 1][Epoch 05]train loss = 0.1598, acc=0.9658, auc=0.9932,f1 = 0.9242, recall=0.9617 | val loss = 0.4083, acc = 0.9357, auc = 0.9766, f1 = 0.8493, recall=0.8378
#   -> no improvement (3/7)
# [ResNet18_RadImageNet][Fold 1][Epoch 06]train loss = 0.0966, acc=0.9766, auc=0.9979,f1 = 0.9479, recall=0.9842 | val loss = 0.5592, acc = 0.9435, auc = 0.9823, f1 = 0.8557, recall=0.7748
#   -> no improvement (4/7)
# [ResNet18_RadImageNet][Fold 1][Epoch 07]train loss = 0.0815, acc=0.9849, auc=0.9977,f1 = 0.9658, recall=0.9865 | val loss = 0.3672, acc = 0.9532, auc = 0.9848, f1 = 0.8889, recall=0.8649
#   -> no improvement (5/7)
# [ResNet18_RadImageNet][Fold 1][Epoch 08]train loss = 0.0723, acc=0.9829, auc=0.9983,f1 = 0.9617, recall=0.9887 | val loss = 0.3551, acc = 0.9318, auc = 0.9815, f1 = 0.8485, recall=0.8829
#   -> no improvement (6/7)
# [ResNet18_RadImageNet][Fold 1][Epoch 09]train loss = 0.0488, acc=0.9878, auc=0.9994,f1 = 0.9724, recall=0.9910 | val loss = 0.6934, acc = 0.9181, auc = 0.9666, f1 = 0.8056, recall=0.7838
#   -> no improvement (7/7)
#   -> early stopping triggered at epoch 9
#
# --Final Evaluation (threshold=0.5) --
# Accuracy: 0.9474
# ROC-AUC : 0.9873
# F1-score : 0.8861
# Sensitivity : 0.9459
# Confusion Matrix:
# [[381  21]
#  [  6 105]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0     0.9845    0.9478    0.9658       402
#            1     0.8333    0.9459    0.8861       111
#
#     accuracy                         0.9474       513
#    macro avg     0.9089    0.9469    0.9259       513
# weighted avg     0.9518    0.9474    0.9485       513
#
#
# [ResNet18_RadImageNet][Fold 1] Final Metrics
# Accuracy: 0.9474
# ROC-AUC: 0.9873
# F1-score : 0.8861
# Sensitivity : 0.9459
# Confusion Matrix:
# [[381  21]
#  [  6 105]]
#
# ================================================================================
# Running ResNet18_RadImageNet | Fold 2 | norm=radimagenet
# ================================================================================
# [FOLD 2] Train benign(0): 1605, malignant(1): 444, pos_weight=3.6149
# [ResNet18_RadImageNet][Fold 2][Epoch 01]train loss = 0.5532, acc=0.8458, auc=0.9228,f1 = 0.7106, recall=0.8739 | val loss = 0.5022, acc = 0.8908, auc = 0.9461, f1 = 0.7686, recall=0.8378
#   -> best saved by val_loss: ct_binary_models_filter_ablation/ResNet18_RadImageNet_fold2_best.pth
# [ResNet18_RadImageNet][Fold 2][Epoch 02]train loss = 0.3323, acc=0.9092, auc=0.9717,f1 = 0.8173, recall=0.9369 | val loss = 0.4958, acc = 0.8713, auc = 0.9538, f1 = 0.7381, recall=0.8378
#   -> best saved by val_loss: ct_binary_models_filter_ablation/ResNet18_RadImageNet_fold2_best.pth
# [ResNet18_RadImageNet][Fold 2][Epoch 03]train loss = 0.2343, acc=0.9366, auc=0.9861,f1 = 0.8660, recall=0.9459 | val loss = 0.4377, acc = 0.8772, auc = 0.9555, f1 = 0.7586, recall=0.8919
#   -> best saved by val_loss: ct_binary_models_filter_ablation/ResNet18_RadImageNet_fold2_best.pth
# [ResNet18_RadImageNet][Fold 2][Epoch 04]train loss = 0.1827, acc=0.9507, auc=0.9916,f1 = 0.8940, recall=0.9595 | val loss = 0.4676, acc = 0.8986, auc = 0.9574, f1 = 0.7920, recall=0.8919
#   -> no improvement (1/7)
# [ResNet18_RadImageNet][Fold 2][Epoch 05]train loss = 0.1467, acc=0.9619, auc=0.9943,f1 = 0.9174, recall=0.9752 | val loss = 0.6466, acc = 0.9006, auc = 0.9417, f1 = 0.7952, recall=0.8919
#   -> no improvement (2/7)
# [ResNet18_RadImageNet][Fold 2][Epoch 06]train loss = 0.0580, acc=0.9858, auc=0.9993,f1 = 0.9682, recall=0.9932 | val loss = 0.9564, acc = 0.9084, auc = 0.9566, f1 = 0.7751, recall=0.7297
#   -> no improvement (3/7)
# [ResNet18_RadImageNet][Fold 2][Epoch 07]train loss = 0.2169, acc=0.9580, auc=0.9867,f1 = 0.9081, recall=0.9572 | val loss = 0.5042, acc = 0.9123, auc = 0.9600, f1 = 0.8117, recall=0.8739
#   -> no improvement (4/7)
# [ResNet18_RadImageNet][Fold 2][Epoch 08]train loss = 0.0681, acc=0.9839, auc=0.9988,f1 = 0.9639, recall=0.9910 | val loss = 0.6202, acc = 0.9162, auc = 0.9573, f1 = 0.8155, recall=0.8559
#   -> no improvement (5/7)
# [ResNet18_RadImageNet][Fold 2][Epoch 09]train loss = 0.0417, acc=0.9917, auc=0.9996,f1 = 0.9810, recall=0.9865 | val loss = 0.6150, acc = 0.9045, auc = 0.9567, f1 = 0.8032, recall=0.9009
#   -> no improvement (6/7)
# [ResNet18_RadImageNet][Fold 2][Epoch 10]train loss = 0.0261, acc=0.9937, auc=0.9997,f1 = 0.9855, recall=0.9955 | val loss = 0.7889, acc = 0.9045, auc = 0.9561, f1 = 0.7860, recall=0.8108
#   -> no improvement (7/7)
#   -> early stopping triggered at epoch 10
#
# --Final Evaluation (threshold=0.5) --
# Accuracy: 0.8772
# ROC-AUC : 0.9554
# F1-score : 0.7586
# Sensitivity : 0.8919
# Confusion Matrix:
# [[351  51]
#  [ 12  99]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0     0.9669    0.8731    0.9176       402
#            1     0.6600    0.8919    0.7586       111
#
#     accuracy                         0.8772       513
#    macro avg     0.8135    0.8825    0.8381       513
# weighted avg     0.9005    0.8772    0.8832       513
#
#
# [ResNet18_RadImageNet][Fold 2] Final Metrics
# Accuracy: 0.8772
# ROC-AUC: 0.9554
# F1-score : 0.7586
# Sensitivity : 0.8919
# Confusion Matrix:
# [[351  51]
#  [ 12  99]]
#
# ================================================================================
# Running ResNet18_RadImageNet | Fold 3 | norm=radimagenet
# ================================================================================
# [FOLD 3] Train benign(0): 1606, malignant(1): 444, pos_weight=3.6171
# [ResNet18_RadImageNet][Fold 3][Epoch 01]train loss = 0.6005, acc=0.8307, auc=0.9106,f1 = 0.6854, recall=0.8514 | val loss = 0.4917, acc = 0.8027, auc = 0.9587, f1 = 0.6773, recall=0.9550
#   -> best saved by val_loss: ct_binary_models_filter_ablation/ResNet18_RadImageNet_fold3_best.pth
# [ResNet18_RadImageNet][Fold 3][Epoch 02]train loss = 0.3528, acc=0.9117, auc=0.9685,f1 = 0.8206, recall=0.9324 | val loss = 0.5871, acc = 0.8867, auc = 0.9532, f1 = 0.7290, recall=0.7027
#   -> no improvement (1/7)
# [ResNet18_RadImageNet][Fold 3][Epoch 03]train loss = 0.2793, acc=0.9278, auc=0.9800,f1 = 0.8505, recall=0.9482 | val loss = 0.4630, acc = 0.8711, auc = 0.9676, f1 = 0.7626, recall=0.9550
#   -> best saved by val_loss: ct_binary_models_filter_ablation/ResNet18_RadImageNet_fold3_best.pth
# [ResNet18_RadImageNet][Fold 3][Epoch 04]train loss = 0.1790, acc=0.9522, auc=0.9919,f1 = 0.8977, recall=0.9685 | val loss = 0.4733, acc = 0.8730, auc = 0.9721, f1 = 0.7636, recall=0.9459
#   -> no improvement (1/7)
# [ResNet18_RadImageNet][Fold 3][Epoch 05]train loss = 0.1922, acc=0.9473, auc=0.9905,f1 = 0.8877, recall=0.9617 | val loss = 0.4663, acc = 0.9180, auc = 0.9634, f1 = 0.8142, recall=0.8288
#   -> no improvement (2/7)
# [ResNet18_RadImageNet][Fold 3][Epoch 06]train loss = 0.0822, acc=0.9805, auc=0.9986,f1 = 0.9563, recall=0.9865 | val loss = 0.6619, acc = 0.9102, auc = 0.9586, f1 = 0.7890, recall=0.7748
#   -> no improvement (3/7)
# [ResNet18_RadImageNet][Fold 3][Epoch 07]train loss = 0.0618, acc=0.9829, auc=0.9991,f1 = 0.9616, recall=0.9865 | val loss = 0.6195, acc = 0.9258, auc = 0.9677, f1 = 0.8304, recall=0.8378
#   -> no improvement (4/7)
# [ResNet18_RadImageNet][Fold 3][Epoch 08]train loss = 0.0346, acc=0.9927, auc=0.9998,f1 = 0.9833, recall=0.9955 | val loss = 0.8477, acc = 0.9238, auc = 0.9626, f1 = 0.8098, recall=0.7477
#   -> no improvement (5/7)
# [ResNet18_RadImageNet][Fold 3][Epoch 09]train loss = 0.0418, acc=0.9912, auc=0.9995,f1 = 0.9798, recall=0.9842 | val loss = 0.6925, acc = 0.9121, auc = 0.9632, f1 = 0.8101, recall=0.8649
#   -> no improvement (6/7)
# [ResNet18_RadImageNet][Fold 3][Epoch 10]train loss = 0.1095, acc=0.9693, auc=0.9969,f1 = 0.9320, recall=0.9730 | val loss = 0.8050, acc = 0.9102, auc = 0.9527, f1 = 0.7890, recall=0.7748
#   -> no improvement (7/7)
#   -> early stopping triggered at epoch 10
#
# --Final Evaluation (threshold=0.5) --
# Accuracy: 0.8691
# ROC-AUC : 0.9676
# F1-score : 0.7599
# Sensitivity : 0.9550
# Confusion Matrix:
# [[339  62]
#  [  5 106]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0     0.9855    0.8454    0.9101       401
#            1     0.6310    0.9550    0.7599       111
#
#     accuracy                         0.8691       512
#    macro avg     0.8082    0.9002    0.8350       512
# weighted avg     0.9086    0.8691    0.8775       512
#
#
# [ResNet18_RadImageNet][Fold 3] Final Metrics
# Accuracy: 0.8691
# ROC-AUC: 0.9676
# F1-score : 0.7599
# Sensitivity : 0.9550
# Confusion Matrix:
# [[339  62]
#  [  5 106]]
#
# ================================================================================
# Running ResNet18_RadImageNet | Fold 4 | norm=radimagenet
# ================================================================================
# [FOLD 4] Train benign(0): 1606, malignant(1): 444, pos_weight=3.6171
# [ResNet18_RadImageNet][Fold 4][Epoch 01]train loss = 0.5768, acc=0.8410, auc=0.9174,f1 = 0.7020, recall=0.8649 | val loss = 0.4271, acc = 0.9023, auc = 0.9576, f1 = 0.7899, recall=0.8468
#   -> best saved by val_loss: ct_binary_models_filter_ablation/ResNet18_RadImageNet_fold4_best.pth
# [ResNet18_RadImageNet][Fold 4][Epoch 02]train loss = 0.3568, acc=0.9127, auc=0.9673,f1 = 0.8201, recall=0.9189 | val loss = 0.4376, acc = 0.8984, auc = 0.9555, f1 = 0.7851, recall=0.8559
#   -> no improvement (1/7)
# [ResNet18_RadImageNet][Fold 4][Epoch 03]train loss = 0.2580, acc=0.9283, auc=0.9830,f1 = 0.8502, recall=0.9392 | val loss = 0.5284, acc = 0.8906, auc = 0.9534, f1 = 0.7795, recall=0.8919
#   -> no improvement (2/7)
# [ResNet18_RadImageNet][Fold 4][Epoch 04]train loss = 0.1822, acc=0.9546, auc=0.9910,f1 = 0.9022, recall=0.9662 | val loss = 0.7120, acc = 0.9160, auc = 0.9510, f1 = 0.8106, recall=0.8288
#   -> no improvement (3/7)
# [ResNet18_RadImageNet][Fold 4][Epoch 05]train loss = 0.1309, acc=0.9649, auc=0.9958,f1 = 0.9231, recall=0.9730 | val loss = 0.6225, acc = 0.8926, auc = 0.9642, f1 = 0.7791, recall=0.8739
#   -> no improvement (4/7)
# [ResNet18_RadImageNet][Fold 4][Epoch 06]train loss = 0.1336, acc=0.9620, auc=0.9953,f1 = 0.9172, recall=0.9730 | val loss = 0.6743, acc = 0.9043, auc = 0.9606, f1 = 0.7721, recall=0.7477
#   -> no improvement (5/7)
# [ResNet18_RadImageNet][Fold 4][Epoch 07]train loss = 0.1216, acc=0.9741, auc=0.9952,f1 = 0.9425, recall=0.9775 | val loss = 0.4322, acc = 0.9258, auc = 0.9732, f1 = 0.8390, recall=0.8919
#   -> no improvement (6/7)
# [ResNet18_RadImageNet][Fold 4][Epoch 08]train loss = 0.0722, acc=0.9810, auc=0.9986,f1 = 0.9576, recall=0.9910 | val loss = 0.5829, acc = 0.9277, auc = 0.9680, f1 = 0.8295, recall=0.8108
#   -> no improvement (7/7)
#   -> early stopping triggered at epoch 8
#
# --Final Evaluation (threshold=0.5) --
# Accuracy: 0.9023
# ROC-AUC : 0.9576
# F1-score : 0.7899
# Sensitivity : 0.8468
# Confusion Matrix:
# [[368  33]
#  [ 17  94]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0     0.9558    0.9177    0.9364       401
#            1     0.7402    0.8468    0.7899       111
#
#     accuracy                         0.9023       512
#    macro avg     0.8480    0.8823    0.8632       512
# weighted avg     0.9091    0.9023    0.9046       512
#
#
# [ResNet18_RadImageNet][Fold 4] Final Metrics
# Accuracy: 0.9023
# ROC-AUC: 0.9576
# F1-score : 0.7899
# Sensitivity : 0.8468
# Confusion Matrix:
# [[368  33]
#  [ 17  94]]
#
# ================================================================================
# Running ResNet18_RadImageNet | Fold 5 | norm=radimagenet
# ================================================================================
# [FOLD 5] Train benign(0): 1606, malignant(1): 444, pos_weight=3.6171
# [ResNet18_RadImageNet][Fold 5][Epoch 01]train loss = 0.5634, acc=0.8527, auc=0.9214,f1 = 0.7151, recall=0.8536 | val loss = 0.4669, acc = 0.8672, auc = 0.9534, f1 = 0.7554, recall=0.9459
#   -> best saved by val_loss: ct_binary_models_filter_ablation/ResNet18_RadImageNet_fold5_best.pth
# [ResNet18_RadImageNet][Fold 5][Epoch 02]train loss = 0.3490, acc=0.9034, auc=0.9699,f1 = 0.8055, recall=0.9234 | val loss = 0.5264, acc = 0.8516, auc = 0.9400, f1 = 0.7246, recall=0.9009
#   -> no improvement (1/7)
# [ResNet18_RadImageNet][Fold 5][Epoch 03]train loss = 0.2392, acc=0.9307, auc=0.9857,f1 = 0.8563, recall=0.9527 | val loss = 0.6253, acc = 0.9102, auc = 0.9536, f1 = 0.7870, recall=0.7658
#   -> no improvement (2/7)
# [ResNet18_RadImageNet][Fold 5][Epoch 04]train loss = 0.2046, acc=0.9478, auc=0.9892,f1 = 0.8887, recall=0.9617 | val loss = 0.4061, acc = 0.9023, auc = 0.9657, f1 = 0.8016, recall=0.9099
#   -> best saved by val_loss: ct_binary_models_filter_ablation/ResNet18_RadImageNet_fold5_best.pth
# [ResNet18_RadImageNet][Fold 5][Epoch 05]train loss = 0.1292, acc=0.9654, auc=0.9956,f1 = 0.9244, recall=0.9775 | val loss = 0.5833, acc = 0.8926, auc = 0.9532, f1 = 0.7809, recall=0.8829
#   -> no improvement (1/7)
# [ResNet18_RadImageNet][Fold 5][Epoch 06]train loss = 0.1027, acc=0.9727, auc=0.9973,f1 = 0.9394, recall=0.9775 | val loss = 0.7241, acc = 0.9102, auc = 0.9534, f1 = 0.8034, recall=0.8468
#   -> no improvement (2/7)
# [ResNet18_RadImageNet][Fold 5][Epoch 07]train loss = 0.1052, acc=0.9722, auc=0.9967,f1 = 0.9386, recall=0.9820 | val loss = 0.8232, acc = 0.9023, auc = 0.9516, f1 = 0.7807, recall=0.8018
#   -> no improvement (3/7)
# [ResNet18_RadImageNet][Fold 5][Epoch 08]train loss = 0.0390, acc=0.9922, auc=0.9996,f1 = 0.9823, recall=0.9977 | val loss = 0.8820, acc = 0.8867, auc = 0.9419, f1 = 0.7500, recall=0.7838
#   -> no improvement (4/7)
# [ResNet18_RadImageNet][Fold 5][Epoch 09]train loss = 0.0807, acc=0.9800, auc=0.9983,f1 = 0.9552, recall=0.9842 | val loss = 0.8549, acc = 0.9102, auc = 0.9528, f1 = 0.8017, recall=0.8378
#   -> no improvement (5/7)
# [ResNet18_RadImageNet][Fold 5][Epoch 10]train loss = 0.0816, acc=0.9834, auc=0.9981,f1 = 0.9626, recall=0.9842 | val loss = 0.9325, acc = 0.9023, auc = 0.9520, f1 = 0.7685, recall=0.7477
#   -> no improvement (6/7)
# [ResNet18_RadImageNet][Fold 5][Epoch 11]train loss = 0.0691, acc=0.9878, auc=0.9982,f1 = 0.9722, recall=0.9842 | val loss = 0.8535, acc = 0.7988, auc = 0.9245, f1 = 0.6667, recall=0.9279
#   -> no improvement (7/7)
#   -> early stopping triggered at epoch 11
#
# --Final Evaluation (threshold=0.5) --
# Accuracy: 0.9023
# ROC-AUC : 0.9656
# F1-score : 0.8016
# Sensitivity : 0.9099
# Confusion Matrix:
# [[361  40]
#  [ 10 101]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0     0.9730    0.9002    0.9352       401
#            1     0.7163    0.9099    0.8016       111
#
#     accuracy                         0.9023       512
#    macro avg     0.8447    0.9051    0.8684       512
# weighted avg     0.9174    0.9023    0.9063       512
#
#
# [ResNet18_RadImageNet][Fold 5] Final Metrics
# Accuracy: 0.9023
# ROC-AUC: 0.9656
# F1-score : 0.8016
# Sensitivity : 0.9099
# Confusion Matrix:
# [[361  40]
#  [ 10 101]]
#                   model  fold       acc   ROC-AUC  F1-score  Sensitivity  \
# 0  ResNet18_RadImageNet     1  0.947368  0.987293  0.886076     0.945946
# 1  ResNet18_RadImageNet     2  0.877193  0.955403  0.758621     0.891892
# 2  ResNet18_RadImageNet     3  0.869141  0.967604  0.759857     0.954955
# 3  ResNet18_RadImageNet     4  0.902344  0.957606  0.789916     0.846847
# 4  ResNet18_RadImageNet     5  0.902344  0.965604  0.801587     0.909910
#
#          Confusion Matrix
# 0   [[381, 21], [6, 105]]
# 1   [[351, 51], [12, 99]]
# 2   [[339, 62], [5, 106]]
# 3   [[368, 33], [17, 94]]
# 4  [[361, 40], [10, 101]]

# %%
print(">>> Training ResNet50 (RadImageNet)...")
resnet50_rad_cv_df, resnet50_rad_history_df = run_cv_for_model(
    model_name="ResNet50_RadImageNet",
    model_type="resnet50_radimagenet",
    build_fn=lambda: build_resnet50_patient_model(load_pretrained=True),
    norm_type="radimagenet"
)
display(resnet50_rad_cv_df)
# Out:
# >>> Training ResNet50 (RadImageNet)...
#
# ================================================================================
# Running ResNet50_RadImageNet | Fold 1 | norm=radimagenet
# ================================================================================
# [FOLD 1] Train benign(0): 1605, malignant(1): 444, pos_weight=3.6149
# [ResNet50_RadImageNet][Fold 1][Epoch 01]train loss = 0.6696, acc=0.8062, auc=0.8879,f1 = 0.6490, recall=0.8266 | val loss = 0.3639, acc = 0.9064, auc = 0.9743, f1 = 0.8110, recall=0.9279
#   -> best saved by val_loss: ct_binary_models_filter_ablation/ResNet50_RadImageNet_fold1_best.pth
# [ResNet50_RadImageNet][Fold 1][Epoch 02]train loss = 0.3848, acc=0.8990, auc=0.9636,f1 = 0.8004, recall=0.9347 | val loss = 0.3420, acc = 0.9259, auc = 0.9810, f1 = 0.8443, recall=0.9279
#   -> best saved by val_loss: ct_binary_models_filter_ablation/ResNet50_RadImageNet_fold1_best.pth
# [ResNet50_RadImageNet][Fold 1][Epoch 03]train loss = 0.2692, acc=0.9287, auc=0.9819,f1 = 0.8516, recall=0.9437 | val loss = 0.4777, acc = 0.8908, auc = 0.9629, f1 = 0.7863, recall=0.9279
#   -> no improvement (1/7)
# [ResNet50_RadImageNet][Fold 1][Epoch 04]train loss = 0.1689, acc=0.9517, auc=0.9928,f1 = 0.8963, recall=0.9640 | val loss = 0.7148, acc = 0.9084, auc = 0.9661, f1 = 0.7638, recall=0.6847
#   -> no improvement (2/7)
# [ResNet50_RadImageNet][Fold 1][Epoch 05]train loss = 0.1660, acc=0.9527, auc=0.9933,f1 = 0.8978, recall=0.9595 | val loss = 0.3571, acc = 0.9240, auc = 0.9737, f1 = 0.8354, recall=0.8919
#   -> no improvement (3/7)
# [ResNet50_RadImageNet][Fold 1][Epoch 06]train loss = 0.1108, acc=0.9707, auc=0.9969,f1 = 0.9353, recall=0.9775 | val loss = 0.3364, acc = 0.9259, auc = 0.9762, f1 = 0.8417, recall=0.9099
#   -> best saved by val_loss: ct_binary_models_filter_ablation/ResNet50_RadImageNet_fold1_best.pth
# [ResNet50_RadImageNet][Fold 1][Epoch 07]train loss = 0.0673, acc=0.9839, auc=0.9986,f1 = 0.9640, recall=0.9955 | val loss = 0.3185, acc = 0.9454, auc = 0.9813, f1 = 0.8772, recall=0.9009
#   -> best saved by val_loss: ct_binary_models_filter_ablation/ResNet50_RadImageNet_fold1_best.pth
# [ResNet50_RadImageNet][Fold 1][Epoch 08]train loss = 0.0340, acc=0.9912, auc=0.9997,f1 = 0.9800, recall=0.9932 | val loss = 0.5313, acc = 0.9201, auc = 0.9663, f1 = 0.8270, recall=0.8829
#   -> no improvement (1/7)
# [ResNet50_RadImageNet][Fold 1][Epoch 09]train loss = 0.0702, acc=0.9844, auc=0.9985,f1 = 0.9648, recall=0.9865 | val loss = 0.4564, acc = 0.9337, auc = 0.9782, f1 = 0.8426, recall=0.8198
#   -> no improvement (2/7)
# [ResNet50_RadImageNet][Fold 1][Epoch 10]train loss = 0.0868, acc=0.9819, auc=0.9974,f1 = 0.9592, recall=0.9797 | val loss = 0.5164, acc = 0.9357, auc = 0.9700, f1 = 0.8559, recall=0.8829
#   -> no improvement (3/7)
# [ResNet50_RadImageNet][Fold 1][Epoch 11]train loss = 0.0565, acc=0.9888, auc=0.9990,f1 = 0.9744, recall=0.9865 | val loss = 0.3594, acc = 0.9259, auc = 0.9774, f1 = 0.8455, recall=0.9369
#   -> no improvement (4/7)
# [ResNet50_RadImageNet][Fold 1][Epoch 12]train loss = 0.0356, acc=0.9917, auc=0.9997,f1 = 0.9811, recall=0.9932 | val loss = 0.3575, acc = 0.9318, auc = 0.9823, f1 = 0.8548, recall=0.9279
#   -> no improvement (5/7)
# [ResNet50_RadImageNet][Fold 1][Epoch 13]train loss = 0.0518, acc=0.9902, auc=0.9991,f1 = 0.9778, recall=0.9932 | val loss = 0.7011, acc = 0.9279, auc = 0.9651, f1 = 0.8177, recall=0.7477
#   -> no improvement (6/7)
# [ResNet50_RadImageNet][Fold 1][Epoch 14]train loss = 0.0393, acc=0.9912, auc=0.9995,f1 = 0.9800, recall=0.9910 | val loss = 0.3370, acc = 0.9279, auc = 0.9788, f1 = 0.8490, recall=0.9369
#   -> no improvement (7/7)
#   -> early stopping triggered at epoch 14
#
# --Final Evaluation (threshold=0.5) --
# Accuracy: 0.9435
# ROC-AUC : 0.9812
# F1-score : 0.8734
# Sensitivity : 0.9009
# Confusion Matrix:
# [[384  18]
#  [ 11 100]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0     0.9722    0.9552    0.9636       402
#            1     0.8475    0.9009    0.8734       111
#
#     accuracy                         0.9435       513
#    macro avg     0.9098    0.9281    0.9185       513
# weighted avg     0.9452    0.9435    0.9441       513
#
#
# [ResNet50_RadImageNet][Fold 1] Final Metrics
# Accuracy: 0.9435
# ROC-AUC: 0.9812
# F1-score : 0.8734
# Sensitivity : 0.9009
# Confusion Matrix:
# [[384  18]
#  [ 11 100]]
#
# ================================================================================
# Running ResNet50_RadImageNet | Fold 2 | norm=radimagenet
# ================================================================================
# [FOLD 2] Train benign(0): 1605, malignant(1): 444, pos_weight=3.6149
# [ResNet50_RadImageNet][Fold 2][Epoch 01]train loss = 0.6660, acc=0.8180, auc=0.8891,f1 = 0.6643, recall=0.8311 | val loss = 0.5255, acc = 0.8908, auc = 0.9417, f1 = 0.7607, recall=0.8018
#   -> best saved by val_loss: ct_binary_models_filter_ablation/ResNet50_RadImageNet_fold2_best.pth
# [ResNet50_RadImageNet][Fold 2][Epoch 02]train loss = 0.3599, acc=0.9161, auc=0.9676,f1 = 0.8263, recall=0.9212 | val loss = 0.5567, acc = 0.8967, auc = 0.9419, f1 = 0.7938, recall=0.9189
#   -> no improvement (1/7)
# [ResNet50_RadImageNet][Fold 2][Epoch 03]train loss = 0.2626, acc=0.9322, auc=0.9822,f1 = 0.8586, recall=0.9505 | val loss = 0.5243, acc = 0.8869, auc = 0.9399, f1 = 0.7698, recall=0.8739
#   -> best saved by val_loss: ct_binary_models_filter_ablation/ResNet50_RadImageNet_fold2_best.pth
# [ResNet50_RadImageNet][Fold 2][Epoch 04]train loss = 0.1996, acc=0.9517, auc=0.9898,f1 = 0.8959, recall=0.9595 | val loss = 0.5564, acc = 0.8752, auc = 0.9379, f1 = 0.7519, recall=0.8739
#   -> no improvement (1/7)
# [ResNet50_RadImageNet][Fold 2][Epoch 05]train loss = 0.1209, acc=0.9751, auc=0.9957,f1 = 0.9450, recall=0.9865 | val loss = 0.5738, acc = 0.9084, auc = 0.9524, f1 = 0.8066, recall=0.8829
#   -> no improvement (2/7)
# [ResNet50_RadImageNet][Fold 2][Epoch 06]train loss = 0.1197, acc=0.9751, auc=0.9956,f1 = 0.9444, recall=0.9752 | val loss = 0.5377, acc = 0.9201, auc = 0.9556, f1 = 0.8194, recall=0.8378
#   -> no improvement (3/7)
# [ResNet50_RadImageNet][Fold 2][Epoch 07]train loss = 0.1046, acc=0.9790, auc=0.9966,f1 = 0.9528, recall=0.9775 | val loss = 0.5447, acc = 0.9142, auc = 0.9624, f1 = 0.8018, recall=0.8018
#   -> no improvement (4/7)
# [ResNet50_RadImageNet][Fold 2][Epoch 08]train loss = 0.0707, acc=0.9829, auc=0.9985,f1 = 0.9613, recall=0.9797 | val loss = 0.7725, acc = 0.9025, auc = 0.9389, f1 = 0.7685, recall=0.7477
#   -> no improvement (5/7)
# [ResNet50_RadImageNet][Fold 2][Epoch 09]train loss = 0.0743, acc=0.9849, auc=0.9983,f1 = 0.9657, recall=0.9820 | val loss = 0.6611, acc = 0.9064, auc = 0.9500, f1 = 0.7857, recall=0.7928
#   -> no improvement (6/7)
# [ResNet50_RadImageNet][Fold 2][Epoch 10]train loss = 0.0382, acc=0.9907, auc=0.9995,f1 = 0.9789, recall=0.9932 | val loss = 0.9756, acc = 0.9142, auc = 0.9460, f1 = 0.7885, recall=0.7387
#   -> no improvement (7/7)
#   -> early stopping triggered at epoch 10
#
# --Final Evaluation (threshold=0.5) --
# Accuracy: 0.8869
# ROC-AUC : 0.9399
# F1-score : 0.7698
# Sensitivity : 0.8739
# Confusion Matrix:
# [[358  44]
#  [ 14  97]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0     0.9624    0.8905    0.9251       402
#            1     0.6879    0.8739    0.7698       111
#
#     accuracy                         0.8869       513
#    macro avg     0.8252    0.8822    0.8475       513
# weighted avg     0.9030    0.8869    0.8915       513
#
#
# [ResNet50_RadImageNet][Fold 2] Final Metrics
# Accuracy: 0.8869
# ROC-AUC: 0.9399
# F1-score : 0.7698
# Sensitivity : 0.8739
# Confusion Matrix:
# [[358  44]
#  [ 14  97]]
#
# ================================================================================
# Running ResNet50_RadImageNet | Fold 3 | norm=radimagenet
# ================================================================================
# [FOLD 3] Train benign(0): 1606, malignant(1): 444, pos_weight=3.6171
# [ResNet50_RadImageNet][Fold 3][Epoch 01]train loss = 0.6758, acc=0.8020, auc=0.8869,f1 = 0.6349, recall=0.7950 | val loss = 0.4127, acc = 0.8965, auc = 0.9574, f1 = 0.7888, recall=0.8919
#   -> best saved by val_loss: ct_binary_models_filter_ablation/ResNet50_RadImageNet_fold3_best.pth
# [ResNet50_RadImageNet][Fold 3][Epoch 02]train loss = 0.3638, acc=0.9107, auc=0.9671,f1 = 0.8183, recall=0.9279 | val loss = 0.4302, acc = 0.9141, auc = 0.9620, f1 = 0.8151, recall=0.8739
#   -> no improvement (1/7)
# [ResNet50_RadImageNet][Fold 3][Epoch 03]train loss = 0.2537, acc=0.9376, auc=0.9837,f1 = 0.8697, recall=0.9617 | val loss = 0.5308, acc = 0.8809, auc = 0.9507, f1 = 0.7530, recall=0.8378
#   -> no improvement (2/7)
# [ResNet50_RadImageNet][Fold 3][Epoch 04]train loss = 0.2325, acc=0.9502, auc=0.9854,f1 = 0.8933, recall=0.9617 | val loss = 0.5270, acc = 0.8906, auc = 0.9549, f1 = 0.7760, recall=0.8739
#   -> no improvement (3/7)
# [ResNet50_RadImageNet][Fold 3][Epoch 05]train loss = 0.1231, acc=0.9688, auc=0.9953,f1 = 0.9316, recall=0.9820 | val loss = 0.6886, acc = 0.9238, auc = 0.9489, f1 = 0.8235, recall=0.8198
#   -> no improvement (4/7)
# [ResNet50_RadImageNet][Fold 3][Epoch 06]train loss = 0.1251, acc=0.9751, auc=0.9956,f1 = 0.9443, recall=0.9730 | val loss = 0.5152, acc = 0.9062, auc = 0.9564, f1 = 0.7983, recall=0.8559
#   -> no improvement (5/7)
# [ResNet50_RadImageNet][Fold 3][Epoch 07]train loss = 0.0729, acc=0.9839, auc=0.9983,f1 = 0.9636, recall=0.9842 | val loss = 0.7872, acc = 0.9336, auc = 0.9533, f1 = 0.8455, recall=0.8378
#   -> no improvement (6/7)
# [ResNet50_RadImageNet][Fold 3][Epoch 08]train loss = 0.0640, acc=0.9888, auc=0.9977,f1 = 0.9745, recall=0.9910 | val loss = 0.6675, acc = 0.9141, auc = 0.9541, f1 = 0.8000, recall=0.7928
#   -> no improvement (7/7)
#   -> early stopping triggered at epoch 8
#
# --Final Evaluation (threshold=0.5) --
# Accuracy: 0.8906
# ROC-AUC : 0.9569
# F1-score : 0.7795
# Sensitivity : 0.8919
# Confusion Matrix:
# [[357  44]
#  [ 12  99]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0     0.9675    0.8903    0.9273       401
#            1     0.6923    0.8919    0.7795       111
#
#     accuracy                         0.8906       512
#    macro avg     0.8299    0.8911    0.8534       512
# weighted avg     0.9078    0.8906    0.8952       512
#
#
# [ResNet50_RadImageNet][Fold 3] Final Metrics
# Accuracy: 0.8906
# ROC-AUC: 0.9569
# F1-score : 0.7795
# Sensitivity : 0.8919
# Confusion Matrix:
# [[357  44]
#  [ 12  99]]
#
# ================================================================================
# Running ResNet50_RadImageNet | Fold 4 | norm=radimagenet
# ================================================================================
# [FOLD 4] Train benign(0): 1606, malignant(1): 444, pos_weight=3.6171
# [ResNet50_RadImageNet][Fold 4][Epoch 01]train loss = 0.7230, acc=0.8107, auc=0.8669,f1 = 0.6319, recall=0.7500 | val loss = 0.4783, acc = 0.8652, auc = 0.9447, f1 = 0.7473, recall=0.9189
#   -> best saved by val_loss: ct_binary_models_filter_ablation/ResNet50_RadImageNet_fold4_best.pth
# [ResNet50_RadImageNet][Fold 4][Epoch 02]train loss = 0.4721, acc=0.8722, auc=0.9447,f1 = 0.7514, recall=0.8919 | val loss = 0.4460, acc = 0.8691, auc = 0.9522, f1 = 0.7491, recall=0.9009
#   -> best saved by val_loss: ct_binary_models_filter_ablation/ResNet50_RadImageNet_fold4_best.pth
# [ResNet50_RadImageNet][Fold 4][Epoch 03]train loss = 0.2769, acc=0.9220, auc=0.9809,f1 = 0.8394, recall=0.9414 | val loss = 0.3866, acc = 0.8750, auc = 0.9634, f1 = 0.7612, recall=0.9189
#   -> best saved by val_loss: ct_binary_models_filter_ablation/ResNet50_RadImageNet_fold4_best.pth
# [ResNet50_RadImageNet][Fold 4][Epoch 04]train loss = 0.2518, acc=0.9410, auc=0.9834,f1 = 0.8746, recall=0.9505 | val loss = 0.4981, acc = 0.8945, auc = 0.9496, f1 = 0.7805, recall=0.8649
#   -> no improvement (1/7)
# [ResNet50_RadImageNet][Fold 4][Epoch 05]train loss = 0.1641, acc=0.9537, auc=0.9932,f1 = 0.8995, recall=0.9572 | val loss = 0.4711, acc = 0.8672, auc = 0.9578, f1 = 0.7463, recall=0.9009
#   -> no improvement (2/7)
# [ResNet50_RadImageNet][Fold 4][Epoch 06]train loss = 0.1409, acc=0.9654, auc=0.9947,f1 = 0.9237, recall=0.9685 | val loss = 0.4836, acc = 0.8809, auc = 0.9517, f1 = 0.7715, recall=0.9279
#   -> no improvement (3/7)
# [ResNet50_RadImageNet][Fold 4][Epoch 07]train loss = 0.0866, acc=0.9795, auc=0.9979,f1 = 0.9541, recall=0.9842 | val loss = 0.4466, acc = 0.9160, auc = 0.9684, f1 = 0.8186, recall=0.8739
#   -> no improvement (4/7)
# [ResNet50_RadImageNet][Fold 4][Epoch 08]train loss = 0.0968, acc=0.9795, auc=0.9971,f1 = 0.9541, recall=0.9842 | val loss = 0.4636, acc = 0.9219, auc = 0.9710, f1 = 0.8148, recall=0.7928
#   -> no improvement (5/7)
# [ResNet50_RadImageNet][Fold 4][Epoch 09]train loss = 0.0486, acc=0.9878, auc=0.9993,f1 = 0.9724, recall=0.9910 | val loss = 0.5138, acc = 0.9160, auc = 0.9685, f1 = 0.8106, recall=0.8288
#   -> no improvement (6/7)
# [ResNet50_RadImageNet][Fold 4][Epoch 10]train loss = 0.0414, acc=0.9956, auc=0.9982,f1 = 0.9899, recall=0.9955 | val loss = 0.6398, acc = 0.9160, auc = 0.9703, f1 = 0.7981, recall=0.7658
#   -> no improvement (7/7)
#   -> early stopping triggered at epoch 10
#
# --Final Evaluation (threshold=0.5) --
# Accuracy: 0.8691
# ROC-AUC : 0.9635
# F1-score : 0.7546
# Sensitivity : 0.9279
# Confusion Matrix:
# [[342  59]
#  [  8 103]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0     0.9771    0.8529    0.9108       401
#            1     0.6358    0.9279    0.7546       111
#
#     accuracy                         0.8691       512
#    macro avg     0.8065    0.8904    0.8327       512
# weighted avg     0.9031    0.8691    0.8769       512
#
#
# [ResNet50_RadImageNet][Fold 4] Final Metrics
# Accuracy: 0.8691
# ROC-AUC: 0.9635
# F1-score : 0.7546
# Sensitivity : 0.9279
# Confusion Matrix:
# [[342  59]
#  [  8 103]]
#
# ================================================================================
# Running ResNet50_RadImageNet | Fold 5 | norm=radimagenet
# ================================================================================
# [FOLD 5] Train benign(0): 1606, malignant(1): 444, pos_weight=3.6171
# [ResNet50_RadImageNet][Fold 5][Epoch 01]train loss = 0.7443, acc=0.8161, auc=0.8633,f1 = 0.6241, recall=0.7050 | val loss = 0.5204, acc = 0.8223, auc = 0.9490, f1 = 0.7016, recall=0.9640
#   -> best saved by val_loss: ct_binary_models_filter_ablation/ResNet50_RadImageNet_fold5_best.pth
# [ResNet50_RadImageNet][Fold 5][Epoch 02]train loss = 0.4501, acc=0.8824, auc=0.9510,f1 = 0.7685, recall=0.9009 | val loss = 0.4591, acc = 0.8477, auc = 0.9565, f1 = 0.7254, recall=0.9279
#   -> best saved by val_loss: ct_binary_models_filter_ablation/ResNet50_RadImageNet_fold5_best.pth
# [ResNet50_RadImageNet][Fold 5][Epoch 03]train loss = 0.2838, acc=0.9244, auc=0.9799,f1 = 0.8436, recall=0.9414 | val loss = 0.4853, acc = 0.9023, auc = 0.9554, f1 = 0.7845, recall=0.8198
#   -> no improvement (1/7)
# [ResNet50_RadImageNet][Fold 5][Epoch 04]train loss = 0.2501, acc=0.9439, auc=0.9836,f1 = 0.8806, recall=0.9550 | val loss = 0.4418, acc = 0.8750, auc = 0.9565, f1 = 0.7576, recall=0.9009
#   -> best saved by val_loss: ct_binary_models_filter_ablation/ResNet50_RadImageNet_fold5_best.pth
# [ResNet50_RadImageNet][Fold 5][Epoch 05]train loss = 0.1400, acc=0.9659, auc=0.9944,f1 = 0.9255, recall=0.9797 | val loss = 0.5815, acc = 0.9102, auc = 0.9572, f1 = 0.7982, recall=0.8198
#   -> no improvement (1/7)
# [ResNet50_RadImageNet][Fold 5][Epoch 06]train loss = 0.1311, acc=0.9668, auc=0.9952,f1 = 0.9267, recall=0.9685 | val loss = 0.6158, acc = 0.8770, auc = 0.9442, f1 = 0.7568, recall=0.8829
#   -> no improvement (2/7)
# [ResNet50_RadImageNet][Fold 5][Epoch 07]train loss = 0.1251, acc=0.9683, auc=0.9955,f1 = 0.9308, recall=0.9842 | val loss = 0.4828, acc = 0.9082, auc = 0.9580, f1 = 0.7930, recall=0.8108
#   -> no improvement (3/7)
# [ResNet50_RadImageNet][Fold 5][Epoch 08]train loss = 0.0578, acc=0.9888, auc=0.9991,f1 = 0.9745, recall=0.9910 | val loss = 0.7343, acc = 0.8984, auc = 0.9554, f1 = 0.7851, recall=0.8559
#   -> no improvement (4/7)
# [ResNet50_RadImageNet][Fold 5][Epoch 09]train loss = 0.0791, acc=0.9785, auc=0.9982,f1 = 0.9521, recall=0.9842 | val loss = 0.6020, acc = 0.8926, auc = 0.9536, f1 = 0.7755, recall=0.8559
#   -> no improvement (5/7)
# [ResNet50_RadImageNet][Fold 5][Epoch 10]train loss = 0.0845, acc=0.9795, auc=0.9978,f1 = 0.9543, recall=0.9887 | val loss = 0.6788, acc = 0.9062, auc = 0.9606, f1 = 0.7838, recall=0.7838
#   -> no improvement (6/7)
# [ResNet50_RadImageNet][Fold 5][Epoch 11]train loss = 0.0214, acc=0.9961, auc=0.9998,f1 = 0.9911, recall=0.9977 | val loss = 0.8283, acc = 0.9023, auc = 0.9526, f1 = 0.7727, recall=0.7658
#   -> no improvement (7/7)
#   -> early stopping triggered at epoch 11
#
# --Final Evaluation (threshold=0.5) --
# Accuracy: 0.8770
# ROC-AUC : 0.9561
# F1-score : 0.7605
# Sensitivity : 0.9009
# Confusion Matrix:
# [[349  52]
#  [ 11 100]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0     0.9694    0.8703    0.9172       401
#            1     0.6579    0.9009    0.7605       111
#
#     accuracy                         0.8770       512
#    macro avg     0.8137    0.8856    0.8388       512
# weighted avg     0.9019    0.8770    0.8832       512
#
#
# [ResNet50_RadImageNet][Fold 5] Final Metrics
# Accuracy: 0.8770
# ROC-AUC: 0.9561
# F1-score : 0.7605
# Sensitivity : 0.9009
# Confusion Matrix:
# [[349  52]
#  [ 11 100]]
#                   model  fold       acc   ROC-AUC  F1-score  Sensitivity  \
# 0  ResNet50_RadImageNet     1  0.943470  0.981198  0.873362     0.900901
# 1  ResNet50_RadImageNet     2  0.886940  0.939895  0.769841     0.873874
# 2  ResNet50_RadImageNet     3  0.890625  0.956887  0.779528     0.891892
# 3  ResNet50_RadImageNet     4  0.869141  0.963492  0.754579     0.927928
# 4  ResNet50_RadImageNet     5  0.876953  0.956146  0.760456     0.900901
#
#          Confusion Matrix
# 0  [[384, 18], [11, 100]]
# 1   [[358, 44], [14, 97]]
# 2   [[357, 44], [12, 99]]
# 3   [[342, 59], [8, 103]]
# 4  [[349, 52], [11, 100]]

# %%
print(">>> Training VIT-B/16 (ImageNet)...")
vit_cv_df, vit_history_df = run_cv_for_model(
    model_name="ViT-B16",
    model_type="vit",
    build_fn=lambda: build_vit_patient_model(load_pretrained=True,
                                             freeze_backbone=True,
                                             unfreeze_last_n_blocks=2),
    norm_type="imagenet",
    lr=1e-5
)

display(vit_cv_df)
# Out:
# >>> Training VIT-B/16 (ImageNet)...
#
# ================================================================================
# Running ViT-B16 | Fold 1 | norm=imagenet
# ================================================================================
# [FOLD 1] Train benign(0): 1605, malignant(1): 444, pos_weight=3.6149
# [ViT-B16][Fold 1][Epoch 01]train loss = 0.8338, acc=0.8038, auc=0.8623,f1 = 0.6229, recall=0.7477 | val loss = 0.5224, acc = 0.8986, auc = 0.9639, f1 = 0.7869, recall=0.8649
#   -> best saved by val_loss: ct_binary_models_filter_ablation/ViT-B16_fold1_best.pth
# [ViT-B16][Fold 1][Epoch 02]train loss = 0.5187, acc=0.8765, auc=0.9353,f1 = 0.7502, recall=0.8559 | val loss = 0.3690, acc = 0.9045, auc = 0.9749, f1 = 0.8032, recall=0.9009
#   -> best saved by val_loss: ct_binary_models_filter_ablation/ViT-B16_fold1_best.pth
# [ViT-B16][Fold 1][Epoch 03]train loss = 0.4449, acc=0.8858, auc=0.9515,f1 = 0.7692, recall=0.8784 | val loss = 0.3345, acc = 0.9162, auc = 0.9779, f1 = 0.8245, recall=0.9099
#   -> best saved by val_loss: ct_binary_models_filter_ablation/ViT-B16_fold1_best.pth
# [ViT-B16][Fold 1][Epoch 04]train loss = 0.3700, acc=0.9102, auc=0.9647,f1 = 0.8156, recall=0.9167 | val loss = 0.2997, acc = 0.9337, auc = 0.9799, f1 = 0.8607, recall=0.9459
#   -> best saved by val_loss: ct_binary_models_filter_ablation/ViT-B16_fold1_best.pth
# [ViT-B16][Fold 1][Epoch 05]train loss = 0.3231, acc=0.9273, auc=0.9738,f1 = 0.8475, recall=0.9324 | val loss = 0.2909, acc = 0.9142, auc = 0.9828, f1 = 0.8295, recall=0.9640
#   -> best saved by val_loss: ct_binary_models_filter_ablation/ViT-B16_fold1_best.pth
# [ViT-B16][Fold 1][Epoch 06]train loss = 0.2627, acc=0.9375, auc=0.9826,f1 = 0.8686, recall=0.9527 | val loss = 0.2736, acc = 0.9279, auc = 0.9815, f1 = 0.8502, recall=0.9459
#   -> best saved by val_loss: ct_binary_models_filter_ablation/ViT-B16_fold1_best.pth
# [ViT-B16][Fold 1][Epoch 07]train loss = 0.2122, acc=0.9478, auc=0.9884,f1 = 0.8882, recall=0.9572 | val loss = 0.2816, acc = 0.9298, auc = 0.9806, f1 = 0.8548, recall=0.9550
#   -> no improvement (1/7)
# [ViT-B16][Fold 1][Epoch 08]train loss = 0.1589, acc=0.9624, auc=0.9928,f1 = 0.9182, recall=0.9730 | val loss = 0.3104, acc = 0.9415, auc = 0.9794, f1 = 0.8696, recall=0.9009
#   -> no improvement (2/7)
# [ViT-B16][Fold 1][Epoch 09]train loss = 0.1226, acc=0.9702, auc=0.9959,f1 = 0.9345, recall=0.9797 | val loss = 0.3411, acc = 0.9064, auc = 0.9743, f1 = 0.8154, recall=0.9550
#   -> no improvement (3/7)
# [ViT-B16][Fold 1][Epoch 10]train loss = 0.0800, acc=0.9844, auc=0.9982,f1 = 0.9651, recall=0.9955 | val loss = 0.3215, acc = 0.9474, auc = 0.9781, f1 = 0.8811, recall=0.9009
#   -> no improvement (4/7)
# [ViT-B16][Fold 1][Epoch 11]train loss = 0.0621, acc=0.9883, auc=0.9983,f1 = 0.9736, recall=0.9955 | val loss = 0.6894, acc = 0.9318, auc = 0.9704, f1 = 0.8223, recall=0.7297
#   -> no improvement (5/7)
# [ViT-B16][Fold 1][Epoch 12]train loss = 0.0366, acc=0.9951, auc=0.9995,f1 = 0.9888, recall=0.9977 | val loss = 0.4291, acc = 0.9454, auc = 0.9766, f1 = 0.8704, recall=0.8468
#   -> no improvement (6/7)
# [ViT-B16][Fold 1][Epoch 13]train loss = 0.0245, acc=0.9976, auc=0.9998,f1 = 0.9944, recall=0.9977 | val loss = 0.4414, acc = 0.9454, auc = 0.9740, f1 = 0.8716, recall=0.8559
#   -> no improvement (7/7)
#   -> early stopping triggered at epoch 13
#
# --Final Evaluation (threshold=0.5) --
# Accuracy: 0.9298
# ROC-AUC : 0.9815
# F1-score : 0.8548
# Sensitivity : 0.9550
# Confusion Matrix:
# [[371  31]
#  [  5 106]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0     0.9867    0.9229    0.9537       402
#            1     0.7737    0.9550    0.8548       111
#
#     accuracy                         0.9298       513
#    macro avg     0.8802    0.9389    0.9043       513
# weighted avg     0.9406    0.9298    0.9323       513
#
#
# [ViT-B16][Fold 1] Final Metrics
# Accuracy: 0.9298
# ROC-AUC: 0.9815
# F1-score : 0.8548
# Sensitivity : 0.9550
# Confusion Matrix:
# [[371  31]
#  [  5 106]]
#
# ================================================================================
# Running ViT-B16 | Fold 2 | norm=imagenet
# ================================================================================
# [FOLD 2] Train benign(0): 1605, malignant(1): 444, pos_weight=3.6149
# [ViT-B16][Fold 2][Epoch 01]train loss = 0.8098, acc=0.7755, auc=0.8642,f1 = 0.6141, recall=0.8243 | val loss = 0.5826, acc = 0.8382, auc = 0.9258, f1 = 0.7046, recall=0.8919
#   -> best saved by val_loss: ct_binary_models_filter_ablation/ViT-B16_fold2_best.pth
# [ViT-B16][Fold 2][Epoch 02]train loss = 0.4803, acc=0.8795, auc=0.9441,f1 = 0.7604, recall=0.8829 | val loss = 0.5079, acc = 0.8772, auc = 0.9375, f1 = 0.7529, recall=0.8649
#   -> best saved by val_loss: ct_binary_models_filter_ablation/ViT-B16_fold2_best.pth
# [ViT-B16][Fold 2][Epoch 03]train loss = 0.3969, acc=0.9122, auc=0.9601,f1 = 0.8167, recall=0.9032 | val loss = 0.4974, acc = 0.8791, auc = 0.9416, f1 = 0.7520, recall=0.8468
#   -> best saved by val_loss: ct_binary_models_filter_ablation/ViT-B16_fold2_best.pth
# [ViT-B16][Fold 2][Epoch 04]train loss = 0.3425, acc=0.9156, auc=0.9688,f1 = 0.8244, recall=0.9144 | val loss = 0.4641, acc = 0.8791, auc = 0.9481, f1 = 0.7597, recall=0.8829
#   -> best saved by val_loss: ct_binary_models_filter_ablation/ViT-B16_fold2_best.pth
# [ViT-B16][Fold 2][Epoch 05]train loss = 0.2979, acc=0.9297, auc=0.9764,f1 = 0.8522, recall=0.9347 | val loss = 0.4634, acc = 0.8967, auc = 0.9507, f1 = 0.7801, recall=0.8468
#   -> no improvement (1/7)
# [ViT-B16][Fold 2][Epoch 06]train loss = 0.2391, acc=0.9507, auc=0.9839,f1 = 0.8938, recall=0.9572 | val loss = 0.4706, acc = 0.8655, auc = 0.9542, f1 = 0.7491, recall=0.9279
#   -> no improvement (2/7)
# [ViT-B16][Fold 2][Epoch 07]train loss = 0.2067, acc=0.9551, auc=0.9869,f1 = 0.9030, recall=0.9640 | val loss = 0.5224, acc = 0.9064, auc = 0.9524, f1 = 0.7895, recall=0.8108
#   -> no improvement (3/7)
# [ViT-B16][Fold 2][Epoch 08]train loss = 0.1583, acc=0.9663, auc=0.9929,f1 = 0.9257, recall=0.9685 | val loss = 0.4741, acc = 0.8908, auc = 0.9544, f1 = 0.7795, recall=0.8919
#   -> no improvement (4/7)
# [ViT-B16][Fold 2][Epoch 09]train loss = 0.1192, acc=0.9746, auc=0.9961,f1 = 0.9438, recall=0.9842 | val loss = 0.5966, acc = 0.9142, auc = 0.9579, f1 = 0.8036, recall=0.8108
#   -> no improvement (5/7)
# [ViT-B16][Fold 2][Epoch 10]train loss = 0.0772, acc=0.9878, auc=0.9978,f1 = 0.9724, recall=0.9932 | val loss = 0.5629, acc = 0.9064, auc = 0.9553, f1 = 0.7931, recall=0.8288
#   -> no improvement (6/7)
# [ViT-B16][Fold 2][Epoch 11]train loss = 0.0602, acc=0.9868, auc=0.9986,f1 = 0.9703, recall=0.9932 | val loss = 0.6565, acc = 0.9084, auc = 0.9548, f1 = 0.7892, recall=0.7928
#   -> no improvement (7/7)
#   -> early stopping triggered at epoch 11
#
# --Final Evaluation (threshold=0.5) --
# Accuracy: 0.8791
# ROC-AUC : 0.9481
# F1-score : 0.7597
# Sensitivity : 0.8829
# Confusion Matrix:
# [[353  49]
#  [ 13  98]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0     0.9645    0.8781    0.9193       402
#            1     0.6667    0.8829    0.7597       111
#
#     accuracy                         0.8791       513
#    macro avg     0.8156    0.8805    0.8395       513
# weighted avg     0.9000    0.8791    0.8847       513
#
#
# [ViT-B16][Fold 2] Final Metrics
# Accuracy: 0.8791
# ROC-AUC: 0.9481
# F1-score : 0.7597
# Sensitivity : 0.8829
# Confusion Matrix:
# [[353  49]
#  [ 13  98]]
#
# ================================================================================
# Running ViT-B16 | Fold 3 | norm=imagenet
# ================================================================================
# [FOLD 3] Train benign(0): 1606, malignant(1): 444, pos_weight=3.6171
# [ViT-B16][Fold 3][Epoch 01]train loss = 0.7955, acc=0.7751, auc=0.8844,f1 = 0.6142, recall=0.8266 | val loss = 0.5099, acc = 0.8945, auc = 0.9457, f1 = 0.7787, recall=0.8559
#   -> best saved by val_loss: ct_binary_models_filter_ablation/ViT-B16_fold3_best.pth
# [ViT-B16][Fold 3][Epoch 02]train loss = 0.5013, acc=0.8717, auc=0.9396,f1 = 0.7474, recall=0.8761 | val loss = 0.4406, acc = 0.9043, auc = 0.9531, f1 = 0.7984, recall=0.8739
#   -> best saved by val_loss: ct_binary_models_filter_ablation/ViT-B16_fold3_best.pth
# [ViT-B16][Fold 3][Epoch 03]train loss = 0.4296, acc=0.8932, auc=0.9537,f1 = 0.7838, recall=0.8941 | val loss = 0.4114, acc = 0.9121, auc = 0.9589, f1 = 0.8148, recall=0.8919
#   -> best saved by val_loss: ct_binary_models_filter_ablation/ViT-B16_fold3_best.pth
# [ViT-B16][Fold 3][Epoch 04]train loss = 0.3739, acc=0.9078, auc=0.9643,f1 = 0.8119, recall=0.9189 | val loss = 0.4073, acc = 0.9238, auc = 0.9615, f1 = 0.8340, recall=0.8829
#   -> best saved by val_loss: ct_binary_models_filter_ablation/ViT-B16_fold3_best.pth
# [ViT-B16][Fold 3][Epoch 05]train loss = 0.3220, acc=0.9263, auc=0.9743,f1 = 0.8445, recall=0.9234 | val loss = 0.4571, acc = 0.8535, auc = 0.9607, f1 = 0.7350, recall=0.9369
#   -> no improvement (1/7)
# [ViT-B16][Fold 3][Epoch 06]train loss = 0.2738, acc=0.9366, auc=0.9801,f1 = 0.8654, recall=0.9414 | val loss = 0.3693, acc = 0.9102, auc = 0.9670, f1 = 0.8115, recall=0.8919
#   -> best saved by val_loss: ct_binary_models_filter_ablation/ViT-B16_fold3_best.pth
# [ViT-B16][Fold 3][Epoch 07]train loss = 0.2374, acc=0.9439, auc=0.9857,f1 = 0.8808, recall=0.9572 | val loss = 0.3856, acc = 0.9297, auc = 0.9681, f1 = 0.8435, recall=0.8739
#   -> no improvement (1/7)
# [ViT-B16][Fold 3][Epoch 08]train loss = 0.1808, acc=0.9580, auc=0.9913,f1 = 0.9093, recall=0.9707 | val loss = 0.3765, acc = 0.9336, auc = 0.9700, f1 = 0.8534, recall=0.8919
#   -> no improvement (2/7)
# [ViT-B16][Fold 3][Epoch 09]train loss = 0.1322, acc=0.9722, auc=0.9950,f1 = 0.9386, recall=0.9820 | val loss = 0.3556, acc = 0.9160, auc = 0.9714, f1 = 0.8245, recall=0.9099
#   -> best saved by val_loss: ct_binary_models_filter_ablation/ViT-B16_fold3_best.pth
# [ViT-B16][Fold 3][Epoch 10]train loss = 0.1016, acc=0.9795, auc=0.9972,f1 = 0.9542, recall=0.9865 | val loss = 0.4051, acc = 0.9121, auc = 0.9708, f1 = 0.8148, recall=0.8919
#   -> no improvement (1/7)
# [ViT-B16][Fold 3][Epoch 11]train loss = 0.0634, acc=0.9883, auc=0.9985,f1 = 0.9736, recall=0.9955 | val loss = 0.4982, acc = 0.9414, auc = 0.9693, f1 = 0.8611, recall=0.8378
#   -> no improvement (2/7)
# [ViT-B16][Fold 3][Epoch 12]train loss = 0.0535, acc=0.9902, auc=0.9989,f1 = 0.9778, recall=0.9932 | val loss = 0.5465, acc = 0.9414, auc = 0.9690, f1 = 0.8611, recall=0.8378
#   -> no improvement (3/7)
# [ViT-B16][Fold 3][Epoch 13]train loss = 0.0388, acc=0.9937, auc=0.9991,f1 = 0.9855, recall=0.9977 | val loss = 0.6048, acc = 0.9434, auc = 0.9680, f1 = 0.8651, recall=0.8378
#   -> no improvement (4/7)
# [ViT-B16][Fold 3][Epoch 14]train loss = 0.0588, acc=0.9873, auc=0.9990,f1 = 0.9712, recall=0.9865 | val loss = 0.6292, acc = 0.9355, auc = 0.9589, f1 = 0.8451, recall=0.8108
#   -> no improvement (5/7)
# [ViT-B16][Fold 3][Epoch 15]train loss = 0.0421, acc=0.9902, auc=0.9996,f1 = 0.9779, recall=0.9955 | val loss = 0.6276, acc = 0.9395, auc = 0.9646, f1 = 0.8571, recall=0.8378
#   -> no improvement (6/7)
# [ViT-B16][Fold 3][Epoch 16]train loss = 0.0187, acc=0.9976, auc=0.9999,f1 = 0.9944, recall=1.0000 | val loss = 0.6336, acc = 0.9395, auc = 0.9643, f1 = 0.8571, recall=0.8378
#   -> no improvement (7/7)
#   -> early stopping triggered at epoch 16
#
# --Final Evaluation (threshold=0.5) --
# Accuracy: 0.9160
# ROC-AUC : 0.9713
# F1-score : 0.8245
# Sensitivity : 0.9099
# Confusion Matrix:
# [[368  33]
#  [ 10 101]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0     0.9735    0.9177    0.9448       401
#            1     0.7537    0.9099    0.8245       111
#
#     accuracy                         0.9160       512
#    macro avg     0.8636    0.9138    0.8846       512
# weighted avg     0.9259    0.9160    0.9187       512
#
#
# [ViT-B16][Fold 3] Final Metrics
# Accuracy: 0.9160
# ROC-AUC: 0.9713
# F1-score : 0.8245
# Sensitivity : 0.9099
# Confusion Matrix:
# [[368  33]
#  [ 10 101]]
#
# ================================================================================
# Running ViT-B16 | Fold 4 | norm=imagenet
# ================================================================================
# [FOLD 4] Train benign(0): 1606, malignant(1): 444, pos_weight=3.6171
# [ViT-B16][Fold 4][Epoch 01]train loss = 0.8409, acc=0.7498, auc=0.8479,f1 = 0.5736, recall=0.7770 | val loss = 0.6531, acc = 0.8906, auc = 0.9151, f1 = 0.7407, recall=0.7207
#   -> best saved by val_loss: ct_binary_models_filter_ablation/ViT-B16_fold4_best.pth
# [ViT-B16][Fold 4][Epoch 02]train loss = 0.4830, acc=0.8854, auc=0.9443,f1 = 0.7703, recall=0.8874 | val loss = 0.5259, acc = 0.8574, auc = 0.9305, f1 = 0.7266, recall=0.8739
#   -> best saved by val_loss: ct_binary_models_filter_ablation/ViT-B16_fold4_best.pth
# [ViT-B16][Fold 4][Epoch 03]train loss = 0.4083, acc=0.9015, auc=0.9584,f1 = 0.7988, recall=0.9032 | val loss = 0.4994, acc = 0.8672, auc = 0.9370, f1 = 0.7444, recall=0.8919
#   -> best saved by val_loss: ct_binary_models_filter_ablation/ViT-B16_fold4_best.pth
# [ViT-B16][Fold 4][Epoch 04]train loss = 0.3413, acc=0.9166, auc=0.9719,f1 = 0.8267, recall=0.9189 | val loss = 0.4851, acc = 0.8770, auc = 0.9424, f1 = 0.7586, recall=0.8919
#   -> best saved by val_loss: ct_binary_models_filter_ablation/ViT-B16_fold4_best.pth
# [ViT-B16][Fold 4][Epoch 05]train loss = 0.2903, acc=0.9298, auc=0.9797,f1 = 0.8522, recall=0.9347 | val loss = 0.4943, acc = 0.9062, auc = 0.9465, f1 = 0.7913, recall=0.8198
#   -> no improvement (1/7)
# [ViT-B16][Fold 4][Epoch 06]train loss = 0.2408, acc=0.9449, auc=0.9852,f1 = 0.8831, recall=0.9617 | val loss = 0.5011, acc = 0.9121, auc = 0.9472, f1 = 0.8035, recall=0.8288
#   -> no improvement (2/7)
# [ViT-B16][Fold 4][Epoch 07]train loss = 0.1857, acc=0.9576, auc=0.9916,f1 = 0.9085, recall=0.9730 | val loss = 0.5194, acc = 0.9121, auc = 0.9521, f1 = 0.8018, recall=0.8198
#   -> no improvement (3/7)
# [ViT-B16][Fold 4][Epoch 08]train loss = 0.1500, acc=0.9663, auc=0.9937,f1 = 0.9265, recall=0.9797 | val loss = 0.6837, acc = 0.9160, auc = 0.9510, f1 = 0.7902, recall=0.7297
#   -> no improvement (4/7)
# [ViT-B16][Fold 4][Epoch 09]train loss = 0.1038, acc=0.9776, auc=0.9972,f1 = 0.9501, recall=0.9865 | val loss = 0.5753, acc = 0.9102, auc = 0.9534, f1 = 0.7965, recall=0.8108
#   -> no improvement (5/7)
# [ViT-B16][Fold 4][Epoch 10]train loss = 0.0876, acc=0.9790, auc=0.9978,f1 = 0.9534, recall=0.9910 | val loss = 0.5809, acc = 0.8887, auc = 0.9442, f1 = 0.7692, recall=0.8559
#   -> no improvement (6/7)
# [ViT-B16][Fold 4][Epoch 11]train loss = 0.0536, acc=0.9902, auc=0.9990,f1 = 0.9779, recall=0.9955 | val loss = 0.7260, acc = 0.9238, auc = 0.9531, f1 = 0.8169, recall=0.7838
#   -> no improvement (7/7)
#   -> early stopping triggered at epoch 11
#
# --Final Evaluation (threshold=0.5) --
# Accuracy: 0.8770
# ROC-AUC : 0.9424
# F1-score : 0.7586
# Sensitivity : 0.8919
# Confusion Matrix:
# [[350  51]
#  [ 12  99]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0     0.9669    0.8728    0.9174       401
#            1     0.6600    0.8919    0.7586       111
#
#     accuracy                         0.8770       512
#    macro avg     0.8134    0.8824    0.8380       512
# weighted avg     0.9003    0.8770    0.8830       512
#
#
# [ViT-B16][Fold 4] Final Metrics
# Accuracy: 0.8770
# ROC-AUC: 0.9424
# F1-score : 0.7586
# Sensitivity : 0.8919
# Confusion Matrix:
# [[350  51]
#  [ 12  99]]
#
# ================================================================================
# Running ViT-B16 | Fold 5 | norm=imagenet
# ================================================================================
# [FOLD 5] Train benign(0): 1606, malignant(1): 444, pos_weight=3.6171
# [ViT-B16][Fold 5][Epoch 01]train loss = 0.8464, acc=0.7698, auc=0.8421,f1 = 0.5755, recall=0.7207 | val loss = 0.5907, acc = 0.8418, auc = 0.9293, f1 = 0.7097, recall=0.8919
#   -> best saved by val_loss: ct_binary_models_filter_ablation/ViT-B16_fold5_best.pth
# [ViT-B16][Fold 5][Epoch 02]train loss = 0.5005, acc=0.8859, auc=0.9392,f1 = 0.7688, recall=0.8761 | val loss = 0.5036, acc = 0.8711, auc = 0.9363, f1 = 0.7462, recall=0.8739
#   -> best saved by val_loss: ct_binary_models_filter_ablation/ViT-B16_fold5_best.pth
# [ViT-B16][Fold 5][Epoch 03]train loss = 0.4215, acc=0.8966, auc=0.9554,f1 = 0.7897, recall=0.8964 | val loss = 0.4861, acc = 0.8965, auc = 0.9412, f1 = 0.7819, recall=0.8559
#   -> best saved by val_loss: ct_binary_models_filter_ablation/ViT-B16_fold5_best.pth
# [ViT-B16][Fold 5][Epoch 04]train loss = 0.3564, acc=0.9146, auc=0.9688,f1 = 0.8231, recall=0.9167 | val loss = 0.4908, acc = 0.8516, auc = 0.9487, f1 = 0.7361, recall=0.9550
#   -> no improvement (1/7)
# [ViT-B16][Fold 5][Epoch 05]train loss = 0.3063, acc=0.9307, auc=0.9756,f1 = 0.8533, recall=0.9302 | val loss = 0.4433, acc = 0.8906, auc = 0.9517, f1 = 0.7760, recall=0.8739
#   -> best saved by val_loss: ct_binary_models_filter_ablation/ViT-B16_fold5_best.pth
# [ViT-B16][Fold 5][Epoch 06]train loss = 0.2684, acc=0.9410, auc=0.9808,f1 = 0.8746, recall=0.9505 | val loss = 0.4443, acc = 0.8906, auc = 0.9507, f1 = 0.7795, recall=0.8919
#   -> no improvement (1/7)
# [ViT-B16][Fold 5][Epoch 07]train loss = 0.2344, acc=0.9507, auc=0.9858,f1 = 0.8920, recall=0.9392 | val loss = 0.4755, acc = 0.8965, auc = 0.9499, f1 = 0.7819, recall=0.8559
#   -> no improvement (2/7)
# [ViT-B16][Fold 5][Epoch 08]train loss = 0.1738, acc=0.9639, auc=0.9908,f1 = 0.9204, recall=0.9640 | val loss = 0.4957, acc = 0.8945, auc = 0.9508, f1 = 0.7805, recall=0.8649
#   -> no improvement (3/7)
# [ViT-B16][Fold 5][Epoch 09]train loss = 0.1421, acc=0.9717, auc=0.9931,f1 = 0.9372, recall=0.9752 | val loss = 0.6131, acc = 0.9102, auc = 0.9483, f1 = 0.7928, recall=0.7928
#   -> no improvement (4/7)
# [ViT-B16][Fold 5][Epoch 10]train loss = 0.1080, acc=0.9815, auc=0.9963,f1 = 0.9582, recall=0.9820 | val loss = 0.5300, acc = 0.9043, auc = 0.9492, f1 = 0.7950, recall=0.8559
#   -> no improvement (5/7)
# [ViT-B16][Fold 5][Epoch 11]train loss = 0.0750, acc=0.9834, auc=0.9977,f1 = 0.9626, recall=0.9865 | val loss = 0.6128, acc = 0.9082, auc = 0.9484, f1 = 0.7948, recall=0.8198
#   -> no improvement (6/7)
# [ViT-B16][Fold 5][Epoch 12]train loss = 0.0631, acc=0.9888, auc=0.9982,f1 = 0.9746, recall=0.9932 | val loss = 0.9227, acc = 0.9102, auc = 0.9467, f1 = 0.7767, recall=0.7207
#   -> no improvement (7/7)
#   -> early stopping triggered at epoch 12
#
# --Final Evaluation (threshold=0.5) --
# Accuracy: 0.8906
# ROC-AUC : 0.9517
# F1-score : 0.7760
# Sensitivity : 0.8739
# Confusion Matrix:
# [[359  42]
#  [ 14  97]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0     0.9625    0.8953    0.9276       401
#            1     0.6978    0.8739    0.7760       111
#
#     accuracy                         0.8906       512
#    macro avg     0.8302    0.8846    0.8518       512
# weighted avg     0.9051    0.8906    0.8948       512
#
#
# [ViT-B16][Fold 5] Final Metrics
# Accuracy: 0.8906
# ROC-AUC: 0.9517
# F1-score : 0.7760
# Sensitivity : 0.8739
# Confusion Matrix:
# [[359  42]
#  [ 14  97]]
#      model  fold       acc   ROC-AUC  F1-score  Sensitivity  \
# 0  ViT-B16     1  0.929825  0.981511  0.854839     0.954955
# 1  ViT-B16     2  0.879142  0.948142  0.759690     0.882883
# 2  ViT-B16     3  0.916016  0.971333  0.824490     0.909910
# 3  ViT-B16     4  0.876953  0.942396  0.758621     0.891892
# 4  ViT-B16     5  0.890625  0.951652  0.776000     0.873874
#
#          Confusion Matrix
# 0   [[371, 31], [5, 106]]
# 1   [[353, 49], [13, 98]]
# 2  [[368, 33], [10, 101]]
# 3   [[350, 51], [12, 99]]
# 4   [[359, 42], [14, 97]]

# %%
print(">>> Training Hybrid (ResNet18+ViT)... ")
hybrid_r18_cv_df, hybrid_r18_history_df = run_cv_for_model(
    model_name="Hybrid_R18",
    model_type="hybrid_r18",
    build_fn=lambda: build_hybrid_r18_patient_model(load_pretrained=True),
    norm_type="imagenet"
)

display(hybrid_r18_cv_df)
# Out:
# >>> Training Hybrid (ResNet18+ViT)...
#
# ================================================================================
# Running Hybrid_R18 | Fold 1 | norm=imagenet
# ================================================================================
# [FOLD 1] Train benign(0): 1605, malignant(1): 444, pos_weight=3.6149
# [Hybrid_R18][Fold 1][Epoch 01]train loss = 0.6520, acc=0.8111, auc=0.8927,f1 = 0.6491, recall=0.8063 | val loss = 0.3457, acc = 0.9201, auc = 0.9767, f1 = 0.8353, recall=0.9369
#   -> best saved by val_loss: ct_binary_models_filter_ablation/Hybrid_R18_fold1_best.pth
# [Hybrid_R18][Fold 1][Epoch 02]train loss = 0.4628, acc=0.8770, auc=0.9449,f1 = 0.7568, recall=0.8829 | val loss = 0.3939, acc = 0.9298, auc = 0.9699, f1 = 0.8500, recall=0.9189
#   -> no improvement (1/7)
# [Hybrid_R18][Fold 1][Epoch 03]train loss = 0.3858, acc=0.9048, auc=0.9610,f1 = 0.8064, recall=0.9144 | val loss = 0.3755, acc = 0.8441, auc = 0.9770, f1 = 0.7297, recall=0.9730
#   -> no improvement (2/7)
# [Hybrid_R18][Fold 1][Epoch 04]train loss = 0.3634, acc=0.9112, auc=0.9669,f1 = 0.8187, recall=0.9257 | val loss = 0.3574, acc = 0.9201, auc = 0.9752, f1 = 0.8340, recall=0.9279
#   -> no improvement (3/7)
# [Hybrid_R18][Fold 1][Epoch 05]train loss = 0.2984, acc=0.9253, auc=0.9754,f1 = 0.8440, recall=0.9324 | val loss = 0.2847, acc = 0.9279, auc = 0.9814, f1 = 0.8465, recall=0.9189
#   -> best saved by val_loss: ct_binary_models_filter_ablation/Hybrid_R18_fold1_best.pth
# [Hybrid_R18][Fold 1][Epoch 06]train loss = 0.1832, acc=0.9610, auc=0.9896,f1 = 0.9138, recall=0.9550 | val loss = 0.3114, acc = 0.9415, auc = 0.9821, f1 = 0.8696, recall=0.9009
#   -> no improvement (1/7)
# [Hybrid_R18][Fold 1][Epoch 07]train loss = 0.1540, acc=0.9614, auc=0.9936,f1 = 0.9155, recall=0.9640 | val loss = 0.5638, acc = 0.9415, auc = 0.9805, f1 = 0.8624, recall=0.8468
#   -> no improvement (2/7)
# [Hybrid_R18][Fold 1][Epoch 08]train loss = 0.1970, acc=0.9492, auc=0.9903,f1 = 0.8903, recall=0.9505 | val loss = 0.3679, acc = 0.9064, auc = 0.9738, f1 = 0.8168, recall=0.9640
#   -> no improvement (3/7)
# [Hybrid_R18][Fold 1][Epoch 09]train loss = 0.0968, acc=0.9776, auc=0.9973,f1 = 0.9493, recall=0.9707 | val loss = 0.5653, acc = 0.9201, auc = 0.9657, f1 = 0.8340, recall=0.9279
#   -> no improvement (4/7)
# [Hybrid_R18][Fold 1][Epoch 10]train loss = 0.1270, acc=0.9688, auc=0.9960,f1 = 0.9306, recall=0.9662 | val loss = 0.3963, acc = 0.9084, auc = 0.9751, f1 = 0.8171, recall=0.9459
#   -> no improvement (5/7)
# [Hybrid_R18][Fold 1][Epoch 11]train loss = 0.0896, acc=0.9771, auc=0.9967,f1 = 0.9489, recall=0.9820 | val loss = 0.4846, acc = 0.9259, auc = 0.9665, f1 = 0.8319, recall=0.8468
#   -> no improvement (6/7)
# [Hybrid_R18][Fold 1][Epoch 12]train loss = 0.1103, acc=0.9776, auc=0.9968,f1 = 0.9493, recall=0.9707 | val loss = 0.4616, acc = 0.9181, auc = 0.9734, f1 = 0.8279, recall=0.9099
#   -> no improvement (7/7)
#   -> early stopping triggered at epoch 12
#
# --Final Evaluation (threshold=0.5) --
# Accuracy: 0.9279
# ROC-AUC : 0.9815
# F1-score : 0.8465
# Sensitivity : 0.9189
# Confusion Matrix:
# [[374  28]
#  [  9 102]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0     0.9765    0.9303    0.9529       402
#            1     0.7846    0.9189    0.8465       111
#
#     accuracy                         0.9279       513
#    macro avg     0.8806    0.9246    0.8997       513
# weighted avg     0.9350    0.9279    0.9298       513
#
#
# [Hybrid_R18][Fold 1] Final Metrics
# Accuracy: 0.9279
# ROC-AUC: 0.9815
# F1-score : 0.8465
# Sensitivity : 0.9189
# Confusion Matrix:
# [[374  28]
#  [  9 102]]
#
# ================================================================================
# Running Hybrid_R18 | Fold 2 | norm=imagenet
# ================================================================================
# [FOLD 2] Train benign(0): 1605, malignant(1): 444, pos_weight=3.6149
# [Hybrid_R18][Fold 2][Epoch 01]train loss = 0.6181, acc=0.8316, auc=0.9036,f1 = 0.6809, recall=0.8288 | val loss = 0.5818, acc = 0.8967, auc = 0.9396, f1 = 0.7686, recall=0.7928
#   -> best saved by val_loss: ct_binary_models_filter_ablation/Hybrid_R18_fold2_best.pth
# [Hybrid_R18][Fold 2][Epoch 02]train loss = 0.4314, acc=0.8887, auc=0.9526,f1 = 0.7765, recall=0.8919 | val loss = 0.8974, acc = 0.6647, auc = 0.9339, f1 = 0.5590, recall=0.9820
#   -> no improvement (1/7)
# [Hybrid_R18][Fold 2][Epoch 03]train loss = 0.3686, acc=0.8970, auc=0.9640,f1 = 0.7921, recall=0.9054 | val loss = 0.6920, acc = 0.7778, auc = 0.9520, f1 = 0.6503, recall=0.9550
#   -> no improvement (2/7)
# [Hybrid_R18][Fold 2][Epoch 04]train loss = 0.2811, acc=0.9346, auc=0.9778,f1 = 0.8619, recall=0.9414 | val loss = 0.8111, acc = 0.9064, auc = 0.9432, f1 = 0.7692, recall=0.7207
#   -> no improvement (3/7)
# [Hybrid_R18][Fold 2][Epoch 05]train loss = 0.2017, acc=0.9541, auc=0.9864,f1 = 0.9004, recall=0.9572 | val loss = 0.7218, acc = 0.8830, auc = 0.9325, f1 = 0.7479, recall=0.8018
#   -> no improvement (4/7)
# [Hybrid_R18][Fold 2][Epoch 06]train loss = 0.2100, acc=0.9488, auc=0.9879,f1 = 0.8896, recall=0.9527 | val loss = 0.7395, acc = 0.8908, auc = 0.9408, f1 = 0.7627, recall=0.8108
#   -> no improvement (5/7)
# [Hybrid_R18][Fold 2][Epoch 07]train loss = 0.1645, acc=0.9658, auc=0.9908,f1 = 0.9246, recall=0.9662 | val loss = 0.8286, acc = 0.9123, auc = 0.9018, f1 = 0.7907, recall=0.7658
#   -> no improvement (6/7)
# [Hybrid_R18][Fold 2][Epoch 08]train loss = 0.1836, acc=0.9619, auc=0.9891,f1 = 0.9159, recall=0.9572 | val loss = 0.6744, acc = 0.8655, auc = 0.9108, f1 = 0.7273, recall=0.8288
#   -> no improvement (7/7)
#   -> early stopping triggered at epoch 8
#
# --Final Evaluation (threshold=0.5) --
# Accuracy: 0.8967
# ROC-AUC : 0.9397
# F1-score : 0.7686
# Sensitivity : 0.7928
# Confusion Matrix:
# [[372  30]
#  [ 23  88]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0     0.9418    0.9254    0.9335       402
#            1     0.7458    0.7928    0.7686       111
#
#     accuracy                         0.8967       513
#    macro avg     0.8438    0.8591    0.8510       513
# weighted avg     0.8994    0.8967    0.8978       513
#
#
# [Hybrid_R18][Fold 2] Final Metrics
# Accuracy: 0.8967
# ROC-AUC: 0.9397
# F1-score : 0.7686
# Sensitivity : 0.7928
# Confusion Matrix:
# [[372  30]
#  [ 23  88]]
#
# ================================================================================
# Running Hybrid_R18 | Fold 3 | norm=imagenet
# ================================================================================
# [FOLD 3] Train benign(0): 1606, malignant(1): 444, pos_weight=3.6171
# [Hybrid_R18][Fold 3][Epoch 01]train loss = 0.6580, acc=0.8141, auc=0.8901,f1 = 0.6577, recall=0.8243 | val loss = 0.3994, acc = 0.8965, auc = 0.9650, f1 = 0.7954, recall=0.9279
#   -> best saved by val_loss: ct_binary_models_filter_ablation/Hybrid_R18_fold3_best.pth
# [Hybrid_R18][Fold 3][Epoch 02]train loss = 0.4314, acc=0.8898, auc=0.9521,f1 = 0.7776, recall=0.8896 | val loss = 0.4231, acc = 0.9043, auc = 0.9661, f1 = 0.8032, recall=0.9009
#   -> no improvement (1/7)
# [Hybrid_R18][Fold 3][Epoch 03]train loss = 0.3421, acc=0.9176, auc=0.9691,f1 = 0.8308, recall=0.9347 | val loss = 0.4094, acc = 0.8984, auc = 0.9630, f1 = 0.7903, recall=0.8829
#   -> no improvement (2/7)
# [Hybrid_R18][Fold 3][Epoch 04]train loss = 0.2981, acc=0.9215, auc=0.9760,f1 = 0.8359, recall=0.9234 | val loss = 0.4240, acc = 0.9219, auc = 0.9673, f1 = 0.8261, recall=0.8559
#   -> no improvement (3/7)
# [Hybrid_R18][Fold 3][Epoch 05]train loss = 0.2514, acc=0.9332, auc=0.9820,f1 = 0.8603, recall=0.9505 | val loss = 0.4942, acc = 0.9102, auc = 0.9618, f1 = 0.8067, recall=0.8649
#   -> no improvement (4/7)
# [Hybrid_R18][Fold 3][Epoch 06]train loss = 0.1613, acc=0.9522, auc=0.9928,f1 = 0.8973, recall=0.9640 | val loss = 0.3651, acc = 0.9023, auc = 0.9749, f1 = 0.8047, recall=0.9279
#   -> best saved by val_loss: ct_binary_models_filter_ablation/Hybrid_R18_fold3_best.pth
# [Hybrid_R18][Fold 3][Epoch 07]train loss = 0.1329, acc=0.9712, auc=0.9948,f1 = 0.9364, recall=0.9775 | val loss = 0.6242, acc = 0.8438, auc = 0.9679, f1 = 0.7315, recall=0.9820
#   -> no improvement (1/7)
# [Hybrid_R18][Fold 3][Epoch 08]train loss = 0.1182, acc=0.9712, auc=0.9961,f1 = 0.9359, recall=0.9707 | val loss = 0.5047, acc = 0.9180, auc = 0.9662, f1 = 0.8293, recall=0.9189
#   -> no improvement (2/7)
# [Hybrid_R18][Fold 3][Epoch 09]train loss = 0.0963, acc=0.9800, auc=0.9963,f1 = 0.9549, recall=0.9775 | val loss = 0.5480, acc = 0.9004, auc = 0.9504, f1 = 0.7848, recall=0.8378
#   -> no improvement (3/7)
# [Hybrid_R18][Fold 3][Epoch 10]train loss = 0.1805, acc=0.9620, auc=0.9903,f1 = 0.9161, recall=0.9595 | val loss = 0.5732, acc = 0.8770, auc = 0.9624, f1 = 0.7675, recall=0.9369
#   -> no improvement (4/7)
# [Hybrid_R18][Fold 3][Epoch 11]train loss = 0.1272, acc=0.9722, auc=0.9938,f1 = 0.9386, recall=0.9820 | val loss = 0.8770, acc = 0.9023, auc = 0.9595, f1 = 0.7768, recall=0.7838
#   -> no improvement (5/7)
# [Hybrid_R18][Fold 3][Epoch 12]train loss = 0.1522, acc=0.9678, auc=0.9907,f1 = 0.9289, recall=0.9707 | val loss = 0.6204, acc = 0.9023, auc = 0.9627, f1 = 0.7967, recall=0.8829
#   -> no improvement (6/7)
# [Hybrid_R18][Fold 3][Epoch 13]train loss = 0.0671, acc=0.9839, auc=0.9980,f1 = 0.9639, recall=0.9910 | val loss = 0.8369, acc = 0.9277, auc = 0.9545, f1 = 0.8141, recall=0.7297
#   -> no improvement (7/7)
#   -> early stopping triggered at epoch 13
#
# --Final Evaluation (threshold=0.5) --
# Accuracy: 0.9062
# ROC-AUC : 0.9748
# F1-score : 0.8110
# Sensitivity : 0.9279
# Confusion Matrix:
# [[361  40]
#  [  8 103]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0     0.9783    0.9002    0.9377       401
#            1     0.7203    0.9279    0.8110       111
#
#     accuracy                         0.9062       512
#    macro avg     0.8493    0.9141    0.8743       512
# weighted avg     0.9224    0.9062    0.9102       512
#
#
# [Hybrid_R18][Fold 3] Final Metrics
# Accuracy: 0.9062
# ROC-AUC: 0.9748
# F1-score : 0.8110
# Sensitivity : 0.9279
# Confusion Matrix:
# [[361  40]
#  [  8 103]]
#
# ================================================================================
# Running Hybrid_R18 | Fold 4 | norm=imagenet
# ================================================================================
# [FOLD 4] Train benign(0): 1606, malignant(1): 444, pos_weight=3.6171
# [Hybrid_R18][Fold 4][Epoch 01]train loss = 0.6645, acc=0.8073, auc=0.8873,f1 = 0.6495, recall=0.8243 | val loss = 0.5481, acc = 0.8320, auc = 0.9444, f1 = 0.7034, recall=0.9189
#   -> best saved by val_loss: ct_binary_models_filter_ablation/Hybrid_R18_fold4_best.pth
# [Hybrid_R18][Fold 4][Epoch 02]train loss = 0.4880, acc=0.8668, auc=0.9385,f1 = 0.7441, recall=0.8941 | val loss = 0.4200, acc = 0.8984, auc = 0.9609, f1 = 0.7953, recall=0.9099
#   -> best saved by val_loss: ct_binary_models_filter_ablation/Hybrid_R18_fold4_best.pth
# [Hybrid_R18][Fold 4][Epoch 03]train loss = 0.3853, acc=0.9010, auc=0.9597,f1 = 0.8004, recall=0.9167 | val loss = 0.4745, acc = 0.9023, auc = 0.9576, f1 = 0.7863, recall=0.8288
#   -> no improvement (1/7)
# [Hybrid_R18][Fold 4][Epoch 04]train loss = 0.3236, acc=0.9268, auc=0.9702,f1 = 0.8450, recall=0.9212 | val loss = 0.4347, acc = 0.9004, auc = 0.9628, f1 = 0.7866, recall=0.8468
#   -> no improvement (2/7)
# [Hybrid_R18][Fold 4][Epoch 05]train loss = 0.2841, acc=0.9327, auc=0.9782,f1 = 0.8577, recall=0.9369 | val loss = 0.5090, acc = 0.9180, auc = 0.9624, f1 = 0.8091, recall=0.8018
#   -> no improvement (3/7)
# [Hybrid_R18][Fold 4][Epoch 06]train loss = 0.2073, acc=0.9507, auc=0.9857,f1 = 0.8940, recall=0.9595 | val loss = 0.5781, acc = 0.8848, auc = 0.9589, f1 = 0.7401, recall=0.7568
#   -> no improvement (4/7)
# [Hybrid_R18][Fold 4][Epoch 07]train loss = 0.1746, acc=0.9600, auc=0.9903,f1 = 0.9130, recall=0.9685 | val loss = 0.4609, acc = 0.8945, auc = 0.9609, f1 = 0.7769, recall=0.8468
#   -> no improvement (5/7)
# [Hybrid_R18][Fold 4][Epoch 08]train loss = 0.1479, acc=0.9654, auc=0.9932,f1 = 0.9241, recall=0.9730 | val loss = 0.5025, acc = 0.9180, auc = 0.9632, f1 = 0.8158, recall=0.8378
#   -> no improvement (6/7)
# [Hybrid_R18][Fold 4][Epoch 09]train loss = 0.1401, acc=0.9741, auc=0.9928,f1 = 0.9422, recall=0.9730 | val loss = 0.5195, acc = 0.8574, auc = 0.9666, f1 = 0.7420, recall=0.9459
#   -> no improvement (7/7)
#   -> early stopping triggered at epoch 9
#
# --Final Evaluation (threshold=0.5) --
# Accuracy: 0.8984
# ROC-AUC : 0.9611
# F1-score : 0.7953
# Sensitivity : 0.9099
# Confusion Matrix:
# [[359  42]
#  [ 10 101]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0     0.9729    0.8953    0.9325       401
#            1     0.7063    0.9099    0.7953       111
#
#     accuracy                         0.8984       512
#    macro avg     0.8396    0.9026    0.8639       512
# weighted avg     0.9151    0.8984    0.9027       512
#
#
# [Hybrid_R18][Fold 4] Final Metrics
# Accuracy: 0.8984
# ROC-AUC: 0.9611
# F1-score : 0.7953
# Sensitivity : 0.9099
# Confusion Matrix:
# [[359  42]
#  [ 10 101]]
#
# ================================================================================
# Running Hybrid_R18 | Fold 5 | norm=imagenet
# ================================================================================
# [FOLD 5] Train benign(0): 1606, malignant(1): 444, pos_weight=3.6171
# [Hybrid_R18][Fold 5][Epoch 01]train loss = 0.6144, acc=0.8332, auc=0.9039,f1 = 0.6845, recall=0.8356 | val loss = 0.5047, acc = 0.8398, auc = 0.9431, f1 = 0.7153, recall=0.9279
#   -> best saved by val_loss: ct_binary_models_filter_ablation/Hybrid_R18_fold5_best.pth
# [Hybrid_R18][Fold 5][Epoch 02]train loss = 0.4405, acc=0.8790, auc=0.9470,f1 = 0.7647, recall=0.9077 | val loss = 0.5597, acc = 0.8320, auc = 0.9458, f1 = 0.6950, recall=0.8829
#   -> no improvement (1/7)
# [Hybrid_R18][Fold 5][Epoch 03]train loss = 0.3641, acc=0.9044, auc=0.9649,f1 = 0.8082, recall=0.9302 | val loss = 0.5026, acc = 0.8555, auc = 0.9580, f1 = 0.7357, recall=0.9279
#   -> best saved by val_loss: ct_binary_models_filter_ablation/Hybrid_R18_fold5_best.pth
# [Hybrid_R18][Fold 5][Epoch 04]train loss = 0.2645, acc=0.9273, auc=0.9798,f1 = 0.8499, recall=0.9505 | val loss = 0.8234, acc = 0.9004, auc = 0.9476, f1 = 0.7302, recall=0.6216
#   -> no improvement (1/7)
# [Hybrid_R18][Fold 5][Epoch 05]train loss = 0.2151, acc=0.9537, auc=0.9875,f1 = 0.8993, recall=0.9550 | val loss = 0.4621, acc = 0.8926, auc = 0.9548, f1 = 0.7826, recall=0.8919
#   -> best saved by val_loss: ct_binary_models_filter_ablation/Hybrid_R18_fold5_best.pth
# [Hybrid_R18][Fold 5][Epoch 06]train loss = 0.2162, acc=0.9556, auc=0.9866,f1 = 0.9029, recall=0.9527 | val loss = 0.6675, acc = 0.8672, auc = 0.9417, f1 = 0.7481, recall=0.9099
#   -> no improvement (1/7)
# [Hybrid_R18][Fold 5][Epoch 07]train loss = 0.2675, acc=0.9288, auc=0.9802,f1 = 0.8537, recall=0.9595 | val loss = 0.6233, acc = 0.9043, auc = 0.9610, f1 = 0.8000, recall=0.8829
#   -> no improvement (2/7)
# [Hybrid_R18][Fold 5][Epoch 08]train loss = 0.1499, acc=0.9605, auc=0.9929,f1 = 0.9141, recall=0.9707 | val loss = 0.6810, acc = 0.8984, auc = 0.9536, f1 = 0.7920, recall=0.8919
#   -> no improvement (3/7)
# [Hybrid_R18][Fold 5][Epoch 09]train loss = 0.1726, acc=0.9644, auc=0.9895,f1 = 0.9223, recall=0.9752 | val loss = 0.5759, acc = 0.9062, auc = 0.9601, f1 = 0.7966, recall=0.8468
#   -> no improvement (4/7)
# [Hybrid_R18][Fold 5][Epoch 10]train loss = 0.1271, acc=0.9683, auc=0.9947,f1 = 0.9303, recall=0.9775 | val loss = 0.5455, acc = 0.8965, auc = 0.9494, f1 = 0.7782, recall=0.8378
#   -> no improvement (5/7)
# [Hybrid_R18][Fold 5][Epoch 11]train loss = 0.0682, acc=0.9868, auc=0.9980,f1 = 0.9700, recall=0.9842 | val loss = 0.7593, acc = 0.9141, auc = 0.9543, f1 = 0.8053, recall=0.8198
#   -> no improvement (6/7)
# [Hybrid_R18][Fold 5][Epoch 12]train loss = 0.0655, acc=0.9878, auc=0.9989,f1 = 0.9722, recall=0.9842 | val loss = 0.9032, acc = 0.9043, auc = 0.9543, f1 = 0.7822, recall=0.7928
#   -> no improvement (7/7)
#   -> early stopping triggered at epoch 12
#
# --Final Evaluation (threshold=0.5) --
# Accuracy: 0.8945
# ROC-AUC : 0.9549
# F1-score : 0.7857
# Sensitivity : 0.8919
# Confusion Matrix:
# [[359  42]
#  [ 12  99]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0     0.9677    0.8953    0.9301       401
#            1     0.7021    0.8919    0.7857       111
#
#     accuracy                         0.8945       512
#    macro avg     0.8349    0.8936    0.8579       512
# weighted avg     0.9101    0.8945    0.8988       512
#
#
# [Hybrid_R18][Fold 5] Final Metrics
# Accuracy: 0.8945
# ROC-AUC: 0.9549
# F1-score : 0.7857
# Sensitivity : 0.8919
# Confusion Matrix:
# [[359  42]
#  [ 12  99]]
#         model  fold       acc   ROC-AUC  F1-score  Sensitivity  \
# 0  Hybrid_R18     1  0.927875  0.981534  0.846473     0.918919
# 1  Hybrid_R18     2  0.896686  0.939671  0.768559     0.792793
# 2  Hybrid_R18     3  0.906250  0.974838  0.811024     0.927928
# 3  Hybrid_R18     4  0.898438  0.961077  0.795276     0.909910
# 4  Hybrid_R18     5  0.894531  0.954865  0.785714     0.891892
#
#          Confusion Matrix
# 0   [[374, 28], [9, 102]]
# 1   [[372, 30], [23, 88]]
# 2   [[361, 40], [8, 103]]
# 3  [[359, 42], [10, 101]]
# 4   [[359, 42], [12, 99]]

# %%
print(">>> Training Hybrid (ResNet50+ViT)... ")
hybrid_cv_df, hybrid_history_df = run_cv_for_model(
    model_name="Hybrid_R50",
    model_type="hybrid_r50",
    build_fn=lambda: build_hybrid_patient_model(load_pretrained=True),
    norm_type="imagenet"
)

display(hybrid_cv_df)
# Out:
# >>> Training Hybrid (ResNet50+ViT)...
#
# ================================================================================
# Running Hybrid_R50 | Fold 1 | norm=imagenet
# ================================================================================
# [FOLD 1] Train benign(0): 1605, malignant(1): 444, pos_weight=3.6149
# [Hybrid_R50][Fold 1][Epoch 01]train loss = 0.6347, acc=0.8175, auc=0.8980,f1 = 0.6581, recall=0.8108 | val loss = 0.5957, acc = 0.7057, auc = 0.9738, f1 = 0.5952, recall=1.0000
#   -> best saved by val_loss: ct_binary_models_filter_ablation/Hybrid_R50_fold1_best.pth
# [Hybrid_R50][Fold 1][Epoch 02]train loss = 0.4037, acc=0.8907, auc=0.9579,f1 = 0.7867, recall=0.9302 | val loss = 0.4558, acc = 0.9220, auc = 0.9767, f1 = 0.8000, recall=0.7207
#   -> best saved by val_loss: ct_binary_models_filter_ablation/Hybrid_R50_fold1_best.pth
# [Hybrid_R50][Fold 1][Epoch 03]train loss = 0.3051, acc=0.9248, auc=0.9746,f1 = 0.8454, recall=0.9482 | val loss = 0.6243, acc = 0.9162, auc = 0.9781, f1 = 0.7701, recall=0.6486
#   -> no improvement (1/7)
# [Hybrid_R50][Fold 1][Epoch 04]train loss = 0.2043, acc=0.9531, auc=0.9888,f1 = 0.8981, recall=0.9527 | val loss = 0.3000, acc = 0.9142, auc = 0.9832, f1 = 0.8268, recall=0.9459
#   -> best saved by val_loss: ct_binary_models_filter_ablation/Hybrid_R50_fold1_best.pth
# [Hybrid_R50][Fold 1][Epoch 05]train loss = 0.1236, acc=0.9683, auc=0.9959,f1 = 0.9300, recall=0.9730 | val loss = 0.3971, acc = 0.9454, auc = 0.9837, f1 = 0.8667, recall=0.8198
#   -> no improvement (1/7)
# [Hybrid_R50][Fold 1][Epoch 06]train loss = 0.1081, acc=0.9766, auc=0.9965,f1 = 0.9473, recall=0.9707 | val loss = 0.4257, acc = 0.9337, auc = 0.9829, f1 = 0.8595, recall=0.9369
#   -> no improvement (2/7)
# [Hybrid_R50][Fold 1][Epoch 07]train loss = 0.0723, acc=0.9858, auc=0.9975,f1 = 0.9680, recall=0.9887 | val loss = 0.8180, acc = 0.9279, auc = 0.9679, f1 = 0.8122, recall=0.7207
#   -> no improvement (3/7)
# [Hybrid_R50][Fold 1][Epoch 08]train loss = 0.1158, acc=0.9780, auc=0.9954,f1 = 0.9504, recall=0.9707 | val loss = 0.8150, acc = 0.7388, auc = 0.9662, f1 = 0.6215, recall=0.9910
#   -> no improvement (4/7)
# [Hybrid_R50][Fold 1][Epoch 09]train loss = 0.1618, acc=0.9536, auc=0.9921,f1 = 0.9018, recall=0.9820 | val loss = 0.4853, acc = 0.9337, auc = 0.9801, f1 = 0.8522, recall=0.8829
#   -> no improvement (5/7)
# [Hybrid_R50][Fold 1][Epoch 10]train loss = 0.0688, acc=0.9863, auc=0.9980,f1 = 0.9690, recall=0.9865 | val loss = 0.4529, acc = 0.9454, auc = 0.9785, f1 = 0.8803, recall=0.9279
#   -> no improvement (6/7)
# [Hybrid_R50][Fold 1][Epoch 11]train loss = 0.0523, acc=0.9863, auc=0.9991,f1 = 0.9690, recall=0.9842 | val loss = 0.5420, acc = 0.9220, auc = 0.9758, f1 = 0.8387, recall=0.9369
#   -> no improvement (7/7)
#   -> early stopping triggered at epoch 11
#
# --Final Evaluation (threshold=0.5) --
# Accuracy: 0.9123
# ROC-AUC : 0.9832
# F1-score : 0.8235
# Sensitivity : 0.9459
# Confusion Matrix:
# [[363  39]
#  [  6 105]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0     0.9837    0.9030    0.9416       402
#            1     0.7292    0.9459    0.8235       111
#
#     accuracy                         0.9123       513
#    macro avg     0.8565    0.9245    0.8826       513
# weighted avg     0.9287    0.9123    0.9161       513
#
#
# [Hybrid_R50][Fold 1] Final Metrics
# Accuracy: 0.9123
# ROC-AUC: 0.9832
# F1-score : 0.8235
# Sensitivity : 0.9459
# Confusion Matrix:
# [[363  39]
#  [  6 105]]
#
# ================================================================================
# Running Hybrid_R50 | Fold 2 | norm=imagenet
# ================================================================================
# [FOLD 2] Train benign(0): 1605, malignant(1): 444, pos_weight=3.6149
# [Hybrid_R50][Fold 2][Epoch 01]train loss = 0.6340, acc=0.8521, auc=0.8936,f1 = 0.7050, recall=0.8153 | val loss = 0.6348, acc = 0.7719, auc = 0.9414, f1 = 0.6444, recall=0.9550
#   -> best saved by val_loss: ct_binary_models_filter_ablation/Hybrid_R50_fold2_best.pth
# [Hybrid_R50][Fold 2][Epoch 02]train loss = 0.3843, acc=0.9126, auc=0.9607,f1 = 0.8197, recall=0.9167 | val loss = 0.5921, acc = 0.9045, auc = 0.9594, f1 = 0.7721, recall=0.7477
#   -> best saved by val_loss: ct_binary_models_filter_ablation/Hybrid_R50_fold2_best.pth
# [Hybrid_R50][Fold 2][Epoch 03]train loss = 0.2586, acc=0.9400, auc=0.9820,f1 = 0.8720, recall=0.9437 | val loss = 0.4061, acc = 0.8908, auc = 0.9668, f1 = 0.7846, recall=0.9189
#   -> best saved by val_loss: ct_binary_models_filter_ablation/Hybrid_R50_fold2_best.pth
# [Hybrid_R50][Fold 2][Epoch 04]train loss = 0.1641, acc=0.9571, auc=0.9913,f1 = 0.9083, recall=0.9820 | val loss = 0.7697, acc = 0.9084, auc = 0.9575, f1 = 0.7873, recall=0.7838
#   -> no improvement (1/7)
# [Hybrid_R50][Fold 2][Epoch 05]train loss = 0.1345, acc=0.9717, auc=0.9937,f1 = 0.9368, recall=0.9685 | val loss = 0.5831, acc = 0.9201, auc = 0.9482, f1 = 0.8019, recall=0.7477
#   -> no improvement (2/7)
# [Hybrid_R50][Fold 2][Epoch 06]train loss = 0.1014, acc=0.9751, auc=0.9966,f1 = 0.9449, recall=0.9842 | val loss = 0.8491, acc = 0.8928, auc = 0.9407, f1 = 0.7465, recall=0.7297
#   -> no improvement (3/7)
# [Hybrid_R50][Fold 2][Epoch 07]train loss = 0.1051, acc=0.9790, auc=0.9952,f1 = 0.9528, recall=0.9775 | val loss = 0.8766, acc = 0.9181, auc = 0.9585, f1 = 0.8056, recall=0.7838
#   -> no improvement (4/7)
# [Hybrid_R50][Fold 2][Epoch 08]train loss = 0.0838, acc=0.9849, auc=0.9974,f1 = 0.9656, recall=0.9797 | val loss = 0.8471, acc = 0.9103, auc = 0.9614, f1 = 0.7810, recall=0.7387
#   -> no improvement (5/7)
# [Hybrid_R50][Fold 2][Epoch 09]train loss = 0.0488, acc=0.9922, auc=0.9992,f1 = 0.9821, recall=0.9887 | val loss = 0.6950, acc = 0.9084, auc = 0.9530, f1 = 0.7965, recall=0.8288
#   -> no improvement (6/7)
# [Hybrid_R50][Fold 2][Epoch 10]train loss = 0.0665, acc=0.9873, auc=0.9974,f1 = 0.9712, recall=0.9887 | val loss = 0.9232, acc = 0.9162, auc = 0.9477, f1 = 0.7923, recall=0.7387
#   -> no improvement (7/7)
#   -> early stopping triggered at epoch 10
#
# --Final Evaluation (threshold=0.5) --
# Accuracy: 0.8908
# ROC-AUC : 0.9668
# F1-score : 0.7846
# Sensitivity : 0.9189
# Confusion Matrix:
# [[355  47]
#  [  9 102]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0     0.9753    0.8831    0.9269       402
#            1     0.6846    0.9189    0.7846       111
#
#     accuracy                         0.8908       513
#    macro avg     0.8299    0.9010    0.8558       513
# weighted avg     0.9124    0.8908    0.8961       513
#
#
# [Hybrid_R50][Fold 2] Final Metrics
# Accuracy: 0.8908
# ROC-AUC: 0.9668
# F1-score : 0.7846
# Sensitivity : 0.9189
# Confusion Matrix:
# [[355  47]
#  [  9 102]]
#
# ================================================================================
# Running Hybrid_R50 | Fold 3 | norm=imagenet
# ================================================================================
# [FOLD 3] Train benign(0): 1606, malignant(1): 444, pos_weight=3.6171
# [Hybrid_R50][Fold 3][Epoch 01]train loss = 0.6464, acc=0.8351, auc=0.8919,f1 = 0.6888, recall=0.8423 | val loss = 0.4486, acc = 0.8945, auc = 0.9618, f1 = 0.7970, recall=0.9550
#   -> best saved by val_loss: ct_binary_models_filter_ablation/Hybrid_R50_fold3_best.pth
# [Hybrid_R50][Fold 3][Epoch 02]train loss = 0.3964, acc=0.8956, auc=0.9585,f1 = 0.7894, recall=0.9032 | val loss = 0.4115, acc = 0.8984, auc = 0.9576, f1 = 0.7903, recall=0.8829
#   -> best saved by val_loss: ct_binary_models_filter_ablation/Hybrid_R50_fold3_best.pth
# [Hybrid_R50][Fold 3][Epoch 03]train loss = 0.2544, acc=0.9337, auc=0.9822,f1 = 0.8604, recall=0.9437 | val loss = 0.4719, acc = 0.8672, auc = 0.9655, f1 = 0.7554, recall=0.9459
#   -> no improvement (1/7)
# [Hybrid_R50][Fold 3][Epoch 04]train loss = 0.1842, acc=0.9498, auc=0.9892,f1 = 0.8930, recall=0.9685 | val loss = 0.4602, acc = 0.9297, auc = 0.9663, f1 = 0.8475, recall=0.9009
#   -> no improvement (2/7)
# [Hybrid_R50][Fold 3][Epoch 05]train loss = 0.1183, acc=0.9717, auc=0.9959,f1 = 0.9375, recall=0.9797 | val loss = 0.5592, acc = 0.9375, auc = 0.9738, f1 = 0.8559, recall=0.8559
#   -> no improvement (3/7)
# [Hybrid_R50][Fold 3][Epoch 06]train loss = 0.0767, acc=0.9805, auc=0.9986,f1 = 0.9564, recall=0.9887 | val loss = 0.5222, acc = 0.9219, auc = 0.9680, f1 = 0.8261, recall=0.8559
#   -> no improvement (4/7)
# [Hybrid_R50][Fold 3][Epoch 07]train loss = 0.1202, acc=0.9751, auc=0.9928,f1 = 0.9446, recall=0.9797 | val loss = 0.6816, acc = 0.9121, auc = 0.9663, f1 = 0.7945, recall=0.7838
#   -> no improvement (5/7)
# [Hybrid_R50][Fold 3][Epoch 08]train loss = 0.1381, acc=0.9727, auc=0.9916,f1 = 0.9391, recall=0.9730 | val loss = 0.4616, acc = 0.8887, auc = 0.9650, f1 = 0.7865, recall=0.9459
#   -> no improvement (6/7)
# [Hybrid_R50][Fold 3][Epoch 09]train loss = 0.0533, acc=0.9883, auc=0.9986,f1 = 0.9735, recall=0.9910 | val loss = 0.5467, acc = 0.9316, auc = 0.9711, f1 = 0.8372, recall=0.8108
#   -> no improvement (7/7)
#   -> early stopping triggered at epoch 9
#
# --Final Evaluation (threshold=0.5) --
# Accuracy: 0.9023
# ROC-AUC : 0.9571
# F1-score : 0.7984
# Sensitivity : 0.8919
# Confusion Matrix:
# [[363  38]
#  [ 12  99]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0     0.9680    0.9052    0.9356       401
#            1     0.7226    0.8919    0.7984       111
#
#     accuracy                         0.9023       512
#    macro avg     0.8453    0.8986    0.8670       512
# weighted avg     0.9148    0.9023    0.9058       512
#
#
# [Hybrid_R50][Fold 3] Final Metrics
# Accuracy: 0.9023
# ROC-AUC: 0.9571
# F1-score : 0.7984
# Sensitivity : 0.8919
# Confusion Matrix:
# [[363  38]
#  [ 12  99]]
#
# ================================================================================
# Running Hybrid_R50 | Fold 4 | norm=imagenet
# ================================================================================
# [FOLD 4] Train benign(0): 1606, malignant(1): 444, pos_weight=3.6171
# [Hybrid_R50][Fold 4][Epoch 01]train loss = 0.6604, acc=0.8073, auc=0.8894,f1 = 0.6457, recall=0.8108 | val loss = 0.4970, acc = 0.8926, auc = 0.9454, f1 = 0.7679, recall=0.8198
#   -> best saved by val_loss: ct_binary_models_filter_ablation/Hybrid_R50_fold4_best.pth
# [Hybrid_R50][Fold 4][Epoch 02]train loss = 0.3894, acc=0.9029, auc=0.9583,f1 = 0.8055, recall=0.9279 | val loss = 0.5311, acc = 0.8730, auc = 0.9522, f1 = 0.7584, recall=0.9189
#   -> no improvement (1/7)
# [Hybrid_R50][Fold 4][Epoch 03]train loss = 0.2327, acc=0.9429, auc=0.9836,f1 = 0.8795, recall=0.9617 | val loss = 0.7738, acc = 0.9062, auc = 0.9461, f1 = 0.7798, recall=0.7658
#   -> no improvement (2/7)
# [Hybrid_R50][Fold 4][Epoch 04]train loss = 0.1743, acc=0.9605, auc=0.9909,f1 = 0.9136, recall=0.9640 | val loss = 0.4086, acc = 0.9082, auc = 0.9636, f1 = 0.8082, recall=0.8919
#   -> best saved by val_loss: ct_binary_models_filter_ablation/Hybrid_R50_fold4_best.pth
# [Hybrid_R50][Fold 4][Epoch 05]train loss = 0.1483, acc=0.9639, auc=0.9919,f1 = 0.9216, recall=0.9797 | val loss = 0.4286, acc = 0.9121, auc = 0.9704, f1 = 0.8163, recall=0.9009
#   -> no improvement (1/7)
# [Hybrid_R50][Fold 4][Epoch 06]train loss = 0.0932, acc=0.9785, auc=0.9975,f1 = 0.9522, recall=0.9865 | val loss = 0.5527, acc = 0.9238, auc = 0.9731, f1 = 0.8340, recall=0.8829
#   -> no improvement (2/7)
# [Hybrid_R50][Fold 4][Epoch 07]train loss = 0.0907, acc=0.9820, auc=0.9968,f1 = 0.9595, recall=0.9865 | val loss = 0.4137, acc = 0.9082, auc = 0.9704, f1 = 0.8142, recall=0.9279
#   -> no improvement (3/7)
# [Hybrid_R50][Fold 4][Epoch 08]train loss = 0.0699, acc=0.9888, auc=0.9975,f1 = 0.9745, recall=0.9887 | val loss = 0.5289, acc = 0.9180, auc = 0.9654, f1 = 0.8250, recall=0.8919
#   -> no improvement (4/7)
# [Hybrid_R50][Fold 4][Epoch 09]train loss = 0.1037, acc=0.9727, auc=0.9964,f1 = 0.9394, recall=0.9775 | val loss = 0.5685, acc = 0.9102, auc = 0.9622, f1 = 0.8115, recall=0.8919
#   -> no improvement (5/7)
# [Hybrid_R50][Fold 4][Epoch 10]train loss = 0.0383, acc=0.9907, auc=0.9994,f1 = 0.9790, recall=0.9977 | val loss = 0.8467, acc = 0.9043, auc = 0.9597, f1 = 0.8016, recall=0.8919
#   -> no improvement (6/7)
# [Hybrid_R50][Fold 4][Epoch 11]train loss = 0.0489, acc=0.9868, auc=0.9989,f1 = 0.9701, recall=0.9865 | val loss = 0.6896, acc = 0.9199, auc = 0.9678, f1 = 0.8270, recall=0.8829
#   -> no improvement (7/7)
#   -> early stopping triggered at epoch 11
#
# --Final Evaluation (threshold=0.5) --
# Accuracy: 0.9062
# ROC-AUC : 0.9642
# F1-score : 0.8049
# Sensitivity : 0.8919
# Confusion Matrix:
# [[365  36]
#  [ 12  99]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0     0.9682    0.9102    0.9383       401
#            1     0.7333    0.8919    0.8049       111
#
#     accuracy                         0.9062       512
#    macro avg     0.8508    0.9011    0.8716       512
# weighted avg     0.9173    0.9062    0.9094       512
#
#
# [Hybrid_R50][Fold 4] Final Metrics
# Accuracy: 0.9062
# ROC-AUC: 0.9642
# F1-score : 0.8049
# Sensitivity : 0.8919
# Confusion Matrix:
# [[365  36]
#  [ 12  99]]
#
# ================================================================================
# Running Hybrid_R50 | Fold 5 | norm=imagenet
# ================================================================================
# [FOLD 5] Train benign(0): 1606, malignant(1): 444, pos_weight=3.6171
# [Hybrid_R50][Fold 5][Epoch 01]train loss = 0.6341, acc=0.8263, auc=0.8981,f1 = 0.6758, recall=0.8356 | val loss = 0.5129, acc = 0.8926, auc = 0.9428, f1 = 0.7809, recall=0.8829
#   -> best saved by val_loss: ct_binary_models_filter_ablation/Hybrid_R50_fold5_best.pth
# [Hybrid_R50][Fold 5][Epoch 02]train loss = 0.3472, acc=0.9220, auc=0.9683,f1 = 0.8344, recall=0.9077 | val loss = 0.5449, acc = 0.8809, auc = 0.9548, f1 = 0.7570, recall=0.8559
#   -> no improvement (1/7)
# [Hybrid_R50][Fold 5][Epoch 03]train loss = 0.2711, acc=0.9234, auc=0.9808,f1 = 0.8419, recall=0.9414 | val loss = 0.5716, acc = 0.9102, auc = 0.9590, f1 = 0.8000, recall=0.8288
#   -> no improvement (2/7)
# [Hybrid_R50][Fold 5][Epoch 04]train loss = 0.1452, acc=0.9629, auc=0.9946,f1 = 0.9185, recall=0.9640 | val loss = 0.6018, acc = 0.8945, auc = 0.9594, f1 = 0.7970, recall=0.9550
#   -> no improvement (3/7)
# [Hybrid_R50][Fold 5][Epoch 05]train loss = 0.1623, acc=0.9590, auc=0.9922,f1 = 0.9108, recall=0.9662 | val loss = 0.6151, acc = 0.9199, auc = 0.9510, f1 = 0.8093, recall=0.7838
#   -> no improvement (4/7)
# [Hybrid_R50][Fold 5][Epoch 06]train loss = 0.0940, acc=0.9800, auc=0.9967,f1 = 0.9551, recall=0.9820 | val loss = 0.6669, acc = 0.8672, auc = 0.9568, f1 = 0.7554, recall=0.9459
#   -> no improvement (5/7)
# [Hybrid_R50][Fold 5][Epoch 07]train loss = 0.1053, acc=0.9800, auc=0.9951,f1 = 0.9550, recall=0.9797 | val loss = 0.8109, acc = 0.9258, auc = 0.9503, f1 = 0.8319, recall=0.8468
#   -> no improvement (6/7)
# [Hybrid_R50][Fold 5][Epoch 08]train loss = 0.0684, acc=0.9902, auc=0.9967,f1 = 0.9778, recall=0.9910 | val loss = 0.6404, acc = 0.8809, auc = 0.9556, f1 = 0.7570, recall=0.8559
#   -> no improvement (7/7)
#   -> early stopping triggered at epoch 8
#
# --Final Evaluation (threshold=0.5) --
# Accuracy: 0.8887
# ROC-AUC : 0.9417
# F1-score : 0.7729
# Sensitivity : 0.8739
# Confusion Matrix:
# [[358  43]
#  [ 14  97]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0     0.9624    0.8928    0.9263       401
#            1     0.6929    0.8739    0.7729       111
#
#     accuracy                         0.8887       512
#    macro avg     0.8276    0.8833    0.8496       512
# weighted avg     0.9039    0.8887    0.8930       512
#
#
# [Hybrid_R50][Fold 5] Final Metrics
# Accuracy: 0.8887
# ROC-AUC: 0.9417
# F1-score : 0.7729
# Sensitivity : 0.8739
# Confusion Matrix:
# [[358  43]
#  [ 14  97]]
#         model  fold       acc   ROC-AUC  F1-score  Sensitivity  \
# 0  Hybrid_R50     1  0.912281  0.983192  0.823529     0.945946
# 1  Hybrid_R50     2  0.890838  0.966788  0.784615     0.918919
# 2  Hybrid_R50     3  0.902344  0.957067  0.798387     0.891892
# 3  Hybrid_R50     4  0.906250  0.964166  0.804878     0.891892
# 4  Hybrid_R50     5  0.888672  0.941745  0.772908     0.873874
#
#         Confusion Matrix
# 0  [[363, 39], [6, 105]]
# 1  [[355, 47], [9, 102]]
# 2  [[363, 38], [12, 99]]
# 3  [[365, 36], [12, 99]]
# 4  [[358, 43], [14, 97]]

# %%
# 11. 5-fold mean +- std

all_cv_df = pd.concat([
    resnet18_imagenet_cv_df, 
    resnet50_imagenet_cv_df,
    resnet18_rad_cv_df,
    resnet50_rad_cv_df,
    vit_cv_df, 
    hybrid_r18_cv_df,
    hybrid_cv_df
], ignore_index=True)

summary_df = (
    all_cv_df.groupby("model")[["acc", "ROC-AUC", "F1-score", "Sensitivity"]]
    .agg(["mean", "std"])
)

display(summary_df)
# Out:
#                            acc             ROC-AUC            F1-score  \
#                           mean       std      mean       std      mean
# model
# Hybrid_R18            0.904756  0.013659  0.962397  0.016552  0.801409
# Hybrid_R50            0.900077  0.010095  0.962592  0.015080  0.796864
# ResNet18_ImageNet     0.889935  0.021626  0.962337  0.010075  0.780461
# ResNet18_RadImageNet  0.899678  0.030523  0.966702  0.012614  0.799211
# ResNet50_ImageNet     0.900857  0.014770  0.959246  0.018547  0.797327
# ResNet50_RadImageNet  0.893426  0.029221  0.959524  0.014909  0.787553
# ViT-B16               0.898512  0.023394  0.959007  0.016631  0.794728
#
#                                Sensitivity
#                            std        mean       std
# model
# Hybrid_R18            0.029522    0.888288  0.055021
# Hybrid_R50            0.019375    0.904505  0.028203
# ResNet18_ImageNet     0.033214    0.897297  0.026725
# ResNet18_RadImageNet  0.052043    0.909910  0.043673
# ResNet50_ImageNet     0.030152    0.900901  0.051359
# ResNet50_RadImageNet  0.048895    0.899099  0.019531
# ViT-B16               0.042957    0.902703  0.032105

# %%
def plot_one_model_by_fold(history_df, model_name):
    folds = sorted(history_df["fold"].unique())

    plt.figure(figsize=(12, 5))
    
    plt.subplot(1,2,1)
    for fold in folds:
        df_fold = history_df[history_df["fold"] == fold].sort_values("epoch")
        plt.plot(df_fold["epoch"], df_fold['train_loss'], linestyle='--', alpha = 0.7, label=f'Fold{fold} Train')
        plt.plot(df_fold["epoch"], df_fold['val_loss'], alpha = 0.7, label=f'Fold{fold} Val')
        
    plt.title(f"{model_name} - Loss by Fold")
    plt.xlabel("Epochs")
    plt.ylabel("Loss")
    plt.legend(fontsize=8)

    plt.subplot(1, 2, 2)
    for fold in folds:
        df_fold = history_df[history_df["fold"] == fold].sort_values("epoch")
        plt.plot(df_fold["epoch"], df_fold["val_auc"], alpha = 0.8, label = f"Fold{fold}")

    plt.title(f"{model_name} - Val ROC-AUC by Fold")
    plt.xlabel("Epoch")
    plt.ylabel("AUC")
    plt.legend(fontsize=8)

    plt.tight_layout()
    plt.savefig(FIGURE_DIR / f"{model_name}_training_curve.png", dpi=150, bbox_inches="tight")
    plt.show()

# %%
plot_one_model_by_fold(resnet18_imagenet_history_df, "ResNet18_ImageNet")
plot_one_model_by_fold(resnet50_imagenet_history_df, "ResNet50_ImageNet")
plot_one_model_by_fold(resnet18_rad_history_df, "ResNet18_RadImageNet")
plot_one_model_by_fold(resnet50_rad_history_df, "ResNet50_RadImageNet")
plot_one_model_by_fold(vit_history_df, "ViT-B16")
plot_one_model_by_fold(hybrid_r18_history_df, "Hybrid_R18")
plot_one_model_by_fold(hybrid_history_df, "Hybrid_R50")

# %%
def plot_roc_curve_paper(model_info_list, save_path=None):
    fig, ax = plt.subplots(figsize=(7, 6))
    ax.plot([0, 1], [0, 1], 'k--', lw=1, label='Random (AUC = 0.50)')

    for info in model_info_list:
        fpr, tpr, _ = roc_curve(info["y_true"], info["y_prob"])
        auc_val = roc_auc_score(info["y_true"], info["y_prob"])
        ax.plot(fpr, tpr, lw=2, color=info["color"],
                label=f'{info["name"]} (AUC = {auc_val:.3f})')
        
    ax.set_xlabel("False Positive Rate", fontsize=13)
    ax.set_ylabel("True Positive Rate", fontsize=13)
    ax.set_title("ROC Curves - CT Binary Classification", fontsize=14, fontweight='bold')
    ax.legend(loc="lower right", fontsize=9, framealpha=0.9)
    ax.set_xli([0, 1])
    ax.set_ylim([0, 1.02])
    ax.grid(alpha=0.3)
    plt.tight_layout()

    if save_path:
        fig.savefig(save_path, dpi=300, bbox_inches="tight")
        print(f"ROC curve saved -> {save_path}")
    plt.show()
    return fig

# %%
from sklearn.metrics import(
    roc_curve, auc, roc_auc_score,
    precision_recall_curve, average_precision_score
)

def _to_1d_prob(y_prob):
    y_prob = np.asarray(y_prob)

    if y_prob.ndim == 1:
        return y_prob
    elif y_prob.ndim == 2 and y_prob.shape[1] ==2:
        return y_prob[:, 1]
    else:
        raise ValueError(
            f"y_prob shape이 이상"
        )
def plot_cv_roc_pr(
    fold_results,
    figsize=(6,6),
    roc_title="5-fold cv roc curve",
    save_roc_path=None,
    show_each_fold=True,
    ddof=1
):
    fold_aucs = []
    fold_aps = []

    all_y_true = []
    all_y_prob = []

    for i, fold in enumerate(fold_results, start=1):
        y_true=np.asarray(fold["y_true"]).astype(int)
        y_prob = _to_1d_prob(fold["y_prob"])

        if len(y_true) != len(y_prob):
            raise ValueError (f" {i}번째 fold: y_true y_prod 길이가 다름")
        if len(np.unique(y_true)) < 2:
            raise ValueError(f" {i}번째 fold: y_true에 클래스가 1개만")
        fold_auc = roc_auc_score(y_true, y_prob)
        fold_ap = average_precision_score(y_true, y_prob)

        fold_aucs.append(fold_auc)
        fold_aps.append(fold_ap)

        all_y_true.append(y_true)
        all_y_prob.append(y_prob)

    all_y_true = np.concatenate(all_y_true)
    all_y_prob = np.concatenate(all_y_prob)

    mean_auc = np.mean(fold_aucs)
    std_auc = np.std(fold_aucs)
    oof_auc = roc_auc_score(all_y_true, all_y_prob)

    plt.figure(figsize=figsize)
    
    if show_each_fold:
        for i, fold in enumerate(fold_results, start=1):
            y_true=np.asarray(fold["y_true"]).astype(int)
            y_prob = _to_1d_prob(fold["y_prob"])

            fpr, tpr, _ = roc_curve(y_true, y_prob)
            fold_auc = roc_auc_score(y_true, y_prob)

            plt.plot(
                fpr, tpr,
                alpha=0.35,
                label=f"Fold {i} (AUC={fold_auc:.4f})"
            )

    fpr_oof, tpr_oof, _ = roc_curve(all_y_true, all_y_prob)
    plt.plot(
        fpr_oof, tpr_oof,
        linewidth=2.5,
        label=f"OOF ROC (AUC={oof_auc:.4f})"
    )
    plt.plot([0,1], [0,1], linestyle="--", linewidth=1)

    plt.xlabel("False Positive Rate")
    plt.ylabel("True Positive Rate")
    plt.title(f"{roc_title}\nMean AUC = {mean_auc:.4f} +- {std_auc:.4f}")
    plt.legend(loc="lower right", fontsize=9)
    plt.tight_layout()

    if save_roc_path is not None:
        plt.savefig(save_roc_path, dpi=150, bbox_inches="tight")

    plt.show()

    print("====5 fold cv roc summary === ")
    print("Fold AUCs:", [f"{x:.4f}" for x in fold_aucs])
    print(f"Mean AUC = {mean_auc:.4f} +- {std_auc:.4f}")
    print(f"OOF AUC = {oof_auc:.4f}")

    return {
        "fold_auc": fold_aucs,
        "mean_auc": mean_auc,
        "std_auc": std_auc,
        "oof_auc": oof_auc
    }

# %%
def plot_confusion_matrices_paper(model_info_list, save_path=None):
    n = len(model_info_list)
    ncols = 3
    nrows = (n + ncols -1) // ncols
    
    fig, axes = plt.subplots(nrows, ncols, figsize=(5 * ncols, 4.5 * nrows))
    axes = axes.flatten()

    for i, info in enumerate(model_info_list):
        y_pred = (np.array(info["y_prob"]) > 0.5).astype(int)
        cm = confusion_matrix(info["y_true"], y_pred)
        disp = ConfusionMatrixDisplay(confusion_matrix=cm,
                                      display_labels=["Benign", "Malignant"])
        disp.plot(ax=axes[i], colorbar=False, cmap="Blues")
        auc_val = roc_auc_score(info["y_true"], info["y_prob"])
        acc_val = accuracy_score(info["y_true"], y_pred)
        sens_val = recall_score(info["y_true"], y_pred, zero_division=0)
        axes[i].set_title(
            f'{info["name"]}\nACC={acc_val:.3f}  AUC={auc_val:.3f}  Sens={sens_val:.3f}',
            fontsize=10, fontweight='bold'
        )

    for j in range(i + 1, len(axes)):
        fig.delaxes(axes[j])
        
    fig.suptitle("Confusion Matrics - CT Binary Classification",
                 fontsize=14, fontweight='bold', y=1.01)
    plt.tight_layout()

    if save_path:
        fig.savefig(save_path, dpi=300, bbox_inches="tight")
        print(f"Confusion matrix figure saved -> {save_path}")
    plt.show()
    return fig

# %%
def get_best_fold(cv_df):
    """ROC-AUC 기준 최고 fold 반환"""
    idx = cv_df["ROC-AUC"].idxmax()
    return int(cv_df.loc[idx, "fold"])

def collect_predictions_from_best(model_name, model_type, build_fn, best_fold, norm_type="imagenet"):
    _, val_loader, _ = make_fold_loaders(best_fold, norm_type=norm_type)
    best_path = OUTPUT_DIR / f"{model_name}_fold{best_fold}_best.pth"

    model = load_model(model_type, best_path, device)
    metrics = eval_confusion(model, val_loader, device, threshold=0.5)

    del model
    gc.collect()
    if torch.cuda.is_available():
        torch.cuda.empty_cache()

    return metrics["y_true"], metrics["y_prob"], metrics

# %%
MODEL_REGISTRY = [
    dict(name="ResNet18\n(ImageNet)", model_name="ResNet18_ImageNet",
         model_type="resnet18_imagenet",
         build_fn=lambda: build_resnet18_patient_model(load_pretrained=False),
         cv_df=resnet50_imagenet_cv_df, color="#aec7e8", norm_type="imagenet"),
    dict(name="ResNet50\n(ImageNet)", model_name="ResNet50_ImageNet",
         model_type="resnet50_imagenet",
         build_fn=lambda: build_resnet50_patient_model(load_pretrained=False),
         cv_df=resnet50_imagenet_cv_df, color="#1f77b4", norm_type="imagenet"),
    dict(name="ResNet18\n(RadImageNet)", model_name="ResNet18_RadImageNet",
         model_type="resnet18_radimagenet",
         build_fn=lambda: build_resnet18_radimagenet_patient_model(load_pretrained=False),
         cv_df=resnet18_rad_cv_df, color="#2ca02c", norm_type="radimagenet"),
    dict(name="ResNet50\n(RadImageNet)", model_name="ResNet50_RadImageNet",
         model_type="resnet50_radimagenet",
         build_fn=lambda: build_resnet50_radimagenet_patient_model(load_pretrained=False),
         cv_df=resnet50_rad_cv_df, color="#ff7f0e", norm_type="radimagenet"),
    dict(name="ViT-B/16\n(ImageNet)", model_name="ViT-B16",
         model_type="vit",
         build_fn=lambda: build_vit_patient_model(load_pretrained=False),
         cv_df=vit_cv_df, color="#d62728", norm_type="imagenet"),
    dict(name="Hybrid\n(R18+ViT)", model_name="Hybrid_R18",
         model_type="hybrid_r18",
         build_fn=lambda: build_hybrid_r18_patient_model(load_pretrained=False),
         cv_df=hybrid_r18_cv_df, color="#8c564b", norm_type="imagenet"),
    dict(name="Hybrid\n(R50+ViT)", model_name="Hybrid_R50",
         model_type="hybrid_r50",
         build_fn=lambda: build_hybrid_patient_model(load_pretrained=False),
         cv_df=hybrid_cv_df, color="#9467bd", norm_type="imagenet"),
]

# %%
model_info_list = []
fold_results_per_model = {}

for entry in MODEL_REGISTRY:
    best_fold = get_best_fold(entry["cv_df"])
    print(f"\n[{entry['model_name']}] Best fold = {best_fold} | norm={entry['norm_type']}")

    y_true, y_prob, metrics = collect_predictions_from_best(
        model_name=entry["model_name"],
        model_type=entry["model_type"],
        build_fn=entry["build_fn"],
        best_fold=best_fold,
        norm_type=entry["norm_type"]
    )
    model_info_list.append({
        "name": entry["name"],
        "y_true": y_true,
        "y_prob": y_prob,
        "metrics": metrics,
        "color": entry["color"],
    })

    fold_results = []
    for fold_idx in FOLDS:
        _, vl, _ = make_fold_loaders(fold_idx, norm_type=entry["norm_type"])
        fp = OUTPUT_DIR / f"{entry['model_name']}_fold{fold_idx}_best.pth"
        m = load_model(entry["model_type"], fp, device)
        mt = eval_confusion(m, vl, device, threshold = 0.5)
        fold_results.append({"y_true": mt["y_true"], "y_prob": mt["y_prob"]})
        del m; gc.collect()
        if torch.cuda.is_available(): torch.cuda.empty_cache()

    fold_results_per_model[entry["model_name"]] = fold_results

for entry in MODEL_REGISTRY:
    plot_cv_roc_pr(
        fold_results=fold_results_per_model[entry["model_name"]],
        roc_title=f"{entry['model_name']} 5-fold CV ROC Curve",
        save_roc_path=FIGURE_DIR / f"{entry['model_name']}_cv_roc.png",
        show_each_fold=True,
        ddof=1
    )
# Out:
# [ResNet18_ImageNet] Best fold = 1 | norm=imagenet
# [FOLD 1] Train benign(0): 1605, malignant(1): 444, pos_weight=3.6149
#
# --Final Evaluation (threshold=0.5) --
# Accuracy: 0.9064
# ROC-AUC : 0.9772
# F1-score : 0.8110
# Sensitivity : 0.9279
# Confusion Matrix:
# [[362  40]
#  [  8 103]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0     0.9784    0.9005    0.9378       402
#            1     0.7203    0.9279    0.8110       111
#
#     accuracy                         0.9064       513
#    macro avg     0.8493    0.9142    0.8744       513
# weighted avg     0.9225    0.9064    0.9104       513
#
# [FOLD 1] Train benign(0): 1605, malignant(1): 444, pos_weight=3.6149
#
# --Final Evaluation (threshold=0.5) --
# Accuracy: 0.9064
# ROC-AUC : 0.9772
# F1-score : 0.8110
# Sensitivity : 0.9279
# Confusion Matrix:
# [[362  40]
#  [  8 103]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0     0.9784    0.9005    0.9378       402
#            1     0.7203    0.9279    0.8110       111
#
#     accuracy                         0.9064       513
#    macro avg     0.8493    0.9142    0.8744       513
# weighted avg     0.9225    0.9064    0.9104       513
#
# [FOLD 2] Train benign(0): 1605, malignant(1): 444, pos_weight=3.6149
#
# --Final Evaluation (threshold=0.5) --
# Accuracy: 0.8596
# ROC-AUC : 0.9515
# F1-score : 0.7372
# Sensitivity : 0.9099
# Confusion Matrix:
# [[340  62]
#  [ 10 101]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0     0.9714    0.8458    0.9043       402
#            1     0.6196    0.9099    0.7372       111
#
#     accuracy                         0.8596       513
#    macro avg     0.7955    0.8778    0.8207       513
# weighted avg     0.8953    0.8596    0.8681       513
#
# [FOLD 3] Train benign(0): 1606, malignant(1): 444, pos_weight=3.6171
#
# --Final Evaluation (threshold=0.5) --
# Accuracy: 0.9121
# ROC-AUC : 0.9674
# F1-score : 0.8101
# Sensitivity : 0.8649
# Confusion Matrix:
# [[371  30]
#  [ 15  96]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0     0.9611    0.9252    0.9428       401
#            1     0.7619    0.8649    0.8101       111
#
#     accuracy                         0.9121       512
#    macro avg     0.8615    0.8950    0.8765       512
# weighted avg     0.9179    0.9121    0.9141       512
#
# [FOLD 4] Train benign(0): 1606, malignant(1): 444, pos_weight=3.6171
#
# --Final Evaluation (threshold=0.5) --
# Accuracy: 0.8770
# ROC-AUC : 0.9587
# F1-score : 0.7549
# Sensitivity : 0.8739
# Confusion Matrix:
# [[352  49]
#  [ 14  97]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0     0.9617    0.8778    0.9179       401
#            1     0.6644    0.8739    0.7549       111
#
#     accuracy                         0.8770       512
#    macro avg     0.8131    0.8758    0.8364       512
# weighted avg     0.8973    0.8770    0.8825       512
#
# [FOLD 5] Train benign(0): 1606, malignant(1): 444, pos_weight=3.6171
#
# --Final Evaluation (threshold=0.5) --
# Accuracy: 0.8945
# ROC-AUC : 0.9569
# F1-score : 0.7891
# Sensitivity : 0.9099
# Confusion Matrix:
# [[357  44]
#  [ 10 101]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0     0.9728    0.8903    0.9297       401
#            1     0.6966    0.9099    0.7891       111
#
#     accuracy                         0.8945       512
#    macro avg     0.8347    0.9001    0.8594       512
# weighted avg     0.9129    0.8945    0.8992       512
#
#
# [ResNet50_ImageNet] Best fold = 1 | norm=imagenet
# [FOLD 1] Train benign(0): 1605, malignant(1): 444, pos_weight=3.6149
#
# --Final Evaluation (threshold=0.5) --
# Accuracy: 0.9162
# ROC-AUC : 0.9859
# F1-score : 0.8340
# Sensitivity : 0.9730
# Confusion Matrix:
# [[362  40]
#  [  3 108]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0     0.9918    0.9005    0.9439       402
#            1     0.7297    0.9730    0.8340       111
#
#     accuracy                         0.9162       513
#    macro avg     0.8608    0.9367    0.8890       513
# weighted avg     0.9351    0.9162    0.9201       513
#
# [FOLD 1] Train benign(0): 1605, malignant(1): 444, pos_weight=3.6149
#
# --Final Evaluation (threshold=0.5) --
# Accuracy: 0.9162
# ROC-AUC : 0.9859
# F1-score : 0.8340
# Sensitivity : 0.9730
# Confusion Matrix:
# [[362  40]
#  [  3 108]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0     0.9918    0.9005    0.9439       402
#            1     0.7297    0.9730    0.8340       111
#
#     accuracy                         0.9162       513
#    macro avg     0.8608    0.9367    0.8890       513
# weighted avg     0.9351    0.9162    0.9201       513
#
# [FOLD 2] Train benign(0): 1605, malignant(1): 444, pos_weight=3.6149
#
# --Final Evaluation (threshold=0.5) --
# Accuracy: 0.8889
# ROC-AUC : 0.9335
# F1-score : 0.7635
# Sensitivity : 0.8288
# Confusion Matrix:
# [[364  38]
#  [ 19  92]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0     0.9504    0.9055    0.9274       402
#            1     0.7077    0.8288    0.7635       111
#
#     accuracy                         0.8889       513
#    macro avg     0.8290    0.8672    0.8454       513
# weighted avg     0.8979    0.8889    0.8919       513
#
# [FOLD 3] Train benign(0): 1606, malignant(1): 444, pos_weight=3.6171
#
# --Final Evaluation (threshold=0.5) --
# Accuracy: 0.9160
# ROC-AUC : 0.9585
# F1-score : 0.8216
# Sensitivity : 0.8919
# Confusion Matrix:
# [[370  31]
#  [ 12  99]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0     0.9686    0.9227    0.9451       401
#            1     0.7615    0.8919    0.8216       111
#
#     accuracy                         0.9160       512
#    macro avg     0.8651    0.9073    0.8833       512
# weighted avg     0.9237    0.9160    0.9183       512
#
# [FOLD 4] Train benign(0): 1606, malignant(1): 444, pos_weight=3.6171
#
# --Final Evaluation (threshold=0.5) --
# Accuracy: 0.8984
# ROC-AUC : 0.9599
# F1-score : 0.7937
# Sensitivity : 0.9009
# Confusion Matrix:
# [[360  41]
#  [ 11 100]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0     0.9704    0.8978    0.9326       401
#            1     0.7092    0.9009    0.7937       111
#
#     accuracy                         0.8984       512
#    macro avg     0.8398    0.8993    0.8631       512
# weighted avg     0.9137    0.8984    0.9025       512
#
# [FOLD 5] Train benign(0): 1606, malignant(1): 444, pos_weight=3.6171
#
# --Final Evaluation (threshold=0.5) --
# Accuracy: 0.8848
# ROC-AUC : 0.9584
# F1-score : 0.7739
# Sensitivity : 0.9099
# Confusion Matrix:
# [[352  49]
#  [ 10 101]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0     0.9724    0.8778    0.9227       401
#            1     0.6733    0.9099    0.7739       111
#
#     accuracy                         0.8848       512
#    macro avg     0.8229    0.8939    0.8483       512
# weighted avg     0.9075    0.8848    0.8904       512
#
#
# [ResNet18_RadImageNet] Best fold = 1 | norm=radimagenet
# [FOLD 1] Train benign(0): 1605, malignant(1): 444, pos_weight=3.6149
#
# --Final Evaluation (threshold=0.5) --
# Accuracy: 0.9474
# ROC-AUC : 0.9873
# F1-score : 0.8861
# Sensitivity : 0.9459
# Confusion Matrix:
# [[381  21]
#  [  6 105]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0     0.9845    0.9478    0.9658       402
#            1     0.8333    0.9459    0.8861       111
#
#     accuracy                         0.9474       513
#    macro avg     0.9089    0.9469    0.9259       513
# weighted avg     0.9518    0.9474    0.9485       513
#
# [FOLD 1] Train benign(0): 1605, malignant(1): 444, pos_weight=3.6149
#
# --Final Evaluation (threshold=0.5) --
# Accuracy: 0.9474
# ROC-AUC : 0.9873
# F1-score : 0.8861
# Sensitivity : 0.9459
# Confusion Matrix:
# [[381  21]
#  [  6 105]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0     0.9845    0.9478    0.9658       402
#            1     0.8333    0.9459    0.8861       111
#
#     accuracy                         0.9474       513
#    macro avg     0.9089    0.9469    0.9259       513
# weighted avg     0.9518    0.9474    0.9485       513
#
# [FOLD 2] Train benign(0): 1605, malignant(1): 444, pos_weight=3.6149
#
# --Final Evaluation (threshold=0.5) --
# Accuracy: 0.8772
# ROC-AUC : 0.9554
# F1-score : 0.7586
# Sensitivity : 0.8919
# Confusion Matrix:
# [[351  51]
#  [ 12  99]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0     0.9669    0.8731    0.9176       402
#            1     0.6600    0.8919    0.7586       111
#
#     accuracy                         0.8772       513
#    macro avg     0.8135    0.8825    0.8381       513
# weighted avg     0.9005    0.8772    0.8832       513
#
# [FOLD 3] Train benign(0): 1606, malignant(1): 444, pos_weight=3.6171
#
# --Final Evaluation (threshold=0.5) --
# Accuracy: 0.8691
# ROC-AUC : 0.9676
# F1-score : 0.7599
# Sensitivity : 0.9550
# Confusion Matrix:
# [[339  62]
#  [  5 106]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0     0.9855    0.8454    0.9101       401
#            1     0.6310    0.9550    0.7599       111
#
#     accuracy                         0.8691       512
#    macro avg     0.8082    0.9002    0.8350       512
# weighted avg     0.9086    0.8691    0.8775       512
#
# [FOLD 4] Train benign(0): 1606, malignant(1): 444, pos_weight=3.6171
#
# --Final Evaluation (threshold=0.5) --
# Accuracy: 0.9023
# ROC-AUC : 0.9576
# F1-score : 0.7899
# Sensitivity : 0.8468
# Confusion Matrix:
# [[368  33]
#  [ 17  94]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0     0.9558    0.9177    0.9364       401
#            1     0.7402    0.8468    0.7899       111
#
#     accuracy                         0.9023       512
#    macro avg     0.8480    0.8823    0.8632       512
# weighted avg     0.9091    0.9023    0.9046       512
#
# [FOLD 5] Train benign(0): 1606, malignant(1): 444, pos_weight=3.6171
#
# --Final Evaluation (threshold=0.5) --
# Accuracy: 0.9023
# ROC-AUC : 0.9656
# F1-score : 0.8016
# Sensitivity : 0.9099
# Confusion Matrix:
# [[361  40]
#  [ 10 101]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0     0.9730    0.9002    0.9352       401
#            1     0.7163    0.9099    0.8016       111
#
#     accuracy                         0.9023       512
#    macro avg     0.8447    0.9051    0.8684       512
# weighted avg     0.9174    0.9023    0.9063       512
#
#
# [ResNet50_RadImageNet] Best fold = 1 | norm=radimagenet
# [FOLD 1] Train benign(0): 1605, malignant(1): 444, pos_weight=3.6149
#
# --Final Evaluation (threshold=0.5) --
# Accuracy: 0.9435
# ROC-AUC : 0.9812
# F1-score : 0.8734
# Sensitivity : 0.9009
# Confusion Matrix:
# [[384  18]
#  [ 11 100]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0     0.9722    0.9552    0.9636       402
#            1     0.8475    0.9009    0.8734       111
#
#     accuracy                         0.9435       513
#    macro avg     0.9098    0.9281    0.9185       513
# weighted avg     0.9452    0.9435    0.9441       513
#
# [FOLD 1] Train benign(0): 1605, malignant(1): 444, pos_weight=3.6149
#
# --Final Evaluation (threshold=0.5) --
# Accuracy: 0.9435
# ROC-AUC : 0.9812
# F1-score : 0.8734
# Sensitivity : 0.9009
# Confusion Matrix:
# [[384  18]
#  [ 11 100]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0     0.9722    0.9552    0.9636       402
#            1     0.8475    0.9009    0.8734       111
#
#     accuracy                         0.9435       513
#    macro avg     0.9098    0.9281    0.9185       513
# weighted avg     0.9452    0.9435    0.9441       513
#
# [FOLD 2] Train benign(0): 1605, malignant(1): 444, pos_weight=3.6149
#
# --Final Evaluation (threshold=0.5) --
# Accuracy: 0.8869
# ROC-AUC : 0.9399
# F1-score : 0.7698
# Sensitivity : 0.8739
# Confusion Matrix:
# [[358  44]
#  [ 14  97]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0     0.9624    0.8905    0.9251       402
#            1     0.6879    0.8739    0.7698       111
#
#     accuracy                         0.8869       513
#    macro avg     0.8252    0.8822    0.8475       513
# weighted avg     0.9030    0.8869    0.8915       513
#
# [FOLD 3] Train benign(0): 1606, malignant(1): 444, pos_weight=3.6171
#
# --Final Evaluation (threshold=0.5) --
# Accuracy: 0.8906
# ROC-AUC : 0.9569
# F1-score : 0.7795
# Sensitivity : 0.8919
# Confusion Matrix:
# [[357  44]
#  [ 12  99]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0     0.9675    0.8903    0.9273       401
#            1     0.6923    0.8919    0.7795       111
#
#     accuracy                         0.8906       512
#    macro avg     0.8299    0.8911    0.8534       512
# weighted avg     0.9078    0.8906    0.8952       512
#
# [FOLD 4] Train benign(0): 1606, malignant(1): 444, pos_weight=3.6171
#
# --Final Evaluation (threshold=0.5) --
# Accuracy: 0.8691
# ROC-AUC : 0.9635
# F1-score : 0.7546
# Sensitivity : 0.9279
# Confusion Matrix:
# [[342  59]
#  [  8 103]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0     0.9771    0.8529    0.9108       401
#            1     0.6358    0.9279    0.7546       111
#
#     accuracy                         0.8691       512
#    macro avg     0.8065    0.8904    0.8327       512
# weighted avg     0.9031    0.8691    0.8769       512
#
# [FOLD 5] Train benign(0): 1606, malignant(1): 444, pos_weight=3.6171
#
# --Final Evaluation (threshold=0.5) --
# Accuracy: 0.8770
# ROC-AUC : 0.9561
# F1-score : 0.7605
# Sensitivity : 0.9009
# Confusion Matrix:
# [[349  52]
#  [ 11 100]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0     0.9694    0.8703    0.9172       401
#            1     0.6579    0.9009    0.7605       111
#
#     accuracy                         0.8770       512
#    macro avg     0.8137    0.8856    0.8388       512
# weighted avg     0.9019    0.8770    0.8832       512
#
#
# [ViT-B16] Best fold = 1 | norm=imagenet
# [FOLD 1] Train benign(0): 1605, malignant(1): 444, pos_weight=3.6149
#
# --Final Evaluation (threshold=0.5) --
# Accuracy: 0.9298
# ROC-AUC : 0.9815
# F1-score : 0.8548
# Sensitivity : 0.9550
# Confusion Matrix:
# [[371  31]
#  [  5 106]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0     0.9867    0.9229    0.9537       402
#            1     0.7737    0.9550    0.8548       111
#
#     accuracy                         0.9298       513
#    macro avg     0.8802    0.9389    0.9043       513
# weighted avg     0.9406    0.9298    0.9323       513
#
# [FOLD 1] Train benign(0): 1605, malignant(1): 444, pos_weight=3.6149
#
# --Final Evaluation (threshold=0.5) --
# Accuracy: 0.9298
# ROC-AUC : 0.9815
# F1-score : 0.8548
# Sensitivity : 0.9550
# Confusion Matrix:
# [[371  31]
#  [  5 106]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0     0.9867    0.9229    0.9537       402
#            1     0.7737    0.9550    0.8548       111
#
#     accuracy                         0.9298       513
#    macro avg     0.8802    0.9389    0.9043       513
# weighted avg     0.9406    0.9298    0.9323       513
#
# [FOLD 2] Train benign(0): 1605, malignant(1): 444, pos_weight=3.6149
#
# --Final Evaluation (threshold=0.5) --
# Accuracy: 0.8791
# ROC-AUC : 0.9481
# F1-score : 0.7597
# Sensitivity : 0.8829
# Confusion Matrix:
# [[353  49]
#  [ 13  98]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0     0.9645    0.8781    0.9193       402
#            1     0.6667    0.8829    0.7597       111
#
#     accuracy                         0.8791       513
#    macro avg     0.8156    0.8805    0.8395       513
# weighted avg     0.9000    0.8791    0.8847       513
#
# [FOLD 3] Train benign(0): 1606, malignant(1): 444, pos_weight=3.6171
#
# --Final Evaluation (threshold=0.5) --
# Accuracy: 0.9160
# ROC-AUC : 0.9713
# F1-score : 0.8245
# Sensitivity : 0.9099
# Confusion Matrix:
# [[368  33]
#  [ 10 101]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0     0.9735    0.9177    0.9448       401
#            1     0.7537    0.9099    0.8245       111
#
#     accuracy                         0.9160       512
#    macro avg     0.8636    0.9138    0.8846       512
# weighted avg     0.9259    0.9160    0.9187       512
#
# [FOLD 4] Train benign(0): 1606, malignant(1): 444, pos_weight=3.6171
#
# --Final Evaluation (threshold=0.5) --
# Accuracy: 0.8770
# ROC-AUC : 0.9424
# F1-score : 0.7586
# Sensitivity : 0.8919
# Confusion Matrix:
# [[350  51]
#  [ 12  99]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0     0.9669    0.8728    0.9174       401
#            1     0.6600    0.8919    0.7586       111
#
#     accuracy                         0.8770       512
#    macro avg     0.8134    0.8824    0.8380       512
# weighted avg     0.9003    0.8770    0.8830       512
#
# [FOLD 5] Train benign(0): 1606, malignant(1): 444, pos_weight=3.6171
#
# --Final Evaluation (threshold=0.5) --
# Accuracy: 0.8906
# ROC-AUC : 0.9517
# F1-score : 0.7760
# Sensitivity : 0.8739
# Confusion Matrix:
# [[359  42]
#  [ 14  97]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0     0.9625    0.8953    0.9276       401
#            1     0.6978    0.8739    0.7760       111
#
#     accuracy                         0.8906       512
#    macro avg     0.8302    0.8846    0.8518       512
# weighted avg     0.9051    0.8906    0.8948       512
#
#
# [Hybrid_R18] Best fold = 1 | norm=imagenet
# [FOLD 1] Train benign(0): 1605, malignant(1): 444, pos_weight=3.6149
#
# --Final Evaluation (threshold=0.5) --
# Accuracy: 0.9279
# ROC-AUC : 0.9815
# F1-score : 0.8465
# Sensitivity : 0.9189
# Confusion Matrix:
# [[374  28]
#  [  9 102]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0     0.9765    0.9303    0.9529       402
#            1     0.7846    0.9189    0.8465       111
#
#     accuracy                         0.9279       513
#    macro avg     0.8806    0.9246    0.8997       513
# weighted avg     0.9350    0.9279    0.9298       513
#
# [FOLD 1] Train benign(0): 1605, malignant(1): 444, pos_weight=3.6149
#
# --Final Evaluation (threshold=0.5) --
# Accuracy: 0.9279
# ROC-AUC : 0.9815
# F1-score : 0.8465
# Sensitivity : 0.9189
# Confusion Matrix:
# [[374  28]
#  [  9 102]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0     0.9765    0.9303    0.9529       402
#            1     0.7846    0.9189    0.8465       111
#
#     accuracy                         0.9279       513
#    macro avg     0.8806    0.9246    0.8997       513
# weighted avg     0.9350    0.9279    0.9298       513
#
# [FOLD 2] Train benign(0): 1605, malignant(1): 444, pos_weight=3.6149
#
# --Final Evaluation (threshold=0.5) --
# Accuracy: 0.8967
# ROC-AUC : 0.9397
# F1-score : 0.7686
# Sensitivity : 0.7928
# Confusion Matrix:
# [[372  30]
#  [ 23  88]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0     0.9418    0.9254    0.9335       402
#            1     0.7458    0.7928    0.7686       111
#
#     accuracy                         0.8967       513
#    macro avg     0.8438    0.8591    0.8510       513
# weighted avg     0.8994    0.8967    0.8978       513
#
# [FOLD 3] Train benign(0): 1606, malignant(1): 444, pos_weight=3.6171
#
# --Final Evaluation (threshold=0.5) --
# Accuracy: 0.9062
# ROC-AUC : 0.9748
# F1-score : 0.8110
# Sensitivity : 0.9279
# Confusion Matrix:
# [[361  40]
#  [  8 103]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0     0.9783    0.9002    0.9377       401
#            1     0.7203    0.9279    0.8110       111
#
#     accuracy                         0.9062       512
#    macro avg     0.8493    0.9141    0.8743       512
# weighted avg     0.9224    0.9062    0.9102       512
#
# [FOLD 4] Train benign(0): 1606, malignant(1): 444, pos_weight=3.6171
#
# --Final Evaluation (threshold=0.5) --
# Accuracy: 0.8984
# ROC-AUC : 0.9611
# F1-score : 0.7953
# Sensitivity : 0.9099
# Confusion Matrix:
# [[359  42]
#  [ 10 101]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0     0.9729    0.8953    0.9325       401
#            1     0.7063    0.9099    0.7953       111
#
#     accuracy                         0.8984       512
#    macro avg     0.8396    0.9026    0.8639       512
# weighted avg     0.9151    0.8984    0.9027       512
#
# [FOLD 5] Train benign(0): 1606, malignant(1): 444, pos_weight=3.6171
#
# --Final Evaluation (threshold=0.5) --
# Accuracy: 0.8945
# ROC-AUC : 0.9549
# F1-score : 0.7857
# Sensitivity : 0.8919
# Confusion Matrix:
# [[359  42]
#  [ 12  99]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0     0.9677    0.8953    0.9301       401
#            1     0.7021    0.8919    0.7857       111
#
#     accuracy                         0.8945       512
#    macro avg     0.8349    0.8936    0.8579       512
# weighted avg     0.9101    0.8945    0.8988       512
#
#
# [Hybrid_R50] Best fold = 1 | norm=imagenet
# [FOLD 1] Train benign(0): 1605, malignant(1): 444, pos_weight=3.6149
#
# --Final Evaluation (threshold=0.5) --
# Accuracy: 0.9123
# ROC-AUC : 0.9832
# F1-score : 0.8235
# Sensitivity : 0.9459
# Confusion Matrix:
# [[363  39]
#  [  6 105]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0     0.9837    0.9030    0.9416       402
#            1     0.7292    0.9459    0.8235       111
#
#     accuracy                         0.9123       513
#    macro avg     0.8565    0.9245    0.8826       513
# weighted avg     0.9287    0.9123    0.9161       513
#
# [FOLD 1] Train benign(0): 1605, malignant(1): 444, pos_weight=3.6149
#
# --Final Evaluation (threshold=0.5) --
# Accuracy: 0.9123
# ROC-AUC : 0.9832
# F1-score : 0.8235
# Sensitivity : 0.9459
# Confusion Matrix:
# [[363  39]
#  [  6 105]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0     0.9837    0.9030    0.9416       402
#            1     0.7292    0.9459    0.8235       111
#
#     accuracy                         0.9123       513
#    macro avg     0.8565    0.9245    0.8826       513
# weighted avg     0.9287    0.9123    0.9161       513
#
# [FOLD 2] Train benign(0): 1605, malignant(1): 444, pos_weight=3.6149
#
# --Final Evaluation (threshold=0.5) --
# Accuracy: 0.8908
# ROC-AUC : 0.9668
# F1-score : 0.7846
# Sensitivity : 0.9189
# Confusion Matrix:
# [[355  47]
#  [  9 102]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0     0.9753    0.8831    0.9269       402
#            1     0.6846    0.9189    0.7846       111
#
#     accuracy                         0.8908       513
#    macro avg     0.8299    0.9010    0.8558       513
# weighted avg     0.9124    0.8908    0.8961       513
#
# [FOLD 3] Train benign(0): 1606, malignant(1): 444, pos_weight=3.6171
#
# --Final Evaluation (threshold=0.5) --
# Accuracy: 0.9023
# ROC-AUC : 0.9571
# F1-score : 0.7984
# Sensitivity : 0.8919
# Confusion Matrix:
# [[363  38]
#  [ 12  99]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0     0.9680    0.9052    0.9356       401
#            1     0.7226    0.8919    0.7984       111
#
#     accuracy                         0.9023       512
#    macro avg     0.8453    0.8986    0.8670       512
# weighted avg     0.9148    0.9023    0.9058       512
#
# [FOLD 4] Train benign(0): 1606, malignant(1): 444, pos_weight=3.6171
#
# --Final Evaluation (threshold=0.5) --
# Accuracy: 0.9062
# ROC-AUC : 0.9642
# F1-score : 0.8049
# Sensitivity : 0.8919
# Confusion Matrix:
# [[365  36]
#  [ 12  99]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0     0.9682    0.9102    0.9383       401
#            1     0.7333    0.8919    0.8049       111
#
#     accuracy                         0.9062       512
#    macro avg     0.8508    0.9011    0.8716       512
# weighted avg     0.9173    0.9062    0.9094       512
#
# [FOLD 5] Train benign(0): 1606, malignant(1): 444, pos_weight=3.6171
#
# --Final Evaluation (threshold=0.5) --
# Accuracy: 0.8887
# ROC-AUC : 0.9417
# F1-score : 0.7729
# Sensitivity : 0.8739
# Confusion Matrix:
# [[358  43]
#  [ 14  97]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0     0.9624    0.8928    0.9263       401
#            1     0.6929    0.8739    0.7729       111
#
#     accuracy                         0.8887       512
#    macro avg     0.8276    0.8833    0.8496       512
# weighted avg     0.9039    0.8887    0.8930       512
# ====5 fold cv roc summary ===
# Fold AUCs: ['0.9772', '0.9515', '0.9674', '0.9587', '0.9569']
# Mean AUC = 0.9623 +- 0.0090
# OOF AUC = 0.9614
# ====5 fold cv roc summary ===
# Fold AUCs: ['0.9859', '0.9335', '0.9585', '0.9599', '0.9584']
# Mean AUC = 0.9592 +- 0.0166
# OOF AUC = 0.9599
# ====5 fold cv roc summary ===
# Fold AUCs: ['0.9873', '0.9554', '0.9676', '0.9576', '0.9656']
# Mean AUC = 0.9667 +- 0.0113
# OOF AUC = 0.9619
# ====5 fold cv roc summary ===
# Fold AUCs: ['0.9812', '0.9399', '0.9569', '0.9635', '0.9561']
# Mean AUC = 0.9595 +- 0.0133
# OOF AUC = 0.9584
# ====5 fold cv roc summary ===
# Fold AUCs: ['0.9815', '0.9481', '0.9713', '0.9424', '0.9517']
# Mean AUC = 0.9590 +- 0.0149
# OOF AUC = 0.9594
# ====5 fold cv roc summary ===
# Fold AUCs: ['0.9815', '0.9397', '0.9748', '0.9611', '0.9549']
# Mean AUC = 0.9624 +- 0.0148
# OOF AUC = 0.9583
# ====5 fold cv roc summary ===
# Fold AUCs: ['0.9832', '0.9668', '0.9571', '0.9642', '0.9417']
# Mean AUC = 0.9626 +- 0.0135
# OOF AUC = 0.9602

# %%
cm_fig = plot_confusion_matrices_paper(
    model_info_list,
    save_path=FIGURE_DIR / "paper_confusion_matrices.png"
)

print("\n>>> All figures saved to:", FIGURE_DIR.resolve())
# Out:
# Confusion matrix figure saved -> ct_binary_figures_filter_ablation/paper_confusion_matrices.png
# >>> All figures saved to: /tf/notebooks/Image Encoder/Untitled Folder/ct_binary_figures_filter_ablation
