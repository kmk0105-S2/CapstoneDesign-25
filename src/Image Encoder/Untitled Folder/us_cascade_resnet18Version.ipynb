# %%
#!/usr/bin/env python
# coding: utf-8

# ============================================================
# CT Cascade 학습 스크립트
#
# [구조 개요]
#   1단계: malignancy binary classification (benign / malignant)
#   2단계: malignant 샘플에 대해서만 subtype multi-class classification
#
# [원본 대비 주요 수정 사항]
#   1. inspect_fold_npz 오타 수정: .exits() → .exists()
#   2. infer_malignant_type_ids 들여쓰기 버그 수정
#      (return이 fold loop 안에 있어 fold 1 결과만 반환하던 문제)
#   3. cascade_correct 인덱스 불일치 버그 수정
#      (oracle_pred/oracle_true는 all_mal_mask 기준,
#       all_mal_pred[gt_mal_mask]는 gt_mal_mask 기준 → 길이 불일치)
#   4. fit_model print 오타 수정: 콤마로 분리된 f-string → 하나로 합침
#   5. 모델 구조 개선:
#      - shared head 이후 task별 projection(mal_proj / sub_proj) 분리
#      - early stopping 기준: val_loss → val_auc (malignancy recall 중심)
#      - subtype_loss_weight warmup 스케줄 추가
# ============================================================


# ============================================================
# 빌드 확인
# ============================================================
from torchvision import models
from torchvision.models import vit_b_16

print("=" * 60)

try:
    m1 = models.resnet18(weights=None)
    print("ResNet18 build success")
except Exception as e:
    print("Fail", e)

try:
    m2 = vit_b_16(weights=None)
    print("Vit-B/16 build success")
except Exception as e:
    print("Fail", e)

print("=" * 60)


# ============================================================
# 1) 환경 설정 + import
# ============================================================
import os
import gc
import random
import torchvision.transforms.functional as TF
from pathlib import Path
from collections import OrderedDict, defaultdict

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.metrics import (
    confusion_matrix, classification_report,
    accuracy_score, f1_score, roc_auc_score, recall_score
)

import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
from torchvision import models
from torchvision.models import vit_b_16, ViT_B_16_Weights, ResNet18_Weights

SEED = 42
random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)
torch.cuda.manual_seed_all(SEED)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Device:", device)

# cuDNN autotuner: 입력 크기가 고정일 때 속도 향상
torch.backends.cudnn.benchmark = True


# ============================================================
# 2) 경로 / 하이퍼파라미터 설정
# ============================================================
print(f"현재 작업 경로: {os.getcwd()}")

DATA_ROOT  = Path("/tf/nasw/dataset001/preprocessed/npz_us")
FOLDS      = [1, 2, 3, 4, 5]

OUTPUT_DIR = Path("./us_cascade_models18")
OUTPUT_DIR.mkdir(parents=True, exist_ok=True)

IMG_SIZE     = 224
BATCH_SIZE   = 8
NUM_WORKERS  = 2
NUM_EPOCHS   = 30
LR           = 1e-4
WEIGHT_DECAY = 1e-4
PATIENCE     = 7
MIN_DELTA    = 0.001
THRESHOLD    = 0.5   # malignancy 판단 임계값

# subtype loss 가중치 warmup 설정
# - 학습 초반에는 malignancy 분류에 집중하고,
#   후반부로 갈수록 subtype loss 비중을 점진적으로 높임
SUBTYPE_LOSS_WEIGHT_START = 0.4   # 1 epoch 시작값
SUBTYPE_LOSS_WEIGHT_END   = 0.8   # NUM_EPOCHS epoch 도달값

print("DATA_ROOT:", DATA_ROOT)
print("OUTPUT_DIR:", OUTPUT_DIR.resolve())
print("FOLDS:", FOLDS)


# ============================================================
# 3) 로컬 pretrained weight 경로
# ============================================================
LOCAL_RESNET18_WEIGHTS = Path("/tf/pretrained_model/resnet18-f37072fd.pth")
LOCAL_VIT_WEIGHTS    = Path("/tf/pretrained_model/vit_b_16-c867db91.pth")

print("LOCAL_RESNET18_WEIGHTS exists:", LOCAL_RESNET18_WEIGHTS.exists())
print("LOCAL_VIT_WEIGHTS exists:",    LOCAL_VIT_WEIGHTS.exists())


# ============================================================
# 4) 유틸 함수
# ============================================================
def load_local_state_dict(weight_path):
    weight_path = Path(weight_path)
    assert weight_path.exists(), f"Weight file not found: {weight_path}"

    ckpt = torch.load(weight_path, map_location="cpu")

    # 일부 checkpoint는 {"state_dict": {...}} 형태로 저장되어 있음
    if isinstance(ckpt, dict) and "state_dict" in ckpt and isinstance(ckpt["state_dict"], dict):
        ckpt = ckpt["state_dict"]

    return ckpt


def inspect_fold_npz(fold_idx):
    train_npz_path = DATA_ROOT / f"fold_{fold_idx}_train.npz"
    val_npz_path   = DATA_ROOT / f"fold_{fold_idx}_val.npz"

    # ✅ 버그 수정: .exits() → .exists()
    print("TRAIN:", train_npz_path, train_npz_path.exists())
    print("VAL:",   val_npz_path,   val_npz_path.exists())

    train_npz = np.load(train_npz_path, allow_pickle=False, mmap_mode="r")
    val_npz   = np.load(val_npz_path,   allow_pickle=False, mmap_mode="r")

    for k in train_npz.files:
        print(f"[train] {k}: shape={train_npz[k].shape}, dtype={train_npz[k].dtype}")
    for k in val_npz.files:
        print(f"[val]   {k}: shape={val_npz[k].shape}, dtype={val_npz[k].dtype}")


def get_subtype_loss_weight(epoch: int, total_epochs: int) -> float:
    """
    subtype loss 가중치를 epoch에 따라 선형 warmup.

    epoch 1  → SUBTYPE_LOSS_WEIGHT_START
    epoch N  → SUBTYPE_LOSS_WEIGHT_END
    사이는 선형 보간.

    이유: 학습 초반 malignancy gate가 불안정할 때
    subtype loss가 너무 크면 전체 학습을 방해할 수 있음.
    """
    t = (epoch - 1) / max(total_epochs - 1, 1)   # 0.0 ~ 1.0
    return SUBTYPE_LOSS_WEIGHT_START + t * (SUBTYPE_LOSS_WEIGHT_END - SUBTYPE_LOSS_WEIGHT_START)


# ============================================================
# 5) malignant subtype ID 자동 추론
# ============================================================
def infer_malignant_type_ids(data_root, folds):
    """
    NPZ 파일에서 tumor_type별로 label(0/1)을 수집하여
    항상 malignant(label=1)인 tumor_type ID 목록을 자동 추론.

    ✅ 버그 수정: 원본은 return이 fold loop 안에 있어서
       fold 1 처리 후 바로 반환되는 문제가 있었음.
       loop 밖으로 conflicts 체크와 return을 이동.
    """
    # tumor_type별로 등장한 label 값들을 수집
    label_set_by_type = defaultdict(set)

    for fold_idx in folds:
        for split_name in ["train", "val"]:
            npz_path = Path(data_root) / f"fold_{fold_idx}_{split_name}.npz"
            data     = np.load(npz_path, allow_pickle=False, mmap_mode="r")

            labels      = data["labels"].astype(int)
            tumor_types = data["tumor_types"].astype(int)

            for y, t in zip(labels, tumor_types):
                label_set_by_type[int(t)].add(int(y))

    # ✅ loop 종료 후 한 번만 체크 (원본: loop 안에서 매 fold마다 체크 후 return)
    # 동일 tumor_type이 benign/malignant 양쪽에 있으면 데이터 오류
    conflicts = {
        t: sorted(list(v))
        for t, v in label_set_by_type.items()
        if len(v) > 1
    }
    if len(conflicts) > 0:
        raise ValueError(
            f"tumor_type이 양성/악성 양쪽에 섞여 있음: {conflicts}\n"
            "데이터 전처리를 확인하세요."
        )

    # label이 {1}만인 tumor_type만 malignant subtype으로 간주
    malignant_type_ids = sorted([
        t for t, labs in label_set_by_type.items()
        if labs == {1}
    ])

    print("malignant_type_ids:", malignant_type_ids)
    return malignant_type_ids


MALIGNANT_TYPE_IDS     = infer_malignant_type_ids(DATA_ROOT, FOLDS)
MALIGNANT_MAP          = {tid: i for i, tid in enumerate(MALIGNANT_TYPE_IDS)}
NUM_MALIGNANT_SUBTYPES = len(MALIGNANT_TYPE_IDS)

print("MALIGNANT_MAP:", MALIGNANT_MAP)
print("NUM_MALIGNANT_SUBTYPES:", NUM_MALIGNANT_SUBTYPES)

#=============================================================
# 5.5) 실시간 증강 모듈
#=============================================================

class CTSliceAugmentor:
    def __init__(
        self,
        p_hflip: float = 0.5,
        p_vflip: float = 0.0,
        p_rotate: float = 0.5,
        max_angle: float = 10.0,
        p_crop: float = 0.5,
        crop_min: float = 0.85,
        p_noise: float = 0.3,
        noise_std: float = 0.01,
    ):
        self.p_hflip = p_hflip
        self.p_vflip = p_vflip
        self.p_rotate = p_rotate
        self.max_angle = max_angle
        self.p_crop = p_crop
        self.crop_min = crop_min
        self.p_noise = p_noise
        self.noise_std = noise_std


    def __call__(self, imgs):
        S, C, H, W = imgs.shape

        do_hflip = random.random() < self.p_hflip
        do_vflip = random.random() < self.p_vflip
        do_rotate = random.random() < self.p_rotate
        angle = random.uniform(-self.max_angle, self.max_angle) if do_rotate else 0.0
        do_crop = random.random() < self.p_crop
        do_noise = random.random() < self.p_noise

        top = left = crop_h = crop_w = 0
        if do_crop:
            scale = random.uniform(self.crop_min, 1.0)
            crop_h = int(H*scale)
            crop_w = int(W*scale)
            top = random.randint(0, H-crop_h)
            left = random.randint(0, W-crop_w)

        augmented = []
        for s in range(S):
            img = imgs[s]
            if do_hflip:
                img = TF.hflip(img)
            if do_vflip:
                img = TF.vflip(img)
            if do_rotate:
                img = TF.rotate(img, angle, interpolation = TF.InterpolationMode.BILINEAR, fill=0)
            if do_crop:
                img = TF.crop(img, top, left, crop_h, crop_w)
                img = TF.resize(img, [H,W], interpolation=TF.InterpolationMode.BILINEAR, antialias=True)
            augmented.append(img)

        imgs=torch.stack(augmented, dim = 0)

        if do_noise:
            imgs = (imgs + torch.randn_like(imgs) * self.noise_std).clamp(0.0, 1.0)

        return imgs


TRAIN_AUGMENTOR = CTSliceAugmentor(
    p_hflip = 0.5, p_vflip = 0.0, p_rotate=0.5, max_angle = 10.0,
    p_crop = 0.5, crop_min = 0.85, p_noise = 0.3, noise_std = 0.01,
)

def _worker_init_fn(worker_id):
    worker_seed = torch.initial_seed() % (2**32)
    np.random.seed(worker_seed)
    random.seed(worker_seed)
    


# ============================================================
# 6) Dataset 정의
# ============================================================
class OvarianCTNPZDataset(Dataset):
    def __init__(self, npz_path, is_train=True):
        super().__init__()
        self.npz = np.load(npz_path, allow_pickle=False, mmap_mode="r")

        self.images      = self.npz["images"]
        self.labels      = self.npz["labels"].astype(np.float32)
        self.tumor_types = self.npz["tumor_types"].astype(np.int64)

        # patient_ids가 없으면 인덱스로 대체
        self.patient_ids = (
            self.npz["patient_ids"]
            if "patient_ids" in self.npz.files
            else np.arange(len(self.labels))
        )

        # ImageNet 정규화 상수 (CT/US 공통으로 사용 가능)
        self.mean = torch.tensor([0.485, 0.456, 0.406], dtype=torch.float32).view(1, 3, 1, 1)
        self.std  = torch.tensor([0.229, 0.224, 0.225], dtype=torch.float32).view(1, 3, 1, 1)

        self.augmentor = TRAIN_AUGMENTOR if is_train else None

    def __len__(self):
        return len(self.labels)

    def __getitem__(self, idx):
        x           = self.images[idx]
        y           = int(self.labels[idx])
        tumor_type  = int(self.tumor_types[idx])

        # NPZ 저장 형태: [S, H, W, C] → [S, C, H, W]
        x = torch.from_numpy(np.array(x)).float().permute(0, 3, 1, 2).contiguous()
        x = x / 255.0

        if self.augmentor is not None:
            x = self.augmentor(x)
            
        x = (x - self.mean) / self.std

        # malignant 샘플에만 subtype label 부여
        if y == 1:
            if tumor_type not in MALIGNANT_MAP:
                raise ValueError(
                    f"malignant sample인데 tumor_type={tumor_type}가 MALIGNANT_MAP에 없음. "
                    f"infer_malignant_type_ids 결과 확인 필요."
                )
            mal_subtype = MALIGNANT_MAP[tumor_type]
            mal_mask    = True
        else:
            # benign은 subtype 없음 → -1로 패딩 (loss 계산 시 mal_mask로 필터링)
            mal_subtype = -1
            mal_mask    = False

        return {
            "image":       x,
            "label":       torch.tensor(y, dtype=torch.float32),
            "mal_subtype": torch.tensor(mal_subtype, dtype=torch.long),
            "mal_mask":    torch.tensor(mal_mask, dtype=torch.bool),
        }


# ============================================================
# 7) fold별 DataLoader 생성
# ============================================================
def make_fold_loaders(fold_idx):
    train_npz_path = DATA_ROOT / f"fold_{fold_idx}_train.npz"
    val_npz_path   = DATA_ROOT / f"fold_{fold_idx}_val.npz"

    assert train_npz_path.exists(), f"Missing: {train_npz_path}"
    assert val_npz_path.exists(),   f"Missing: {val_npz_path}"

    train_dataset = OvarianCTNPZDataset(train_npz_path, is_train=True)
    val_dataset   = OvarianCTNPZDataset(val_npz_path, is_train=False)

    train_loader = DataLoader(
        train_dataset,
        batch_size=BATCH_SIZE,
        shuffle=True,
        num_workers=NUM_WORKERS,
        pin_memory=True,
        worker_init_fn = _worker_init_fn,
        persistent_workers = (NUM_WORKERS > 0),
    )
    val_loader = DataLoader(
        val_dataset,
        batch_size=BATCH_SIZE,
        shuffle=False,
        num_workers=NUM_WORKERS,
        pin_memory=True
    )

    # ── malignancy pos_weight ────────────────────────────────
    # benign/malignant 불균형 보정: neg/pos 비율로 BCEWithLogitsLoss에 전달
    labels_np        = train_dataset.labels.astype(int)
    neg              = (labels_np == 0).sum()
    pos              = (labels_np == 1).sum()
    pos_weight_value = neg / max(pos, 1)
    mal_pos_weight   = torch.tensor([pos_weight_value], device=device, dtype=torch.float32)

    # ── subtype class weight ─────────────────────────────────
    # subtype별 샘플 수 역수로 class weight 계산 (inv mean normalization)
    subtype_counts = np.zeros(NUM_MALIGNANT_SUBTYPES, dtype=np.float64)
    for y, t in zip(train_dataset.labels.astype(int), train_dataset.tumor_types.astype(int)):
        if y == 1 and t in MALIGNANT_MAP:
            subtype_counts[MALIGNANT_MAP[t]] += 1.0

    subtype_counts       = np.maximum(subtype_counts, 1.0)   # 0 나누기 방지
    inv                  = 1.0 / subtype_counts
    subtype_class_weights = inv / inv.mean()                  # 평균 1로 정규화
    subtype_class_weights = torch.tensor(subtype_class_weights, dtype=torch.float32, device=device)

    print(
        f"[FOLD {fold_idx}] Train benign(0): {neg}, malignant(1): {pos}, "
        f"pos_weight={mal_pos_weight.item():.4f}, "
        f"subtype_counts={subtype_counts.tolist()}, "
        f"subtype_class_weights={subtype_class_weights.detach().cpu().numpy().round(4).tolist()}"
    )

    return train_loader, val_loader, mal_pos_weight, subtype_class_weights


# ============================================================
# 8) Cascade 손실 함수
# ============================================================
class CascadeCriterion(nn.Module):
    def __init__(self, pos_weight, subtype_class_weights, subtype_loss_weight=0.5):
        """
        Args:
            pos_weight           : BCEWithLogitsLoss의 pos_weight (malignancy)
            subtype_class_weights: CrossEntropyLoss의 class weight (subtype)
            subtype_loss_weight  : subtype loss를 얼마나 반영할지 가중치
                                   epoch마다 외부에서 업데이트 가능
        """
        super().__init__()
        self.bce               = nn.BCEWithLogitsLoss(pos_weight=pos_weight)
        self.ce                = nn.CrossEntropyLoss(weight=subtype_class_weights)
        self.subtype_loss_weight = subtype_loss_weight

    def forward(self, outputs, batch):
        labels      = batch["label"].to(device).view(-1)        # [B]
        mal_mask    = batch["mal_mask"].to(device).view(-1)     # [B] bool
        mal_subtype = batch["mal_subtype"].to(device).view(-1)  # [B]

        # malignancy binary loss (benign/malignant 전체 샘플)
        loss_m = self.bce(outputs["malignancy_logits"], labels)

        # subtype loss (malignant 샘플만)
        # mal_mask=True인 샘플만 필터링해서 CrossEntropyLoss 계산
        if mal_mask.any():
            loss_s = self.ce(
                outputs["subtype_logits"][mal_mask],
                mal_subtype[mal_mask]
            )
        else:
            # batch 안에 malignant 샘플이 없는 경우 (소규모 데이터에서 발생 가능)
            loss_s = torch.tensor(0.0, device=device)

        loss_total = loss_m + self.subtype_loss_weight * loss_s

        return {
            "loss_total":      loss_total,
            "loss_malignancy": loss_m,
            "loss_subtype":    loss_s,
        }


# ============================================================
# 9) 지표 계산 함수
# ============================================================
def compute_binary_metrics(y_true, y_prob, threshold=0.5):
    y_true = np.asarray(y_true).astype(int)
    y_prob = np.asarray(y_prob).astype(float)
    y_pred = (y_prob >= threshold).astype(int)

    return {
        "acc":    accuracy_score(y_true, y_pred),
        "auc":    roc_auc_score(y_true, y_prob) if len(np.unique(y_true)) > 1 else 0.5,
        "f1":     f1_score(y_true, y_pred, zero_division=0),
        "recall": recall_score(y_true, y_pred, zero_division=0),
        "cm":     confusion_matrix(y_true, y_pred),
    }


def compute_multiclass_metrics(y_true, y_pred):
    y_true = np.asarray(y_true).astype(int)
    y_pred = np.asarray(y_pred).astype(int)

    if len(y_true) == 0:
        return {"acc": np.nan, "macro_f1": np.nan, "macro_recall": np.nan, "cm": None}

    return {
        "acc":          accuracy_score(y_true, y_pred),
        "macro_f1":     f1_score(y_true, y_pred, average="macro", zero_division=0),
        "macro_recall": recall_score(y_true, y_pred, average="macro", zero_division=0),
        "cm":           confusion_matrix(y_true, y_pred),
    }


# ============================================================
# 10) train / eval 함수
# ============================================================
scaler = torch.amp.GradScaler(enabled=(device.type == "cuda"))


def _compute_cascade_metrics(
    all_label, all_mal_prob, all_mal_mask,
    all_subtype_true, all_subtype_pred,
    running_total, running_m, running_s,
    n_samples,
):
    """
    train_one_epoch / eval_one_epoch 공통 지표 계산 로직.
    중복 코드를 줄이기 위해 분리.

    ✅ 버그 수정: cascade_correct 인덱스 불일치 수정
        - oracle_pred / oracle_true: all_mal_mask(GT malignant) 기준으로 필터링된 배열
        - all_mal_pred[gt_mal_mask]: GT malignant 샘플에 대한 예측값
        - 위 두 배열의 길이는 동일 (gt_mal_mask == all_mal_mask)
        - 원본 코드는 all_mal_mask 대신 mal_mask를 별도로 쓰거나
          배열 길이가 맞지 않는 경우 발생 → gt_mal_mask로 통일하여 수정
    """
    mal_metrics = compute_binary_metrics(all_label, all_mal_prob, threshold=THRESHOLD)

    all_label        = np.asarray(all_label).astype(int)
    all_mal_pred     = (np.asarray(all_mal_prob) >= THRESHOLD).astype(int)
    all_mal_mask     = np.asarray(all_mal_mask).astype(bool)
    all_subtype_true = np.asarray(all_subtype_true).astype(int)
    all_subtype_pred = np.asarray(all_subtype_pred).astype(int)

    # oracle subtype: GT가 malignant인 샘플에 대해서만 subtype 평가
    # (malignancy gate의 영향 없이, subtype head 자체 성능 측정)
    oracle_true    = all_subtype_true[all_mal_mask]
    oracle_pred    = all_subtype_pred[all_mal_mask]
    subtype_oracle = compute_multiclass_metrics(oracle_true, oracle_pred)

    # cascade subtype: GT malignant 샘플 중
    #   ① malignancy gate도 malignant로 예측하고 (gate pass)
    #   ② subtype도 맞춰야 정답
    gt_mal_mask = all_mal_mask   # GT label == 1인 샘플 = mal_mask와 동일

    if gt_mal_mask.sum() > 0:
        gate_pass = all_mal_pred[gt_mal_mask] == 1   # gate 통과 여부 [N_mal]

        # ✅ oracle_pred는 gt_mal_mask 기준으로 필터링된 배열이므로 길이 일치
        subtype_correct = oracle_pred == oracle_true  # subtype 정답 여부 [N_mal]

        gate_recall          = gate_pass.mean()
        # cascade 정답 = gate도 통과하고 subtype도 맞아야 함
        subtype_cascade_acc  = (gate_pass & subtype_correct).mean()
    else:
        gate_recall         = np.nan
        subtype_cascade_acc = np.nan

    return {
        "loss":           running_total / n_samples,
        "loss_malignancy": running_m / n_samples,
        "loss_subtype":   running_s / n_samples,

        # malignancy 지표
        "acc":    mal_metrics["acc"],
        "auc":    mal_metrics["auc"],
        "f1":     mal_metrics["f1"],
        "recall": mal_metrics["recall"],
        "cm":     mal_metrics["cm"],

        # subtype oracle 지표 (gate 무관, subtype head 자체 성능)
        "subtype_oracle_acc":      subtype_oracle["acc"],
        "subtype_oracle_macro_f1": subtype_oracle["macro_f1"],
        "subtype_oracle_cm":       subtype_oracle["cm"],

        # cascade 지표 (gate + subtype 통합 성능)
        "subtype_cascade_acc":  float(subtype_cascade_acc),
        "subtype_gate_recall":  float(gate_recall),
    }


def train_one_epoch(model, loader, criterion, optimizer, device):
    model.train()

    running_total, running_m, running_s = 0.0, 0.0, 0.0
    all_label        = []
    all_mal_prob     = []
    all_mal_mask     = []
    all_subtype_true = []
    all_subtype_pred = []

    for batch in loader:
        imgs = batch["image"].to(device, non_blocking=True)

        optimizer.zero_grad()

        with torch.amp.autocast(device_type="cuda", enabled=(device.type == "cuda")):
            outputs   = model(imgs)
            loss_dict = criterion(outputs, batch)
            loss      = loss_dict["loss_total"]

        scaler.scale(loss).backward()
        scaler.step(optimizer)
        scaler.update()

        bs             = imgs.size(0)
        running_total += loss_dict["loss_total"].item() * bs
        running_m     += loss_dict["loss_malignancy"].item() * bs
        running_s     += loss_dict["loss_subtype"].item() * bs

        # CPU로 이동 후 numpy 변환
        label_np        = batch["label"].detach().cpu().numpy().astype(int).ravel()
        mal_mask_np     = batch["mal_mask"].detach().cpu().numpy().astype(bool).ravel()
        mal_prob_np     = torch.sigmoid(outputs["malignancy_logits"]).detach().cpu().numpy().ravel()
        subtype_pred_np = outputs["subtype_logits"].argmax(dim=1).detach().cpu().numpy().astype(int).ravel()
        subtype_true_np = batch["mal_subtype"].detach().cpu().numpy().astype(int).ravel()

        all_label.extend(label_np.tolist())
        all_mal_prob.extend(mal_prob_np.tolist())
        all_mal_mask.extend(mal_mask_np.tolist())
        all_subtype_true.extend(subtype_true_np.tolist())
        all_subtype_pred.extend(subtype_pred_np.tolist())

    return _compute_cascade_metrics(
        all_label, all_mal_prob, all_mal_mask,
        all_subtype_true, all_subtype_pred,
        running_total, running_m, running_s,
        len(loader.dataset),
    )


@torch.no_grad()
def eval_one_epoch(model, loader, criterion, device):
    model.eval()

    running_total, running_m, running_s = 0.0, 0.0, 0.0
    all_label        = []
    all_mal_prob     = []
    all_mal_mask     = []
    all_subtype_true = []
    all_subtype_pred = []

    for batch in loader:
        imgs = batch["image"].to(device, non_blocking=True)

        with torch.amp.autocast(device_type="cuda", enabled=(device.type == "cuda")):
            outputs   = model(imgs)
            loss_dict = criterion(outputs, batch)

        bs             = imgs.size(0)
        running_total += loss_dict["loss_total"].item() * bs
        running_m     += loss_dict["loss_malignancy"].item() * bs
        running_s     += loss_dict["loss_subtype"].item() * bs

        label_np        = batch["label"].detach().cpu().numpy().astype(int).ravel()
        mal_mask_np     = batch["mal_mask"].detach().cpu().numpy().astype(bool).ravel()
        mal_prob_np     = torch.sigmoid(outputs["malignancy_logits"]).detach().cpu().numpy().ravel()
        subtype_pred_np = outputs["subtype_logits"].argmax(dim=1).detach().cpu().numpy().astype(int).ravel()
        subtype_true_np = batch["mal_subtype"].detach().cpu().numpy().astype(int).ravel()

        all_label.extend(label_np.tolist())
        all_mal_prob.extend(mal_prob_np.tolist())
        all_mal_mask.extend(mal_mask_np.tolist())
        all_subtype_true.extend(subtype_true_np.tolist())
        all_subtype_pred.extend(subtype_pred_np.tolist())

    return _compute_cascade_metrics(
        all_label, all_mal_prob, all_mal_mask,
        all_subtype_true, all_subtype_pred,
        running_total, running_m, running_s,
        len(loader.dataset),
    )


@torch.no_grad()
def eval_confusion(model, loader, criterion, device, threshold=0.5):
    """최종 평가 + classification report 출력."""
    metrics = eval_one_epoch(model, loader, criterion, device)

    print("\n-- Final Evaluation --")
    print(f"[Malignancy]  AUC={metrics['auc']:.4f}, F1={metrics['f1']:.4f}, Recall={metrics['recall']:.4f}, Acc={metrics['acc']:.4f}")
    print(f"[Subtype Oracle]  Acc={metrics['subtype_oracle_acc']:.4f}, MacroF1={metrics['subtype_oracle_macro_f1']:.4f}")
    print(f"[Cascade]  SubtypeAcc={metrics['subtype_cascade_acc']:.4f}, GateRecall={metrics['subtype_gate_recall']:.4f}")
    print("Binary CM:")
    print(metrics["cm"])
    print("Subtype Oracle CM:")
    print(metrics["subtype_oracle_cm"])

    return metrics


# ============================================================
# 11) 모델 정의
# ============================================================

# ── 공통 Attention Pooling + Dual Head Classifier ────────────
class PatientSliceAttentionClassifier(nn.Module):
    """
    [구조 개선]
    원본: shared → malignancy_head / subtype_head (동일 표현 공유)
    수정: shared → mal_proj → malignancy_head
                 → sub_proj → subtype_head

    이유: malignancy 판단(global 패턴)과 subtype 분류(세부 형태 패턴)는
    집중해야 할 특징이 달라서 task별 projection을 추가하면 각 head가
    더 특화된 표현을 학습할 수 있음.
    """
    def __init__(self, encoder, feat_dim, hidden_dim=512, proj_dim=256, dropout=0.1):
        super().__init__()
        self.encoder = encoder

        # slice 간 중요도 attention (슬라이스별 가중합 풀링)
        self.attn = nn.Sequential(
            nn.Linear(feat_dim, feat_dim // 2),
            nn.Tanh(),
            nn.Linear(feat_dim // 2, 1),
        )

        # 공통 표현 추출
        self.shared = nn.Sequential(
            nn.Linear(feat_dim, hidden_dim),
            nn.ReLU(),
            nn.Dropout(dropout),
        )

        # ── task별 projection (개선 포인트) ──────────────────
        # malignancy: 양성/악성 global 구분에 집중
        self.mal_proj = nn.Sequential(
            nn.Linear(hidden_dim, proj_dim),
            nn.ReLU(),
            nn.Dropout(dropout),
        )
        # subtype: 악성 내 세부 형태 패턴 분류에 집중
        self.sub_proj = nn.Sequential(
            nn.Linear(hidden_dim, proj_dim),
            nn.ReLU(),
            nn.Dropout(dropout),
        )

        self.malignancy_head = nn.Linear(proj_dim, 1)
        self.subtype_head    = nn.Linear(proj_dim, NUM_MALIGNANT_SUBTYPES)

    def forward(self, x):
        # x: (B, S, C, H, W)
        B, S, C, H, W = x.shape
        x = x.view(B * S, C, H, W)

        feat = self.encoder(x)           # (B*S, feat_dim)
        feat = feat.view(B, S, -1)       # (B, S, feat_dim)

        # attention pooling
        attn_score  = self.attn(feat)                    # (B, S, 1)
        attn_weight = torch.softmax(attn_score, dim=1)
        pooled      = (feat * attn_weight).sum(dim=1)    # (B, feat_dim)

        # 공통 → task별 분기
        z     = self.shared(pooled)    # (B, hidden_dim)
        z_mal = self.mal_proj(z)       # (B, proj_dim)
        z_sub = self.sub_proj(z)       # (B, proj_dim)

        return {
            # squeeze(1): [B,1] → [B]  (BCEWithLogitsLoss 입력 형태)
            "malignancy_logits": self.malignancy_head(z_mal).squeeze(1),
            "subtype_logits":    self.subtype_head(z_sub),   # (B, NUM_MALIGNANT_SUBTYPES)
        }


# ── ResNet50 기반 모델 ────────────────────────────────────────
def build_resnet18_patient_model(
    load_pretrained=True,
    freeze_backbone=True,
    unfreeze_layer4=True,
    weight_path=LOCAL_RESNET18_WEIGHTS,
):
    encoder = models.resnet18(weights=None)

    if load_pretrained:
        state_dict = load_local_state_dict(weight_path)
        encoder.load_state_dict(state_dict, strict=True)

    feat_dim   = encoder.fc.in_features   # 512
    encoder.fc = nn.Identity()

    if freeze_backbone:
        for p in encoder.parameters():
            p.requires_grad = False
        if unfreeze_layer4:
            # layer4만 fine-tuning (고수준 특징 추출 레이어)
            for p in encoder.layer4.parameters():
                p.requires_grad = True

    model = PatientSliceAttentionClassifier(
        encoder=encoder,
        feat_dim=feat_dim,
        hidden_dim=256,
        proj_dim=128,
        dropout=0.3,
    )
    return model


# ── ViT-B/16 기반 모델 ───────────────────────────────────────
def build_vit_patient_model(
    load_pretrained=True,
    weight_path=LOCAL_VIT_WEIGHTS,
):
    encoder = vit_b_16(weights=None)

    if load_pretrained:
        state_dict = load_local_state_dict(weight_path)
        encoder.load_state_dict(state_dict, strict=True)

    feat_dim      = encoder.heads.head.in_features   # 768
    encoder.heads = nn.Identity()

    model = PatientSliceAttentionClassifier(
        encoder=encoder,
        feat_dim=feat_dim,
        hidden_dim=512,
        proj_dim=256,
        dropout=0.1,
    )
    return model


# ── CNN + Transformer Hybrid 모델 ────────────────────────────
class CNNTransformerHybridPatient(nn.Module):
    """
    ResNet50으로 슬라이스별 특징 추출 후
    Transformer로 슬라이스 간 관계를 모델링.

    [구조 개선]
    원본: shared → malignancy_head / subtype_head
    수정: shared → mal_proj → malignancy_head
                 → sub_proj → subtype_head
    """
    def __init__(
        self,
        d_model=512,
        nhead=8,
        num_layers=2,
        dim_feedforward=1024,
        proj_dim=256,
        dropout=0.1,
        load_pretrained=True,
        freeze_backbone=True,
        unfreeze_layer4=True,
        resnet_weight_path=LOCAL_RESNET18_WEIGHTS,
    ):
        super().__init__()

        # ── ResNet18 backbone ─────────────────────────────────
        backbone = models.resnet18(weights=None)
        if load_pretrained:
            state_dict = load_local_state_dict(resnet_weight_path)
            backbone.load_state_dict(state_dict, strict=True)
        feat_dim    = backbone.fc.in_features   # 2048
        backbone.fc = nn.Identity()
        self.encoder = backbone

        if freeze_backbone:
            for p in self.encoder.parameters():
                p.requires_grad = False
            if unfreeze_layer4:
                for p in self.encoder.layer4.parameters():
                    p.requires_grad = True

        # ── Transformer 입력 준비 ─────────────────────────────
        # ResNet 출력(2048) → Transformer 차원(d_model)으로 projection
        self.proj = nn.Linear(feat_dim, d_model)

        # CLS 토큰: 슬라이스 전체를 요약하는 학습 가능한 토큰
        self.cls_token = nn.Parameter(torch.zeros(1, 1, d_model))

        # pos_embed: 슬라이스 위치 정보 인코딩 (1+8: CLS + 슬라이스 최대 8장)
        # 실제 슬라이스 수 S가 8보다 작으면 자동으로 슬라이싱됨
        self.pos_embed = nn.Parameter(torch.zeros(1, 1 + 8, d_model))

        # ── Transformer Encoder ───────────────────────────────
        enc_layer = nn.TransformerEncoderLayer(
            d_model=d_model,
            nhead=nhead,
            dim_feedforward=dim_feedforward,
            dropout=0.1,
            batch_first=True,
            activation="gelu",
        )
        self.transformer = nn.TransformerEncoder(enc_layer, num_layers=num_layers)
        self.norm        = nn.LayerNorm(d_model)

        # ── 공통 표현 + task별 projection (개선 포인트) ────────
        self.shared = nn.Sequential(
            nn.Linear(d_model, 512),
            nn.ReLU(),
            nn.Dropout(dropout),
        )
        self.mal_proj = nn.Sequential(
            nn.Linear(512, proj_dim),
            nn.ReLU(),
            nn.Dropout(dropout),
        )
        self.sub_proj = nn.Sequential(
            nn.Linear(512, proj_dim),
            nn.ReLU(),
            nn.Dropout(dropout),
        )
        self.malignancy_head = nn.Linear(proj_dim, 1)
        self.subtype_head    = nn.Linear(proj_dim, NUM_MALIGNANT_SUBTYPES)

    def forward(self, x):
        B, S, C, H, W = x.shape
        x = x.view(B * S, C, H, W)

        feat = self.encoder(x)          # (B*S, 2048)
        feat = feat.view(B, S, -1)      # (B, S, 2048)
        feat = self.proj(feat)          # (B, S, d_model)

        # CLS 토큰 prepend
        cls    = self.cls_token.expand(B, -1, -1)       # (B, 1, d_model)
        tokens = torch.cat([cls, feat], dim=1)           # (B, 1+S, d_model)
        # pos_embed는 최대 슬라이스 수 기준으로 정의하고 실제 S에 맞게 슬라이싱
        tokens = tokens + self.pos_embed[:, :tokens.size(1), :]

        tokens  = self.transformer(tokens)    # (B, 1+S, d_model)
        tokens  = self.norm(tokens)
        cls_out = tokens[:, 0, :]             # (B, d_model) CLS 토큰만 추출

        z     = self.shared(cls_out)   # (B, 512)
        z_mal = self.mal_proj(z)       # (B, proj_dim)
        z_sub = self.sub_proj(z)       # (B, proj_dim)

        return {
            "malignancy_logits": self.malignancy_head(z_mal).squeeze(1),
            "subtype_logits":    self.subtype_head(z_sub),
        }


def build_hybrid_patient_model(load_pretrained=True):
    return CNNTransformerHybridPatient(
        load_pretrained=load_pretrained,
        freeze_backbone=True,
        unfreeze_layer4=True,
        resnet_weight_path=LOCAL_RESNET_WEIGHTS,
    )


# ============================================================
# 12) 공통 학습 함수
# ============================================================
def fit_model(
    model, model_name, fold_idx,
    train_loader, val_loader, device,
    num_epochs=30, lr=1e-4, weight_decay=1e-4,
    criterion=None,
    patience=7, min_delta=0.001,
):
    """
    [early stopping 기준 변경]
    원본: val_loss 기준
    수정: val_auc 기준

    이유: cascade 모델에서 malignancy gate recall이 낮으면
    subtype 예측 자체가 의미 없어짐.
    val_loss는 subtype loss가 섞여 있어 malignancy 성능을
    직접 반영하지 못함 → val_auc가 더 적합.

    [subtype_loss_weight warmup]
    epoch마다 CascadeCriterion의 weight를 업데이트.
    학습 초반에는 malignancy에 집중, 후반으로 갈수록 subtype 비중 증가.
    """
    if criterion is None:
        raise ValueError("cascade 모델에서는 criterion에 CascadeCriterion을 넘겨야 함")

    model = model.to(device)
    optimizer = torch.optim.Adam(
        filter(lambda p: p.requires_grad, model.parameters()),
        lr=lr,
        weight_decay=weight_decay,
    )

    best_auc           = -1.0
    best_path          = OUTPUT_DIR / f"{model_name}_fold{fold_idx}_best.pth"
    history            = []
    early_stop_counter = 0

    for epoch in range(1, num_epochs + 1):

        # subtype loss weight warmup: epoch마다 선형 증가
        current_subtype_weight = get_subtype_loss_weight(epoch, num_epochs)
        criterion.subtype_loss_weight = current_subtype_weight

        train_metrics = train_one_epoch(model, train_loader, criterion, optimizer, device)
        val_metrics   = eval_one_epoch(model, val_loader, criterion, device)

        row = {
            "fold":  fold_idx,
            "epoch": epoch,
            "subtype_loss_weight": current_subtype_weight,

            # train 지표
            "train_loss":                    train_metrics["loss"],
            "train_loss_malignancy":         train_metrics["loss_malignancy"],
            "train_loss_subtype":            train_metrics["loss_subtype"],
            "train_acc":                     train_metrics["acc"],
            "train_auc":                     train_metrics["auc"],
            "train_f1":                      train_metrics["f1"],
            "train_recall":                  train_metrics["recall"],
            "train_subtype_oracle_acc":      train_metrics["subtype_oracle_acc"],
            "train_subtype_oracle_macro_f1": train_metrics["subtype_oracle_macro_f1"],
            "train_subtype_cascade_acc":     train_metrics["subtype_cascade_acc"],
            "train_subtype_gate_recall":     train_metrics["subtype_gate_recall"],

            # val 지표
            "val_loss":                    val_metrics["loss"],
            "val_loss_malignancy":         val_metrics["loss_malignancy"],
            "val_loss_subtype":            val_metrics["loss_subtype"],
            "val_acc":                     val_metrics["acc"],
            "val_auc":                     val_metrics["auc"],
            "val_f1":                      val_metrics["f1"],
            "val_recall":                  val_metrics["recall"],
            "val_subtype_oracle_acc":      val_metrics["subtype_oracle_acc"],
            "val_subtype_oracle_macro_f1": val_metrics["subtype_oracle_macro_f1"],
            "val_subtype_cascade_acc":     val_metrics["subtype_cascade_acc"],
            "val_subtype_gate_recall":     val_metrics["subtype_gate_recall"],
        }
        history.append(row)

        # ✅ 버그 수정: 원본은 콤마로 f-string이 분리되어 별도 출력됨
        # → 하나의 f-string으로 합침
        print(
            f"[{model_name}][Fold {fold_idx}][Epoch {epoch:02d}] "
            f"sub_w={current_subtype_weight:.3f} | "
            f"train loss={row['train_loss']:.4f}(mal={row['train_loss_malignancy']:.4f},sub={row['train_loss_subtype']:.4f}), "
            f"auc={row['train_auc']:.4f}, f1={row['train_f1']:.4f}, recall={row['train_recall']:.4f}, "
            f"oracle_f1={row['train_subtype_oracle_macro_f1']:.4f}, cascade_acc={row['train_subtype_cascade_acc']:.4f} | "
            f"val loss={row['val_loss']:.4f}(mal={row['val_loss_malignancy']:.4f},sub={row['val_loss_subtype']:.4f}), "
            f"auc={row['val_auc']:.4f}, f1={row['val_f1']:.4f}, recall={row['val_recall']:.4f}, "
            f"oracle_f1={row['val_subtype_oracle_macro_f1']:.4f}, cascade_acc={row['val_subtype_cascade_acc']:.4f}"
        )

        # ✅ early stopping 기준: val_loss → val_auc
        val_auc = row["val_auc"]
        if val_auc > best_auc + min_delta:
            best_auc           = val_auc
            early_stop_counter = 0
            torch.save(model.state_dict(), best_path)
            print(f"  -> best saved (val_auc={best_auc:.4f}): {best_path}")
        else:
            early_stop_counter += 1
            print(f"  -> no improvement ({early_stop_counter}/{patience})")

        if early_stop_counter >= patience:
            print(f"  -> early stopping triggered at epoch {epoch}")
            break

    history_df = pd.DataFrame(history)
    return model, history_df, best_path


# ============================================================
# 13) 모델 로드 함수
# ============================================================
def load_model(model_type, model_path, device):
    if model_type == "resnet":
        model = build_resnet18_patient_model(load_pretrained=False)
    elif model_type == "vit":
        model = build_vit_patient_model(load_pretrained=False)
    elif model_type == "hybrid":
        model = build_hybrid_patient_model(load_pretrained=False)
    else:
        raise ValueError(f"Unknown model type: {model_type}")

    model.load_state_dict(torch.load(model_path, map_location=device))
    model.to(device)
    model.eval()
    return model


# ============================================================
# 14) CV 실행 함수
# ============================================================
def run_cv_for_model(model_name, model_type, build_fn):
    fold_results   = []
    fold_histories = []

    for fold_idx in FOLDS:
        print("\n" + "=" * 80)
        print(f"Running {model_name} | Fold {fold_idx}")
        print("=" * 80)

        train_loader, val_loader, pos_weight, subtype_class_weights = make_fold_loaders(fold_idx)

        model = build_fn()

        # CascadeCriterion: subtype_loss_weight는 fit_model 내부에서 epoch마다 업데이트
        criterion = CascadeCriterion(
            pos_weight=pos_weight,
            subtype_class_weights=subtype_class_weights,
            subtype_loss_weight=SUBTYPE_LOSS_WEIGHT_START,
        )

        _, history_df, best_path = fit_model(
            model=model,
            model_name=model_name,
            fold_idx=fold_idx,
            train_loader=train_loader,
            val_loader=val_loader,
            device=device,
            num_epochs=NUM_EPOCHS,
            lr=LR,
            weight_decay=WEIGHT_DECAY,
            criterion=criterion,
            patience=PATIENCE,
            min_delta=MIN_DELTA,
        )

        best_model    = load_model(model_type, best_path, device)
        final_metrics = eval_confusion(best_model, val_loader, criterion, device, threshold=THRESHOLD)

        print(f"\n[{model_name}][Fold {fold_idx}] Final Metrics")
        print(f"Malignancy  AUC={final_metrics['auc']:.4f}, F1={final_metrics['f1']:.4f}, Recall={final_metrics['recall']:.4f}")
        print(f"Subtype Oracle  Acc={final_metrics['subtype_oracle_acc']:.4f}, MacroF1={final_metrics['subtype_oracle_macro_f1']:.4f}")
        print(f"Cascade  Acc={final_metrics['subtype_cascade_acc']:.4f}, GateRecall={final_metrics['subtype_gate_recall']:.4f}")

        fold_results.append({
            "model":                   model_name,
            "fold":                    fold_idx,
            "mal_acc":                 final_metrics["acc"],
            "mal_auc":                 final_metrics["auc"],
            "mal_f1":                  final_metrics["f1"],
            "mal_recall":              final_metrics["recall"],
            "subtype_oracle_acc":      final_metrics["subtype_oracle_acc"],
            "subtype_oracle_macro_f1": final_metrics["subtype_oracle_macro_f1"],
            "subtype_cascade_acc":     final_metrics["subtype_cascade_acc"],
            "subtype_gate_recall":     final_metrics["subtype_gate_recall"],
            "binary_cm":               final_metrics["cm"],
            "subtype_oracle_cm":       final_metrics["subtype_oracle_cm"],
        })

        history_df["model"] = model_name
        fold_histories.append(history_df)

        del model, best_model, train_loader, val_loader
        gc.collect()
        if torch.cuda.is_available():
            torch.cuda.empty_cache()

    result_df      = pd.DataFrame(fold_results)
    history_df_all = pd.concat(fold_histories, ignore_index=True)
    return result_df, history_df_all


# ============================================================
# 15) 학습 실행
# ============================================================

# ── ResNet50 ──────────────────────────────────────────────────
print(">>> Training ResNet18...")
resnet_cv_df, resnet_history_df = run_cv_for_model(
    model_name="ResNet18",
    model_type="resnet",
    build_fn=lambda: build_resnet18_patient_model(load_pretrained=True),
)
display(resnet_cv_df)

# ── ViT-B/16 ─────────────────────────────────────────────────
print(">>> Training ViT-B/16...")
vit_cv_df, vit_history_df = run_cv_for_model(
    model_name="ViT-B16",
    model_type="vit",
    build_fn=lambda: build_vit_patient_model(load_pretrained=True),
)
display(vit_cv_df)

# ── Hybrid ────────────────────────────────────────────────────
print(">>> Training Hybrid...")
hybrid_cv_df, hybrid_history_df = run_cv_for_model(
    model_name="Hybrid",
    model_type="hybrid",
    build_fn=lambda: build_hybrid_patient_model(load_pretrained=True),
)
display(hybrid_cv_df)


# ============================================================
# 16) 5-fold 평균 ± 표준편차 요약
# ============================================================
all_cv_df = pd.concat([resnet_cv_df, vit_cv_df, hybrid_cv_df], ignore_index=True)

summary_df = (
    all_cv_df.groupby("model")[[
        "mal_auc", "mal_f1", "mal_recall",
        "subtype_oracle_acc", "subtype_oracle_macro_f1",
        "subtype_cascade_acc", "subtype_gate_recall",
    ]]
    .agg(["mean", "std"])
)
display(summary_df)


# ============================================================
# 17) 학습 곡선 시각화
# ============================================================
def plot_one_model_by_fold(history_df, model_name):
    folds = sorted(history_df["fold"].unique())

    fig, axes = plt.subplots(1, 3, figsize=(18, 5))

    # Loss
    ax = axes[0]
    for fold in folds:
        df_f = history_df[history_df["fold"] == fold].sort_values("epoch")
        ax.plot(df_f["epoch"], df_f["train_loss"], linestyle="--", alpha=0.7, label=f"Fold{fold} Train")
        ax.plot(df_f["epoch"], df_f["val_loss"],   alpha=0.7,      label=f"Fold{fold} Val")
    ax.set_title(f"{model_name} - Total Loss")
    ax.set_xlabel("Epoch")
    ax.set_ylabel("Loss")
    ax.legend(fontsize=7)

    # Malignancy AUC
    ax = axes[1]
    for fold in folds:
        df_f = history_df[history_df["fold"] == fold].sort_values("epoch")
        ax.plot(df_f["epoch"], df_f["val_auc"], alpha=0.8, label=f"Fold{fold}")
    ax.set_title(f"{model_name} - Val Malignancy AUC")
    ax.set_xlabel("Epoch")
    ax.set_ylabel("AUC")
    ax.legend(fontsize=7)

    # Subtype cascade acc
    ax = axes[2]
    for fold in folds:
        df_f = history_df[history_df["fold"] == fold].sort_values("epoch")
        ax.plot(df_f["epoch"], df_f["val_subtype_cascade_acc"], alpha=0.8, label=f"Fold{fold}")
    ax.set_title(f"{model_name} - Val Subtype Cascade Acc")
    ax.set_xlabel("Epoch")
    ax.set_ylabel("Cascade Acc")
    ax.legend(fontsize=7)

    plt.suptitle(model_name, fontsize=13)
    plt.tight_layout()
    plt.show()


plot_one_model_by_fold(resnet_history_df, "ResNet50")
plot_one_model_by_fold(vit_history_df,    "ViT-B16")
plot_one_model_by_fold(hybrid_history_df, "Hybrid")
# Out:
# ============================================================
# ResNet18 build success
# Vit-B/16 build success
# ============================================================
# Device: cuda
# 현재 작업 경로: /tf/notebooks/Image Encoder/Untitled Folder
# DATA_ROOT: /tf/nasw/dataset001/preprocessed/npz_us
# OUTPUT_DIR: /tf/notebooks/Image Encoder/Untitled Folder/us_cascade_models18
# FOLDS: [1, 2, 3, 4, 5]
# LOCAL_RESNET18_WEIGHTS exists: True
# LOCAL_VIT_WEIGHTS exists: True
# malignant_type_ids: [0, 1, 3, 5, 7]
# MALIGNANT_MAP: {0: 0, 1: 1, 3: 2, 5: 3, 7: 4}
# NUM_MALIGNANT_SUBTYPES: 5
# >>> Training ResNet18...
#
# ================================================================================
# Running ResNet18 | Fold 1
# ================================================================================
# [FOLD 1] Train benign(0): 2077, malignant(1): 395, pos_weight=5.2582, subtype_counts=[32.0, 22.0, 67.0, 25.0, 249.0], subtype_class_weights=[1.151900053024292, 1.6755000352859497, 0.5501999855041504, 1.4744000434875488, 0.14800000190734863]
# [ResNet18][Fold 1][Epoch 01] sub_w=0.400 | train loss=1.0349(mal=0.6202,sub=1.0369), auc=0.9201, f1=0.5992, recall=0.9139, oracle_f1=0.1666, cascade_acc=0.5494 | val loss=0.5128(mal=0.4047,sub=0.2704), auc=0.9647, f1=0.6960, recall=0.9694, oracle_f1=0.1550, cascade_acc=0.6122
#   -> best saved (val_auc=0.9647): us_cascade_models18/ResNet18_fold1_best.pth
# [ResNet18][Fold 1][Epoch 02] sub_w=0.414 | train loss=0.8070(mal=0.3894,sub=1.0094), auc=0.9658, f1=0.7383, recall=0.9392, oracle_f1=0.1814, cascade_acc=0.5772 | val loss=0.3208(mal=0.2096,sub=0.2687), auc=0.9901, f1=0.8276, recall=0.9796, oracle_f1=0.2113, cascade_acc=0.6224
#   -> best saved (val_auc=0.9901): us_cascade_models18/ResNet18_fold1_best.pth
# [ResNet18][Fold 1][Epoch 03] sub_w=0.428 | train loss=0.7495(mal=0.3353,sub=0.9686), auc=0.9751, f1=0.7819, recall=0.9392, oracle_f1=0.1597, cascade_acc=0.5747 | val loss=0.3601(mal=0.2144,sub=0.3406), auc=0.9907, f1=0.8033, recall=0.9796, oracle_f1=0.1550, cascade_acc=0.6224
#   -> no improvement (1/7)
# [ResNet18][Fold 1][Epoch 04] sub_w=0.441 | train loss=0.6802(mal=0.2834,sub=0.8992), auc=0.9811, f1=0.8147, recall=0.9519, oracle_f1=0.1655, cascade_acc=0.6000 | val loss=0.3480(mal=0.2281,sub=0.2716), auc=0.9886, f1=0.8440, recall=0.9388, oracle_f1=0.2273, cascade_acc=0.5612
#   -> no improvement (2/7)
# [ResNet18][Fold 1][Epoch 05] sub_w=0.455 | train loss=0.6199(mal=0.2312,sub=0.8541), auc=0.9870, f1=0.8398, recall=0.9620, oracle_f1=0.2356, cascade_acc=0.6228 | val loss=0.3191(mal=0.1942,sub=0.2744), auc=0.9922, f1=0.8384, recall=0.9796, oracle_f1=0.1880, cascade_acc=0.6224
#   -> best saved (val_auc=0.9922): us_cascade_models18/ResNet18_fold1_best.pth
# [ResNet18][Fold 1][Epoch 06] sub_w=0.469 | train loss=0.6144(mal=0.1970,sub=0.8900), auc=0.9908, f1=0.8652, recall=0.9671, oracle_f1=0.2324, cascade_acc=0.6354 | val loss=0.3724(mal=0.2190,sub=0.3272), auc=0.9902, f1=0.8688, recall=0.9796, oracle_f1=0.1704, cascade_acc=0.5918
#   -> no improvement (1/7)
# [ResNet18][Fold 1][Epoch 07] sub_w=0.483 | train loss=0.6515(mal=0.2075,sub=0.9197), auc=0.9901, f1=0.8650, recall=0.9570, oracle_f1=0.2650, cascade_acc=0.6354 | val loss=0.3246(mal=0.1995,sub=0.2592), auc=0.9908, f1=0.8559, recall=0.9694, oracle_f1=0.2434, cascade_acc=0.6020
#   -> no improvement (2/7)
# [ResNet18][Fold 1][Epoch 08] sub_w=0.497 | train loss=0.5675(mal=0.1638,sub=0.8129), auc=0.9935, f1=0.8876, recall=0.9696, oracle_f1=0.2512, cascade_acc=0.6481 | val loss=0.3478(mal=0.2139,sub=0.2696), auc=0.9893, f1=0.8879, recall=0.9694, oracle_f1=0.2428, cascade_acc=0.6020
#   -> no improvement (3/7)
# [ResNet18][Fold 1][Epoch 09] sub_w=0.510 | train loss=0.5849(mal=0.1514,sub=0.8494), auc=0.9933, f1=0.9021, recall=0.9797, oracle_f1=0.2639, cascade_acc=0.6684 | val loss=0.3727(mal=0.2151,sub=0.3089), auc=0.9920, f1=0.9171, recall=0.9592, oracle_f1=0.2300, cascade_acc=0.5816
#   -> no improvement (4/7)
# [ResNet18][Fold 1][Epoch 10] sub_w=0.524 | train loss=0.5894(mal=0.1411,sub=0.8553), auc=0.9946, f1=0.8925, recall=0.9772, oracle_f1=0.2600, cascade_acc=0.6608 | val loss=0.4467(mal=0.3012,sub=0.2777), auc=0.9840, f1=0.8505, recall=0.9286, oracle_f1=0.2280, cascade_acc=0.5408
#   -> no improvement (5/7)
# [ResNet18][Fold 1][Epoch 11] sub_w=0.538 | train loss=0.5512(mal=0.1074,sub=0.8250), auc=0.9969, f1=0.9286, recall=0.9873, oracle_f1=0.2857, cascade_acc=0.6684 | val loss=0.7342(mal=0.5967,sub=0.2555), auc=0.9786, f1=0.8502, recall=0.8980, oracle_f1=0.2170, cascade_acc=0.5000
#   -> no improvement (6/7)
# [ResNet18][Fold 1][Epoch 12] sub_w=0.552 | train loss=0.5756(mal=0.1553,sub=0.7617), auc=0.9938, f1=0.8964, recall=0.9747, oracle_f1=0.2638, cascade_acc=0.6684 | val loss=0.4442(mal=0.2418,sub=0.3669), auc=0.9882, f1=0.8426, recall=0.9286, oracle_f1=0.2197, cascade_acc=0.6020
#   -> no improvement (7/7)
#   -> early stopping triggered at epoch 12
#
# -- Final Evaluation --
# [Malignancy]  AUC=0.9922, F1=0.8384, Recall=0.9796, Acc=0.9401
# [Subtype Oracle]  Acc=0.6224, MacroF1=0.1880
# [Cascade]  SubtypeAcc=0.6224, GateRecall=0.9796
# Binary CM:
# [[485  35]
#  [  2  96]]
# Subtype Oracle CM:
# [[ 0  0  1  0  7]
#  [ 0  0  0  0  5]
#  [ 0  0  2  0 15]
#  [ 0  0  0  0  6]
#  [ 0  0  3  0 59]]
#
# [ResNet18][Fold 1] Final Metrics
# Malignancy  AUC=0.9922, F1=0.8384, Recall=0.9796
# Subtype Oracle  Acc=0.6224, MacroF1=0.1880
# Cascade  Acc=0.6224, GateRecall=0.9796
#
# ================================================================================
# Running ResNet18 | Fold 2
# ================================================================================
# [FOLD 2] Train benign(0): 2077, malignant(1): 395, pos_weight=5.2582, subtype_counts=[32.0, 22.0, 67.0, 25.0, 249.0], subtype_class_weights=[1.151900053024292, 1.6755000352859497, 0.5501999855041504, 1.4744000434875488, 0.14800000190734863]
# [ResNet18][Fold 2][Epoch 01] sub_w=0.400 | train loss=1.0386(mal=0.6270,sub=1.0289), auc=0.9191, f1=0.6173, recall=0.8962, oracle_f1=0.1621, cascade_acc=0.5620 | val loss=0.4723(mal=0.3548,sub=0.2937), auc=0.9735, f1=0.7706, recall=0.9082, oracle_f1=0.1519, cascade_acc=0.5612
#   -> best saved (val_auc=0.9735): us_cascade_models18/ResNet18_fold2_best.pth
# [ResNet18][Fold 2][Epoch 02] sub_w=0.414 | train loss=0.7836(mal=0.3893,sub=0.9527), auc=0.9659, f1=0.7444, recall=0.9291, oracle_f1=0.1860, cascade_acc=0.5899 | val loss=0.5318(mal=0.4072,sub=0.3012), auc=0.9782, f1=0.6644, recall=0.9898, oracle_f1=0.1535, cascade_acc=0.6224
#   -> best saved (val_auc=0.9782): us_cascade_models18/ResNet18_fold2_best.pth
# [ResNet18][Fold 2][Epoch 03] sub_w=0.428 | train loss=0.6787(mal=0.2829,sub=0.9258), auc=0.9809, f1=0.7888, recall=0.9595, oracle_f1=0.1800, cascade_acc=0.5924 | val loss=0.3652(mal=0.2464,sub=0.2779), auc=0.9901, f1=0.7823, recall=0.9898, oracle_f1=0.1550, cascade_acc=0.6224
#   -> best saved (val_auc=0.9901): us_cascade_models18/ResNet18_fold2_best.pth
# [ResNet18][Fold 2][Epoch 04] sub_w=0.441 | train loss=0.7130(mal=0.3119,sub=0.9088), auc=0.9778, f1=0.7899, recall=0.9519, oracle_f1=0.1866, cascade_acc=0.6025 | val loss=0.3471(mal=0.2034,sub=0.3256), auc=0.9906, f1=0.8066, recall=1.0000, oracle_f1=0.1560, cascade_acc=0.6327
#   -> no improvement (1/7)
# [ResNet18][Fold 2][Epoch 05] sub_w=0.455 | train loss=0.6357(mal=0.2273,sub=0.8973), auc=0.9873, f1=0.8439, recall=0.9646, oracle_f1=0.2100, cascade_acc=0.6127 | val loss=0.3915(mal=0.2617,sub=0.2851), auc=0.9864, f1=0.8017, recall=0.9898, oracle_f1=0.2262, cascade_acc=0.6531
#   -> no improvement (2/7)
# [ResNet18][Fold 2][Epoch 06] sub_w=0.469 | train loss=0.6113(mal=0.1984,sub=0.8804), auc=0.9889, f1=0.8664, recall=0.9772, oracle_f1=0.2237, cascade_acc=0.6253 | val loss=0.4192(mal=0.2759,sub=0.3055), auc=0.9848, f1=0.7833, recall=0.9592, oracle_f1=0.2542, cascade_acc=0.6531
#   -> no improvement (3/7)
# [ResNet18][Fold 2][Epoch 07] sub_w=0.483 | train loss=0.6042(mal=0.1821,sub=0.8745), auc=0.9922, f1=0.8790, recall=0.9747, oracle_f1=0.2271, cascade_acc=0.6278 | val loss=0.3448(mal=0.2259,sub=0.2462), auc=0.9904, f1=0.8911, recall=0.9184, oracle_f1=0.2385, cascade_acc=0.5510
#   -> no improvement (4/7)
# [ResNet18][Fold 2][Epoch 08] sub_w=0.497 | train loss=0.5588(mal=0.1422,sub=0.8391), auc=0.9936, f1=0.8998, recall=0.9772, oracle_f1=0.2425, cascade_acc=0.6456 | val loss=0.3563(mal=0.2230,sub=0.2685), auc=0.9869, f1=0.8444, recall=0.9694, oracle_f1=0.2352, cascade_acc=0.6429
#   -> no improvement (5/7)
# [ResNet18][Fold 2][Epoch 09] sub_w=0.510 | train loss=0.5352(mal=0.1327,sub=0.7888), auc=0.9949, f1=0.9068, recall=0.9848, oracle_f1=0.2265, cascade_acc=0.6430 | val loss=0.3579(mal=0.2143,sub=0.2814), auc=0.9889, f1=0.8716, recall=0.9694, oracle_f1=0.2312, cascade_acc=0.6020
#   -> no improvement (6/7)
# [ResNet18][Fold 2][Epoch 10] sub_w=0.524 | train loss=0.5503(mal=0.1280,sub=0.8055), auc=0.9949, f1=0.9059, recall=0.9747, oracle_f1=0.2564, cascade_acc=0.6253 | val loss=0.3789(mal=0.2169,sub=0.3090), auc=0.9900, f1=0.8762, recall=0.9388, oracle_f1=0.2376, cascade_acc=0.5918
#   -> no improvement (7/7)
#   -> early stopping triggered at epoch 10
#
# -- Final Evaluation --
# [Malignancy]  AUC=0.9901, F1=0.7823, Recall=0.9898, Acc=0.9126
# [Subtype Oracle]  Acc=0.6327, MacroF1=0.1550
# [Cascade]  SubtypeAcc=0.6224, GateRecall=0.9898
# Binary CM:
# [[467  53]
#  [  1  97]]
# Subtype Oracle CM:
# [[ 0  0  0  0  8]
#  [ 0  0  0  0  5]
#  [ 0  0  0  0 17]
#  [ 0  0  0  0  6]
#  [ 0  0  0  0 62]]
#
# [ResNet18][Fold 2] Final Metrics
# Malignancy  AUC=0.9901, F1=0.7823, Recall=0.9898
# Subtype Oracle  Acc=0.6327, MacroF1=0.1550
# Cascade  Acc=0.6224, GateRecall=0.9898
#
# ================================================================================
# Running ResNet18 | Fold 3
# ================================================================================
# [FOLD 3] Train benign(0): 2078, malignant(1): 394, pos_weight=5.2741, subtype_counts=[32.0, 21.0, 68.0, 25.0, 248.0], subtype_class_weights=[1.1354999542236328, 1.730299949645996, 0.5343000292778015, 1.4534000158309937, 0.14650000631809235]
# [ResNet18][Fold 3][Epoch 01] sub_w=0.400 | train loss=1.0439(mal=0.6395,sub=1.0108), auc=0.9179, f1=0.6293, recall=0.8680, oracle_f1=0.1926, cascade_acc=0.5482 | val loss=0.4362(mal=0.3282,sub=0.2699), auc=0.9832, f1=0.7273, recall=0.9697, oracle_f1=0.1556, cascade_acc=0.6162
#   -> best saved (val_auc=0.9832): us_cascade_models18/ResNet18_fold3_best.pth
# [ResNet18][Fold 3][Epoch 02] sub_w=0.414 | train loss=0.7592(mal=0.3558,sub=0.9747), auc=0.9711, f1=0.7589, recall=0.9467, oracle_f1=0.1660, cascade_acc=0.5939 | val loss=0.4191(mal=0.2996,sub=0.2887), auc=0.9855, f1=0.7570, recall=0.9596, oracle_f1=0.1556, cascade_acc=0.6162
#   -> best saved (val_auc=0.9855): us_cascade_models18/ResNet18_fold3_best.pth
# [ResNet18][Fold 3][Epoch 03] sub_w=0.428 | train loss=0.7228(mal=0.3192,sub=0.9437), auc=0.9757, f1=0.7885, recall=0.9416, oracle_f1=0.1646, cascade_acc=0.5990 | val loss=0.3769(mal=0.2623,sub=0.2679), auc=0.9878, f1=0.7950, recall=0.9596, oracle_f1=0.1801, cascade_acc=0.6263
#   -> best saved (val_auc=0.9878): us_cascade_models18/ResNet18_fold3_best.pth
# [ResNet18][Fold 3][Epoch 04] sub_w=0.441 | train loss=0.6709(mal=0.2627,sub=0.9247), auc=0.9820, f1=0.8253, recall=0.9594, oracle_f1=0.2001, cascade_acc=0.6091 | val loss=0.3725(mal=0.2557,sub=0.2648), auc=0.9872, f1=0.7950, recall=0.9596, oracle_f1=0.2395, cascade_acc=0.6263
#   -> no improvement (1/7)
# [ResNet18][Fold 3][Epoch 05] sub_w=0.455 | train loss=0.6272(mal=0.2162,sub=0.9030), auc=0.9870, f1=0.8448, recall=0.9670, oracle_f1=0.2094, cascade_acc=0.6091 | val loss=0.4366(mal=0.3100,sub=0.2781), auc=0.9881, f1=0.8476, recall=0.8990, oracle_f1=0.2274, cascade_acc=0.5960
#   -> no improvement (2/7)
# [ResNet18][Fold 3][Epoch 06] sub_w=0.469 | train loss=0.5967(mal=0.2039,sub=0.8377), auc=0.9890, f1=0.8494, recall=0.9594, oracle_f1=0.2254, cascade_acc=0.6218 | val loss=0.4618(mal=0.3231,sub=0.2957), auc=0.9885, f1=0.8667, recall=0.9192, oracle_f1=0.2380, cascade_acc=0.6162
#   -> no improvement (3/7)
# [ResNet18][Fold 3][Epoch 07] sub_w=0.483 | train loss=0.6196(mal=0.1849,sub=0.9004), auc=0.9908, f1=0.8780, recall=0.9772, oracle_f1=0.2234, cascade_acc=0.6117 | val loss=0.4294(mal=0.3013,sub=0.2654), auc=0.9882, f1=0.8505, recall=0.9192, oracle_f1=0.2542, cascade_acc=0.5960
#   -> no improvement (4/7)
# [ResNet18][Fold 3][Epoch 08] sub_w=0.497 | train loss=0.5884(mal=0.1570,sub=0.8688), auc=0.9934, f1=0.8879, recall=0.9746, oracle_f1=0.2305, cascade_acc=0.6218 | val loss=0.3658(mal=0.2265,sub=0.2807), auc=0.9907, f1=0.8291, recall=0.9798, oracle_f1=0.2653, cascade_acc=0.6667
#   -> best saved (val_auc=0.9907): us_cascade_models18/ResNet18_fold3_best.pth
# [ResNet18][Fold 3][Epoch 09] sub_w=0.510 | train loss=0.5546(mal=0.1249,sub=0.8421), auc=0.9958, f1=0.9029, recall=0.9797, oracle_f1=0.2556, cascade_acc=0.6650 | val loss=0.4487(mal=0.2989,sub=0.2935), auc=0.9894, f1=0.8738, recall=0.9091, oracle_f1=0.2324, cascade_acc=0.5455
#   -> no improvement (1/7)
# [ResNet18][Fold 3][Epoch 10] sub_w=0.524 | train loss=0.5343(mal=0.1369,sub=0.7582), auc=0.9954, f1=0.9067, recall=0.9746, oracle_f1=0.2502, cascade_acc=0.6421 | val loss=0.5221(mal=0.3567,sub=0.3155), auc=0.9897, f1=0.8768, recall=0.8990, oracle_f1=0.2289, cascade_acc=0.5859
#   -> no improvement (2/7)
# [ResNet18][Fold 3][Epoch 11] sub_w=0.538 | train loss=0.5173(mal=0.1061,sub=0.7644), auc=0.9967, f1=0.9337, recall=0.9822, oracle_f1=0.3004, cascade_acc=0.6497 | val loss=0.5044(mal=0.3456,sub=0.2952), auc=0.9802, f1=0.8142, recall=0.9293, oracle_f1=0.2285, cascade_acc=0.5354
#   -> no improvement (3/7)
# [ResNet18][Fold 3][Epoch 12] sub_w=0.552 | train loss=0.5293(mal=0.1210,sub=0.7401), auc=0.9959, f1=0.9046, recall=0.9746, oracle_f1=0.3792, cascade_acc=0.7030 | val loss=0.5686(mal=0.3845,sub=0.3337), auc=0.9884, f1=0.8670, recall=0.8889, oracle_f1=0.2894, cascade_acc=0.6263
#   -> no improvement (4/7)
# [ResNet18][Fold 3][Epoch 13] sub_w=0.566 | train loss=0.5496(mal=0.1262,sub=0.7486), auc=0.9952, f1=0.9271, recall=0.9848, oracle_f1=0.3234, cascade_acc=0.6853 | val loss=0.5112(mal=0.3308,sub=0.3190), auc=0.9872, f1=0.8713, recall=0.8889, oracle_f1=0.2487, cascade_acc=0.5556
#   -> no improvement (5/7)
# [ResNet18][Fold 3][Epoch 14] sub_w=0.579 | train loss=0.5322(mal=0.1093,sub=0.7301), auc=0.9973, f1=0.9264, recall=0.9746, oracle_f1=0.3701, cascade_acc=0.6980 | val loss=0.6147(mal=0.4287,sub=0.3211), auc=0.9856, f1=0.8683, recall=0.8990, oracle_f1=0.2418, cascade_acc=0.5657
#   -> no improvement (6/7)
# [ResNet18][Fold 3][Epoch 15] sub_w=0.593 | train loss=0.4913(mal=0.1021,sub=0.6562), auc=0.9971, f1=0.9316, recall=0.9848, oracle_f1=0.3359, cascade_acc=0.7005 | val loss=0.4208(mal=0.2199,sub=0.3387), auc=0.9932, f1=0.8995, recall=0.9495, oracle_f1=0.3026, cascade_acc=0.6061
#   -> best saved (val_auc=0.9932): us_cascade_models18/ResNet18_fold3_best.pth
# [ResNet18][Fold 3][Epoch 16] sub_w=0.607 | train loss=0.4754(mal=0.0816,sub=0.6490), auc=0.9979, f1=0.9422, recall=0.9924, oracle_f1=0.3853, cascade_acc=0.7234 | val loss=0.6047(mal=0.4079,sub=0.3243), auc=0.9889, f1=0.8844, recall=0.8889, oracle_f1=0.2408, cascade_acc=0.5051
#   -> no improvement (1/7)
# [ResNet18][Fold 3][Epoch 17] sub_w=0.621 | train loss=0.4313(mal=0.0932,sub=0.5448), auc=0.9974, f1=0.9385, recall=0.9873, oracle_f1=0.4825, cascade_acc=0.7538 | val loss=0.6419(mal=0.4165,sub=0.3632), auc=0.9878, f1=0.8923, recall=0.8788, oracle_f1=0.2296, cascade_acc=0.3838
#   -> no improvement (2/7)
# [ResNet18][Fold 3][Epoch 18] sub_w=0.634 | train loss=0.4799(mal=0.1132,sub=0.5779), auc=0.9965, f1=0.9200, recall=0.9772, oracle_f1=0.4516, cascade_acc=0.7208 | val loss=0.5597(mal=0.3132,sub=0.3885), auc=0.9883, f1=0.8326, recall=0.9293, oracle_f1=0.3146, cascade_acc=0.5253
#   -> no improvement (3/7)
# [ResNet18][Fold 3][Epoch 19] sub_w=0.648 | train loss=0.4600(mal=0.0753,sub=0.5934), auc=0.9987, f1=0.9373, recall=0.9873, oracle_f1=0.4354, cascade_acc=0.7360 | val loss=0.6998(mal=0.3879,sub=0.4812), auc=0.9868, f1=0.8679, recall=0.9293, oracle_f1=0.2796, cascade_acc=0.6364
#   -> no improvement (4/7)
# [ResNet18][Fold 3][Epoch 20] sub_w=0.662 | train loss=0.3973(mal=0.0773,sub=0.4834), auc=0.9985, f1=0.9465, recall=0.9873, oracle_f1=0.4978, cascade_acc=0.7792 | val loss=0.7151(mal=0.3081,sub=0.6147), auc=0.9893, f1=0.8479, recall=0.9293, oracle_f1=0.2932, cascade_acc=0.6263
#   -> no improvement (5/7)
# [ResNet18][Fold 3][Epoch 21] sub_w=0.676 | train loss=0.4349(mal=0.0747,sub=0.5330), auc=0.9982, f1=0.9475, recall=0.9848, oracle_f1=0.5169, cascade_acc=0.7716 | val loss=0.8207(mal=0.4972,sub=0.4787), auc=0.9875, f1=0.8788, recall=0.8788, oracle_f1=0.2715, cascade_acc=0.5758
#   -> no improvement (6/7)
# [ResNet18][Fold 3][Epoch 22] sub_w=0.690 | train loss=0.4003(mal=0.0674,sub=0.4828), auc=0.9988, f1=0.9513, recall=0.9924, oracle_f1=0.4742, cascade_acc=0.7817 | val loss=0.7288(mal=0.4230,sub=0.4434), auc=0.9876, f1=0.8756, recall=0.8889, oracle_f1=0.2706, cascade_acc=0.4646
#   -> no improvement (7/7)
#   -> early stopping triggered at epoch 22
#
# -- Final Evaluation --
# [Malignancy]  AUC=0.9932, F1=0.8995, Recall=0.9495, Acc=0.9660
# [Subtype Oracle]  Acc=0.6465, MacroF1=0.3026
# [Cascade]  SubtypeAcc=0.6061, GateRecall=0.9495
# Binary CM:
# [[503  16]
#  [  5  94]]
# Subtype Oracle CM:
# [[ 0  0  3  0  5]
#  [ 0  0  2  0  4]
#  [ 1  0 11  0  4]
#  [ 0  0  5  1  0]
#  [ 0  0  9  2 52]]
#
# [ResNet18][Fold 3] Final Metrics
# Malignancy  AUC=0.9932, F1=0.8995, Recall=0.9495
# Subtype Oracle  Acc=0.6465, MacroF1=0.3026
# Cascade  Acc=0.6061, GateRecall=0.9495
#
# ================================================================================
# Running ResNet18 | Fold 4
# ================================================================================
# [FOLD 4] Train benign(0): 2078, malignant(1): 394, pos_weight=5.2741, subtype_counts=[32.0, 21.0, 67.0, 25.0, 249.0], subtype_class_weights=[1.1338000297546387, 1.7276999950408936, 0.5414999723434448, 1.451300024986267, 0.14569999277591705]
# [ResNet18][Fold 4][Epoch 01] sub_w=0.400 | train loss=1.0044(mal=0.6065,sub=0.9948), auc=0.9255, f1=0.6270, recall=0.8832, oracle_f1=0.1664, cascade_acc=0.5127 | val loss=0.4565(mal=0.3441,sub=0.2811), auc=0.9747, f1=0.7860, recall=0.9091, oracle_f1=0.1540, cascade_acc=0.5657
#   -> best saved (val_auc=0.9747): us_cascade_models18/ResNet18_fold4_best.pth
# [ResNet18][Fold 4][Epoch 02] sub_w=0.414 | train loss=0.7609(mal=0.3716,sub=0.9408), auc=0.9693, f1=0.7520, recall=0.9315, oracle_f1=0.1598, cascade_acc=0.6041 | val loss=0.4350(mal=0.3215,sub=0.2743), auc=0.9802, f1=0.7884, recall=0.9596, oracle_f1=0.1519, cascade_acc=0.5960
#   -> best saved (val_auc=0.9802): us_cascade_models18/ResNet18_fold4_best.pth
# [ResNet18][Fold 4][Epoch 03] sub_w=0.428 | train loss=0.6812(mal=0.2851,sub=0.9262), auc=0.9812, f1=0.8043, recall=0.9594, oracle_f1=0.1793, cascade_acc=0.6091 | val loss=0.5391(mal=0.4218,sub=0.2744), auc=0.9744, f1=0.8372, recall=0.9091, oracle_f1=0.1695, cascade_acc=0.5859
#   -> no improvement (1/7)
# [ResNet18][Fold 4][Epoch 04] sub_w=0.441 | train loss=0.6188(mal=0.2212,sub=0.9007), auc=0.9881, f1=0.8396, recall=0.9569, oracle_f1=0.1840, cascade_acc=0.6091 | val loss=0.5065(mal=0.3907,sub=0.2623), auc=0.9774, f1=0.8072, recall=0.9091, oracle_f1=0.2082, cascade_acc=0.5657
#   -> no improvement (2/7)
# [ResNet18][Fold 4][Epoch 05] sub_w=0.455 | train loss=0.6184(mal=0.1895,sub=0.9424), auc=0.9904, f1=0.8682, recall=0.9695, oracle_f1=0.2215, cascade_acc=0.6244 | val loss=0.6598(mal=0.5275,sub=0.2905), auc=0.9740, f1=0.8072, recall=0.9091, oracle_f1=0.1996, cascade_acc=0.5758
#   -> no improvement (3/7)
# [ResNet18][Fold 4][Epoch 06] sub_w=0.469 | train loss=0.6074(mal=0.2175,sub=0.8315), auc=0.9890, f1=0.8511, recall=0.9645, oracle_f1=0.2577, cascade_acc=0.6523 | val loss=0.5100(mal=0.3871,sub=0.2619), auc=0.9818, f1=0.8713, recall=0.8889, oracle_f1=0.1878, cascade_acc=0.5253
#   -> best saved (val_auc=0.9818): us_cascade_models18/ResNet18_fold4_best.pth
# [ResNet18][Fold 4][Epoch 07] sub_w=0.483 | train loss=0.5709(mal=0.1578,sub=0.8559), auc=0.9943, f1=0.8860, recall=0.9670, oracle_f1=0.2386, cascade_acc=0.6345 | val loss=0.5171(mal=0.3799,sub=0.2842), auc=0.9780, f1=0.8364, recall=0.9293, oracle_f1=0.2241, cascade_acc=0.5657
#   -> no improvement (1/7)
# [ResNet18][Fold 4][Epoch 08] sub_w=0.497 | train loss=0.5790(mal=0.1692,sub=0.8253), auc=0.9932, f1=0.8719, recall=0.9670, oracle_f1=0.2581, cascade_acc=0.6675 | val loss=0.5089(mal=0.3630,sub=0.2937), auc=0.9779, f1=0.7718, recall=0.9394, oracle_f1=0.1986, cascade_acc=0.5657
#   -> no improvement (2/7)
# [ResNet18][Fold 4][Epoch 09] sub_w=0.510 | train loss=0.5670(mal=0.1447,sub=0.8275), auc=0.9947, f1=0.9053, recall=0.9822, oracle_f1=0.2505, cascade_acc=0.6472 | val loss=0.5434(mal=0.3754,sub=0.3293), auc=0.9833, f1=0.8545, recall=0.9192, oracle_f1=0.2061, cascade_acc=0.5455
#   -> best saved (val_auc=0.9833): us_cascade_models18/ResNet18_fold4_best.pth
# [ResNet18][Fold 4][Epoch 10] sub_w=0.524 | train loss=0.5412(mal=0.1206,sub=0.8025), auc=0.9959, f1=0.9087, recall=0.9721, oracle_f1=0.2799, cascade_acc=0.6523 | val loss=0.5338(mal=0.3925,sub=0.2697), auc=0.9833, f1=0.8696, recall=0.9091, oracle_f1=0.2182, cascade_acc=0.4646
#   -> no improvement (1/7)
# [ResNet18][Fold 4][Epoch 11] sub_w=0.538 | train loss=0.5648(mal=0.1554,sub=0.7610), auc=0.9940, f1=0.9025, recall=0.9746, oracle_f1=0.3008, cascade_acc=0.6853 | val loss=0.5151(mal=0.3670,sub=0.2752), auc=0.9779, f1=0.7673, recall=0.9495, oracle_f1=0.1981, cascade_acc=0.5152
#   -> no improvement (2/7)
# [ResNet18][Fold 4][Epoch 12] sub_w=0.552 | train loss=0.5254(mal=0.1390,sub=0.7003), auc=0.9954, f1=0.9078, recall=0.9746, oracle_f1=0.3329, cascade_acc=0.7005 | val loss=0.6358(mal=0.3991,sub=0.4290), auc=0.9851, f1=0.8476, recall=0.8990, oracle_f1=0.2091, cascade_acc=0.5354
#   -> best saved (val_auc=0.9851): us_cascade_models18/ResNet18_fold4_best.pth
# [ResNet18][Fold 4][Epoch 13] sub_w=0.566 | train loss=0.5065(mal=0.0673,sub=0.7766), auc=0.9985, f1=0.9490, recall=0.9924, oracle_f1=0.3299, cascade_acc=0.6878 | val loss=0.7355(mal=0.5493,sub=0.3292), auc=0.9824, f1=0.8500, recall=0.8586, oracle_f1=0.2048, cascade_acc=0.5152
#   -> no improvement (1/7)
# [ResNet18][Fold 4][Epoch 14] sub_w=0.579 | train loss=0.4453(mal=0.0780,sub=0.6340), auc=0.9981, f1=0.9499, recall=0.9873, oracle_f1=0.3717, cascade_acc=0.7157 | val loss=0.7541(mal=0.5431,sub=0.3641), auc=0.9764, f1=0.7811, recall=0.9192, oracle_f1=0.1961, cascade_acc=0.5354
#   -> no improvement (2/7)
# [ResNet18][Fold 4][Epoch 15] sub_w=0.593 | train loss=0.5096(mal=0.1197,sub=0.6574), auc=0.9958, f1=0.9093, recall=0.9797, oracle_f1=0.3706, cascade_acc=0.7107 | val loss=0.6818(mal=0.4875,sub=0.3277), auc=0.9810, f1=0.8517, recall=0.8990, oracle_f1=0.2225, cascade_acc=0.3939
#   -> no improvement (3/7)
# [ResNet18][Fold 4][Epoch 16] sub_w=0.607 | train loss=0.4190(mal=0.0507,sub=0.6068), auc=0.9992, f1=0.9630, recall=0.9898, oracle_f1=0.4778, cascade_acc=0.7563 | val loss=0.7299(mal=0.4976,sub=0.3827), auc=0.9829, f1=0.8318, recall=0.8990, oracle_f1=0.2198, cascade_acc=0.4949
#   -> no improvement (4/7)
# [ResNet18][Fold 4][Epoch 17] sub_w=0.621 | train loss=0.4769(mal=0.1051,sub=0.5991), auc=0.9975, f1=0.9275, recall=0.9746, oracle_f1=0.4393, cascade_acc=0.7462 | val loss=0.9665(mal=0.7192,sub=0.3983), auc=0.9832, f1=0.8235, recall=0.7778, oracle_f1=0.1822, cascade_acc=0.4343
#   -> no improvement (5/7)
# [ResNet18][Fold 4][Epoch 18] sub_w=0.634 | train loss=0.4463(mal=0.1045,sub=0.5388), auc=0.9972, f1=0.9361, recall=0.9848, oracle_f1=0.4327, cascade_acc=0.7437 | val loss=0.9437(mal=0.7229,sub=0.3480), auc=0.9840, f1=0.8387, recall=0.7879, oracle_f1=0.2013, cascade_acc=0.3737
#   -> no improvement (6/7)
# [ResNet18][Fold 4][Epoch 19] sub_w=0.648 | train loss=0.4655(mal=0.0819,sub=0.5917), auc=0.9980, f1=0.9510, recall=0.9848, oracle_f1=0.5061, cascade_acc=0.7766 | val loss=0.6864(mal=0.4680,sub=0.3369), auc=0.9830, f1=0.8462, recall=0.8889, oracle_f1=0.2255, cascade_acc=0.4343
#   -> no improvement (7/7)
#   -> early stopping triggered at epoch 19
#
# -- Final Evaluation --
# [Malignancy]  AUC=0.9851, F1=0.8476, Recall=0.8990, Acc=0.9482
# [Subtype Oracle]  Acc=0.5657, MacroF1=0.2091
# [Cascade]  SubtypeAcc=0.5354, GateRecall=0.8990
# Binary CM:
# [[497  22]
#  [ 10  89]]
# Subtype Oracle CM:
# [[ 0  0  2  0  6]
#  [ 0  0  1  0  5]
#  [ 1  0  6  0 10]
#  [ 0  0  2  0  4]
#  [ 0  0 10  2 50]]
#
# [ResNet18][Fold 4] Final Metrics
# Malignancy  AUC=0.9851, F1=0.8476, Recall=0.8990
# Subtype Oracle  Acc=0.5657, MacroF1=0.2091
# Cascade  Acc=0.5354, GateRecall=0.8990
#
# ================================================================================
# Running ResNet18 | Fold 5
# ================================================================================
# [FOLD 5] Train benign(0): 2078, malignant(1): 394, pos_weight=5.2741, subtype_counts=[32.0, 22.0, 67.0, 24.0, 249.0], subtype_class_weights=[1.1378999948501587, 1.6550999879837036, 0.5435000061988831, 1.517199993133545, 0.1462000012397766]
# [ResNet18][Fold 5][Epoch 01] sub_w=0.400 | train loss=0.9767(mal=0.5571,sub=1.0489), auc=0.9401, f1=0.6832, recall=0.8731, oracle_f1=0.1518, cascade_acc=0.5584 | val loss=0.4316(mal=0.3067,sub=0.3124), auc=0.9806, f1=0.7948, recall=0.9192, oracle_f1=0.1540, cascade_acc=0.5758
#   -> best saved (val_auc=0.9806): us_cascade_models18/ResNet18_fold5_best.pth
# [ResNet18][Fold 5][Epoch 02] sub_w=0.414 | train loss=0.7898(mal=0.3696,sub=1.0156), auc=0.9668, f1=0.7526, recall=0.9340, oracle_f1=0.1648, cascade_acc=0.5888 | val loss=0.3997(mal=0.2745,sub=0.3025), auc=0.9867, f1=0.7734, recall=1.0000, oracle_f1=0.1540, cascade_acc=0.6263
#   -> best saved (val_auc=0.9867): us_cascade_models18/ResNet18_fold5_best.pth
# [ResNet18][Fold 5][Epoch 03] sub_w=0.428 | train loss=0.7204(mal=0.3033,sub=0.9754), auc=0.9774, f1=0.8004, recall=0.9518, oracle_f1=0.1659, cascade_acc=0.6015 | val loss=0.3812(mal=0.2591,sub=0.2856), auc=0.9865, f1=0.8304, recall=0.9394, oracle_f1=0.1540, cascade_acc=0.6061
#   -> no improvement (1/7)
# [ResNet18][Fold 5][Epoch 04] sub_w=0.441 | train loss=0.6432(mal=0.2390,sub=0.9158), auc=0.9850, f1=0.8284, recall=0.9619, oracle_f1=0.1606, cascade_acc=0.6142 | val loss=0.4600(mal=0.3194,sub=0.3186), auc=0.9838, f1=0.8626, recall=0.9192, oracle_f1=0.1745, cascade_acc=0.5960
#   -> no improvement (2/7)
# [ResNet18][Fold 5][Epoch 05] sub_w=0.455 | train loss=0.6643(mal=0.2119,sub=0.9940), auc=0.9886, f1=0.8523, recall=0.9670, oracle_f1=0.1774, cascade_acc=0.5990 | val loss=0.4365(mal=0.2886,sub=0.3247), auc=0.9854, f1=0.8378, recall=0.9394, oracle_f1=0.1540, cascade_acc=0.6061
#   -> no improvement (3/7)
# [ResNet18][Fold 5][Epoch 06] sub_w=0.469 | train loss=0.6410(mal=0.2046,sub=0.9305), auc=0.9895, f1=0.8549, recall=0.9645, oracle_f1=0.1695, cascade_acc=0.6015 | val loss=0.3954(mal=0.2554,sub=0.2984), auc=0.9884, f1=0.8774, recall=0.9394, oracle_f1=0.1540, cascade_acc=0.6061
#   -> best saved (val_auc=0.9884): us_cascade_models18/ResNet18_fold5_best.pth
# [ResNet18][Fold 5][Epoch 07] sub_w=0.483 | train loss=0.5926(mal=0.1665,sub=0.8826), auc=0.9931, f1=0.8848, recall=0.9746, oracle_f1=0.1881, cascade_acc=0.6218 | val loss=0.4800(mal=0.2993,sub=0.3742), auc=0.9848, f1=0.8083, recall=0.9798, oracle_f1=0.1540, cascade_acc=0.6162
#   -> no improvement (1/7)
# [ResNet18][Fold 5][Epoch 08] sub_w=0.497 | train loss=0.5841(mal=0.1502,sub=0.8738), auc=0.9938, f1=0.8959, recall=0.9721, oracle_f1=0.2009, cascade_acc=0.6294 | val loss=0.3926(mal=0.2186,sub=0.3504), auc=0.9894, f1=0.8435, recall=0.9798, oracle_f1=0.2396, cascade_acc=0.6061
#   -> no improvement (2/7)
# [ResNet18][Fold 5][Epoch 09] sub_w=0.510 | train loss=0.6179(mal=0.1868,sub=0.8448), auc=0.9918, f1=0.8776, recall=0.9645, oracle_f1=0.2410, cascade_acc=0.6345 | val loss=0.3983(mal=0.2066,sub=0.3758), auc=0.9917, f1=0.8879, recall=0.9596, oracle_f1=0.2214, cascade_acc=0.5859
#   -> best saved (val_auc=0.9917): us_cascade_models18/ResNet18_fold5_best.pth
# [ResNet18][Fold 5][Epoch 10] sub_w=0.524 | train loss=0.5929(mal=0.1366,sub=0.8707), auc=0.9951, f1=0.9010, recall=0.9822, oracle_f1=0.2328, cascade_acc=0.6269 | val loss=0.4369(mal=0.2547,sub=0.3477), auc=0.9903, f1=0.8976, recall=0.9293, oracle_f1=0.2541, cascade_acc=0.6263
#   -> no improvement (1/7)
# [ResNet18][Fold 5][Epoch 11] sub_w=0.538 | train loss=0.6151(mal=0.1752,sub=0.8177), auc=0.9928, f1=0.8799, recall=0.9670, oracle_f1=0.2417, cascade_acc=0.6472 | val loss=0.3624(mal=0.1951,sub=0.3110), auc=0.9928, f1=0.8700, recall=0.9798, oracle_f1=0.2544, cascade_acc=0.6263
#   -> best saved (val_auc=0.9928): us_cascade_models18/ResNet18_fold5_best.pth
# [ResNet18][Fold 5][Epoch 12] sub_w=0.552 | train loss=0.5543(mal=0.1139,sub=0.7984), auc=0.9966, f1=0.9214, recall=0.9822, oracle_f1=0.2561, cascade_acc=0.6574 | val loss=0.3536(mal=0.1884,sub=0.2994), auc=0.9935, f1=0.8700, recall=0.9798, oracle_f1=0.2223, cascade_acc=0.5758
#   -> no improvement (1/7)
# [ResNet18][Fold 5][Epoch 13] sub_w=0.566 | train loss=0.5438(mal=0.1057,sub=0.7747), auc=0.9970, f1=0.9393, recall=0.9822, oracle_f1=0.2579, cascade_acc=0.6497 | val loss=0.3711(mal=0.1721,sub=0.3518), auc=0.9945, f1=0.8634, recall=0.9899, oracle_f1=0.1967, cascade_acc=0.5253
#   -> best saved (val_auc=0.9945): us_cascade_models18/ResNet18_fold5_best.pth
# [ResNet18][Fold 5][Epoch 14] sub_w=0.579 | train loss=0.5515(mal=0.1038,sub=0.7727), auc=0.9971, f1=0.9277, recall=0.9772, oracle_f1=0.2624, cascade_acc=0.6675 | val loss=0.4552(mal=0.2339,sub=0.3821), auc=0.9911, f1=0.8826, recall=0.9495, oracle_f1=0.2172, cascade_acc=0.5556
#   -> no improvement (1/7)
# [ResNet18][Fold 5][Epoch 15] sub_w=0.593 | train loss=0.5665(mal=0.1140,sub=0.7629), auc=0.9964, f1=0.9314, recall=0.9822, oracle_f1=0.2883, cascade_acc=0.6980 | val loss=0.4538(mal=0.2193,sub=0.3954), auc=0.9936, f1=0.9109, recall=0.9293, oracle_f1=0.2375, cascade_acc=0.5455
#   -> no improvement (2/7)
# [ResNet18][Fold 5][Epoch 16] sub_w=0.607 | train loss=0.5463(mal=0.0916,sub=0.7492), auc=0.9978, f1=0.9415, recall=0.9797, oracle_f1=0.2788, cascade_acc=0.6701 | val loss=0.4243(mal=0.2452,sub=0.2952), auc=0.9917, f1=0.9010, recall=0.9192, oracle_f1=0.2569, cascade_acc=0.5758
#   -> no improvement (3/7)
# [ResNet18][Fold 5][Epoch 17] sub_w=0.621 | train loss=0.5199(mal=0.0771,sub=0.7134), auc=0.9980, f1=0.9498, recall=0.9848, oracle_f1=0.2727, cascade_acc=0.6853 | val loss=0.5405(mal=0.3000,sub=0.3874), auc=0.9936, f1=0.9062, recall=0.8788, oracle_f1=0.2365, cascade_acc=0.5758
#   -> no improvement (4/7)
# [ResNet18][Fold 5][Epoch 18] sub_w=0.634 | train loss=0.5218(mal=0.0778,sub=0.6997), auc=0.9982, f1=0.9509, recall=0.9822, oracle_f1=0.3075, cascade_acc=0.7234 | val loss=0.3758(mal=0.1847,sub=0.3013), auc=0.9945, f1=0.8533, recall=0.9697, oracle_f1=0.2231, cascade_acc=0.5152
#   -> no improvement (5/7)
# [ResNet18][Fold 5][Epoch 19] sub_w=0.648 | train loss=0.4980(mal=0.0638,sub=0.6698), auc=0.9983, f1=0.9535, recall=0.9898, oracle_f1=0.3129, cascade_acc=0.7081 | val loss=0.4332(mal=0.2081,sub=0.3472), auc=0.9935, f1=0.8995, recall=0.9495, oracle_f1=0.2443, cascade_acc=0.5859
#   -> no improvement (6/7)
# [ResNet18][Fold 5][Epoch 20] sub_w=0.662 | train loss=0.4996(mal=0.0794,sub=0.6346), auc=0.9979, f1=0.9428, recall=0.9822, oracle_f1=0.3505, cascade_acc=0.7157 | val loss=0.6410(mal=0.3613,sub=0.4225), auc=0.9880, f1=0.7854, recall=0.9798, oracle_f1=0.2396, cascade_acc=0.6061
#   -> no improvement (7/7)
#   -> early stopping triggered at epoch 20
#
# -- Final Evaluation --
# [Malignancy]  AUC=0.9945, F1=0.8634, Recall=0.9899, Acc=0.9498
# [Subtype Oracle]  Acc=0.5253, MacroF1=0.1967
# [Cascade]  SubtypeAcc=0.5253, GateRecall=0.9899
# Binary CM:
# [[489  30]
#  [  1  98]]
# Subtype Oracle CM:
# [[ 0  0  4  0  4]
#  [ 0  0  3  0  2]
#  [ 0  0  7  0 10]
#  [ 0  0  4  0  3]
#  [ 0  0 17  0 45]]
#
# [ResNet18][Fold 5] Final Metrics
# Malignancy  AUC=0.9945, F1=0.8634, Recall=0.9899
# Subtype Oracle  Acc=0.5253, MacroF1=0.1967
# Cascade  Acc=0.5253, GateRecall=0.9899
#       model  fold   mal_acc   mal_auc    mal_f1  mal_recall  \
# 0  ResNet18     1  0.940129  0.992249  0.838428    0.979592
# 1  ResNet18     2  0.912621  0.990130  0.782258    0.989796
# 2  ResNet18     3  0.966019  0.993169  0.899522    0.949495
# 3  ResNet18     4  0.948220  0.985111  0.847619    0.898990
# 4  ResNet18     5  0.949838  0.994492  0.863436    0.989899
#
#    subtype_oracle_acc  subtype_oracle_macro_f1  subtype_cascade_acc  \
# 0            0.622449                 0.188029             0.622449
# 1            0.632653                 0.155000             0.622449
# 2            0.646465                 0.302597             0.606061
# 3            0.565657                 0.209143             0.535354
# 4            0.525253                 0.196703             0.525253
#
#    subtype_gate_recall              binary_cm  \
# 0             0.979592   [[485, 35], [2, 96]]
# 1             0.989796   [[467, 53], [1, 97]]
# 2             0.949495   [[503, 16], [5, 94]]
# 3             0.898990  [[497, 22], [10, 89]]
# 4             0.989899   [[489, 30], [1, 98]]
#
#                                    subtype_oracle_cm
# 0  [[0, 0, 1, 0, 7], [0, 0, 0, 0, 5], [0, 0, 2, 0...
# 1  [[0, 0, 0, 0, 8], [0, 0, 0, 0, 5], [0, 0, 0, 0...
# 2  [[0, 0, 3, 0, 5], [0, 0, 2, 0, 4], [1, 0, 11, ...
# 3  [[0, 0, 2, 0, 6], [0, 0, 1, 0, 5], [1, 0, 6, 0...
# 4  [[0, 0, 4, 0, 4], [0, 0, 3, 0, 2], [0, 0, 7, 0...
# >>> Training ViT-B/16...
#
# ================================================================================
# Running ViT-B16 | Fold 1
# ================================================================================
# [FOLD 1] Train benign(0): 2077, malignant(1): 395, pos_weight=5.2582, subtype_counts=[32.0, 22.0, 67.0, 25.0, 249.0], subtype_class_weights=[1.151900053024292, 1.6755000352859497, 0.5501999855041504, 1.4744000434875488, 0.14800000190734863]
# [ViT-B16][Fold 1][Epoch 01] sub_w=0.400 | train loss=1.6074(mal=1.1793,sub=1.0702), auc=0.4850, f1=0.2195, recall=0.4101, oracle_f1=0.1543, cascade_acc=0.2861 | val loss=1.2712(mal=1.1616,sub=0.2741), auc=0.6575, f1=0.2737, recall=1.0000, oracle_f1=0.1550, cascade_acc=0.6327
#   -> best saved (val_auc=0.6575): us_cascade_models18/ViT-B16_fold1_best.pth
# [ViT-B16][Fold 1][Epoch 02] sub_w=0.414 | train loss=1.5874(mal=1.1683,sub=1.0127), auc=0.5130, f1=0.2512, recall=0.5367, oracle_f1=0.1547, cascade_acc=0.3519 | val loss=1.3187(mal=1.1914,sub=0.3077), auc=0.6734, f1=0.0000, recall=0.0000, oracle_f1=0.1550, cascade_acc=0.0000
#   -> best saved (val_auc=0.6734): us_cascade_models18/ViT-B16_fold1_best.pth
# [ViT-B16][Fold 1][Epoch 03] sub_w=0.428 | train loss=1.5896(mal=1.1727,sub=0.9748), auc=0.4808, f1=0.2285, recall=0.4734, oracle_f1=0.1547, cascade_acc=0.3190 | val loss=1.2848(mal=1.1635,sub=0.2835), auc=0.6252, f1=0.2737, recall=1.0000, oracle_f1=0.1550, cascade_acc=0.6327
#   -> no improvement (1/7)
# [ViT-B16][Fold 1][Epoch 04] sub_w=0.441 | train loss=1.6140(mal=1.1688,sub=1.0086), auc=0.5048, f1=0.2395, recall=0.4886, oracle_f1=0.1547, cascade_acc=0.3089 | val loss=1.2820(mal=1.1623,sub=0.2712), auc=0.5918, f1=0.2737, recall=1.0000, oracle_f1=0.1550, cascade_acc=0.6327
#   -> no improvement (2/7)
# [ViT-B16][Fold 1][Epoch 05] sub_w=0.455 | train loss=1.6356(mal=1.1711,sub=1.0203), auc=0.5138, f1=0.2452, recall=0.4835, oracle_f1=0.1547, cascade_acc=0.3190 | val loss=1.2909(mal=1.1637,sub=0.2793), auc=0.6045, f1=0.0000, recall=0.0000, oracle_f1=0.1550, cascade_acc=0.0000
#   -> no improvement (3/7)
# [ViT-B16][Fold 1][Epoch 06] sub_w=0.469 | train loss=1.6337(mal=1.1625,sub=1.0048), auc=0.5384, f1=0.2730, recall=0.5494, oracle_f1=0.1547, cascade_acc=0.3671 | val loss=1.2962(mal=1.1650,sub=0.2797), auc=0.6041, f1=0.2710, recall=0.8061, oracle_f1=0.1550, cascade_acc=0.5204
#   -> no improvement (4/7)
# [ViT-B16][Fold 1][Epoch 07] sub_w=0.483 | train loss=1.6192(mal=1.1475,sub=0.9771), auc=0.5806, f1=0.2878, recall=0.6456, oracle_f1=0.1547, cascade_acc=0.4228 | val loss=1.2553(mal=1.1198,sub=0.2806), auc=0.5945, f1=0.3350, recall=0.3367, oracle_f1=0.1550, cascade_acc=0.2449
#   -> no improvement (5/7)
# [ViT-B16][Fold 1][Epoch 08] sub_w=0.497 | train loss=1.6114(mal=1.1254,sub=0.9789), auc=0.5931, f1=0.3126, recall=0.3443, oracle_f1=0.1547, cascade_acc=0.2633 | val loss=1.2548(mal=1.1146,sub=0.2823), auc=0.5914, f1=0.3235, recall=0.4490, oracle_f1=0.1550, cascade_acc=0.3265
#   -> no improvement (6/7)
# [ViT-B16][Fold 1][Epoch 09] sub_w=0.510 | train loss=1.6481(mal=1.1257,sub=1.0237), auc=0.5928, f1=0.3063, recall=0.3392, oracle_f1=0.1547, cascade_acc=0.2557 | val loss=1.2521(mal=1.1141,sub=0.2704), auc=0.5889, f1=0.3333, recall=0.3673, oracle_f1=0.1550, cascade_acc=0.2755
#   -> no improvement (7/7)
#   -> early stopping triggered at epoch 9
#
# -- Final Evaluation --
# [Malignancy]  AUC=0.6734, F1=0.0000, Recall=0.0000, Acc=0.8414
# [Subtype Oracle]  Acc=0.6327, MacroF1=0.1550
# [Cascade]  SubtypeAcc=0.0000, GateRecall=0.0000
# Binary CM:
# [[520   0]
#  [ 98   0]]
# Subtype Oracle CM:
# [[ 0  0  0  0  8]
#  [ 0  0  0  0  5]
#  [ 0  0  0  0 17]
#  [ 0  0  0  0  6]
#  [ 0  0  0  0 62]]
#
# [ViT-B16][Fold 1] Final Metrics
# Malignancy  AUC=0.6734, F1=0.0000, Recall=0.0000
# Subtype Oracle  Acc=0.6327, MacroF1=0.1550
# Cascade  Acc=0.0000, GateRecall=0.0000
#
# ================================================================================
# Running ViT-B16 | Fold 2
# ================================================================================
# [FOLD 2] Train benign(0): 2077, malignant(1): 395, pos_weight=5.2582, subtype_counts=[32.0, 22.0, 67.0, 25.0, 249.0], subtype_class_weights=[1.151900053024292, 1.6755000352859497, 0.5501999855041504, 1.4744000434875488, 0.14800000190734863]
# [ViT-B16][Fold 2][Epoch 01] sub_w=0.400 | train loss=1.5990(mal=1.1795,sub=1.0488), auc=0.4912, f1=0.2393, recall=0.4861, oracle_f1=0.1535, cascade_acc=0.3114 | val loss=1.2906(mal=1.1782,sub=0.2812), auc=0.4550, f1=0.2737, recall=1.0000, oracle_f1=0.1550, cascade_acc=0.6327
#   -> best saved (val_auc=0.4550): us_cascade_models18/ViT-B16_fold2_best.pth
# [ViT-B16][Fold 2][Epoch 02] sub_w=0.414 | train loss=1.5814(mal=1.1731,sub=0.9867), auc=0.4813, f1=0.2406, recall=0.4709, oracle_f1=0.1547, cascade_acc=0.2810 | val loss=1.2751(mal=1.1679,sub=0.2591), auc=0.6074, f1=0.2737, recall=1.0000, oracle_f1=0.1550, cascade_acc=0.6327
#   -> best saved (val_auc=0.6074): us_cascade_models18/ViT-B16_fold2_best.pth
# [ViT-B16][Fold 2][Epoch 03] sub_w=0.428 | train loss=1.5934(mal=1.1664,sub=0.9987), auc=0.5201, f1=0.2520, recall=0.5494, oracle_f1=0.1547, cascade_acc=0.3519 | val loss=1.2590(mal=1.1474,sub=0.2611), auc=0.5814, f1=0.3209, recall=0.3061, oracle_f1=0.1550, cascade_acc=0.2245
#   -> no improvement (1/7)
# [ViT-B16][Fold 2][Epoch 04] sub_w=0.441 | train loss=1.6105(mal=1.1634,sub=1.0129), auc=0.5240, f1=0.2391, recall=0.4304, oracle_f1=0.1547, cascade_acc=0.2456 | val loss=1.2828(mal=1.1616,sub=0.2745), auc=0.5714, f1=0.2737, recall=1.0000, oracle_f1=0.1550, cascade_acc=0.6327
#   -> no improvement (2/7)
# [ViT-B16][Fold 2][Epoch 05] sub_w=0.455 | train loss=1.6209(mal=1.1662,sub=0.9988), auc=0.5136, f1=0.2585, recall=0.6000, oracle_f1=0.1547, cascade_acc=0.3899 | val loss=1.2859(mal=1.1608,sub=0.2748), auc=0.5991, f1=0.2693, recall=0.6224, oracle_f1=0.1550, cascade_acc=0.4082
#   -> no improvement (3/7)
# [ViT-B16][Fold 2][Epoch 06] sub_w=0.469 | train loss=1.6261(mal=1.1594,sub=0.9952), auc=0.5355, f1=0.2578, recall=0.4937, oracle_f1=0.1547, cascade_acc=0.3241 | val loss=1.2601(mal=1.1334,sub=0.2700), auc=0.5736, f1=0.2747, recall=0.2551, oracle_f1=0.1550, cascade_acc=0.1837
#   -> no improvement (4/7)
# [ViT-B16][Fold 2][Epoch 07] sub_w=0.483 | train loss=1.5934(mal=1.1294,sub=0.9611), auc=0.5842, f1=0.3044, recall=0.3418, oracle_f1=0.1547, cascade_acc=0.2481 | val loss=1.2661(mal=1.1340,sub=0.2735), auc=0.5828, f1=0.2361, recall=0.1735, oracle_f1=0.1550, cascade_acc=0.1122
#   -> no improvement (5/7)
# [ViT-B16][Fold 2][Epoch 08] sub_w=0.497 | train loss=1.6354(mal=1.1355,sub=1.0068), auc=0.5816, f1=0.2860, recall=0.3241, oracle_f1=0.1547, cascade_acc=0.2456 | val loss=1.2990(mal=1.1463,sub=0.3077), auc=0.5703, f1=0.2992, recall=0.3878, oracle_f1=0.1550, cascade_acc=0.2755
#   -> no improvement (6/7)
# [ViT-B16][Fold 2][Epoch 09] sub_w=0.510 | train loss=1.6066(mal=1.1156,sub=0.9621), auc=0.5801, f1=0.3324, recall=0.3114, oracle_f1=0.1547, cascade_acc=0.2405 | val loss=1.2994(mal=1.1494,sub=0.2940), auc=0.5824, f1=0.2029, recall=0.1429, oracle_f1=0.1550, cascade_acc=0.0816
#   -> no improvement (7/7)
#   -> early stopping triggered at epoch 9
#
# -- Final Evaluation --
# [Malignancy]  AUC=0.6074, F1=0.2737, Recall=1.0000, Acc=0.1586
# [Subtype Oracle]  Acc=0.6327, MacroF1=0.1550
# [Cascade]  SubtypeAcc=0.6327, GateRecall=1.0000
# Binary CM:
# [[  0 520]
#  [  0  98]]
# Subtype Oracle CM:
# [[ 0  0  0  0  8]
#  [ 0  0  0  0  5]
#  [ 0  0  0  0 17]
#  [ 0  0  0  0  6]
#  [ 0  0  0  0 62]]
#
# [ViT-B16][Fold 2] Final Metrics
# Malignancy  AUC=0.6074, F1=0.2737, Recall=1.0000
# Subtype Oracle  Acc=0.6327, MacroF1=0.1550
# Cascade  Acc=0.6327, GateRecall=1.0000
#
# ================================================================================
# Running ViT-B16 | Fold 3
# ================================================================================
# [FOLD 3] Train benign(0): 2078, malignant(1): 394, pos_weight=5.2741, subtype_counts=[32.0, 21.0, 68.0, 25.0, 248.0], subtype_class_weights=[1.1354999542236328, 1.730299949645996, 0.5343000292778015, 1.4534000158309937, 0.14650000631809235]
# [ViT-B16][Fold 3][Epoch 01] sub_w=0.400 | train loss=1.5767(mal=1.1762,sub=1.0012), auc=0.4999, f1=0.2332, recall=0.4543, oracle_f1=0.1606, cascade_acc=0.3147 | val loss=1.2792(mal=1.1677,sub=0.2789), auc=0.7486, f1=0.0000, recall=0.0000, oracle_f1=0.1556, cascade_acc=0.0000
#   -> best saved (val_auc=0.7486): us_cascade_models18/ViT-B16_fold3_best.pth
# [ViT-B16][Fold 3][Epoch 02] sub_w=0.414 | train loss=1.5789(mal=1.1711,sub=0.9855), auc=0.4996, f1=0.2315, recall=0.4569, oracle_f1=0.1545, cascade_acc=0.2716 | val loss=1.3025(mal=1.1878,sub=0.2771), auc=0.7223, f1=0.2762, recall=1.0000, oracle_f1=0.1556, cascade_acc=0.6364
#   -> no improvement (1/7)
# [ViT-B16][Fold 3][Epoch 03] sub_w=0.428 | train loss=1.5906(mal=1.1734,sub=0.9758), auc=0.4693, f1=0.2412, recall=0.6320, oracle_f1=0.1545, cascade_acc=0.3782 | val loss=1.2897(mal=1.1675,sub=0.2858), auc=0.7118, f1=0.2762, recall=1.0000, oracle_f1=0.1556, cascade_acc=0.6364
#   -> no improvement (2/7)
# [ViT-B16][Fold 3][Epoch 04] sub_w=0.441 | train loss=1.5798(mal=1.1682,sub=0.9325), auc=0.4989, f1=0.2241, recall=0.3782, oracle_f1=0.1545, cascade_acc=0.2259 | val loss=1.3003(mal=1.1751,sub=0.2837), auc=0.7173, f1=0.2762, recall=1.0000, oracle_f1=0.1556, cascade_acc=0.6364
#   -> no improvement (3/7)
# [ViT-B16][Fold 3][Epoch 05] sub_w=0.455 | train loss=1.6136(mal=1.1694,sub=0.9760), auc=0.4954, f1=0.2505, recall=0.5990, oracle_f1=0.1545, cascade_acc=0.3756 | val loss=1.2971(mal=1.1673,sub=0.2852), auc=0.7142, f1=0.2762, recall=1.0000, oracle_f1=0.1556, cascade_acc=0.6364
#   -> no improvement (4/7)
# [ViT-B16][Fold 3][Epoch 06] sub_w=0.469 | train loss=1.6375(mal=1.1645,sub=1.0085), auc=0.5251, f1=0.2711, recall=0.6371, oracle_f1=0.1545, cascade_acc=0.3909 | val loss=1.2940(mal=1.1631,sub=0.2792), auc=0.7254, f1=0.2762, recall=1.0000, oracle_f1=0.1556, cascade_acc=0.6364
#   -> no improvement (5/7)
# [ViT-B16][Fold 3][Epoch 07] sub_w=0.483 | train loss=1.6615(mal=1.1689,sub=1.0205), auc=0.5283, f1=0.2548, recall=0.5076, oracle_f1=0.1541, cascade_acc=0.3198 | val loss=1.2999(mal=1.1681,sub=0.2729), auc=0.7274, f1=0.0000, recall=0.0000, oracle_f1=0.1556, cascade_acc=0.0000
#   -> no improvement (6/7)
# [ViT-B16][Fold 3][Epoch 08] sub_w=0.497 | train loss=1.6372(mal=1.1610,sub=0.9591), auc=0.5461, f1=0.2671, recall=0.5152, oracle_f1=0.1545, cascade_acc=0.3173 | val loss=1.3223(mal=1.1842,sub=0.2780), auc=0.7365, f1=0.0000, recall=0.0000, oracle_f1=0.1556, cascade_acc=0.0000
#   -> no improvement (7/7)
#   -> early stopping triggered at epoch 8
#
# -- Final Evaluation --
# [Malignancy]  AUC=0.7486, F1=0.0000, Recall=0.0000, Acc=0.8398
# [Subtype Oracle]  Acc=0.6364, MacroF1=0.1556
# [Cascade]  SubtypeAcc=0.0000, GateRecall=0.0000
# Binary CM:
# [[519   0]
#  [ 99   0]]
# Subtype Oracle CM:
# [[ 0  0  0  0  8]
#  [ 0  0  0  0  6]
#  [ 0  0  0  0 16]
#  [ 0  0  0  0  6]
#  [ 0  0  0  0 63]]
#
# [ViT-B16][Fold 3] Final Metrics
# Malignancy  AUC=0.7486, F1=0.0000, Recall=0.0000
# Subtype Oracle  Acc=0.6364, MacroF1=0.1556
# Cascade  Acc=0.0000, GateRecall=0.0000
#
# ================================================================================
# Running ViT-B16 | Fold 4
# ================================================================================
# [FOLD 4] Train benign(0): 2078, malignant(1): 394, pos_weight=5.2741, subtype_counts=[32.0, 21.0, 67.0, 25.0, 249.0], subtype_class_weights=[1.1338000297546387, 1.7276999950408936, 0.5414999723434448, 1.451300024986267, 0.14569999277591705]
# [ViT-B16][Fold 4][Epoch 01] sub_w=0.400 | train loss=1.6014(mal=1.1823,sub=1.0478), auc=0.4958, f1=0.2331, recall=0.4036, oracle_f1=0.1596, cascade_acc=0.2487 | val loss=1.2860(mal=1.1686,sub=0.2936), auc=0.6495, f1=0.2762, recall=1.0000, oracle_f1=0.1540, cascade_acc=0.6263
#   -> best saved (val_auc=0.6495): us_cascade_models18/ViT-B16_fold4_best.pth
# [ViT-B16][Fold 4][Epoch 02] sub_w=0.414 | train loss=1.5819(mal=1.1719,sub=0.9909), auc=0.5028, f1=0.2430, recall=0.5051, oracle_f1=0.1549, cascade_acc=0.3198 | val loss=1.2982(mal=1.1870,sub=0.2687), auc=0.5574, f1=0.2762, recall=1.0000, oracle_f1=0.1540, cascade_acc=0.6263
#   -> no improvement (1/7)
# [ViT-B16][Fold 4][Epoch 03] sub_w=0.428 | train loss=1.5981(mal=1.1716,sub=0.9975), auc=0.4967, f1=0.2295, recall=0.4619, oracle_f1=0.1549, cascade_acc=0.2843 | val loss=1.2814(mal=1.1678,sub=0.2657), auc=0.6545, f1=0.2762, recall=1.0000, oracle_f1=0.1540, cascade_acc=0.6263
#   -> best saved (val_auc=0.6545): us_cascade_models18/ViT-B16_fold4_best.pth
# [ViT-B16][Fold 4][Epoch 04] sub_w=0.441 | train loss=1.6161(mal=1.1684,sub=1.0141), auc=0.5074, f1=0.2565, recall=0.6041, oracle_f1=0.1549, cascade_acc=0.3858 | val loss=1.2997(mal=1.1793,sub=0.2728), auc=0.5896, f1=0.0000, recall=0.0000, oracle_f1=0.1540, cascade_acc=0.0000
#   -> no improvement (1/7)
# [ViT-B16][Fold 4][Epoch 05] sub_w=0.455 | train loss=1.6214(mal=1.1682,sub=0.9957), auc=0.5034, f1=0.2425, recall=0.4416, oracle_f1=0.1549, cascade_acc=0.2970 | val loss=1.3002(mal=1.1679,sub=0.2906), auc=0.6500, f1=0.0000, recall=0.0000, oracle_f1=0.1540, cascade_acc=0.0000
#   -> no improvement (2/7)
# [ViT-B16][Fold 4][Epoch 06] sub_w=0.469 | train loss=1.6209(mal=1.1703,sub=0.9609), auc=0.5032, f1=0.2564, recall=0.5178, oracle_f1=0.1549, cascade_acc=0.3274 | val loss=1.3010(mal=1.1700,sub=0.2794), auc=0.6386, f1=0.0000, recall=0.0000, oracle_f1=0.1540, cascade_acc=0.0000
#   -> no improvement (3/7)
# [ViT-B16][Fold 4][Epoch 07] sub_w=0.483 | train loss=1.6421(mal=1.1665,sub=0.9850), auc=0.5169, f1=0.2588, recall=0.5939, oracle_f1=0.1549, cascade_acc=0.3756 | val loss=1.2982(mal=1.1670,sub=0.2718), auc=0.6325, f1=0.2737, recall=0.9899, oracle_f1=0.1540, cascade_acc=0.6263
#   -> no improvement (4/7)
# [ViT-B16][Fold 4][Epoch 08] sub_w=0.497 | train loss=1.6405(mal=1.1665,sub=0.9548), auc=0.5125, f1=0.2635, recall=0.6675, oracle_f1=0.1549, cascade_acc=0.4416 | val loss=1.3398(mal=1.2031,sub=0.2754), auc=0.6896, f1=0.0000, recall=0.0000, oracle_f1=0.1540, cascade_acc=0.0000
#   -> best saved (val_auc=0.6896): us_cascade_models18/ViT-B16_fold4_best.pth
# [ViT-B16][Fold 4][Epoch 09] sub_w=0.510 | train loss=1.6798(mal=1.1733,sub=0.9925), auc=0.5133, f1=0.2430, recall=0.4213, oracle_f1=0.1528, cascade_acc=0.2386 | val loss=1.3270(mal=1.1723,sub=0.3032), auc=0.4827, f1=0.0000, recall=0.0000, oracle_f1=0.1540, cascade_acc=0.0000
#   -> no improvement (1/7)
# [ViT-B16][Fold 4][Epoch 10] sub_w=0.524 | train loss=1.6926(mal=1.1680,sub=1.0009), auc=0.5017, f1=0.2620, recall=0.6497, oracle_f1=0.1549, cascade_acc=0.3934 | val loss=1.3229(mal=1.1795,sub=0.2736), auc=0.6682, f1=0.0000, recall=0.0000, oracle_f1=0.1540, cascade_acc=0.0000
#   -> no improvement (2/7)
# [ViT-B16][Fold 4][Epoch 11] sub_w=0.538 | train loss=1.6984(mal=1.1695,sub=0.9832), auc=0.4959, f1=0.2347, recall=0.4670, oracle_f1=0.1549, cascade_acc=0.3173 | val loss=1.3293(mal=1.1683,sub=0.2992), auc=0.6929, f1=0.0000, recall=0.0000, oracle_f1=0.1540, cascade_acc=0.0000
#   -> best saved (val_auc=0.6929): us_cascade_models18/ViT-B16_fold4_best.pth
# [ViT-B16][Fold 4][Epoch 12] sub_w=0.552 | train loss=1.6935(mal=1.1679,sub=0.9527), auc=0.4909, f1=0.2262, recall=0.3731, oracle_f1=0.1549, cascade_acc=0.2487 | val loss=1.3240(mal=1.1701,sub=0.2789), auc=0.6867, f1=0.2762, recall=1.0000, oracle_f1=0.1540, cascade_acc=0.6263
#   -> no improvement (1/7)
# [ViT-B16][Fold 4][Epoch 13] sub_w=0.566 | train loss=1.7277(mal=1.1663,sub=0.9927), auc=0.5018, f1=0.2260, recall=0.3832, oracle_f1=0.1549, cascade_acc=0.2640 | val loss=1.3231(mal=1.1708,sub=0.2693), auc=0.5293, f1=0.2762, recall=1.0000, oracle_f1=0.1540, cascade_acc=0.6263
#   -> no improvement (2/7)
# [ViT-B16][Fold 4][Epoch 14] sub_w=0.579 | train loss=1.7319(mal=1.1656,sub=0.9776), auc=0.5221, f1=0.2608, recall=0.6650, oracle_f1=0.1549, cascade_acc=0.4213 | val loss=1.3236(mal=1.1660,sub=0.2721), auc=0.5387, f1=0.2830, recall=0.8990, oracle_f1=0.1540, cascade_acc=0.5758
#   -> no improvement (3/7)
# [ViT-B16][Fold 4][Epoch 15] sub_w=0.593 | train loss=1.7470(mal=1.1704,sub=0.9722), auc=0.4835, f1=0.2360, recall=0.4695, oracle_f1=0.1549, cascade_acc=0.2893 | val loss=1.3274(mal=1.1668,sub=0.2709), auc=0.5377, f1=0.2769, recall=0.9495, oracle_f1=0.1540, cascade_acc=0.6061
#   -> no improvement (4/7)
# [ViT-B16][Fold 4][Epoch 16] sub_w=0.607 | train loss=1.7618(mal=1.1690,sub=0.9767), auc=0.4895, f1=0.2526, recall=0.6218, oracle_f1=0.1549, cascade_acc=0.3959 | val loss=1.3428(mal=1.1715,sub=0.2823), auc=0.5057, f1=0.2762, recall=1.0000, oracle_f1=0.1540, cascade_acc=0.6263
#   -> no improvement (5/7)
# [ViT-B16][Fold 4][Epoch 17] sub_w=0.621 | train loss=1.7753(mal=1.1679,sub=0.9786), auc=0.4907, f1=0.2494, recall=0.6294, oracle_f1=0.1549, cascade_acc=0.3985 | val loss=1.3447(mal=1.1678,sub=0.2851), auc=0.5043, f1=0.0000, recall=0.0000, oracle_f1=0.1540, cascade_acc=0.0000
#   -> no improvement (6/7)
# [ViT-B16][Fold 4][Epoch 18] sub_w=0.634 | train loss=1.8128(mal=1.1670,sub=1.0179), auc=0.4647, f1=0.1783, recall=0.2716, oracle_f1=0.1549, cascade_acc=0.1650 | val loss=1.3410(mal=1.1678,sub=0.2731), auc=0.5000, f1=0.2762, recall=1.0000, oracle_f1=0.1540, cascade_acc=0.6263
#   -> no improvement (7/7)
#   -> early stopping triggered at epoch 18
#
# -- Final Evaluation --
# [Malignancy]  AUC=0.6929, F1=0.0000, Recall=0.0000, Acc=0.8398
# [Subtype Oracle]  Acc=0.6263, MacroF1=0.1540
# [Cascade]  SubtypeAcc=0.0000, GateRecall=0.0000
# Binary CM:
# [[519   0]
#  [ 99   0]]
# Subtype Oracle CM:
# [[ 0  0  0  0  8]
#  [ 0  0  0  0  6]
#  [ 0  0  0  0 17]
#  [ 0  0  0  0  6]
#  [ 0  0  0  0 62]]
#
# [ViT-B16][Fold 4] Final Metrics
# Malignancy  AUC=0.6929, F1=0.0000, Recall=0.0000
# Subtype Oracle  Acc=0.6263, MacroF1=0.1540
# Cascade  Acc=0.0000, GateRecall=0.0000
#
# ================================================================================
# Running ViT-B16 | Fold 5
# ================================================================================
# [FOLD 5] Train benign(0): 2078, malignant(1): 394, pos_weight=5.2741, subtype_counts=[32.0, 22.0, 67.0, 24.0, 249.0], subtype_class_weights=[1.1378999948501587, 1.6550999879837036, 0.5435000061988831, 1.517199993133545, 0.1462000012397766]
# [ViT-B16][Fold 5][Epoch 01] sub_w=0.400 | train loss=1.5772(mal=1.1767,sub=1.0014), auc=0.5048, f1=0.2390, recall=0.4492, oracle_f1=0.1542, cascade_acc=0.2970 | val loss=1.3221(mal=1.1973,sub=0.3121), auc=0.6041, f1=0.2762, recall=1.0000, oracle_f1=0.1540, cascade_acc=0.6263
#   -> best saved (val_auc=0.6041): us_cascade_models18/ViT-B16_fold5_best.pth
# [ViT-B16][Fold 5][Epoch 02] sub_w=0.414 | train loss=1.5643(mal=1.1714,sub=0.9495), auc=0.4990, f1=0.2528, recall=0.5736, oracle_f1=0.1549, cascade_acc=0.3604 | val loss=1.3167(mal=1.1734,sub=0.3463), auc=0.5880, f1=0.0000, recall=0.0000, oracle_f1=0.1540, cascade_acc=0.0000
#   -> no improvement (1/7)
# [ViT-B16][Fold 5][Epoch 03] sub_w=0.428 | train loss=1.6038(mal=1.1665,sub=1.0227), auc=0.5229, f1=0.2476, recall=0.4569, oracle_f1=0.1549, cascade_acc=0.3020 | val loss=1.3038(mal=1.1760,sub=0.2989), auc=0.5917, f1=0.2953, recall=0.9798, oracle_f1=0.1540, cascade_acc=0.6061
#   -> no improvement (2/7)
# [ViT-B16][Fold 5][Epoch 04] sub_w=0.441 | train loss=1.6092(mal=1.1585,sub=1.0211), auc=0.5545, f1=0.2721, recall=0.5508, oracle_f1=0.1549, cascade_acc=0.3579 | val loss=1.2977(mal=1.1697,sub=0.2899), auc=0.5811, f1=0.2762, recall=1.0000, oracle_f1=0.1540, cascade_acc=0.6263
#   -> no improvement (3/7)
# [ViT-B16][Fold 5][Epoch 05] sub_w=0.455 | train loss=1.5937(mal=1.1496,sub=0.9755), auc=0.5728, f1=0.2720, recall=0.4391, oracle_f1=0.1549, cascade_acc=0.2893 | val loss=1.2607(mal=1.1151,sub=0.3199), auc=0.5810, f1=0.3113, recall=0.3333, oracle_f1=0.1540, cascade_acc=0.2626
#   -> no improvement (4/7)
# [ViT-B16][Fold 5][Epoch 06] sub_w=0.469 | train loss=1.5959(mal=1.1286,sub=0.9964), auc=0.5856, f1=0.3047, recall=0.3147, oracle_f1=0.1549, cascade_acc=0.2360 | val loss=1.2895(mal=1.1490,sub=0.2997), auc=0.5862, f1=0.2980, recall=0.4545, oracle_f1=0.1540, cascade_acc=0.3232
#   -> no improvement (5/7)
# [ViT-B16][Fold 5][Epoch 07] sub_w=0.483 | train loss=1.6100(mal=1.1268,sub=1.0009), auc=0.5915, f1=0.3106, recall=0.3756, oracle_f1=0.1549, cascade_acc=0.2792 | val loss=1.2563(mal=1.1148,sub=0.2930), auc=0.5625, f1=0.3277, recall=0.2929, oracle_f1=0.1540, cascade_acc=0.2424
#   -> no improvement (6/7)
# [ViT-B16][Fold 5][Epoch 08] sub_w=0.497 | train loss=1.6190(mal=1.1272,sub=0.9903), auc=0.5658, f1=0.2623, recall=0.2716, oracle_f1=0.1549, cascade_acc=0.1980 | val loss=1.2798(mal=1.1264,sub=0.3089), auc=0.5735, f1=0.2581, recall=0.2020, oracle_f1=0.1540, cascade_acc=0.1717
#   -> no improvement (7/7)
#   -> early stopping triggered at epoch 8
#
# -- Final Evaluation --
# [Malignancy]  AUC=0.6041, F1=0.2762, Recall=1.0000, Acc=0.1602
# [Subtype Oracle]  Acc=0.6263, MacroF1=0.1540
# [Cascade]  SubtypeAcc=0.6263, GateRecall=1.0000
# Binary CM:
# [[  0 519]
#  [  0  99]]
# Subtype Oracle CM:
# [[ 0  0  0  0  8]
#  [ 0  0  0  0  5]
#  [ 0  0  0  0 17]
#  [ 0  0  0  0  7]
#  [ 0  0  0  0 62]]
#
# [ViT-B16][Fold 5] Final Metrics
# Malignancy  AUC=0.6041, F1=0.2762, Recall=1.0000
# Subtype Oracle  Acc=0.6263, MacroF1=0.1540
# Cascade  Acc=0.6263, GateRecall=1.0000
#      model  fold   mal_acc   mal_auc    mal_f1  mal_recall  \
# 0  ViT-B16     1  0.841424  0.673391  0.000000         0.0
# 1  ViT-B16     2  0.158576  0.607418  0.273743         1.0
# 2  ViT-B16     3  0.839806  0.748574  0.000000         0.0
# 3  ViT-B16     4  0.839806  0.692912  0.000000         0.0
# 4  ViT-B16     5  0.160194  0.604144  0.276151         1.0
#
#    subtype_oracle_acc  subtype_oracle_macro_f1  subtype_cascade_acc  \
# 0            0.632653                 0.155000             0.000000
# 1            0.632653                 0.155000             0.632653
# 2            0.636364                 0.155556             0.000000
# 3            0.626263                 0.154037             0.000000
# 4            0.626263                 0.154037             0.626263
#
#    subtype_gate_recall            binary_cm  \
# 0                  0.0  [[520, 0], [98, 0]]
# 1                  1.0  [[0, 520], [0, 98]]
# 2                  0.0  [[519, 0], [99, 0]]
# 3                  0.0  [[519, 0], [99, 0]]
# 4                  1.0  [[0, 519], [0, 99]]
#
#                                    subtype_oracle_cm
# 0  [[0, 0, 0, 0, 8], [0, 0, 0, 0, 5], [0, 0, 0, 0...
# 1  [[0, 0, 0, 0, 8], [0, 0, 0, 0, 5], [0, 0, 0, 0...
# 2  [[0, 0, 0, 0, 8], [0, 0, 0, 0, 6], [0, 0, 0, 0...
# 3  [[0, 0, 0, 0, 8], [0, 0, 0, 0, 6], [0, 0, 0, 0...
# 4  [[0, 0, 0, 0, 8], [0, 0, 0, 0, 5], [0, 0, 0, 0...
# >>> Training Hybrid...
#
# ================================================================================
# Running Hybrid | Fold 1
# ================================================================================
# [FOLD 1] Train benign(0): 2077, malignant(1): 395, pos_weight=5.2582, subtype_counts=[32.0, 22.0, 67.0, 25.0, 249.0], subtype_class_weights=[1.151900053024292, 1.6755000352859497, 0.5501999855041504, 1.4744000434875488, 0.14800000190734863]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1185
#    1183 # ── Hybrid ────────────────────────────────────────────────────
#    1184 print(">>> Training Hybrid...")
# -> 1185 hybrid_cv_df, hybrid_history_df = run_cv_for_model(
#    1186     model_name="Hybrid",
#    1187     model_type="hybrid",
#    1188     build_fn=lambda: build_hybrid_patient_model(load_pretrained=True),
#    1189 )
#    1190 display(hybrid_cv_df)
#    1193 # ============================================================
#    1194 # 16) 5-fold 평균 ± 표준편차 요약
#    1195 # ============================================================
#
# Cell In[3], line 1101, in run_cv_for_model(model_name, model_type, build_fn)
#    1097 print("=" * 80)
#    1099 train_loader, val_loader, pos_weight, subtype_class_weights = make_fold_loaders(fold_idx)
# -> 1101 model = build_fn()
#    1103 # CascadeCriterion: subtype_loss_weight는 fit_model 내부에서 epoch마다 업데이트
#    1104 criterion = CascadeCriterion(
#    1105     pos_weight=pos_weight,
#    1106     subtype_class_weights=subtype_class_weights,
#    1107     subtype_loss_weight=SUBTYPE_LOSS_WEIGHT_START,
#    1108 )
#
# Cell In[3], line 1188, in <lambda>()
#    1183 # ── Hybrid ────────────────────────────────────────────────────
#    1184 print(">>> Training Hybrid...")
#    1185 hybrid_cv_df, hybrid_history_df = run_cv_for_model(
#    1186     model_name="Hybrid",
#    1187     model_type="hybrid",
# -> 1188     build_fn=lambda: build_hybrid_patient_model(load_pretrained=True),
#    1189 )
#    1190 display(hybrid_cv_df)
#    1193 # ============================================================
#    1194 # 16) 5-fold 평균 ± 표준편차 요약
#    1195 # ============================================================
#
# Cell In[3], line 951, in build_hybrid_patient_model(load_pretrained)
#     946 def build_hybrid_patient_model(load_pretrained=True):
#     947     return CNNTransformerHybridPatient(
#     948         load_pretrained=load_pretrained,
#     949         freeze_backbone=True,
#     950         unfreeze_layer4=True,
# --> 951         resnet_weight_path=LOCAL_RESNET_WEIGHTS,
#     952     )
#
# NameError: name 'LOCAL_RESNET_WEIGHTS' is not defined
