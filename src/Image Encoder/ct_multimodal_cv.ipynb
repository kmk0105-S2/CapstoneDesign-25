# %%
from torchvision import models
from torchvision.models import vit_b_16

print("=" * 60)

try:
    m1 = models.resnet50(weights=None)
    print("ResNet50 build success")
except Exception as e:
    print("Fail", e)

try:
    m2 = vit_b_16(weights=None)
    print("Vit-B/16 build success")
except Exception as e:
    print("Fail",e)

print("=" * 60)
# Out:
# ============================================================
# ResNet50 build success
# Vit-B/16 build success
# ============================================================

# %%
# 1) 환경 설정 + import
import os
import gc
import random
from pathlib import Path
from collections import OrderedDict, defaultdict

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.metrics import (
    confusion_matrix, classification_report,
    accuracy_score, f1_score, roc_auc_score, recall_score
)

import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader, WeightedRandomSampler
from torchvision import models
from torchvision.models import vit_b_16, ViT_B_16_Weights, ResNet50_Weights

SEED = 42
random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)
torch.cuda.manual_seed_all(SEED)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Device:", device)

torch.backends.cudnn.benchmark = True
# Out:
# Device: cuda

# %%
print(f"현재 작업 경로: {os.getcwd()}")

test_relative = '/tf/nasw/dataset001/preprocessed/npz/fold_1_train.npz'
print(f"상대경로: {os.path.exists(test_relative)}")
# Out:
# 현재 작업 경로: /tf/notebooks/image encoder
# 상대경로: True

# %%
#2. 경로 설정
DATA_ROOT = Path("/tf/nasw/dataset001/preprocessed/npz_v3_full_image")

FOLDS = [1, 2, 3, 4, 5]

OUTPUT_DIR = Path("./ct_cascade_models")
OUTPUT_DIR.mkdir(parents=True, exist_ok=True)

IMG_SIZE = 224
BATCH_SIZE = 8
NUM_WORKERS = 2
NUM_EPOCHS = 30
LR = 1e-4
WEIGHT_DECAY = 1e-4
PATIENCE = 7
MIN_DELTA = 0.001
THRESHOLD = 0.5

print("DATA_ROOT:", DATA_ROOT)
print("OUTPUT_DIR:", OUTPUT_DIR.resolve())
print("FOLDS:", FOLDS)
# Out:
# DATA_ROOT: /tf/nasw/dataset001/preprocessed/npz_v3_full_image
# OUTPUT_DIR: /tf/notebooks/image encoder/ct_cascade_models
# FOLDS: [1, 2, 3, 4, 5]

# %%
def inspect_fold_npz(fold_idx):
    train_npz_path = DATA_ROOT / f"fold_{fold_idx}_train.npz"
    val_npz_path = DATA_ROOT / f"fold_{fold_idx}_val.npz"

    print("TRAIN:", train_npz_path, train_npz_path.exits())
    print("VAL:", val_npz_path, val_npz_path.exists())

    train_npz = np.load(train_npz_path, allow_pickle=False, mmap_mode="r")
    val_npz = np.load(val_npz_path, allow_pickle=False, mmap_mode="r")

    for k in train_npz.files:
        print(f"[train] {k}: shape={train_npz[k].shape}, dtype={train_npz[k].dtype}")
    for k in val_npz.files:
        print(f"[val] {k}: shape={val_npz[k].shape}, dtype={val_npz[k].dtype}")

# %%
#로컬 pretrained weight 경로
LOCAL_RESNET_WEIGHTS = Path("/tf/models/pretrained/resnet50-11ad3fa6.pth")
LOCAL_VIT_WEIGHTS = Path("/tf/models/pretrained/vit_b_16-c867db91.pth")

print("LOCAL_RESNET_WEIGHTS exists:", LOCAL_RESNET_WEIGHTS.exists())
print("LOCAL_VIT_WEIGHTS exists:", LOCAL_VIT_WEIGHTS.exists())
# Out:
# LOCAL_RESNET_WEIGHTS exists: True
# LOCAL_VIT_WEIGHTS exists: True

# %%
def load_local_state_dict(weight_path):
    weight_path = Path(weight_path)
    assert weight_path.exists(), f"Weight file not found: {weight_path}"

    ckpt = torch.load(weight_path, map_location="cpu")

    if isinstance(ckpt, dict) and "state_dict" in ckpt and isinstance(ckpt["state_dict"], dict):
        ckpt = ckpt["state_dict"]

    return ckpt

# %%
def infer_malignant_type_ids(data_root, folds):
    label_set_by_type = defaultdict(set)

    for fold_idx in folds:
        for split_name in ["train", "val"]:
            npz_path = Path(data_root) / f"fold_{fold_idx}_{split_name}.npz"
            data = np.load(npz_path, allow_pickle=False, mmap_mode = "r")

            labels = data["labels"].astype(int)
            tumor_types = data["tumor_types"].astype(int)

            for y, t in zip(labels, tumor_types):
                label_set_by_type[int(t)].add(int(y))
                
        conflicts = {
            t: sorted(list(v))
            for t, v in label_set_by_type.items()
            if len(v) > 1
        }

        if len(conflicts) > 0:
            raise ValueError(
                f"tumor_type가 양성/악성 양쪽에 섞여있음: {conflicts}\n"
            )
        malignant_type_ids = sorted([
            t for t, labs in label_set_by_type.items()
            if labs == {1}
        ])

        print("malignant_type_ids:", malignant_type_ids)
        return malignant_type_ids


MALIGNANT_TYPE_IDS = infer_malignant_type_ids(DATA_ROOT, FOLDS)
MALIGNANT_MAP = {tid: i for i, tid in enumerate(MALIGNANT_TYPE_IDS)}
NUM_MALIGNANT_SUBTYPES = len(MALIGNANT_TYPE_IDS)

print("NUM_MALIGNANT_SUBTYPES:", NUM_MALIGNANT_SUBTYPES)
# Out:
# malignant_type_ids: [0, 1, 3, 5, 7]
# NUM_MALIGNANT_SUBTYPES: 5

# %%
#4. Dataset 정의
class OvarianCTNPZDataset(torch.utils.data.Dataset):
    def __init__(self, npz_path):
        super().__init__()
        self.npz = np.load(npz_path, allow_pickle=False, mmap_mode="r")

        self.images = self.npz["images"]
        self.labels = self.npz["labels"].astype(np.float32)
        self.tumor_types = self.npz["tumor_types"].astype(np.int64)
        self.patient_ids = self.npz["patient_ids"] if "patient_ids" in self.npz.files else np.arange(len(self.labels))

        assert "text_feats" in data, "NPZ must contain 'text_feats'"
        assert "recurrence_labels" in data "NPZ must contain 'recurrence_labels'"

        self.text_feats = data["text_feats"].astype(np.float32)
        self.recurrence_labels = data["recurrence_labels"].astype(np.int64)

        self.mal_mask = (self.labels == 1).astype(np.int64)
        self.mal_subtypes = np.full_like(self.labels, fill_values=-1, dtype=np.int64)

        for i, (y, t) in enumerate(zip(self.labels, self.tumor_types):
            if y == 1 and t in MALIGNANT_MAP:
                self.mal_subtypes[i] = MALIGNANT_MAP[t]
                
        self.text_dim = self.text_feats.shape[1]

        self.mean = torch.tensor([0.485, 0.456, 0.406], dtype=torch.float32).view(1, 3, 1, 1)
        self.std = torch.tensor([0.229, 0.224, 0.225], dtype=torch.float32).view(1, 3, 1, 1)

    def __len__(self):
        return len(self.labels)

    def __getitem__(self, idx):
        x = self.images[idx]
        y = self.labels[idx]

        x = torch.from_numpy(x).float().permute(0, 3, 1, 2).contiguous()

        x = x / 255.0
        x = (x-self.mean) / self.std

        y = int(self.labels[idx])
        tumor_type = int(self.tumor_types[idx])

        if y == 1:
            if tumor_type not in MALIGNANT_MAP:
                raise ValueError(
                    f"malignant sample인데 tumor_type={tumor_type}가 MAP에 없음"
                )
            mal_subtype = MALIGNANT_MAP[tumor_type]
            mal_mask = True
        else:
            mal_subtype = -1
            mal_mask = False
            
        return {
            "image": x,
            "label": torch.tensor(y, dtype = torch.float32),
            "mal_subtype": torch.tensor(mal_subtype, dtype=torch.long),
            "mal_mask": torch.tensor(mal_mask, dtype=torch.bool),
            "text_feat": torch.tensor(self.text_feats[idx], dtype=torch.float32),
            "recurrence": torch.tensor(self.recurrence_labels[idx], dtype=torch.float32)
        }

# %%
# fold별 dataLoader 생성
def make_fold_loaders(fold_idx):
    train_npz_path = DATA_ROOT / f"fold_{fold_idx}_train.npz"
    val_npz_path = DATA_ROOT / f"fold_{fold_idx}_val.npz"

    assert train_npz_path.exists(), f"Missing: {train_npz_path}"
    assert val_npz_path.exists(), f"Missing: {val_npz_path}"

    train_dataset = OvarianCTNPZDataset(train_npz_path)
    val_dataset = OvarianCTNPZDataset(val_npz_path)

    train_loader = DataLoader(
        train_dataset,
        batch_size = BATCH_SIZE,
        shuffle = True,
        num_workers = NUM_WORKERS,
        pin_memory = True
    )

    val_loader = DataLoader(
        val_dataset,
        batch_size = BATCH_SIZE,
        shuffle = False,
        num_workers = NUM_WORKERS,
        pin_memory = True
    )

    labels_np = train_dataset.labels.astype(int)
    neg = (labels_np == 0).sum()
    pos = (labels_np == 1).sum()
    pos_weight_value = neg / max(pos, 1)
    mal_pos_weight = torch.tensor([pos_weight_value], device = device, dtype = torch.float32)

    subtype_counts = np.zeros(NUM_MALIGNANT_SUBTYPES, dtype=np.float64)
    for y, t in zip(train_dataset.labels.astype(int), train_dataset.tumor_types.astype(int)):
        if y == 1 and t in MALIGNANT_MAP:
            subtype_counts[MALIGNANT_MAP[t]] += 1.0
            
    subtype_counts = np.maximum(subtype_counts, 1.0)
    inv = 1.0 / subtype_counts
    subtype_class_weights = inv / inv.mean()
    subtype_class_weights = torch.tensor(subtype_class_weights, dtype = torch.float32, device=device)

    rec_labels = train_dataset.recurrence_labels.astype(int)
    rec_negs = (rec_labels == 0).sum()
    rec_pos = (rec_labels == 1).sum()
    rec_pos_weight_value = rec_neg / max(rec_pos, 1)
    recurrence_pos_weight = torch.tensor([rec_pos_weight_value], device=device, dtype=torch.float32)

    print(f"[FOLD {fold_idx}] Train benign(0): {neg}, malignant(1): {pos}, pos_weight={mal_pos_weight.item():.4f}, "
          f"recurrence_pos_weight={recurrence_pos_weight.item():.4f}\n"
          f"subtype_class_weights = {subtype_class_weights.detach().cpu().numpy().round(4).tolist()} "
         )

    return train_loader, val_loader, mal_pos_weight, subtype_class_weights, recurrence_pos_weight

# %%
class MultimodalCascadeCriterion(nn.Module):
    def __init__(self, pos_weight, subtype_class_weights, subtype_loss_weight, recurrence_pos_weight, recurrence_loss_weight):
        super().__init__()
        self.bce = nn.BCEWithLogitsLoss(pos_weight=pos_weight)
        
        self.ce = nn.CrossEntropyLoss(weight = subtype_class_weights)
        self.subtype_loss_weight = subtype_loss_weight
        print("subtype_loss_weight =", self.subtype_loss_weight)

        self.bce_r = nn.BCEWithLogitsLoss(pos_weight = recurrence_pos_weight)
        self.recurrence_pos_weight = recurrence_pos_weight
        print("recurrence_pos_weight =", self.recurrence_pos_weight)

    def forward(self, outputs, batch, device):
        labels = batch["label"].to(device).view(-1)
        mal_mask = batch["mal_mask"].to(device).view(-1)
        mal_subtype = batch["mal_subtype"].to(device).view(-1)
        rec_label = batch["recurrence"].to(device).view(-1)

        loss_m = self.bce(outputs["malignancy_logits"].view(-1), labels)

        if mal_mask.any():
            loss_s = self.ce(
                outputs["subtype_logits"][mal_mask],
                mal_subtype[mal_mask]
            )

        else:
            loss_s = torch.tensor(0.0, device = device)

        loss_r = self.bce_r(outputs["recurrence_logits"].view(-1), rec_label)

        loss_total = loss_m + self.subtype_loss_weight * loss_s + self.recurrence_loss_weight * loss_r

        return {
            "loss_total": loss_total,
            "loss_malignancy": loss_m,
            "loss_subtype": loss_s,
            "loss_recurrence": loss_r

        }

# %%
#6 train/eval 함수

scaler = torch.amp.GradScaler(enabled=(device.type == "cuda"))

def compute_binary_metrics(y_true, y_prob, threshold = 0.5):
    y_true = np.asarray(y_true).astype(int)
    y_prob = np.asarray(y_prob).astype(float)
    y_pred = (y_prob >= threshold).astype(int)

    metrics = {
        "acc": accuracy_score(y_true, y_pred),
        "auc": roc_auc_score(y_true, y_prob) if len(np.unique(y_true)) > 1 else 0.5,
        "f1": f1_score(y_true, y_pred, zero_division=0),
        "recall": recall_score(y_true, y_pred, zero_division=0),
        "cm": confusion_matrix(y_true, y_pred)
    }
    return metrics

def compute_multiclass_metrics(y_true, y_pred):
    y_true = np.asarray(y_true).astype(int)
    y_pred = np.asarray(y_pred).astype(int)

    if len(y_true) == 0:
        return {
            "acc": np.nan,
            "macro_f1": np.nan,
            "cm": None
        }
    return {
        "acc": accuracy_score(y_true, y_pred),
         "cm": confusion_matrix(y_true, y_pred),
        "macro_f1": f1_score(y_true, y_pred, average="macro", zero_division = 0),
        "macro recall": recall_score(y_true, y_pred, average="macro", zero_division=0)
    }

def train_one_epoch(model, loader, criterion, optimizer, device):
    model.train()
    running_total = 0.0
    running_m = 0.0
    running_s = 0.0
    running_r = 0.0

    all_label = []
    all_mal_prob = []
    all_mal_pred = []

    all_mal_mask = []
    all_subtype_true = []
    all_subtype_pred = []

    all_rec_mask = []
    all_rec_true = []
    all_rec_prob = []

    for batch in loader:
        imgs = batch["image"].to(device, non_blocking=True)
        text_feat = batch["text_feat"].to(device, non_blocking=True)

        optimizer.zero_grad()

        with torch.amp.autocast(device_type="cuda", enabled=(device.type == "cuda")):
            outputs = model(imgs, text_feat)
            loss_dict = criterion(outputs, batch, device)
            loss = loss_dict["loss_total"]

        scaler.scale(loss).backward()
        scaler.step(optimizer)
        scaler.update()

        bs = imgs.size(0)
        running_total += loss_dict["loss_total"].item() * bs
        running_m += loss_dict["loss_malignancy"].item() * bs
        running_s += loss_dict["loss_subtype"].item() * bs
        running_r += loss_dict["loss_recurrence"].item() * bs

        #malignancy
        label_np = batch["label"].detach().cpu().numpy().astype(int).ravel()
        mal_prob_np = torch.sigmoid(outputs["malignancy_logits"]).detach().cpu().numpy().ravel()
        mal_pred_np = (mal_prob_np >= THRESHOLD).astype(int)

        all_label.extend(label_np.tolist())
        all_mal_prob.extend(mal_prob_np.tolist())
        all_mal_pred.extend(mal_pred_np.tolist())

        #subtype
        mal_mask_np = batch["mal_mask"].detach().cpu().numpy().astype(bool).ravel()
        subtype_pred_np = outputs["subtype_logits"].argmax(dim=1).detach().cpu().numpy().astype(int).ravel()
        subtype_true_np = batch["mal_subtype"].detach().cpu().numpy().astype(int).ravel()

        all_mal_mask.extend(mal_mask_np.tolist())
        all_subtype_true.extend(subtype_true_np.tolist())
        all_subtype_pred.extend(subtype_pred_np.tolist())

        #recurrence
        rec_mask_np = batch["recurrence_mask"].view(-1).cpu().numpy().astype(bool)
        rec_true_np = batch["recurrence_label"].view(-1).cpu().numpy().astype(int)
        rec_prob_np = torch.sigmoid(outputs["recurrence_logits"]).detach().cpu().numpy()

        

    all_label = np.concatenate(all_label)
    all_mal_prob = np.concatenate(all_mal_prob)
    all_mal_mask = np.concatenate(all_mal_mask)
    all_subtype_true = np.concatenate(all_subtype_true)
    all_subtype_pred = np.concatenate(all_subtype_pred)

    mal_metrics = compute_binary_metrics(all_label, all_mal_prob, threshold = 0.5)
    
    gt_mal_mask = (all_label == 1)
    oracle_true = all_subtype_true[gt_mal_mask]
    oracle_pred = all_subtype_pred[gt_mal_mask]
    subtype_oracle = compute_multiclass_metrics(oracle_true, oracle_pred)

    #Cascade subtype:
    #GT 악성 샘플 중에서, malignancy도 맞추고 subtype도 맞춰야 정답
    if gt_mal_mask.sum() > 0:
        gate_recall = float((all_mal_pred[gt_mal_mask] == 1).mean())
        cascade_correct = ((all_mal_pred[gt_mal_mask] == 1 ) & (oracle_pred == oracle_true)).astype(np.float32)
        subtype_cascade_acc = float(cascade_correct.mean())
    else:
        gate_recall = np.nan
        subtype_cascade_acc = np.nan

    all_rec_mask = np.concatenate(all_rec_mask)
    all_rec_true = np.concatenate(all_rec_true)
    all_rec_prob = np.concatenate(all_rec_prob)
    rec_metrics = compute_binary_metrics(all_rec_

    metrics = {
        "loss": running_total / len(loader.dataset),
        "loss_malignancy": running_m / len(loader.dataset),
        "loss_subtype": running_s / len(loader.dataset),
        "loss_recurrence": running_r / len(loader.dataset),
        
        "acc": mal_metrics["acc"],
        "auc": mal_metrics["auc"],
        "f1":mal_metrics["f1"],
        "recall": mal_metrics["recall"],
        "cm": mal_metrics["cm"],

        "subtype_oracle_acc": subtype_oracle["acc"],
        "subtype_oracle_macro_f1": subtype_oracle["macro_f1"],
        "subtype_oracle_cm": subtype_oracle["cm"],
        "subtype_cascade_acc": float(subtype_cascade_acc),
        "subtype_gate_recall": float(gate_recall),

        "rec_acc": rec_metrics["acc"],
        "rec_auc": rec_metrics["auc"],
        "rec_f1": rec_metrics["f1"],
        "rec_recall": rec_metrics["recall"],
        "rec_cm": rec_metrics["cm"],
    }
    return metrics

@torch.no_grad()
def eval_one_epoch(model, loader, criterion, device):
    model.eval()
    running_total = 0.0
    running_m = 0.0
    running_s = 0.0
    running_r = 0.0

    all_label = []
    all_mal_prob = []
    all_mal_pred = []

    all_mal_mask = []
    all_subtype_true = []
    all_subtype_pred = []

    all_rec_mask = []
    all_rec_true = []
    all_rec_prob = []

    for batch in loader:
        imgs = batch["image"].to(device, non_blocking=True)
        text_feat = batch["text_feat"].to(device, non_blocking=True)

        with torch.amp.autocast(device_type="cuda", enabled=(device.type == "cuda")):
            outputs = model(imgs)
            loss_dict = criterion(outputs, batch)

        bs = imgs.size(0)
        running_total += loss_dict["loss_total"].item() * bs
        running_m += loss_dict["loss_malignancy"].item() * bs
        running_s += loss_dict["loss_subtype"].item() * bs
        running_r += loss_dict["loss_recurrence"].

        label_np = batch["label"].detach().cpu().numpy().astype(int).ravel()
        mal_mask_np = batch["mal_mask"].detach().cpu().numpy().astype(bool).ravel()

        mal_prob_np = torch.sigmoid(outputs["malignancy_logits"]).detach().cpu().numpy().ravel()
        mal_pred_np = (mal_prob_np >= THRESHOLD).astype(int)

        subtype_pred_np = outputs["subtype_logits"].argmax(dim=1).detach().cpu().numpy().astype(int).ravel()
        subtype_true_np = batch["mal_subtype"].detach().cpu().numpy().astype(int).ravel()

        all_label.append(labels_np)
        all_mal_prob.append(mal_prob_np)
        all_mal_pred.extend(mal_pred_np.tolist())

        all_mal_mask.append(mal_mask_np)
        all_subtype_true.append(mal_subtype_np)
        all_subtype_pred.append(subtype_pred_np)

        rec_mask_np = batch["recurrence_mask"].view(-1).cpu().numpy().astype(bool)
        rec_true_np = batch["recurrence_label"].view(-1).cpu().numpy().astype(int)
        rec_prob_np = torch.sigmoid(outputs["recurrence_logits"]).detach().cpu().numpy()

        all_rec_mask.append(rec_mask_up)
        all_rec_true.append(rec_true_np)
        all_rec_prob.append(rec_prob_np)


    all_label = np.concatenate(all_label)
    all_mal_prob = np.concatenate(all_mal_prob)
    mal_metrics = compute_binary_metrics(all_label, all_mal_prob, threshold = 0.5)
    
    all_mal_mask = np.concatenate(all_mal_mask)
    all_subtype_true = np.concatenate(all_subtype_true)
    all_subtype_pred = np.concatenate(all_subtype_pred)


    gt_mal_mask = (all_label == 1)
    oracle_true = all_subtype_true[all_mal_mask]
    oracle_pred = all_subtype_pred[all_mal_mask]
    subtype_oracle = compute_multiclass_metrics(oracle_true, oracle_pred)

    all_mal_pred = (all_mal_prob >=0.5).astype(int)

    #Cascade subtype:
    #GT 악성 샘플 중에서, malignancy도 맞추고 subtype도 맞춰야 정답
    if gt_mal_mask.sum() > 0:
        gate_recall = float((all_mal_pred[gt_mal_mask] == 1).mean())
        cascade_correct = ((all_mal_pred[gt_mal_mask] == 1 ) & (oracle_pred == oracle_true)).astype(np.float32)
        subtype_cascade_acc = cascade_correct.mean()
    else:
        gate_recall = np.nan
        subtype_cascade_acc = np.nan

    all_rec_mask = np.concatenate(all_rec_mask)
    all_rec_true = np.concatenate(all_rec_true)
    all_rec_prob = np.concatenate(all_rec_prob)
    rec_metrics = compute_binary_metrics(all_rec_true[all_rec_mask], all_rec_prob[all_rec_mask])

    metrics = {
        "loss": running_total / len(loader.dataset),
        "loss_malignancy": running_m / len(loader.dataset),
        "loss_subtype": running_s / len(loader.dataset),
        "loss_recurrence": running_r / len(loader.dataset),
        
        "acc": mal_metrics["acc"],
        "auc": mal_metrics["auc"],
        "f1": mal_metrics["f1"],
        "recall": mal_metrics["recall"],
        "cm": mal_metrics["cm"],

        "subtype_oracle_acc": subtype_oracle["acc"],
        "subtype_oracle_macro_f1": subtype_oracle["macro_f1"],
        "subtype_oracle_cm": subtype_oracle["cm"],

        "subtype_cascade_acc": float(subtype_cascade_acc),
        "subtype_gate_recall": float(gate_recall),

        "rec_acc": rec_metrics["acc"],
        "rec_auc": rec_metrics["auc"],
        "rec_f1": rec_metrics["f1"],
        "rec_recall": rec_metrics["recall"],
        "rec_cm": rec_metrics["cm"],
    }
    return metrics

@torch.no_grad()
def eval_confusion(model, loader, device, criterion, threshold = 0.5):
    return eval_one_epoch(model, loader, criterion, device)

# %%
# slice encoder + patient-level pooling wrapper

class PatientSliceAttentionClassifier(nn.Module):
    def __init__(self, encoder, feat_dim, text dim, hidden_dim=512, text_hidden_dim=256, fusion_hidden_dim=512, dropout=0.3):
        super().__init__()
        self.encoder = encoder

        self.attn = nn.Sequential(
            nn.Linear(feat_dim, feat_dim // 2),
            nn.Tanh(),
            nn.Linear(feat_dim // 2, 1)
        )

        self.shared = nn.Sequential(
            nn.Linear(feat_dim, hidden_dim),
            nn.ReLU(),
            nn.Dropout(dropout)
        )

        #image-only heads
        self.malignancy_head = nn.Linear(hidden_dim, 1)
        self.subtype_head = nn.Linear(hidden_dim, NUM_MALIGNANT_SUBTYPES)

        #text branch
        self.text_branch = nn.Sequential(
            nn.Linear(text_dim, text_hidden_dim),
            nn.ReLU(),
            nn.Dropout(dropout)
        )

        #image + text fusion for recurrence
        self.fusion = nn.Sequential(
            nn.Linear(hidden_dim + text_hidden_dim, fusion_hidden_dim),
            nn.ReLU(),
            nn.Dropout(dropout),
            nn.Linear(fusion_hidden_dim, fusion_hidden_dim),
            nn.ReLU(),
            nn.Dropout(dropout),
        )
        self.recurrence_head = nn.Linear(fusion_hidden_dim, 1)

    def forward(self, image, text_feat):
        # image: [B, S, C, H, W]
        B, S, C, H, W = image.shape
        x = image.view(B * S, C, H, W)

        feat = self.encoder(x)
        feat = feat.view(B, S, -1)

        attn_score = self.attn(feat)
        attn_weight = torch.softmax(attn_score, dim=1)
        pooled = (feat * attn_weight).sum(dim=1)

        z_img = self.shared(pooled)
        z_txt = self.text_branch(text_feat)

        malignancy_logits = self.malignancy_head(z_img).squeeze(1)
        subtype_logits = self.subtype_head(z_img)

        z_fused = self.fusion(torch.cat[z_img, z_txt], dim=1))
        recurrence_logits = self.recurrence_head(z_fused).squeeze(1)

        return {
            "malignancy_logits": malignancy_logits,
            "subtype_logits": subtype_logits,
            "recurrence_logits": recurrence_logits,
            "attn_weight": attn_weight.squeeze(-1)
        }

# %%
#7 모델 정의
def build_resnet50_mm_model(text_dim, load_pretrained=True, freeze_backbone=True, unfreeze_layer4=True, weight_path=LOCAL_RESNET_WEIGHTS):
    encoder = models.resnet50(weights=None)

    if load_pretrained:
        state_dict = load_local_state_dict(weight_path)
        encoder.load_state_dict(state_dict, strict = True)
        
    feat_dim = encoder.fc.in_features
    encoder.fc = nn.Identity()

    if freeze_backbone:
        for p in encoder.parameters():
            p.requires_grad = False

        if unfreeze_layer4:
            for p in encoder.layer4.parameters():
                p.requires_grad = True
    
    model = PatientSliceAttentionMultimodalClassifier(
        encoder = encoder,
        feat_dim = feat_dim,
        text_dim = text_dim
        hidden_dim = 512,
        dropout=0.3
    )
    
    return model

def build_vit_mm_model(text_dim, load_pretrained=True, weight_path=LOCAL_VIT_WEIGHTS):
    encoder = vit_b_16(weights=None)
    if load_pretrained:
        state_dict = load_local_state_dict(weight_path)
        encoder.load_state_dict(state_dict, strict = True)
    
    feat_dim = encoder.heads.head.in_features
    encoder.heads = nn.Identity()

    for p in encoder.parameters():
        p_requires_grad = True
    
    model = PatientSliceAttentionClassifier(
        encoder = encoder,
        feat_dim = feat_dim,
        text_dim = text_dim
        hidden_dim = 512,
        dropout=0.3
    )

    return model

class CNNTransformerHybridPatient(nn.Module):
    def __init__(self, text_dim, d_model=512, nhead=8, num_layers=2, dim_feedforward=1024, dropout=0.3, load_pretrained=True, freeze_backbone=True, unfreeze_layer4=True, resnet_weight_path=LOCAL_RESNET_WEIGHTS):
        super().__init__()
        backbone = models.resnet50(weights=None)
        if load_pretrained:
            state_dict = load_local_state_dict(resnet_weight_path)
            backbone.load_state_dict(state_dict, strict = True)
        feat_dim = backbone.fc.in_features
        backbone.fc = nn.Identity()
        self.encoder = backbone

        if freeze_backbone:
            for p in self.encoder.parameters():
                p.requires_grad = False

            if unfreeze_layer4:
                for p in self.encoder.layer4.parameters():
                    p.requires_grad = True

        self.proj = nn.Linear(feat_dim, d_model)
        self.cls_token = nn.Parameter(torch.zeros(1, 1, d_model))
        self.pos_embed = nn.Parameter(torch.zeros(1, 1+8, d_model))

        encoder_layer = nn.TransformerEncoderLayer(
            d_model=d_model,
            nhead=nhead,
            dim_feedforward=dim_feedforward,
            dropout=dropout,
            batch_first=True,
            activation="gelu"
        )

        self.transformer = nn.TransformerEncoder(encoder_layer, num_layers= num_layers)
        self.norm = nn.LayerNorm(d_model)

        self.shared = nn.Sequential(
            nn.Linear(d_model, 512),
            nn.ReLU(),
            nn.Dropout(dropout),
        )
        self.malignancy_head = nn.Linear(512, 1)
        self.subtype_head = nn.Linear(512, NUM_MALIGNANT_SUBTYPES)

        self.text_branch = nn.Sequential(
            nn.Linear(text_dim, 256),
            nn.ReLU(),
            nn.Dropout(dropout)
        )

        self.recurrence_fusion = nn.Sequential(
            nn.Linear(512 + 256, 512),
            nn.ReLU(),
            nn.Dropout(dropout),
            nn.Linear(512, 1)
        )

    def forward(self, image, text_feat):
        B, S, C, H, W = x.shape
        x = image.view(B * S, C, H, W)

        feat = self.encoder(x)
        feat = feat.view(B, S, -1)

        attn_score = self.attn(feat)
        attn_weight = torch.softmax(attn_score, dim=1)
        pooled = (feat * attn_weight).sum(dim=1)

        z_img = self.shared(pooled)
        z_txt = self.text_branch(text_feat)

        malignancy_logits = self.malignancy_head(z_img).squeeze(1)
        subtype_logits = self.subtype_head(z_img)

        z_fused = self.fusion(torch.cat[z_img, z_txt], dim=1))
        recurrence_logits = self.recurrence_head(z_fused).squeeze(1)

        return {
            "malignancy_logits": malignancy_logits,
            "subtype_logits": subtype_logits,
            "recurrence_logits": recurrence_logits
        }

        

def build_hybrid_patient_model(load_pretrained=True):
    return CNNTransformerHybridPatient(
        load_pretrained=load_pretrained,
        freeze_backbone = True,
        unfreeze_layer4 = True,
        resnet_weight_path=LOCAL_RESNET_WEIGHTS
    )

# %%
#8 공통 학습 함수
def fit_model(model, model_name, fold_idx, train_loader, val_loader, device, num_epochs=30, lr = 1e-4, weight_decay=1e-4, pos_weight=None, criterion=None, patience = 7, min_delta=0.001):
    model = model.to(device)
    
    if criterion is None:
        raise ValueError("cascade 모델에서는 criterion에 CascadeCriterion을 넘겨야함")
        
    optimizer = torch.optim.Adam(
        filter(lambda p: p.requires_grad, model.parameters()),
        lr = lr,
        weight_decay = weight_decay
    )

    best_auc = -1
    best_val_loss = np.inf
    best_path = OUTPUT_DIR / f"{model_name}_fold{fold_idx}_best.pth"
    history = []
    early_stop_counter = 0

    for epoch in range(1, num_epochs+1):
        train_metrics = train_one_epoch(model, train_loader, criterion, optimizer, device)
        val_metrics = eval_one_epoch(model, val_loader, criterion, device)

        row = {
            "fold": fold_idx,
            "epoch": epoch,
            
            "train_loss": train_metrics["loss"],
            "train_acc": train_metrics["acc"],
            "train_f1": train_metrics["f1"],
            "train_recall": train_metrics["recall"],
            "train_auc": train_metrics["auc"],
            "train_subtype_oracle_acc": train_metrics["subtype_oracle_acc"],
            "train_subtype_oracle_macro_f1": train_metrics["subtype_oracle_macro_f1"],
            "train_subtype_cascade_acc": train_metrics["subtype_cascade_acc"],
            "train_rec_auc": train_metrics["rec_auc"],
            "train_rec_f1": train_metrics["rec_f1"],
            
            "val_loss":val_metrics["loss"],
            "val_acc": val_metrics["acc"],
            "val_f1": val_metrics["f1"],
            "val_auc": val_metrics["auc"],
            "val_recall": val_metrics["recall"],
            "val_subtype_oracle_acc": val_metrics["subtype_oracle_acc"],
            "val_subtype_oracle_macro_f1": val_metrics["subtype_oracle_macro_f1"],
            "val_subtype_cascade_acc": val_metrics["subtype_cascade_acc"],
            "val_subtype_gate_recall": val_metrics["subtype_gate_recall"],
            "val_rec_auc": val_metrics["rec_auc"],
            "val_rec_f1": val_metrics["rec_f1"],
        }
        
        history.append(row)

        print(
            f"[{model_name}][Fold {fold_idx}][Epoch {epoch:02d}]"
            f"train loss = {row['train_loss']:.4f}, acc={row['train_acc']:.4f}, auc={row['train_auc']:.4f},"
            f"f1 = {row['train_f1']:.4f}, recall={row['train_recall']:.4f},"
            f"subtype_oracle_f1 = {row['train_subtype_oracle_macro_f1']:.4f}, subtype_oracle_acc = {row['train_subtype_oracle_acc']:.4f} | "
            f"val loss = {row['val_loss']:.4f}, acc = {row['val_acc']:.4f}, auc = {row['val_auc']:.4f}, "
            f"f1 = {row['val_f1']:.4f}, recall={row['val_recall']:.4f}, "
            f"subtype_oracle_f1 = {row['val_subtype_oracle_macro_f1']:.4f}",
            f"subtype_cascade_acc = {row['val_subtype_cascade_acc']:.4f}",
            f"rec_auc = {row['val_rec_auc']:.4f}, rec_f1 = {row['val_rec_f1']:.4f}"
        )

        if row["val_auc"] > best_auc:
            best_auc = row["val_auc"]

        if row["val_loss"] < best_val_loss - min_delta:
            best_val_loss = row["val_loss"]
            early_stop_counter = 0
            torch.save(model.state_dict(), best_path)
            print(f"  -> best saved by val_loss: {best_path}")
        else:
            early_stop_counter += 1
            print(f"  -> no improvement ({early_stop_counter}/{patience})")

        if early_stop_counter >= patience:
            print(f"  -> early stopping triggered at epoch {epoch}")
            break

    history_df = pd.DataFrame(history)
    return model, history_df, best_path

# %%
# model 로드 함수
def load_model(model_type, model_path, device):
    if model_type == "resnet":
        model = build_resnet50_patient_model()
    elif model_type == "vit":
        model = build_vit_patient_model()
    elif model_type == "hybrid":
        model = build_hybrid_patient_model()
    else:
        raise ValueError("Unknown model type")

    model.load_state_dict(torch.load(model_path, map_location=device))
    model.to(device)
    model.eval()
    return model

# %%
def run_cv_for_model(model_name, model_type, build_fn, text_dim):
    #text_dim: 임상 데이터 차원 수
    
    fold_results = []
    fold_histories = []

    for fold_idx in FOLDS:
        print("\n" + "=" * 80)
        print(f"Running {model_name} | Fold {fold_idx}")
        print("=" * 80)

        train_loader, val_loader, pos_weight, subtype_class_weights, rec_weight = make_fold_loaders(fold_idx)

        model = build_fn(text_dim=text_dim)
        model = model.to(device)

        criterion = CascadeCriterion(
            pos_weight = pos_weight,
            subtype_class_weights = subtype_class_weights,
            recurrence_pos_weight = rec_weight.item() if torch.is_tensor(rec_weight) else rec_weight,
            subtype_loss_weight = 0.5 #필요에 따라 조절
            recurrence_loss_weight = 0.5 #필요에 따라 조절
        )

        model, history_df, best_path = fit_model(
            model=model,
            model_name=model_name,
            fold_idx = fold_idx,
            train_loader=train_loader,
            val_loader=val_loader,
            device=device,
            num_epochs=NUM_EPOCHS,
            lr=LR,
            weight_decay=WEIGHT_DECAY,
            criterion = criterion,
            pos_weight=pos_weight,
            patience=PATIENCE,
            min_delta = MIN_DELTA
        )

        best_model = load_model(model_type, best_path, device)
        final_metrics = eval_confusion(best_model, val_loader, device, criterion, threshold=0.5)

        print(f"\n[{model_name}][Fold {fold_idx}] Final Metrics")
        print(f"malignancy auc: {final_metrics['auc']:.4f}, f1 = {final_metrics['f1']:.4f}, recall = {final_metrics['recall']:.4f}")
        print(f"subtype oracle acc: {final_metrics['subtype_oracle_acc']:.4f}, macro_f1 = {final_metrics['subtype_oracle_macro_f1']}")
        print(f"subtype cascade acc : {final_metrics['subtype_cascade_acc']:.4f}, gate_recall={final_metrics['subtype_gate_recall']:.4f}")
        print(f"Recurrence AUC: {final_metrics['rec_auc']:.4f}, Recurrence f1: {final_metrics['rec_f1']:.4f}")
        print(f"Binary cm: {final_metrics['cm']}")
        print(f"Subtype oracle cm: {final_metrics['subtype_oracle_cm']}")
        print(f"Recurrence cm: {final_metrics['rec_cm']}")

        fold_results.append({
            "model": model_name,
            "fold": fold_idx,
            "mal acc": final_metrics["acc"],
            "mal auc": final_metrics["auc"],
            "mal f1": final_metrics["f1"],
            "mal recall": final_metrics["recall"],
            "subtype_oracle_acc": final_metrics["subtype_oracle_acc"],
            "subtype_oracle_macro_f1": final_metrics["subtype_oracle_macro_f1"],
            "subtype_cascade_acc": final_metrics["subtype_cascade_acc"],
            "subtype_gate_recall": final_metrics["subtype_gate_recall"],
            "rec_auc":final_metrics["rec_auc"],
            "rec_f1": final_metrics["rec_f1"],
            "rec_acc":final_metrics["rec_acc"],
            
            "Binary cm": final_metrics["cm"],
            "subtype_oracle_cm": final_metrics["subtype_oracle_cm"],
            "rec_cm": final_metrics["rec_cm"],
        })

        history_df["model"] = model_name
        fold_histories.append(history_df)

        del model
        del best_model
        del train_loader
        del val_loader
        gc.collect()
        if torch.cuda.is_available():
            torch.cuda.empty_cache()
            
    result_df = pd.DataFrame(fold_results)
    history_df_all = pd.concat(fold_histories, ignore_index=True)
    return result_df, history_df_all

# %%
#9 ResNet50

print(">>> Training ResNet50...")
resnet_cv_df, resnet_history_df = run_cv_for_model(
    model_name="ResNet50",
    model_type="resnet",
    build_fn=lambda: build_resnet50_patient_model(load_pretrained=True)
)

display(resnet_cv_df)
# Out:
# >>> Training ResNet50...
#
# ================================================================================
# Running ResNet50 | Fold 1
# ================================================================================
# [FOLD 1] Train benign(0): 1605, malignant(1): 444, pos_weight=3.6149, subtype_class_weights = [1.6541999578475952, 0.8529000282287598, 1.1613999605178833, 1.1139999628067017, 0.2175000011920929]
# subtype_loss_weight = 0.5
# [ResNet50][Fold 1][Epoch 01]train loss = 1.3556, acc=0.7897, auc=0.8587,f1 = 0.6028, recall=0.7365,subtype_oracle_f1 = 0.1789, subtype_oracle_acc = 0.5360 | val loss = 0.7688, acc = 0.8285, auc = 0.9175, f1 = 0.6835, recall=0.8559, subtype_oracle_f1 = 0.1628 subtype_cascade_acc = 0.4505
#   -> best saved by val_loss: ct_cascade_models/ResNet50_fold1_best.pth
# [ResNet50][Fold 1][Epoch 02]train loss = 1.0623, acc=0.8633, auc=0.9433,f1 = 0.7398, recall=0.8964,subtype_oracle_f1 = 0.2817, subtype_oracle_acc = 0.5766 | val loss = 0.6430, acc = 0.8752, auc = 0.9523, f1 = 0.7576, recall=0.9009, subtype_oracle_f1 = 0.2326 subtype_cascade_acc = 0.5045
#   -> best saved by val_loss: ct_cascade_models/ResNet50_fold1_best.pth
# [ResNet50][Fold 1][Epoch 03]train loss = 0.8483, acc=0.9097, auc=0.9730,f1 = 0.8167, recall=0.9279,subtype_oracle_f1 = 0.3633, subtype_oracle_acc = 0.6149 | val loss = 0.6785, acc = 0.9103, auc = 0.9493, f1 = 0.7946, recall=0.8018, subtype_oracle_f1 = 0.2440 subtype_cascade_acc = 0.4054
#   -> no improvement (1/7)
# [ResNet50][Fold 1][Epoch 04]train loss = 0.6875, acc=0.9370, auc=0.9885,f1 = 0.8674, recall=0.9505,subtype_oracle_f1 = 0.4078, subtype_oracle_acc = 0.6351 | val loss = 0.5794, acc = 0.9181, auc = 0.9666, f1 = 0.8220, recall=0.8739, subtype_oracle_f1 = 0.3077 subtype_cascade_acc = 0.4595
#   -> best saved by val_loss: ct_cascade_models/ResNet50_fold1_best.pth
# [ResNet50][Fold 1][Epoch 05]train loss = 0.5694, acc=0.9502, auc=0.9917,f1 = 0.8940, recall=0.9685,subtype_oracle_f1 = 0.5575, subtype_oracle_acc = 0.7095 | val loss = 0.7350, acc = 0.9240, auc = 0.9547, f1 = 0.8186, recall=0.7928, subtype_oracle_f1 = 0.3037 subtype_cascade_acc = 0.4054
#   -> no improvement (1/7)
# [ResNet50][Fold 1][Epoch 06]train loss = 0.4518, acc=0.9688, auc=0.9968,f1 = 0.9310, recall=0.9730,subtype_oracle_f1 = 0.6634, subtype_oracle_acc = 0.7860 | val loss = 0.6969, acc = 0.9201, auc = 0.9668, f1 = 0.8145, recall=0.8108, subtype_oracle_f1 = 0.3522 subtype_cascade_acc = 0.4324
#   -> no improvement (2/7)
# [ResNet50][Fold 1][Epoch 07]train loss = 0.3598, acc=0.9722, auc=0.9958,f1 = 0.9386, recall=0.9820,subtype_oracle_f1 = 0.7756, subtype_oracle_acc = 0.8491 | val loss = 0.7391, acc = 0.9006, auc = 0.9605, f1 = 0.7733, recall=0.7838, subtype_oracle_f1 = 0.2537 subtype_cascade_acc = 0.3874
#   -> no improvement (3/7)
# [ResNet50][Fold 1][Epoch 08]train loss = 0.2291, acc=0.9878, auc=0.9989,f1 = 0.9723, recall=0.9887,subtype_oracle_f1 = 0.8415, subtype_oracle_acc = 0.8896 | val loss = 0.9348, acc = 0.9240, auc = 0.9500, f1 = 0.8203, recall=0.8018, subtype_oracle_f1 = 0.3129 subtype_cascade_acc = 0.4685
#   -> no improvement (4/7)
# [ResNet50][Fold 1][Epoch 09]train loss = 0.1664, acc=0.9883, auc=0.9992,f1 = 0.9733, recall=0.9865,subtype_oracle_f1 = 0.9010, subtype_oracle_acc = 0.9369 | val loss = 0.7710, acc = 0.9064, auc = 0.9545, f1 = 0.7913, recall=0.8198, subtype_oracle_f1 = 0.2533 subtype_cascade_acc = 0.2703
#   -> no improvement (5/7)
# [ResNet50][Fold 1][Epoch 10]train loss = 0.1268, acc=0.9868, auc=0.9989,f1 = 0.9702, recall=0.9887,subtype_oracle_f1 = 0.9371, subtype_oracle_acc = 0.9527 | val loss = 0.7545, acc = 0.9006, auc = 0.9624, f1 = 0.7918, recall=0.8739, subtype_oracle_f1 = 0.3628 subtype_cascade_acc = 0.4414
#   -> no improvement (6/7)
# [ResNet50][Fold 1][Epoch 11]train loss = 0.0762, acc=0.9863, auc=0.9993,f1 = 0.9692, recall=0.9910,subtype_oracle_f1 = 0.9814, subtype_oracle_acc = 0.9865 | val loss = 1.0472, acc = 0.9376, auc = 0.9612, f1 = 0.8462, recall=0.7928, subtype_oracle_f1 = 0.3474 subtype_cascade_acc = 0.3874
#   -> no improvement (7/7)
#   -> early stopping triggered at epoch 11
#
# [ResNet50][Fold 1] Final Metrics
# malignancy auc: 0.9666, f1 = 0.8220, recall = 0.8739
# subtype oracle acc: 0.4685, macro_f1 = 0.30771780970452695
# subtype cascade acc : 0.4595, gate_recall=0.8739
# Binary cm: [[374  28]
#  [ 14  97]]
# Subtype oracle cm: [[ 0  3  2  0  4]
#  [ 1  8  3  1  7]
#  [ 0  4  5  1  3]
#  [ 0  4  2  2  1]
#  [ 2 11  6  4 37]]
#
# ================================================================================
# Running ResNet50 | Fold 2
# ================================================================================
# [FOLD 2] Train benign(0): 1605, malignant(1): 444, pos_weight=3.6149, subtype_class_weights = [1.5044000148773193, 0.8331999778747559, 1.1282999515533447, 1.3208999633789062, 0.21320000290870667]
# subtype_loss_weight = 0.5
# [ResNet50][Fold 2][Epoch 01]train loss = 1.2880, acc=0.8131, auc=0.8851,f1 = 0.6637, recall=0.8514,subtype_oracle_f1 = 0.1861, subtype_oracle_acc = 0.5135 | val loss = 0.6627, acc = 0.8908, auc = 0.9490, f1 = 0.7742, recall=0.8649, subtype_oracle_f1 = 0.1341 subtype_cascade_acc = 0.4685
#   -> best saved by val_loss: ct_cascade_models/ResNet50_fold2_best.pth
# [ResNet50][Fold 2][Epoch 02]train loss = 0.9549, acc=0.9063, auc=0.9645,f1 = 0.8076, recall=0.9077,subtype_oracle_f1 = 0.2133, subtype_oracle_acc = 0.5766 | val loss = 0.6189, acc = 0.8986, auc = 0.9492, f1 = 0.7903, recall=0.8829, subtype_oracle_f1 = 0.3859 subtype_cascade_acc = 0.5225
#   -> best saved by val_loss: ct_cascade_models/ResNet50_fold2_best.pth
# [ResNet50][Fold 2][Epoch 03]train loss = 0.7759, acc=0.9302, auc=0.9841,f1 = 0.8548, recall=0.9482,subtype_oracle_f1 = 0.3558, subtype_oracle_acc = 0.6149 | val loss = 0.7010, acc = 0.8986, auc = 0.9523, f1 = 0.7815, recall=0.8378, subtype_oracle_f1 = 0.3564 subtype_cascade_acc = 0.4685
#   -> no improvement (1/7)
# [ResNet50][Fold 2][Epoch 04]train loss = 0.6566, acc=0.9492, auc=0.9907,f1 = 0.8910, recall=0.9572,subtype_oracle_f1 = 0.4109, subtype_oracle_acc = 0.6532 | val loss = 0.9956, acc = 0.8986, auc = 0.9440, f1 = 0.7570, recall=0.7297, subtype_oracle_f1 = 0.2465 subtype_cascade_acc = 0.3514
#   -> no improvement (2/7)
# [ResNet50][Fold 2][Epoch 05]train loss = 0.5844, acc=0.9717, auc=0.9961,f1 = 0.9374, recall=0.9775,subtype_oracle_f1 = 0.5091, subtype_oracle_acc = 0.6892 | val loss = 0.6240, acc = 0.9220, auc = 0.9633, f1 = 0.8276, recall=0.8649, subtype_oracle_f1 = 0.4102 subtype_cascade_acc = 0.5045
#   -> no improvement (3/7)
# [ResNet50][Fold 2][Epoch 06]train loss = 0.4756, acc=0.9639, auc=0.9960,f1 = 0.9209, recall=0.9707,subtype_oracle_f1 = 0.5367, subtype_oracle_acc = 0.7410 | val loss = 0.8500, acc = 0.9181, auc = 0.9610, f1 = 0.8056, recall=0.7838, subtype_oracle_f1 = 0.4205 subtype_cascade_acc = 0.4414
#   -> no improvement (4/7)
# [ResNet50][Fold 2][Epoch 07]train loss = 0.3926, acc=0.9766, auc=0.9966,f1 = 0.9478, recall=0.9820,subtype_oracle_f1 = 0.7267, subtype_oracle_acc = 0.8266 | val loss = 0.7199, acc = 0.9084, auc = 0.9573, f1 = 0.7911, recall=0.8018, subtype_oracle_f1 = 0.4526 subtype_cascade_acc = 0.4865
#   -> no improvement (5/7)
# [ResNet50][Fold 2][Epoch 08]train loss = 0.1924, acc=0.9922, auc=0.9998,f1 = 0.9821, recall=0.9910,subtype_oracle_f1 = 0.8322, subtype_oracle_acc = 0.8896 | val loss = 0.9511, acc = 0.9025, auc = 0.9541, f1 = 0.7934, recall=0.8649, subtype_oracle_f1 = 0.4079 subtype_cascade_acc = 0.4955
#   -> no improvement (6/7)
# [ResNet50][Fold 2][Epoch 09]train loss = 0.1391, acc=0.9849, auc=0.9988,f1 = 0.9660, recall=0.9910,subtype_oracle_f1 = 0.9287, subtype_oracle_acc = 0.9527 | val loss = 1.0377, acc = 0.8850, auc = 0.9442, f1 = 0.7401, recall=0.7568, subtype_oracle_f1 = 0.4185 subtype_cascade_acc = 0.4775
#   -> no improvement (7/7)
#   -> early stopping triggered at epoch 9
#
# [ResNet50][Fold 2] Final Metrics
# malignancy auc: 0.9492, f1 = 0.7903, recall = 0.8829
# subtype oracle acc: 0.5586, macro_f1 = 0.38585161964472314
# subtype cascade acc : 0.5225, gate_recall=0.8829
# Binary cm: [[363  39]
#  [ 13  98]]
# Subtype oracle cm: [[ 0  0  3  0  3]
#  [ 0  6  5  0  8]
#  [ 0  0  8  0  4]
#  [ 0  3  8  5  1]
#  [ 0  2 12  0 43]]
#
# ================================================================================
# Running ResNet50 | Fold 3
# ================================================================================
# [FOLD 3] Train benign(0): 1606, malignant(1): 444, pos_weight=3.6171, subtype_class_weights = [1.6117000579833984, 0.8547000288963318, 1.1282000541687012, 1.1751999855041504, 0.23019999265670776]
# subtype_loss_weight = 0.5
# [ResNet50][Fold 3][Epoch 01]train loss = 1.3097, acc=0.7810, auc=0.8887,f1 = 0.6268, recall=0.8491,subtype_oracle_f1 = 0.1792, subtype_oracle_acc = 0.5225 | val loss = 0.5506, acc = 0.9141, auc = 0.9645, f1 = 0.8211, recall=0.9099, subtype_oracle_f1 = 0.2418 subtype_cascade_acc = 0.5676
#   -> best saved by val_loss: ct_cascade_models/ResNet50_fold3_best.pth
# [ResNet50][Fold 3][Epoch 02]train loss = 0.9710, acc=0.9054, auc=0.9632,f1 = 0.8068, recall=0.9122,subtype_oracle_f1 = 0.2220, subtype_oracle_acc = 0.5428 | val loss = 0.5690, acc = 0.8789, auc = 0.9649, f1 = 0.7737, recall=0.9550, subtype_oracle_f1 = 0.3812 subtype_cascade_acc = 0.6126
#   -> no improvement (1/7)
# [ResNet50][Fold 3][Epoch 03]train loss = 0.7749, acc=0.9346, auc=0.9850,f1 = 0.8633, recall=0.9527,subtype_oracle_f1 = 0.3585, subtype_oracle_acc = 0.5923 | val loss = 0.6479, acc = 0.9004, auc = 0.9509, f1 = 0.7901, recall=0.8649, subtype_oracle_f1 = 0.2841 subtype_cascade_acc = 0.5225
#   -> no improvement (2/7)
# [ResNet50][Fold 3][Epoch 04]train loss = 0.6480, acc=0.9624, auc=0.9921,f1 = 0.9178, recall=0.9685,subtype_oracle_f1 = 0.3973, subtype_oracle_acc = 0.6239 | val loss = 0.8376, acc = 0.9180, auc = 0.9659, f1 = 0.7961, recall=0.7387, subtype_oracle_f1 = 0.2488 subtype_cascade_acc = 0.2883
#   -> no improvement (3/7)
# [ResNet50][Fold 3][Epoch 05]train loss = 0.5606, acc=0.9659, auc=0.9938,f1 = 0.9242, recall=0.9617,subtype_oracle_f1 = 0.4997, subtype_oracle_acc = 0.6869 | val loss = 0.5542, acc = 0.9219, auc = 0.9690, f1 = 0.8305, recall=0.8829, subtype_oracle_f1 = 0.3918 subtype_cascade_acc = 0.4685
#   -> no improvement (4/7)
# [ResNet50][Fold 3][Epoch 06]train loss = 0.4070, acc=0.9771, auc=0.9967,f1 = 0.9489, recall=0.9820,subtype_oracle_f1 = 0.7003, subtype_oracle_acc = 0.7995 | val loss = 0.6118, acc = 0.9277, auc = 0.9695, f1 = 0.8412, recall=0.8829, subtype_oracle_f1 = 0.3677 subtype_cascade_acc = 0.5135
#   -> no improvement (5/7)
# [ResNet50][Fold 3][Epoch 07]train loss = 0.2512, acc=0.9839, auc=0.9990,f1 = 0.9638, recall=0.9887,subtype_oracle_f1 = 0.8269, subtype_oracle_acc = 0.8941 | val loss = 0.7311, acc = 0.9219, auc = 0.9658, f1 = 0.8276, recall=0.8649, subtype_oracle_f1 = 0.2634 subtype_cascade_acc = 0.4685
#   -> no improvement (6/7)
# [ResNet50][Fold 3][Epoch 08]train loss = 0.1721, acc=0.9873, auc=0.9987,f1 = 0.9712, recall=0.9887,subtype_oracle_f1 = 0.8866, subtype_oracle_acc = 0.9234 | val loss = 0.7120, acc = 0.9121, auc = 0.9681, f1 = 0.7945, recall=0.7838, subtype_oracle_f1 = 0.2917 subtype_cascade_acc = 0.4414
#   -> no improvement (7/7)
#   -> early stopping triggered at epoch 8
#
# [ResNet50][Fold 3] Final Metrics
# malignancy auc: 0.9645, f1 = 0.8211, recall = 0.9099
# subtype oracle acc: 0.5946, macro_f1 = 0.24182806324110667
# subtype cascade acc : 0.5676, gate_recall=0.9099
# Binary cm: [[367  34]
#  [ 10 101]]
# Subtype oracle cm: [[ 0  0  1  0  6]
#  [ 0  2  3  0 13]
#  [ 0  0  3  0  7]
#  [ 0  1  2  0  7]
#  [ 0  2  3  0 61]]
#
# ================================================================================
# Running ResNet50 | Fold 4
# ================================================================================
# [FOLD 4] Train benign(0): 1606, malignant(1): 444, pos_weight=3.6171, subtype_class_weights = [1.7798999547958374, 0.7215999960899353, 1.2136000394821167, 1.0678999423980713, 0.21709999442100525]
# subtype_loss_weight = 0.5
# [ResNet50][Fold 4][Epoch 01]train loss = 1.2723, acc=0.7893, auc=0.8901,f1 = 0.6333, recall=0.8401,subtype_oracle_f1 = 0.2075, subtype_oracle_acc = 0.5315 | val loss = 0.6917, acc = 0.8984, auc = 0.9506, f1 = 0.7851, recall=0.8559, subtype_oracle_f1 = 0.2204 subtype_cascade_acc = 0.5045
#   -> best saved by val_loss: ct_cascade_models/ResNet50_fold4_best.pth
# [ResNet50][Fold 4][Epoch 02]train loss = 0.9654, acc=0.8854, auc=0.9601,f1 = 0.7760, recall=0.9167,subtype_oracle_f1 = 0.2825, subtype_oracle_acc = 0.5563 | val loss = 0.6072, acc = 0.8516, auc = 0.9635, f1 = 0.7361, recall=0.9550, subtype_oracle_f1 = 0.1860 subtype_cascade_acc = 0.5135
#   -> best saved by val_loss: ct_cascade_models/ResNet50_fold4_best.pth
# [ResNet50][Fold 4][Epoch 03]train loss = 0.7894, acc=0.9312, auc=0.9827,f1 = 0.8583, recall=0.9617,subtype_oracle_f1 = 0.3889, subtype_oracle_acc = 0.6194 | val loss = 0.5709, acc = 0.9023, auc = 0.9671, f1 = 0.8031, recall=0.9189, subtype_oracle_f1 = 0.2538 subtype_cascade_acc = 0.5135
#   -> best saved by val_loss: ct_cascade_models/ResNet50_fold4_best.pth
# [ResNet50][Fold 4][Epoch 04]train loss = 0.6390, acc=0.9454, auc=0.9890,f1 = 0.8845, recall=0.9662,subtype_oracle_f1 = 0.5129, subtype_oracle_acc = 0.7050 | val loss = 0.5207, acc = 0.9297, auc = 0.9782, f1 = 0.8500, recall=0.9189, subtype_oracle_f1 = 0.2801 subtype_cascade_acc = 0.5045
#   -> best saved by val_loss: ct_cascade_models/ResNet50_fold4_best.pth
# [ResNet50][Fold 4][Epoch 05]train loss = 0.5415, acc=0.9571, auc=0.9933,f1 = 0.9068, recall=0.9640,subtype_oracle_f1 = 0.5750, subtype_oracle_acc = 0.7275 | val loss = 0.6057, acc = 0.9199, auc = 0.9770, f1 = 0.8111, recall=0.7928, subtype_oracle_f1 = 0.2625 subtype_cascade_acc = 0.4324
#   -> no improvement (1/7)
# [ResNet50][Fold 4][Epoch 06]train loss = 0.3903, acc=0.9766, auc=0.9972,f1 = 0.9478, recall=0.9820,subtype_oracle_f1 = 0.6552, subtype_oracle_acc = 0.7883 | val loss = 0.5943, acc = 0.9121, auc = 0.9753, f1 = 0.8207, recall=0.9279, subtype_oracle_f1 = 0.2720 subtype_cascade_acc = 0.5315
#   -> no improvement (2/7)
# [ResNet50][Fold 4][Epoch 07]train loss = 0.2310, acc=0.9834, auc=0.9983,f1 = 0.9626, recall=0.9865,subtype_oracle_f1 = 0.8169, subtype_oracle_acc = 0.8874 | val loss = 0.8269, acc = 0.9316, auc = 0.9739, f1 = 0.8444, recall=0.8559, subtype_oracle_f1 = 0.2776 subtype_cascade_acc = 0.4595
#   -> no improvement (3/7)
# [ResNet50][Fold 4][Epoch 08]train loss = 0.1901, acc=0.9854, auc=0.9991,f1 = 0.9670, recall=0.9887,subtype_oracle_f1 = 0.8639, subtype_oracle_acc = 0.9167 | val loss = 0.8488, acc = 0.9199, auc = 0.9673, f1 = 0.8270, recall=0.8829, subtype_oracle_f1 = 0.3091 subtype_cascade_acc = 0.5135
#   -> no improvement (4/7)
# [ResNet50][Fold 4][Epoch 09]train loss = 0.1455, acc=0.9780, auc=0.9976,f1 = 0.9508, recall=0.9797,subtype_oracle_f1 = 0.9379, subtype_oracle_acc = 0.9617 | val loss = 0.8077, acc = 0.9199, auc = 0.9671, f1 = 0.8299, recall=0.9009, subtype_oracle_f1 = 0.2927 subtype_cascade_acc = 0.4865
#   -> no improvement (5/7)
# [ResNet50][Fold 4][Epoch 10]train loss = 0.0965, acc=0.9902, auc=0.9985,f1 = 0.9778, recall=0.9910,subtype_oracle_f1 = 0.9782, subtype_oracle_acc = 0.9797 | val loss = 0.6671, acc = 0.9121, auc = 0.9670, f1 = 0.8207, recall=0.9279, subtype_oracle_f1 = 0.3565 subtype_cascade_acc = 0.4865
#   -> no improvement (6/7)
# [ResNet50][Fold 4][Epoch 11]train loss = 0.0456, acc=0.9951, auc=0.9998,f1 = 0.9888, recall=0.9977,subtype_oracle_f1 = 0.9741, subtype_oracle_acc = 0.9752 | val loss = 0.7969, acc = 0.9238, auc = 0.9721, f1 = 0.8326, recall=0.8739, subtype_oracle_f1 = 0.3464 subtype_cascade_acc = 0.5135
#   -> no improvement (7/7)
#   -> early stopping triggered at epoch 11
#
# [ResNet50][Fold 4] Final Metrics
# malignancy auc: 0.9782, f1 = 0.8500, recall = 0.9189
# subtype oracle acc: 0.5315, macro_f1 = 0.2800503018108652
# subtype cascade acc : 0.5045, gate_recall=0.9189
# Binary cm: [[374  27]
#  [  9 102]]
# Subtype oracle cm: [[ 1  0  1  2  8]
#  [ 0  1  0  3  6]
#  [ 1  1  3  3  8]
#  [ 0  1  2  2  3]
#  [ 0  3  8  2 52]]
#
# ================================================================================
# Running ResNet50 | Fold 5
# ================================================================================
# [FOLD 5] Train benign(0): 1606, malignant(1): 444, pos_weight=3.6171, subtype_class_weights = [1.6212999820709229, 0.822700023651123, 1.080899953842163, 1.2527999877929688, 0.2222999930381775]
# subtype_loss_weight = 0.5
# [ResNet50][Fold 5][Epoch 01]train loss = 1.3363, acc=0.8054, auc=0.8872,f1 = 0.6336, recall=0.7770,subtype_oracle_f1 = 0.1634, subtype_oracle_acc = 0.5563 | val loss = 0.9369, acc = 0.8770, auc = 0.9132, f1 = 0.6736, recall=0.5856, subtype_oracle_f1 = 0.1732 subtype_cascade_acc = 0.3874
#   -> best saved by val_loss: ct_cascade_models/ResNet50_fold5_best.pth
# [ResNet50][Fold 5][Epoch 02]train loss = 1.0108, acc=0.9054, auc=0.9566,f1 = 0.8056, recall=0.9054,subtype_oracle_f1 = 0.2429, subtype_oracle_acc = 0.5405 | val loss = 0.6695, acc = 0.8652, auc = 0.9380, f1 = 0.7376, recall=0.8739, subtype_oracle_f1 = 0.3090 subtype_cascade_acc = 0.5676
#   -> best saved by val_loss: ct_cascade_models/ResNet50_fold5_best.pth
# [ResNet50][Fold 5][Epoch 03]train loss = 0.8136, acc=0.9263, auc=0.9808,f1 = 0.8473, recall=0.9437,subtype_oracle_f1 = 0.3303, subtype_oracle_acc = 0.5901 | val loss = 0.7011, acc = 0.8770, auc = 0.9417, f1 = 0.7470, recall=0.8378, subtype_oracle_f1 = 0.3237 subtype_cascade_acc = 0.5405
#   -> no improvement (1/7)
# [ResNet50][Fold 5][Epoch 04]train loss = 0.6412, acc=0.9473, auc=0.9927,f1 = 0.8875, recall=0.9595,subtype_oracle_f1 = 0.4295, subtype_oracle_acc = 0.6419 | val loss = 0.8722, acc = 0.8848, auc = 0.9305, f1 = 0.7378, recall=0.7477, subtype_oracle_f1 = 0.2267 subtype_cascade_acc = 0.2252
#   -> no improvement (2/7)
# [ResNet50][Fold 5][Epoch 05]train loss = 0.6107, acc=0.9576, auc=0.9918,f1 = 0.9085, recall=0.9730,subtype_oracle_f1 = 0.5031, subtype_oracle_acc = 0.6712 | val loss = 0.7961, acc = 0.8887, auc = 0.9385, f1 = 0.7635, recall=0.8288, subtype_oracle_f1 = 0.3794 subtype_cascade_acc = 0.5315
#   -> no improvement (3/7)
# [ResNet50][Fold 5][Epoch 06]train loss = 0.4314, acc=0.9722, auc=0.9966,f1 = 0.9382, recall=0.9752,subtype_oracle_f1 = 0.6705, subtype_oracle_acc = 0.7883 | val loss = 0.9288, acc = 0.8945, auc = 0.9458, f1 = 0.7750, recall=0.8378, subtype_oracle_f1 = 0.2923 subtype_cascade_acc = 0.5225
#   -> no improvement (4/7)
# [ResNet50][Fold 5][Epoch 07]train loss = 0.3430, acc=0.9785, auc=0.9955,f1 = 0.9521, recall=0.9842,subtype_oracle_f1 = 0.7615, subtype_oracle_acc = 0.8423 | val loss = 0.8373, acc = 0.8906, auc = 0.9426, f1 = 0.7742, recall=0.8649, subtype_oracle_f1 = 0.3491 subtype_cascade_acc = 0.4955
#   -> no improvement (5/7)
# [ResNet50][Fold 5][Epoch 08]train loss = 0.2449, acc=0.9776, auc=0.9969,f1 = 0.9500, recall=0.9842,subtype_oracle_f1 = 0.8674, subtype_oracle_acc = 0.9054 | val loss = 1.0524, acc = 0.9121, auc = 0.9502, f1 = 0.8000, recall=0.8108, subtype_oracle_f1 = 0.3043 subtype_cascade_acc = 0.4144
#   -> no improvement (6/7)
# [ResNet50][Fold 5][Epoch 09]train loss = 0.1643, acc=0.9927, auc=0.9988,f1 = 0.9832, recall=0.9887,subtype_oracle_f1 = 0.8887, subtype_oracle_acc = 0.9212 | val loss = 1.4636, acc = 0.8965, auc = 0.9257, f1 = 0.7512, recall=0.7207, subtype_oracle_f1 = 0.2895 subtype_cascade_acc = 0.4054
#   -> no improvement (7/7)
#   -> early stopping triggered at epoch 9
#
# [ResNet50][Fold 5] Final Metrics
# malignancy auc: 0.9380, f1 = 0.7376, recall = 0.8739
# subtype oracle acc: 0.6216, macro_f1 = 0.30903726708074536
# subtype cascade acc : 0.5676, gate_recall=0.8739
# Binary cm: [[346  55]
#  [ 14  97]]
# Subtype oracle cm: [[ 0  0  1  1  6]
#  [ 0  0  2  0 15]
#  [ 0  0  3  1  5]
#  [ 0  0  0  4 10]
#  [ 0  0  1  0 62]]
#       model  fold   mal acc   mal auc    mal f1  mal recall  \
# 0  ResNet50     1  0.918129  0.966631  0.822034    0.873874
# 1  ResNet50     2  0.898635  0.949229  0.790323    0.882883
# 2  ResNet50     3  0.914062  0.964481  0.821138    0.909910
# 3  ResNet50     4  0.929688  0.978174  0.850000    0.918919
# 4  ResNet50     5  0.865234  0.938049  0.737643    0.873874
#
#    subtype_oracle_acc  subtype_oracle_macro_f1  subtype_cascade_acc  \
# 0            0.468468                 0.307718             0.459459
# 1            0.558559                 0.385852             0.522523
# 2            0.594595                 0.241828             0.567568
# 3            0.531532                 0.280050             0.504505
# 4            0.621622                 0.309037             0.567568
#
#    subtype_gate_recall               Binary cm  \
# 0             0.873874   [[374, 28], [14, 97]]
# 1             0.882883   [[363, 39], [13, 98]]
# 2             0.909910  [[367, 34], [10, 101]]
# 3             0.918919   [[374, 27], [9, 102]]
# 4             0.873874   [[346, 55], [14, 97]]
#
#                                    subtype_oracle_cm
# 0  [[0, 3, 2, 0, 4], [1, 8, 3, 1, 7], [0, 4, 5, 1...
# 1  [[0, 0, 3, 0, 3], [0, 6, 5, 0, 8], [0, 0, 8, 0...
# 2  [[0, 0, 1, 0, 6], [0, 2, 3, 0, 13], [0, 0, 3, ...
# 3  [[1, 0, 1, 2, 8], [0, 1, 0, 3, 6], [1, 1, 3, 3...
# 4  [[0, 0, 1, 1, 6], [0, 0, 2, 0, 15], [0, 0, 3, ...

# %%
#10 vit
print(">>> Training VIT...")
vit_cv_df, vit_history_df = run_cv_for_model(
    model_name="ViT-B16",
    model_type="vit",
    build_fn=lambda: build_vit_patient_model(load_pretrained=True)
)

display(vit_cv_df)
# Out:
# >>> Training VIT...
#
# ================================================================================
# Running ViT-B16 | Fold 1
# ================================================================================
# [FOLD 1] Train benign(0): 1605, malignant(1): 444, pos_weight=3.6149, subtype_class_weights = [1.6541999578475952, 0.8529000282287598, 1.1613999605178833, 1.1139999628067017, 0.2175000011920929]
# subtype_loss_weight = 0.5
# [ViT-B16][Fold 1][Epoch 01]train loss = 1.7671, acc=0.5105, auc=0.5248,f1 = 0.3218, recall=0.5360,subtype_oracle_f1 = 0.1721, subtype_oracle_acc = 0.5293 | val loss = 1.3296, acc = 0.2164, auc = 0.7468, f1 = 0.3558, recall=1.0000, subtype_oracle_f1 = 0.1404 subtype_cascade_acc = 0.5405
#   -> best saved by val_loss: ct_cascade_models/ViT-B16_fold1_best.pth
# [ViT-B16][Fold 1][Epoch 02]train loss = 1.6882, acc=0.5456, auc=0.5990,f1 = 0.3688, recall=0.6126,subtype_oracle_f1 = 0.1445, subtype_oracle_acc = 0.5653 | val loss = 1.2817, acc = 0.7836, auc = 0.7589, f1 = 0.2930, recall=0.2072, subtype_oracle_f1 = 0.1404 subtype_cascade_acc = 0.0901
#   -> best saved by val_loss: ct_cascade_models/ViT-B16_fold1_best.pth
# [ViT-B16][Fold 1][Epoch 03]train loss = 1.6568, acc=0.5964, auc=0.6419,f1 = 0.4020, recall=0.6261,subtype_oracle_f1 = 0.1445, subtype_oracle_acc = 0.5653 | val loss = 1.0756, acc = 0.7037, auc = 0.7989, f1 = 0.5280, recall=0.7658, subtype_oracle_f1 = 0.1404 subtype_cascade_acc = 0.4054
#   -> best saved by val_loss: ct_cascade_models/ViT-B16_fold1_best.pth
# [ViT-B16][Fold 1][Epoch 04]train loss = 1.6531, acc=0.5198, auc=0.6417,f1 = 0.3911, recall=0.7117,subtype_oracle_f1 = 0.1443, subtype_oracle_acc = 0.5631 | val loss = 1.2572, acc = 0.7641, auc = 0.7029, f1 = 0.0620, recall=0.0360, subtype_oracle_f1 = 0.1404 subtype_cascade_acc = 0.0180
#   -> no improvement (1/7)
# [ViT-B16][Fold 1][Epoch 05]train loss = 1.6248, acc=0.6696, auc=0.7100,f1 = 0.4344, recall=0.5856,subtype_oracle_f1 = 0.1445, subtype_oracle_acc = 0.5653 | val loss = 1.0761, acc = 0.6140, auc = 0.7956, f1 = 0.4975, recall=0.8829, subtype_oracle_f1 = 0.1404 subtype_cascade_acc = 0.4685
#   -> no improvement (2/7)
# [ViT-B16][Fold 1][Epoch 06]train loss = 1.5290, acc=0.6589, auc=0.7693,f1 = 0.5004, recall=0.7883,subtype_oracle_f1 = 0.1445, subtype_oracle_acc = 0.5653 | val loss = 1.1943, acc = 0.7057, auc = 0.7715, f1 = 0.4702, recall=0.6036, subtype_oracle_f1 = 0.1404 subtype_cascade_acc = 0.3153
#   -> no improvement (3/7)
# [ViT-B16][Fold 1][Epoch 07]train loss = 1.4944, acc=0.7199, auc=0.8012,f1 = 0.5378, recall=0.7523,subtype_oracle_f1 = 0.1445, subtype_oracle_acc = 0.5653 | val loss = 1.0136, acc = 0.7076, auc = 0.8058, f1 = 0.5130, recall=0.7117, subtype_oracle_f1 = 0.1404 subtype_cascade_acc = 0.3964
#   -> best saved by val_loss: ct_cascade_models/ViT-B16_fold1_best.pth
# [ViT-B16][Fold 1][Epoch 08]train loss = 1.4140, acc=0.7326, auc=0.8320,f1 = 0.5644, recall=0.7995,subtype_oracle_f1 = 0.1445, subtype_oracle_acc = 0.5653 | val loss = 1.0290, acc = 0.7135, auc = 0.8085, f1 = 0.5212, recall=0.7207, subtype_oracle_f1 = 0.1404 subtype_cascade_acc = 0.3964
#   -> no improvement (1/7)
# [ViT-B16][Fold 1][Epoch 09]train loss = 1.3673, acc=0.7750, auc=0.8579,f1 = 0.6050, recall=0.7950,subtype_oracle_f1 = 0.1445, subtype_oracle_acc = 0.5653 | val loss = 1.0180, acc = 0.7758, auc = 0.8265, f1 = 0.5418, recall=0.6126, subtype_oracle_f1 = 0.1404 subtype_cascade_acc = 0.3694
#   -> no improvement (2/7)
# [ViT-B16][Fold 1][Epoch 10]train loss = 1.3059, acc=0.7984, auc=0.8786,f1 = 0.6348, recall=0.8086,subtype_oracle_f1 = 0.1529, subtype_oracle_acc = 0.5676 | val loss = 0.9361, acc = 0.7758, auc = 0.8575, f1 = 0.5993, recall=0.7748, subtype_oracle_f1 = 0.1820 subtype_cascade_acc = 0.4505
#   -> best saved by val_loss: ct_cascade_models/ViT-B16_fold1_best.pth
# [ViT-B16][Fold 1][Epoch 11]train loss = 1.2749, acc=0.8092, auc=0.8849,f1 = 0.6597, recall=0.8536,subtype_oracle_f1 = 0.1837, subtype_oracle_acc = 0.5450 | val loss = 1.0754, acc = 0.7797, auc = 0.8439, f1 = 0.5703, recall=0.6757, subtype_oracle_f1 = 0.1788 subtype_cascade_acc = 0.3514
#   -> no improvement (1/7)
# [ViT-B16][Fold 1][Epoch 12]train loss = 1.2483, acc=0.8184, auc=0.8995,f1 = 0.6679, recall=0.8423,subtype_oracle_f1 = 0.1985, subtype_oracle_acc = 0.5743 | val loss = 1.2535, acc = 0.7992, auc = 0.8281, f1 = 0.5024, recall=0.4685, subtype_oracle_f1 = 0.1404 subtype_cascade_acc = 0.2523
#   -> no improvement (2/7)
# [ViT-B16][Fold 1][Epoch 13]train loss = 1.1813, acc=0.8429, auc=0.9212,f1 = 0.7067, recall=0.8739,subtype_oracle_f1 = 0.2103, subtype_oracle_acc = 0.5563 | val loss = 1.1711, acc = 0.7875, auc = 0.8370, f1 = 0.5551, recall=0.6126, subtype_oracle_f1 = 0.1404 subtype_cascade_acc = 0.3604
#   -> no improvement (3/7)
# [ViT-B16][Fold 1][Epoch 14]train loss = 1.1074, acc=0.8712, auc=0.9426,f1 = 0.7466, recall=0.8761,subtype_oracle_f1 = 0.2093, subtype_oracle_acc = 0.5721 | val loss = 1.0977, acc = 0.7524, auc = 0.8399, f1 = 0.5836, recall=0.8018, subtype_oracle_f1 = 0.1633 subtype_cascade_acc = 0.4144
#   -> no improvement (4/7)
# [ViT-B16][Fold 1][Epoch 15]train loss = 1.0539, acc=0.8804, auc=0.9501,f1 = 0.7664, recall=0.9054,subtype_oracle_f1 = 0.2202, subtype_oracle_acc = 0.5766 | val loss = 1.1781, acc = 0.7836, auc = 0.8500, f1 = 0.5934, recall=0.7297, subtype_oracle_f1 = 0.1388 subtype_cascade_acc = 0.3874
#   -> no improvement (5/7)
# [ViT-B16][Fold 1][Epoch 16]train loss = 0.9837, acc=0.9019, auc=0.9628,f1 = 0.8027, recall=0.9212,subtype_oracle_f1 = 0.1971, subtype_oracle_acc = 0.5563 | val loss = 1.3252, acc = 0.8441, auc = 0.8630, f1 = 0.6364, recall=0.6306, subtype_oracle_f1 = 0.1761 subtype_cascade_acc = 0.3604
#   -> no improvement (6/7)
# [ViT-B16][Fold 1][Epoch 17]train loss = 1.0107, acc=0.8878, auc=0.9603,f1 = 0.7776, recall=0.9054,subtype_oracle_f1 = 0.2105, subtype_oracle_acc = 0.5676 | val loss = 1.2059, acc = 0.8382, auc = 0.8654, f1 = 0.6140, recall=0.5946, subtype_oracle_f1 = 0.1673 subtype_cascade_acc = 0.3153
#   -> no improvement (7/7)
#   -> early stopping triggered at epoch 17
#
# [ViT-B16][Fold 1] Final Metrics
# malignancy auc: 0.8575, f1 = 0.5993, recall = 0.7748
# subtype oracle acc: 0.5495, macro_f1 = 0.18201183431952664
# subtype cascade acc : 0.4505, gate_recall=0.7748
# Binary cm: [[312  90]
#  [ 25  86]]
# Subtype oracle cm: [[ 0  0  0  0  9]
#  [ 0  0  0  0 20]
#  [ 0  1  0  0 12]
#  [ 0  0  0  1  8]
#  [ 0  0  0  0 60]]
#
# ================================================================================
# Running ViT-B16 | Fold 2
# ================================================================================
# [FOLD 2] Train benign(0): 1605, malignant(1): 444, pos_weight=3.6149, subtype_class_weights = [1.5044000148773193, 0.8331999778747559, 1.1282999515533447, 1.3208999633789062, 0.21320000290870667]
# subtype_loss_weight = 0.5
# [ViT-B16][Fold 2][Epoch 01]train loss = 1.7530, acc=0.5046, auc=0.5053,f1 = 0.3081, recall=0.5090,subtype_oracle_f1 = 0.1622, subtype_oracle_acc = 0.5541 | val loss = 1.2808, acc = 0.2164, auc = 0.6585, f1 = 0.3558, recall=1.0000, subtype_oracle_f1 = 0.1357 subtype_cascade_acc = 0.5135
#   -> best saved by val_loss: ct_cascade_models/ViT-B16_fold2_best.pth
# [ViT-B16][Fold 2][Epoch 02]train loss = 1.7337, acc=0.4729, auc=0.5226,f1 = 0.3225, recall=0.5788,subtype_oracle_f1 = 0.1456, subtype_oracle_acc = 0.5721 | val loss = 1.2697, acc = 0.4425, auc = 0.6720, f1 = 0.4211, recall=0.9369, subtype_oracle_f1 = 0.1357 subtype_cascade_acc = 0.4865
#   -> best saved by val_loss: ct_cascade_models/ViT-B16_fold2_best.pth
# [ViT-B16][Fold 2][Epoch 03]train loss = 1.6796, acc=0.5642, auc=0.5738,f1 = 0.3515, recall=0.5450,subtype_oracle_f1 = 0.1456, subtype_oracle_acc = 0.5721 | val loss = 1.3157, acc = 0.2261, auc = 0.7208, f1 = 0.3586, recall=1.0000, subtype_oracle_f1 = 0.1357 subtype_cascade_acc = 0.5135
#   -> no improvement (1/7)
# [ViT-B16][Fold 2][Epoch 04]train loss = 1.6525, acc=0.5725, auc=0.6438,f1 = 0.4105, recall=0.6869,subtype_oracle_f1 = 0.1456, subtype_oracle_acc = 0.5721 | val loss = 1.1341, acc = 0.6959, auc = 0.7536, f1 = 0.4658, recall=0.6126, subtype_oracle_f1 = 0.1357 subtype_cascade_acc = 0.3423
#   -> best saved by val_loss: ct_cascade_models/ViT-B16_fold2_best.pth
# [ViT-B16][Fold 2][Epoch 05]train loss = 1.6346, acc=0.6105, auc=0.6862,f1 = 0.4332, recall=0.6869,subtype_oracle_f1 = 0.1456, subtype_oracle_acc = 0.5721 | val loss = 1.1954, acc = 0.5848, auc = 0.7293, f1 = 0.4320, recall=0.7297, subtype_oracle_f1 = 0.1357 subtype_cascade_acc = 0.3874
#   -> no improvement (1/7)
# [ViT-B16][Fold 2][Epoch 06]train loss = 1.6315, acc=0.6013, auc=0.6806,f1 = 0.4369, recall=0.7140,subtype_oracle_f1 = 0.1456, subtype_oracle_acc = 0.5721 | val loss = 1.1717, acc = 0.5926, auc = 0.7267, f1 = 0.4456, recall=0.7568, subtype_oracle_f1 = 0.1357 subtype_cascade_acc = 0.4054
#   -> no improvement (2/7)
# [ViT-B16][Fold 2][Epoch 07]train loss = 1.5444, acc=0.6076, auc=0.7354,f1 = 0.4704, recall=0.8041,subtype_oracle_f1 = 0.1456, subtype_oracle_acc = 0.5721 | val loss = 1.1396, acc = 0.6043, auc = 0.7524, f1 = 0.4808, recall=0.8468, subtype_oracle_f1 = 0.1357 subtype_cascade_acc = 0.4414
#   -> no improvement (3/7)
# [ViT-B16][Fold 2][Epoch 08]train loss = 1.5389, acc=0.6510, auc=0.7627,f1 = 0.4918, recall=0.7793,subtype_oracle_f1 = 0.1456, subtype_oracle_acc = 0.5721 | val loss = 1.2033, acc = 0.5068, auc = 0.7710, f1 = 0.4488, recall=0.9279, subtype_oracle_f1 = 0.1357 subtype_cascade_acc = 0.4775
#   -> no improvement (4/7)
# [ViT-B16][Fold 2][Epoch 09]train loss = 1.5273, acc=0.6501, auc=0.7716,f1 = 0.4911, recall=0.7793,subtype_oracle_f1 = 0.1452, subtype_oracle_acc = 0.5698 | val loss = 1.1326, acc = 0.5984, auc = 0.7679, f1 = 0.4663, recall=0.8108, subtype_oracle_f1 = 0.1357 subtype_cascade_acc = 0.4234
#   -> best saved by val_loss: ct_cascade_models/ViT-B16_fold2_best.pth
# [ViT-B16][Fold 2][Epoch 10]train loss = 1.4399, acc=0.6979, auc=0.8146,f1 = 0.5328, recall=0.7950,subtype_oracle_f1 = 0.1456, subtype_oracle_acc = 0.5721 | val loss = 1.1262, acc = 0.6862, auc = 0.7787, f1 = 0.4921, recall=0.7027, subtype_oracle_f1 = 0.1357 subtype_cascade_acc = 0.3514
#   -> best saved by val_loss: ct_cascade_models/ViT-B16_fold2_best.pth
# [ViT-B16][Fold 2][Epoch 11]train loss = 1.4260, acc=0.7199, auc=0.8288,f1 = 0.5537, recall=0.8018,subtype_oracle_f1 = 0.1456, subtype_oracle_acc = 0.5721 | val loss = 1.0951, acc = 0.7875, auc = 0.7966, f1 = 0.5514, recall=0.6036, subtype_oracle_f1 = 0.1357 subtype_cascade_acc = 0.2883
#   -> best saved by val_loss: ct_cascade_models/ViT-B16_fold2_best.pth
# [ViT-B16][Fold 2][Epoch 12]train loss = 1.4578, acc=0.7057, auc=0.8098,f1 = 0.5463, recall=0.8176,subtype_oracle_f1 = 0.1456, subtype_oracle_acc = 0.5721 | val loss = 1.2307, acc = 0.5068, auc = 0.7709, f1 = 0.4512, recall=0.9369, subtype_oracle_f1 = 0.1357 subtype_cascade_acc = 0.4685
#   -> no improvement (1/7)
# [ViT-B16][Fold 2][Epoch 13]train loss = 1.3973, acc=0.7204, auc=0.8318,f1 = 0.5534, recall=0.7995,subtype_oracle_f1 = 0.1456, subtype_oracle_acc = 0.5721 | val loss = 1.4294, acc = 0.7973, auc = 0.7824, f1 = 0.4951, recall=0.4595, subtype_oracle_f1 = 0.1357 subtype_cascade_acc = 0.2432
#   -> no improvement (2/7)
# [ViT-B16][Fold 2][Epoch 14]train loss = 1.3302, acc=0.7799, auc=0.8784,f1 = 0.6213, recall=0.8333,subtype_oracle_f1 = 0.1456, subtype_oracle_acc = 0.5721 | val loss = 1.1189, acc = 0.7212, auc = 0.7886, f1 = 0.5249, recall=0.7117, subtype_oracle_f1 = 0.1357 subtype_cascade_acc = 0.3784
#   -> no improvement (3/7)
# [ViT-B16][Fold 2][Epoch 15]train loss = 1.2655, acc=0.7872, auc=0.8922,f1 = 0.6391, recall=0.8694,subtype_oracle_f1 = 0.1456, subtype_oracle_acc = 0.5721 | val loss = 1.2103, acc = 0.7524, auc = 0.8038, f1 = 0.5448, recall=0.6847, subtype_oracle_f1 = 0.1357 subtype_cascade_acc = 0.3423
#   -> no improvement (4/7)
# [ViT-B16][Fold 2][Epoch 16]train loss = 1.1919, acc=0.8214, auc=0.9170,f1 = 0.6795, recall=0.8739,subtype_oracle_f1 = 0.1456, subtype_oracle_acc = 0.5721 | val loss = 1.2143, acc = 0.6784, auc = 0.7996, f1 = 0.5161, recall=0.7928, subtype_oracle_f1 = 0.1357 subtype_cascade_acc = 0.4054
#   -> no improvement (5/7)
# [ViT-B16][Fold 2][Epoch 17]train loss = 1.1861, acc=0.8194, auc=0.9172,f1 = 0.6805, recall=0.8874,subtype_oracle_f1 = 0.1456, subtype_oracle_acc = 0.5721 | val loss = 1.1049, acc = 0.7037, auc = 0.8166, f1 = 0.5309, recall=0.7748, subtype_oracle_f1 = 0.1357 subtype_cascade_acc = 0.3964
#   -> no improvement (6/7)
# [ViT-B16][Fold 2][Epoch 18]train loss = 1.1627, acc=0.8380, auc=0.9289,f1 = 0.7067, recall=0.9009,subtype_oracle_f1 = 0.1456, subtype_oracle_acc = 0.5721 | val loss = 1.2791, acc = 0.6784, auc = 0.7708, f1 = 0.4828, recall=0.6937, subtype_oracle_f1 = 0.1357 subtype_cascade_acc = 0.3333
#   -> no improvement (7/7)
#   -> early stopping triggered at epoch 18
#
# [ViT-B16][Fold 2] Final Metrics
# malignancy auc: 0.7966, f1 = 0.5514, recall = 0.6036
# subtype oracle acc: 0.5135, macro_f1 = 0.13571428571428573
# subtype cascade acc : 0.2883, gate_recall=0.6036
# Binary cm: [[337  65]
#  [ 44  67]]
# Subtype oracle cm: [[ 0  0  0  0  6]
#  [ 0  0  0  0 19]
#  [ 0  0  0  0 12]
#  [ 0  0  0  0 17]
#  [ 0  0  0  0 57]]
#
# ================================================================================
# Running ViT-B16 | Fold 3
# ================================================================================
# [FOLD 3] Train benign(0): 1606, malignant(1): 444, pos_weight=3.6171, subtype_class_weights = [1.6117000579833984, 0.8547000288963318, 1.1282000541687012, 1.1751999855041504, 0.23019999265670776]
# subtype_loss_weight = 0.5
# [ViT-B16][Fold 3][Epoch 01]train loss = 1.7682, acc=0.5210, auc=0.5306,f1 = 0.3246, recall=0.5315,subtype_oracle_f1 = 0.1397, subtype_oracle_acc = 0.5293 | val loss = 1.2597, acc = 0.7832, auc = 0.6899, f1 = 0.0000, recall=0.0000, subtype_oracle_f1 = 0.1492 subtype_cascade_acc = 0.0000
#   -> best saved by val_loss: ct_cascade_models/ViT-B16_fold3_best.pth
# [ViT-B16][Fold 3][Epoch 02]train loss = 1.7271, acc=0.4732, auc=0.4909,f1 = 0.2987, recall=0.5180,subtype_oracle_f1 = 0.1422, subtype_oracle_acc = 0.5518 | val loss = 1.2846, acc = 0.7832, auc = 0.6939, f1 = 0.0000, recall=0.0000, subtype_oracle_f1 = 0.1492 subtype_cascade_acc = 0.0000
#   -> no improvement (1/7)
# [ViT-B16][Fold 3][Epoch 03]train loss = 1.7416, acc=0.5839, auc=0.5210,f1 = 0.3048, recall=0.4212,subtype_oracle_f1 = 0.1666, subtype_oracle_acc = 0.5383 | val loss = 1.2574, acc = 0.7363, auc = 0.6910, f1 = 0.1615, recall=0.1171, subtype_oracle_f1 = 0.0558 subtype_cascade_acc = 0.0180
#   -> best saved by val_loss: ct_cascade_models/ViT-B16_fold3_best.pth
# [ViT-B16][Fold 3][Epoch 04]train loss = 1.7388, acc=0.4985, auc=0.5114,f1 = 0.3228, recall=0.5518,subtype_oracle_f1 = 0.1453, subtype_oracle_acc = 0.5360 | val loss = 1.2431, acc = 0.6270, auc = 0.6913, f1 = 0.4431, recall=0.6847, subtype_oracle_f1 = 0.1492 subtype_cascade_acc = 0.3874
#   -> best saved by val_loss: ct_cascade_models/ViT-B16_fold3_best.pth
# [ViT-B16][Fold 3][Epoch 05]train loss = 1.7501, acc=0.5629, auc=0.5437,f1 = 0.3139, recall=0.4617,subtype_oracle_f1 = 0.1715, subtype_oracle_acc = 0.4595 | val loss = 1.2603, acc = 0.7832, auc = 0.6615, f1 = 0.0000, recall=0.0000, subtype_oracle_f1 = 0.1492 subtype_cascade_acc = 0.0000
#   -> no improvement (1/7)
# [ViT-B16][Fold 3][Epoch 06]train loss = 1.7356, acc=0.4571, auc=0.4978,f1 = 0.3142, recall=0.5743,subtype_oracle_f1 = 0.1422, subtype_oracle_acc = 0.5518 | val loss = 1.2661, acc = 0.7832, auc = 0.6694, f1 = 0.0000, recall=0.0000, subtype_oracle_f1 = 0.1492 subtype_cascade_acc = 0.0000
#   -> no improvement (2/7)
# [ViT-B16][Fold 3][Epoch 07]train loss = 1.7268, acc=0.4902, auc=0.4797,f1 = 0.2867, recall=0.4730,subtype_oracle_f1 = 0.1422, subtype_oracle_acc = 0.5518 | val loss = 1.2542, acc = 0.4531, auc = 0.6782, f1 = 0.4355, recall=0.9730, subtype_oracle_f1 = 0.1492 subtype_cascade_acc = 0.5766
#   -> no improvement (3/7)
# [ViT-B16][Fold 3][Epoch 08]train loss = 1.7022, acc=0.4985, auc=0.4995,f1 = 0.2901, recall=0.4730,subtype_oracle_f1 = 0.1415, subtype_oracle_acc = 0.5473 | val loss = 1.2675, acc = 0.2168, auc = 0.6830, f1 = 0.3563, recall=1.0000, subtype_oracle_f1 = 0.1492 subtype_cascade_acc = 0.5946
#   -> no improvement (4/7)
# [ViT-B16][Fold 3][Epoch 09]train loss = 1.7270, acc=0.5093, auc=0.5102,f1 = 0.3091, recall=0.5068,subtype_oracle_f1 = 0.1422, subtype_oracle_acc = 0.5518 | val loss = 1.2557, acc = 0.2168, auc = 0.6826, f1 = 0.3563, recall=1.0000, subtype_oracle_f1 = 0.1492 subtype_cascade_acc = 0.5946
#   -> no improvement (5/7)
# [ViT-B16][Fold 3][Epoch 10]train loss = 1.7224, acc=0.4634, auc=0.5249,f1 = 0.3218, recall=0.5878,subtype_oracle_f1 = 0.1413, subtype_oracle_acc = 0.5450 | val loss = 1.2627, acc = 0.7832, auc = 0.6880, f1 = 0.0000, recall=0.0000, subtype_oracle_f1 = 0.1492 subtype_cascade_acc = 0.0000
#   -> no improvement (6/7)
# [ViT-B16][Fold 3][Epoch 11]train loss = 1.7502, acc=0.5010, auc=0.4971,f1 = 0.2901, recall=0.4707,subtype_oracle_f1 = 0.1412, subtype_oracle_acc = 0.5405 | val loss = 1.2640, acc = 0.7832, auc = 0.6615, f1 = 0.0000, recall=0.0000, subtype_oracle_f1 = 0.1492 subtype_cascade_acc = 0.0000
#   -> no improvement (7/7)
#   -> early stopping triggered at epoch 11
#
# [ViT-B16][Fold 3] Final Metrics
# malignancy auc: 0.6913, f1 = 0.4431, recall = 0.6847
# subtype oracle acc: 0.5946, macro_f1 = 0.14915254237288136
# subtype cascade acc : 0.3874, gate_recall=0.6847
# Binary cm: [[245 156]
#  [ 35  76]]
# Subtype oracle cm: [[ 0  0  0  0  7]
#  [ 0  0  0  0 18]
#  [ 0  0  0  0 10]
#  [ 0  0  0  0 10]
#  [ 0  0  0  0 66]]
#
# ================================================================================
# Running ViT-B16 | Fold 4
# ================================================================================
# [FOLD 4] Train benign(0): 1606, malignant(1): 444, pos_weight=3.6171, subtype_class_weights = [1.7798999547958374, 0.7215999960899353, 1.2136000394821167, 1.0678999423980713, 0.21709999442100525]
# subtype_loss_weight = 0.5
# [ViT-B16][Fold 4][Epoch 01]train loss = 1.7396, acc=0.4980, auc=0.4987,f1 = 0.2986, recall=0.4932,subtype_oracle_f1 = 0.1702, subtype_oracle_acc = 0.5045 | val loss = 1.2777, acc = 0.2168, auc = 0.7056, f1 = 0.3563, recall=1.0000, subtype_oracle_f1 = 0.1477 subtype_cascade_acc = 0.5856
#   -> best saved by val_loss: ct_cascade_models/ViT-B16_fold4_best.pth
# [ViT-B16][Fold 4][Epoch 02]train loss = 1.7414, acc=0.5263, auc=0.5191,f1 = 0.3196, recall=0.5135,subtype_oracle_f1 = 0.1481, subtype_oracle_acc = 0.5563 | val loss = 1.2598, acc = 0.6855, auc = 0.7158, f1 = 0.4505, recall=0.5946, subtype_oracle_f1 = 0.1477 subtype_cascade_acc = 0.3514
#   -> best saved by val_loss: ct_cascade_models/ViT-B16_fold4_best.pth
# [ViT-B16][Fold 4][Epoch 03]train loss = 1.7321, acc=0.4902, auc=0.5167,f1 = 0.3236, recall=0.5631,subtype_oracle_f1 = 0.1555, subtype_oracle_acc = 0.5473 | val loss = 1.2936, acc = 0.2168, auc = 0.6464, f1 = 0.3563, recall=1.0000, subtype_oracle_f1 = 0.1477 subtype_cascade_acc = 0.5856
#   -> no improvement (1/7)
# [ViT-B16][Fold 4][Epoch 04]train loss = 1.7105, acc=0.5259, auc=0.5230,f1 = 0.3106, recall=0.4932,subtype_oracle_f1 = 0.1426, subtype_oracle_acc = 0.5541 | val loss = 1.2657, acc = 0.3438, auc = 0.6803, f1 = 0.3978, recall=1.0000, subtype_oracle_f1 = 0.1477 subtype_cascade_acc = 0.5856
#   -> no improvement (2/7)
# [ViT-B16][Fold 4][Epoch 05]train loss = 1.7022, acc=0.5244, auc=0.5678,f1 = 0.3581, recall=0.6126,subtype_oracle_f1 = 0.1421, subtype_oracle_acc = 0.5495 | val loss = 1.2875, acc = 0.2402, auc = 0.6870, f1 = 0.3633, recall=1.0000, subtype_oracle_f1 = 0.1477 subtype_cascade_acc = 0.5856
#   -> no improvement (3/7)
# [ViT-B16][Fold 4][Epoch 06]train loss = 1.6925, acc=0.5141, auc=0.5889,f1 = 0.3688, recall=0.6554,subtype_oracle_f1 = 0.1411, subtype_oracle_acc = 0.5428 | val loss = 1.1912, acc = 0.6309, auc = 0.6684, f1 = 0.4220, recall=0.6216, subtype_oracle_f1 = 0.1477 subtype_cascade_acc = 0.3874
#   -> best saved by val_loss: ct_cascade_models/ViT-B16_fold4_best.pth
# [ViT-B16][Fold 4][Epoch 07]train loss = 1.6580, acc=0.5210, auc=0.6482,f1 = 0.4217, recall=0.8063,subtype_oracle_f1 = 0.1474, subtype_oracle_acc = 0.5518 | val loss = 1.2579, acc = 0.2734, auc = 0.6492, f1 = 0.3737, recall=1.0000, subtype_oracle_f1 = 0.1477 subtype_cascade_acc = 0.5856
#   -> no improvement (1/7)
# [ViT-B16][Fold 4][Epoch 08]train loss = 1.7326, acc=0.5551, auc=0.5372,f1 = 0.3143, recall=0.4707,subtype_oracle_f1 = 0.1421, subtype_oracle_acc = 0.5090 | val loss = 1.2469, acc = 0.3223, auc = 0.6564, f1 = 0.3902, recall=1.0000, subtype_oracle_f1 = 0.1477 subtype_cascade_acc = 0.5856
#   -> no improvement (2/7)
# [ViT-B16][Fold 4][Epoch 09]train loss = 1.6823, acc=0.5132, auc=0.6175,f1 = 0.4067, recall=0.7703,subtype_oracle_f1 = 0.1459, subtype_oracle_acc = 0.5450 | val loss = 1.1894, acc = 0.5996, auc = 0.6255, f1 = 0.4474, recall=0.7477, subtype_oracle_f1 = 0.1477 subtype_cascade_acc = 0.4775
#   -> best saved by val_loss: ct_cascade_models/ViT-B16_fold4_best.pth
# [ViT-B16][Fold 4][Epoch 10]train loss = 1.6236, acc=0.5054, auc=0.6567,f1 = 0.4367, recall=0.8851,subtype_oracle_f1 = 0.1426, subtype_oracle_acc = 0.5541 | val loss = 1.1099, acc = 0.5605, auc = 0.6865, f1 = 0.4681, recall=0.8919, subtype_oracle_f1 = 0.1477 subtype_cascade_acc = 0.5225
#   -> best saved by val_loss: ct_cascade_models/ViT-B16_fold4_best.pth
# [ViT-B16][Fold 4][Epoch 11]train loss = 1.6056, acc=0.5454, auc=0.6798,f1 = 0.4575, recall=0.8851,subtype_oracle_f1 = 0.1426, subtype_oracle_acc = 0.5541 | val loss = 1.1285, acc = 0.5137, auc = 0.6983, f1 = 0.4622, recall=0.9640, subtype_oracle_f1 = 0.1477 subtype_cascade_acc = 0.5676
#   -> no improvement (1/7)
# [ViT-B16][Fold 4][Epoch 12]train loss = 1.6024, acc=0.5034, auc=0.6642,f1 = 0.4388, recall=0.8964,subtype_oracle_f1 = 0.1426, subtype_oracle_acc = 0.5541 | val loss = 1.1338, acc = 0.5996, auc = 0.7173, f1 = 0.4533, recall=0.7658, subtype_oracle_f1 = 0.1477 subtype_cascade_acc = 0.4775
#   -> no improvement (2/7)
# [ViT-B16][Fold 4][Epoch 13]train loss = 1.6029, acc=0.5424, auc=0.6855,f1 = 0.4553, recall=0.8829,subtype_oracle_f1 = 0.1426, subtype_oracle_acc = 0.5541 | val loss = 1.2346, acc = 0.6270, auc = 0.6632, f1 = 0.4230, recall=0.6306, subtype_oracle_f1 = 0.1804 subtype_cascade_acc = 0.3964
#   -> no improvement (3/7)
# [ViT-B16][Fold 4][Epoch 14]train loss = 1.6268, acc=0.5020, auc=0.6518,f1 = 0.4156, recall=0.8176,subtype_oracle_f1 = 0.1811, subtype_oracle_acc = 0.5180 | val loss = 1.1456, acc = 0.6016, auc = 0.7089, f1 = 0.4574, recall=0.7748, subtype_oracle_f1 = 0.1477 subtype_cascade_acc = 0.4775
#   -> no improvement (4/7)
# [ViT-B16][Fold 4][Epoch 15]train loss = 1.5759, acc=0.5395, auc=0.6924,f1 = 0.4593, recall=0.9032,subtype_oracle_f1 = 0.1426, subtype_oracle_acc = 0.5541 | val loss = 1.3581, acc = 0.6367, auc = 0.6869, f1 = 0.4076, recall=0.5766, subtype_oracle_f1 = 0.1477 subtype_cascade_acc = 0.3514
#   -> no improvement (5/7)
# [ViT-B16][Fold 4][Epoch 16]train loss = 1.5744, acc=0.5507, auc=0.6799,f1 = 0.4521, recall=0.8559,subtype_oracle_f1 = 0.1428, subtype_oracle_acc = 0.5541 | val loss = 1.1315, acc = 0.4746, auc = 0.7111, f1 = 0.4454, recall=0.9730, subtype_oracle_f1 = 0.1477 subtype_cascade_acc = 0.5766
#   -> no improvement (6/7)
# [ViT-B16][Fold 4][Epoch 17]train loss = 1.6020, acc=0.5590, auc=0.6937,f1 = 0.4664, recall=0.8896,subtype_oracle_f1 = 0.1421, subtype_oracle_acc = 0.5495 | val loss = 1.1561, acc = 0.4766, auc = 0.7236, f1 = 0.4463, recall=0.9730, subtype_oracle_f1 = 0.1477 subtype_cascade_acc = 0.5766
#   -> no improvement (7/7)
#   -> early stopping triggered at epoch 17
#
# [ViT-B16][Fold 4] Final Metrics
# malignancy auc: 0.6865, f1 = 0.4681, recall = 0.8919
# subtype oracle acc: 0.5856, macro_f1 = 0.14772727272727273
# subtype cascade acc : 0.5225, gate_recall=0.8919
# Binary cm: [[188 213]
#  [ 12  99]]
# Subtype oracle cm: [[ 0  0  0  0 12]
#  [ 0  0  0  0 10]
#  [ 0  0  0  0 16]
#  [ 0  0  0  0  8]
#  [ 0  0  0  0 65]]
#
# ================================================================================
# Running ViT-B16 | Fold 5
# ================================================================================
# [FOLD 5] Train benign(0): 1606, malignant(1): 444, pos_weight=3.6171, subtype_class_weights = [1.6212999820709229, 0.822700023651123, 1.080899953842163, 1.2527999877929688, 0.2222999930381775]
# subtype_loss_weight = 0.5
# [ViT-B16][Fold 5][Epoch 01]train loss = 1.7683, acc=0.4956, auc=0.5122,f1 = 0.3116, recall=0.5270,subtype_oracle_f1 = 0.1522, subtype_oracle_acc = 0.5293 | val loss = 1.2519, acc = 0.7852, auc = 0.7631, f1 = 0.0678, recall=0.0360, subtype_oracle_f1 = 0.1448 subtype_cascade_acc = 0.0090
#   -> best saved by val_loss: ct_cascade_models/ViT-B16_fold5_best.pth
# [ViT-B16][Fold 5][Epoch 02]train loss = 1.7186, acc=0.5444, auc=0.5296,f1 = 0.3040, recall=0.4595,subtype_oracle_f1 = 0.1434, subtype_oracle_acc = 0.5586 | val loss = 1.2442, acc = 0.7812, auc = 0.7266, f1 = 0.0345, recall=0.0180, subtype_oracle_f1 = 0.1448 subtype_cascade_acc = 0.0090
#   -> best saved by val_loss: ct_cascade_models/ViT-B16_fold5_best.pth
# [ViT-B16][Fold 5][Epoch 03]train loss = 1.7205, acc=0.5151, auc=0.5367,f1 = 0.3266, recall=0.5428,subtype_oracle_f1 = 0.1434, subtype_oracle_acc = 0.5586 | val loss = 1.2331, acc = 0.6016, auc = 0.7340, f1 = 0.4660, recall=0.8018, subtype_oracle_f1 = 0.1448 subtype_cascade_acc = 0.4775
#   -> best saved by val_loss: ct_cascade_models/ViT-B16_fold5_best.pth
# [ViT-B16][Fold 5][Epoch 04]train loss = 1.7360, acc=0.5361, auc=0.5391,f1 = 0.3222, recall=0.5090,subtype_oracle_f1 = 0.1415, subtype_oracle_acc = 0.5473 | val loss = 1.2618, acc = 0.2168, auc = 0.6850, f1 = 0.3563, recall=1.0000, subtype_oracle_f1 = 0.1448 subtype_cascade_acc = 0.5676
#   -> no improvement (1/7)
# [ViT-B16][Fold 5][Epoch 05]train loss = 1.7345, acc=0.5151, auc=0.5838,f1 = 0.3562, recall=0.6194,subtype_oracle_f1 = 0.1434, subtype_oracle_acc = 0.5586 | val loss = 1.2717, acc = 0.7832, auc = 0.6821, f1 = 0.0000, recall=0.0000, subtype_oracle_f1 = 0.1448 subtype_cascade_acc = 0.0000
#   -> no improvement (2/7)
# [ViT-B16][Fold 5][Epoch 06]train loss = 1.6642, acc=0.5434, auc=0.6311,f1 = 0.4038, recall=0.7140,subtype_oracle_f1 = 0.1434, subtype_oracle_acc = 0.5586 | val loss = 1.1927, acc = 0.6152, auc = 0.6903, f1 = 0.4189, recall=0.6396, subtype_oracle_f1 = 0.1448 subtype_cascade_acc = 0.3604
#   -> best saved by val_loss: ct_cascade_models/ViT-B16_fold5_best.pth
# [ViT-B16][Fold 5][Epoch 07]train loss = 1.6843, acc=0.4907, auc=0.5965,f1 = 0.3741, recall=0.7027,subtype_oracle_f1 = 0.1430, subtype_oracle_acc = 0.5563 | val loss = 1.2409, acc = 0.4727, auc = 0.6646, f1 = 0.4255, recall=0.9009, subtype_oracle_f1 = 0.1448 subtype_cascade_acc = 0.5315
#   -> no improvement (1/7)
# [ViT-B16][Fold 5][Epoch 08]train loss = 1.6832, acc=0.5366, auc=0.6258,f1 = 0.4010, recall=0.7162,subtype_oracle_f1 = 0.1430, subtype_oracle_acc = 0.5563 | val loss = 1.2656, acc = 0.2168, auc = 0.6743, f1 = 0.3563, recall=1.0000, subtype_oracle_f1 = 0.1448 subtype_cascade_acc = 0.5676
#   -> no improvement (2/7)
# [ViT-B16][Fold 5][Epoch 09]train loss = 1.6831, acc=0.5512, auc=0.6123,f1 = 0.3716, recall=0.6126,subtype_oracle_f1 = 0.1434, subtype_oracle_acc = 0.5586 | val loss = 1.2294, acc = 0.7832, auc = 0.6749, f1 = 0.0000, recall=0.0000, subtype_oracle_f1 = 0.1448 subtype_cascade_acc = 0.0000
#   -> no improvement (3/7)
# [ViT-B16][Fold 5][Epoch 10]train loss = 1.6750, acc=0.5293, auc=0.6120,f1 = 0.3786, recall=0.6622,subtype_oracle_f1 = 0.1434, subtype_oracle_acc = 0.5586 | val loss = 1.2982, acc = 0.2227, auc = 0.6765, f1 = 0.3581, recall=1.0000, subtype_oracle_f1 = 0.1448 subtype_cascade_acc = 0.5676
#   -> no improvement (4/7)
# [ViT-B16][Fold 5][Epoch 11]train loss = 1.6537, acc=0.4654, auc=0.6077,f1 = 0.4082, recall=0.8514,subtype_oracle_f1 = 0.1434, subtype_oracle_acc = 0.5586 | val loss = 1.1353, acc = 0.6016, auc = 0.6897, f1 = 0.4796, recall=0.8468, subtype_oracle_f1 = 0.1448 subtype_cascade_acc = 0.4775
#   -> best saved by val_loss: ct_cascade_models/ViT-B16_fold5_best.pth
# [ViT-B16][Fold 5][Epoch 12]train loss = 1.6158, acc=0.5278, auc=0.6655,f1 = 0.4292, recall=0.8198,subtype_oracle_f1 = 0.1434, subtype_oracle_acc = 0.5586 | val loss = 1.1364, acc = 0.5254, auc = 0.6801, f1 = 0.4588, recall=0.9279, subtype_oracle_f1 = 0.1448 subtype_cascade_acc = 0.5405
#   -> no improvement (1/7)
# [ViT-B16][Fold 5][Epoch 13]train loss = 1.5539, acc=0.5561, auc=0.6821,f1 = 0.4609, recall=0.8761,subtype_oracle_f1 = 0.1434, subtype_oracle_acc = 0.5586 | val loss = 1.1128, acc = 0.5859, auc = 0.6894, f1 = 0.4752, recall=0.8649, subtype_oracle_f1 = 0.1448 subtype_cascade_acc = 0.4865
#   -> best saved by val_loss: ct_cascade_models/ViT-B16_fold5_best.pth
# [ViT-B16][Fold 5][Epoch 14]train loss = 1.5746, acc=0.5478, auc=0.6914,f1 = 0.4626, recall=0.8986,subtype_oracle_f1 = 0.1434, subtype_oracle_acc = 0.5586 | val loss = 1.1196, acc = 0.5234, auc = 0.7308, f1 = 0.4554, recall=0.9189, subtype_oracle_f1 = 0.1434 subtype_cascade_acc = 0.5315
#   -> no improvement (1/7)
# [ViT-B16][Fold 5][Epoch 15]train loss = 1.5480, acc=0.5434, auc=0.6886,f1 = 0.4558, recall=0.8829,subtype_oracle_f1 = 0.1426, subtype_oracle_acc = 0.5541 | val loss = 1.1286, acc = 0.5156, auc = 0.7362, f1 = 0.4655, recall=0.9730, subtype_oracle_f1 = 0.1448 subtype_cascade_acc = 0.5586
#   -> no improvement (2/7)
# [ViT-B16][Fold 5][Epoch 16]train loss = 1.5656, acc=0.5468, auc=0.6934,f1 = 0.4596, recall=0.8896,subtype_oracle_f1 = 0.1434, subtype_oracle_acc = 0.5586 | val loss = 1.1133, acc = 0.5293, auc = 0.7313, f1 = 0.4609, recall=0.9279, subtype_oracle_f1 = 0.1448 subtype_cascade_acc = 0.5405
#   -> no improvement (3/7)
# [ViT-B16][Fold 5][Epoch 17]train loss = 1.5384, acc=0.5610, auc=0.7068,f1 = 0.4718, recall=0.9054,subtype_oracle_f1 = 0.1434, subtype_oracle_acc = 0.5586 | val loss = 1.1259, acc = 0.5996, auc = 0.7278, f1 = 0.4757, recall=0.8378, subtype_oracle_f1 = 0.1448 subtype_cascade_acc = 0.4685
#   -> no improvement (4/7)
# [ViT-B16][Fold 5][Epoch 18]train loss = 1.5505, acc=0.5488, auc=0.7054,f1 = 0.4600, recall=0.8874,subtype_oracle_f1 = 0.1434, subtype_oracle_acc = 0.5586 | val loss = 1.1054, acc = 0.5449, auc = 0.7414, f1 = 0.4668, recall=0.9189, subtype_oracle_f1 = 0.1448 subtype_cascade_acc = 0.5315
#   -> best saved by val_loss: ct_cascade_models/ViT-B16_fold5_best.pth
# [ViT-B16][Fold 5][Epoch 19]train loss = 1.5688, acc=0.5800, auc=0.7358,f1 = 0.4740, recall=0.8739,subtype_oracle_f1 = 0.1430, subtype_oracle_acc = 0.5563 | val loss = 1.0908, acc = 0.5547, auc = 0.7388, f1 = 0.4648, recall=0.8919, subtype_oracle_f1 = 0.1448 subtype_cascade_acc = 0.5135
#   -> best saved by val_loss: ct_cascade_models/ViT-B16_fold5_best.pth
# [ViT-B16][Fold 5][Epoch 20]train loss = 1.5478, acc=0.5785, auc=0.7165,f1 = 0.4770, recall=0.8874,subtype_oracle_f1 = 0.1426, subtype_oracle_acc = 0.5541 | val loss = 1.1436, acc = 0.4805, auc = 0.7057, f1 = 0.4458, recall=0.9640, subtype_oracle_f1 = 0.1448 subtype_cascade_acc = 0.5586
#   -> no improvement (1/7)
# [ViT-B16][Fold 5][Epoch 21]train loss = 1.5557, acc=0.5741, auc=0.7143,f1 = 0.4699, recall=0.8716,subtype_oracle_f1 = 0.1434, subtype_oracle_acc = 0.5586 | val loss = 1.1082, acc = 0.5254, auc = 0.7022, f1 = 0.4612, recall=0.9369, subtype_oracle_f1 = 0.1448 subtype_cascade_acc = 0.5405
#   -> no improvement (2/7)
# [ViT-B16][Fold 5][Epoch 22]train loss = 1.5467, acc=0.5698, auc=0.7083,f1 = 0.4731, recall=0.8919,subtype_oracle_f1 = 0.1434, subtype_oracle_acc = 0.5586 | val loss = 1.1346, acc = 0.5215, auc = 0.7184, f1 = 0.4568, recall=0.9279, subtype_oracle_f1 = 0.1448 subtype_cascade_acc = 0.5405
#   -> no improvement (3/7)
# [ViT-B16][Fold 5][Epoch 23]train loss = 1.5177, acc=0.5902, auc=0.7345,f1 = 0.4847, recall=0.8896,subtype_oracle_f1 = 0.1434, subtype_oracle_acc = 0.5586 | val loss = 1.1037, acc = 0.5957, auc = 0.7124, f1 = 0.4864, recall=0.8829, subtype_oracle_f1 = 0.1448 subtype_cascade_acc = 0.5045
#   -> no improvement (4/7)
# [ViT-B16][Fold 5][Epoch 24]train loss = 1.5481, acc=0.5639, auc=0.7336,f1 = 0.4704, recall=0.8941,subtype_oracle_f1 = 0.1507, subtype_oracle_acc = 0.5586 | val loss = 1.1253, acc = 0.4824, auc = 0.7071, f1 = 0.4491, recall=0.9730, subtype_oracle_f1 = 0.1448 subtype_cascade_acc = 0.5586
#   -> no improvement (5/7)
# [ViT-B16][Fold 5][Epoch 25]train loss = 1.5286, acc=0.5678, auc=0.7114,f1 = 0.4707, recall=0.8874,subtype_oracle_f1 = 0.1498, subtype_oracle_acc = 0.5541 | val loss = 1.1489, acc = 0.6113, auc = 0.7367, f1 = 0.4721, recall=0.8018, subtype_oracle_f1 = 0.1448 subtype_cascade_acc = 0.4595
#   -> no improvement (6/7)
# [ViT-B16][Fold 5][Epoch 26]train loss = 1.5588, acc=0.5820, auc=0.7286,f1 = 0.4809, recall=0.8941,subtype_oracle_f1 = 0.1493, subtype_oracle_acc = 0.5518 | val loss = 1.1054, acc = 0.5781, auc = 0.7185, f1 = 0.4757, recall=0.8829, subtype_oracle_f1 = 0.1434 subtype_cascade_acc = 0.5045
#   -> no improvement (7/7)
#   -> early stopping triggered at epoch 26
#
# [ViT-B16][Fold 5] Final Metrics
# malignancy auc: 0.7388, f1 = 0.4648, recall = 0.8919
# subtype oracle acc: 0.5676, macro_f1 = 0.14482758620689656
# subtype cascade acc : 0.5135, gate_recall=0.8919
# Binary cm: [[185 216]
#  [ 12  99]]
# Subtype oracle cm: [[ 0  0  0  0  8]
#  [ 0  0  0  0 17]
#  [ 0  0  0  0  9]
#  [ 0  0  0  0 14]
#  [ 0  0  0  0 63]]
#      model  fold   mal acc   mal auc    mal f1  mal recall  \
# 0  ViT-B16     1  0.775828  0.857525  0.599303    0.774775
# 1  ViT-B16     2  0.787524  0.796591  0.551440    0.603604
# 2  ViT-B16     3  0.626953  0.691312  0.443149    0.684685
# 3  ViT-B16     4  0.560547  0.686527  0.468085    0.891892
# 4  ViT-B16     5  0.554688  0.738829  0.464789    0.891892
#
#    subtype_oracle_acc  subtype_oracle_macro_f1  subtype_cascade_acc  \
# 0            0.549550                 0.182012             0.450450
# 1            0.513514                 0.135714             0.288288
# 2            0.594595                 0.149153             0.387387
# 3            0.585586                 0.147727             0.522523
# 4            0.567568                 0.144828             0.513514
#
#    subtype_gate_recall               Binary cm  \
# 0             0.774775   [[312, 90], [25, 86]]
# 1             0.603604   [[337, 65], [44, 67]]
# 2             0.684685  [[245, 156], [35, 76]]
# 3             0.891892  [[188, 213], [12, 99]]
# 4             0.891892  [[185, 216], [12, 99]]
#
#                                    subtype_oracle_cm
# 0  [[0, 0, 0, 0, 9], [0, 0, 0, 0, 20], [0, 1, 0, ...
# 1  [[0, 0, 0, 0, 6], [0, 0, 0, 0, 19], [0, 0, 0, ...
# 2  [[0, 0, 0, 0, 7], [0, 0, 0, 0, 18], [0, 0, 0, ...
# 3  [[0, 0, 0, 0, 12], [0, 0, 0, 0, 10], [0, 0, 0,...
# 4  [[0, 0, 0, 0, 8], [0, 0, 0, 0, 17], [0, 0, 0, ...

# %%
#11 Hybrid
print(">>> Training Hybrid...")
hybrid_cv_df, hybrid_history_df = run_cv_for_model(
    model_name="Hybrid",
    model_type="hybrid",
    build_fn=lambda: build_hybrid_patient_model(load_pretrained=True)
)

display(hybrid_cv_df)
# Out:
# >>> Training Hybrid...
#
# ================================================================================
# Running Hybrid | Fold 1
# ================================================================================
# [FOLD 1] Train benign(0): 1605, malignant(1): 444, pos_weight=3.6149, subtype_class_weights = [1.6541999578475952, 0.8529000282287598, 1.1613999605178833, 1.1139999628067017, 0.2175000011920929]
# subtype_loss_weight = 0.5
# [Hybrid][Fold 1][Epoch 01]train loss = 1.3015, acc=0.7921, auc=0.8814,f1 = 0.6315, recall=0.8221,subtype_oracle_f1 = 0.2570, subtype_oracle_acc = 0.5360 | val loss = 0.6462, acc = 0.8908, auc = 0.9489, f1 = 0.7829, recall=0.9099, subtype_oracle_f1 = 0.1731 subtype_cascade_acc = 0.4955
#   -> best saved by val_loss: ct_cascade_models/Hybrid_fold1_best.pth
# [Hybrid][Fold 1][Epoch 02]train loss = 1.0096, acc=0.8878, auc=0.9554,f1 = 0.7784, recall=0.9099,subtype_oracle_f1 = 0.3003, subtype_oracle_acc = 0.5541 | val loss = 0.7476, acc = 0.9045, auc = 0.9500, f1 = 0.7879, recall=0.8198, subtype_oracle_f1 = 0.2364 subtype_cascade_acc = 0.4324
#   -> no improvement (1/7)
# [Hybrid][Fold 1][Epoch 03]train loss = 0.8993, acc=0.9107, auc=0.9703,f1 = 0.8179, recall=0.9257,subtype_oracle_f1 = 0.3412, subtype_oracle_acc = 0.5811 | val loss = 0.5337, acc = 0.9220, auc = 0.9723, f1 = 0.8291, recall=0.8739, subtype_oracle_f1 = 0.3485 subtype_cascade_acc = 0.4775
#   -> best saved by val_loss: ct_cascade_models/Hybrid_fold1_best.pth
# [Hybrid][Fold 1][Epoch 04]train loss = 0.6541, acc=0.9492, auc=0.9893,f1 = 0.8919, recall=0.9662,subtype_oracle_f1 = 0.4447, subtype_oracle_acc = 0.6351 | val loss = 0.7437, acc = 0.9415, auc = 0.9682, f1 = 0.8611, recall=0.8378, subtype_oracle_f1 = 0.3145 subtype_cascade_acc = 0.3964
#   -> no improvement (1/7)
# [Hybrid][Fold 1][Epoch 05]train loss = 0.5445, acc=0.9639, auc=0.9927,f1 = 0.9208, recall=0.9685,subtype_oracle_f1 = 0.5548, subtype_oracle_acc = 0.7027 | val loss = 0.5928, acc = 0.9123, auc = 0.9657, f1 = 0.8148, recall=0.8919, subtype_oracle_f1 = 0.3695 subtype_cascade_acc = 0.4595
#   -> no improvement (2/7)
# [Hybrid][Fold 1][Epoch 06]train loss = 0.4268, acc=0.9771, auc=0.9971,f1 = 0.9490, recall=0.9842,subtype_oracle_f1 = 0.6794, subtype_oracle_acc = 0.7725 | val loss = 0.7003, acc = 0.8811, auc = 0.9682, f1 = 0.7732, recall=0.9369, subtype_oracle_f1 = 0.3643 subtype_cascade_acc = 0.4865
#   -> no improvement (3/7)
# [Hybrid][Fold 1][Epoch 07]train loss = 0.2821, acc=0.9839, auc=0.9968,f1 = 0.9637, recall=0.9865,subtype_oracle_f1 = 0.7900, subtype_oracle_acc = 0.8468 | val loss = 0.7700, acc = 0.9513, auc = 0.9764, f1 = 0.8815, recall=0.8378, subtype_oracle_f1 = 0.3436 subtype_cascade_acc = 0.4054
#   -> no improvement (4/7)
# [Hybrid][Fold 1][Epoch 08]train loss = 0.2341, acc=0.9819, auc=0.9974,f1 = 0.9596, recall=0.9887,subtype_oracle_f1 = 0.8338, subtype_oracle_acc = 0.8874 | val loss = 0.7815, acc = 0.8908, auc = 0.9622, f1 = 0.7879, recall=0.9369, subtype_oracle_f1 = 0.3671 subtype_cascade_acc = 0.4955
#   -> no improvement (5/7)
# [Hybrid][Fold 1][Epoch 09]train loss = 0.2683, acc=0.9776, auc=0.9967,f1 = 0.9499, recall=0.9820,subtype_oracle_f1 = 0.8578, subtype_oracle_acc = 0.8941 | val loss = 0.7214, acc = 0.9396, auc = 0.9750, f1 = 0.8646, recall=0.8919, subtype_oracle_f1 = 0.3198 subtype_cascade_acc = 0.3964
#   -> no improvement (6/7)
# [Hybrid][Fold 1][Epoch 10]train loss = 0.1051, acc=0.9898, auc=0.9991,f1 = 0.9766, recall=0.9887,subtype_oracle_f1 = 0.9550, subtype_oracle_acc = 0.9662 | val loss = 0.8774, acc = 0.9298, auc = 0.9696, f1 = 0.8364, recall=0.8288, subtype_oracle_f1 = 0.2531 subtype_cascade_acc = 0.4414
#   -> no improvement (7/7)
#   -> early stopping triggered at epoch 10
#
# [Hybrid][Fold 1] Final Metrics
# malignancy auc: 0.9723, f1 = 0.8291, recall = 0.8739
# subtype oracle acc: 0.5225, macro_f1 = 0.34853423882286366
# subtype cascade acc : 0.4775, gate_recall=0.8739
# Binary cm: [[376  26]
#  [ 14  97]]
# Subtype oracle cm: [[ 0  0  5  0  4]
#  [ 0  6  3  1 10]
#  [ 0  2  6  1  4]
#  [ 0  2  1  3  3]
#  [ 0  6 10  1 43]]
#
# ================================================================================
# Running Hybrid | Fold 2
# ================================================================================
# [FOLD 2] Train benign(0): 1605, malignant(1): 444, pos_weight=3.6149, subtype_class_weights = [1.5044000148773193, 0.8331999778747559, 1.1282999515533447, 1.3208999633789062, 0.21320000290870667]
# subtype_loss_weight = 0.5
# [Hybrid][Fold 2][Epoch 01]train loss = 1.2722, acc=0.8214, auc=0.8944,f1 = 0.6715, recall=0.8423,subtype_oracle_f1 = 0.2084, subtype_oracle_acc = 0.5180 | val loss = 0.9842, acc = 0.8791, auc = 0.9304, f1 = 0.7019, recall=0.6577, subtype_oracle_f1 = 0.1330 subtype_cascade_acc = 0.1261
#   -> best saved by val_loss: ct_cascade_models/Hybrid_fold2_best.pth
# [Hybrid][Fold 2][Epoch 02]train loss = 0.9714, acc=0.9087, auc=0.9645,f1 = 0.8128, recall=0.9144,subtype_oracle_f1 = 0.2863, subtype_oracle_acc = 0.5248 | val loss = 0.6014, acc = 0.8986, auc = 0.9684, f1 = 0.7886, recall=0.8739, subtype_oracle_f1 = 0.2024 subtype_cascade_acc = 0.4324
#   -> best saved by val_loss: ct_cascade_models/Hybrid_fold2_best.pth
# [Hybrid][Fold 2][Epoch 03]train loss = 0.7986, acc=0.9366, auc=0.9828,f1 = 0.8665, recall=0.9505,subtype_oracle_f1 = 0.3469, subtype_oracle_acc = 0.5878 | val loss = 0.8501, acc = 0.7680, auc = 0.9520, f1 = 0.6426, recall=0.9640, subtype_oracle_f1 = 0.2765 subtype_cascade_acc = 0.4955
#   -> no improvement (1/7)
# [Hybrid][Fold 2][Epoch 04]train loss = 0.7318, acc=0.9444, auc=0.9823,f1 = 0.8792, recall=0.9347,subtype_oracle_f1 = 0.3760, subtype_oracle_acc = 0.5901 | val loss = 0.7205, acc = 0.9181, auc = 0.9703, f1 = 0.8125, recall=0.8198, subtype_oracle_f1 = 0.2182 subtype_cascade_acc = 0.4234
#   -> no improvement (2/7)
# [Hybrid][Fold 2][Epoch 05]train loss = 0.5416, acc=0.9722, auc=0.9954,f1 = 0.9380, recall=0.9707,subtype_oracle_f1 = 0.5150, subtype_oracle_acc = 0.6779 | val loss = 0.7164, acc = 0.9220, auc = 0.9700, f1 = 0.8276, recall=0.8649, subtype_oracle_f1 = 0.2412 subtype_cascade_acc = 0.4414
#   -> no improvement (3/7)
# [Hybrid][Fold 2][Epoch 06]train loss = 0.3964, acc=0.9790, auc=0.9965,f1 = 0.9530, recall=0.9820,subtype_oracle_f1 = 0.6840, subtype_oracle_acc = 0.7928 | val loss = 0.8668, acc = 0.9084, auc = 0.9619, f1 = 0.8033, recall=0.8649, subtype_oracle_f1 = 0.3934 subtype_cascade_acc = 0.4865
#   -> no improvement (4/7)
# [Hybrid][Fold 2][Epoch 07]train loss = 0.3350, acc=0.9819, auc=0.9977,f1 = 0.9593, recall=0.9820,subtype_oracle_f1 = 0.7790, subtype_oracle_acc = 0.8423 | val loss = 1.1805, acc = 0.9045, auc = 0.9394, f1 = 0.7803, recall=0.7838, subtype_oracle_f1 = 0.3920 subtype_cascade_acc = 0.4324
#   -> no improvement (5/7)
# [Hybrid][Fold 2][Epoch 08]train loss = 0.2382, acc=0.9883, auc=0.9991,f1 = 0.9734, recall=0.9887,subtype_oracle_f1 = 0.8318, subtype_oracle_acc = 0.8829 | val loss = 1.3526, acc = 0.7778, auc = 0.9383, f1 = 0.6524, recall=0.9640, subtype_oracle_f1 = 0.3949 subtype_cascade_acc = 0.5946
#   -> no improvement (6/7)
# [Hybrid][Fold 2][Epoch 09]train loss = 0.1741, acc=0.9888, auc=0.9988,f1 = 0.9746, recall=0.9932,subtype_oracle_f1 = 0.9132, subtype_oracle_acc = 0.9347 | val loss = 0.9827, acc = 0.9181, auc = 0.9493, f1 = 0.8205, recall=0.8649, subtype_oracle_f1 = 0.3579 subtype_cascade_acc = 0.4775
#   -> no improvement (7/7)
#   -> early stopping triggered at epoch 9
#
# [Hybrid][Fold 2] Final Metrics
# malignancy auc: 0.9684, f1 = 0.7886, recall = 0.8739
# subtype oracle acc: 0.4595, macro_f1 = 0.2024160441483276
# subtype cascade acc : 0.4324, gate_recall=0.8739
# Binary cm: [[364  38]
#  [ 14  97]]
# Subtype oracle cm: [[ 0  2  1  0  3]
#  [ 0  5  3  0 11]
#  [ 0  7  0  0  5]
#  [ 0  9  1  1  6]
#  [ 0 10  2  0 45]]
#
# ================================================================================
# Running Hybrid | Fold 3
# ================================================================================
# [FOLD 3] Train benign(0): 1606, malignant(1): 444, pos_weight=3.6171, subtype_class_weights = [1.6117000579833984, 0.8547000288963318, 1.1282000541687012, 1.1751999855041504, 0.23019999265670776]
# subtype_loss_weight = 0.5
# [Hybrid][Fold 3][Epoch 01]train loss = 1.3116, acc=0.8366, auc=0.8957,f1 = 0.6831, recall=0.8131,subtype_oracle_f1 = 0.2037, subtype_oracle_acc = 0.4685 | val loss = 0.6543, acc = 0.9062, auc = 0.9536, f1 = 0.7949, recall=0.8378, subtype_oracle_f1 = 0.1842 subtype_cascade_acc = 0.5225
#   -> best saved by val_loss: ct_cascade_models/Hybrid_fold3_best.pth
# [Hybrid][Fold 3][Epoch 02]train loss = 0.9740, acc=0.9122, auc=0.9646,f1 = 0.8193, recall=0.9189,subtype_oracle_f1 = 0.2670, subtype_oracle_acc = 0.5541 | val loss = 0.6952, acc = 0.8828, auc = 0.9474, f1 = 0.7521, recall=0.8198, subtype_oracle_f1 = 0.3248 subtype_cascade_acc = 0.4775
#   -> no improvement (1/7)
# [Hybrid][Fold 3][Epoch 03]train loss = 0.8027, acc=0.9380, auc=0.9791,f1 = 0.8687, recall=0.9459,subtype_oracle_f1 = 0.3718, subtype_oracle_acc = 0.5946 | val loss = 0.5388, acc = 0.9160, auc = 0.9699, f1 = 0.8216, recall=0.8919, subtype_oracle_f1 = 0.3010 subtype_cascade_acc = 0.5225
#   -> best saved by val_loss: ct_cascade_models/Hybrid_fold3_best.pth
# [Hybrid][Fold 3][Epoch 04]train loss = 0.6378, acc=0.9629, auc=0.9908,f1 = 0.9190, recall=0.9707,subtype_oracle_f1 = 0.4701, subtype_oracle_acc = 0.6419 | val loss = 0.8033, acc = 0.9023, auc = 0.9537, f1 = 0.7788, recall=0.7928, subtype_oracle_f1 = 0.3766 subtype_cascade_acc = 0.4865
#   -> no improvement (1/7)
# [Hybrid][Fold 3][Epoch 05]train loss = 0.4633, acc=0.9820, auc=0.9952,f1 = 0.9593, recall=0.9820,subtype_oracle_f1 = 0.6144, subtype_oracle_acc = 0.7117 | val loss = 0.5481, acc = 0.9082, auc = 0.9788, f1 = 0.8171, recall=0.9459, subtype_oracle_f1 = 0.3164 subtype_cascade_acc = 0.3874
#   -> no improvement (2/7)
# [Hybrid][Fold 3][Epoch 06]train loss = 0.3880, acc=0.9727, auc=0.9948,f1 = 0.9389, recall=0.9685,subtype_oracle_f1 = 0.7285, subtype_oracle_acc = 0.7973 | val loss = 1.1324, acc = 0.9062, auc = 0.9326, f1 = 0.7736, recall=0.7387, subtype_oracle_f1 = 0.3472 subtype_cascade_acc = 0.3874
#   -> no improvement (3/7)
# [Hybrid][Fold 3][Epoch 07]train loss = 0.3359, acc=0.9654, auc=0.9954,f1 = 0.9239, recall=0.9707,subtype_oracle_f1 = 0.8170, subtype_oracle_acc = 0.8536 | val loss = 0.7778, acc = 0.9102, auc = 0.9634, f1 = 0.8130, recall=0.9009, subtype_oracle_f1 = 0.3436 subtype_cascade_acc = 0.5766
#   -> no improvement (4/7)
# [Hybrid][Fold 3][Epoch 08]train loss = 0.1481, acc=0.9898, auc=0.9994,f1 = 0.9767, recall=0.9932,subtype_oracle_f1 = 0.8982, subtype_oracle_acc = 0.9257 | val loss = 0.9136, acc = 0.9082, auc = 0.9592, f1 = 0.8066, recall=0.8829, subtype_oracle_f1 = 0.3655 subtype_cascade_acc = 0.5135
#   -> no improvement (5/7)
# [Hybrid][Fold 3][Epoch 09]train loss = 0.0763, acc=0.9951, auc=0.9999,f1 = 0.9888, recall=0.9977,subtype_oracle_f1 = 0.9493, subtype_oracle_acc = 0.9617 | val loss = 1.0420, acc = 0.9062, auc = 0.9608, f1 = 0.8017, recall=0.8739, subtype_oracle_f1 = 0.3449 subtype_cascade_acc = 0.5225
#   -> no improvement (6/7)
# [Hybrid][Fold 3][Epoch 10]train loss = 0.0557, acc=0.9980, auc=0.9999,f1 = 0.9955, recall=0.9977,subtype_oracle_f1 = 0.9639, subtype_oracle_acc = 0.9685 | val loss = 1.2798, acc = 0.9180, auc = 0.9676, f1 = 0.8073, recall=0.7928, subtype_oracle_f1 = 0.3117 subtype_cascade_acc = 0.3874
#   -> no improvement (7/7)
#   -> early stopping triggered at epoch 10
#
# [Hybrid][Fold 3] Final Metrics
# malignancy auc: 0.9699, f1 = 0.8216, recall = 0.8919
# subtype oracle acc: 0.5946, macro_f1 = 0.3010467793076489
# subtype cascade acc : 0.5225, gate_recall=0.8919
# Binary cm: [[370  31]
#  [ 12  99]]
# Subtype oracle cm: [[ 0  2  0  0  5]
#  [ 0 11  1  1  5]
#  [ 0  2  2  0  6]
#  [ 0  2  0  0  8]
#  [ 1 11  1  0 53]]
#
# ================================================================================
# Running Hybrid | Fold 4
# ================================================================================
# [FOLD 4] Train benign(0): 1606, malignant(1): 444, pos_weight=3.6171, subtype_class_weights = [1.7798999547958374, 0.7215999960899353, 1.2136000394821167, 1.0678999423980713, 0.21709999442100525]
# subtype_loss_weight = 0.5
# [Hybrid][Fold 4][Epoch 01]train loss = 1.3529, acc=0.7927, auc=0.8723,f1 = 0.6236, recall=0.7928,subtype_oracle_f1 = 0.1991, subtype_oracle_acc = 0.4910 | val loss = 0.7873, acc = 0.7852, auc = 0.9589, f1 = 0.6605, recall=0.9640, subtype_oracle_f1 = 0.2048 subtype_cascade_acc = 0.5225
#   -> best saved by val_loss: ct_cascade_models/Hybrid_fold4_best.pth
# [Hybrid][Fold 4][Epoch 02]train loss = 0.9880, acc=0.8995, auc=0.9628,f1 = 0.7956, recall=0.9032,subtype_oracle_f1 = 0.2632, subtype_oracle_acc = 0.5158 | val loss = 0.5867, acc = 0.8828, auc = 0.9652, f1 = 0.7744, recall=0.9279, subtype_oracle_f1 = 0.2328 subtype_cascade_acc = 0.3514
#   -> best saved by val_loss: ct_cascade_models/Hybrid_fold4_best.pth
# [Hybrid][Fold 4][Epoch 03]train loss = 0.7871, acc=0.9263, auc=0.9819,f1 = 0.8476, recall=0.9459,subtype_oracle_f1 = 0.3463, subtype_oracle_acc = 0.5563 | val loss = 0.4922, acc = 0.9082, auc = 0.9785, f1 = 0.8127, recall=0.9189, subtype_oracle_f1 = 0.1873 subtype_cascade_acc = 0.2973
#   -> best saved by val_loss: ct_cascade_models/Hybrid_fold4_best.pth
# [Hybrid][Fold 4][Epoch 04]train loss = 0.6782, acc=0.9551, auc=0.9895,f1 = 0.9017, recall=0.9505,subtype_oracle_f1 = 0.4574, subtype_oracle_acc = 0.6261 | val loss = 0.4952, acc = 0.9219, auc = 0.9772, f1 = 0.8319, recall=0.8919, subtype_oracle_f1 = 0.2329 subtype_cascade_acc = 0.3694
#   -> no improvement (1/7)
# [Hybrid][Fold 4][Epoch 05]train loss = 0.5722, acc=0.9595, auc=0.9930,f1 = 0.9118, recall=0.9662,subtype_oracle_f1 = 0.5663, subtype_oracle_acc = 0.6959 | val loss = 0.6311, acc = 0.8926, auc = 0.9753, f1 = 0.7985, recall=0.9820, subtype_oracle_f1 = 0.1998 subtype_cascade_acc = 0.4775
#   -> no improvement (2/7)
# [Hybrid][Fold 4][Epoch 06]train loss = 0.3930, acc=0.9771, auc=0.9970,f1 = 0.9489, recall=0.9820,subtype_oracle_f1 = 0.7001, subtype_oracle_acc = 0.7860 | val loss = 1.0055, acc = 0.9180, auc = 0.9705, f1 = 0.7921, recall=0.7207, subtype_oracle_f1 = 0.3379 subtype_cascade_acc = 0.4324
#   -> no improvement (3/7)
# [Hybrid][Fold 4][Epoch 07]train loss = 0.2921, acc=0.9829, auc=0.9984,f1 = 0.9614, recall=0.9820,subtype_oracle_f1 = 0.7829, subtype_oracle_acc = 0.8356 | val loss = 0.9309, acc = 0.9277, auc = 0.9753, f1 = 0.8326, recall=0.8288, subtype_oracle_f1 = 0.2838 subtype_cascade_acc = 0.4595
#   -> no improvement (4/7)
# [Hybrid][Fold 4][Epoch 08]train loss = 0.1706, acc=0.9907, auc=0.9989,f1 = 0.9789, recall=0.9932,subtype_oracle_f1 = 0.8708, subtype_oracle_acc = 0.9099 | val loss = 0.8623, acc = 0.9102, auc = 0.9706, f1 = 0.8160, recall=0.9189, subtype_oracle_f1 = 0.3538 subtype_cascade_acc = 0.5315
#   -> no improvement (5/7)
# [Hybrid][Fold 4][Epoch 09]train loss = 0.0898, acc=0.9932, auc=0.9995,f1 = 0.9844, recall=0.9977,subtype_oracle_f1 = 0.9334, subtype_oracle_acc = 0.9482 | val loss = 1.1871, acc = 0.9316, auc = 0.9761, f1 = 0.8341, recall=0.7928, subtype_oracle_f1 = 0.3427 subtype_cascade_acc = 0.4865
#   -> no improvement (6/7)
# [Hybrid][Fold 4][Epoch 10]train loss = 0.1493, acc=0.9893, auc=0.9990,f1 = 0.9756, recall=0.9910,subtype_oracle_f1 = 0.9063, subtype_oracle_acc = 0.9302 | val loss = 0.9704, acc = 0.9297, auc = 0.9736, f1 = 0.8421, recall=0.8649, subtype_oracle_f1 = 0.3224 subtype_cascade_acc = 0.4324
#   -> no improvement (7/7)
#   -> early stopping triggered at epoch 10
#
# [Hybrid][Fold 4] Final Metrics
# malignancy auc: 0.9785, f1 = 0.8127, recall = 0.9189
# subtype oracle acc: 0.2973, macro_f1 = 0.18727272727272726
# subtype cascade acc : 0.2973, gate_recall=0.9189
# Binary cm: [[363  38]
#  [  9 102]]
# Subtype oracle cm: [[ 0  6  2  2  2]
#  [ 0  3  3  4  0]
#  [ 0  2  9  3  2]
#  [ 0  4  4  0  0]
#  [ 0 19 20  5 21]]
#
# ================================================================================
# Running Hybrid | Fold 5
# ================================================================================
# [FOLD 5] Train benign(0): 1606, malignant(1): 444, pos_weight=3.6171, subtype_class_weights = [1.6212999820709229, 0.822700023651123, 1.080899953842163, 1.2527999877929688, 0.2222999930381775]
# subtype_loss_weight = 0.5
# [Hybrid][Fold 5][Epoch 01]train loss = 1.2965, acc=0.8249, auc=0.8940,f1 = 0.6733, recall=0.8333,subtype_oracle_f1 = 0.2441, subtype_oracle_acc = 0.5090 | val loss = 0.7380, acc = 0.8867, auc = 0.9407, f1 = 0.7500, recall=0.7838, subtype_oracle_f1 = 0.1974 subtype_cascade_acc = 0.4685
#   -> best saved by val_loss: ct_cascade_models/Hybrid_fold5_best.pth
# [Hybrid][Fold 5][Epoch 02]train loss = 0.9946, acc=0.9073, auc=0.9646,f1 = 0.8065, recall=0.8919,subtype_oracle_f1 = 0.2814, subtype_oracle_acc = 0.5203 | val loss = 0.6673, acc = 0.9043, auc = 0.9477, f1 = 0.7841, recall=0.8018, subtype_oracle_f1 = 0.3365 subtype_cascade_acc = 0.4234
#   -> best saved by val_loss: ct_cascade_models/Hybrid_fold5_best.pth
# [Hybrid][Fold 5][Epoch 03]train loss = 0.7990, acc=0.9361, auc=0.9841,f1 = 0.8645, recall=0.9414,subtype_oracle_f1 = 0.3323, subtype_oracle_acc = 0.5541 | val loss = 0.9061, acc = 0.9062, auc = 0.9472, f1 = 0.7692, recall=0.7207, subtype_oracle_f1 = 0.2610 subtype_cascade_acc = 0.4955
#   -> no improvement (1/7)
# [Hybrid][Fold 5][Epoch 04]train loss = 0.6367, acc=0.9580, auc=0.9901,f1 = 0.9091, recall=0.9685,subtype_oracle_f1 = 0.4691, subtype_oracle_acc = 0.6149 | val loss = 0.7905, acc = 0.8965, auc = 0.9430, f1 = 0.7819, recall=0.8559, subtype_oracle_f1 = 0.2449 subtype_cascade_acc = 0.3694
#   -> no improvement (2/7)
# [Hybrid][Fold 5][Epoch 05]train loss = 0.5454, acc=0.9717, auc=0.9944,f1 = 0.9375, recall=0.9797,subtype_oracle_f1 = 0.5786, subtype_oracle_acc = 0.6982 | val loss = 1.4144, acc = 0.8965, auc = 0.9576, f1 = 0.7072, recall=0.5766, subtype_oracle_f1 = 0.2273 subtype_cascade_acc = 0.2162
#   -> no improvement (3/7)
# [Hybrid][Fold 5][Epoch 06]train loss = 0.3261, acc=0.9756, auc=0.9975,f1 = 0.9455, recall=0.9775,subtype_oracle_f1 = 0.7790, subtype_oracle_acc = 0.8356 | val loss = 0.8951, acc = 0.9121, auc = 0.9536, f1 = 0.8000, recall=0.8108, subtype_oracle_f1 = 0.2873 subtype_cascade_acc = 0.5045
#   -> no improvement (4/7)
# [Hybrid][Fold 5][Epoch 07]train loss = 0.2208, acc=0.9878, auc=0.9989,f1 = 0.9723, recall=0.9887,subtype_oracle_f1 = 0.8362, subtype_oracle_acc = 0.8761 | val loss = 1.2323, acc = 0.8965, auc = 0.9396, f1 = 0.7558, recall=0.7387, subtype_oracle_f1 = 0.3034 subtype_cascade_acc = 0.4144
#   -> no improvement (5/7)
# [Hybrid][Fold 5][Epoch 08]train loss = 0.1297, acc=0.9888, auc=0.9985,f1 = 0.9745, recall=0.9887,subtype_oracle_f1 = 0.9121, subtype_oracle_acc = 0.9369 | val loss = 1.0633, acc = 0.9141, auc = 0.9617, f1 = 0.8053, recall=0.8198, subtype_oracle_f1 = 0.2813 subtype_cascade_acc = 0.4775
#   -> no improvement (6/7)
# [Hybrid][Fold 5][Epoch 09]train loss = 0.0580, acc=0.9985, auc=1.0000,f1 = 0.9966, recall=0.9977,subtype_oracle_f1 = 0.9538, subtype_oracle_acc = 0.9640 | val loss = 1.1516, acc = 0.9043, auc = 0.9502, f1 = 0.7932, recall=0.8468, subtype_oracle_f1 = 0.3572 subtype_cascade_acc = 0.5225
#   -> no improvement (7/7)
#   -> early stopping triggered at epoch 9
#
# [Hybrid][Fold 5] Final Metrics
# malignancy auc: 0.9477, f1 = 0.7841, recall = 0.8018
# subtype oracle acc: 0.4865, macro_f1 = 0.3364761904761905
# subtype cascade acc : 0.4234, gate_recall=0.8018
# Binary cm: [[374  27]
#  [ 22  89]]
# Subtype oracle cm: [[ 0  1  4  1  2]
#  [ 0  5  4  3  5]
#  [ 0  3  5  0  1]
#  [ 0  2  3  6  3]
#  [ 0  7 17  1 38]]
#     model  fold   mal acc   mal auc    mal f1  mal recall  subtype_oracle_acc  \
# 0  Hybrid     1  0.922027  0.972278  0.829060    0.873874            0.522523
# 1  Hybrid     2  0.898635  0.968401  0.788618    0.873874            0.459459
# 2  Hybrid     3  0.916016  0.969918  0.821577    0.891892            0.594595
# 3  Hybrid     4  0.908203  0.978500  0.812749    0.918919            0.297297
# 4  Hybrid     5  0.904297  0.947676  0.784141    0.801802            0.486486
#
#    subtype_oracle_macro_f1  subtype_cascade_acc  subtype_gate_recall  \
# 0                 0.348534             0.477477             0.873874
# 1                 0.202416             0.432432             0.873874
# 2                 0.301047             0.522523             0.891892
# 3                 0.187273             0.297297             0.918919
# 4                 0.336476             0.423423             0.801802
#
#                Binary cm                                  subtype_oracle_cm
# 0  [[376, 26], [14, 97]]  [[0, 0, 5, 0, 4], [0, 6, 3, 1, 10], [0, 2, 6, ...
# 1  [[364, 38], [14, 97]]  [[0, 2, 1, 0, 3], [0, 5, 3, 0, 11], [0, 7, 0, ...
# 2  [[370, 31], [12, 99]]  [[0, 2, 0, 0, 5], [0, 11, 1, 1, 5], [0, 2, 2, ...
# 3  [[363, 38], [9, 102]]  [[0, 6, 2, 2, 2], [0, 3, 3, 4, 0], [0, 2, 9, 3...
# 4  [[374, 27], [22, 89]]  [[0, 1, 4, 1, 2], [0, 5, 4, 3, 5], [0, 3, 5, 0...

# %%
#13 5-fold 평균 +- 표준편차

all_cv_df = pd.concat([resnet_cv_df, vit_cv_df, hybrid_cv_df], ignore_index=True)

summary_df = (
    all_cv_df.groupby("model")[["mal auc", "mal f1", "mal recall", "subtype_oracle_acc", "subtype_oracle_macro_f1", "subtype_cascade_acc", "subtype_gate_recall"]]
    .agg(["mean", "std"])
)

display(summary_df)
# Out:
#            mal auc              mal f1           mal recall            \
#               mean       std      mean       std       mean       std
# model
# Hybrid    0.967355  0.011655  0.807229  0.019952   0.872072  0.043393
# ResNet50  0.959313  0.015731  0.804227  0.042793   0.891892  0.021128
# ViT-B16   0.754157  0.072877  0.505353  0.066810   0.769369  0.127183
#
#          subtype_oracle_acc           subtype_oracle_macro_f1            \
#                        mean       std                    mean       std
# model
# Hybrid             0.472072  0.110080                0.275149  0.075547
# ResNet50           0.554955  0.059282                0.304897  0.052853
# ViT-B16            0.562162  0.032232                0.151887  0.017633
#
#          subtype_cascade_acc           subtype_gate_recall
#                         mean       std                mean       std
# model
# Hybrid              0.430631  0.084368            0.872072  0.043393
# ResNet50            0.524324  0.045671            0.891892  0.021128
# ViT-B16             0.432432  0.097239            0.769369  0.127183

# %%
import matplotlib.pyplot as plt

def plot_one_model_by_fold(history_df, model_name):
    folds = sorted(history_df["fold"].unique())

    plt.figure(figsize=(12, 5))
    
    plt.subplot(1,2,1)
    for fold in folds:
        df_fold = history_df[history_df["fold"] == fold].sort_values("epoch")
        plt.plot(df_fold["epoch"], df_fold['train_loss'], linestyle='--', alpha = 0.7, label=f'Fold{fold} Train')
        plt.plot(df_fold["epoch"], df_fold['val_loss'], alpha = 0.7, label=f'Fold{fold} Val')
    plt.title(f"{model_name} - Loss by Fold")
    plt.xlabel("Epochs")
    plt.ylabel("Loss")
    plt.legend(fontsize=8)

    plt.subplot(1, 2, 2)
    for fold in folds:
        df_fold = history_df[history_df["fold"] == fold].sort_values("epoch")
        plt.plot(df_fold["epoch"], df_fold["val_auc"], alpha = 0.8, label = f"Fold{fold}")

    plt.title(f"{model_name} - Val ROC-AUC by Fold")
    plt.xlabel("Epoch")
    plt.ylabel("AUC")
    plt.legend(fontsize=8)

    plt.tight_layout()
    plt.show()

# %%
plot_one_model_by_fold(resnet_history_df, "ResNet50")
plot_one_model_by_fold(vit_history_df, "ViT")
plot_one_model_by_fold(hybrid_history_df, "Hybrid")
